# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">DA & DVwPY</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">The Exploratory Data Analysis (EDA) Project</p>
#
# <img src=https://i.ibb.co/wJW61Y2/Used-cars.jpg width="700" height="200">
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">AutoScout Car Price Prediction EDA</p>

# %% [markdown]
# ## Introduction
# Welcome to "***AutoScout Exploratory Data Analysis (EDA) Project***". This is the project of completing ***Data Analysis & Data Visualization*** Courses and a successful hand-over is mandatory for getting certification for both courses. **Auto Scout** data used in this project scraped from the Website of an online car trading company in 2022, and contains many features of 13 different car makes including 594 models. In this project, you will have the opportunity to apply many commonly used algorithms for Data Cleaning and Exploratory Data Analysis by using a variety of Python libraries, such as Numpy, Pandas, Matplotlib, Seaborn, Scipy, and then you will get a clean dataset for your analysis and pretictive modelling in Machine Learning Path. So you will have the chance to use all the skills you have already learned in the Data Analysis and Visualization courses.
#
# **``In this context, the project consists of 3 parts in general:``**
# * **The first part** is related to ``'Data Cleaning'``. It deals with Incorrect Headers, Incorrect Format, Anomalies, and Dropping useless columns.
# * **The second part** is related to ``'Filling Data'``, in other words 'Imputation'. It deals with Missing Values. Categorical to numeric transformation, Encoding, is done as well.
# * **The third part** is related to ``'Handling Outliers of Data'`` via Visualization libraries. So, some insights will be extracted.
#
# **``SPECIAL NOTE:``**  However, you are ``free to create your own style``. You do ``NOT`` have to stick to the steps above. Nevertheless, we, the DA & DV instructors, recommend you study each part separately to create a source notebook for your further studies.
#
# In order to build your Portfolio in terms of the GitHub account, you need to push your solution file up to your own repository.
#
# Please after solving the task, commit your notebook to GitHub and submit its link to LMS page where the project is settled down.
#
# **BE NOTED:** Please ``DO NOT FORGET`` to click the submit button.
#
# ### Some Reminders on Exploratory data analysis (EDA)
#
# Exploratory data analysis (EDA) is an especially important activity in the routine of a data analyst or scientist. It enables an in depth understanding of the dataset, define or discard hypotheses and create predictive models on a solid basis. It uses data manipulation techniques and several statistical tools to describe and understand the relationship between variables and how these can impact business. By means of EDA, we can obtain meaningful insights that can impact analysis under the following questions (If a checklist is good enough for pilots to use every flight, it’s good enough for data scientists to use with every dataset).
# 1. What question are you trying to solve (or prove wrong)?
# 2. What kind of data do you have?
# 3. What’s missing from the data?
# 4. Where are the outliers?
# 5. How can you add, change or remove features to get more out of your data?
#
# **``Exploratory data analysis (EDA)``** is often an **iterative brainstorming process** where you pose a question, review the data, and develop further questions to investigate before beginning model development work. The image below shows how the brainstorming phase is connected with that of understanding the variables and how this in turn is connected again with the brainstorming phase.<br>
#
# <img src=https://i.ibb.co/k0MC950/EDA-Process.png width="300" height="100">
#
# [Image Credit: Andrew D.](https://towardsdatascience.com/exploratory-data-analysis-in-python-a-step-by-step-process-d0dfa6bf94ee)

# %% [markdown]
# # <p style="background-color:#FF6961; font-family:newtimeroman;color:#FFF9ED;font-size:220%; text-align:center; border-radius: 15px 55px;">🚗AutoScout Exploratory Data Analysis (EDA) Project 🚚</p>

# %% [markdown]
# <h3 style="text-align:center;font-size:200%;">Progress Bars</h3>
# <div class="progress">
#   <div class="progress-bar bg-danger" role="progressbar" style="width: 33%;" aria-valuenow="33" aria-valuemin="33" aria-valuemax="100">33%</div>
# </div>

# %% [markdown]
# <h6><span class="label label-danger">Attention</span>This study consists of three parts. You can access the entire study through the following links. Good luck with your work. </h6>

# %% [markdown]
# <ul class="nav flex-column">
#   <h3 class="list-group-item list-group-item-action active" data-toggle="list" role="tab" aria-controls="home" style="background-color:#FF6961; color:white"><b>AutoScout Exploratory Data Analysis (EDA) Project</b></h3>
#   <li class="nav-item">
#     <a class="nav-link active" style="background-color:; color:Blue" href="https://github.com/huseyincenik/data_science/tree/main/Projects/Capstone%20Project" role="tab"><b>Part - 1 - Data Cleaning</b></a>
#   </li>
#   <li class="nav-item">
#     <a class="nav-link" style="background-color:; color:black" href="https://github.com/huseyincenik/data_science/tree/main/Projects/Capstone%20Project"><b>Part - 2 - Handling With Missing Values</b></a>
#   </li>
#   <li class="nav-item">
#     <a class="nav-link" style="background-color:; color:red" href="https://github.com/huseyincenik/data_science/tree/main/Projects/Capstone%20Project"><b>Part - 3 - Handling With Outliers</b></a>
#   </li>
#     <li class="nav-item">
#     <a class="nav-link" style="background-color:; color:blue" href="https://github.com/huseyincenik/data_science/tree/main/Projects/Capstone%20Project"><b>Analysis of the Dataset</b></a>
#   </li>
#   <li class="nav-item">
#     <a class="nav-link" style="background-color:; color:green" href="https://www.linkedin.com/in/huseyincenik/"><b>Linkedin Account</b></a>
#   </li>
# </ul>

# %% [markdown]
# # <p style="background-color:#FF6961; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ PART - 2 ( Handling With Missing Values ) ✨</p>

# %% [markdown]
# <a id="toc"></a>
#
# <div style="border-radius: 10px;
#             border: black solid;
#             background-color: #F9BF3B;
#             font-size: 100%;
#             text-align: left;
#             box-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
#
# <h2 style="border: 0; border-radius: 15px; font-weight: bold; font-size: 220%; color: white"><center> ✍✍ Content ✍✍</center></h2>
#
# <div>
#   <ul>
#     <li><a href="#0">DATASET EXPLANATION</a></li>
#     <li><a href="#1">EXPLANATION OF THE VARIABLES</a></li>
#     <li><a href="#2">IMPORTING LIBRARIES NEEDED IN THIS NOTEBOOK</a></li>
#     <li><a href="#3">READING & UNDERSTANDING THE DATA</a></li>
#     <li><a href="#50">NAN : MISSING VALUES OR UNKNOWN DATA</a></li>
#     <li><a href="#49">FEATURE ENGINEERING</a></li>
#   </ul>
# </div>
#
#
# <div style="display: flex;">
#     <hr style="border: none;
#                height: 2px;
#                width: 100%;
#                background-color: linear-gradient(to right, black, blue);
#                box-shadow: 0px 2px 4px rgba(0, 0, 0, 0.5);
#                margin-left: 0;">
# </div>
#
# <div style="display: flex; justify-content: center;">
#   <ul>
#     <li><a href="#4">OPERATIONS ON SOME COLUMNS</a></li>
#   </ul>
# </div>
#
# <div style="display: flex; flex-wrap: wrap; justify-content: center;">
#    <div style="flex: 0 0 25%; text-align: center; margin-right: 5%;">
#         <ul style="list-style-type: none; padding-left: 100;">
#             <li><a href="#5">POWER</a></li>
#             <li><a href="#6">ENGINE_SIZE</a></li>
#             <li><a href="#7">COMFORT_&_CONVENIENCE</a></li>
#             <li><a href="#8">ENTERTAINMENT_&_MEDIA</a></li>
#             <li><a href="#9">SAFETY_&_SECURITY</a></li>
#             <li><a href="#10">EXTRAS</a></li>
#             <li><a href="#11">SELLER</a></li>
#             <li><a href="#12">SEATS</a></li>
#             <li><a href="#13">EMPTY_WEIGHT</a></li>
#             <li><a href="#38">GEARBOX</a></li>
#             <li><a href="#14">FUEL_TYPE</a></li>
#             <li><a href="#15">GEARS</a></li>
#             <li><a href="#16">FIRST_REGISTRATION</a></li>
#
# </ul>
# </div>
#     <div style="flex: 0 0 25%; text-align: center; margin-right: 5%;">
#         <ul style="list-style-type: none; padding-left: 5;">
#             <li><a href="#17">DOORS</a></li>
#             <li><a href="#18">DRIVETRAIN</a></li>
#             <li><a href="#19">COLOUR</a></li>
#             <li><a href="#20">MANUFACTURER_COLOUR</a></li>
#             <li><a href="#21">PAINT</a></li>
#             <li><a href="#22">COUNTRY_VERSION</a></li>
#             <li><a href="#23">FULL_SERVICE_HISTORY</a></li>
#             <li><a href="#24">MILEAGE</a></li>
#             <li><a href="#25">PREVIOUS_OWNER</a></li>
#             <li><a href="#26">WARRANTY</a></li>
#             <li><a href="#27">GENERAL_INSEPTION</a></li>
#             <li><a href="#28">UPHOLSTERY</a></li>
#             <li><a href="#29">UPHOLSTERY_COLOUR</a></li>
#
# </ul>
#     </div>
#     <div style="flex: 0 0 25%; text-align: center; margin-right: 1%;">
#         <ul style="list-style-type: none; padding-left: 100;">
#             <li><a href="#30">FUEL_CONSUMPTION</a></li>
#             <li><a href="#31">MAKE_MODEL AND MODEL</a></li>
#             <li><a href="#32">EMISSION_CLASS</a></li>
#             <li><a href="#33">EMISSIONS_STICKER</a></li>
#             <li><a href="#34">CYLINDERS</a></li>
#         </ul>
#     </div>
# </div>
#
# <div style="display: flex;">
#     <hr style="border: none;
#                height: 2px;
#                width: 100%;
#                background-color: linear-gradient(to right, black, blue);
#                box-shadow: 0px 2px 4px rgba(0, 0, 0, 0.5);
#                margin-left: 0;">
# </div>
#
# <div>
#   <ul>
#     <li><a href="#52">DROP</a></li>
#     <li><a href="#51">SAVE THE FINAL STATE OF THE DATAFRAME AS A CSV</a></li>
#     <li><a href="#48">THE END OF THE PART - 2</a></li>
#   </ul>
# </div>
# </div>

# %% [markdown]
# <a id="0"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Dataset Explanation ✨</p>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %% [markdown]
# <a id="1"></a>
# <div style="border-radius: 10px;
#             border: black solid;
#             background-color: #F9BF3B;
#             font-size: 100%;
#             text-align: left;
#             box-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
#
# <h2 style="border: 0; border-radius: 15px; font-weight: bold; font-size: 220%; color: white"><center> ⚡️ Explanation of the Variables ⚡️</center></h2>
#
# - **make_model**: Vehicle brand and model.
# - **short_description**: Brief description.
# - **make**: Vehicle brand.
# - **model**: Vehicle model.
# - **location**: Location of the vehicle.
# - **price**: Price.
# - **body_type**: Vehicle body type.
# - **type**: Vehicle type.
# - **doors**: Number of doors in the vehicle.
# - **country_version**: Country version of the vehicle.
# - **offer_number**: Offer number.
# - **warranty**: Warranty.
# - **mileage**: Vehicle mileage information.
# - **first_registration**: First registration date.
# - **gearbox**: Gearbox type.
# - **fuel_type**: Fuel type.
# - **colour**: Vehicle color.
# - **paint**: Paint type.
# - **desc**: Description.
# - **seller**: Seller.
# - **seats**: Number of seats in the vehicle.
# - **power**: Engine power.
# - **engine_size**: Engine size.
# - **gears**: Number of gears.
# - **co_emissions**:  CO₂ emissions.
# - **manufacturer_colour**: Manufacturer color.
# - **drivetrain**: Drivetrain type.
# - **cylinders**: Number of cylinders.
# - **fuel_consumption**: Fuel consumption.
# - **comfort_&_convenience**: Comfort and convenience features.
# - **entertainment_&_media**: Entertainment and media features.
# - **safety_&_security**: Safety and security features.
# - **extras**: Extra features.
# - **empty_weight**: Empty weight.
# - **model_code**: Model code.
# - **general_inspection**: General inspection.
# - **last_service**: Last service.
# - **full_service_history**: Full service history.
# - **non_smoker_vehicle**: Non-smoker vehicle.
# - **emission_class**: Emission class.
# - **emissions_sticker**: Emissions sticker.
# - **upholstery_colour**: Upholstery color.
# - **upholstery**: Upholstery.
# - **production_date**: Production date.
# - **previous_owner**: Previous owner.
# - **other_fuel_types**: Other fuel types.
# - **power_consumption**: Power consumption.
# - **energy_efficiency_class**: Energy efficiency class.
# - **co_efficiency**:  CO₂ efficiency.
# - **fuel_consumption_wltp**: WLTP fuel consumption.
# - **co_emissions_wltp**: WLTP  CO₂ emissions.
# - **available_from**: Available from.
# - **taxi_or_rental_car**: Taxi or rental car.
# - **availability**: Availability status.
# - **last_timing_belt_change**: Last timing belt change.
# - **electric_range_wltp**: WLTP electric range.
# - **power_consumption_wltp**: WLTP power consumption.
# - **battery_ownership**: Battery ownership.

# %% [markdown]
# <a id="2"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Importing Libraries Needed in This Notebook ✨</p>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
from skimpy import clean_columns
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
import seaborn as sns

# from zipfile import ZipFile

# with ZipFile("as24_cars.zip", "r") as file:
#     file.extractall()

# pip install skimpy
# !pip install termcolor

# import colorama
# from colorama import Fore, Style  # makes strings colored
# from termcolor import colored
# from termcolor import cprint


# import warnings
# warnings.filterwarnings("ignore")
# warnings.warn("this will not show")

# plt.rcParams["figure.figsize"] = (8, 5)

# sns.set_style("whitegrid")
# pd.set_option('display.float_format', lambda x: '%.3f' % x)

# # Set it None to display all rows in the dataframe
# # pd.set_option('display.max_rows', None)

# # Set it to None to display all columns in the dataframe
# pd.set_option('display.max_columns', None)

# %%
libraries = ['skimpy', 'pandas', 'numpy', 'matplotlib', 'seaborn']

for lib in libraries:
    module = __import__(lib)
    version = getattr(module, '__version__', 'unknown')
    print(f"{lib} version: {version}")
# Out:
# skimpy version: unknown
# pandas version: 1.5.3
# numpy version: 1.23.5
# matplotlib version: 3.7.1
# seaborn version: 0.12.2

# %% [markdown]
# <a id="3"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Reading & Understanding Data ✨</p>
#
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
df0 = pd.read_csv("capstone_part_1_final.csv")
df = df0.copy()
df.sample(1).T
# Out:
#                                                                      15636
# make_model                                                   Dacia Sandero
# short_description                      1.5 Blue dCi Stepway Essential 70kW
# make                                                                 Dacia
# model                                                              Sandero
# location                          Plaza de la Luna, 1,  03006 Alicante, ES
# price                                                              14409.0
# body_type                                                          Compact
# type                                                                  Used
# doors                                                                  5.0
# country_version                                                      Spain
# offer_number                                                       7329909
# warranty                                                         12 months
# mileage                                                            30473.0
# first_registration                                                  2020.0
# gearbox                                                             Manual
# fuel_type                                                           Diesel
# colour                                                                Blue
# paint                                                                  NaN
# desc                     Precio Al Contado: 15850 Euros Ref.  5474Lmb  ...
# seller                                                              Dealer
# seats                                                                  5.0
# power                                                                 95.0
# engine_size                                                            1.4
# gears                                                                  5.0
# co_emissions                                                           NaN
# manufacturer_colour                                                   Azul
# drivetrain                                                           Front
# cylinders                                                              4.0
# fuel_consumption                                                      41.6
# comfort_&_convenience    climate,steering&trim,functional&mechanical,bo...
# entertainment_&_media                                                  NaN
# safety_&_security             lighting_feature,safety_feature,conv_feature
# extras                                                           accessory
# empty_weight                                                        1090.0
# model_code                                                             NaN
# general_inspection                                                     NaN
# full_service_history                                                   NaN
# non_smoker_vehicle                                                     NaN
# emission_class                                                         NaN
# emissions_sticker                                                      NaN
# upholstery_colour                                                      NaN
# upholstery                                                             NaN
# previous_owner                                                         NaN
# energy_efficiency_class                                                NaN
# co_efficiency                                                          NaN

# %%
df.shape
# Out:
# (29480, 45)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29480 entries, 0 to 29479
# Data columns (total 45 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   make_model               28630 non-null  object
#  1   short_description        28417 non-null  object
#  2   make                     28630 non-null  object
#  3   model                    28354 non-null  object
#  4   location                 28630 non-null  object
#  5   price                    28630 non-null  float64
#  6   body_type                28630 non-null  object
#  7   type                     28630 non-null  object
#  8   doors                    28271 non-null  float64
#  9   country_version          16889 non-null  object
#  10  offer_number             23100 non-null  object
#  11  warranty                 15784 non-null  object
#  12  mileage                  28629 non-null  float64
#  13  first_registration       28628 non-null  float64
#  14  gearbox                  28382 non-null  object
#  15  fuel_type                26843 non-null  object
#  16  colour                   26906 non-null  object
#  17  paint                    14495 non-null  object
#  18  desc                     27957 non-null  object
#  19  seller                   28630 non-null  object
#  20  seats                    25505 non-null  float64
#  21  power                    28058 non-null  float64
#  22  engine_size              27227 non-null  float64
#  23  gears                    18954 non-null  float64
#  24  co_emissions             18594 non-null  float64
#  25  manufacturer_colour      21787 non-null  object
#  26  drivetrain               16893 non-null  object
#  27  cylinders                18852 non-null  float64
#  28  fuel_consumption         23385 non-null  float64
#  29  comfort_&_convenience    25433 non-null  object
#  30  entertainment_&_media    23644 non-null  object
#  31  safety_&_security        25415 non-null  object
#  32  extras                   23480 non-null  object
#  33  empty_weight             17758 non-null  float64
#  34  model_code               8367 non-null   object
#  35  general_inspection       12254 non-null  object
#  36  full_service_history     12565 non-null  object
#  37  non_smoker_vehicle       11594 non-null  object
#  38  emission_class           17859 non-null  object
#  39  emissions_sticker        9414 non-null   object
#  40  upholstery_colour        14569 non-null  object
#  41  upholstery               18610 non-null  object
#  42  previous_owner           14015 non-null  object
#  43  energy_efficiency_class  7804 non-null   object
#  44  co_efficiency            7804 non-null   object
# dtypes: float64(12), object(33)
# memory usage: 10.1+ MB

# %%
sns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap='viridis');

# %%
def group_create(column_name ,my_list, func1, extra_feature, func2):
    a = df[column_name].fillna(df.groupby(my_list))[column_name].transform(func1)
    print(a.isnull().sum())
    b = pd.concat([a, df[extra_feature]], axis = 1)
    c = b[column_name].fillna(df.groupby([extra_feature]))[column_name].transform(func2).isnull().sum()
    print(c)

# %%
# user defined function for missing values

def handle_missing_values(df, column):
    # Count the number of missing values in the column
    missing_count = df[column].isnull().sum()
    
    # Calculate the percentage of missing values
    missing_percentage = (missing_count / len(df)) * 100
    
    # Print the results
    print("Missing Values in '{}':".format(column))
    print("Count: {}".format(missing_count))
    print("Percentage: {:.2f}%".format(missing_percentage))
    
# function for first looking to the columns

def first_looking(col):
    print("column name    : ", col)
    print("--------------------------------")
    print("per_of_nulls   : ", "%", round(df[col].isnull().sum()/df.shape[0]*100, 2))
    print("num_of_nulls   : ", df[col].isnull().sum())
    print("num_of_uniques : ", df[col].nunique())
    print(df[col].value_counts(dropna = False))

## Some Useful User-Defined-Functions

###############################################################################

def missing_values(df):
    missing_number = df.isnull().sum().sort_values(ascending=False)
    missing_percent = (df.isnull().sum()/df.isnull().count()*100).sort_values(ascending=False)
    missing_values = pd.concat([missing_number, missing_percent], axis=1, keys=['Missing_Number', 'Missing_Percent'])
    return missing_values[missing_values['Missing_Number']>0]
                    
###############################################################################

# %%
import pandas as pd
import ipywidgets as widgets
from IPython.display import display


# Seçim işlemini gerçekleştiren fonksiyon
def select_rows(df, selected_columns=None, filters=None):
    if selected_columns is None:
        selected_columns = df.columns  # Tüm sutunlar varsayılan olarak seçilir
    if filters is None:
        filters = {}  # Hiçbir filtreleme yapılmaz

    column_values = {column: df[column].unique() for column in filters}

    def select_button_clicked(button):
        selected_rows = df.copy()
        for column, dropdown in dropdowns.items():
            value = dropdown.value
            selected_rows = selected_rows[selected_rows[column] == value]
        selected_rows = selected_rows[selected_columns]
        display(selected_rows)

    dropdowns = {}
    for column in filters:
        if column in df.columns:
            column_options = column_values[column]
            dropdown = widgets.Dropdown(options=column_options, description=f'{column}:')
            dropdowns[column] = dropdown

    select_button = widgets.Button(description='Selection')
    select_button.on_click(select_button_clicked)

    display(*dropdowns.values(), select_button)

# %% [markdown]
# <a id="50"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ NaN: Missing Values or Unknown Data ✨</p>
#
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %% [markdown]
# <a id="36"></a>
# <div class="alert alert-info" role="alert">
# <h1><span style="color:red"> First of all </span></h1>
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Operation : </b> <span style="color:red"><b> We need to drop 850 rows that are completely NaN </b></span> .
# </div>

# %%
df.isnull().all(axis=1).sum()
# Out:
# 850

# %%
df.dropna(how = "all", inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28630 entries, 0 to 29478
# Data columns (total 45 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   make_model               28630 non-null  object
#  1   short_description        28417 non-null  object
#  2   make                     28630 non-null  object
#  3   model                    28354 non-null  object
#  4   location                 28630 non-null  object
#  5   price                    28630 non-null  float64
#  6   body_type                28630 non-null  object
#  7   type                     28630 non-null  object
#  8   doors                    28271 non-null  float64
#  9   country_version          16889 non-null  object
#  10  offer_number             23100 non-null  object
#  11  warranty                 15784 non-null  object
#  12  mileage                  28629 non-null  float64
#  13  first_registration       28628 non-null  float64
#  14  gearbox                  28382 non-null  object
#  15  fuel_type                26843 non-null  object
#  16  colour                   26906 non-null  object
#  17  paint                    14495 non-null  object
#  18  desc                     27957 non-null  object
#  19  seller                   28630 non-null  object
#  20  seats                    25505 non-null  float64
#  21  power                    28058 non-null  float64
#  22  engine_size              27227 non-null  float64
#  23  gears                    18954 non-null  float64
#  24  co_emissions             18594 non-null  float64
#  25  manufacturer_colour      21787 non-null  object
#  26  drivetrain               16893 non-null  object
#  27  cylinders                18852 non-null  float64
#  28  fuel_consumption         23385 non-null  float64
#  29  comfort_&_convenience    25433 non-null  object
#  30  entertainment_&_media    23644 non-null  object
#  31  safety_&_security        25415 non-null  object
#  32  extras                   23480 non-null  object
#  33  empty_weight             17758 non-null  float64
#  34  model_code               8367 non-null   object
#  35  general_inspection       12254 non-null  object
#  36  full_service_history     12565 non-null  object
#  37  non_smoker_vehicle       11594 non-null  object
#  38  emission_class           17859 non-null  object
#  39  emissions_sticker        9414 non-null   object
#  40  upholstery_colour        14569 non-null  object
#  41  upholstery               18610 non-null  object
#  42  previous_owner           14015 non-null  object
#  43  energy_efficiency_class  7804 non-null   object
#  44  co_efficiency            7804 non-null   object
# dtypes: float64(12), object(33)
# memory usage: 10.0+ MB

# %%
sns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap='viridis');

# %% [markdown]
# <a id="4"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Analyzing the target column ( Price ) ✨</p>
#
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
df.price
# Out:
# 0        16950.0
# 1        80900.0
# 2        69900.0
# 3        46990.0
# 4        16800.0
#           ...
# 29474    37600.0
# 29475     5499.0
# 29476     7300.0
# 29477    29900.0
# 29478     4440.0
# Name: price, Length: 28630, dtype: float64

# %%
handle_missing_values(df, 'price')
# Out:
# Missing Values in 'price':
# Count: 0
# Percentage: 0.00%

# %% [markdown]
# <a id="49"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Feature Engineering  ✨</p>

# %% [markdown]
# <div class="alert alert-warning" role="alert">
#  <b>Feature Engineering:</b> Let's create a new column by extracting<span style="color:red"><b> the countries and the cities</b></span>  from the location information.
# </div>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
# Let's extract the country information from the location data.
df["location_country"] = df.location.str.extract("(\w+)$")
df.location_country.sample(5)
# Out:
# 10094    DE
# 17796    FR
# 26148    NL
# 23867    DE
# 10237    DE
# Name: location_country, dtype: object

# %%
handle_missing_values(df , "location_country")
# Out:
# Missing Values in 'location_country':
# Count: 0
# Percentage: 0.00%

# %%
# Let's extract the city information from the location data.
df["location_city"] = df.location.str.extract("(\w+), \w+$")
df["location_city"] = df.location_city.str.title()
df.location_city.sample(5)
# Out:
# 3856       Krefeld
# 9942        Torino
# 11860           Ta
# 12029     Alicante
# 1098     Rheinbach
# Name: location_city, dtype: object

# %%
handle_missing_values(df , "location_city")
# Out:
# Missing Values in 'location_city':
# Count: 221
# Percentage: 0.77%

# %%
# After the groupby operation, how many NaN values do I have remaining?
df.groupby(['location_country'], group_keys = False)['location_city'].transform(lambda x: x.fillna(x.mode()[0]) if len(x.mode()) > 0 else x).isnull().sum()
# Out:
# 0

# %%
df.location_city = df.groupby(['location_country'], group_keys = False)['location_city'].transform(lambda x: x.fillna(x.mode()[0]) if len(x.mode()) > 0 else x)

# %%
handle_missing_values(df , "location_city")
# Out:
# Missing Values in 'location_city':
# Count: 0
# Percentage: 0.00%

# %%
df.location_city.sample(5)
# Out:
# 16080         Pa
# 446         Elda
# 4559     Genappe
# 11921         To
# 22258      Husum
# Name: location_city, dtype: object

# %% [markdown]
# <a id="4"></a>
# <button type="button" class="btn btn-lg btn-danger" data-toggle="popover" title="Popover title" >Operations on some columns</button>
#
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %% [markdown]
# <a id="5"></a>
# <div class="alert alert-info" role="alert">
# <h1>Column name :<span style="color:red"> power </span></h1>
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Operation : </b>The numbers preceding the <span style="color:red"><b>"ch" and "cv" words</b></span> in the short description indicate the unit of horsepower. Therefore, I will use the <span style="color:red"><b>short description column</b></span> to fill in the power values. Since the "power" column is associated with <span style="color:red"><b> " make " " model " " body_type " " type " and " engine_size "</b></span> . let's fill in the <span style="color:red"><b> NaN values</b></span> in this column by grouping the data based on these columns and performing the necessary operations.
# </div>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
first_looking("power")
# Out:
# column name    :  power
# --------------------------------
# per_of_nulls   :  % 2.0
# num_of_nulls   :  572
# num_of_uniques :  351
# 150.0     1992
# 131.0     1356
# 120.0     1182
# 110.0     1166
# 90.0      1110
#           ...
# 1014.0       1
# 775.0        1
# 640.0        1
# 243.0        1
# 35.0         1
# Name: power, Length: 352, dtype: int64

# %%
# df[df["power"].notnull()][["short_description", "power"]].index

# %%
# list(df.loc[df[df["power"].isnull()][["short_description", "power"]].index, "short_description"])

# %%
list(df.loc[df[df["power"].isnull()].index, "short_description"])
# Out:
# ['CDi',
#  '180D',
#  '450+ AMG Line 108kWh',
#  'Business Solution AMG',
#  'Business Solution AMG',
#  'Business Solution AMG',
#  'e AMG Line Panodak',
#  'Business Solution AMG',
#  'CDi',
#  '200 d Fascination 7G-DCT',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '200 d 150ch Progressive Line 8G-DCT 8cv',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '35 AMG 306ch 4Matic 7G-DCT Speedshift AMG 19cv',
#  '200 d Inspiration 7G-DCT Euro6c',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '180 d 116ch Business Line 7G-DCT',
#  '180 d 116ch AMG Line 7G-DCT',
#  '200 d 150ch AMG Line 8G-DCT 8cv',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '180 136ch Progressive Line 7G-DCT 7cv',
#  '180 d Sensation 7G-DCT',
#  '180 136ch Business Line 7G-DCT',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '160 109ch Style Line',
#  '200 163ch AMG Line 7G-DCT',
#  '160 Inspiration 7G-DCT',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '180 d 116ch Progressive Line 7G-DCT',
#  '180d',
#  'SL Pagode',
#  'SL',
#  '190SL',
#  'D',
#  'CDI Inspiration 7G-DCT',
#  'd',
#  '1.6',
#  'd',
#  'D',
#  '1.4 Twinport 87ch Unlimited Start/Stop',
#  '1.4 OPC LINE / COLOR EDITION / AIRCO / NAVI / CRUI',
#  '1.4 Twinport 87ch Unlimited Start/Stop',
#  '1.4 Twinport 87ch Start/Stop',
#  '-e LAUNCH EXECUTIVE 60 KWH *INCL. BTW* + ADAPTIVE',
#  '2.0 CDTI 165ch Cosmo Start\\u0026Stop',
#  '2.0i-16V DTM',
#  'GTC 1.8 16V SPORT ECC 68173 km !!! ZEER MOOI',
#  'B LS Fastback',
#  'Sports Tourer 1.6 CDTi s&s 136cv Business',
#  'Q210 Life Quickcharge 22 kWh (AccuHuur) incl. BTW',
#  'R240 Zen 22 kWh Huur Accu Navi ParkeerCam PDC Clim',
#  'Q210 Zen Quickcharge 22 kWh (ex Accu) | CAMERA | K',
#  'Q210 Zen Quickcharge 22 kWh (ex Accu) Full map nav',
#  'Hybrid 140 Intens - Automaat - Luxe uitgerust',
#  'R90 Life 41 kWh|Clima|Bluetooth|Cruise',
#  'Q210 Life Quickcharge 22 kWh (AccuHuur) incl. BTW',
#  'Q210 Zen Quickcharge 22 kWh (ex Accu) Navigatie/ P',
#  '0.9 TCe 95ch Signature',
#  '0.9 TCe 90ch energy Zen',
#  '0.9 TCe 95ch Zen',
#  '0.9 TCe 90ch energy Limited Euro6C',
#  '1.0 SCe 70ch Life 2 Boîte Courte Euro6',
#  '1.0 SCe 70ch Stop\\u0026Start Zen eco²',
#  'Electric Life R80 Achat Intégral 3CV',
#  'R4 Cabriolet / Sammlerfahrzeug / 1. Hand',
#  '3 coupe cabriolet III COUPE CABRIOLET 1.9 DCI 130',
#  '1.5 dCi 110ch energy FAP eco²',
#  'tce 140 edc fap',
#  'tce 140 edc fap',
#  'tce 140 edc fap - 21b',
#  'A PREPARER',
#  'tce 140 edc fap r.s. line',
#  '3 coupe III COUPE 2.0 DCI 160 FAP GT EURO5',
#  '3 coupe III COUPE 2.0 DCI 180 FAP GT',
#  'Cargo incl. accu incl. BTW',
#  'tce 160 edc fap - 21b r.s. line',
#  'III Coupé dCi 165 GT',
#  'ARKANA E-Tech 145 - 21B R.S. Line',
#  'tce 160 edc fap - 21b',
#  'ARKANA TCe 140 EDC FAP R.S. Line',
#  'DCI 180 4 CONTROL',
#  'tce 160 edc fap - 21b',
#  'tce 140 edc fap - 21b r.s. line',
#  'Technic 45 (ex Accu) (80 KMH, BROMMER KENTEKEN, CA',
#  'dci 90',
#  'e-tech 145 - 21',
#  '1.5 dCi 110ch energy Business',
#  '1.5 Blue dCi 115ch Intens',
#  '(ex Accu)',
#  '2.3 dCi 190ch Double Cabine Zen',
#  '1.3 TCe 140ch FAP RS Line EDC -21B',
#  '1.5 Blue dCi 115ch Intens',
#  '1.6 E-Tech 145ch RS Line',
#  'e-tech 145 - 21',
#  '2.0 dCi 175ch energy Initiale Paris X-Tronic',
#  '1.5 dCi 110ch energy Intens EDC eco²',
#  '1.5 Blue dCi 115ch Business',
#  'blue dci 115',
#  'tce 160 edc',
#  '1.2 TCe 130ch energy Intens EDC',
#  '1.5 dCi 90ch energy Business eco²',
#  '1.5 dCi 110ch energy Business eco²',
#  '1.3 TCe 140ch FAP RS Line EDC -21B',
#  '1.5 dCi 90ch energy Business Euro6c',
#  '1.6 E-Tech 145ch Intens -21B',
#  'tce 160 edc',
#  '2.0 dCi 175ch Intens X-Tronic - 18',
#  '1.0 TCe 100ch Intens GPL -21',
#  '1.6 E-Tech Plug-in Hybrid Intens, navi, cruise en',
#  '1.5 dCi Bose - Leer Xenon Navi',
#  'tce 160 edc',
#  '1.2 TCe 120ch energy Intens EDC Euro6 2015',
#  '1.5 dCi 110ch energy Business',
#  '1.5 dCi 90ch energy Business EDC Euro6c',
#  'grand scénic dci 130 energy fap eco2',
#  '1.5 Blue dCi 115ch RS Line EDC',
#  '1.5 dCi 110ch energy Zen EDC',
#  '1.5 dCi 110ch energy Limited',
#  '1.6 dCi 160ch energy Intens EDC',
#  '1.5 dCi 110ch energy Limited',
#  '1.5 dCi 90ch energy Business Euro6c',
#  'blue dci 150',
#  'estate dci 130 energy',
#  '1.6 dCi 160ch energy Intens EDC',
#  '2.0 Blue dCi 200ch Business Intens EDC - 19',
#  '1.5 Blue dCi 95ch Life',
#  '1.5 dCi 110ch energy Business EDC',
#  '1.3 TCe 115ch energy Business',
#  '1.3 TCe 140ch FAP Intens 120g',
#  '1.7 Blue dCi 150ch Business',
#  '1.5 dCi 90ch energy Business',
#  '1.6 E-Tech Plug-in 160ch RS Line -21N',
#  '1.7 Blue dCi 150ch Business Intens',
#  '2.0 Blue dCi 190ch Initiale Paris EDC',
#  '1.5 Blue dCi 95ch Business',
#  '1.5 Blue dCi 115ch Business - 20',
#  '1.5 dCi 75ch energy Business Euro6c',
#  'mégane iv estate blue dci 115 - 21b',
#  '1.5 Blue dCi 115ch Business - 20',
#  'INTENS R135 B-Rent',
#  'TCe Cool & Sound Benzine',
#  'Intens charge normale R90',
#  'Zen charge normale R90 MY19',
#  '2.0 Blue dCi 160ch Intens EDC - 19',
#  '1.6 dCi 130ch energy Intens',
#  '1.6 dCi 160ch energy Intens EDC',
#  'ii 1.2 lev 16v 75 eco2',
#  '1.0 TCe 100ch Evolution GPL',
#  '1.6 dCi 130ch energy Zen EDC',
#  '2.0 Blue dCi 200ch Initiale Paris EDC - 19',
#  '4 IV (BFB) 1.8T 280CH RS EDC',
#  '4 IV (BFB) 1.8T 280CH RS EDC',
#  'Intens R110 MY19',
#  '1.5 dCi 110ch energy Zen',
#  '1.6 dCi 160ch energy Initiale Paris EDC',
#  '1.5 dCi 110ch energy Business',
#  '2.0 Blue dCi 160ch Intens EDC',
#  '2.0 Blue dCi 190ch Initiale Paris EDC',
#  '1.6 dCi 130ch energy Limited EDC',
#  '1.6 dCi 130ch energy Business EDC',
#  '2.0 Blue dCi 160ch Intens EDC',
#  '2.0 Blue dCi 190ch Initiale Paris EDC',
#  'Life charge normale Type 2',
#  'Zen charge normale R110',
#  '1.6 dCi 130ch energy Intens',
#  'Zen charge normale R90',
#  'Zen charge normale R90',
#  'City charge normale R90',
#  '2.0 Blue dCi 190ch Initiale Paris EDC',
#  'Intens charge normale Type 2',
#  'Zen charge normale R90',
#  '2.0 Blue dCi 160ch Intens EDC',
#  'Life charge normale Type 2',
#  '5 Porte 0.9 TCe Moschino Life',
#  'e-208 136ch Active',
#  'VTi 72 Allure 5p',
#  'VTi 72 Like S\\u0026S 85g 3p',
#  '1.4 Essence 75 CV BVA',
#  'VTi 72 Like S\\u0026S 4cv 5p',
#  'VTi 72 Allure S\\u0026S 4cv 5p',
#  '1.2 PureTech Style Top 5p',
#  'VTi 72 Active S\\u0026S 85g 5p',
#  '1.0 12v Urban Move 5p',
#  '1.2 PureTech Style 5p',
#  'Cabriolet 2 l',
#  '2.0 HDI 120CV DISTRIB OK',
#  'CABRIOLET 1.8 CABRIOLET, NW. CABRIO KAP, NETTE AUT',
#  '1.6 VTI 16V FELINE',
#  'cc roland garros 1.6hdi 112 fap',
#  'coupe COUPE 2.7 V6 HDI SPORT PACK BVA',
#  'coupe COUPE 2.0 HDI 136 FAP SPORT',
#  'II 2016 3008 1.5 bluehdi GT Line s&s 130cv eat8',
#  '2.0 BlueHDi 180ch GT S\\u0026S EAT6',
#  '2.0 BlueHDi 180ch S\\u0026S GT Line EAT8',
#  '1.2 PureTech 130ch S\\u0026S Style EAT8',
#  '1.2 PureTech 130ch S\\u0026S Style EAT8',
#  'e-2008 136ch GT Line',
#  'SW GT HYBRID 180 e-EAT8',
#  '1.2 PureTech 130ch E6.c S\\u0026S Allure EAT8',
#  'PureTech 225ch S\\u0026S First Edition EAT8 119g',
#  'BlueHDi 130ch S\\u0026S GT EAT8',
#  '2.0 BlueHDi 180ch FAP EAT6',
#  'BlueHDi 180ch S\\u0026S GT Line EAT8',
#  'PHEV 225ch GT Pack e-EAT8',
#  '1.5 BlueHDi 130ch S\\u0026S Active Business',
#  'BlueHDi 130ch S\\u0026S Allure Pack EAT8',
#  '1.5 BlueHDi 130ch S\\u0026S GT EAT8',
#  '2.0 BlueHDi 180ch FAP EAT6',
#  'HYBRID 225ch GT e-EAT8',
#  '1.5 BlueHDi 130ch S\\u0026S Active Business',
#  'HYBRID 225ch GT e-EAT8',
#  '1.6 BlueHDi 120ch GT Line S\\u0026S',
#  'HYBRID4 360ch e-EAT8 PEUGEOT SPORT ENGINEERED',
#  'PureTech 180ch S\\u0026S Allure Business EAT8',
#  'PHEV 180ch Allure Pack e-EAT8',
#  '1.2 PureTech 130ch S\\u0026S Allure Pack EAT8',
#  'PHEV 225ch GT Pack e-EAT8',
#  'PHEV 180ch Allure Pack e-EAT8',
#  '1.2 PureTech 110ch Allure S\\u0026S',
#  'II Ph2 1.5 BlueHDi 130 S\\u0026S GT Line BA8',
#  'HYBRID 225ch GT e-EAT8',
#  '1.5 BlueHDi 130ch S\\u0026S Active Business',
#  '1.5 BlueHDi 130ch S\\u0026S Allure Business',
#  'PHEV 180ch Allure Pack e-EAT8',
#  '1.5 BlueHDi 100ch E6.c S\\u0026S Style',
#  '1.2 PureTech 130ch S\\u0026S Allure Pack',
#  'PHEV 180ch Allure Pack e-EAT8',
#  '1.5 BlueHDi 130ch S\\u0026S Active Business',
#  'II Ph1 NG 1.2 PTech 100 S\\u0026S Allure',
#  '1.2 PureTech 110ch E6.3 S\\u0026S Style',
#  '1.2 PureTech 110ch E6.3 S\\u0026S Active Business',
#  'HYBRID4 360ch e-EAT8 PEUGEOT SPORT ENGINEERED',
#  '1.2 PureTech 130ch S\\u0026S GT EAT8',
#  'BlueHDi 160ch S\\u0026S Allure EAT8',
#  '1.2 PureTech 82ch Active 5p',
#  '2.0 BlueHDi 180ch FAP Féline EAT6',
#  'PHEV 225ch GT Pack e-EAT8',
#  '1.0 PureTech Like 3p',
#  'HYBRID 225ch GT e-EAT8 10cv',
#  'BlueHDi 130ch S\\u0026S Allure EAT8 7cv',
#  'ACTIVE 1.2 ESS POUR ALGERIE UNIQUEMENT',
#  'e-208 136ch Allure',
#  'BlueHDi 180ch S\\u0026S GT EAT8',
#  'HYBRID4 360ch e-EAT8 PEUGEOT SPORT ENGINEERED',
#  'HYBRID4 360ch e-EAT8 PEUGEOT SPORT ENGINEERED',
#  '1.2 PureTech 130ch S\\u0026S Allure Pack EAT8',
#  '2.0 BlueHDi 180ch S\\u0026S GT EAT8',
#  'BlueHDi 160ch S\\u0026S GT Line EAT8',
#  '1.2 PureTech 130ch S\\u0026S Allure Pack',
#  '1.2 PureTech 130ch S\\u0026S GT Line EAT8 7cv',
#  'e-208 136ch GT Pack',
#  'e-208 136ch Active',
#  '1.5 BlueHDi 130ch S\\u0026S GT Line EAT8 7cv',
#  'BlueHDi 130ch S\\u0026S Active Pack EAT8',
#  'e-208 136ch GT',
#  'PureTech 180ch S\\u0026S GT Line EAT8',
#  '1.6 THP 16v 165ch Allure S\\u0026S',
#  'e-208 136ch GT',
#  'PHEV 225ch GT Pack e-EAT8',
#  '1.6 BlueHDi 120ch Active Business S\\u0026S EAT6 5p',
#  'e-208 136ch GT Line',
#  'puretech 68ch bvm5',
#  'e-208 136ch Style',
#  'BlueHDi 130ch S\\u0026S Active Business EAT8 7cv',
#  'e-208 136ch Allure',
#  '1.2 PureTech 110ch GT Line S\\u0026S 3p',
#  '1.6 BlueHDi 120ch S\\u0026S GT Line EAT6',
#  '1.2 8v 69ch Popstar',
#  'Icon 118cv',
#  '1.2 8v 69ch S',
#  '1.2 8v 69ch S\\u0026S Lounge  Euro6D',
#  '1.3 Multijet 16v 95ch DPF S\\u0026S Lounge 97g',
#  'PININFARINA Spider 2000',
#  '1973 FIAT COUPE',
#  'S 0.9 TWIN AIR',
#  'S COUPE',
#  '1.6 Multijet 120cv Lounge 4x2',
#  '1.0 FireFly Turbo T3 120ch Urban',
#  '1.3 FireFly Turbo T4 150ch Sport DCT',
#  '1.3 FireFly Turbo T4 150ch Cross DCT',
#  '1.0 T3 120cv Business',
#  '1.6 MultiJet 120ch Lounge S/S DCT MY20',
#  '1.0 100 ch S/S sw cross Red MY22',
#  'Stationwagon Cross 1.5 Hybrid Garmin',
#  '4X4 Cross 0.9 Twinair Turbo 85cv S&S 5 posti',
#  '1.0 FireFly Hybrid City Life',
#  '1.4 95ch Pop 5p',
#  '1.4 95ch Easy 4p',
#  '1.4 95ch Pop 4p',
#  '1.4 95ch Tipo MY19 5p',
#  '1.6 MultiJet 120ch Mirror S/S MY19 5p',
#  '1.4 95ch S/S Elysia MY20 5p',
#  '1.6 MultiJet 120ch Pop S/S 5p',
#  'Ibiza SC 1.2 70 ch',
#  '2.0 TSI 290ch Cupra DSG7',
#  '2.0 TSI 300ch Cupra 4Drive DSG7 Euro6d-T',
#  '1.8 TSI 180ch Start\\u0026Stop 4DRIVE DSG',
#  '1.4 e-Hybrid 204cv FR DSG',
#  '1.5 eTSI 150ch FR DSG7',
#  '1.0 EcoTSI 110ch FR DSG7',
#  '1.0 EcoTSI 115ch Start/Stop FR Euro6d-T',
#  '1.5 eTSI 150ch FR DSG7',
#  'e iV EV Style 1240KM! PDC CLIMA € 2.000,- SUBSIDIE',
#  'Pequeño Manual de 2 Puertas',
#  'CABRIOLET 1.6 TDI  COCCINELLE CABRIOLET 1.6 TDI 10',
#  '1.5 TSI 150ch Monte-Carlo DSG7 Euro6d-T EVAP',
#  '1.4 TSI ACT 150ch Style',
#  '1.4 TSI PHEV iV 245ch RS DSG6e Euro6d-AP',
#  '1.6 TDI 116ch SCR Active Euro6d-T',
#  '1.5 dCi 110ch Black Touch 4X2',
#  '1.6 SCe Techroad',
#  '1.5 Blue dCi 115ch Prestige 108g 4x2 - 19',
#  '1.2 TCe 125ch Prestige 4X2',
#  '1.5 dCi 110ch Prestige 4X2 EDC',
#  '1.5 dCi 90ch Silver Line 2017 4X2',
#  'blue dci 115 4x2',
#  '1.5 Blue dCi 115ch Prestige 4x2',
#  'blue dci 115 4x2',
#  '1.0 ECO-G 100ch 15 ans 4x2 - E6U',
#  '1.5 dCi 110ch Black Touch 2017 4X2',
#  '1.5 dCi 110ch Black Touch 2017 4X2',
#  '1.5 Blue dCi 115ch Prestige 4x2 - 20',
#  '1.5 Blue dCi 115ch Prestige 4x2',
#  '1.5 dCi 110ch Prestige 4X2',
#  '1.5 dCi 110ch Prestige 4X2 EDC',
#  'blue dci 115 4x2',
#  '1.5 dCi 110ch SL 10 ans 4X2',
#  '1.0 ECO-G 100ch Prestige + 4x2',
#  'blue dci 115 4x2',
#  '1.5 Blue dCi 115ch Essentiel 4x2',
#  '1.5 Blue dCi Prestige',
#  '1.5 Blue dCi 95ch 4x2',
#  '1.5 dCi 110ch Prestige 4X2',
#  '1.5 dCi 110ch Confort 4X2 EDC',
#  '1.5 Blue dCi 115ch Prestige 4x2 - 20',
#  'blue dci 115 4x2',
#  '1.5 Blue dCi 115ch Techroad 4x2',
#  '1.5 Blue dCi 115ch Prestige 4x2 E6U',
#  '1.3 TCe 150ch FAP Prestige 4x2 EDC',
#  '1.5 Blue dCi 115ch Prestige 4x2',
#  '1.5 Blue dCi 115ch Techroad 4x2',
#  '1.5 Blue dCi 115ch Prestige 4x2 - 20',
#  '1.3 TCe 150ch FAP Prestige  4x2 - 20',
#  '1.5 dCi 110ch Black Touch 2017 4X2 EDC',
#  '1.5 Blue dCi 115ch Prestige 4x4',
#  '1.3 TCe 150ch FAP Prestige 4x2',
#  '1.3 TCe 150ch FAP Prestige 4x2 EDC',
#  '1.3 TCe 150ch FAP Prestige 4x2',
#  '1.5 dCi 90ch Blackline',
#  'MCV 0.9 TCe Comfort',
#  'Jogger Extreme TCE 110',
#  '1.5 Blue dCi 75ch Confort',
#  '1.5 dCi 75ch Ambiance',
#  'Stepway 1.6 8V 85CV',
#  '0.9 TCe 90ch Stepway Easy-R',
#  '1.0 SCe 75ch 4cv',
#  '0.9 TCe 90ch Stepway',
#  '0.9 TCe 90ch Ambiance Euro6c',
#  '1.5 dCi 90ch Stepway',
#  'tce 90',
#  '0.9 TCe 90ch Stepway',
#  '0.9 TCe 90ch Stepway Easy-R -18',
#  '1.5 dCi 75ch Ambiance',
#  '1.0 SCe 75ch Ambiance 4cv',
#  'tce 90',
#  '0.9 TCe 90ch Confort',
#  '0.9 TCe 90ch Techroad',
#  '0.9 TCe 90ch Techroad',
#  '0.9 TCe 90ch Advance Euro6c',
#  '1.0 SCe 75ch Evasion',
#  '1.0 TCe 90ch Stepway Confort -22',
#  '1.0 TCe 90ch Stepway Confort -22',
#  '1.0 ECO-G 100ch Stepway Confort -22',
#  '1.5 Hybrid 116PK XT07546',
#  '1.8 Plug-In Hybrid Comfort 100PK ZC33920',
#  '1.0 VVT-i Terra MMT',
#  '1.8 Aspiration Sport Automaat (FACELIFT, NAVIGATIE',
#  '2.0 Hybrid GR-Sport Automaat I APPLE CAR PLAY & AN',
#  '1.5 Hybrid Aspiration CAMERA I AUTOMAAT',
#  '1.5 Hybrid Dynamic l Navigatie l Airco',
#  '1.5 Hybrid Dynamic Automaat I LICHTMETALEN VELGEN',
#  '1.8 Hybrid Aspiration / Cruise / Climate / Navigat',
#  '1.5 Hybrid Y20 Bi-tone | PARKEERCAMERA | CLIMA |',
#  '2.0 Hybrid Dynamic l Automatische Airco | Navigati',
#  '1.8 Hybrid Aspiration l Automatische Airco l Navig',
#  '1.8 Hybrid Active l Automaat l Apple Car Play l Pa',
#  '1.5 Hybrid GR Sport l Premium Pack  ( o.a. JBL Spe',
#  '1.8 Hybrid Full-Led Cam Orig NL.+NAP Dynamic Go',
#  '1.5 Hybrid Aspiration Ned. Auto, Automaat, Hoge Zi',
#  '1.5 Hybrid Aspiration | Navigatie | Lichtmetaal',
#  '1.5 Hybrid Executive l met Premium pack: JBL Speak',
#  '1.0 VVT-i 69ch x-play 5p',
#  'COUPE 2.0 D-4S 200 BVA PACK TRD',
#  '122h EDITION 2WD MY22',
#  '1.8 Hybrid Active 122PK BX72052',
#  '4.0 V6 4WD',
#  '2.5 Hybrid 4X2 178PK TP83484',
#  '4.0 V6 4WD',
#  '1982 Rouge Diesel 5 portes Manuelle 4.3 Turbo SUV/',
#  '2.5 Hybrid Navi/Cam Stoel/stuurverw Adapt-cruise C',
#  '4.0 Fj70',
#  '4.0 V6 4WD',
#  '1.5 Hybrid Adventure l Side Steps l Dash Cam',
#  '1.5 Hybrid AWD Adventure Automaat | NAVIGATIE | PA',
#  '4.0 Fj73',
#  '2.5 Hybrid Dynamic Automaat | SENSOREN V+A | PARKE',
#  '1988 Gris Essence 3 portes Manuelle 4.0 SUV/4&#215',
#  'Fj55 1978',
#  '1.8 Hybrid Active / Adaptive Cruise / Camera / Led',
#  '2.5 AWD Hybrid Premium Automaat I PANORAMISCH SCHU',
#  '1.5 Hybrid First Edition Automaat | PARKEERCAMERA',
#  '4.5 Fzj73',
#  '2.5 Hybrid Automaat Adapt-Cruise Elek-Klep Camera',
#  '1.5 Hybrid Luxury l Stoel verwarming l Stuur verwa',
#  '2.5 Hybrid AWD Bi-Tone Automaat I 1650KG TREKGEWIC',
#  'Touring Sports 1.8 Hybrid Business Plus Automaat I',
#  'Touring Sports 1.8 Hybrid Dynamic Go | Trekhaak',
#  'Touring Sports 1.8 Hybrid Lease+ Top 5 NL auto! 17',
#  'Touring Sports 1.8 Hybrid Business Automaat I STOE',
#  'Touring Sports 1.8 Hybrid Business Plus Automaat I',
#  'Touring Sports 1.8 Hybrid Dynamic Go Automaat I CR',
#  'Touring Sports 1.8 Hybrid Dynamic Automaat I LUXE',
#  'Touring Sports 1.8 Hybrid Business Automaat | NAVI',
#  'Touring Sports 1.8 Hybrid Business Automaat I ADAP',
#  'Touring Sports 1.8 Hybrid Business Plus | Navigati',
#  'Touring Sports 1.8 Hybrid Dynamic Automaat | NAVI',
#  'Touring Sports 2.0 Hybrid GR-Sport Plus l Stuurver',
#  'Touring Sports 1.8 Hybrid Active l Navigatie l ACC',
#  '1.8 Hybrid Executive | Automaat | Navi',
#  'Touring Sports 1.8 Hybrid Dynamic Automaat I PANOR',
#  'HSD 136h Design Business',
#  'Touring Sports 1.8 Hybrid Business Automaat I STOE',
#  'Touring Sports 1.8 Hybrid Active Automaat I ACHTER',
#  '125H ACTIVE TECH',
#  '180h Design',
#  '122h Design MY21',
#  '143 D-4D Dynamic',
#  '184h Collection MY22',
#  '180h Collection',
#  '100h Chic 5p',
#  '90 D-4D Dynamic 5p',
#  'HSD 136h Dynamic',
#  'HSD 100h Dynamic 5p',
#  '136h Dynamic 15',
#  '100h Dynamic 5p MY19',
#  'Hybride 218ch Design',
#  'HSD 136h Collection RC18',
#  'Base 24 kWh Automaat | Climate Control | Navi | Cr',
#  'Base 24 kWh Org. NL/82DKM',
#  'Electric 40kWh Tekna',
#  '2.ZERO EDITION 40 kWh 150pk / Adaptive Cruise/ 360',
#  'NISSAN ZXT Targa (origineel Duits)',
#  nan,
#  '1.5 dci 110',
#  '1.5 dCi 110ch Connect Edition Euro6',
#  '1.5 dCi 110ch N-Connecta Euro6 7 places',
#  '1.5 DCI 110 CONNECT EDITION 360',
#  nan,
#  'N-Connecta + Design pack',
#  'Tekna',
#  'Acenta met navi VOOR HANDELAAR',
#  '1.0 IG-T 92ch Acenta Xtronic 2021.5',
#  '1.0 IG-T 92ch Made in France 2021',
#  '1.5 dCi 90ch Acenta 2018 Euro6c',
#  '109ch 24kWh Visia',
#  '150ch 40kWh 10ème Anniversaire 21',
#  '150ch 40kWh Acenta',
#  '1.0 IG-T 100ch N-Sport 2020',
#  '1.0 IG-T 92ch Acenta Xtronic 2021',
#  '150ch 40kWh N-Connecta 2018',
#  '1966 FORD CABRIOLET',
#  '1966 FORD CABRIOLET V8',
#  '1965 Ford 64 1/2 Convertible V8',
#  '1965 FORD CABRIOLET PONY',
#  '1967 FORD CABRIOLET CODE A V8',
#  '1965 FORD V8',
#  'CABRIOLET',
#  'CABRIOLET',
#  'CABRIOLET',
#  'CABRIOLET',
#  'CABRIOLET',
#  'CABRIOLET',
#  'CABRIOLET',
#  'CABRIOLET',
#  'CABRIOLET',
#  'Cabrio Aut.',
#  'GT V8',
#  'Cabriolet Speciale Sport Sprint Edition',
#  'COBRA 427 PIGEON PERFORMANCE',
#  'cabriolet',
#  '-',
#  'CABRIOLET V8 BVM 289 ESSENCE',
#  'V8 312, PACK ELEC, HARD TOP',
#  '289 CI COUPE 4,7 200ch',
#  '1969 FORD FASTBACK MACH1',
#  '1967 FORD COUPE V8',
#  '2021 Ford Shelby GT500',
#  '1970 FORD FASTBACK MACH1',
#  '1966 FORD COUPE GREEN APPLE',
#  'COUPE',
#  'FASTBACK',
#  '1966 FORD COUPE V8',
#  '1967 FORD COUPE V8',
#  'COUPE V8 289CI',
#  '1969 FORD COUPE V8',
#  'COUPE V8',
#  'COUPE',
#  'COUPE',
#  'ELEANOR GT500',
#  '1965 FORD COUPE',
#  '1968 FORD FASTBACK V8',
#  'COUPE',
#  'COUPE',
#  'COUPE',
#  'COUPE',
#  'COUPE',
#  'COUPE',
#  'COUPE',
#  'COUPE V8',
#  '1976 FORD BLACK EDITION',
#  'COUPE',
#  '2.3 EcoBoost 317ch',
#  'EcoBoost V6',
#  'Shelby GT350',
#  'V6 Coupé 202cv Aut.',
#  'Shelby GT350R',
#  'Shelby GT350',
#  'Shelby GT350R',
#  'EcoBoost V6',
#  '2.0 Hybrid 177PK KJ47436',
#  'Fastback 1.0 T-GDI MILD-HYBRID KLASS 120PK MP22635',
#  '1.6 GDi Hybride Creative',
#  '1.6 GDi Comfort - Plus',
#  '1.6 GDi Comfort',
#  '1.6 GDi Intuitive',
#  '1.6 GDi Hybride Premium | Leder | Adapt. cruise |',
#  '1.6 GDi Hybride Automaat Comfort I Adapt. Cruise I',
#  '1.0 T-GDi 120 Creative',
#  '20 coupe1.0 t gdi 120 creative',
#  '1.6 T-GDI MILD-HYBRID TREND 2WD 110PK LR11554',
#  'electrique 39 kwh - 136 ch',
#  '1.6 CRDi 136ch Creative',
#  'CW 1.4i i-Motion Business AIRCO TREKHAAL LPG-G3 De',
#  'Wagon 1.5 T-GDi MHEV N Line | N-line | Sport uitvo',
#  'Wagon 1.0 T-GDi MHEV Comfort VAN € 30.100,- VOOR €',
#  'Hybrid 141ch Creative',
#  '1.4 T-GDi 140ch N Line DCT-7 Euro6d-T',
#  '1.1 CRDi 75 Blue Drive Business',
#  '1.4 T-GDi 140ch Creative',
#  '1.2 75ch Initia',
#  'D2 115ch Start\\u0026Stop Xenium',
#  'T2 122ch Momentum Business',
#  'T3 152ch Geartronic',
#  'D2 115ch Start\\u0026Stop Xenium',
#  'T2 122ch Momentum Business',
#  'T3 152ch Geartronic',
#  '2.0  - ONLINE AUCTION',
#  '2.0  - ONLINE AUCTION',
#  'Coupé Bertone',
#  '444 kattenrug',
#  'Coupé Bertone',
#  '444 kattenrug',
#  '2.0 T8 PLUG-IN HYBRID INSCRIPTION 304PK WC44666',
#  '2.0 T8 PLUG-IN HYBRID INSCRIPTION 304PK WC44666',
#  '2.3 GL !!UNIEK !!',
#  '2.3 GL !!UNIEK !!',
#  '2.0 T5 Summum Automaat']

# %%
df.loc[df[df["power"].isnull()].index, "short_description"].str.extract("(\d+)ch|(\d+\.*\d*)cv", flags=re.IGNORECASE).notnull().sum()
# Out:
# 0    268
# 1     13
# dtype: int64

# %%
# How many values can I fill using the short_description that contains the "ch" value?
df.loc[df[df["power"].isnull()].index, "short_description"].str.extract("(\d+\.*\d*)ch", flags=re.IGNORECASE).notnull().sum()
# Out:
# 0    268
# dtype: int64

# %%
df.loc[df[df["power"].isnull()].index, "power"] = df.loc[df[df["power"].isnull()].index, "short_description"].str.extract("(\d+\.*\d*)ch", flags=re.IGNORECASE).values.astype(float)

# %%
handle_missing_values(df , "power")
# Out:
# Missing Values in 'power':
# Count: 304
# Percentage: 1.06%

# %%
# How many values can I fill using the short_description that contains the "cv" value?
df.loc[df[df["power"].isnull()].index, "short_description"].str.extract("(\d+\.*\d*)cv", flags=re.IGNORECASE).notnull().sum()
# Out:
# 0    13
# dtype: int64

# %%
df.loc[df[df["power"].isnull()].index, "power"] = df.loc[df[df["power"].isnull()].index, "short_description"].str.extract("(\d+\.*\d*)cv", flags=re.IGNORECASE).values.astype(float)

# %%
handle_missing_values(df , "power")
# Out:
# Missing Values in 'power':
# Count: 291
# Percentage: 1.02%

# %%
# df.groupby(['make', 'model', 'body_type', 'type']).agg({'power': 'mean'})

# %%
# Since the "power" column is associated with " make " " model " " body_type " " type " and " engine_size ". 
# let's fill in the NaN values in this column by grouping the data based on these columns 
# and performing the necessary operations. 

df['power'].fillna(df.groupby(['make', 'model', 'body_type', "type"])['power'].transform('mean'), inplace = True)  # veya 'median' yerine 'mean'

# %%
handle_missing_values(df , "power")
# Out:
# Missing Values in 'power':
# Count: 25
# Percentage: 0.09%

# %% [markdown]
# <h6><span class="label label-danger">Attention</span>Since there is no other column available to fill the remaining values, let's proceed with dropping them. </h6>

# %%
df.dropna(subset=['power'], inplace = True)

# %%
handle_missing_values(df , "power")
# Out:
# Missing Values in 'power':
# Count: 0
# Percentage: 0.00%

# %%
df.power.sample(5)
# Out:
# 22255    526.0
# 7166     116.0
# 11145    140.0
# 13440     95.0
# 13716    150.0
# Name: power, dtype: float64

# %%
# Let's not take the decimal digits of power . so let's convert it to int first and then to float
df.power = df.power.astype(int).astype(float)
df.power.sample(5)
# Out:
# 315      190.0
# 6574     131.0
# 936      286.0
# 13643     86.0
# 13722     86.0
# Name: power, dtype: float64

# %% [markdown]
# <a id="6"></a>
# <div class="alert alert-info" role="alert">
# <h1>Column name :<span style="color:red"> engine_size </span></h1>
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Operation : </b> To fill in the missing values in the "engine_size" column, we can use the "short_description" column . Since the "engine_size" column is associated with <span style="color:red"><b> " make " " model " " body_type " " type " and " power "</b></span> . let's fill in the <span style="color:red"><b> NaN values</b></span> in this column by grouping the data based on these columns and performing the necessary operations.
# </div>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
first_looking("engine_size")
# Out:
# column name    :  engine_size
# --------------------------------
# per_of_nulls   :  % 4.85
# num_of_nulls   :  1388
# num_of_uniques :  69
# 1.9     6346
# 1.5     3620
# 1.4     3124
# 0.9     3058
# 1.3     2121
#         ...
# 54.0       1
# 19.1       1
# 99.9       1
# 16.5       1
# 3.3        1
# Name: engine_size, Length: 70, dtype: int64

# %%
list(df.loc[df[df["engine_size"].isnull()][["short_description", "engine_size"]].index, "short_description"])
# Out:
# ['CDi',
#  'A-CLASS A180 1.3 136 CV 7G-DCT 5P',
#  'd Avantgarde Largo',
#  '580 4MATIC AMG Line Premium plus | Rij-assist + |',
#  '450+ AMG Line 108kWh',
#  '350 AMG Line 90kWh Premium Pack',
#  'Business Solution AMG',
#  'Business Solution AMG',
#  'CDi',
#  '200 CDi 1.8 CDI Boîte auto',
#  'Coupé 3.0 CDI V6 DPF 7G-TRONIC BlueEFFICIENCY 265',
#  'MERCEDES-BENZ Clase GLK Pequeño  Automático de 5',
#  'Pequeño Automático de 5 Puertas',
#  nan,
#  'BlueEFFICIENCY Urban',
#  'CDI',
#  'MERCEDES-BENZ Clase SL Descapotable  Automático d',
#  'MercedesAMG',
#  'AMG Airscarf Kamera ToT Winkel SHZ PDC Spurhalte',
#  'SL Vollrestauration',
#  '-CLASS 6.2 COUPE SPORT AUTO 457 2P',
#  'SL',
#  'Extrem gepflegtes Ex-Pressefahrzeug W 231',
#  'V8 Cabrio Aut.',
#  'SL',
#  'Cabrio',
#  'CABRIOLET 2.1 CDI 204CV AUTO GARANTIE 6 MOIS',
#  '200 AMG Sport 7G-Tronic BVA',
#  '190SL',
#  nan,
#  'D',
#  '-CLASS 4MATIC',
#  '-CLASS 3.0 4MATIC AUTO 333 2P',
#  'Coupe Aerodynamik-P. Performance Sitze Pano Faceli',
#  'Coupé 220d',
#  'CDI Inspiration 7G-DCT',
#  'AMGpack + NIGHTPACK - CAMERA 48700€ + btw',
#  '4MATIC',
#  '4MATIC',
#  '4MATIC AMG Line',
#  '4M Progressive+Pano+DISTRON+HUP+KEYLESS',
#  '4MATIC',
#  'Progressive 7-Sitzer 20" Pano 360° Ke',
#  '4M AMG/KEYLESS/PTS/360/MEMORY/DISTRO/SHD',
#  '4MATIC',
#  '4M AMG Line',
#  '4M AMG Line Night Pano Advanced+',
#  '4M AMG/ MBUX/Schiebedach/Multibeam/Distr Navi/SHD',
#  '250 Progressive/LED/Memory-P./Kamera/Navi/',
#  '4M AMG-Line+AHK+DISTRONIC+MULTIBEAM+MBUX',
#  '4M AMG/DISTRO/KEYLESS/PTS/NIGHT/PANO/SHZ',
#  'AMG **Designo Magno** AHK Multibeam',
#  nan,
#  '4M AMG Line Night Navi Kamera LED SHZ',
#  '4M AMG Multibeam MBUX-AR',
#  '300 4MATIC',
#  '4MATIC',
#  '258PS 4Matic LED HIGH Luxury NAV CAM',
#  'D ADVANTAGE + PAQ NIGHT',
#  nan,
#  'Coupé 350D 258 CV',
#  '+ Electric Art MBUX+LED+RüKam+El.Heck+18',
#  "4Matic+360° Park+19''Alu+Schiebedach",
#  'D 2.2 170CV AUT 5P',
#  'd',
#  '53 AMG 4M+ Sitzklima*Drivers P.*Burmester',
#  '350 Fahrassist.*Pano.-Dach*360°*Night*Memory',
#  'AMG 4M Sitzklima*Burmester*Fahrassist.',
#  '+ AMG*Sitzklima*Burmester*Distronic*Night',
#  '450+ 360°Kam*Pano.-D.*20"LMR*AIRMATIC*Memory',
#  'lang Avantgarde Sitzklima vo+hi, Pano, Navi/SHD',
#  'EQV 250 Avantgarde Airmatic El Sitze vorne 7-Sitze',
#  'CLA-CLASS 2.1 D DCT SHOOTING BRAKE 136 5P',
#  '580 4Matic',
#  '580 4MATIC AMG HYPERSCREEN+DIGITAL LIGHT+HUD',
#  '580 4M AMG+21"+AHK+AR-HUD+SITZKLIMA+PANO+360',
#  '580 4Matic',
#  '450+ NIGHT+20"+PANO+FAHRASS+DIG.LIGHT+360°',
#  '2.3 16',
#  'd',
#  'Mercedes-AM53 4MATIC+',
#  '-CLASS 4.7 455 4P',
#  '-CLASS 4.7 455 4P',
#  '580 4M AMG+21"+HA-LENKUNG+AR-HUD+SITZKLIMA',
#  'Electric/Distr/KeyG/360/Memory/Burmeste Navi/LED',
#  'AMG 4M 21"+HYPERSCREEN+SITZKLIMA+CARBON',
#  'Mercedes-AMG S 4MATIC+',
#  'Mercedes-AMG S 4MATIC+',
#  '450+ Electric Art DIGITAL LIGHT+DISTRO+Pano',
#  '-CLASS 2.1 D 4MATIC AUTO 170CV 4P',
#  '450+ ELECTRIC ART/DISTRO/MBUX/PANO/360/PTS',
#  '450+ PANO+DIG.LIGHT+KEYLESS+FAHRASS+360°',
#  '-CLASS D G TRONIC PLUS AVANTGARDE',
#  'Pano/Distr/KeyG/360/Memory/Burmester Navi/Klima',
#  'AMG/Pano/Distr/KeyG/360/AHK/Mem/Burmest Navi/LED',
#  '350 amg distronic, memory, keyless go, led',
#  'd',
#  'd',
#  'd',
#  '450  AMG+NIGHT+21"+FONDSITZ-PAKET+PANO+HUD',
#  'd',
#  '350 NIGHT+PREMIUM+21"+PANO+AHK+SITZKLIMA',
#  '+ EDITION 1-HEADUP-PANO-AIRMATIC-360°',
#  '4MATIC DIGITAL LIGHT+HUD+BURMESTER+PANO',
#  '350+',
#  'CLA-CLASS 2.1 CDI DCT 170CV 4P',
#  'CLA-CLASS 2.1 CDI DCT 170CV 4P',
#  '350 4M grau magno PROGRESSIVE+AHK+PANO+TOTW',
#  'AMG  4M /21"/Digital Light/Pano-D',
#  '+ AMG MBUX+Dig-LED+HUD+Pano+Distronic+21',
#  '+ AMG MBUX+360°+Pano+DIG-LED+HUD+Distro',
#  '+ AMG/AIRMATIC/NAVI/DISTRO/PANO/360/SOUND',
#  '4M AMG MBUX+360°+HUD+DIG-LED+Burmeste',
#  '350+',
#  '350+ AMG Line',
#  'CLS-CLASS 272 4P',
#  'AMG*NightP*Digital-Light*AHK*',
#  '350+ AMG*Urban Guard*Digital-Light*Pano*',
#  'Electric Art*Digital-Light*Pano-SD*',
#  '+ EDITION1+AMG+AIRMATIC+PANO+HUD+MEMORY',
#  'Electric Art*Digital-Light*Pano-SD*',
#  'ElectricArt/PanoDa/Distr/KeyG/360/Memor Navi/LED',
#  '43 AMG 4M*Pano-SD*Urban Guard*HUD*360°',
#  '450+  AMG+NIGHT+20"+PANO+AHK+HUD+KEYLESS+360',
#  '4M EDITION ONE AMG-DISTR-PREMIUM-PANO-360°',
#  '+   ELECTRIC ART+20"+SITZKLIMA+AHK+KEYL.',
#  'Jam 1.4 Benzine 100PK + Navigatie',
#  'Enjoy 1.4 Benzine 100PK',
#  'Ultimate KAMERA NAVI LED STANDHZ ACC',
#  'F e Elegance',
#  'D Black Edition 5D 1.4B 100PK + Navigatie',
#  '-e ELEGANCE NAVI|LED||STANDHEIZUNG|1-PHASEN',
#  '1.0 120 Jahre KLIMA PDC SITZHEIZUNG',
#  'S 1.4 Turbo KLIMA KURVENLICHT PDC SHZ',
#  '-e GS-LINE NAVI|SHZ|LED|PDC|ALU|1-PHASEN',
#  'e Ultimate +11kW+Active+Keyless+R-Kamera+',
#  '-e ELEGANCE NAVI|SHZ|LED|ALU|1-PHASEN',
#  '-e ELEGANCE NAVI|SHZ|LED|PDC|ALU|1-PHASEN',
#  '-e ELEGANCE NAVI|LED||STANDHEIZUNG|1-PHASEN',
#  'F e Edition LM Klima Bluetooth Navi PDC',
#  '-e ELEGANCE NAVI|KAMERA|SHZ|LED|ALU|1-PHASE',
#  '-e ELEGANCE NAVI|KAMERA|SHZ|LED|ALU|1-PHASE',
#  '-e ELEGANCE NAVI|SHZ|LED|KAMERA|ALU|1-PHASE',
#  '-e ELEGANCE NAVI|SHZ|KAMERA|1-PHASEN',
#  '-e Edition Elektromotor Allwetter PDC',
#  '-e EDITION NAVI|SHZ|1-PHASEN|KAMERA|PDC',
#  'Corsa-e Elegance-e',
#  'OPC 1.6 Turbo KLIMA SHZ LEDER BI-XENON',
#  '1.6 Turbo Innovation NAVI W-LAN EU6',
#  '1.6SIDI Turbo Innovation XENON NAVI',
#  nan,
#  'Descapotable Manual de 3 Puertas',
#  '2.0 turbo',
#  '2.0 Turbo Einzelstück/Rennwagen/Track.',
#  nan,
#  'Deportivo Manual de 3 Puertas',
#  'C 2.2 de Luxe',
#  nan,
#  'Deportivo Manual de 3 Puertas',
#  nan,
#  'Coupe GS',
#  'GTC OPC J 280 cv',
#  'GTC 1.4 Twinport ecoFLEX',
#  '19 SR',
#  '2.0i-16V DTM',
#  nan,
#  'V6 190ps',
#  'Olympia',
#  'GT1900 AL',
#  'GSE (état concours)',
#  'Turbo 4x4  H-Kennzeichen Großer Service',
#  nan,
#  nan,
#  nan,
#  nan,
#  'GTE - CONRERO',
#  'Manta-B',
#  'Twip top 140 ,18',
#  'Astra H GTC Opc Line',
#  '1,8 E Coupe Berlina Automatik  1 Hand Schiebedach',
#  'B LS Fastback',
#  'oldtimer 3.0 6cil GSE 180pk manual gears box',
#  nan,
#  nan,
#  'AT',
#  '1.3 CDTI . GTC',
#  'B 2.0 GT/E,IRMSCHER,SERVO,H-ZULASSUNG,SPANIEN',
#  'Astra G OPC 1, 2.0 16V',
#  'A GTE Gelb Leder',
#  'e    1.4i  32jahre alt  h kennzeichen-möglich',
#  '1.3 CDTI Advance 95cv S/S 5 PORTE',
#  '1.3 CDTI b-Color 75cv 5 PORTE',
#  'GTC 1.7 CDTI 125 Sport 3p',
#  'Mokka-e GS Line-e',
#  'GS LINE',
#  'GS LINE',
#  'GS LINE',
#  'GS LINE',
#  '1.5 Diesel 96kW Innov Automatik',
#  'X EXCELLENCE',
#  'TODOTERRENO 1.6 CDTI EXCELLENCE 120 5P',
#  '1.6 CDTI EXCELLENCE AUTO 2WD 136 5P',
#  '1.2 Direct Elegance INTELLILINK LED',
#  'e Ultimate FLA+Massage+Leder+SpurW+DynLi',
#  'Ultimate PDC SHZ KAMERA NAVI LED ACC',
#  'INS-ST INNOV. 1.6D 136CV MT6',
#  '1.6 CDTI TURBO D INNOVATION ST 136CV 5P',
#  '-e Cargo Edition, Navi, PDC, Klima, uvm....',
#  'ST 1.2T NAVI/LED/WINTER/PDC/SHZ/TEMP./USB',
#  'K ST 1.4T NAVI/LED/TEMP./WINTER/PDC/SHZ',
#  '1.6 CDTI 100KW EXCELLENCE S',
#  'Sports Tourer 2.0 Turbo Innovation 4x4',
#  'Astra ST 1,6 CDTI Innovation|1 BESITZER|TOP AUSSTA',
#  'Meriva 1,4 Ecotec Turbo Edition|1 BESITZER|VOLLSTÄ',
#  'Berlina Manual de 5 Puertas',
#  '1.2 Twinport ecoFLEX Edition Tüv + Insp.',
#  'E 1.4 Edition Winterpaket',
#  'E 1.4 Edition Winterpaket',
#  'SEDAN 1.6 CDTI 110 HP EXCELLENCE S',
#  '5-Türer 1.2 Edition *LED*Klima*PDC*DAB*',
#  '1.6 CDTI 81KW SELECTIVE 110 5P',
#  '1.5D DVC 77KW 105 5P',
#  'LIFE ZE.40 Batteriemiete R110 Z.E. 40 CARPLAY SHZ ',
#  'EXPERIENCE (Selection) R135 ZE 50 PDC KLIMA',
#  'Life 40 R90 68kW',
#  'EXPERIENCE (Selection) R135 ZE 50 CCS TechnoP',
#  'Color/Miet Batterie/Türen mit Scheiben',
#  'Life 40 R90 68kW',
#  'ELECTRIC INTENS elektr. Faltdach EasyLink',
#  'ELECTRIC URBAN NIGHT NAVI SHZ PDC',
#  'LIFE 40 kW/h zzgl. Batteriemiete',
#  'Life 80',
#  'Electric Equilibre *PDC*DAB*Klima*MFA*ZV*',
#  'ELECTRIC ZEN',
#  'Electric Zen R80 60kW Batería 20kW/h',
#  '5-Deurs 1.5 Diesel 68PK met garantie',
#  'Q210 Life Quickcharge 22 kWh (AccuHuur) incl. BTW',
#  'Ver.+TÜF alles mitversichert bis 50 T  KM.',
#  'R240 Zen 22 kWh Huur Accu Navi ParkeerCam PDC Clim',
#  '80 INTENS WHITE',
#  '1.3 TCE 165 ENERGY INTENS EDC BVA',
#  'Q210 Zen Quickcharge 22 kWh (ex Accu) | CAMERA | K',
#  'Q210 Zen Quickcharge 22 Kwh [ Nav Clima ]',
#  'Q210 Zen Quickcharge 22 kWh (ex Accu) Full map nav',
#  'R90 Life 41 kWh|Clima|Bluetooth|Cruise',
#  'Intens Q210',
#  'Combi Energy dCi 90 Intense 5 places',
#  'Q210 Life Quickcharge 22 kWh (AccuHuur) incl. BTW',
#  'R240 Life 22 kWh (Accuhuur) / incl. BTW / excl. Ov',
#  'R90 Life 41 kWh (AccuHuur) incl. BTW excl. Overhei',
#  'R135 Intens 50 *CCS-SNELLADER* (Koopbatterij) incl',
#  'Q210 Zen Quickcharge 22 kWh (ex Accu) Aut. Navi|Cl',
#  'Q210 Zen Quickcharge 22 kWh (ex Accu) Navigatie/ P',
#  'R135 Z.E. 50 Riviera KAMERA+NAVI+SHZ+LEDER',
#  'Intens 40 R90 68kW',
#  'R135 Intens 50 | Huuraccu | Camera | Navi | Parkee',
#  'R90 Intens 41 kWh (KoopBatterij) incl. BTW excl. O',
#  'R110 Life 50 (AccuHuur) incl. BTW excl. Overheidss',
#  'EXPERIENCE (Selection) R110 ZE50 SHZ TechnoP',
#  'EXPERIENCE Batteriekauf R110 ZE 50 NAVI SHZ',
#  'Alpine A110 1.8 Pure auto',
#  'R135 Experience 50 *CCS-SNELLADER* (AccuHuur) incl',
#  'R240 Intens 22 kWh (Accuhuur) / incl. BTW / excl.',
#  'INTENS R135 ZE50 Batteriekauf WinterP Allwetter',
#  'TCe 90 ZEN',
#  'R110 Life ZE50 (incl Accupakket) | LED | APPLE CAR',
#  'Q210 Intens Quickcharge 22 kWh (AccuHuur)',
#  '1.3 Tce 130ch  Intens',
#  'R110 Life 50 (Accuhuur) / incl. BTW / excl. Overhe',
#  'R240 Zen 22 kWh (AccuHuur) incl. BTW excl. Overhei',
#  'TCe 90 ZEN Sitzheizung',
#  'Q210 Zen Quickcharge 22 kWh (ex Accu) (89PK), Auto',
#  'R110 Life 50 (AccuHuur) incl. BTW excl. Overheidss',
#  '1.0 SCe 75ch Zen - 20',
#  'R135 Zen 50 (AccuHuur) incl. BTW excl. Overheidssu',
#  'R135 Intens 50 *CCS-SNELLADER* (Koopbatterij) incl',
#  'LIMITED LIFE 41KW/H',
#  'Zoe R110 ZE40 Life  LIMITED Nav 17Z PDC',
#  'R90 Life 41 kWh (AccuHuur) incl. BTW excl. Overhei',
#  'Life R240 65kW',
#  'Life (Kauf-Batterie)',
#  'E-TECH 100% el. ZEN SHZ PDC KLIMA BT USB',
#  'R110 Life 50 (AccuHuur) incl. BTW excl. Overheidss',
#  'COMPLETE INTENS R135',
#  'Electric Life R80 Achat Intégral 3CV',
#  'R110 Life 50 (AccuHuur) incl. BTW excl. Overheidss',
#  'R110 Life 50 (AccuHuur) incl. BTW excl. Overheidss',
#  'R110 Life 50 (AccuHuur) incl. BTW excl. Overheidss',
#  'Twizy 45 Intens Black Flex',
#  'R4 Cabriolet / Sammlerfahrzeug / 1. Hand',
#  'Descapotable Manual de 3 Puertas',
#  'III Phase 3 1.5 dCi eco2 110 cv DYNAMIQUE - GARANT',
#  'D53 Cabriolet',
#  '3 coupe cabriolet III COUPE CABRIOLET 1.9 DCI 130',
#  '8.5',
#  'Edition',
#  'Edition',
#  'Pare-Brise 2.0 150 ch Avec Hard Top',
#  'GTA V 2.5 V6 Turbo consignatie verkoop/Valckenier',
#  'A110 S 1.8T 292ch Bleu Alpine',
#  'Williams Phase 2',
#  'tce 140 edc fap',
#  'tce 140 edc fap',
#  'tce 140 edc fap - 21b',
#  'A PREPARER',
#  'Deportivo Automático de 3 Puertas',
#  'Zen',
#  'tce 140 edc fap r.s. line',
#  'Renault Megane 1,5 dCI Energy Limited S&S 95',
#  'RS Trophy Automatik',
#  'A310 S “Pack“ 3,0 Turbo',
#  nan,
#  '3 coupe III COUPE 2.0 DCI 160 FAP GT EURO5',
#  'A 310',
#  nan,
#  'Coupe 2.0 turbo RS 275cv E6',
#  '3 coupe III COUPE 2.0 DCI 180 FAP GT',
#  '45 ELECTRIQUE',
#  'Renault Laguna Coupe 2.0 dCi 150',
#  'Le Mans, LETZE MÖGLICHKEIT',
#  'Cargo incl. accu incl. BTW',
#  'tce 160 edc fap - 21b r.s. line',
#  'RS',
#  '(ohne Batterie) Cargo',
#  '3 COUPE RENAULT SPORT 265 S&S',
#  'ARKANA E-Tech 145 - 21B R.S. Line',
#  'A310,Devil Auspuff,HKennz.,15" Gotti,TÜV neu!!',
#  '1.4 16V Sport Coupe `Wertanlage aus 1.Hand`',
#  'V6 TURBO',
#  'tce 160 edc fap - 21b',
#  'RS',
#  'ARKANA TCe 140 EDC FAP R.S. Line',
#  nan,
#  '1.0 TCE 74KW BUSINESS 5 PORTE',
#  'DCI 180 4 CONTROL',
#  'tce 160 edc fap - 21b',
#  'Technik 80 Z.E14.04.2014',
#  'coach 2000 16 v montecarlo',
#  '(Mietbatterie) Life',
#  'II 2.0 DCI 150 GT COUPE',
#  'tce 140 edc fap - 21b r.s. line',
#  'Zen E-TECH Híbrido 105kW(145CV)',
#  'Intens TCe 140 EDC',
#  '1.3 TCE 103KW ZEN EDC 140 5P',
#  'Black Edition 1.6 dCi 130 Energy',
#  'dci 90',
#  'e-tech 145 - 21',
#  'Business 1.5 dCi 90 Energy eco2',
#  '1.2 TCE 120CV EDC ENERGY IRIDIUM LED NAVI CAMERA S',
#  'e-tech 145 - 21',
#  'blue dci 115',
#  'tce 160 edc',
#  'tce 160 edc',
#  '1.5 BLUE DCI 115CV BUSINESS',
#  '2.0 BLUE dCi Kombi+ACC+AHK+HuD+LED+Navi',
#  'Ini. P. Blue dCi 139 kW (190CV) EDC',
#  'Energy TCe 225 EDC Initiale Paris - 7p.',
#  'tce 160 edc',
#  'IV Estate 1.5 dCi 110ch',
#  'ZEN ENERGY dCI 81 KW 110 CV EDC 5',
#  'Grand Scénic III TomTom Edition 1,6 16V |7 SITZER|',
#  'grand scénic dci 130 energy fap eco2',
#  'SPORT TOURER 1.3 TCE ZEN 103KW 140 5P',
#  'blue dci 150',
#  'estate dci 130 energy',
#  'Zen Blue dCi 88 kW (120CV) - SS',
#  'ZEN ENERGY dCI 81 KW 110 CV EDC 5',
#  'mégane iv estate blue dci 115 - 21b',
#  'E-TECH ZEN 117KW 160 5P',
#  'GT Sport TCE 205 EDC BOSE HUD NAVI LED',
#  'Electric Iconic 100% Elektrisch Klima Navi Leder',
#  '1.8 TCE RS TROPHY EDC 221KW 300 5P',
#  'Init. P. Blue dCi 118 kW(160CV) EDC SS',
#  '1.3 TCE INTENS 103KW 140 5P',
#  nan,
#  '1.3 TCE INTENS 103KW 140 5P',
#  'INTENS R135 B-Rent',
#  'Life 41kwh Batteriemiete, Kaufopt. möglich Klima',
#  'E-TECH 100% Electric TECHNO EV60',
#  'LIMITED Batteriemiete Z.E. 40 SHZ K&GO ALU',
#  'EXPERIENCE-Selection R110 Z.E.50 mit CCS',
#  'LIFE 22 kwH zzgl. Batteriemiete NAVI KLIMA',
#  'ETech 100% electric TECHNO EV60 opt charge',
#  'LIFE Batteriemiete Z.E.22 (23,3kWh)',
#  'Life 41kwh Batteriemiete Klima Navi Einparkhilfe',
#  'LIFE 22kw Mietbatterie NAVI KLIMA BT eFH ABS',
#  'Life 41kwh Batteriemiete Klima Navi Fenster el.',
#  'Life 41 kwh Battermiete, Kaufoption möglich Klima',
#  'Z.E. 40 Life Batteriemiete NAVI PDC BT',
#  'LIFE zzgl. Batteriemiete',
#  'LIMITED Batteriemiete Z.E.40 (41kWh) SITZH',
#  'LIFE Batteriemiete R110 Z.E.50 (52kWh)',
#  'E-Tech 100% Electric TECHNO EV60 NAVI PDC',
#  'E-Tech 100% electric TECHNO EV60 NAVI PDC',
#  'E-Tech 100% electric TECHNO EV60 NAVI PDC',
#  'LIFE Limited zzgl. Batteriemiete  Navi',
#  'EXPERIENCE Batteriekauf R110 Z.E.50 (52kWh)',
#  'E-Tech 100% ele. TECHNO EV60 220hp',
#  'Life Z.E. 40 Mietbatterie Klima Navi Fenster el.',
#  'INTENS 22 kWh Batteriemiete SHZ KAMERA PDC',
#  '1.8 TCE RS TROPHY EDC 221KW 300 5P',
#  '1.8i 16v  140 cv avec CT et CarPass Reprise/éch',
#  'iv rs trophy 300hp - sans malus',
#  '(mit Batterie) Z.E. 50 LIFE',
#  'INTENS (Mietbatterie) VB',
#  'II Phase 2 (VP) 1.5 dCi S&S 90 cv',
#  '1.2 TCE ENERGY GT LINE 97KW 130 5P',
#  'Initiale Paris 1.6 dCi 160 Energy EDC6',
#  'Electric Evolution EV60 220hp optimum charge',
#  'ii 1.2 lev 16v 75 eco2',
#  'Berlina Manual de 5 Puertas',
#  '4 IV (BFB) 1.8T 280CH RS EDC',
#  '4 IV (BFB) 1.8T 280CH RS EDC',
#  'Intens R110 MY19',
#  'Initiale 1.6 16V 110',
#  'Intens R110 Flex',
#  'Berlina Manual de 5 Puertas',
#  'E-TECH EVOLUTION ER EV60 130hp NAVI+LED',
#  '0.9 TCE 90CV ENERGY TREND',
#  'Clio Exception 1,6 16V |AUTOMATIK|TOP AUSSTATTUNG|',
#  '1.5 BLUE DCI ZEN 85KW 115 5P',
#  '4 Energy dCi 75 eco2 Euro 6 Business',
#  'Life charge normale Type 2',
#  'E-TECH ICONIC EV60 220hp WÄRMEPUMPE+ACC',
#  'Zen charge normale R90',
#  'Zen charge normale R90',
#  'City charge normale R90',
#  'Intens charge normale Type 2',
#  'Life charge normale Type 2',
#  'Allure Eléctrico 100kW',
#  'Pequeño Manual de 5 Puertas',
#  'e- GT 3 Phasen Lader SHZ',
#  'e- GT 3 Phasen Lader SHZ',
#  'e- GT Sitzheizung',
#  'e-208 136ch Active',
#  '1.6 HDi 100 Ch GPS / TEL CLIM',
#  'EV Allure 50 kWh LED 16" KEYLESS CCS',
#  'e-208 136ch GT Line Siege Chauf LED GPS Camera Rad',
#  '1.4 Essence 75 CV BVA',
#  'EV Active 50 kWh Cruise Control, Apple CarPlay',
#  '50kWh Allure | Geïntegreerde Lader 7 KW 1-FASE | P',
#  'Allure Pack Eléctrico 100kW',
#  'Allure Pack Eléctrico 100kW',
#  'WAGON Business 1.6 8v e-HDi 115cv S/S',
#  nan,
#  'Cabriolet ROLAND GARROS Paris Capote électric',
#  '206 CC Roland Garros',
#  'Cabriolet 2 l',
#  'Descapotable Manual de 3 Puertas',
#  'CC 2.0 Platinum Leder ACC SHZ',
#  'cabriolet $$je recherche en état ou a refaire$$',
#  'coupé cabriolet',
#  '2.0 HDI 120CV DISTRIB OK',
#  'cabrio',
#  nan,
#  'CABRIOLET 1.8 CABRIOLET, NW. CABRIO KAP, NETTE AUT',
#  'CC',
#  'CC',
#  'pack allure 1.5 bluehdi',
#  '1.6 VTI 16V FELINE',
#  'Automatik Leder',
#  'coupe 2.7 hdi 204ch griffe ba',
#  'Deportivo Manual de 3 Puertas',
#  '2.0 HDi/Leder/Navi/Memory/PDC/Xenon/19.Z/JBL',
#  nan,
#  '16 GTI',
#  '1.Hand unfallfrei alle Inspektionen Top Extras!',
#  'cc roland garros 1.6hdi 112 fap',
#  '2.0 HDi 163',
#  's16',
#  'COUPE GRIFFE 2.7 V6 HDI 204ch BVA6 1ere MAIN',
#  'coupe COUPE 2.7 V6 HDI SPORT PACK BVA',
#  'Active BlueHDi 120cv S&S 5 PORTE BERLINA',
#  '2.7 V6 HDI 204 CH FELINE BA *CUIR*GPS*',
#  'coupe COUPE 2.0 HDI 136 FAP SPORT',
#  nan,
#  '1.6EHDI 115CV ALLURE 5P',
#  'ALLURE HDI 130 CV',
#  '1.2 PURETECH S&S ACTIVE 130 5P',
#  'Elektromotor GT *LED*PDC*Stizheizung*',
#  'ALLURE HDI 130 CV',
#  '1.6BLUEHDI ALLURE S&S 120CV 5P',
#  'e- GT Panorama, Kessy, ACC',
#  '1.6BLUEHDI ALLURE S&S 120CV 5P',
#  '1.5 BLUEHDI S&S AUTO GT LINE 130CV 5P 7 PLAZAS',
#  '1.5 BLUEHDI 96KW ACTIVE S&S 130 5P',
#  '2.0BLUEHDI 133KW GT AUTO S&S 180 5P',
#  'ALLURE HDI 130 CV',
#  'e-2008 136ch GT Line',
#  '1.6 BLUEHDI 88KW BUSINESS LINE SW 120 5P',
#  'GT Long BlueHDi  96kW',
#  'Active Standard BlueHDi 73kW',
#  'SW GT HYBRID 180 e-EAT8',
#  'SW 1.5 BLUEHDI 130 EAT8 ALLURE',
#  'e-2008 136ch GT',
#  'e-2008 136ch GT',
#  'e-2008 136ch GT Pack +T.O',
#  'II SW Hybrid 225 e-EAT8 Allure Pack',
#  'e-2008 136ch Active',
#  nan,
#  'e-2008 136ch GT',
#  'e-2008 136ch GT',
#  'e-2008 136ch GT',
#  'e-2008 136ch GT',
#  '5P PSE HYBRID 360 e-EAT8',
#  '5P PSE HYBRID 360 e-EAT8  Sport Engineered',
#  '2.0 BLUEHDI AUTO GT 180 CV 4P',
#  'Berlina Manual de 5 Puertas',
#  '1.5 BLUEHDI ACTIVE 100CV 5P 2 PLAZAS',
#  'e- GT Pack - VFW - Prämie verrechnet!',
#  'e- Allure Pack 5T',
#  nan,
#  'GTI BY SPORT 1.6 PURETECH 263 CV 5P',
#  '2.2-16V Pack rijdt super en zeer luxe',
#  'GTI 1.6 THP 270 CV S&S 5P',
#  '2.0 BLUEHDI 180CV EAT8 F1 AUTOMATIC S/S GT FULL LE',
#  '3ª serie Hybrid 180 e-EAT8 GT',
#  '1.6 BLUEHDI 88KW BUSINESS LINE 120 5P',
#  'e-208 136ch Allure',
#  '1.5 BLUEHDI 73KW BUSINESS LINE 100 5P',
#  'e-208 136ch GT Pack',
#  'Elektromotor 136 Allure Pack NAVI,SHZ,Sofort',
#  'e-208 136ch Active',
#  'e-208 136ch GT',
#  'e-208 136ch GT',
#  'e-208 136ch GT Line',
#  'puretech 68ch bvm5',
#  'e-208 136ch Style',
#  'e-208 136ch Allure',
#  '595',
#  '1.5 HYBRID MHEV DCT GARMIN 130 5P',
#  '500e 3+1 87Kw La Prima',
#  'Pop Elektro Standheizung Kundendienst neu',
#  'Elektro ICON 42 kWh * PARK PAKET * NAVI * RÜKFAHRK',
#  'BEV HB E ICON 87KW 118CV',
#  'Elektro ICON 42 kWh * MAGIC EYE PAKET * NAVI * PAR',
#  'Pequeño Manual de 3 Puertas',
#  'Elektro ICON 42 kWh * PARK PAKET * NAVI * RÜCKFAHR',
#  'Elektro ICON 42 kWh * KOMFORT PAKET * NAVI * PARKT',
#  'Elektro ICON 42 kWh * PARK PAKET * NAVI * RÜCKFAHR',
#  'Elektro RED 23.8 kWh * NAVI * PARKTRONIC * KLIMAAU',
#  'Elektro ICON 42 kWh * PARK PAKET * NAVI * RÜCKFAHR',
#  '500e 87Kw Icon',
#  'Icon Elektro 42 kWh * PARK PAKET NAVI RÜCKFAHRK...',
#  'e 95ch Action Plus',
#  'Icon 3+1',
#  'Abarth 595 Tourismo 1.4 Turbo-Jet 165 BVA',
#  nan,
#  'La Nuova 500e RED BERLINA',
#  'LOUNGE   OK NEO PATENTATI     .PRONTA CONSEGNA.',
#  'Neuer  ICON 3+1 42kWh MÄRZ 23 - KOMFORT PARK WI',
#  nan,
#  'Neuer 500 ICON 42kWh MJ22 ICON NAVI SITZHZG. MAGIC',
#  'Dynamic 1.4 16v Starjet 95',
#  'e 118ch Passion',
#  'Icon 118cv',
#  'e Icon*17Zoll*Winter*MagicEye*Komfort*',
#  'Pequeño Manual de 3 Puertas',
#  'LA PRIMA ELEKTRO 3+1 118',
#  'RED 24 kWh Airco',
#  'e 118 Icon SHZ PDC Nav KeyLess adapt.Tempomat',
#  nan,
#  '1.2 LOUNGE OK NEO PATENTATI AUTOMATICA',
#  '1.0 hybrid dolcevita',
#  'Fiat Panda 0,9 Twinair Turbo 85 Trekking',
#  '1.0 70CV HYBRID ROCKSTAR S8 TETTO CARPLAY SENSOR C',
#  'LOUNGE FULL OPZIONAL CON TETTO APR ELET PRONTI VIA',
#  'LOUNGE 1.2 69CV 3P',
#  '1.2 70CV LOUNGE 3P',
#  'e',
#  '1.0 70CV HYBRID SPORT CONNECT CLIMA CARPLAY SENSOR',
#  'lounge ok neo pat.   solo 23000km!',
#  '500Ce 87Kw Icon',
#  '42 kWh La Prima****6824Km***Gsm 0475323828***',
#  'Descapotable Manual de 2 Puertas',
#  'CABRIO La Prima ELEKTRO (42 kWh) WINTER',
#  'Neuer 500 Cabrio La Prima 42kWh FEBRUAR 23 - WINTE',
#  'CABRIO La Prima ELEKTRO (42 kWh) WINTER',
#  'Neuer 500 Cabrio ICON 42kWh JANUAR 23 - KOMFORT PA',
#  'Neuer 500 Cabrio By Bocelli 42kWh JANUAR 23 - WINT',
#  'Neuer 500 Cabrio La Prima 42kWh JANUAR 23 - WINTER',
#  'Neuer 500 Cabrio La Prima 42kWh FEBRUAR 23 - WINTE',
#  '500Ce 87Kw Icon',
#  nan,
#  '500e Cabrio 42 kWh Icon',
#  '500E La Nuova 500c Serie1 La Nuova - Icon+ Cabrio',
#  'ICON | CABRIO | DIREKT RIJDEN | 42KWH | VOORRAAD',
#  'Neuer 500 Cabrio By Bocelli 42kWh JANUAR 23 - WINT',
#  '500E La Nuova 500c Serie1 La Nuova - Red Cabrio',
#  'Icon Cabrio 42 kW 118hp/87 kW New Garantuee',
#  'Neuer 500 Cabrio ICON 42kWh JANUAR 23 - PARK WINTE',
#  'LOUNGE OK NEO PATENTATI 2 ANNI GAR. pronta cons.',
#  'RIVA',
#  '1.0 70CV HYBRID CABRIO LOUNGE CARPLAY CLIMA BICOLO',
#  '1.8 16v GPL',
#  'Lusso',
#  'E 3+1 ICON 320KM 87KW',
#  'Lusso',
#  'Lusso',
#  'Lusso',
#  'C 320km 118cv Auto. Icon',
#  '500Ce 87Kw Icon',
#  'BEV 24KWH RED 95 2P',
#  'Lusso',
#  '2,0 16V* 2 Hand*Klima*Leder*El.Fester*gepf',
#  '1973 FIAT COUPE',
#  'e Icon',
#  'Fiat Coupè 1987 - 16 valvole - 180cv',
#  'Evo  1.3 MJT 16V 75 cv 1.3 D Multijet',
#  'Fiat - 1500 cabriolet',
#  'Eveline',
#  '2400 coupe',
#  'SPORT !!!! IN PERFETTE CONDIZIONI',
#  'Lightweight Hans Brösch',
#  nan,
#  nan,
#  'S COUPE',
#  '2000 turbo 16 plus',
#  nan,
#  'coupe',
#  'Coupé 20V Turbo Plus',
#  'Sport 70HP *26TKM*',
#  "COUPE' 2000",
#  'Turbo 20 valvole',
#  "1100/103 TV COUPE' PININFARINA",
#  '4x4 Sisley',
#  'Sport',
#  'Original Zustand',
#  '2.0 20v turbo Limited edition ( LTD )',
#  'Icon',
#  '2000 Coupè Bellissimo',
#  'COUPE 1a SERIE',
#  'COUPE SL 1100 iscritta ALBO STORICO FIAT 2022',
#  '1000 OT  4 FARI',
#  '2400 Coupé Ferrari ASI',
#  "VIOTTI SPECIAL COUPE' restauro completo con doc",
#  'R',
#  'F',
#  'Coupe',
#  'Action-Topolino Lotus Edition, Modellreihe 2022',
#  'E Elektro Red Edition',
#  '42 kWh La Prima*Tetto Panoramic*Navi*Retrocam*Led',
#  'ufficiale 1971',
#  nan,
#  nan,
#  '1.3 MultiJet Lounge 95cv S&S EU6 5 PORTE BERLINA',
#  'City Cross 10GSE T3 88kW 120CV SS',
#  'cross 4x4 ok neo patentatiGARANZIA TOTALE 24 M.',
#  '1.5 DCi 115 Cv 4x4 Comfort PickUp',
#  '1.6 MJT 130CV SPORT FULL LED NAVI CAMERA CERCHI 19',
#  '1.3 MULTIJET 95 CV URBAN LOOK  - 4° SERIE',
#  'DoubleCabLaunchEdition Aut*SPUR*RFK*Navi*MWST*AHK*',
#  '1.3 MJT 95CV CROSS CONNECT CARPLAY',
#  'Lounge 1.6 Multijet 120',
#  'off road look 2.0 mjet 140cv 4x4 cross plus',
#  '1.6 MJET 96KW SPORT 130 5P',
#  'City Cross 10GSE T3 88kW 120CV SS',
#  'City Cross 10GSE T3 88kW 120CV SS',
#  '1.0 FIREFLY T3 88KW LOUNGE 5P',
#  '1.6 MJET MIRROR FWD 120CV 5P',
#  '1.6 MJET MIRROR FWD 120CV 5P',
#  'City Cross 10GSE T3 88kW 120CV SS',
#  'City Cross 10GSE T3 88kW 120CV SS',
#  'station wagon 1,6 mjt 120cv dct lounge sw',
#  'SW 1.3 MJT 95CV S/S LOUNGE',
#  'station wagon 1,4 t-jet 120cv gpl easy 2017 sw',
#  '5P CITY LIFE 1.0 73KW (100CV)',
#  '5P HATCHBACK MY21 LIFE 1.0 73KW (100CV)',
#  'SW MIRROR 1.3 MULTIJET 95 CV 5P',
#  'CROSS 1.5 HYBRID 130CV',
#  "Icon 85KW-Lader 10,25'' Navigation Keyless Alu",
#  'e Passion ***sofort verfügbar***',
#  '1.0 HYBRID DOLCEVITA 70 3P',
#  'e 118ch La Prima',
#  'e 118ch La Prima by Bocelli 3+1',
#  'E E RED 118CV',
#  'e 118ch La Prima by Bocelli',
#  'e 118ch La Prima',
#  '5p Street 1.3 multijet 95cv s&s 5 porte - e',
#  '1.6 MULTIJET LIFE 130 4P',
#  '1.3 mjt 16v 95cv e6 s&s easy',
#  'ICON 58CV BERLINA TETTO PANORAMICO',
#  'ICON 58CV BERLINA',
#  '1.3 MJT 95CV EASY LOUNGE UCONNECT SENSOR FENDINEBB',
#  'Icon, Voll LED, DAB+ Navi Sitzheiz.',
#  '3+1 Passion',
#  'Icon Berlina',
#  'city look 1.6 mjet 120cv 4x2 lounge',
#  's0 1.3 mjt 16v 95cv e6 s&s easy',
#  'Icon, Voll LED, DAB+ Navi Sitzheiz',
#  'Icon, Voll LED, DAB+ Navi Sitzheiz.',
#  'Icon*Navi*PDC*DAB*LaneAssist* Klima Navi',
#  'urban look 1.6 mjet 120cv dct 4x2 popstar',
#  'city look 1.6 mjet 120cv 4x2 lounge',
#  's0 1.3 mjt 16v 95cv e6 s&s easy',
#  'Urban Look 1.6 mjet 120cv 4x2 lounge',
#  '1.4 95CV HB 5P LOUNGE',
#  'Icon 3+1 320km 85kW (118CV)',
#  '500E La Nuova Serie1 La Nuova - Red Berlina',
#  '5p Street 1.3 multijet 95cv s&s 5 porte - e',
#  'Dolcevita 1.0 Mild-Hybrid km 0',
#  '0.9 TURBO 85CV TWINAIR 4X4 CROSS',
#  'Dolcevita Hybrid 1.0 km0',
#  '1.0 95CV STYLE 5P',
#  'Pequeño Manual de 5 Puertas',
#  'Signo',
#  'Style',
#  '128 sport',
#  'Cupra',
#  'Cupra (290 ch ) Full Stock , black Edition Beats ,',
#  'sport coupe',
#  '1.2 TDI',
#  'Ibiza SC 1.2 70 ch',
#  'FR Anniversary TFSI 1.5 DSG',
#  'SC Ibiza SC 2.0 TDI 143 FAP FR',
#  '1.0 TSI STYLE EDITION ECO 115 CV',
#  'Xperience 1.0 TSI DSG 81\u202fkW (110\u202fPS), Autom. 7-...',
#  '2.0 TDI DSG Style',
#  '1.5 TSI FR 150CV',
#  '1.2 12V 70 REFERENCE 70 5P',
#  '1.0 TGI 66KW STYLE PLUS 90 5P',
#  'LEON 2.0 TSI 300ch DSG FULL',
#  '3ª serie Leon 1.5 tgi 5p. business',
#  '1.4 e-Hybrid 204cv FR DSG',
#  '1.6 TDI 105cv I-Tech',
#  '1.2 benzina',
#  '1.4 TDI 105ch FR Start/Stop',
#  'Monte Carlo 5d 1.2B 90pk',
#  'e iV Style CCS AC Automatik SHZ  1.Hand',
#  'iV Style 61 kW, 1-Gang-Automatik',
#  'e iV Style 1-Gang *CCS PDC SHZ SUNSET LED*',
#  'e iV EV Style 1240KM! PDC CLIMA € 2.000,- SUBSIDIE',
#  'e iV Ambition CCS SHZ PDC KLIMAAUT.',
#  'Pequeño Manual de 2 Puertas',
#  '1.4 TDI 90HP LIKE 5P',
#  'AMBITION 1.2 TSI 90CV 5P',
#  'III 1.0 Drive Tempomat Sitzhzg Climatronic',
#  '1.0 MPI 55KW AMBITION 75 5P',
#  '1.0 MPI 55KW AMBITION 75 5P',
#  '1.0 MPI 55KW AMBITION 75 5P',
#  '1.0 MPI 55KW AMBITION 75 5P',
#  'Sportline 80x|POMPE|ATR|COMF SEAT|CONV|L/V+|PARK+|',
#  'iV 80 Loft *LED*Navi*Kamera*Pano*20 Zoll* Klima',
#  'iV 80 Loft NAVI AHK WP PACC ALU LED',
#  'iV 60 Lodge -SOFORT- ACC DAB LED NAVI KAMERA KE...',
#  'RS 2.0 TSI DSG 4x4 ** AUF LAGER** 180\u202fkW (245\u202fP...',
#  '80 Suite  **SOFORT VERFÜGBAR** LEDER *21"',
#  'iV 60 Loft Matrix-LED Navi Kamera',
#  'iV 60 Loft Navi Kamera ACC Voll-LED',
#  'iV 60 Loft Navi Kamera ACC Voll-LED',
#  'iV 80 eco Suite ab 12/2022',
#  'iV 60 Lounge Matrix-LED Navi ACC Kamera',
#  'iV 80 Sportline AHK Matrix-LED Navi Kamera',
#  'DIESEL',
#  'iV 60 Navi Kamera SHZ Matrix-LED',
#  'iV 50 Loft Voll-LED Navi Kamera SHZ',
#  'iV 80 Sportline ab 02.01.2023 verfügbar AHK-Vorb.*',
#  '1.9 TDI 74 KW Elegance Combi Klima',
#  'Combi 2.0 TDI Style*LED*Navi*HUD*Sunset*Climatroni',
#  'CITIGOe iV Style Sunset Komfort Alu Licht+Sicht',
#  'iV 80 AHK Multifunktionslenkrad beheizbar',
#  '150cv elegence BA',
#  'Business NAVI PDC jetzt Probe fahren',
#  'Business NAVI PDC jetzt Probe fahren',
#  'Business NAVI PDC jetzt Probe fahren',
#  'Business NAVI PDC jetzt Probe fahren',
#  'Business NAVI PDC jetzt Probe fahren',
#  'Business NAVI PDC jetzt Probe fahren',
#  'Business NAVI PDC jetzt Probe fahren',
#  'Business NAVI PDC jetzt Probe fahren',
#  'Business NAVI PDC jetzt Probe fahren',
#  'Business NAVI PDC jetzt Probe fahren',
#  'Business NAVI PDC jetzt Probe fahren',
#  'Business NAVI PDC jetzt Probe fahren',
#  'Business NAVI PDC jetzt Probe fahren',
#  'Business NAVI PDC jetzt Probe fahren',
#  'Business NAVI PDC jetzt Probe fahren',
#  'Business NAVI KLIMA PDC',
#  'Business NAVI PDC jetzt Probe fahren',
#  'Business NAVI PDC jetzt Probe fahren',
#  'BUSINESS-EDITION/EPH/KLIMA/NAVI/USB/ELEKTRO!!',
#  'Business NAVI PDC jetzt Probe fahren',
#  'Business  NAVI PDC KLIMA',
#  'Business NAVI PDC KLIMA',
#  'Business NAVI PDC jetzt Probe fahren',
#  'Business NAVI KLIMA jetzt Probe fahren',
#  'Business NAVI PDC jetzt Probe fahren',
#  'Business NAVI PDC jetzt Probe fahren',
#  'Essential NAVI+KAMERA+CARPLAY+KLIMA+LED',
#  'Essential NAVI+KAMERA+CARPLAY+KLIMA+LED',
#  'Comfort Plus - Business - WLTP Combi 230km - - Dem',
#  '1.0 SCe 75 Essentiel',
#  'Stepway 3 Comfort TCe 90 CVT Navi  PDC v+h+Kamera',
#  'Confort Plus - Achat Intégral Camera GPS',
#  'TCe 150 4WD',
#  'Electric Comfort Plus Aut.',
#  '1.6 SCe 115 4x2 Ambiance Klima, AHK,Sitzh',
#  'blue dci 115 4x2',
#  'blue dci 115 4x2',
#  'blue dci 115 4x2',
#  'blue dci 115 4x2',
#  'blue dci 115 4x2',
#  '0.9 TCE 90CV WOW',
#  'Todoterreno Manual de 5 Puertas',
#  'nur auf Bestellung (Probefahrt möglich)',
#  '0.9 TCE LAUREATE 66KW MCV 90 5P',
#  'Stepway Essential Blue dCi 70kW (95CV)',
#  'SL Nomada BluedCi 70kW 95CV 18',
#  'SL Nomada BluedCi 70kW 95CV 18',
#  'SL Nomada BluedCi 70kW 95CV 18',
#  'SL Nomada BluedCi 70kW 95CV 18',
#  'SL Xplore TCE 96kW 130CV 7Pl',
#  'SL Nomada BluedCi 70kW 95CV 18',
#  '0.9 TCE LAUREATE 66KW MCV 90 5P',
#  '0.9 TCE LAUREATE 66KW MCV 90 5P',
#  'MCV dCi 90 S/S Easy-R Lauréate*NAVI*Automa',
#  'MCV II Kombi Stepway Celebration  Navi',
#  'MCV II Kombi Stepway Celebration  Navi',
#  'Comfort :SOFORT *Elektro* Kima',
#  'Comfort :SOFORT *Elektro* Kima',
#  'Comfort :SOFORT *Elektro* Kima',
#  'Electric45 Comfort Plus inkl. Batterie NAVI KAM...',
#  'Comfort :SOFORT *Elektro* Kima',
#  '1.0 TCE 100 S&S STEPWAY ESSENTIAL 100 5P',
#  'Comfort :SOFORT *Elektro* Kima',
#  'Berlina Automático de 5 Puertas',
#  '1.0 SCE AMBIANCE 54KW 73 5P',
#  'Berlina Manual de 4 Puertas',
#  'Comfort Electric 45',
#  'Comfort Electric 45',
#  '0.9 TCE XPLORE 66KW 90 5P',
#  'tce 90',
#  'tce 90',
#  'Berlina Manual de 4 Puertas',
#  '0.9 TCE XPLORE 66KW 90 5P',
#  '0.9 TCE 90 STEPWAY E6 90 5P',
#  '0.9 TCE XPLORE 66KW 90 5P',
#  '1.0 TCE 100 S&S STEPWAY ESSENTIAL 100 5P',
#  '0.9 TCE 90 STEPWAY E6 90 5P',
#  '1.0 TCE 100 S&S STEPWAY ESSENTIAL 100 5P',
#  'EFICACIA 1.5 DCI 75 CV 5P',
#  '0.9 TCE XPLORE 66KW 90 5P',
#  '0.9 TCE XPLORE 66KW 90 5P',
#  '0.9 TCE 90 STEPWAY E6 90 5P',
#  '0.9 TCE XPLORE 66KW 90 5P',
#  '1.6D-4D 82KW ADVANCE 112 5P',
#  '1.6D-4D 82KW ADVANCE 112 5P',
#  'Yaris - 1,5 l Hybrid, 5-türig, Active Dr',
#  'Pequeño Manual de 5 Puertas',
#  'Toyota Supra 3.0 V6 Turbo',
#  'Tornado',
#  'cabriolet GT',
#  nan,
#  '1.0 Cabrio 5p',
#  'Turbo Targa',
#  'ii hsd 136h dynamic',
#  'COUPE 2.0 D-4S 200 BVA PACK TRD',
#  'WAGON Hybrid Business',
#  'Tbar',
#  '1.6 TC 16',
#  '*francois duval rally sport vintage*pret a rouler*',
#  'MK4 RHD Twin Turbo',
#  'TA 22  GT 1600 2-TG',
#  '1.6 STI',
#  '1.8i',
#  'ST185 Carlos Sainz',
#  '1.6 Automatique',
#  'GTi',
#  'Coupé 2 posti 1.6 16 V',
#  nan,
#  '122h EDITION 2WD MY22',
#  '4.0 V6 4WD',
#  'RAV4 2.0I VVT-I LUNA 4WD 3P',
#  '125H AUTOMaTICO (E-CVT) 5P ADVANCE',
#  '125H AUTOMaTICO (E-CVT) 5P ADVANCE',
#  'X-MODE Comfort- und Technik-Paket',
#  '4.0 V6 4WD',
#  'Todoterreno Automático de 5 Puertas',
#  'IV 4WD 2.4 D-4D 150 DOUBLE CABINE',
#  'Todoterreno Manual de 3 Puertas',
#  'IV 4WD 2.4 D-4D 150 DOUBLE CABINE',
#  '1982 Rouge Diesel 5 portes Manuelle 4.3 Turbo SUV/',
#  '4.0 Fj70',
#  'bj 42 4 marce asi',
#  'IV 4WD 2.4 D-4D 150 DOUBLE CABINE',
#  '4.0 V6 4WD',
#  'IV 4WD 2.4 D-4D 150 DOUBLE CABINE',
#  '4.0 Fj73',
#  'SUV 1.5 VVT-I HYBRID PREMIERE EDITION 116 5P',
#  '1988 Gris Essence 3 portes Manuelle 4.0 SUV/4&#215',
#  nan,
#  'Fj55 1978',
#  '4.0 4x4',
#  '4.5 Fzj73',
#  '2.5 DOUBLE CABINE 144 4X4',
#  'Rav4 PLUG IN ADVANCE',
#  '2.0D 105KW ADVANCE 143 5P',
#  'Verso L1 Electric 75 kWh Team D HUD',
#  'TS 125H BUSINESS',
#  'TS 180H STYLE PLUS',
#  '125H ACTIVE TECH',
#  'Medium Electric 50kWh Design',
#  '1.8 VVT-I 100KW HYBRID ACTIVE 136 5P',
#  '1.8 VVT-I 100KW HYBRID BUSINESS 136 5P',
#  '*WASSERSTOFF* *LEDER*NAVI*JBL*ACC*LED*SHZ*',
#  'Fuel Cell Wasserstoff+Leder+Navigation+Key-Less go',
#  '1.8 VVT-I HYBRID ADVANCE AUTO 122 5P',
#  'II Advanced HEAD-UP LED NAVI SHZ LEDER',
#  'Hybrid 2,0l Club Kamera,BT, DAB,',
#  'BERLINA CON PORTON 1.0 VVT-I ACTIVE 69 5P',
#  'Hybrid Feel! Edition',
#  'TOYOTA Corolla Verso facelift 2.2 D4-D 136cv',
#  '2.ZERO',
#  '62 kWh e+ N-Connecta',
#  '2.ZERO',
#  '217PS E+ N-CONNECTA 62KWH 217 5P',
#  '217PS E+ N-CONNECTA 62KWH 217 5P',
#  '40 kWh Tekna',
#  'Base 24 kWh Automaat | Climate Control | Navi | Cr',
#  '1.6 DIG-T 163ch Tekna II',
#  'Base 24 kWh Org. NL/82DKM',
#  'Pequeño Manual de 3 Puertas',
#  'N-Connecta 40 kWh, (150PK) (INCL BTW) Automaat, 1-',
#  'Acenta 40 kWh | APPLE CARPLAY | ANDROID AUTO | ADA',
#  'N-Connecta 40 kWh, (150PK) (INCL BTW) Automaat, 1-',
#  'N-Connecta 40 kWh (150PK), INCL BTW) Automaat, Dea',
#  'Acenta 24 kWh ✅ Navi ✅ Camera ✅ Clima',
#  'Tekna 30 kWh (109PK) (INCL BTW) Automaat, 1-Ste-Ei',
#  '217PS E+ N-CONNECTA 62KWH 217 5P',
#  'Base 24 kWh Automaat Bovag-garantie',
#  '2.ZERO EDITION 40 kWh, Automaat, Navigatie',
#  '40 kWh Tekna',
#  'Tekna 40 kWh, navi, cruise, climate, camera, 1/2le',
#  'N-Connecta 40 kWh [ Black Optik 360cam Nav ]',
#  'N-Connecta 40 kWh (incl. BTW), Automaat, Navigatie',
#  'Tekna 24 kWh 2015 | BTW | Airco | LED | Cruise Con',
#  '40 kWh Acenta',
#  '150ch 40kWh Acenta Gps Camera',
#  '150ch 40kWh Acenta 19 Siege Chauff GPS Camera',
#  '109ch 24kWh Visia',
#  '2.ZERO EDITION 40 kWh',
#  '40 kWh Acenta',
#  'Acenta 30KWh',
#  'ACENTA 0.9 IG-T 90CV 5P',
#  'N-CONNECTA 1.5 DCI 90CV 5P',
#  'N-CONNECTA 0.9 IG-T 90CV 5P',
#  'N-CONNECTA 0.9 IG-T 90CV 5P',
#  'N-CONNECTA 1.5 DCI 110CV 5P',
#  '62 kWh e+ N-Connecta',
#  '2.ZERO EDITION 40 kWh 150pk / Adaptive Cruise/ 360',
#  'N-CONNECTA 0.9 IG-T 90CV 5P',
#  'N-CONNECTA 0.9 IG-T 90CV 5P',
#  '40 kWh Acenta',
#  'ACENTA 0.9 IG-T 90CV 5P',
#  'N-CONNECTA 0.9 IG-T 90CV 5P',
#  'Acenta 30KWh',
#  'N-CONNECTA 0.9 IG-T 90CV 5P',
#  'ROADSTER Premium Pack',
#  'ROADSTER Pack  TOP GEPFLEGT !!!',
#  '3.7 i V6 24V 328 cv ROADSTER PACK',
#  nan,
#  '*Targa*Sehr guter zustand* bald H-Zulassung',
#  nan,
#  nan,
#  'COUPE 3.7 V6 328 3P',
#  'Track Edition',
#  '2000 GT-R / INTROUVABLE .... 1ère GTR historique',
#  'VUL 2.3 dCi 160ch King-Cab N-Connecta+options',
#  'VUL 2.3 dCi 160ch King-Cab N-Pro+Hard Top+Attelage',
#  'GT-R R34 Coupé',
#  'S15 Spec R AERO / Perlmutt white / NETTO 29.000€',
#  'R34 GTR Vspec / Limited #51/80 / Nismo',
#  'R33 Gtst',
#  '3.0 v6 targa wit metaal',
#  nan,
#  '(2) COUPE 3.7 V6 344 NISMO',
#  'GT-R 32 TT turbo',
#  'Turbo 16V Silvia S14',
#  'Skyline gtst',
#  'GTS-T',
#  '160J    SSS Coupe',
#  '300 ZX  TARGA  1 Hand  Automatik  Leder   BOSE',
#  '63kWh Advance | Nu te zien in onze showrooms! | Be',
#  'H-Kennzeichen',
#  'TEKNA DC 2.3dCi 190PK 7AT',
#  '1.3 DIG-T MHEV 103KW ACENTA 140 5P',
#  '1.3 DIG-T 103KW MHEV PREM.EDITION TWO 140 4X2',
#  'Acenta 1.6 dCi 130',
#  'V8 5,6L King Cab SE BVA 4X4',
#  '1.5 dci 110',
#  '7 posti N-Connecta DIG-T 1.6 163cv benz',
#  'Familiar Manual de 5 Puertas',
#  nan,
#  'Evalia',
#  'e-NV 200 Zero Edition Navigation',
#  'Kombi Evalia (mit 40kwh Batterie)',
#  'DCI 110 CV BV6 TEKNA PERLE',
#  'e-Evalia Zero Edition Navigation',
#  'DCI 130 CV BV6 TEKNA',
#  'Tekna Navigation, Sitzheizung, Klimaautom, DAB+',
#  ...]

# %%
# How many values can I fill using the short_description?
# The floating-point numbers (e.g., 1.0, 2.0) in the short_description correspond to the engine_size.
df.loc[df[df["engine_size"].isnull()].index, "short_description"].str.extract("(\d+\.\d+)").notnull().sum()
# Out:
# 0    374
# dtype: int64

# %%
# The floating-point numbers (e.g., 1.0, 2.0) in the short_description correspond to the engine_size.
# Let's fill the NaN values by extracting these floating-point numbers.
df.loc[df[df["engine_size"].isnull()].index, "engine_size"] = df.loc[df[df["engine_size"].isnull()].index, "short_description"].str.extract("(\d+\.\d+)").values.astype(float)

# %%
handle_missing_values(df , "engine_size")
# Out:
# Missing Values in 'engine_size':
# Count: 1014
# Percentage: 3.54%

# %%
# After the groupby operation, how many NaN values do I have remaining?
df['engine_size'].fillna(df.groupby(['make', 'model', 'body_type', "type"])['engine_size'].transform('mean')).isnull().sum()
# Out:
# 245

# %%
df['engine_size'].fillna(df.groupby(['make', 'model', 'body_type', "type"])['engine_size'].transform('mean'), inplace = True)

# %%
handle_missing_values(df , "engine_size")
# Out:
# Missing Values in 'engine_size':
# Count: 245
# Percentage: 0.86%

# %%
# After the groupby operation, how many NaN values do I have remaining?
df["engine_size"].fillna(df.groupby(["power"])["engine_size"].transform("mean")).isnull().sum()
# Out:
# 2

# %%
df["engine_size"].fillna(df.groupby(["power"])["engine_size"].transform("mean"), inplace = True)

# %%
handle_missing_values(df , "engine_size")
# Out:
# Missing Values in 'engine_size':
# Count: 2
# Percentage: 0.01%

# %% [markdown]
# <h6><span class="label label-danger">Attention</span>Since there is no other column available to fill the remaining values, let's proceed with dropping them. </h6>

# %%
df.dropna(subset=['engine_size'], inplace = True)

# %%
handle_missing_values(df , "engine_size")
# Out:
# Missing Values in 'engine_size':
# Count: 0
# Percentage: 0.00%

# %%
df.engine_size.sample(5)
# Out:
# 11159    1.2
# 11052    1.5
# 135      1.5
# 16813    1.4
# 2146     0.0
# Name: engine_size, dtype: float64

# %%
# let's take 1 decimal place of engine_size
df.engine_size = df['engine_size'].map('{:.1f}'.format).astype(float)
df.engine_size.sample(5)
# Out:
# 27172    2.6
# 21249    1.6
# 4595     1.5
# 473      1.9
# 11827    1.1
# Name: engine_size, dtype: float64

# %% [markdown]
# <a id="7"></a>
# <div class="alert alert-info" role="alert">
# <h1>Column name :<span style="color:red"> comfort_&_convenience </span></h1>
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Operation : </b>First, let's leverage <span style="color:red"><b>the dictionary we created in Part 1  </b></span>to examine the short_description. If we find any matching values, let's <span style="color:red"><b>replace </b></span> them with their corresponding keys . Also,  let's assign <span style="color:red"><b>"functional&mechanical" </b></span>  to the values in the "comfort_&_convenience" column that contain "Start & Stop" based on the <span style="color:red"><b> "short_description"</b></span>  column. Then, let's perform the fillna operation using the <span style="color:red"><b>"seats", "make", and "type" </b></span>  columns.
# </div>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
first_looking("comfort_&_convenience")
# Out:
# column name    :  comfort_&_convenience
# --------------------------------
# per_of_nulls   :  % 11.14
# num_of_nulls   :  3185
# num_of_uniques :  57
# bodywork,functional&mechanical,steering&trim,climate,seats             10647
# bodywork,functional&mechanical,steering&trim,climate,seats,security     5922
# NaN                                                                     3185
# climate,steering&trim,functional&mechanical,bodywork                    2753
# climate,functional&mechanical,bodywork                                   715
# climate,functional&mechanical,seats,bodywork                             471
# climate,bodywork                                                         418
# climate,steering&trim,functional&mechanical,seats                        335
# steering&trim,functional&mechanical,seats,bodywork                       320
# bodywork                                                                 315
# climate,steering&trim,bodywork                                           302
# bodywork,functional&mechanical,steering&trim,climate,security            300
# functional&mechanical,bodywork                                           293
# climate,steering&trim,functional&mechanical                              290
# climate,steering&trim                                                    260
# climate                                                                  243
# steering&trim,functional&mechanical,bodywork                             241
# functional&mechanical,steering&trim,climate,seats,security               231
# climate,steering&trim,seats,bodywork                                     198
# steering&trim                                                            156
# steering&trim,bodywork                                                   117
# bodywork,functional&mechanical,steering&trim,seats,security              110
# climate,seats,bodywork                                                   110
# climate,functional&mechanical                                            104
# functional&mechanical,seats,bodywork                                      64
# seats,bodywork                                                            54
# functional&mechanical                                                     49
# steering&trim,functional&mechanical                                       44
# steering&trim,functional&mechanical,seats                                 40
# climate,steering&trim,functional&mechanical,security                      36
# steering&trim,seats,bodywork                                              26
# climate,functional&mechanical,seats                                       24
# seats                                                                     24
# climate,steering&trim,seats                                               23
# climate,seats                                                             21
# bodywork,functional&mechanical,climate,seats,security                     21
# functional&mechanical,seats                                               18
# steering&trim,functional&mechanical,seats,security                        17
# climate,functional&mechanical,security                                    16
# steering&trim,functional&mechanical,security,bodywork                     16
# climate,functional&mechanical,seats,security                              14
# steering&trim,seats                                                       10
# functional&mechanical,seats,security                                       9
# bodywork,steering&trim,climate,seats,security                              8
# climate,functional&mechanical,security,bodywork                            6
# functional&mechanical,seats,security,bodywork                              5
# steering&trim,functional&mechanical,security                               5
# functional&mechanical,security,bodywork                                    3
# security                                                                   3
# seats,security,bodywork                                                    2
# climate,steering&trim,security,bodywork                                    2
# climate,steering&trim,seats,security                                       1
# seats,security                                                             1
# climate,seats,security                                                     1
# steering&trim,security                                                     1
# climate,security,bodywork                                                  1
# steering&trim,seats,security,bodywork                                      1
# climate,security                                                           1
# Name: comfort_&_convenience, dtype: int64

# %%
con_conve = {
    
"climate" :[  "Air Conditioning",
              "Automatic Climate Control",
              "2 Zones",
              "3 Zones",
              "4 Zones",
              "Auxiliary Heating"
                ],
    
"seats":  [     "Split Rear Seats",
                "Leather Seats",
                "Armrest",
                "Lumbar Support",
                "Seat Heating",
                "Seat Ventilation",
                "Massage Seats",
                "Fold Flat Passenger Seat",
                "Electric Backseat Adjustment",
                "Electrically Adjustable Seats",
                "Electrically Heated Windshield"
            ],
    
"functional&mechanical": ["Parking Assist System Sensors Front",
                          "Parking Assist System Sensors Rear",
                          "Parking Assist System Self-Steering",
                          "Parking Assist System Camera",
                          "Park Distance Control",
                          "360° Camera",
                          "Heads-Up Display",
                          "Rain Sensor",
                          "Light Sensor",
                          "Hill Holder",
                          "Navigation System",
                          "Air Suspension",
                          "Electrical Side Mirrors",
                          "Electric Tailgate",
                          "Start-Stop System"
                        ],
    
"steering&trim" :[     "Cruise Control",
                       "Heated Steering Wheel",
                       "Leather Steering Wheel",
                       "Multi-Function Steering Wheel"
                   ],
    
"bodywork" : [ "Wind Deflector",
               "Sliding Door Right",
               "Sliding Door Left",
               "Tinted Windows",
               "Panorama Roof",
               "Sunroof",
               "Power Windows"
             ],
    
"security" : [
               "Keyless Central Door Lock"
                   ]
}

# %%
# Sure, let's query the key-value pairs of the dictionary in the short description.
for category, keywords in con_conve.items():
    for keyword in keywords:
        result = df.loc[df[df["comfort_&_convenience"].isnull()].index, "short_description"].str.contains(f"(?i){keyword}")
        print(f"{category} {keyword}: {result.value_counts()}")
# Out:
# climate Air Conditioning: False    3117
# Name: short_description, dtype: int64
# climate Automatic Climate Control: False    3117
# Name: short_description, dtype: int64
# climate 2 Zones: False    3117
# Name: short_description, dtype: int64
# climate 3 Zones: False    3117
# Name: short_description, dtype: int64
# climate 4 Zones: False    3117
# Name: short_description, dtype: int64
# climate Auxiliary Heating: False    3117
# Name: short_description, dtype: int64
# seats Split Rear Seats: False    3117
# Name: short_description, dtype: int64
# seats Leather Seats: False    3117
# Name: short_description, dtype: int64
# seats Armrest: False    3117
# Name: short_description, dtype: int64
# seats Lumbar Support: False    3117
# Name: short_description, dtype: int64
# seats Seat Heating: False    3117
# Name: short_description, dtype: int64
# seats Seat Ventilation: False    3117
# Name: short_description, dtype: int64
# seats Massage Seats: False    3117
# Name: short_description, dtype: int64
# seats Fold Flat Passenger Seat: False    3117
# Name: short_description, dtype: int64
# seats Electric Backseat Adjustment: False    3117
# Name: short_description, dtype: int64
# seats Electrically Adjustable Seats: False    3117
# Name: short_description, dtype: int64
# seats Electrically Heated Windshield: False    3117
# Name: short_description, dtype: int64
# functional&mechanical Parking Assist System Sensors Front: False    3117
# Name: short_description, dtype: int64
# functional&mechanical Parking Assist System Sensors Rear: False    3117
# Name: short_description, dtype: int64
# functional&mechanical Parking Assist System Self-Steering: False    3117
# Name: short_description, dtype: int64
# functional&mechanical Parking Assist System Camera: False    3117
# Name: short_description, dtype: int64
# functional&mechanical Park Distance Control: False    3117
# Name: short_description, dtype: int64
# functional&mechanical 360° Camera: False    3117
# Name: short_description, dtype: int64
# functional&mechanical Heads-Up Display: False    3117
# Name: short_description, dtype: int64
# functional&mechanical Rain Sensor: False    3117
# Name: short_description, dtype: int64
# functional&mechanical Light Sensor: False    3117
# Name: short_description, dtype: int64
# functional&mechanical Hill Holder: False    3117
# Name: short_description, dtype: int64
# functional&mechanical Navigation System: False    3117
# Name: short_description, dtype: int64
# functional&mechanical Air Suspension: False    3117
# Name: short_description, dtype: int64
# functional&mechanical Electrical Side Mirrors: False    3117
# Name: short_description, dtype: int64
# functional&mechanical Electric Tailgate: False    3117
# Name: short_description, dtype: int64
# functional&mechanical Start-Stop System: False    3117
# Name: short_description, dtype: int64
# steering&trim Cruise Control: False    3117
# Name: short_description, dtype: int64
# steering&trim Heated Steering Wheel: False    3117
# Name: short_description, dtype: int64
# steering&trim Leather Steering Wheel: False    3117
# Name: short_description, dtype: int64
# steering&trim Multi-Function Steering Wheel: False    3117
# Name: short_description, dtype: int64
# bodywork Wind Deflector: False    3117
# Name: short_description, dtype: int64
# bodywork Sliding Door Right: False    3117
# Name: short_description, dtype: int64
# bodywork Sliding Door Left: False    3117
# Name: short_description, dtype: int64
# bodywork Tinted Windows: False    3117
# Name: short_description, dtype: int64
# bodywork Panorama Roof: False    3117
# Name: short_description, dtype: int64
# bodywork Sunroof: False    3117
# Name: short_description, dtype: int64
# bodywork Power Windows: False    3117
# Name: short_description, dtype: int64
# security Keyless Central Door Lock: False    3117
# Name: short_description, dtype: int64

# %%
# Because the "Short_Description" column does not contain any values that are present in the "safety_security" dictionary, 
# then we won't be able to utilize the dictionary in this case.

# %%
# To be more thorough, let's check if there are any words in the short description 
# that match the key-value pairs of the dictionary, as a precautionary measure.
list(df.loc[df[df["comfort_&_convenience"].isnull()].index, "short_description"].unique())
# Out:
# ['CDi',
#  '350+',
#  'S 4Matic+ 8G-DCT',
#  'd 4Matic (EURO 6d)',
#  '250e 8G-DCT',
#  'CDI Elegance',
#  'd (177.003)',
#  '200d 4Matic 8G-DCT',
#  '200d Sedán 8G-DCT',
#  '4-Door 63 S 4MATIC+',
#  '250e Sedán 8G-DCT',
#  '200d 7G-DCT',
#  'CDI 100kW ( 136CV ) Urban',
#  'e A 250e Progressive Sfeerverlichting / NIEUW GERE',
#  'd Premium',
#  'MERCEDES-BENZ Clase GLK Pequeño  Automático de 5',
#  'Pequeño Automático de 5 Puertas',
#  '180d 8G-DCT',
#  'CDI Premium',
#  'CDI Style',
#  'Biturbo V-Max',
#  'abrio Mercedes-AMG 4MATIC',
#  'MERCEDES-BENZ Clase SL Descapotable  Automático d',
#  'SL *Pagode*3.Besitz/Dt.Fahrzeug/H-Zul.',
#  'MercedesAMG',
#  'SL Pagode',
#  '200K',
#  'Cabrio d',
#  'Deutsches Fahrzeug  Sammlerzustand',
#  'SL Vollrestauration',
#  'V12 - Origineel Nederlands -',
#  '200 K.',
#  'GE',
#  'SL',
#  'Cabriolet AMG Line',
#  '(R129)',
#  '(R129) 2nd Owner/Collectable',
#  'Cabrio',
#  'cabrio d  Premium Plus 4matic auto',
#  '220 d executive a',
#  '220 A Cabriolet',
#  '190SL',
#  'S Cabriolet Ponton Typ A (W 180)',
#  'D',
#  nan,
#  'SEb (111)*DEUTSCHES-FAHRZEUG*H-KENNZEICHEN*TOP-ZUS',
#  'S Coupe',
#  '4Matic (EURO 6d-TEMP)',
#  'C Coupe*DEUTSCHES-FAHRZEUG*AUTOMATIK*H-KENNZEICHEN',
#  'Compressor',
#  '220d Aut.',
#  'Coupé d (238.314)',
#  'd 4MATIC -',
#  'Coupé 400d 4Matic Aut.',
#  'CDI Chrome',
#  'Coupé d AMG LINE',
#  'd (205.314)',
#  'EQ Boost Aut. (9.75)',
#  'CDI (LA) Sport Edition (203.708)',
#  'Coupé 220d',
#  'COUPE AMG -Line',
#  'CDI Inspiration 7G-DCT',
#  '220d 4Matic 8G-DCT',
#  '300e 4Matic 9G-Tronic',
#  '4MATIC',
#  'd 4MATIC',
#  'd 4 MATIC 245cv 9 vel. *IVA deducible* *2020* *Nac',
#  'CDI',
#  '4Matic 8G-DCT',
#  'd 4Matic (253.915)',
#  'Puch  JAGD-FZG./WINDE/KOFFER/BRAUSE/AHK',
#  'e 4Matic',
#  '300 4MATIC',
#  'D ADVANTAGE + PAQ NIGHT',
#  'GE lang Cabrio Steyr-D-Puch AHK Automatik Rücksitz',
#  'Coupé 350D 258 CV',
#  'Mercedes-AMG 4MATIC',
#  'Mercedes-AMG 4MATIC+',
#  'D 2.2 170CV AUT 5P',
#  '300d 4Matic Aut.',
#  'd',
#  '(+)2.0 AVANTGARDE AUTO 211 5P STATE',
#  'd Estate Avantgarde',
#  'de Estate AMG LINE',
#  'CDI Blue Efficiency Estate',
#  'Estate Estate',
#  'd Estate',
#  '(+)2.1 D AMG LINE 5P',
#  'B200 CDI AMG AUT 136CV',
#  '580 4Matic',
#  'CDI BlueEfficiency (204.001)',
#  '1.6',
#  '2.3 16',
#  'Mercedes-AM53 4MATIC+',
#  'Mercedes-AMG S 4MATIC+',
#  'CDI Business',
#  'BlueTEC Sport',
#  '220d 9G-Tronic 194',
#  'BlueTEC 4Matic (212.011)',
#  '*1.HAND*ORIGINAL ZUSTAND*KEIN ROST',
#  '1.6T PHEV S/S GS-Line Aut. 180',
#  '1.5D DT S/S GS-Line + 100',
#  '1.2T S/S Design & Tech 130',
#  'Corsa-e Elegance-e',
#  '1.5D DTH S/S Elegance 130',
#  '1.4 Twinport 87ch Start/Stop',
#  'TwinTop 1.4 16V Sport',
#  '2.0 CDTi S/S 165 CV Excellence',
#  '1.4 Turbo Excellence',
#  '1.4 T S/S Excellence',
#  '1.4T 140cv Excellence S/S #NAVY, BLUETOOTH',
#  'Descapotable Manual de 3 Puertas',
#  '2.0 264 turbo cab / suivi complet opel / 1e main',
#  '2.0 Turbo Einzelstück/Rennwagen/Track.',
#  'Roadster',
#  '2.0 Turbo ECOTEC',
#  '2.0 T',
#  '2.0 Turbo Pack',
#  '2.2 16v VX 220 VX220',
#  'opel astra h cabrio opc',
#  'Twin Top 1.8 (Enjoy)',
#  '1.4-16V cabrio',
#  'Deportivo Manual de 3 Puertas',
#  'B 2.0 GSI 1985 ATS RECARO APK 2023',
#  'GT/J Sport',
#  'C 2.2 de Luxe',
#  '3 Puertas 1.4T GSI',
#  'GTC 2.0 CDTi 195cv Biturbo 3p S/S #NAVY, BLUETOOTH',
#  'Coupe GS',
#  'MANTA STINGRAY-RESTAURATIONSOBJEKT-AUTOMATIK',
#  '2.5i V6',
#  'olimpia record coupe',
#  '19 SR',
#  'Commodore 2.5 GS Coupe Automat',
#  'Olimpia 1.5 Coupe  //Top Zustand//',
#  '*H-Kennzeichen*Oldtimer*TÜV Neu*',
#  '3.0 E',
#  '1.4',
#  'A Berlinetta 1,9 S',
#  'GT/E gruppo 2',
#  '1900 S Berlina',
#  'V6 190ps',
#  'opel Astra g coupe project',
#  'Olympia',
#  '1900',
#  'GT1900 AL',
#  'Opel GT 1900',
#  'GSE (état concours)',
#  '1200 S',
#  'GTC 1.6 t ecotec Cosmo S s&s 180cv',
#  'GT-A-L',
#  'B Coupe aus 1969',
#  '1.7 CDTi 111 y. Ed.',
#  '1.7 CDTi Enjoy',
#  '1.9 N',
#  'B Coupe',
#  'GTE - CONRERO',
#  'Irmscher GSE Oltimer FIA Liebhaber ',
#  '2.2 16V Coupe',
#  'Manta-B',
#  'C1 Coupe 1200H',
#  'B LS Fastback',
#  'coupé',
#  '2.0 GSi / Look Manta 400 /  Rally / Oldtimer /',
#  'GSI !! 1.8i !! ZERO CORROSION !!',
#  'oldtimer 3.0 6cil GSE 180pk manual gears box',
#  '1200 S  Allestimento Irmscher',
#  'AT',
#  'Berlinetta',
#  'Coupe 2.0 turbo 16v 200cv',
#  'B GSI - Hatchback - Same Owner since 1990',
#  'B 2.0 GT/E,IRMSCHER,SERVO,H-ZULASSUNG,SPANIEN',
#  'A 1,6S Original 28300 KM Neuwertig',
#  'B CC Berlinetta H-KENNZEICHEN und Tüv Neu*',
#  '5p 1.6i twinport 16v',
#  '1.8 16V Coupe',
#  '200',
#  'B 1,9 S 1 Hand',
#  'ASTRA GTC 1.4',
#  'Astra Coupe 1.8 16v',
#  '3p 1.4i 16v Club',
#  'e    1.4i  32jahre alt  h kennzeichen-möglich',
#  '1.3 CDTI Advance 95cv S/S 5 PORTE',
#  '1.4i 16V',
#  'B CC - 2.0E - 22tkm ! -perfekt original',
#  '1.3 CDTI b-Color 75cv 5 PORTE',
#  'PHEV 1.6 Turbo GS Line Aut. 4x2 225',
#  '3.0TD LS',
#  '1.5CDTi S&S GS Line Aut. 130',
#  '1.6 Turbo  Auto 4x4 Ultimate',
#  '1.2T S&S GS Line 130',
#  '1.2 96kW (130CV)  S/S Innovation',
#  'Mokka-e GS Line-e',
#  'GS LINE',
#  '1.2 Turbo Selective',
#  'X 1.6 CDTI Excellence',
#  'X EXCELLENCE',
#  'INS-ST INNOV. 1.6D 136CV MT6',
#  'SPORT TOURER 1.2 TURBO 145 CV ELEGANCE',
#  'Life 1.2 T S/S   XL Selective',
#  'Sports Tourer 2.0 CDTI 130CV Edition Aut',
#  'Life 1.5 CDTI INNOVATION',
#  'Life 1.5 TD 75kW (100CV) S/S   L Selective',
#  'ST 1.5D DVH S&S Business Edition 122',
#  'Life 1.5 TD 96kW 130cv SS Edition L',
#  'ST  2.0D DVH 130kW AT8 Business Elegance',
#  'Berlina Manual de 5 Puertas',
#  '1.2T SHR 107kW (145CV) Business Elegance',
#  'GS  1.5D DVH 90kW MT6 Business Edition',
#  'GS  2.0T SHT 169kW AT9 4x4 GSi',
#  '2.0 T SHT S&S Business Elegance AT9 170',
#  '1.4T Elegance AUT 5p',
#  '1.5D DVH S&S GS-Line AT8 122',
#  '1.6 Turbo S/S GSi Line',
#  'GS 1.6 CDTi 100kW Turbo D Business',
#  '1.2T XHL 74kW (100CV) GS-Line',
#  '1.4 Turbo S/S Sportive',
#  '1.6T Hybrid 132kW (180CV)  Auto GS-Line',
#  '1.2T XHL 74kW (100CV)  Auto Elegance',
#  '1.8 TCe GPF RS Trophy EDC 221kW',
#  '1.5 dCi 110CV Nav',
#  '1.5 ENERGY dCI 110 CV AUT',
#  'Color/Miet Batterie/Türen mit Scheiben',
#  'E-TECH RS Line 117kW',
#  'TCe Zen 67kW',
#  '1.3 TCe 140cv Zen Energy',
#  'Life 80',
#  'Electric Zen R80 60kW Batería 20kW/h',
#  '80 INTENS WHITE',
#  '1.5dCi Blue R.S. Line EDC 85kW',
#  'E-TECH Híbrido Intens 103kW',
#  'E-TECH Híbrido Zen 103kW',
#  'tce 120 intens pack trophy + equipe pmr handicap',
#  '0.9 Dynamique Navi*MMI*Clima*Parksensor*Keyless*Ca',
#  '1.3 TCe GPF Intens 103kW',
#  'LIMITED LIFE 41KW/H',
#  '1.4 RN Orig.NL 54dkm+nap Topstaat!',
#  'Twizy 45 Intens Black Flex',
#  'Sport 1. Vorbes. Scheckheft gepflegt',
#  '1.5 DCI LMV NAVIGATIE CRUISE CD CV+AB',
#  'life 80 kw r110 batería 40kwh',
#  'Plein Air*Komplettneuaufbau*H-Kennz.',
#  'R4 Cabriolet / Sammlerfahrzeug / 1. Hand',
#  'CC 1.5 dCi Dynamique 110 CV',
#  'CC TCe 130 Dynamique 130 CV',
#  'Sporter Blue dCi 160 CV EDC Exe',
#  '1.8-16V | Cabrio | 69.000 KM | 1994 | 1 Swiss Owne',
#  '1.8 Fairway',
#  '1.6-16V Priv.Luxe',
#  'renault megane 5 porte dci  110cv',
#  'Cabriolet 1.6',
#  '4cv * DECOUVRABLE',
#  'Mégane',
#  '2.0 Coupe-Cabriolet Confort Dynamique',
#  'Cabriolet 16V',
#  'Coupe 2.0 16v T RS 250cv LEGGERE BENE !!!',
#  'CC 1.5 dCi 110 FAP GT Line EDC 2015',
#  'Mégane C.C. 1.5dCi Dynamique',
#  'SporTour 1.9 dci Dynamique 130cv fap',
#  '1.6-16V Privilège',
#  '1.6 Dynamique',
#  'II CC 1.9 dCi 130 FAP Privilège',
#  '2.0 Coupe-Cabriolet Privilege',
#  '8.5',
#  '1.5 dCi 110CV S-S 4p. Express Ice',
#  'ACL  Cabrio   Rodeo',
#  'Pare-Brise 2.0 150 ch Avec Hard Top',
#  '1.9 dCi FAP Coupe-Cabriolet Dynamique',
#  'R19 Cabriolet 1.8',
#  '2.0i',
#  '1.2 75CV GPL 5 porte Wave 201407',
#  'FLORIDE ( con hard top)',
#  'Megane SporTour 1.5 dci Gt Line 110cv',
#  'mit Frontscheibe',
#  'Coupé RS 2.0 16v 265 S&S',
#  'Williams Phase 2',
#  'tce 140 edc fap',
#  'COUPE EXPRESSION 1.9DCI',
#  'Mégane Coupé 1.6ie',
#  'tce 140 edc fap - 21b',
#  'A PREPARER',
#  'Deportivo Automático de 3 Puertas',
#  'CoupÃ© 2.0 dCi 150cv 2p #LIBRO, NAVY, BLUETOOTH',
#  'anterior TCe GPF Energy Limited 66kW',
#  'Zen',
#  'TCe 115 Expression Energy SANDS 85 kW (115 CV)',
#  'anterior TCe Limited 55kW',
#  '1600 S',
#  'Europa Cup',
#  'Renault Megane 1,5 dCI Energy Limited S&S 95',
#  'Group 4 * Roadlegal *',
#  'GTS',
#  '3 coupe III COUPE 2.0 DCI 160 FAP GT EURO5',
#  'A 310',
#  'TURBO 1',
#  'Megane coupe manual 2.0 dCi',
#  'SporTour 2.0 dci 4Control esm 150cv',
#  '45 ELECTRIQUE',
#  'Coupe Energy dCi 110 FAP Start & Stop GT Line',
#  'TR',
#  'v6 fase2    -   65000km',
#  'Mégane Sport R.S. 265 Stop&Start Start&Stop',
#  'Tbo',
#  '2.0 T RS',
#  'GT 18Fuchs/Ablage-/Sichtpaket',
#  'Rs',
#  'Turbo Maxi 2 Gruppo B Omologata Stradale',
#  'Coupe 2.0 16V Turbo GT',
#  'II 3.0 V6 Sport',
#  'Coupe Energy dCi 130 FAP Start & Stop GT Line',
#  'ARKANA E-Tech 145 - 21B R.S. Line',
#  'V6 TURBO',
#  'tce 160 edc fap - 21b',
#  '1.9 dCi Expression',
#  'Coupe dCi 175 FAP',
#  'RENAULT CLIO V6 SPORT "PHASE 2"',
#  '1.0 TCE 74KW BUSINESS 5 PORTE',
#  'DCI 180 4 CONTROL',
#  'Coupe 2.0 dCi 150ch Monaco GP',
#  'Technik 80 Z.E14.04.2014',
#  'TCe 160 EDC GPF BOSE EDITION',
#  'Coupe 2.0 dci Wave Edition 150cv',
#  'COUPE 1.6 dCi 130 FAP Energy Bose eco²',
#  'Fleischmann',
#  'dCi 110 FAP Coupe Dynamique',
#  '1.6 E-Tech R.S.Line 105kW',
#  'Limited',
#  '1.3 TCe R.S. Line EDC 103kW',
#  'Zen E-TECH Híbrido 105kW(145CV)',
#  '2.0 Blue dCi 184cv X-Tronic Initiale Paris',
#  '1.6 E-Tech 145cv RS Line',
#  'dci 90',
#  'e-tech 145 - 21',
#  'Bose Edition 2.0 dCi 150cv 4x4',
#  'blue dci 115',
#  'tce 160 edc',
#  '1.5 BLUE DCI 115CV BUSINESS',
#  '1.2 VOOR EXPORT',
#  'V INITIALE PARIS 1.6 DCI 160CV AT6',
#  'S.T E-TECH Intens 117kW',
#  '1.8 TCe SL Icon EDC',
#  '1.6  dCi 130',
#  'S.T. 1.5dCi Blue Intens 85kW',
#  'S.T. E-TECH Zen 117kW',
#  'S.T. 2.0dCi Blue Zen EDC 147kW',
#  'Ini. P. Blue dCi 139 kW (190CV) EDC',
#  '4P 1.6 DCI 130CV',
#  'Life',
#  'ZEN ENERGY dCI 81 KW 110 CV EDC 5',
#  'grand scénic dci 130 energy fap eco2',
#  'Zen Energy dCi 81kW (110CV)',
#  'S.T. 1.5dCi Energy Tech',
#  'blue dci 150',
#  'estate dci 130 energy',
#  'Luxe Privilege 2.0 16V EU4',
#  'Zen Blue dCi 88 kW (120CV) - SS',
#  'S.T. 1.8dCi Blue GT Line EDC 110kW',
#  'mégane iv estate blue dci 115 - 21b',
#  'BUSINESS BLUE DCI 70 KW 95CV',
#  '1.5 DCI TECH ROAD ENERGY 110CV',
#  '1.8 RS Energy Tce 205kW 280cv',
#  'RS Trophy Energy 162kW (220CV) EDC',
#  'LIMITED BLUE DCI 88 KW 120CV',
#  '4 Energy dCi 55kW (75CV) Business',
#  'Zen TCe GPF 74 kW (100CV)',
#  'Init. P. Blue dCi 118 kW(160CV) EDC SS',
#  'INTENS R135 B-Rent',
#  'Energy TCe 120 EDC Euro 6 Intens',
#  'Limited Energy TCe 66kw (90CV) eco2',
#  '1.9 dCi/130CV 4p. Dynamique',
#  'Renault 18 Turbo',
#  'BOSE Edition',
#  'ii 1.2 lev 16v 75 eco2',
#  'dci 130 energy intens / origine france',
#  '1.5 dci - 90ch   iv berline business',
#  '4 IV (BFB) 1.8T 280CH RS EDC',
#  'RS',
#  '4 Energy dCi 75 eco2 Euro 6 Business',
#  '1.2 TCe 115 SS Energy Expression',
#  '1.5BlueHDi S&S GT EAT8 130',
#  '1.6 Hybrid Allure Pack EAT8 180',
#  '1.2 Puretech S&S Allure Pack 100',
#  '1.5 BlueHDi S&S Active Pack 100',
#  'Pequeño Manual de 5 Puertas',
#  '1.5 BlueHDi S&S GT Pack EAT8 130',
#  '1.2 PureTech S&S Allure Pack 130',
#  '1.5 BlueHDi S&S GT EAT8 130',
#  '1.2 PureTech S&S Active Pack 110',
#  '12V VTi 82CV 5p. Active',
#  'VTi 52kW (72CV) Allure',
#  'Allure Long PureTech 110',
#  '1.2 PureTech S&S GT EAT8 130',
#  '1ste Eigenaar 134.000km Garantie+Keuring',
#  '1.6 Hybrid GT EAT8 225',
#  '1.2 Puretech S&S Allure Pack EAT8 100',
#  '1.0-12V XR',
#  '1.5 BlueHDi S&S Allure Pack EAT8 130',
#  '1.4Diesel !!!75.000km!!! GARANTIE + KEURING',
#  '1.2 Puretech S&S Allure Pack EAT8 130',
#  'Allure Pack Eléctrico 100kW',
#  '1.0-12V XR| SPORT| ELEK. RAMEN| LM-VELGEN',
#  'WAGON Business 1.6 8v e-HDi 115cv S/S',
#  'CC 1.6 HDI 112 FAP',
#  '206 CC Roland Garros',
#  '1.1i cat Cabriolet CJ',
#  '207 CC 1.6 16v 120ch',
#  'Cabriolet 2 l',
#  'CC Sport 1.6 VTI 120',
#  'CC 1.6 VTI 16V 120',
#  'Cabrio 1.6 THP Sport Pack 115 kW (156 CV)',
#  'CC 1.6',
#  'CC 1.6 THP Edition Limitada 150CV',
#  'CC Cabrio 2.0 HDI Sport 140CV',
#  'CC Cabrio 1.6 VTi Sport 122CV',
#  'CC 1.6 VTi Active 120 CV',
#  'CC 1.6 VTi 120cv SPORT 2p #BLUETOOTH',
#  'CC HDI 136 FAP',
#  'cabriolet $$je recherche en état ou a refaire$$',
#  'Cabriolet Injection',
#  'GTI',
#  'CC 2.0 Sport 180',
#  '206CC',
#  '2.0 HDI 120CV DISTRIB OK',
#  '1.6-16V',
#  'cabrio',
#  'CC 2.0 HDi 16V 140 ch FAP Féline 7',
#  '2.0-16V',
#  '1.6-16V Roland G.',
#  'CC 2.0 16V',
#  'CC',
#  '1.6 Vti Cabrio 2008 Zwart',
#  '<NULL',
#  'CC 135',
#  'CC e-HDi FAP 110 Start&Stop Active',
#  'CC 110 Roland Garros',
#  'CABRIOLET (KF2)',
#  'CC HDi FAP 110 Premium',
#  '1.6-16V T Roland G.',
#  'Cabriolet 1.8',
#  '206CC Hardtop Cabriolet',
#  'Automatik Leder',
#  '1.3i Rallye',
#  'Coupé 2.0l - Garantie 12 mois',
#  '1.6 THP 155cv',
#  '1.6 THP',
#  '2.0 HDi  163 CV',
#  '2.0 HDi 163 CV',
#  'Coupé Ultima Edizione HDi Pack 136',
#  'CoupÃ© 2.2 163cv 2p #LIBRO',
#  '2.7 V6 hdi 24v Feline auto fap',
#  '1,6 THP 160',
#  '3.0-24V V6 Pack',
#  "201 '30",
#  '5p 1.4 vti 16v XS',
#  '16 GTI',
#  'Coupe "S" ( 1974 )',
#  'cc roland garros 1.6hdi 112 fap',
#  '2.0i 16V cat Coupé',
#  'Coupe 165 Sport',
#  'SW 2.0 hdi 16v Tecno Ciel fap',
#  'GTI 1.9 130 CV--ASI ORO--ORIGINALE--PARI AL NUOVO',
#  '3.0i V6 24V cat Coupé Plus',
#  "3.0i V6 24V cat Coupé Plus Settant'anni",
#  's16',
#  '1.6 thp 16v 156cv auto',
#  '2.0 HDi FAP 160',
#  'GTI 1.6 THP S&S 3 porte',
#  'Active BlueHDi 120cv S&S 5 PORTE BERLINA',
#  '1.6 thp 16v 200cv',
#  '007 2.2-16V Pack ( heerlijke wagen! )',
#  '1.6 155 THP',
#  '3p 1.6 16v XS',
#  'Coupé 2.7 V6 HDi Tecno',
#  'Plus 3p 1.1 X-Line eco-Gpl',
#  '1.5BlueHDi Active Pack S&S 130',
#  '1.6 BlueHDi 88KW (120CV) S&S Allure',
#  'BlueHDI 81kW (110CV) Active',
#  'HYB PHEV 225 Allure Pack e-EAT8',
#  '1.2 PureTech S&S Allure Pack EAT8 130',
#  '1.5 BLUE HDI 130 CV EAT8 ALLURE',
#  '1.5 BLUE HDI 130 CV ACTIVE PACK',
#  '300 e-EAT8 Allure Pack',
#  'ALLURE HDI 130 CV',
#  '1.6 THP 156cv -',
#  '1.2 PureTech 96KW S&S Active Pack',
#  'BlueHDI 130 S&S EAT8 Allure',
#  '1.5BlueHDi S&S Roadtrip S&S EAT8 130',
#  'BlueHDI 130 S&S EAT8 Allure Pack',
#  'BlueHDI 81kW (110CV) Allure Pack',
#  '1.2 PureTech SS Allure',
#  '1.5 Blue-HDi GT Line',
#  'GT LINE 1.2 PURE TECH 130 CV',
#  '300 e-EAT8 GT Pack',
#  'ALLURE',
#  'Puretech 100 S&S 6 Vel. MAN Active Pack',
#  'GT-Line BlueHDi 96kW (130CV) S&S EAT8 GT Line',
#  '1.6 BlueHDi 88KW 120CV Allure SS',
#  '1.2 PURETECH 100 S&S ACTIVE PACK 5P',
#  '1.5BlueHDi S&S Allure 100',
#  'BlueHDI 100 S&S BVM6 Allure',
#  '1.5BlueHDi S&S GT Line 100',
#  '1.5 BlueHDi 96kW S&S  EAT8 Allure Pack',
#  'Confort 1.6 HDI 110 FAP',
#  'Active 1.6 BlueHDi 100',
#  '1.5 BLUEHDI 96KW ALLURE S&S 5P',
#  '1.2 PureTech S&S Active Pack 100',
#  '1.2 PureTech S&S Active 100',
#  '1.5BlueHDi S&S Allure Pack EAT8 130',
#  '1.2 PureTech Style 82',
#  '1.5 BLUEHDI 96KW S&S ALLURE 5P 7 Plazas',
#  '1.5 BlueHDi 96kW (130CV) S&S Active Pack',
#  'HYB PHEV 300 GT AWD e-EAT8',
#  '225 e-EAT8 Allure Pack',
#  '1.6 e-HDi 92 Allure',
#  '1.2 S&S PureTech Allure Pack EAT8 130',
#  '2.0 bluehdi 150ch s\\u0026amp;s bvm6 allure / suivi',
#  '1.2 PureTech 96KW (130CV) S&S Allure',
#  '1.2 PURETECH 96KW S&S ALLURE 5P',
#  'Puretech 100 S&S BVM6 Active Pack',
#  '1.5bluehdi active s&s 130',
#  'BlueHDi 96kW (130CV) S&S EAT8 Allure',
#  'SW 1.6 Hybrid GT Pack EAT8 225',
#  'SW  HYBRID 225 e-EAT8 GT',
#  '5p Active 1.4 HDi 70 FAP',
#  'SW 1.2 PureTech S&S Active Pack 110',
#  'SW 1.6 Hybrid Allure Pack EAT8 180',
#  'GT Long BlueHDi  96kW',
#  '1.5 Blue-HDi Access Standard',
#  '1.5 Blue-HDi Access L1',
#  'SW Allure Pack PureTech 130 EAT8 Klima AB',
#  'Active Standard BlueHDi 73kW',
#  'SW GT Line 1.2 PureTech 96KW (130CV)',
#  '1.2 PureTech EAT8 GT Long 7 plazas',
#  'SW ACTIVE 1.6 BLUEHDI 88KW 120CV',
#  'SW PSE Hybrid 360 Automatik 8-Gang',
#  'SW  BlueHDi 130 S&S GT',
#  'SW  PureTech 130 S&S 6 Vel. MAN Style',
#  '2.0 bluehdi 180ch eat6 / suivi entretien complet à',
#  'SW 1.2 PureTech S&S Allure Pack EAT8 130',
#  'standard 1.5 BLUEHDI gt line 130 eat8',
#  '5p XT 2.0 HDI 136 FAP',
#  '1.6 hdi 16v Lee',
#  'SW  BlueHDi 130 S&S EAT8 Style',
#  'SW Hybrid 225 GT e-EAT8',
#  '308 BlueHDi 180 EAT6 S&S SW GT',
#  '1.5 BLUEHDI 96KW ALLURE AUTO SW 5P',
#  '5p GT Line 1.2 PureTech 130 S&S',
#  'SW  Puretech 130 S&S EAT8 GT',
#  '1.5 BLUEHDI 96KW STYLE AUTO SW 5P',
#  'SW Active Pack Puretech 130 S&S MAN',
#  'RXH 2.0 BlueHDi 180CV Autom.',
#  '2ª serie PureTech Turbo 130 S&S SW Allure',
#  'SW  1.6 BlueHDi 88KW (120CV) Active',
#  'Style 1.6 BlueHDi 120 FAP',
#  'SW  PureTech 130 S&S EAT8 Active Pack',
#  'SW GT Pack BlueHDi 130 Automatik 8-Gang',
#  'II Ph2 1.5 BlueHDi 130 S\\u0026S GT Line BA8',
#  'ACTPK PT100',
#  '1.5 Blue-HDi GT Line Standard',
#  'SW  Hybrid 225 eEAT8 GT',
#  '1.5 BLUEHDI ALLURE 130 standard',
#  '5P PSE HYBRID 360 e-EAT8',
#  '5P PSE HYBRID 360 e-EAT8  Sport Engineered',
#  'Hybrid 225 GT e-EAT8',
#  '403 Oldtimer/ Sammler /Rarität/Black Panther/',
#  'Berline Bj.1956',
#  'Hybrid 225 Allure Pack e-EAT8',
#  '1.5 BLUEHDI 96KW TECH EDITION 5P',
#  'Active BlueHDi 96kW (130) S&S 6vel MAN',
#  '1.6 HYBRID 225 ALLURE PACK E-AUTO 225 5P',
#  '1.6 PHEV 225 E-EAT8 GT 225 5P',
#  '1.2 PureTech S&S Active Pack EAT8 130',
#  'PureTech 96kW (130CV) EAT8 GT Line',
#  '5p  BlueHDi 130 S&S Active',
#  '5P  BlueHDi 130 S&S EAT8 Allure Pack',
#  '5P  PureTech 130kW (180) S&S EAT8 Active',
#  '1.6 Hybrid 225cv eEAT8  GT Pack',
#  'Active BlueHDi 96kW (130CV) S&S EAT8',
#  '1.5 BLUEHDI 130 ALLURE AUTO 5P',
#  '16V SR',
#  '5P  BlueHDi 120kW (160) S&S EAT8 GT Line',
#  '1.5 BLUEHDI 73KW GT LINE 5P',
#  '1.2 PureTech 60KW (82CV)',
#  'PureTech 73kW (100CV) Active Pack',
#  '2.2 Sport',
#  'Tbo Inj Ti',
#  'BlueHDi FAP 100 Stop & Start Active',
#  '1.6 e-HDi 112 CV ca. rob. S&S Active',
#  '5P ACCESS 1.6 BLUEHDI 75',
#  '5p 1.5 bluehdi allure s&s 130cv eat6',
#  '403 Berlina',
#  'GLS 1,5',
#  '2.3d GL Neuer Motor Neue Innenausstattung',
#  '1.5BlueHDi S&S Business Line EAT8 130',
#  '1.5 BlueHDi Allure S&S 130',
#  'business line bluehdi 130 eat8',
#  '1.6 PureTech GT Line 5p',
#  '2.0 HDi 16V FAP - 136  BERLINE Confort Pack GARANT',
#  '1.5 BLUEHDI 96KW ALLURE 5P',
#  'GT LINE PURETECH 130 EAT8',
#  '5P  PureTech 130 S&S EAT8 Active Pack',
#  '5P  Hybrid 225 eEAT8 GT',
#  '1.5 BlueHDi 130 ALLURE S&S EAT8',
#  '5p  PureTech 110 S&S Allure Pack',
#  '1.4 3 porte Roland Garros',
#  '1.6 Automatik *Oldtimer*Schiebedach*Servo*..',
#  'Active',
#  '1.5 BlueHDi 130 allure S&S EAT8',
#  '5P  Hybrid 180 eEAT8 GT',
#  '5P  BlueHDi 130 S&S EAT8 GT',
#  'GT BlueHDi 130 EAT8 S&S aut.',
#  'puretech 68ch bvm5',
#  '500e 3+1 87Kw La Prima',
#  '1.0 GSE Lounge',
#  'Pequeño Manual de 3 Puertas',
#  '1.3 MJet 95cv Cargo Base N1',
#  '500e 87Kw Icon',
#  'Wenig Km 8-fach TÜV 10.2023',
#  '1.0 Hybrid Dolcevita 52kW',
#  '1.0 Gse City Cross Hybrid',
#  "Coupe' Prototipo Motore Ferrari 8.32",
#  'FSM',
#  'P Polski Komplett Restaurierter Fiat',
#  '1.3 MJT 95 CV S&S Lounge',
#  '4x4 Trekking Country Club',
#  '1.0 hybrid Lounge 70cv',
#  '1ª serie 1100 i.e. cat 4x4 Country Club',
#  '110F',
#  '1.2 GASOLINA 60 CV 5P',
#  'LOUNGE FULL OPZIONAL CON TETTO APR ELET PRONTI VIA',
#  'GIANNINI',
#  'e',
#  '500Ce 87Kw Icon',
#  '1.0 Hybrid 51KW (70 CV) Sport',
#  '1.2 8v 51kW (69CV) Lounge',
#  '2.0 Automatik 76\u202fkW (103\u202fPS), Automatik, Fronta...',
#  'Descapotable Manual de 2 Puertas',
#  '2+2',
#  '522L Cabriolet',
#  'Fiat 850 Spider',
#  'Savio Jungla Junglaboo H-Kennzeichen TÜV neu',
#  '1.2 Lounge 69cv',
#  '1.0 70CV HYBRID CABRIO LOUNGE CARPLAY CLIMA BICOLO',
#  'D  RESTAURO TOTALE',
#  '1.8 16v GPL',
#  '595c 1.4 16v t. t-jet turismo 160cv mta e6',
#  'Lusso',
#  'E 3+1 ICON 320KM 87KW',
#  'Lounge 1.2 8v 51KW (69 CV)',
#  'C 1.2 8v 51kW (69CV) Lounge',
#  'C 1.2 8v 69 CV Pop',
#  'C Lounge 1.2 8v 51KW (69 CV)',
#  'C 1.2 8v 69 CV Lounge',
#  'C 1.2 8v 51kW (69CV) S',
#  'BEV 24KWH RED 95 2P',
#  '1973 FIAT COUPE',
#  'Rally',
#  '850c coupe',
#  '128 A1 Coupe Moretti 1300',
#  'Abarth Rally Gruppe 4 Stradale',
#  'Fiat 124 BC1 , BJ. 1971',
#  '2300 S Coupe',
#  '1300 coupe Raritat',
#  '1800',
#  '2300 S COUPÈ',
#  'Fiat - 1500 cabriolet',
#  'Eveline',
#  'coupè',
#  'Sport 1800 "76.000 chilometri"',
#  '1.8-16V Kanarie Pininfarina !',
#  '1800 sport',
#  '"74 IN ECCELLENTI CONDIZIONI !',
#  'Other Coupè 2.0 i.e. turbo 16V Plus',
#  'Coupe 2.0 16v turbo Plus ASI permute storiche',
#  'Coupe 2.0 20v turbo iscritta ASI',
#  '1300 mirafiori cl 2 porte',
#  '2.0 Turbo 16v',
#  '2,0 20V Turbo Limited Edition',
#  '2400 coupe',
#  'Spider 124 Sport 1.6',
#  'Coupè',
#  'SPORT !!!! IN PERFETTE CONDIZIONI',
#  'Lightweight Hans Brösch',
#  '850 Coupè',
#  '2.0 Coupé ',
#  'Coupé 2.0 20S Tbo',
#  'Coupe ( SL )',
#  'S COUPE',
#  'Fiat 124 ac COUPE’ 124 sport',
#  'sport',
#  'Sport',
#  'Fiat Dino Coupe 2.0',
#  '2.0 20v turbo Limited Edition n.1540',
#  '2.0 16v turbo Plus',
#  '2.0 20v turbo',
#  '2300 Coupé Ghia',
#  'Icon 42kWh, Navi, Camera',
#  'Other Coupè 1.8 i.e. 16V',
#  '2.0 16v turbo Plus c/airbag/rate/permute/garanzia/',
#  '2.0 20v',
#  'ABARTH  1000 ot  valuto  permuta',
#  '850 Coupe 1.Serie ,TÜV+H-Zulassung neu',
#  'SISLEY 4X4',
#  '2.0 i.e. 16V Confort',
#  'Mirafiori s',
#  '*Fiat 850 Coupe´Serie 1*TÜV+H*',
#  'Coupe 2.0 16v turbo Plus',
#  '20 valvole plus',
#  '1.8-16V',
#  '2,0 16V',
#  "COUPE' 2000",
#  '1500 VIGNALE 1Â° SERIE',
#  'COUPE',
#  'Barchetta 1.8 16v',
#  'Special',
#  '2.0 i.e. 20V * 63.000KM * TAGLIANDATA FCA *',
#  "1100/103 TV COUPE' PININFARINA",
#  'Coupe 1.8 16v',
#  'Barchetta LIMITED EDITION',
#  '4x4 Sisley',
#  '130 TC ABARTH',
#  'Original Zustand',
#  'Lombardy my car sporting very rare',
#  '2000 Coupè Bellissimo',
#  'coupé condizioni uniche libretto tagliandi!',
#  'COUPE 1a SERIE',
#  'COUPE SL 1100 iscritta ALBO STORICO FIAT 2022',
#  '1000 OT  4 FARI',
#  '2400 Coupé Ferrari ASI',
#  'R',
#  'F',
#  'RIVIERA CLIMATIZZATA ORIGINALE ASI CRS',
#  'Vignale',
#  '2000 Motore Ferrari Prima Serie PERMUTE RATE',
#  'Coupe 2.0 20v',
#  'Five Speed In Versione America N. 192/300',
#  '900 DA COLLEZIONE',
#  'BEV La Prima **PROMPT LIEFERBAR**',
#  'ufficiale 1971',
#  '1.2 69cv 500s',
#  '2.0 i.e. 20V',
#  'Fiat 126P',
#  'Firefly 70 LOUNGE *AKTION*',
#  '1.8 i.e. 16V',
#  '1.3 MultiJet Lounge 95cv S&S EU6 5 PORTE BERLINA',
#  'Cross 1.6 MultiJet 88kW (120CV) 4x2',
#  'Sport 1.3 Firefly T4 110KW S&S DCT',
#  'Dolcevita Sport 1.5 Hyb. 97kW(130cv)DCT',
#  'City Cross 10GSE T3 88kW 120CV SS',
#  '1.3 MJet 70kW (95CV) 4x2 Pop Star',
#  '1.0 City Cross',
#  '1.6 Mjet 88KW (120hp) S&S Cross',
#  '1.MULTIJET URBAN FWD',
#  'Urban 1.3 MultiJet 70KW (95 CV) 4x2 S&S',
#  '1,0 Firefly T3 88KW (120 CV) S&S Connect',
#  'Cross My21 0.9 Twinair Turbo 85cv S&S 4x4 Cross',
#  '1.5 Hybrid Red DDCT',
#  'Urban AWD 2.0 16v 170cv Diésel auto.',
#  '1.0 FIREFLY T3 88KW SPORT 120 5P',
#  'Red 1.5 Hybrid 97kW (130cv) DCT',
#  'S5 SPORT 1.0 T3 120CV',
#  '1.6 E-Torq 110 CV City Cross',
#  'Pop Star 1.6 MultiJet 120cv 4x2',
#  'Cross 1.6 MultiJet 120cv 4x2',
#  '1.0 120CV 120 ANIVERSARIO',
#  'NUEV  URB 1.0 GSE 88KW 120',
#  'Dolcevita SS Edition 1.0 Firefly T3 88KW',
#  'HEY GOOGLE 1.0 88KW 120CV',
#  '1.0 Sport 120cv',
#  'City Cross 1.6 MJet 88kW (120CV) DCT 4x2',
#  '1.0 Firefly S&S Dolcevita Red',
#  'Lounge 1.4 MAir 103kW (140CV) 4x2',
#  '1.6 POPSTAR',
#  'S5 CROSS 1.0 T3 120 CV',
#  'Cross 1.6 Mjet 88KW (120hp) S&S',
#  'Sport 1,0 Firefly T3 88KW (120 CV) S&S',
#  '1.6 E-torQ Urban',
#  'Cross 1.6 Mjet 96KW (130 CV) S&S',
#  'Lounge 1.0 Firefly T3 88 kW (120CV) S&S',
#  '1.6 ETorq Mirror',
#  'Lounge 1,0 Firefly T3 88KW (120 CV) S&S',
#  'Cross Plus 1.6 MJet 88kW (120CV) DCT 4x2',
#  '1.0 Firefly SS 120th',
#  '1.0 Turbo Urban',
#  '1.6 MultiJet 88 kW (120 CV) Cross',
#  'SW STATIONWAGON E6D 1.3 MIRROR',
#  'SW 1.3 Multijet 70kW (95CV) Mirror',
#  'SW 1.3 MJT 95CV S/S LOUNGE',
#  '1.0 100 ch S/S sw cross Red MY22',
#  'Pop Star 1.4 16v 70kW (95CV)',
#  '1.1 Active',
#  '1.1 Active TÜV 07/2024 Zahnriemen/Service 07/22',
#  'STATION WAGON 1.0 100cv CityLife',
#  'Sedici 1.6 16v Dynamic 4x4 107cv',
#  'SW LIFE 1.0 73KW (100CV) BZ',
#  '1.4 120CV GLP',
#  'Urban 1.6 16v Multijet II 120CV S&S',
#  'Fiat 1500 Familiare OSI',
#  '3p 1.4 95cv Feel',
#  '1.6 Active 105 CV Multijet ECO',
#  '1.6 16v Multijet 88kW (120CV) S&S Lounge',
#  'Pop Star 1.3 16v Multijet II 95CV auto.',
#  'S1 SW 1.6 120 CV LOUNGE AT',
#  '1.6 16v Lounge 120 CV diesel Mjet II SW',
#  '1.6 16v MJet 88kw 120cv  SS Trekking',
#  '1.9 Multijet Dynamic',
#  '2 1.6 16v Pop 88kW (120CV) Mjet. Business',
#  'SW 1.6 Multijet 88kW (120CV) Mirror',
#  'Autobianchi Bianchina Panoramica 2. Hand',
#  'Cross 1.4 16v 70 kW (95 CV) S&S',
#  'RED 1.4 MPI 95HP',
#  '1.6 Lounge 88kW (120CV)diesel Mjet II SW',
#  'Easy 1.3 Mjet 59kW (80CV)',
#  '1.3 16v Multijet 70kW (95CV) S&S Lounge',
#  'Pop Star 1.6 16v Mjet 88kW (120CV) S&S',
#  '5P 1.3 Multijet 70kW (95CV) Mirror',
#  'Pop Star 1.3 16v Multijet II 85CV S&S',
#  '5p 1.4 16v 70 kW (95 CV) Lounge Plus',
#  '1.4 16v Lounge 70kW (95CV) gasolina SW',
#  '1.4 95cv Easy #LIBRO, BLUETOOTH',
#  'City Cross 1.6 E-Torq 81kW (110CV) 4x2',
#  'SW 1.4 Fire 70kW (95CV) Pop',
#  '1.3 16v Multijet II 85CV Start&Stop',
#  'Connect 1.4 16v 70 kW (95 CV) S&S',
#  '1.3 16v Mjet 70kW (95CV) S&S City Cross',
#  '1.4 16v 95CV',
#  '1.4 8v 57kW (77CV) Lounge',
#  'Pop Star 1.4 16v 95CV',
#  'My Life 1.6 Multijet 105 CV',
#  'Combi SX 1.3 Mjt 75cv 5plazas E5+',
#  '1.4 Lounge',
#  'Easy 1.4 Natural Power 52kW (70CV)',
#  '1.6 Multijet 105cv 5p S/S #LIBRO, BLUETOOTH',
#  'SW 1.6 Multijet Life 95KW',
#  'SW 1.0 Life',
#  '1.2 51 kW (69 CV) Lounge',
#  '1.4 16v 70kW (95CV) Cross',
#  '1.3  70kW (95CV) diesel Mjet. SW Easy',
#  '1.0 Hybrid 51 KW (70 CV) Lounge',
#  '1.2 51 kW (69 CV) Mirror',
#  'CROSS 1.5 HYBRID 130CV',
#  '1.2 69CV',
#  '1.2 Lounge 51kW 69CV',
#  '1.2 lounge',
#  'Lounge 1.0 6v GSE 52KW (70 CV)',
#  '1.0 hybrid',
#  'A',
#  'E E RED 118CV',
#  'Ritmo 130 TC 3 porte Abarth',
#  '13 sport 95 cv multijet e5 ss',
#  '1.3 MJT II S&S 95 CV Euro 6',
#  'BERLINA',
#  'HB City Life 1.6 96kW (130CV)',
#  '1100 i.e. cat 4x4 Country Club eccellenti condizio',
#  '1.4 95CV HB 5P LOUNGE',
#  'Icon 3+1 320km 85kW (118CV)',
#  '1.0 100CV  - PROMO WOW',
#  '3p 1.0 ie 45cv cat.',
#  '(2007-2016) 1.4 16V Lounge',
#  '650',
#  'Style',
#  '1.0 TSI S&S Xcellence 110',
#  '2.0TDI S&S Style 115',
#  '2.0TDI CR S&S FR DSG-7 150',
#  'Sport Limited',
#  '1.5 TGI S&S XcellenCe DSG-7 130',
#  '1.5 TSI S&S FR 150',
#  'Seat 600',
#  '1.5 TSI S&S Style 130',
#  '2.0TDI CR S&S Style DSG-7 150',
#  '2.0TDI S&S Xcellence 150',
#  '1.0i Select',
#  '1.5 TGI S&S Style DSG-7 130',
#  '2.0 TSI S&S Cupra Carbon DSG7 290',
#  '2.0 TSI S&S Cupra R DSG 300',
#  '1.5 TGI GNC S&S Style 130',
#  'ST Style Connect',
#  'Seat 600 D Cabriolet',
#  'Signo',
#  '850',
#  '1.6 TDI 105CV CR DPF 3p. Sport',
#  '128 sport',
#  'SportCoupé Cupra 1,8 TSI Start-Stopp',
#  '1.2 TDI',
#  'Ibiza SC 1.2 70 ch',
#  '1.2 tdi 75 ch',
#  'SportCoupé Reference 1,9 TDI',
#  'SC 1.2i 12V 70 Réference',
#  'SportCoupé Chili 1,2',
#  'SC 1.4i 16V 85 I Tech',
#  'ST 1.4 TSI ACT Start&Stop FR',
#  'SportCoupé 1,2',
#  '1.6 TDI ECOMOTIVE REFERENCE EDITION',
#  '1.6 TDI CR STYLE 115 CV',
#  '2.0 TDI SS Style',
#  '1.5 EcoTSI S&S Style Go DSG',
#  'Style Plus',
#  '1.0 95CV',
#  '1.0 TSI 70kW (95CV) Reference Plus Eco',
#  '1.0 TGI 66kW (90CV) FR',
#  '1.0 TSI 85kW (115CV) DSG FR Ecomotive',
#  '1.5 EcoTSI S&S Style DSG',
#  '1.5 TSI 110kW DSG S&S Style Go L',
#  '2.0 TDI 150cv StSp Xcellence',
#  '2.0TDI CR S&S Style 150',
#  '1.0 TSI 70kW (95CV)  Ecomotive Style',
#  '2.0TDI CR S&S X-Perience XM DSG 150',
#  '2.0TDI S&S FR DSG 4Drive 200',
#  '2.0 TDI DSG Style',
#  '2.0 TDI 150CV ST FR DSG',
#  'ST 1.5 eTSI S&S FR DSG-7 150',
#  'ST 1.6TDI 110CV XPERIENCE',
#  'ST 2.0 TSI 221kW 4Drive DSG S&S Cupra R',
#  '2.0 tdi 150 cv 4drive st x-perience',
#  '1.9 TDI 105cv DPF DSG Style',
#  'ST 2.0TDI CR S&S FR DSG-7 150',
#  'ST 1.5 TSI S&S FR 150',
#  'ST 2.0 TDI 184cv 4Drive DSG6 St&Sp X-per',
#  'ST 1.5 EcoTSI S&S FR Fast Edition 150',
#  '1.4 TSI 125cv  Style',
#  '4p 1.9 SDi Stella',
#  '2.0 TDI 140cv Style 5p',
#  '1.6 105 CV Sport',
#  '1.4 TDI 80 CV Reference',
#  '2.0 TDI 140 CV Stylance',
#  'ST 2.0 TSI 221kW (300CV) DSG-6 S&S CUPRA',
#  'ST 2.0 TSI 221kW (300CV) St&Sp CUPRA',
#  'ST 2.0 TSI 221kW 4Drive DSG S&S Cupra',
#  'ST 2.0 TDI 184cv DSG-6 St&Sp FR',
#  'ST 1.6 TDI 110cv St&Sp Style Ecomotive',
#  'ST 2.0 TSI 213kW (290CV) DSG-7 S&S Cupra',
#  'ST 2.0 TSi 290cv Cupra "Orange Edition"',
#  'ST 2.0 TDI 110kW (150CV) DSG-6 St&Sp FR',
#  '2.0 TDI 115 CV S&S Reference 4Kids',
#  '1.0 TSI XCellence',
#  '1.5 TGI 96kW DSG-7 S&S FR Fast Edition',
#  '1.2 12V 70 REFERENCE 70 5P',
#  '1.6 SIGNO 100CV',
#  '1.0 MPI 59kW S&amp,S Style PDC SHZ FullLink+',
#  '2.0 TSI Cupra 300',
#  '2.0 TSI 280cv StSp Cupra',
#  '2.0 tsi 290 dsg7 cupra',
#  '3ª serie 1.5 TGI DSG 5p. Black Edition',
#  '2.0 TDI 150 DSG fr go l',
#  '1.5 TGI 96kW DSG-7 S&S Xcellence',
#  'IV 2.0 TDI 150 FR DSG7',
#  '1.4 Benzina 5 Porte',
#  '1.2 benzina',
#  '1.6 TDI 70kW (95CV) Reference Plus',
#  '2.0 TSI RS DSG',
#  '1.0 TSI Ambition 81kW',
#  '1.6 TDI 85KW AMBITION DSG 5P',
#  '1.5 TSI STYLE 5P',
#  '2.0TDI Ambition 85kW',
#  'Style 1,0 TSI 81 kW 6-Gang mech.',
#  'GreenTec Cool-Edition DAB+ Klima ZV ...',
#  '1.0+MPI+AMBITION+KLIMA+PDC+SHZ+NSW+MAL+',
#  '1.9 TDI/110 CV Ambiente',
#  '2.0 TDI CR 110KW (150CV) Ambition',
#  '2.0TDI Sport DSG 110kW',
#  'SPACEBACK 1.2 TSI 105 TOUR DE FRANCE',
#  '1.5 TSI Ambition 4x2 110kW',
#  '1.0 TSI Sport 81kW',
#  '1.0 60 CV 3 porte Active',
#  '1.5 TSI Ambition DSG 110kW',
#  '1.5 TSI Style 110kW',
#  'Pequeño Manual de 2 Puertas',
#  '1.5 TSI Ambition',
#  'Felicia',
#  '1.2 HTP Ambiente',
#  '1.5 TSI Emotion',
#  '2.0 TSI RS 4x4 DSG 180kW',
#  '1.0 TSI Ambition 81kW DSG',
#  '1.5 TSI Emotion DSG',
#  '1.5 TSI 110kW 150CV ACT Ambition',
#  '2.0TDI AB tech Sportline 4x4 DSG 147kW',
#  '1.5 TSI DSG Tour',
#  'DIESEL',
#  '2.0 TDI 190 CV SCR DSG7 SPORTLINE 4X4',
#  '2.0 TDI 150 CV STYLE DSG COMBI',
#  'Combi 2.0 TDI 110KW (150cv) Ambition',
#  'Combi 2.0TDI AdBlue tech SportLine DSG 147kW',
#  'COMBI  STYLE 1.4TSI PHEV',
#  '1.5 TSI 110kW (150CV) DSG STYLE',
#  '2.0 TDI AdBlue tech Style DSG',
#  '1.4 TSI P-HEV Style DSG',
#  '1.9 TDI TREND',
#  '1.5 TSI 110KW (150CV) Like',
#  '1.6 TDI 85 KW (115 CV) DSG Ambitio',
#  '1.0 TSI 110cv DSG Ambition',
#  '1.0 TSI 81KW (110cv) DSG Monte Carlo',
#  'Stepway TCe Comfort 67kW',
#  'TCe Expresion 67kW',
#  '1.4 5-Deurs Goedkoop rijden',
#  'SCe Essential 49kW',
#  '1.2 Base 75',
#  '1.5 Blue dCi 115cv 7Pl - 18 Comfort',
#  '1.0 TCE Comfort 74kW',
#  'ECO-G Comfort 74kW',
#  'Stepway ECO-G Comfort 74kW',
#  ...]

# %%
# Let's retrieve the entries that contain "Start Stop System" and assign them the label "functional&mechanical".

# The expression "(?i)" in the code disables case sensitivity.

start_stop  = df.loc[df[df["comfort_&_convenience"].isnull()].index, "short_description"].str.contains("(?i)S&S|(?i)Start&Stop|(?i)SS|(?i)S/S|(?i)Start/Stop|(?i)Start-Stopp|(?i)Stop & Start")
start_stop
# Out:
# 0        False
# 1        False
# 2        False
# 24       False
# 26       False
#          ...
# 29369     True
# 29384     True
# 29395     True
# 29401    False
# 29426    False
# Name: short_description, Length: 3185, dtype: object

# %%
# Let's retrieve the indices of the ones that return True.
start_stop_index = start_stop[start_stop == True].index

# %%
# After the this operation, how many NaN values do I have filling?
start_stop[start_stop == True].count()
# Out:
# 477

# %%
# Now let's assign "functional&mechanical" to the indices we obtained.
df.loc[start_stop_index, "comfort_&_convenience"] = "functional&mechanical"

# %%
handle_missing_values(df , "comfort_&_convenience")
# Out:
# Missing Values in 'comfort_&_convenience':
# Count: 2708
# Percentage: 9.47%

# %%
# After the groupby operation, how many NaN values do I have remaining?
df['comfort_&_convenience'].fillna(df.groupby(["seats"])['comfort_&_convenience'].transform(lambda x: x.mode()[0])).isnull().sum()
# Out:
# 1419

# %%
df['comfort_&_convenience'].fillna(df.groupby(["seats"])['comfort_&_convenience'].transform(lambda x: x.mode()[0]), inplace = True)

# %%
handle_missing_values(df , "comfort_&_convenience")
# Out:
# Missing Values in 'comfort_&_convenience':
# Count: 1419
# Percentage: 4.96%

# %%
# After the groupby operation, how many NaN values do I have remaining?
df['comfort_&_convenience'].fillna(df.groupby(['make', 'type'])['comfort_&_convenience'].transform(lambda x: x.mode()[0])).isnull().sum()
# Out:
# 0

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
df['comfort_&_convenience'].fillna(df.groupby(['make', 'type'])['comfort_&_convenience'].transform(lambda x: x.mode()[0]), inplace = True)

# %%
handle_missing_values(df , "comfort_&_convenience")
# Out:
# Missing Values in 'comfort_&_convenience':
# Count: 0
# Percentage: 0.00%

# %% [markdown]
# <a id="8"></a>
# <div class="alert alert-info" role="alert">
# <h1>Column name :<span style="color:red"> entertainment_&_media </span></h1>
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Operation : </b> First, let's leverage <span style="color:red"><b>the dictionary we created in Part 1  </b></span>to examine the short_description. If we find any matching values, let's <span style="color:red"><b>replace </b></span> them with their corresponding keys. Then, <span style="color:red"><b>to prevent duplicates </b></span>, let's convert the expressions within each row into sets and then retrieve them back. Also since the "comfort_&_convenience" column is associated with <span style="color:red"><b> " make ", " type "</b></span> . let's fill in the <span style="color:red"><b> NaN values</b></span> in this column by grouping the data based on these columns and performing the necessary operations.
# </div>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
first_looking("entertainment_&_media")
# Out:
# column name    :  entertainment_&_media
# --------------------------------
# per_of_nulls   :  % 17.39
# num_of_nulls   :  4973
# num_of_uniques :  12
# con_nect                                            12588
# NaN                                                  4973
# con_nect,sphone_integ                                4265
# con_nect,sound_system                                3381
# con_nect,sound_system,sphone_integ                   3188
# sound_system                                           60
# con_nect,sound_system,entertainment,sphone_integ       56
# con_nect,sound_system,entertainment                    53
# con_nect,entertainment                                 17
# sphone_integ                                           13
# con_nect,entertainment,sphone_integ                     7
# entertainment,sphone_integ                              1
# sound_system,sphone_integ                               1
# Name: entertainment_&_media, dtype: int64

# %%
# To be more thorough, let's check if there are any words in the short description 
# that match the key-value pairs of the dictionary, as a precautionary measure.
list(df.loc[df[df["entertainment_&_media"].isnull()].index, "short_description"].unique())
# Out:
# ['CDi',
#  '350+',
#  'S 4Matic+ 8G-DCT',
#  '4MATIC',
#  '200CDI Autotronic',
#  '4Matic 7G-DCT',
#  'e Limousine',
#  '180d 7G-DCT',
#  nan,
#  'd 4Matic (EURO 6d)',
#  'Limousine',
#  '250e 8G-DCT',
#  'CDI Elegance',
#  '7G-DCT (4.75)',
#  'd AMG Line (EURO 6d)',
#  'd (177.003)',
#  '200d 7G-DCT',
#  'A-CLASS A180 1.3 136 CV 7G-DCT 5P',
#  'S 4MATIC+',
#  'Sport 4Matic 7G-DCT',
#  'C Coupe (BM 190)',
#  'S AMG 4MATIC+',
#  'AMG A 35 4MATIC',
#  '4-Door 63 S 4MATIC+',
#  '180CDI',
#  '250e Sedán 8G-DCT',
#  '220d 7G-DCT',
#  '35 AMG 306ch 4Matic 7G-DCT Speedshift AMG',
#  'd Business Solution, Automaat, Navigatie',
#  '220 d Fascination 7G-DCT',
#  'Classe  d (cdi) Premium auto FL E6',
#  '220 190ch Progressive Line 7G-DCT Siege chauf gran',
#  'd 4Matic AMG Line (EURO 6d)',
#  '220 d 190ch AMG Line 8G-DCT 10cv GPS Camera Radar ',
#  '200 d 150ch Business Line 8G-DCT GPS Camera',
#  '200 163ch Style Line 7G-DCT',
#  '35 AMG 306ch 4Matic 7G-DCT Speedshift AMG TOuvrant',
#  '200 d Fascination Tpano GPS Camera',
#  'CDI 100kW ( 136CV ) Urban',
#  '180 d 116ch AMG Line LED GPS Camera Radar AV/AR',
#  'd',
#  '180 d Sensation 7G-DCT',
#  'e A 250e Progressive Sfeerverlichting / NIEUW GERE',
#  '200 d 150ch AMG Line 8G-DCT',
#  '220 190ch Progressive Line 7G-DCT',
#  'd Premium',
#  'MERCEDES-BENZ Clase GLK Pequeño  Automático de 5',
#  '180d',
#  '180CDI Polar Star',
#  'Pequeño Automático de 5 Puertas',
#  '4Matic Coupe 4Matic+ (EURO 6d-TEMP)',
#  'S 4Matic+ 4Matic (EURO 6d)',
#  '200d',
#  '180CDI Autotronic',
#  '180d 8G-DCT',
#  'de 4Matic AMG Line (EURO 6d)',
#  'CDI Premium',
#  'CDI Style',
#  'C Roadster',
#  'Biturbo V-Max',
#  'abrio Mercedes-AMG 4MATIC',
#  'MERCEDES-BENZ Clase SL Descapotable  Automático d',
#  'SL *Pagode*3.Besitz/Dt.Fahrzeug/H-Zul.',
#  'MercedesAMG',
#  'd Cabriolet',
#  'Cabriolet AMG Line',
#  'r107 original belgian delivery! first owner car.',
#  'R107 Cabrio Hardtop + Softtop H-Kennzeichen',
#  '200K',
#  'R107 Cabrio Hardtop + Softtop US Modell H-Kennzeic',
#  'Cabrio d',
#  'SL Vollrestauration',
#  'Roadster Kompressor SCHWARZ AUTOMATIK KLIMA LEDER',
#  'Autom. Top-Zustand aus 2. Hd. Deutsches M.',
#  'Cabrio 9G-Tronic',
#  '-CLASS 6.2 COUPE SPORT AUTO 457 2P',
#  'V12 - Origineel Nederlands -',
#  '200 K.',
#  'GE',
#  '(R129)',
#  '(R129) 2nd Owner/Collectable',
#  'Extrem gepflegtes Ex-Pressefahrzeug W 231',
#  'Cabrio',
#  'SL',
#  'cabrio d  Premium Plus 4matic auto',
#  '220 d executive a',
#  '| 48.000KM | Orig. NL | BOSE',
#  'Cabrio 9G-Tronic (9.75)',
#  '220 A Cabriolet',
#  'ROADSTER',
#  '190SL',
#  'S Cabriolet Ponton Typ A (W 180)',
#  'CDI BlueEfficiency E -Klasse Cabrio (BM 207)',
#  'E Cabrio 220 d Premium auto',
#  'D',
#  'Coupé R',
#  'AMG GLC 43 4MATIC Coupé',
#  'Aut.',
#  '-CLASS 4MATIC',
#  'Coupé 462',
#  '4MATIC+ Coupé',
#  'oupé Mercedes-AMG 4MATIC',
#  'SEb (111)*DEUTSCHES-FAHRZEUG*H-KENNZEICHEN*TOP-ZUS',
#  'd 4MATIC',
#  'd 4MATIC Coupé AMG Line',
#  'CLK Coupe 320/Automatik/Leder/Navi/Alus',
#  '220CE',
#  'S Coupe',
#  'Mercedes-AMG S 4MATIC+',
#  '4Matic (EURO 6d-TEMP)',
#  '-CLASS 3.0 4MATIC AUTO 333 2P',
#  'Coupé 4M Aut.',
#  'C Coupe*DEUTSCHES-FAHRZEUG*AUTOMATIK*H-KENNZEICHEN',
#  'Coupé S 4Matic Aut.',
#  'Coupé',
#  'Coupe AMG + NIGHTPACK - LEDER - PANO DAK - 360° -',
#  'AMG Line',
#  'SEC',
#  'Compressor',
#  '220d Aut.',
#  'Coupé d (238.314)',
#  'Matte wrapping',
#  '270CDI',
#  'd 4MATIC -',
#  'coupé 4.0 4MATIC 469 2P',
#  'Coupé 7G-DCT AMG LINE - BURMESTER - SFEERVERLICHTI',
#  'd 4MATIC Coupé',
#  '350d 4Matic Aut.',
#  'Coupé 400d 4Matic Aut.',
#  'CDI Chrome',
#  'e Coupé',
#  'Coupé d AMG LINE',
#  'd (205.314)',
#  'EQ Boost Aut. (9.75)',
#  'Coupé 350d 4Matic Aut.',
#  'CDI (LA) Sport Edition (203.708)',
#  'Coupé 220d',
#  'COUPE AMG -Line',
#  'CDI Inspiration 7G-DCT',
#  '320CDI Aut.',
#  '4Matic 9G-Tronic',
#  '4M Aut.',
#  '300d 4Matic Aut.',
#  '220d 4Matic 9G-Tronic',
#  '220d 4Matic 8G-DCT',
#  '300e 4Matic 9G-Tronic',
#  'e 4Matic',
#  '320CDI 4M Aut.',
#  'd 4Matic All-Terrain Estate Avantdarde',
#  'G Klasse 350d Mercedes-Benz G Klasse 350d - Direct',
#  'd 4Matic 9G-Tronic',
#  '4M AMG Line',
#  "7G-DCT AMG + NIGHTPACK - ALU 19' - SFEERVERLICHTIN",
#  'd 4 MATIC 245cv 9 vel. *IVA deducible* *2020* *Nac',
#  'CDI',
#  '4Matic 8G-DCT',
#  'd 4Matic (253.915)',
#  'Puch  JAGD-FZG./WINDE/KOFFER/BRAUSE/AHK',
#  '300 4MATIC',
#  'GE lang Cabrio Steyr-D-Puch AHK Automatik Rücksitz',
#  '250d 4Matic Aut.',
#  'Coupé 350D 258 CV',
#  'Puch PLANE/AHK/ALLRAD/SCHLIEßANLAGE NEU',
#  '320CDI Edition 10 Aut.',
#  'Mercedes-AMG 4MATIC',
#  'Mercedes-AMG 4MATIC+',
#  '280CDI Aut.',
#  'D 2.2 170CV AUT 5P',
#  'Urban',
#  'd 4Matic',
#  'AMG CLA 35 4MATIC Shooting Brake',
#  'Estate S 4Matic+ 9G-Tronic',
#  'Estate 4Matic 7G Plus',
#  'Estate 200d 9G-Tronic',
#  '(+)2.0 AVANTGARDE AUTO 211 5P STATE',
#  'd Estate Avantgarde',
#  'd Estate',
#  'de Estate AMG LINE',
#  'CDI Blue Efficiency Estate',
#  'AMG E 53 4MATIC+ Estate',
#  'Mercedes-AMG 4MATIC Estate',
#  'Estate 220d',
#  'd Estate Business Line',
#  'Estate 220d 9G-Tronic',
#  'Estate Business Line',
#  'd AMG/rijassist',
#  'Estate Estate',
#  'CDI Urban Style Edition',
#  'de Estate',
#  'd 4M All-Terrain',
#  '(+)2.1 D AMG LINE 5P',
#  'CLA-CLASS 2.1 D DCT SHOOTING BRAKE 136 5P',
#  'B200 CDI AMG AUT 136CV',
#  '9G-Tronic',
#  '580 4Matic',
#  'S 4Matic+ 9G-Tronic',
#  'PLUG-IN HYBRID Lang',
#  'CDI BlueEfficiency (204.001)',
#  '1.6',
#  '4Matic 7G Plus',
#  '7G Plus',
#  '220d 4Matic 9G-Tronic 194',
#  'S 7G Plus',
#  '-CLASS 4.7 455 4P',
#  '-CLASS 2.1 D 4MATIC AUTO 170CV 4P',
#  '220d 9G-Tronic 194',
#  'CDI Business',
#  '-CLASS D G TRONIC PLUS AVANTGARDE',
#  '220BlueTec 7G Plus (4.75)',
#  '350d 4Matic 9G-Tronic',
#  'e Largo',
#  'de',
#  'CLA-CLASS 2.1 CDI DCT 170CV 4P',
#  'd AMG',
#  'Sedan 9G-Tronic AMG LINE - FULL LED - ALU - BLIS -',
#  'BlueTEC Sport',
#  '220d 9G-Tronic (4.75)',
#  'CLS-CLASS 272 4P',
#  'CDI Avantgarde',
#  'BT Edition 1 Aut.',
#  '350d 4M Largo 9G-Tronic (9.75)',
#  'BlueTEC 4Matic (212.011)',
#  'Business-Solution',
#  'd AMG Line (EURO 6d-TEMP)',
#  '*1.HAND*ORIGINAL ZUSTAND*KEIN ROST',
#  '400d 4Matic Largo 9G-Tronic',
#  '1.6T PHEV S/S GS-Line Aut. 180',
#  '1.4 66KW (90 CV) EXPRESSION PRO',
#  '1.5D DT S/S GS-Line + 100',
#  '1.2T S/S Design & Tech 130',
#  '2.0DTi 16v Sport',
#  'Corsa-e Elegance-e',
#  '1.5D DTH S/S Elegance 130',
#  '2.5 V6 Pearl',
#  '2,2 Excellence 4x4 2011',
#  '1.2-16V Njoy 3DRS MOOI NAP',
#  '1.2-16V RHYTHM',
#  '1.4 Twinport 87ch Start/Stop',
#  '1.4 Selection Airco',
#  'TwinTop 1.4 16V Sport',
#  "TwinTop 1.4 16V First Edition 'CABRIO'",
#  '2.0 CDTi S/S 165 CV Excellence',
#  '1.4 Turbo Excellence',
#  '1.4 T S/S Excellence',
#  '1.4T 140cv Excellence S/S #NAVY, BLUETOOTH',
#  'Descapotable Manual de 3 Puertas',
#  '1.3CDTi Enjoy',
#  'Twin Top Edition',
#  'Rocks Open Air',
#  '2.0 264 turbo cab / suivi complet opel / 1e main',
#  'Roadster',
#  '2.0 Turbo ECOTEC',
#  '2.0 T',
#  '2.0 Turbo',
#  '2.0 Turbo Pack',
#  '2.0 16v Turbo VX 220 VX220',
#  '1.8-16V Enjoy',
#  '225 PS , original LHD, 2 owner car, hardtop',
#  '2.2 16v VX 220 VX220',
#  'SE 16v Limited Edition',
#  'opel astra h cabrio opc',
#  'Twin Top 1.8 (Enjoy)',
#  '1.4-16V cabrio',
#  'E Cabrio GSi 2,0 i',
#  '2.2 16v VX 220',
#  'Deportivo Manual de 3 Puertas',
#  'B 2.0 GSI 1985 ATS RECARO APK 2023',
#  'C 2.2 de Luxe',
#  '3 Puertas 1.4T GSI',
#  'GTC 2.0 CDTi 195cv Biturbo 3p S/S #NAVY, BLUETOOTH',
#  'Coupé 1.8 16v Bertone Edition',
#  'H GTC Sport',
#  'Coupe GS',
#  '2.5i V6',
#  'olimpia record coupe',
#  '19 SR',
#  'Commodore 2.5 GS Coupe Automat',
#  '2.0i 16v',
#  '2.0S',
#  'Olimpia 1.5 Coupe  //Top Zustand//',
#  '*H-Kennzeichen*Oldtimer*TÜV Neu*',
#  '3.0 E',
#  '2.0i-16V DTM',
#  '1.4',
#  'A Berlinetta 1,9 S',
#  'GT/E gruppo 2',
#  '1900 S Berlina',
#  'V6 190ps',
#  'opel Astra g coupe project',
#  'Olympia',
#  'J GTC Basis, MOTOR STARTET NICHT',
#  '1900',
#  '2.0i cat',
#  'GSE (état concours)',
#  'Rallye 16S',
#  '1200 S',
#  'GTC 1.6 t ecotec Cosmo S s&s 180cv',
#  'GT-A-L',
#  'B Coupe aus 1969',
#  '2.0i',
#  '1.7 CDTi Enjoy',
#  '1.9 N',
#  'B Coupe',
#  'GTE - CONRERO',
#  'Irmscher GSE Oltimer FIA Liebhaber ',
#  '2.0i 16V cat',
#  '2.2 16V Coupe',
#  'Manta-B',
#  'Twip top 140 ,18',
#  'C1 Coupe 1200H',
#  'B LS Fastback',
#  'coupé',
#  '2.0 GSi / Look Manta 400 /  Rally / Oldtimer /',
#  'oldtimer 3.0 6cil GSE 180pk manual gears box',
#  '1200 S  Allestimento Irmscher',
#  'AT',
#  'Coupe 2.0 turbo 16v 200cv',
#  'B 2.0 GT/E,IRMSCHER,SERVO,H-ZULASSUNG,SPANIEN',
#  '1.8 16V Coupe Edition 90 Jahre Bertone',
#  '1.6i 16V Sports',
#  'G Coupé Bertone !',
#  'A 1,6S Original 28300 KM Neuwertig',
#  '5p 1.6i twinport 16v',
#  'Astra G OPC 1, 2.0 16V',
#  '1.8 16V Coupe',
#  'A GTE Gelb Leder',
#  '200',
#  'B 1,9 S 1 Hand',
#  '1.4i-16V',
#  '(AUS ERSTER HAND,SEHR GUTER ZUSTAND)',
#  'Color Selection VI',
#  'GTC 1.8',
#  'ASTRA GTC 1.4',
#  'Astra Coupe 1.8 16v',
#  '3p 1.4i 16v Club',
#  'E Gsi',
#  '2.0i H-ZULASSUNG',
#  'GTC Edition Navi Tempo Park Pilot Klimaaut',
#  '1.3 CDTI Advance 95cv S/S 5 PORTE',
#  '1.6i 16V',
#  '1.3 CDTI b-Color 75cv 5 PORTE',
#  '1,4i-16V',
#  'PHEV 1.6 Turbo GS Line Aut. 4x2 225',
#  '3.0TD LS',
#  '1.5CDTi S&S GS Line Aut. 130',
#  '1.6 Turbo  Auto 4x4 Ultimate',
#  '1.2T S&S GS Line 130',
#  '1.2 96kW (130CV)  S/S Innovation',
#  '2.2DTI Sport RS',
#  '2.2DTI Sport',
#  'Mokka-e GS Line-e',
#  'X 1.6 CDTI 110 CV ECOFLEX BUSINESS EDITION',
#  '1.5D S&S Business Elegance',
#  '1.2 Turbo Selective',
#  'X 1.6 CDTI Excellence',
#  'X EXCELLENCE',
#  'TODOTERRENO 1.6 CDTI EXCELLENCE 120 5P',
#  '1.6 CDTI EXCELLENCE AUTO 2WD 136 5P',
#  '1.2T S&S Ultimate 130',
#  'INS-ST INNOV. 1.6D 136CV MT6',
#  '1.6 CDTI TURBO D INNOVATION ST 136CV 5P',
#  'SPORT TOURER 1.2 TURBO 145 CV ELEGANCE',
#  'Life 1.2 T S/S   XL Selective',
#  'Life 1.5 CDTI INNOVATION',
#  'Life 1.5 TD 75kW (100CV) S/S   L Selective',
#  'ST 1.5D DVH S&S Business Edition 122',
#  '1.6 CDTI 100KW EXCELLENCE S',
#  '1.4 Turbo S/S 110kW Innovation Auto ST',
#  'Life 1.5 TD 96kW 130cv SS Edition L',
#  'ST  2.0D DVH 130kW AT8 Business Elegance',
#  'Berlina Manual de 5 Puertas',
#  '1.2T SHR 107kW (145CV) Business Elegance',
#  'GS  1.5D DVH 90kW MT6 Business Edition',
#  'GS  2.0T SHT 169kW AT9 4x4 GSi',
#  '2.0 T SHT S&S Business Elegance AT9 170',
#  '1.4T Elegance AUT 5p',
#  '1.5D DVH S&S GS-Line AT8 122',
#  'SEDAN 1.6 CDTI 110 HP EXCELLENCE S',
#  '1.6 CDTI 81KW SELECTIVE 110 5P',
#  '1.2T XHL 74kW (100CV) GS-Line',
#  '1.6T Hybrid 132kW (180CV)  Auto GS-Line',
#  '1.6 16v Comfort',
#  '1.5D DVC 77KW 105 5P',
#  '1.2T XHL 74kW (100CV)  Auto Elegance',
#  '1.5dCi Energy Zen EDC 66kW',
#  '1.5dCi eco2 Energy Business 75',
#  '1.8 TCe GPF RS Trophy EDC 221kW',
#  '1.5 dCi 110CV Nav',
#  '1.5dCi Energy Business 66kW',
#  '1.5 ENERGY dCI 110 CV AUT',
#  '1.5dCi SS Energy Business 55kW',
#  'TCe GPF Energy Zen 66kW',
#  'TCe Energy Limited 66kW',
#  '1.2 TCe Energy Zen EDC 87kW',
#  'Color/Miet Batterie/Türen mit Scheiben',
#  '1.5dCi Blue Business 85kW',
#  'E-TECH RS Line 117kW',
#  'TCe Zen 67kW',
#  '1.5dCi Blue Business 70kW',
#  '1.3 TCe 140cv Zen Energy',
#  '1.2 16v Dynamique eco2',
#  'TCe Energy GLP Limited 66kW',
#  'TCe GPF Energy Limited 66kW',
#  'Life 80',
#  '1.2 16v Authentique',
#  'SCe Energy S&S Intens 52kW',
#  '1.2 Authentique',
#  'SCe Energy S&S Limited 52kW',
#  'Electric Zen R80 60kW Batería 20kW/h',
#  '1.9D RN',
#  'V6 3.0i 24v PHASE I UNIQUE Condition',
#  '1.8-16V Coupé | Black | 1993 | 56.000 KM',
#  '1.8 16v',
#  '80 INTENS WHITE',
#  '1.5dCi Energy Business 81kW',
#  '1.5dCi Energy Business 55kW',
#  '1.6 TCe 205ch energy GT EDC',
#  '1.5 dCi 110ch energy Business eco² GPS Radar Av/Ar',
#  '1.5dCi Blue R.S. Line EDC 85kW',
#  'E-TECH Híbrido Intens 103kW',
#  'E-TECH Híbrido Zen 103kW',
#  'TCe Energy GLP Business 66kW',
#  '1.6 Emotion 110',
#  '1.6 dCi 130ch energy Intens',
#  '1.5 Blue dCi 115ch Intens GPS Camera Radar AV/AR',
#  'tce 120 intens pack trophy + equipe pmr handicap',
#  '0.9 Dynamique Navi*MMI*Clima*Parksensor*Keyless*Ca',
#  '1.3 TCe GPF Intens 103kW',
#  '1.3 TCe 140ch FAP Business EDC -21B GPS Radar AV/A',
#  '1.3 TCe 160ch FAP GT-Line EDC GPS Camera Park Assi',
#  'LIMITED LIFE 41KW/H',
#  '1.3 TCe 140ch energy Limited EDC GPS Radar AR',
#  '1.2 Emotion',
#  '1.5 Blue dCi 95ch Business GPS Radar Av/Ar',
#  '1.6 E-Tech Plug-in 160ch RS Line -21N',
#  '1.2 Expression - NAP KM STAND - ELEKTR RAMEN / SPI',
#  '1.5 Blue dCi 115ch Business -21B',
#  '1.0 SCe Expression 70PK | JU84387 | 5-Deurs | Airc',
#  '1.4 RN Orig.NL 54dkm+nap Topstaat!',
#  '1.5 Blue dCi 115ch Intens EDC',
#  '1.2 Expression AIRCO. Stuurbekr. 113.000 km',
#  '1.2 16v Expression 75',
#  'Twizy 45 Intens Black Flex',
#  'Sport 1. Vorbes. Scheckheft gepflegt',
#  '1.5 DCI 110CH FAP DYNAMIQUE ECO²',
#  'Coupé Cabriolet 2.0 Dynamique Aut. Navi|Pano|Xenon',
#  '1.5 DCI LMV NAVIGATIE CRUISE CD CV+AB',
#  'life 80 kw r110 batería 40kwh',
#  'Plein Air*Komplettneuaufbau*H-Kennz.',
#  'R4 Cabriolet / Sammlerfahrzeug / 1. Hand',
#  'CC 1.5 dCi Dynamique 110 CV',
#  'CC TCe 130 Dynamique 130 CV',
#  '1.8-16V Fairway',
#  'Sporter Blue dCi 160 CV EDC Exe',
#  '1.8-16V | Cabrio | 69.000 KM | 1994 | 1 Swiss Owne',
#  '1.8 Fairway',
#  '1.6-16V Priv.Luxe',
#  'coupé cabriolet 2.0 Dynamique / LEER / AUTOMAAT /',
#  'renault megane 5 porte dci  110cv',
#  '2.0 Coupe-Cabriolet Aut. Avantage',
#  'Megane CC 1.9 dci Luxe 130cv',
#  'Cabriolet 1.6',
#  'coupé cabriolet 2.0 TCE 180 PK GT | NAVI | LEDER |',
#  '4cv * DECOUVRABLE',
#  'Spider Sport',
#  'Mégane',
#  '5p 1.5 dci Dynamique 105cv',
#  '2.0 Coupe-Cabriolet Confort Dynamique',
#  'Cabriolet 16V',
#  'Coupe 2.0 16v T RS 250cv LEGGERE BENE !!!',
#  'AMC Alliance DL Convertible',
#  'Cabriolet 1.4 TCE Dynamique',
#  'mit Frontscheibe 1-Hand',
#  '2.0 16V Sport (147cv)',
#  'Sport Spider 2.0 Windschutz-Scheibe 1. Hand',
#  '3 coupe cabriolet III COUPE CABRIOLET 1.9 DCI 130',
#  'Renault Megane II Cabriolet 1,6 16V 112 PS',
#  'CC 1.5 dCi 110 FAP GT Line EDC 2015',
#  'Mégane C.C. 1.5dCi Dynamique',
#  'SporTour 1.9 dci Dynamique 130cv fap',
#  '1.6-16V Privilège',
#  '1.6 Dynamique',
#  'II CC 1.9 dCi 130 FAP Privilège',
#  'Cabrio 1.4-16V Sport Stuurbekrachtiging',
#  '2.0 Coupe-Cabriolet Privilege',
#  '8.5',
#  '1.5 dCi 110CV S-S 4p. Express Ice',
#  'ACL  Cabrio   Rodeo',
#  'Pare-Brise 2.0 150 ch Avec Hard Top',
#  '1.9 dCi FAP Coupe-Cabriolet Dynamique',
#  'Sport 2.0 16V mit Frontscheibe | 2.Hand',
#  'R19 Cabriolet 1.8',
#  'coupé cabriolet 1.4 TCE Dynamique Half leder, 18"',
#  'coupé cabriolet 1.4 TCE Dynamique org. NL-auto h.l',
#  '1.6-16V Tech Line',
#  '1.2 75CV GPL 5 porte Wave 201407',
#  'FLORIDE ( con hard top)',
#  '1.6-16V Aria',
#  'coupé cabriolet 1.4 TCE Privilège / LEER / NAVI /',
#  'Cabriolet 2.0',
#  'coupé cabriolet 1.4 131PK TCE Privilège / Panorama',
#  'Megane SporTour 1.5 dci Gt Line 110cv',
#  'coupé cabriolet 1.4 TCE Dynamique',
#  'GTA V 2.5 V6 Turbo consignatie verkoop/Valckenier',
#  'Coupé RS 2.0 16v 265 S&S',
#  'Tbo GT  S',
#  'Societé Diesel 4 Societé 1.5dCi Energy',
#  'Williams Phase 2',
#  'tce 140 edc fap',
#  'COUPE EXPRESSION 1.9DCI',
#  'Mégane Coupé 1.6ie',
#  'tce 140 edc fap - 21b',
#  'A PREPARER',
#  'II 1.5 dCi 80',
#  'Deportivo Automático de 3 Puertas',
#  'Turbo 1.Hand Scheckheft Sammlerzustand',
#  '1.5dCi eco2 Energy Limited 75',
#  'CoupÃ© 2.0 dCi 150cv 2p #LIBRO, NAVY, BLUETOOTH',
#  'anterior 1.5dCi Energy Zen 66kW',
#  'anterior TCe Energy Limited 66kW',
#  'anterior TCe GPF Energy Limited 66kW',
#  'Zen',
#  'TCe 115 Expression Energy SANDS 85 kW (115 CV)',
#  'anterior TCe Limited 55kW',
#  'Expression dCi 110',
#  '1600 S',
#  'Europa Cup',
#  'tce 140 edc fap r.s. line',
#  'Renault Megane 1,5 dCI Energy Limited S&S 95',
#  'Group 4 * Roadlegal *',
#  'GTS',
#  'RENAULT ALPINE GTA 19900 EURO PRIVE',
#  '3 coupe III COUPE 2.0 DCI 160 FAP GT EURO5',
#  'A 310',
#  'TURBO 1',
#  'Megane coupe manual 2.0 dCi',
#  'SporTour 2.0 dci 4Control esm 150cv',
#  '3 coupe III COUPE 2.0 DCI 180 FAP GT',
#  '45 ELECTRIQUE',
#  'Coupe Energy dCi 110 FAP Start & Stop GT Line',
#  'TR',
#  'Mégane Sport R.S. 265 Stop&Start Start&Stop',
#  'Tbo',
#  '2.0 T RS',
#  'tce 160 edc fap - 21b r.s. line',
#  'GT 18Fuchs/Ablage-/Sichtpaket',
#  'Rs',
#  'Turbo Maxi 2 Gruppo B Omologata Stradale',
#  'Coupe 2.0 16V Turbo GT',
#  'II 3.0 V6 Sport',
#  'Coupe Energy dCi 130 FAP Start & Stop GT Line',
#  '3 COUPE RENAULT SPORT 265 S&S',
#  'ARKANA E-Tech 145 - 21B R.S. Line',
#  '1.8 16 V',
#  'V6 TURBO',
#  'tce 160 edc fap - 21b',
#  '1.9 dCi Expression',
#  'Coupe dCi 175 FAP',
#  'ARKANA TCe 140 EDC FAP R.S. Line',
#  'RENAULT CLIO V6 SPORT "PHASE 2"',
#  '1.0 TCE 74KW BUSINESS 5 PORTE',
#  'DCI 180 4 CONTROL',
#  'Coupe 2.0 dCi 150ch Monaco GP',
#  'Technik 80 Z.E14.04.2014',
#  'III (3) COUPE 1.6 DCI 130 ENERGY',
#  'V6',
#  'TCe 160 EDC GPF BOSE EDITION',
#  'Coupe 2.0 dci Wave Edition 150cv',
#  'COUPE 1.6 dCi 130 FAP Energy Bose eco²',
#  'Fleischmann',
#  'tce 140 edc fap - 21b r.s. line',
#  'dCi 110 FAP Coupe Dynamique',
#  '1.6 E-Tech R.S.Line 105kW',
#  '1.5 Blue dCi 115cv EDC Zen',
#  'Limited',
#  '1.3 TCe R.S. Line EDC 103kW',
#  'ZEN TCe 140 EDC',
#  '1.3 TCE 103KW ZEN EDC 140 5P',
#  '2.0 Blue dCi 184cv X-Tronic Initiale Paris',
#  'INTENS TCe 90',
#  'ZEN TCe 90',
#  '1.7dCi Blue Zen 4x2 110kW',
#  '1.6 E-Tech 145cv RS Line',
#  'dci 90',
#  'e-tech 145 - 21',
#  '1.5 dCi 110ch energy Intens EDC eco²',
#  '1.5 dCi 110ch energy Business EDC eco²',
#  '2.0 dCi 175 FAP Energy Intens',
#  '1.3 TCe 140ch FAP Intens EDC -21 LED GPS Radar Ar',
#  'dCi 110 EDC Intens Energy',
#  'GPS/Camera/Alu!!slechts 8000km',
#  '1.3 TCe 140 EDC Business Edition',
#  '1.3 TCe 160ch FAP Black Edition SL EDC',
#  'Bose Edition 2.0 dCi 150cv 4x4',
#  '1.3 TCe 155ch FAP Intens EDC - 20 GPS Radar Ar',
#  '1.5 Blue dCi 115ch Business 131g',
#  '2.0 dci Initiale Paris 175cv 4x4 x-tronic',
#  '1.5 dCi Dynamique Automaat Navi|Clima|Cruise|LMV 1',
#  'blue dci 115',
#  '2.0 dCi 175ch energy Initiale Paris X-Tronic Cuir',
#  'tce 160 edc',
#  'TCe 140 - 21 Intens',
#  'TCe 130 FAP Intens',
#  '1.2 TCe Dynamique Aut',
#  '1.5 BLUE DCI 115CV BUSINESS',
#  '2.0 dCi 175 EDC 4x4 Initiale',
#  '1.2 VOOR EXPORT',
#  'V INITIALE PARIS 1.6 DCI 160CV AT6',
#  'S.T E-TECH Intens 117kW',
#  '1.8 TCe SL Icon EDC',
#  '1.6  dCi 130',
#  'S.T. 1.5dCi Blue Intens 85kW',
#  'S.T. E-TECH Zen 117kW',
#  'S.T. 2.0dCi Blue Zen EDC 147kW',
#  '4P 1.6 DCI 130CV',
#  'S.T. Initiale Par. En. dCi 118kW TT EDC',
#  'Life',
#  'ZEN ENERGY dCI 81 KW 110 CV EDC 5',
#  '1.2 TCe 130ch energy Intens EDC',
#  'Grandt. 1.6 dCi 160 Intens LED',
#  'grand scénic dci 130 energy fap eco2',
#  'SPORT TOURER 1.3 TCE ZEN 103KW 140 5P',
#  'Zen Energy dCi 81kW (110CV)',
#  'S.T. 1.5dCi Energy Tech',
#  'blue dci 150',
#  'estate dci 130 energy',
#  'IV Grandtour 1.2 TCe 130 Intens',
#  'S.T. 1.8dCi Blue GT Line EDC 110kW',
#  'IV ESTATE dCi 110 Energy EDC Intens',
#  'IV ESTATE BUSINESS Blue dCi 115',
#  'mégane iv estate blue dci 115 - 21b',
#  '1.2 TCe 130ch energy Intens',
#  'E-TECH ZEN 117KW 160 5P',
#  'BUSINESS BLUE DCI 70 KW 95CV',
#  '1.5 DCI TECH ROAD ENERGY 110CV',
#  '1.8 RS Energy Tce 205kW 280cv',
#  'Expression dCi 150',
#  'RS Trophy Energy 162kW (220CV) EDC',
#  'LIMITED BLUE DCI 88 KW 120CV',
#  '4 Energy dCi 55kW (75CV) Business',
#  '1.8 TCE RS TROPHY EDC 221KW 300 5P',
#  'Zen TCe GPF 74 kW (100CV)',
#  '2.0 Si',
#  '1.8 TCe GPF 300cv - 18 RS Trophy-R',
#  '1.3 TCE INTENS 103KW 140 5P',
#  'INTENS R135 B-Rent',
#  '1.5 Blue dCi 115cv Zen',
#  'Energy TCe 120 EDC Euro 6 Intens',
#  'Limited Energy TCe 66kw (90CV) eco2',
#  '1.8i 16v  140 cv avec CT et CarPass Reprise/éch',
#  '1.9 dCi/130CV 4p. Dynamique',
#  'Renault 18 Turbo',
#  'BOSE Edition',
#  'II Phase 2 (VP) 1.5 dCi S&S 90 cv',
#  '1.5 dCi 110 EDC BOSE LED GPS ACC',
#  '1.2 TCE ENERGY GT LINE 97KW 130 5P',
#  '22 kwh Zen batterie ok',
#  '2.0 12V GTI',
#  'IV BERLINE TCe 300 RS Trophy-R',
#  '1.8 TCe 225 EDC Initiale Paris',
#  'ii 1.2 lev 16v 75 eco2',
#  'IV BERLINE TCe 300 RS Trophy',
#  '1.6 Plug-in Hybrid E-TECH 160 R.S. Line EDC',
#  'IV BERLINE TCe 280 Energy EDC RS',
#  'Megane Berlina DUEL 2 Blue dCi 115 EDC',
#  'dci 130 energy intens / origine france',
#  '1.5 dci - 90ch   iv berline business',
#  '1.6 E-Tech Híbrido 140cv Intens',
#  '4 IV (BFB) 1.8T 280CH RS EDC',
#  'dCi 110 Limited',
#  'RS',
#  'Initiale 1.6 16V 110',
#  'iv rs 300 trophy - malus inclus',
#  '1.6 dCi 130 EDC FullLED GPS',
#  '1.5 BLUE DCI ZEN 85KW 115 5P',
#  '4 Energy dCi 75 eco2 Euro 6 Business',
#  'Mégane IV 1.5 Blue dCi - 115 - BV EDC -  GT Line P',
#  'IV BERLINE BUSINESS Blue dCi 115',
#  '1.2 TCe 115 SS Energy Expression',
#  '1.5BlueHDi S&S GT EAT8 130',
#  '1.4HDI XS',
#  '1.6 Hybrid Allure Pack EAT8 180',
#  '1.2 Puretech S&S Allure Pack 100',
#  '1.5 BlueHDi S&S Active Pack 100',
#  '1.6HDI XS',
#  'Pequeño Manual de 5 Puertas',
#  '1.5 BlueHDi S&S GT Pack EAT8 130',
#  '1.2 PureTech S&S Allure Pack 130',
#  '1.5 BlueHDi S&S GT EAT8 130',
#  '1.2 PureTech S&S Active Pack 110',
#  '12V VTi 82CV 5p. Active',
#  'VTi 52kW (72CV) Allure',
#  '1.2 PURE TECH ACTIVE 75 CV',
#  'Allure Long PureTech 110',
#  '1.2 PureTech S&S GT EAT8 130',
#  '1.6HDI FAP Confort',
#  '1.2 Puretech S&S Active 100',
#  '1.6 THP 270ch GTi S7S 5p Tpano GPS Camera',
#  '1ste Eigenaar 134.000km Garantie+Keuring',
#  '1.6 THP 270ch GTi S/S 5p GPS Camera Radar AV/AR',
#  '1.6 Hybrid GT EAT8 225',
#  '1.2 Puretech S&S Allure Pack EAT8 100',
#  '1.0-12V XS Apple Carplay / Elek. ramen / Toerentel',
#  '1.0-12V XR',
#  '206+ 1.1i',
#  '1.5 BlueHDi S&S Allure Pack EAT8 130',
#  '1.2 Puretech S&S Like 75',
#  '2.0HDI XS 136',
#  '1.1 XR 48.656 KM NAP 1e eigenaar',
#  '1.4 Gentry INRUILKOOPJE !!',
#  '1.4 Freddy Neopatentati',
#  '1.4Diesel !!!75.000km!!! GARANTIE + KEURING',
#  'e-208 136ch GT Line Siege Chauf LED GPS Camera Rad',
#  '1.4 XS',
#  '1.6-16V XS / Airco / 5 Deurs / Trekhaak',
#  '1.6 BlueHDi 120ch GT Line S/S EAT6 5p',
#  '1.4 S 5 drs. AIRCO NAP',
#  '1.2 Puretech Blue Lease Executive, Navigatie, Pano',
#  '1.2 PureTech 100ch S\\u0026S Allure Pack Siege Chau',
#  '1.6HDI XS 110',
#  '1.4i Urban 75',
#  '1.6HDI X-Line',
#  '1.2 Puretech S&S Allure Pack EAT8 130',
#  '1.5 BlueHDi 130ch S/S Allure EAT6',
#  'Allure Pack Eléctrico 100kW',
#  '1.0-12V XR| SPORT| ELEK. RAMEN| LM-VELGEN',
#  '1.5 BlueHDi 100ch E6.c S/S Style GPS Camera JA17',
#  '1.5 BlueHDi 130ch S/S Allure GPS Camera Car Play K',
#  '1.2 PureTech 130ch S/S Allure EAT6 Siege chauf',
#  '1.2 PureTech 130ch ¤6.c S/S Active Business Siege',
#  'WAGON Business 1.6 8v e-HDi 115cv S/S',
#  '1.2 PureTech 130ch S\\u0026S GT Line EAT8 7cv',
#  '1.2 PureTech 130ch Active Business Siege chauf Cam',
#  '1.5 BlueHDi 130ch S/S Active Business GPS Camera R',
#  '1.2 PureTech 100ch S/S Allure Business',
#  'CC 2.0',
#  'CC Sport Pack 1.6 THP 140 Automático',
#  'Cabriolet ROLAND GARROS Paris Capote électric',
#  '2.0-16V CC CABRIO LEER AIRCO CLIMA NAP 2DE EIGENAA',
#  '206 CC Roland Garros',
#  '1.1i cat Cabriolet CJ',
#  '207 CC 1.6 16v 120ch',
#  'CC 110 Filou',
#  'Cabriolet 2 l',
#  'CC Sport 1.6 VTI 120',
#  'CC 1.6 VTI 16V 120',
#  'Sport 1.6 HDI 110 FAP',
#  'Cabrio 1.6 THP Sport Pack 115 kW (156 CV)',
#  'CC 1.6',
#  'CC 1.6HDI FAP 110',
#  'CC 1.6 THP Edition Limitada 150CV',
#  'CC Cabrio 2.0 HDI Sport 140CV',
#  'CC Cabrio 1.6 VTi Sport 122CV',
#  'CC 1.6 VTi Active 120 CV',
#  'CC 1.6 VTi 120cv SPORT 2p #BLUETOOTH',
#  'CC HDI 136 FAP',
#  'cabriolet $$je recherche en état ou a refaire$$',
#  'Cabriolet Injection',
#  'GTI',
#  '1.6-16V',
#  'CC 2.0 Sport 180',
#  'coupé cabriolet',
#  'CC HDi FAP 140 Premium',
#  '206CC',
#  'CC FAP 110 (Blue Lion) Filou',
#  'Cabriolet 1.6i CTi',
#  'cabrio',
#  'CC 2.0 HDi 16V 140 ch FAP Féline 7',
#  '2.0-16V',
#  'CC 2.0-16V Airco,',
#  '1.6-16V Roland G.',
#  'CC 2.0 16V',
#  'CC',
#  '1.6 Vti Cabrio 2008 Zwart',
#  '<NULL',
#  'CC 135',
#  'CABRIOLET 1.8 CABRIOLET, NW. CABRIO KAP, NETTE AUT',
#  'CC e-HDi FAP 110 Start&Stop Active',
#  'CC 110 Roland Garros',
#  'Cabriolet 2.0-16V',
#  '1.4i Cabrio oldtimerkeuring + 1JAAR garantie!',
#  '1.6 VTi',
#  '1.6 VTI 16V FELINE',
#  'CABRIOLET (KF2)',
#  'CC HDi FAP 110 Premium',
#  '1.6-16V T Roland G.',
#  'PEUGEOT 308 CC, 2.0 DIESEL CABRIOLET',
#  'Cabriolet 1.8',
#  '206CC Hardtop Cabriolet',
#  'Automatik Leder',
#  'Coupé 2.2',
#  '1.3i Rallye',
#  'Coupé 2.0l - Garantie 12 mois',
#  'R 270ch',
#  '1.6 THP 155cv',
#  '1.6 THP',
#  'Coupé 2.0HDI Pack',
#  '2.0 HDi  163 CV',
#  '2.0 HDi 163 CV',
#  'Coupé Ultima Edizione HDi Pack 136',
#  'Coupé 2.2 Pack',
#  'CoupÃ© 2.2 163cv 2p #LIBRO',
#  'Coupé 3.0 V6 Pack',
#  'Coupé 2.0 16v',
#  '2.7 V6 hdi 24v Feline auto fap',
#  'coupè',
#  '1,6 THP 160',
#  '2.0 COUPE brandstofpomp defect',
#  '16v gti',
#  '3.0-24V V6 Pack',
#  "201 '30",
#  '5p 1.4 vti 16v XS',
#  '16 GTI',
#  'Coupe "S" ( 1974 )',
#  'cc roland garros 1.6hdi 112 fap',
#  '2.0i 16V cat Coupé',
#  'Coupé 2.0 16v GTI',
#  'Coupe 165 Sport',
#  'SW 2.0 hdi 16v Tecno Ciel fap',
#  '1.6 THP 200ch BVM6 GT Line',
#  'GTI 1.9 130 CV--ASI ORO--ORIGINALE--PARI AL NUOVO',
#  '3.0i V6 24V cat Coupé Plus',
#  "3.0i V6 24V cat Coupé Plus Settant'anni",
#  's16',
#  '1.6 thp 16v 156cv auto',
#  'Plus 3p 1.1 Urban',
#  '2.0 HDi FAP 160',
#  'GTI 1.6 THP S&S 3 porte',
#  '206 3p 2.0 hdi XS c/2airbag',
#  '1.6 thp 16v 200cv',
#  '007 2.2-16V Pack ( heerlijke wagen! )',
#  '1.6 155 THP',
#  '3p 1.6 16v XS',
#  '+ Basis 1TÜV NEU 2.HAND',
#  'cabrio xen cc 3p 1.6 hdi 16v Feline 110cv fap',
#  'Plus 3p 1.1 X-Line eco-Gpl',
#  '1.5BlueHDi Active Pack S&S 130',
#  '1.6 BlueHDi 88KW (120CV) S&S Allure',
#  'BlueHDI 81kW (110CV) Active',
#  'HYB PHEV 225 Allure Pack e-EAT8',
#  '1.2 PureTech S&S Allure Pack EAT8 130',
#  '1.5 BLUE HDI 130 CV EAT8 ALLURE',
#  '1.5 BLUE HDI 130 CV ACTIVE PACK',
#  '1.6EHDI 115CV ALLURE 5P',
#  '300 e-EAT8 Allure Pack',
#  'ALLURE HDI 130 CV',
#  '1.6 THP 156cv -',
#  '1.2 PureTech 96KW S&S Active Pack',
#  '1.2 PURETECH S&S ACTIVE 130 5P',
#  'BlueHDI 130 S&S EAT8 Allure',
#  '1.5BlueHDi S&S Roadtrip S&S EAT8 130',
#  'BlueHDI 130 S&S EAT8 Allure Pack',
#  'BlueHDI 81kW (110CV) Allure Pack',
#  '1.6BLUEHDI ALLURE S&S 120CV 5P',
#  '1.2 PureTech SS Allure',
#  '1.5 Blue-HDi GT Line',
#  'GT LINE 1.2 PURE TECH 130 CV',
#  'Puretech 130 S&S EAT8 Allure Pack',
#  '300 e-EAT8 GT Pack',
#  'ALLURE',
#  '1.6BlueHDi S&S GT-Line EAT6 120',
#  '1.6BlueHDi S&S GT-Line 120',
#  '1.5BlueHDi S&S Allure 130',
#  '1.2 PureTech S&S GT Line 130',
#  '1.6BlueHDi S&S Allure EAT6 120',
#  'Puretech 100 S&S 6 Vel. MAN Active Pack',
#  '1.5 BLUEHDI S&S AUTO GT LINE 130CV 5P 7 PLAZAS',
#  'GT-Line BlueHDi 96kW (130CV) S&S EAT8 GT Line',
#  '1.6 BlueHDi 88KW 120CV Allure SS',
#  '1.2 PURETECH 100 S&S ACTIVE PACK 5P',
#  '1.5BlueHDi S&S Allure 100',
#  '1.5BlueHDi S&S Allure EAT8 130',
#  'BlueHDI 100 S&S BVM6 Allure',
#  '1.5 BLUEHDI 96KW ACTIVE S&S 130 5P',
#  '1.5BlueHDi S&S GT Line 100',
#  '1.5 BlueHDi 96kW S&S  EAT8 Allure Pack',
#  'Confort 1.6 HDI 110 FAP',
#  'Active 1.6 BlueHDi 100',
#  '2.0BLUEHDI 133KW GT AUTO S&S 180 5P',
#  '1.5 BLUEHDI 96KW ALLURE S&S 5P',
#  '1.2 PureTech S&S Active Pack 100',
#  '1.2 PureTech S&S Active 100',
#  '1.5BlueHDi S&S Allure Pack EAT8 130',
#  'HYB PHEV 300 Allure Pack AWD e-EAT8',
#  'II 2016 3008 1.5 bluehdi GT Line s&s 130cv eat8',
#  '1.5 BLUEHDI 96KW S&S ALLURE 5P 7 Plazas',
#  '1.6 BlueHDi S\\u0026S - 120 - BV EAT6  Active Busin',
#  '1.5 BlueHDi 96kW (130CV) S&S Active Pack',
#  'HYB PHEV 300 GT AWD e-EAT8',
#  '225 e-EAT8 Allure Pack',
#  '1.6 e-HDi 92 Allure',
#  '1.2 S&S PureTech Allure Pack EAT8 130',
#  '2.0 bluehdi 150ch s\\u0026amp;s bvm6 allure / suivi',
#  '1.2 PureTech 96KW (130CV) S&S Allure',
#  '1.6 BlueHDi 120ch S&S EAT6 Active Business',
#  '1.2 PURETECH 96KW S&S ALLURE 5P',
#  'HYB PHEV 225 Allure e-EAT8',
#  '2.0 BlueHDi 150ch GT Line S/S TOuvrant/Pano GPS Ra',
#  'Puretech 100 S&S BVM6 Active Pack',
#  '1.6 HDi 120 EAT6  Allure',
#  '1.6 THP 16v 165ch Allure S/S EAT6 Tpano HUD Camera',
#  '1.5bluehdi active s&s 130',
#  'BlueHDi 96kW (130CV) S&S EAT8 Allure',
#  'SW 1.6 Hybrid GT Pack EAT8 225',
#  'SW  HYBRID 225 e-EAT8 GT',
#  '5p Active 1.4 HDi 70 FAP',
#  'SW 1.2 PureTech S&S Active Pack 110',
#  '1.6 BLUEHDI 88KW BUSINESS LINE SW 120 5P',
#  'SW 1.6 Hybrid Allure Pack EAT8 180',
#  'GT Long BlueHDi  96kW',
#  'SW 2.0HDI 110',
#  '1.5 Blue-HDi Access Standard',
#  '1.5 Blue-HDi Access L1',
#  'SW 2.0HDI Pack 136',
#  '1.2 PureTech EAT8 GT Long 7 plazas',
#  'SW GT HYBRID 180 e-EAT8',
#  'SW ACTIVE 1.6 BLUEHDI 88KW 120CV',
#  'SW 1.6 BlueHDI 120pk Blue Lease Navi|Clima|LMV|PDC',
#  'SW PSE Hybrid 360 Automatik 8-Gang',
#  'SW  BlueHDi 130 S&S GT',
#  'SW  PureTech 130 S&S 6 Vel. MAN Style',
#  '2.0 bluehdi 180ch eat6 / suivi entretien complet à',
#  'SW 1.2 PureTech S&S Allure Pack EAT8 130',
#  'standard 1.5 BLUEHDI gt line 130 eat8',
#  'HYBRID4 300ch GT Pack e-EAT8',
#  '5p XT 2.0 HDI 136 FAP',
#  'SW 1.6 BlueHDI Blue Lease Pack NAVI LMC PDC CLIMA',
#  '1.6 hdi 16v Lee',
#  'SW 1.2 PureTech Allure 130PK | FS18900 | Dealer On',
#  '1.5 BlueHDi 130ch S\\u0026S GT EAT8',
#  'SW  BlueHDi 130 S&S EAT8 Style',
#  'e-2008 136ch GT',
#  'SW Hybrid 225 GT e-EAT8',
#  '308 BlueHDi 180 EAT6 S&S SW GT',
#  'II 2018 SW 308 SW 1.5 bluehdi Allure s&s 130cv my2',
#  '2.0 BlueHDi 180ch S\\u0026S Roadtrip EAT8',
#  '1.5 BLUEHDI 96KW ALLURE AUTO SW 5P',
#  'SW Allure 1.2 PureTech 96KW (130CV) S&S',
#  '2.0 BlueHDi - 180 - BV EAT8   SW (BREAK) GT LINE',
#  '5p GT Line 1.2 PureTech 130 S&S',
#  '1.2 PureTech 130ch S\\u0026S Allure Business EAT8 C',
#  'SW  Puretech 130 S&S EAT8 GT',
#  '1.5 BLUEHDI 96KW STYLE AUTO SW 5P',
#  'SW Active Pack Puretech 130 S&S MAN',
#  'RXH 2.0 BlueHDi 180CV Autom.',
#  '1.5 BlueHDi 130ch S\\u0026S GT Pack EAT8',
#  '1.5 BlueHDi 130ch S/S Active Business 7cv Siege Ch',
#  '2ª serie PureTech Turbo 130 S&S SW Allure',
#  'SW  1.6 BlueHDi 88KW (120CV) Active',
#  'SW 1.4 VTi Confort',
#  'SW  PureTech 130 S&S EAT8 Active Pack',
#  '1.5 BlueHDi 130ch S\\u0026S Style',
#  '1.5 BLUEHDI 130CH S\\u0026S ALLURE EAT8',
#  '1.2 PureTech 130ch S\\u0026S GT EAT8',
#  'II Ph2 1.5 BlueHDi 130 S\\u0026S GT Line BA8',
#  'HYBRID4 360ch e-EAT8 PSE 2500km',
#  'ACTPK PT100',
#  'BlueHDi 130ch Active EAT8 T.O+ADML',
#  '1.5 Blue-HDi GT Line Standard',
#  'SW  Hybrid 225 eEAT8 GT',
#  '1.5 BLUEHDI ALLURE 130 standard',
#  '1.2 PureTech 130ch S/S Active Business EAT8',
#  'HYBRID 225ch Allure Pack e-EAT8',
#  'HYBRID 225ch GT e-EAT8',
#  '1.6 8V HDi 93 CV SW X Line',
#  '5P PSE HYBRID 360 e-EAT8  Sport Engineered',
#  '3.0 V6 ST Sport Pack Aut.',
#  '2.7HDi Titanio Aut.',
#  'Hybrid 225 GT e-EAT8',
#  '403 Oldtimer/ Sammler /Rarität/Black Panther/',
#  'Berline Bj.1956',
#  '2.0HDI ST Confort Pack',
#  'Hybrid 225 Allure Pack e-EAT8',
#  '1.5 BLUEHDI 96KW TECH EDITION 5P',
#  '2.0 BLUEHDI AUTO GT 180 CV 4P',
#  '2.0HDI Sport',
#  'Active BlueHDi 96kW (130) S&S 6vel MAN',
#  '5P ACCESS 1.2L PureTech 82',
#  '1.6 HYBRID 225 ALLURE PACK E-AUTO 225 5P',
#  '1.6 PHEV 225 E-EAT8 GT 225 5P',
#  '1.2 PureTech S&S Active Pack EAT8 130',
#  'PureTech 96kW (130CV) EAT8 GT Line',
#  '5p  BlueHDi 130 S&S Active',
#  '5P  BlueHDi 130 S&S EAT8 Allure Pack',
#  '5P  PureTech 130kW (180) S&S EAT8 Active',
#  '2.0HDI SRDT 110',
#  '1.6 Hybrid 225cv eEAT8  GT Pack',
#  'Active BlueHDi 96kW (130CV) S&S EAT8',
#  '1.5 BLUEHDI ACTIVE 100CV 5P 2 PLAZAS',
#  '1.5 BLUEHDI 130 ALLURE AUTO 5P',
#  '16V SR',
#  '5P  BlueHDi 120kW (160) S&S EAT8 GT Line',
#  '5p Style 1.6 BlueHDi 88KW (120CV)',
#  '1.5 BLUEHDI 73KW GT LINE 5P',
#  '1.5 HDI 100cv',
#  'PureTech 73kW (100CV) Active Pack',
#  'Tbo Inj Ti',
#  '2.2 ST Sport Aut.',
#  'BlueHDi FAP 100 Stop & Start Active',
#  '1.6 e-HDi 112 CV ca. rob. S&S Active',
#  ...]

# %%
categorized_dict = {
    'con_nect': [ # 'Digitalconnectivity',
                      'Usb',
                      'Bluetooth',
                      'Cd Player', 
                      'Mp3',
                      'On-Board Computer',                      
                      'Digital Cockpit',
                      'Hands-Free Equipment',
                      'Digital Radio',                      
                      'Induction Charging For Smartphones',
                      'Integrated Music Streaming',
                      'Wlan / Wifi Hotspot',
                      'Radio'
                     # 'Digital'
    ],
    
    'entertainment': [
                      'Television'
    ],
    
    'sphone_integ': [
                      'Android Auto',
                      'Apple Carplay'
    ],
    
    'sound_system': [
                      'Sound System'
    ]
}

# %%
# Sure, let's query the key-value pairs of the dictionary in the short description.
for category, keywords in categorized_dict.items():
    for keyword in keywords:
        result = df.loc[df[df["entertainment_&_media"].isnull()].index, "short_description"].str.contains(f"(?i){keyword}")
        print(f"{category} {keyword}: {result.value_counts()}")
# Out:
# con_nect Usb: False    4881
# Name: short_description, dtype: int64
# con_nect Bluetooth: False    4863
# True       18
# Name: short_description, dtype: int64
# con_nect Cd Player: False    4881
# Name: short_description, dtype: int64
# con_nect Mp3: False    4881
# Name: short_description, dtype: int64
# con_nect On-Board Computer: False    4881
# Name: short_description, dtype: int64
# con_nect Digital Cockpit: False    4881
# Name: short_description, dtype: int64
# con_nect Hands-Free Equipment: False    4881
# Name: short_description, dtype: int64
# con_nect Digital Radio: False    4881
# Name: short_description, dtype: int64
# con_nect Induction Charging For Smartphones: False    4881
# Name: short_description, dtype: int64
# con_nect Integrated Music Streaming: False    4881
# Name: short_description, dtype: int64
# con_nect Wlan / Wifi Hotspot: False    4881
# Name: short_description, dtype: int64
# con_nect Radio: False    4879
# True        2
# Name: short_description, dtype: int64
# entertainment Television: False    4881
# Name: short_description, dtype: int64
# sphone_integ Android Auto: False    4881
# Name: short_description, dtype: int64
# sphone_integ Apple Carplay: False    4880
# True        1
# Name: short_description, dtype: int64
# sound_system Sound System: False    4881
# Name: short_description, dtype: int64

# %%
handle_missing_values(df , "entertainment_&_media")
# Out:
# Missing Values in 'entertainment_&_media':
# Count: 4973
# Percentage: 17.39%

# %%
# FINAL CODE
# For all rows where 'extras' is NaN and 'short_description' is not empty,
# we are searching for ALL keywords.
index_no = df.loc[df["entertainment_&_media"].isnull() & df["short_description"].notnull()].index

for category, keywords in categorized_dict.items():
    for keyword in keywords:
        result_indices = index_no.intersection(df[df["short_description"].str.lower().str.contains(keyword.lower(), na=False)].index)
        df.loc[result_indices, "entertainment_&_media"] = df.loc[result_indices, "entertainment_&_media"].apply(lambda x: x + ", " + category if pd.notnull(x) else category)

# %%
handle_missing_values(df , "entertainment_&_media")
# Out:
# Missing Values in 'entertainment_&_media':
# Count: 4952
# Percentage: 17.31%

# %%
# To prevent duplicates within a row, let's use a set.
df["entertainment_&_media"] = df["entertainment_&_media"].apply(lambda x : ",".join(set(x.replace(" ","").split(","))) if type(x) == str else x)

# %%
handle_missing_values(df , "entertainment_&_media")
# Out:
# Missing Values in 'entertainment_&_media':
# Count: 4952
# Percentage: 17.31%

# %%
df["entertainment_&_media"].value_counts()
# Out:
# con_nect                                            12608
# sphone_integ,con_nect                                4265
# con_nect,sound_system                                3381
# sphone_integ,con_nect,sound_system                   3188
# sound_system                                           60
# entertainment,sphone_integ,con_nect,sound_system       56
# entertainment,con_nect,sound_system                    53
# entertainment,con_nect                                 17
# sphone_integ                                           14
# entertainment,sphone_integ,con_nect                     7
# entertainment,sphone_integ                              1
# sphone_integ,sound_system                               1
# Name: entertainment_&_media, dtype: int64

# %%
# After the groupby operation, how many NaN values do I have remaining?
df['entertainment_&_media'].fillna(df.groupby(['make', 'type'])['entertainment_&_media'].transform(lambda x: x.mode()[0])).isnull().sum()
# Out:
# 0

# %%
df["entertainment_&_media"] = df['entertainment_&_media'].fillna(df.groupby(['make', 'type'])['entertainment_&_media'].transform(lambda x: x.mode()[0]))

# %%
handle_missing_values(df , "entertainment_&_media")
# Out:
# Missing Values in 'entertainment_&_media':
# Count: 0
# Percentage: 0.00%

# %%
# IMPORTANT CODES BELOW

# %%
# # The code below can only add a single key.

# for category, keywords in categorized_dict.items():
#     for keyword in keywords:
#         result_indices =   df.loc[(df["entertainment_&_media"].isnull()) & (df["short_description"].str.contains(f"(?i){keyword}"))].index
#         df.loc[result_indices, "entertainment_&_media"] = category

# %%
# It keeps the matching value for different key values.

# for category, keywords in categorized_dict.items():
#     for keyword in keywords:
#         result_indices = df.loc[(df["entertainment_&_media"].isnull()) & (df["short_description"].str.contains(f"(?i){keyword}"))].index
#         df.loc[result_indices, "entertainment_&_media"] = df.loc[result_indices, "entertainment_&_media"].apply(lambda x: x + ", " + category if pd.notnull(x) else category)

# %%
# FINAL CODE, THE ONE BEFORE THE LAST CODE

# index_no = df.loc[df["entertainment_&_media"].isnull() & df["short_description"].notnull()].index

# for category, keywords in categorized_dict.items():
#     for keyword in keywords:
#         result_indices = df.loc[index_no & df["short_description"].str.lower().str.contains(keyword.lower())].index
#         df.loc[result_indices, "entertainment_&_media"] = df.loc[result_indices, "entertainment_&_media"].apply(lambda x: x + ", " + category if pd.notnull(x) else category)

# %%
# index_no = df.loc[df["entertainment_&_media"].isnull() & df["short_description"]].index

# for category, keywords in categorized_dict.items():
#     for keyword in keywords:
#         result_indices = df.loc[index_no , "short_description"].apply(lambda x: keyword.lower() in x.lower()).index
#         df.loc[result_indices, "entertainment_&_media"] = df.loc[result_indices, "entertainment_&_media"].apply(lambda x: x + ", " + category if pd.notnull(x) else category)

# %% [markdown]
# <a id="9"></a>
# <div class="alert alert-info" role="alert">
# <h1>Column name :<span style="color:red"> safety_&_security </span></h1>
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Operation : </b> First, let's leverage <span style="color:red"><b>the dictionary we created in Part 1  </b></span>to examine the short_description. If we find any matching values, let's <span style="color:red"><b>replace </b></span> them with their corresponding keys. Then, <span style="color:red"><b>to prevent duplicates </b></span>, let's convert the expressions within each row into sets and then retrieve them back. Since the <span style="color:red"><b> " Safety_&Security "</b></span> column is related to <span style="color:red"><b>"body_type" and "gearbox" </b></span>, we can fill the missing values using them. Additionally, we can fill the <span style="color:red"><b>remaining values using the "comfort&convenience" column </b></span> and it would result in a more homogeneous distribution.
# </div>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
first_looking("safety_&_security")
# Out:
# column name    :  safety_&_security
# --------------------------------
# per_of_nulls   :  % 11.2
# num_of_nulls   :  3204
# num_of_uniques :  36
# lighting_feature,safety_feature,conv_feature                                 9407
# other_feature,conv_feature,lighting_feature,safety_feature,driver_feature    6887
# NaN                                                                          3204
# safety_feature,conv_feature                                                  2664
# driver_feature,lighting_feature,safety_feature,conv_feature                  2614
# lighting_feature,driver_feature,safety_feature,conv_feature                  1239
# lighting_feature,safety_feature,other_feature,conv_feature                    891
# safety_feature                                                                599
# lighting_feature,safety_feature                                               251
# conv_feature                                                                  219
# driver_feature,safety_feature,conv_feature                                    133
# lighting_feature,conv_feature                                                  72
# safety_feature,other_feature,conv_feature                                      69
# lighting_feature                                                               57
# safety_feature,lighting_feature,driver_feature,conv_feature                    48
# driver_feature,safety_feature,other_feature,conv_feature                       35
# driver_feature,lighting_feature,safety_feature                                 31
# lighting_feature,driver_feature,safety_feature                                 29
# safety_feature,driver_feature,conv_feature                                     17
# lighting_feature,safety_feature,other_feature                                  14
# lighting_feature,other_feature                                                 13
# driver_feature                                                                 13
# lighting_feature,driver_feature,conv_feature,safety_feature                    13
# driver_feature,lighting_feature,safety_feature,other_feature                   12
# safety_feature,other_feature                                                   12
# driver_feature,safety_feature                                                  10
# lighting_feature,other_feature,conv_feature                                     9
# safety_feature,driver_feature,other_feature,conv_feature                        8
# lighting_feature,driver_feature                                                 6
# driver_feature,conv_feature                                                     6
# lighting_feature,driver_feature,conv_feature                                    5
# lighting_feature,driver_feature,safety_feature,other_feature                    5
# driver_feature,other_feature,conv_feature,safety_feature                        4
# driver_feature,safety_feature,other_feature                                     3
# lighting_feature,driver_feature,other_feature,safety_feature                    2
# lighting_feature,driver_feature,other_feature,conv_feature                      1
# other_feature                                                                   1
# Name: safety_&_security, dtype: int64

# %%
# To be more thorough, let's check if there are any words in the short description 
# that match the key-value pairs of the dictionary, as a precautionary measure.
list(df.loc[df[df["safety_&_security"].isnull()].index, "short_description"].unique())
# Out:
# ['CDi',
#  '350+',
#  'S 4Matic+ 8G-DCT',
#  'd 4Matic (EURO 6d)',
#  '250e 8G-DCT',
#  'CDI Elegance',
#  'd AMG Line (EURO 6d)',
#  'd (177.003)',
#  '200d 4Matic 8G-DCT',
#  '200d Sedán 8G-DCT',
#  'S AMG 4MATIC+',
#  '4-Door 63 S 4MATIC+',
#  '250e Sedán 8G-DCT',
#  '200d 7G-DCT',
#  'CDI 100kW ( 136CV ) Urban',
#  'd',
#  'e A 250e Progressive Sfeerverlichting / NIEUW GERE',
#  'E 280',
#  'd Premium',
#  'MERCEDES-BENZ Clase GLK Pequeño  Automático de 5',
#  'Pequeño Automático de 5 Puertas',
#  nan,
#  '180d 8G-DCT',
#  'CDI Premium',
#  'CDI',
#  'CDI Style',
#  'Biturbo V-Max',
#  'abrio Mercedes-AMG 4MATIC',
#  'MERCEDES-BENZ Clase SL Descapotable  Automático d',
#  'SL *Pagode*3.Besitz/Dt.Fahrzeug/H-Zul.',
#  'MercedesAMG',
#  'SL Pagode',
#  'r107 original belgian delivery! first owner car.',
#  '200K',
#  'Cabrio d',
#  'SL Vollrestauration',
#  'V12 - Origineel Nederlands -',
#  '200 K.',
#  'GE',
#  'Cabriolet AMG Line',
#  '(R129)',
#  '(R129) 2nd Owner/Collectable',
#  'Extrem gepflegtes Ex-Pressefahrzeug W 231',
#  'SL',
#  'Cabrio',
#  'cabrio d  Premium Plus 4matic auto',
#  '220 d executive a',
#  '220 A Cabriolet',
#  '190SL',
#  'S Cabriolet Ponton Typ A (W 180)',
#  'D',
#  'AMG GLC 43 4MATIC Coupé',
#  'SEb (111)*DEUTSCHES-FAHRZEUG*H-KENNZEICHEN*TOP-ZUS',
#  'd 4MATIC Coupé AMG Line',
#  'S Coupe',
#  '4Matic (EURO 6d-TEMP)',
#  'C Coupe*DEUTSCHES-FAHRZEUG*AUTOMATIK*H-KENNZEICHEN',
#  'Compressor',
#  '220d Aut.',
#  'Coupé d (238.314)',
#  'Matte wrapping',
#  'd 4MATIC -',
#  'Coupé 400d 4Matic Aut.',
#  'CDI Chrome',
#  'Coupé d AMG LINE',
#  'd (205.314)',
#  'EQ Boost Aut. (9.75)',
#  'CDI (LA) Sport Edition (203.708)',
#  'Coupé 220d',
#  'COUPE AMG -Line',
#  'CDI Inspiration 7G-DCT',
#  '220d 4Matic 8G-DCT',
#  '300e 4Matic 9G-Tronic',
#  '4MATIC',
#  'd 4MATIC',
#  'd 4 MATIC 245cv 9 vel. *IVA deducible* *2020* *Nac',
#  '4Matic 8G-DCT',
#  'd 4Matic (253.915)',
#  'Puch  JAGD-FZG./WINDE/KOFFER/BRAUSE/AHK',
#  'e 4Matic',
#  '300 4MATIC',
#  'D ADVANTAGE + PAQ NIGHT',
#  'Coupé 350D 258 CV',
#  'Puch PLANE/AHK/ALLRAD/SCHLIEßANLAGE NEU',
#  'Mercedes-AMG 4MATIC',
#  'Mercedes-AMG 4MATIC+',
#  '300d 4Matic Aut.',
#  '(+)2.0 AVANTGARDE AUTO 211 5P STATE',
#  'd Estate Avantgarde',
#  'de Estate AMG LINE',
#  'CDI Blue Efficiency Estate',
#  'Estate Estate',
#  'd Estate',
#  '(+)2.1 D AMG LINE 5P',
#  'B200 CDI AMG AUT 136CV',
#  '580 4Matic',
#  'CDI BlueEfficiency (204.001)',
#  '1.6',
#  'Mercedes-AM53 4MATIC+',
#  'Mercedes-AMG S 4MATIC+',
#  'CDI Business',
#  'd AMG',
#  'BlueTEC Sport',
#  '220d 9G-Tronic 194',
#  'BlueTEC 4Matic (212.011)',
#  'Org. 61.000km Aut. Historie 1A Sammlerzust.',
#  '1.4 66KW (90 CV) EXPRESSION PRO',
#  '1.5D DT S/S GS-Line + 100',
#  '1.2T S/S Design & Tech 130',
#  'Corsa-e Elegance-e',
#  '1.5D DTH S/S Elegance 130',
#  '1.4 Twinport 87ch Start/Stop',
#  'TwinTop 1.4 16V Sport',
#  '2.0 CDTi S/S 165 CV Excellence',
#  '1.4 Turbo Excellence',
#  '1.4 T S/S Excellence',
#  '1.4T 140cv Excellence S/S #NAVY, BLUETOOTH',
#  'Descapotable Manual de 3 Puertas',
#  '2.0 264 turbo cab / suivi complet opel / 1e main',
#  'Roadster',
#  '2.0 Turbo ECOTEC',
#  '2.0 T',
#  '2.0 Turbo Pack',
#  '2.2 16v VX 220 VX220',
#  '2.0 CDTI 165CH COSMO PACK AUTOMATIQUE',
#  'opel astra h cabrio opc',
#  'Twin Top 1.8 (Enjoy)',
#  '1.4-16V cabrio',
#  'Deportivo Manual de 3 Puertas',
#  'B 2.0 GSI 1985 ATS RECARO APK 2023',
#  'GT/J Sport',
#  'C 2.2 de Luxe',
#  '3 Puertas 1.4T GSI',
#  'GTC 2.0 CDTi 195cv Biturbo 3p S/S #NAVY, BLUETOOTH',
#  'Coupe GS',
#  '2.5i V6',
#  'olimpia record coupe',
#  '19 SR',
#  'Commodore 2.5 GS Coupe Automat',
#  '2.0S',
#  'Olimpia 1.5 Coupe  //Top Zustand//',
#  '*H-Kennzeichen*Oldtimer*TÜV Neu*',
#  '3.0 E',
#  '1.4',
#  'A Berlinetta 1,9 S',
#  'GT/E gruppo 2',
#  '1900 S Berlina',
#  'opel Astra g coupe project',
#  'Olympia',
#  '1900',
#  'GT1900 AL',
#  'GSE (état concours)',
#  'Rallye 16S',
#  '1200 S',
#  'GTC 1.6 t ecotec Cosmo S s&s 180cv',
#  'GT-A-L',
#  'B Coupe aus 1969',
#  '1.7 CDTi 111 y. Ed.',
#  '2.0 i gt/e 110cv',
#  '1.7 CDTi Enjoy',
#  '1.9 N',
#  'B Coupe',
#  'GTE - CONRERO',
#  'Irmscher GSE Oltimer FIA Liebhaber ',
#  '2.2 16V Coupe',
#  'Manta-B',
#  'C1 Coupe 1200H',
#  'B LS Fastback',
#  'coupé',
#  '2.0 GSi / Look Manta 400 /  Rally / Oldtimer /',
#  'oldtimer 3.0 6cil GSE 180pk manual gears box',
#  'AT',
#  'Berlinetta',
#  '1.3 CDTI . GTC',
#  'Coupe 2.0 turbo 16v 200cv',
#  'B GSI - Hatchback - Same Owner since 1990',
#  'B 2.0 GT/E,IRMSCHER,SERVO,H-ZULASSUNG,SPANIEN',
#  '1.6i 16V Sports',
#  'G Coupé Bertone !',
#  'A 1,6S Original 28300 KM Neuwertig',
#  '5p 1.6i twinport 16v',
#  '1.8 16V Coupe',
#  'A GTE Gelb Leder',
#  '200',
#  'B 1,9 S 1 Hand',
#  '1.6 Executive',
#  'ASTRA GTC 1.4',
#  'Astra Coupe 1.8 16v',
#  '3p 1.4i 16v Club',
#  'G CC',
#  'e    1.4i  32jahre alt  h kennzeichen-möglich',
#  '1.3 CDTI Advance 95cv S/S 5 PORTE',
#  '1.4i 16V',
#  'B CC - 2.0E - 22tkm ! -perfekt original',
#  '1.3 CDTI b-Color 75cv 5 PORTE',
#  'PHEV 1.6 Turbo GS Line Aut. 4x2 225',
#  '3.0TD LS',
#  '1.5CDTi S&S GS Line Aut. 130',
#  '1.6 Turbo  Auto 4x4 Ultimate',
#  '1.2T S&S GS Line 130',
#  '1.2 96kW (130CV)  S/S Innovation',
#  'Mokka-e GS Line-e',
#  'X 1.6 CDTI 110 CV ECOFLEX BUSINESS EDITION',
#  'GS LINE',
#  '1.2 Turbo Selective',
#  'X 1.6 CDTI Excellence',
#  'X EXCELLENCE',
#  'INS-ST INNOV. 1.6D 136CV MT6',
#  'SPORT TOURER 1.2 TURBO 145 CV ELEGANCE',
#  'Life 1.2 T S/S   XL Selective',
#  'Sports Tourer 2.0 CDTI 130CV Edition Aut',
#  'Life 1.5 CDTI INNOVATION',
#  'Life 1.5 TD 75kW (100CV) S/S   L Selective',
#  'ST 1.5D DVH S&S Business Edition 122',
#  'Life 1.5 TD 96kW 130cv SS Edition L',
#  'ST  2.0D DVH 130kW AT8 Business Elegance',
#  'Berlina Manual de 5 Puertas',
#  '1.2T SHR 107kW (145CV) Business Elegance',
#  'GS  1.5D DVH 90kW MT6 Business Edition',
#  'GS  2.0T SHT 169kW AT9 4x4 GSi',
#  '2.0 T SHT S&S Business Elegance AT9 170',
#  '1.4T Elegance AUT 5p',
#  '1.5D DVH S&S GS-Line AT8 122',
#  '1.6 Turbo S/S GSi Line',
#  'GS 1.6 CDTi 100kW Turbo D Business',
#  '1.2T XHL 74kW (100CV) GS-Line',
#  '1.4 Turbo S/S Sportive',
#  '1.6T Hybrid 132kW (180CV)  Auto GS-Line',
#  '1.2T XHL 74kW (100CV)  Auto Elegance',
#  '1.8 TCe GPF RS Trophy EDC 221kW',
#  '1.5 dCi 110CV Nav',
#  '1.5 ENERGY dCI 110 CV AUT',
#  'E-TECH RS Line 117kW',
#  'TCe Zen 67kW',
#  '1.3 TCe 140cv Zen Energy',
#  '1.9D RN',
#  '80 INTENS WHITE',
#  'tce 120 intens pack trophy + equipe pmr handicap',
#  '0.9 Dynamique Navi*MMI*Clima*Parksensor*Keyless*Ca',
#  'LIMITED LIFE 41KW/H',
#  '1.4 RN Orig.NL 54dkm+nap Topstaat!',
#  'Twizy 45 Intens Black Flex',
#  '1.5 DCI LMV NAVIGATIE CRUISE CD CV+AB',
#  'life 80 kw r110 batería 40kwh',
#  'Plein Air*Komplettneuaufbau*H-Kennz.',
#  'R4 Cabriolet / Sammlerfahrzeug / 1. Hand',
#  'CC 1.5 dCi Dynamique 110 CV',
#  'CC TCe 130 Dynamique 130 CV',
#  'Sporter Blue dCi 160 CV EDC Exe',
#  '1.8 Fairway',
#  '1.6-16V Priv.Luxe',
#  'renault megane 5 porte dci  110cv',
#  'Cabriolet 1.6',
#  '4cv * DECOUVRABLE',
#  'Spider Sport',
#  'Mégane',
#  '2.0 Coupe-Cabriolet Confort Dynamique',
#  'Coupe 2.0 16v T RS 250cv LEGGERE BENE !!!',
#  'Cabrioni cabriolet, 1.2',
#  'Cabrio H.Kennz. EINMALIG',
#  'CC 1.5 dCi 110 FAP GT Line EDC 2015',
#  'Mégane C.C. 1.5dCi Dynamique',
#  'SporTour 1.9 dci Dynamique 130cv fap',
#  '1.6-16V Privilège',
#  '1.6 Dynamique',
#  'II CC 1.9 dCi 130 FAP Privilège',
#  '2.0 Coupe-Cabriolet Privilege',
#  '1.5 dCi 110CV S-S 4p. Express Ice',
#  'ACL  Cabrio   Rodeo',
#  '1.9 dCi FAP Coupe-Cabriolet Dynamique',
#  'R19 Cabriolet 1.8',
#  '1.2 75CV GPL 5 porte Wave 201407',
#  'FLORIDE ( con hard top)',
#  'Megane SporTour 1.5 dci Gt Line 110cv',
#  'GTA V 2.5 V6 Turbo consignatie verkoop/Valckenier',
#  'Coupé RS 2.0 16v 265 S&S',
#  'Tbo GT  S',
#  'Williams Phase 2',
#  'tce 140 edc fap',
#  'tce 140 edc fap - 21b',
#  'A PREPARER',
#  'Deportivo Automático de 3 Puertas',
#  'CoupÃ© 2.0 dCi 150cv 2p #LIBRO, NAVY, BLUETOOTH',
#  'anterior TCe GPF Energy Limited 66kW',
#  'Zen',
#  'TCe 115 Expression Energy SANDS 85 kW (115 CV)',
#  'anterior TCe Limited 55kW',
#  '1600 S',
#  'Europa Cup',
#  'Renault Megane 1,5 dCI Energy Limited S&S 95',
#  'Group 4 * Roadlegal *',
#  'GTS',
#  'RENAULT ALPINE GTA 19900 EURO PRIVE',
#  '3 coupe III COUPE 2.0 DCI 160 FAP GT EURO5',
#  'A 310',
#  'TURBO 1',
#  'Megane coupe manual 2.0 dCi',
#  'SporTour 2.0 dci 4Control esm 150cv',
#  '45 ELECTRIQUE',
#  'Coupe Energy dCi 110 FAP Start & Stop GT Line',
#  'TR',
#  'v6 fase2    -   65000km',
#  'Mégane Sport R.S. 265 Stop&Start Start&Stop',
#  'Tbo',
#  '2.0 T RS',
#  'GT 18Fuchs/Ablage-/Sichtpaket',
#  'Rs',
#  'Turbo Maxi 2 Gruppo B Omologata Stradale',
#  'Coupe 2.0 16V Turbo GT',
#  '*Turbo*Sammler*Edelstahlauspuff*',
#  'II 3.0 V6 Sport',
#  'Coupe Energy dCi 130 FAP Start & Stop GT Line',
#  'ARKANA E-Tech 145 - 21B R.S. Line',
#  'A310,Devil Auspuff,HKennz.,15" Gotti,TÜV neu!!',
#  'tce 160 edc fap - 21b',
#  '1.9 dCi Expression',
#  'Coupe dCi 175 FAP',
#  'RENAULT CLIO V6 SPORT "PHASE 2"',
#  '1.0 TCE 74KW BUSINESS 5 PORTE',
#  'Coupe 2.0 dCi 150ch Monaco GP',
#  'Technik 80 Z.E14.04.2014',
#  'TCe 160 EDC GPF BOSE EDITION',
#  'Coupe 2.0 dci Wave Edition 150cv',
#  'COUPE 1.6 dCi 130 FAP Energy Bose eco²',
#  'Fleischmann',
#  'dCi 110 FAP Coupe Dynamique',
#  '1.6 E-Tech R.S.Line 105kW',
#  'Limited',
#  '1.3 TCe R.S. Line EDC 103kW',
#  'Zen E-TECH Híbrido 105kW(145CV)',
#  'dci 90',
#  'e-tech 145 - 21',
#  'Bose Edition 2.0 dCi 150cv 4x4',
#  'blue dci 115',
#  'tce 160 edc',
#  '1.5 BLUE DCI 115CV BUSINESS',
#  '1.2 VOOR EXPORT',
#  'V INITIALE PARIS 1.6 DCI 160CV AT6',
#  'S.T E-TECH Intens 117kW',
#  '1.8 TCe SL Icon EDC',
#  '1.6  dCi 130',
#  'S.T. 1.5dCi Blue Intens 85kW',
#  'S.T. E-TECH Zen 117kW',
#  'S.T. 2.0dCi Blue Zen EDC 147kW',
#  'Ini. P. Blue dCi 139 kW (190CV) EDC',
#  '4P 1.6 DCI 130CV',
#  'Life',
#  'ZEN ENERGY dCI 81 KW 110 CV EDC 5',
#  'grand scénic dci 130 energy fap eco2',
#  'Zen Energy dCi 81kW (110CV)',
#  'S.T. 1.5dCi Energy Tech',
#  'blue dci 150',
#  'estate dci 130 energy',
#  'Luxe Privilege 2.0 16V EU4',
#  'Zen Blue dCi 88 kW (120CV) - SS',
#  'S.T. 1.8dCi Blue GT Line EDC 110kW',
#  'mégane iv estate blue dci 115 - 21b',
#  'BUSINESS BLUE DCI 70 KW 95CV',
#  '1.5 DCI TECH ROAD ENERGY 110CV',
#  '1.8 RS Energy Tce 205kW 280cv',
#  'RS Trophy Energy 162kW (220CV) EDC',
#  'LIMITED BLUE DCI 88 KW 120CV',
#  '4 Energy dCi 55kW (75CV) Business',
#  'Zen TCe GPF 74 kW (100CV)',
#  'Init. P. Blue dCi 118 kW(160CV) EDC SS',
#  'INTENS R135 B-Rent',
#  'TR -Prima G-Kat',
#  'Energy TCe 120 EDC Euro 6 Intens',
#  'Limited Energy TCe 66kw (90CV) eco2',
#  '1.9 dCi/130CV 4p. Dynamique',
#  'Renault 18 Turbo',
#  'BOSE Edition',
#  '22 kwh Zen batterie ok',
#  'ii 1.2 lev 16v 75 eco2',
#  '1.6 Plug-in Hybrid E-TECH 160 R.S. Line EDC',
#  '1.2 energy tce 130  limited',
#  'dci 130 energy intens / origine france',
#  '1.5 dci - 90ch   iv berline business',
#  '4 IV (BFB) 1.8T 280CH RS EDC',
#  'RS',
#  '1.5 DCI 110 BUSINESS GARANTIE 12 MOIS',
#  '4 Energy dCi 75 eco2 Euro 6 Business',
#  '1.2 TCe 115 SS Energy Expression',
#  '1.5BlueHDi S&S GT EAT8 130',
#  '/ Automatik/ 1 Hd/el.FH/Original zustand/',
#  '1.6 Hybrid Allure Pack EAT8 180',
#  '1.2 Puretech S&S Allure Pack 100',
#  '1.5 BlueHDi S&S Active Pack 100',
#  'Pequeño Manual de 5 Puertas',
#  '1.5 BlueHDi S&S GT Pack EAT8 130',
#  '1.2 PureTech S&S Allure Pack 130',
#  '1.5 BlueHDi S&S GT EAT8 130',
#  '1.2 PureTech S&S Active Pack 110',
#  '12V VTi 82CV 5p. Active',
#  'VTi 52kW (72CV) Allure',
#  '1.2 PURE TECH ACTIVE 75 CV',
#  'Allure Long PureTech 110',
#  '1.2 PureTech S&S GT EAT8 130',
#  '1ste Eigenaar 134.000km Garantie+Keuring',
#  '1.6 Hybrid GT EAT8 225',
#  '1.6 GTI *Originalzustand*',
#  '1.2 Puretech S&S Allure Pack EAT8 100',
#  '1.4Diesel !!!75.000km!!! GARANTIE + KEURING',
#  '1.2 Puretech S&S Allure Pack EAT8 130',
#  'Allure Pack Eléctrico 100kW',
#  'WAGON Business 1.6 8v e-HDi 115cv S/S',
#  'CC 1.6 HDI 112 FAP',
#  'Cabriolet ROLAND GARROS Paris Capote électric',
#  '206 CC Roland Garros',
#  '1.1i cat Cabriolet CJ',
#  '207 CC 1.6 16v 120ch',
#  'Cabriolet 2 l',
#  'CC Sport 1.6 VTI 120',
#  'CC 1.6 VTI 16V 120',
#  'Cabrio 1.6 THP Sport Pack 115 kW (156 CV)',
#  'CC 1.6',
#  'CC 1.6 THP Edition Limitada 150CV',
#  'CC Cabrio 2.0 HDI Sport 140CV',
#  'CC Cabrio 1.6 VTi Sport 122CV',
#  'CC 1.6 VTi Active 120 CV',
#  'CC 1.6 VTi 120cv SPORT 2p #BLUETOOTH',
#  'CC HDI 136 FAP',
#  'cabriolet $$je recherche en état ou a refaire$$',
#  'CABRIOLET (pininfarina!)',
#  'Cabriolet Injection',
#  'CC 110 Quiksilver',
#  'GTI',
#  'CC 2.0 Sport 180',
#  'CC HDi FAP 140 Premium',
#  '206CC',
#  '2.0 HDI 120CV DISTRIB OK',
#  '1.6-16V',
#  'CC FAP 110 (Blue Lion) Filou',
#  'cabrio',
#  'CC 2.0 HDi 16V 140 ch FAP Féline 7',
#  '2.0-16V',
#  '1.6-16V Roland G.',
#  'CC 2.0 16V',
#  'CC',
#  '1.6 Vti Cabrio 2008 Zwart',
#  '<NULL',
#  'CC 135',
#  'CC e-HDi FAP 110 Start&Stop Active',
#  'CC 110 Roland Garros',
#  '1.4i Cabrio oldtimerkeuring + 1JAAR garantie!',
#  'CABRIOLET (KF2)',
#  'CC HDi FAP 110 Premium',
#  '1.6-16V T Roland G.',
#  'Cabriolet 1.8',
#  '206CC Hardtop Cabriolet',
#  'Automatik Leder',
#  '1.3i Rallye',
#  'Coupé 2.0l - Garantie 12 mois',
#  '1.6 THP 155cv',
#  '1.6 THP',
#  '2.0 HDi  163 CV',
#  '2.0 HDi 163 CV',
#  'Coupé Ultima Edizione HDi Pack 136',
#  'CoupÃ© 2.2 163cv 2p #LIBRO',
#  '2.7 V6 hdi 24v Feline auto fap',
#  '1,6 THP 160',
#  'GTI 16V ( vraie et bleu Miami !! )',
#  '3.0-24V V6 Pack',
#  "201 '30",
#  '5p 1.4 vti 16v XS',
#  '16 GTI',
#  'Coupe "S" ( 1974 )',
#  'cc roland garros 1.6hdi 112 fap',
#  '2.7 V6 HDI FELINE BAA FAP',
#  '2.0i 16V cat Coupé',
#  'Coupe 165 Sport',
#  'SW 2.0 hdi 16v Tecno Ciel fap',
#  'GTI 1.9 130 CV--ASI ORO--ORIGINALE--PARI AL NUOVO',
#  '3.0i V6 24V cat Coupé Plus',
#  "3.0i V6 24V cat Coupé Plus Settant'anni",
#  '1.6 thp 16v 156cv auto',
#  '2.0 HDi FAP 160',
#  'GTI 1.6 THP S&S 3 porte',
#  'Active BlueHDi 120cv S&S 5 PORTE BERLINA',
#  '1.6 thp 16v 200cv',
#  '007 2.2-16V Pack ( heerlijke wagen! )',
#  '1.6 155 THP',
#  '3p 1.6 16v XS',
#  'Plus 3p 1.1 X-Line eco-Gpl',
#  '1.5BlueHDi Active Pack S&S 130',
#  '1.6 BlueHDi 88KW (120CV) S&S Allure',
#  'BlueHDI 81kW (110CV) Active',
#  'HYB PHEV 225 Allure Pack e-EAT8',
#  '1.2 PureTech S&S Allure Pack EAT8 130',
#  '1.5 BLUE HDI 130 CV EAT8 ALLURE',
#  '1.5 BLUE HDI 130 CV ACTIVE PACK',
#  '1.6EHDI 115CV ALLURE 5P',
#  '300 e-EAT8 Allure Pack',
#  'ALLURE HDI 130 CV',
#  '1.6 THP 156cv -',
#  '1.2 PureTech 96KW S&S Active Pack',
#  'BlueHDI 130 S&S EAT8 Allure',
#  '1.5BlueHDi S&S Roadtrip S&S EAT8 130',
#  'BlueHDI 130 S&S EAT8 Allure Pack',
#  'BlueHDI 81kW (110CV) Allure Pack',
#  '1.2 PureTech SS Allure',
#  '1.5 Blue-HDi GT Line',
#  'GT LINE 1.2 PURE TECH 130 CV',
#  'ALLURE',
#  'Puretech 100 S&S 6 Vel. MAN Active Pack',
#  'GT-Line BlueHDi 96kW (130CV) S&S EAT8 GT Line',
#  '1.6 BlueHDi 88KW 120CV Allure SS',
#  '1.2 PURETECH 100 S&S ACTIVE PACK 5P',
#  '1.5BlueHDi S&S Allure 100',
#  'BlueHDI 100 S&S BVM6 Allure',
#  '1.5BlueHDi S&S GT Line 100',
#  '1.5 BlueHDi 96kW S&S  EAT8 Allure Pack',
#  'Confort 1.6 HDI 110 FAP',
#  'Active 1.6 BlueHDi 100',
#  '1.5 BLUEHDI 96KW ALLURE S&S 5P',
#  '1.2 PureTech S&S Active Pack 100',
#  '1.2 PureTech S&S Active 100',
#  '1.5BlueHDi S&S Allure Pack EAT8 130',
#  '1.5 BLUEHDI 96KW S&S ALLURE 5P 7 Plazas',
#  '1.5 BlueHDi 96kW (130CV) S&S Active Pack',
#  'HYB PHEV 300 GT AWD e-EAT8',
#  '225 e-EAT8 Allure Pack',
#  '1.6 e-HDi 92 Allure',
#  '1.2 S&S PureTech Allure Pack EAT8 130',
#  '2.0 bluehdi 150ch s\\u0026amp;s bvm6 allure / suivi',
#  '1.2 PureTech 96KW (130CV) S&S Allure',
#  '1.2 PURETECH 96KW S&S ALLURE 5P',
#  'Puretech 100 S&S BVM6 Active Pack',
#  '1.5bluehdi active s&s 130',
#  'BlueHDi 96kW (130CV) S&S EAT8 Allure',
#  'SW 1.6 Hybrid GT Pack EAT8 225',
#  'SW  HYBRID 225 e-EAT8 GT',
#  '5p Active 1.4 HDi 70 FAP',
#  'SW 1.2 PureTech S&S Active Pack 110',
#  'GT Long BlueHDi  96kW',
#  '1.5 Blue-HDi Access Standard',
#  '1.5 Blue-HDi Access L1',
#  'Active Standard BlueHDi 73kW',
#  'SW GT Line 1.2 PureTech 96KW (130CV)',
#  '1.2 PureTech EAT8 GT Long 7 plazas',
#  'SW GT HYBRID 180 e-EAT8',
#  'SW ACTIVE 1.6 BLUEHDI 88KW 120CV',
#  'SW PSE Hybrid 360 Automatik 8-Gang',
#  'SW  BlueHDi 130 S&S GT',
#  'SW  PureTech 130 S&S 6 Vel. MAN Style',
#  '2.0 bluehdi 180ch eat6 / suivi entretien complet à',
#  '1.2i puretech 130  gt line',
#  'SW 1.2 PureTech S&S Allure Pack EAT8 130',
#  'standard 1.5 BLUEHDI gt line 130 eat8',
#  '5p XT 2.0 HDI 136 FAP',
#  '1.6 hdi 16v Lee',
#  'SW  BlueHDi 130 S&S EAT8 Style',
#  'SW Hybrid 225 GT e-EAT8',
#  '308 BlueHDi 180 EAT6 S&S SW GT',
#  '1.5 BLUEHDI 96KW ALLURE AUTO SW 5P',
#  '5p GT Line 1.2 PureTech 130 S&S',
#  'SW  Puretech 130 S&S EAT8 GT',
#  '1.5 BLUEHDI 96KW STYLE AUTO SW 5P',
#  'SW Active Pack Puretech 130 S&S MAN',
#  'RXH 2.0 BlueHDi 180CV Autom.',
#  '2ª serie PureTech Turbo 130 S&S SW Allure',
#  'SW  1.6 BlueHDi 88KW (120CV) Active',
#  'Style 1.6 BlueHDi 120 FAP',
#  'SW  PureTech 130 S&S EAT8 Active Pack',
#  'SW GT Pack BlueHDi 130 Automatik 8-Gang',
#  'II Ph2 1.5 BlueHDi 130 S\\u0026S GT Line BA8',
#  'ACTPK PT100',
#  '1.5 Blue-HDi GT Line Standard',
#  'SW  Hybrid 225 eEAT8 GT',
#  '1.5 BLUEHDI ALLURE 130 standard',
#  '5P PSE HYBRID 360 e-EAT8',
#  '5P PSE HYBRID 360 e-EAT8  Sport Engineered',
#  'Hybrid 225 GT e-EAT8',
#  '403 Oldtimer/ Sammler /Rarität/Black Panther/',
#  'Berline Bj.1956',
#  'Hybrid 225 Allure Pack e-EAT8',
#  '1.5 BLUEHDI 96KW TECH EDITION 5P',
#  'Active BlueHDi 96kW (130) S&S 6vel MAN',
#  '5P ACCESS 1.2L PureTech 82',
#  '1.6 HYBRID 225 ALLURE PACK E-AUTO 225 5P',
#  '1.6 PHEV 225 E-EAT8 GT 225 5P',
#  '1.2 PureTech S&S Active Pack EAT8 130',
#  'PureTech 96kW (130CV) EAT8 GT Line',
#  '5p  BlueHDi 130 S&S Active',
#  '5P  BlueHDi 130 S&S EAT8 Allure Pack',
#  '5P  PureTech 130kW (180) S&S EAT8 Active',
#  'Active BlueHDi 96kW (130CV) S&S EAT8',
#  '1.5 BLUEHDI 130 ALLURE AUTO 5P',
#  '16V SR',
#  '5P  BlueHDi 120kW (160) S&S EAT8 GT Line',
#  '1.5 BLUEHDI 73KW GT LINE 5P',
#  '1.5 HDI 100cv',
#  'PureTech 73kW (100CV) Active Pack',
#  '2.2 Sport',
#  'Tbo Inj Ti',
#  'BlueHDi FAP 100 Stop & Start Active',
#  '1.6 e-HDi 112 CV ca. rob. S&S Active',
#  '5P ACCESS 1.6 BLUEHDI 75',
#  '5p 1.5 bluehdi allure s&s 130cv eat6',
#  '403 Berlina',
#  '5P Allure Pack Puretech 130 S&S MAN',
#  'GLS 1,5',
#  '2.3d GL Neuer Motor Neue Innenausstattung',
#  '1.5BlueHDi S&S Business Line EAT8 130',
#  '1.5 BlueHDi Allure S&S 130',
#  'business line bluehdi 130 eat8',
#  '1.6 PureTech GT Line 5p',
#  '1.5 BLUEHDI 96KW ALLURE 5P',
#  'GT LINE PURETECH 130 EAT8',
#  '5P  PureTech 130 S&S EAT8 Active Pack',
#  '5P  Hybrid 225 eEAT8 GT',
#  '1.5 BlueHDi 130 ALLURE S&S EAT8',
#  '5p  PureTech 110 S&S Allure Pack',
#  '1.4 3 porte Roland Garros',
#  'Active',
#  '1.5 BlueHDi 130 allure S&S EAT8',
#  '5P Active Pack PureTech 130 S&S EAT8',
#  '5P  Hybrid 180 eEAT8 GT',
#  '5P  BlueHDi 130 S&S EAT8 GT',
#  'GT BlueHDi 130 EAT8 S&S aut.',
#  'puretech 68ch bvm5',
#  '500e 3+1 87Kw La Prima',
#  '1.0 GSE Lounge',
#  'Pequeño Manual de 3 Puertas',
#  '500e 87Kw Icon',
#  'Wenig Km 8-fach TÜV 10.2023',
#  '1.0 Hybrid Dolcevita 52kW',
#  '1.0 Gse City Cross Hybrid',
#  "Coupe' Prototipo Motore Ferrari 8.32",
#  'Abarth 595 Tourismo 1.4 Turbo-Jet 165 BVA',
#  'FSM',
#  'P Polski Komplett Restaurierter Fiat',
#  'turbo i.e. cat 3 porte Racing GIANNINI',
#  '1.3 MJT 95 CV S&S Lounge',
#  '4x4 Trekking Country Club',
#  'Dynamic 1.4 16v Starjet 95',
#  '1.0 hybrid Lounge 70cv',
#  '1ª serie 1100 i.e. cat 4x4 Country Club',
#  '110F',
#  '1.2 GASOLINA 60 CV 5P',
#  'LOUNGE FULL OPZIONAL CON TETTO APR ELET PRONTI VIA',
#  '1.2 70CV LOUNGE 3P',
#  'GIANNINI',
#  'e',
#  '500Ce 87Kw Icon',
#  '1.0 Hybrid 51KW (70 CV) Sport',
#  '1.2 8v 51kW (69CV) Lounge',
#  '2000 Turbo * Herbst Special *',
#  '2.0 Automatik 76\u202fkW (103\u202fPS), Automatik, Fronta...',
#  'Descapotable Manual de 2 Puertas',
#  '2+2',
#  '522L Cabriolet',
#  'Fiat 850 Spider',
#  'Savio Jungla Junglaboo H-Kennzeichen TÜV neu',
#  '1.2 Lounge 69cv',
#  'D  RESTAURO TOTALE',
#  '1.8 16v GPL',
#  '595c 1.4 16v t. t-jet turismo 160cv mta e6',
#  'Lusso',
#  'E 3+1 ICON 320KM 87KW',
#  'Lounge 1.2 8v 51KW (69 CV)',
#  'C 1.2 8v 51kW (69CV) Lounge',
#  'C 1.2 8v 69 CV Pop',
#  'C Lounge 1.2 8v 51KW (69 CV)',
#  'C 1.2 8v 69 CV Lounge',
#  'C 1.2 8v 51kW (69CV) S',
#  'BEV 24KWH RED 95 2P',
#  'Coupé',
#  '1973 FIAT COUPE',
#  'Rally',
#  'Coupe Klima',
#  '850c coupe',
#  '128 A1 Coupe Moretti 1300',
#  '2400 Vollrestauration',
#  'Nuova SPORT - limitata',
#  'Abarth Rally Gruppe 4 Stradale',
#  'Fiat 124 BC1 , BJ. 1971',
#  '2300 S Coupe',
#  'Fiat Coupè 1987 - 16 valvole - 180cv',
#  '1300 coupe Raritat',
#  '1800',
#  '2300 S COUPÈ',
#  'Fiat - 1500 cabriolet',
#  'Eveline',
#  'coupè',
#  '1995ccm TURBO 140KW, 190PS Motor: 175A1.000',
#  '1800 sport',
#  '"74 IN ECCELLENTI CONDIZIONI !',
#  'Other Coupè 2.0 i.e. turbo 16V Plus',
#  'Coupe 2.0 16v turbo Plus ASI permute storiche',
#  'Coupe 2.0 20v turbo iscritta ASI',
#  '1300 mirafiori cl 2 porte',
#  'coupe',
#  '2.0 Turbo 16v',
#  '2,0 20V Turbo Limited Edition',
#  '2400 coupe',
#  'Spider 124 Sport 1.6',
#  'Coupè',
#  'SPORT !!!! IN PERFETTE CONDIZIONI',
#  'Coupè del 1970 "Auto d\'Epoca"',
#  'Lightweight Hans Brösch',
#  '850 Coupè',
#  '2.0 Coupé ',
#  'Coupe ( SL )',
#  'S COUPE',
#  'Fiat 124 ac COUPE’ 124 sport',
#  'sport',
#  'Sport',
#  'Fiat Dino Coupe 2.0',
#  '2.0 20v turbo Limited Edition n.1540',
#  '2.0 16v turbo Plus',
#  '2300 S',
#  '2.0 20v turbo',
#  '2300 Coupé Ghia',
#  'Icon 42kWh, Navi, Camera',
#  '2.0 16v turbo Plus c/airbag/rate/permute/garanzia/',
#  '2.0 20v',
#  'ABARTH  1000 ot  valuto  permuta',
#  '850 Coupe 1.Serie ,TÜV+H-Zulassung neu',
#  'SISLEY 4X4',
#  'Mirafiori s',
#  '*Fiat 850 Coupe´Serie 1*TÜV+H*',
#  '2.0 16V Turbo',
#  'Coupe 2.0 16v turbo Plus',
#  '20 valvole plus',
#  '1.8-16V',
#  'Sport 70HP *26TKM*',
#  '2,0 16V',
#  "COUPE' 2000",
#  '1500 VIGNALE 1Â° SERIE',
#  'COUPE',
#  'Barchetta 1.8 16v',
#  'Special',
#  '2.0 i.e. 20V * 63.000KM * TAGLIANDATA FCA *',
#  "1100/103 TV COUPE' PININFARINA",
#  'Coupe 1.8 16v',
#  'Barchetta LIMITED EDITION',
#  '4x4 Sisley',
#  '130 TC ABARTH',
#  'Original Zustand',
#  'Lombardy my car sporting very rare',
#  '2000 Coupè Bellissimo',
#  'coupé condizioni uniche libretto tagliandi!',
#  'COUPE 1a SERIE',
#  '1.8 131CV',
#  'COUPE SL 1100 iscritta ALBO STORICO FIAT 2022',
#  '1000 OT  4 FARI',
#  '2400 Coupé Ferrari ASI',
#  "VIOTTI SPECIAL COUPE' restauro completo con doc",
#  '2.0 i.e. 16V Confort',
#  'R',
#  'F',
#  'RIVIERA CLIMATIZZATA ORIGINALE ASI CRS',
#  'Coupe',
#  'Vignale',
#  '2000 Motore Ferrari Prima Serie PERMUTE RATE',
#  '900 DA COLLEZIONE',
#  'BEV La Prima **PROMPT LIEFERBAR**',
#  'ufficiale 1971',
#  '1.2 69cv 500s',
#  '2.0 i.e. 20V',
#  'COMPLETAMENTE RESTAURATA-MOTORE NUOVO',
#  'Fiat 126P',
#  'MY21 1.0 GSE Hyb. Dolcevita',
#  'Firefly 70 LOUNGE *AKTION*',
#  '1.8 i.e. 16V',
#  '1.3 MultiJet Lounge 95cv S&S EU6 5 PORTE BERLINA',
#  'Cross 1.6 MultiJet 88kW (120CV) 4x2',
#  'Sport 1.3 Firefly T4 110KW S&S DCT',
#  'Dolcevita Sport 1.5 Hyb. 97kW(130cv)DCT',
#  'City Cross 10GSE T3 88kW 120CV SS',
#  '1.3 MJet 70kW (95CV) 4x2 Pop Star',
#  '1.0 City Cross',
#  '1.6 Mjet 88KW (120hp) S&S Cross',
#  '1.MULTIJET URBAN FWD',
#  'Urban 1.3 MultiJet 70KW (95 CV) 4x2 S&S',
#  '1,0 Firefly T3 88KW (120 CV) S&S Connect',
#  'X 1.6 E-TorQ EVO Pop Star',
#  'Cross My21 0.9 Twinair Turbo 85cv S&S 4x4 Cross',
#  '1.5 Hybrid Red DDCT',
#  'Urban AWD 2.0 16v 170cv Diésel auto.',
#  '1.0 FIREFLY T3 88KW SPORT 120 5P',
#  'Red 1.5 Hybrid 97kW (130cv) DCT',
#  'S5 SPORT 1.0 T3 120CV',
#  '1.6 E-Torq 110 CV City Cross',
#  'Pop Star 1.6 MultiJet 120cv 4x2',
#  'Cross 1.6 MultiJet 120cv 4x2',
#  '1.0 120CV 120 ANIVERSARIO',
#  'NUEV  URB 1.0 GSE 88KW 120',
#  'Dolcevita SS Edition 1.0 Firefly T3 88KW',
#  'HEY GOOGLE 1.0 88KW 120CV',
#  '1.0 Sport 120cv',
#  'City Cross 1.6 MJet 88kW (120CV) DCT 4x2',
#  '1.0 Firefly S&S Dolcevita Red',
#  'Lounge 1.4 MAir 103kW (140CV) 4x2',
#  '1.6 POPSTAR',
#  'S5 CROSS 1.0 T3 120 CV',
#  'Cross 1.6 Mjet 88KW (120hp) S&S',
#  'Sport 1,0 Firefly T3 88KW (120 CV) S&S',
#  '1.6 E-torQ Urban',
#  'Cross 1.6 Mjet 96KW (130 CV) S&S',
#  'Lounge 1.0 Firefly T3 88 kW (120CV) S&S',
#  '1.6 ETorq Mirror',
#  'Lounge 1,0 Firefly T3 88KW (120 CV) S&S',
#  'Cross Plus 1.6 MJet 88kW (120CV) DCT 4x2',
#  '1.0 Firefly SS 120th',
#  '1.0 Turbo Urban',
#  '1.6 MultiJet 88 kW (120 CV) Cross',
#  'SW STATIONWAGON E6D 1.3 MIRROR',
#  'SW 1.3 MJT 95CV S/S LOUNGE',
#  '1.0 100 ch S/S sw cross Red MY22',
#  'Pop Star 1.4 16v 70kW (95CV)',
#  'STATION WAGON 1.0 100cv CityLife',
#  'Sedici 1.6 16v Dynamic 4x4 107cv',
#  'SW LIFE 1.0 73KW (100CV) BZ',
#  '1.4 120CV GLP',
#  'Urban 1.6 16v Multijet II 120CV S&S',
#  'Fiat 1500 Familiare OSI',
#  '3p 1.4 95cv Feel',
#  '1.6 Active 105 CV Multijet ECO',
#  '1.6 16v Multijet 88kW (120CV) S&S Lounge',
#  'Pop Star 1.3 16v Multijet II 95CV auto.',
#  'S1 SW 1.6 120 CV LOUNGE AT',
#  '1.6 16v Lounge 120 CV diesel Mjet II SW',
#  '1.6 16v MJet 88kw 120cv  SS Trekking',
#  '1.9 Multijet Dynamic',
#  '2 1.6 16v Pop 88kW (120CV) Mjet. Business',
#  'SW 1.6 Multijet 88kW (120CV) Mirror',
#  'Autobianchi Bianchina Panoramica 2. Hand',
#  'Cross 1.4 16v 70 kW (95 CV) S&S',
#  'RED 1.4 MPI 95HP',
#  '1.6 Lounge 88kW (120CV)diesel Mjet II SW',
#  'Easy 1.3 Mjet 59kW (80CV)',
#  '1.3 16v Multijet 70kW (95CV) S&S Lounge',
#  'Pop Star 1.6 16v Mjet 88kW (120CV) S&S',
#  '5P 1.3 Multijet 70kW (95CV) Mirror',
#  'Pop Star 1.3 16v Multijet II 85CV S&S',
#  '5p 1.4 16v 70 kW (95 CV) Lounge Plus',
#  '1.4 16v Lounge 70kW (95CV) gasolina SW',
#  '1.4 95cv Easy #LIBRO, BLUETOOTH',
#  'City Cross 1.6 E-Torq 81kW (110CV) 4x2',
#  'SW 1.4 Fire 70kW (95CV) Pop',
#  'SW 1.3 Multijet 70kW (95CV) Mirror',
#  '1.3 16v Multijet II 85CV Start&Stop',
#  'Connect 1.4 16v 70 kW (95 CV) S&S',
#  '1.3 16v Mjet 70kW (95CV) S&S City Cross',
#  '1.4 16v 95CV',
#  '1.4 8v 57kW (77CV) Lounge',
#  'Pop Star 1.4 16v 95CV',
#  'My Life 1.6 Multijet 105 CV',
#  'Combi SX 1.3 Mjt 75cv 5plazas E5+',
#  '1.4 Lounge',
#  'Easy 1.4 Natural Power 52kW (70CV)',
#  '1.6 Multijet 105cv 5p S/S #LIBRO, BLUETOOTH',
#  'SW 1.6 Multijet Life 95KW',
#  'SW 1.0 Life',
#  '1.2 51 kW (69 CV) Lounge',
#  '1.4 16v 70kW (95CV) Cross',
#  '1.3  70kW (95CV) diesel Mjet. SW Easy',
#  '1.0 Hybrid 51 KW (70 CV) Lounge',
#  '1.2 51 kW (69 CV) Mirror',
#  'CROSS 1.5 HYBRID 130CV',
#  '1.2 69CV',
#  '1.2 8v 69 CV Lounge',
#  '1.2 Lounge 51kW 69CV',
#  '1.2 lounge',
#  'Lounge 1.0 6v GSE 52KW (70 CV)',
#  '1.0 hybrid',
#  '1.2 Lounge 69cv EU6',
#  '2.0 i.e. 16V cat',
#  'A',
#  '1100D',
#  'E E RED 118CV',
#  'Ritmo 130 TC 3 porte Abarth',
#  '1.1 i.e. cat 5 porte S Eleganza - 1 PROP- Perfetta',
#  '13 sport 95 cv multijet e5 ss',
#  '1.3 MJT II S&S 95 CV Euro 6',
#  'BERLINA',
#  'Panda 1.1 Trekking 4x4',
#  'HB City Life 1.6 96kW (130CV)',
#  '4p 1.4 Easy 95cv my19',
#  '1.4 95CV HB 5P LOUNGE',
#  'Icon 3+1 320km 85kW (118CV)',
#  '1.0 100CV  - PROMO WOW',
#  '3p 1.0 ie 45cv cat.',
#  '(2007-2016) 1.4 16V Lounge',
#  '650',
#  'Style',
#  '1.0 TSI S&S Xcellence 110',
#  '2.0TDI S&S Style 115',
#  '2.0TDI CR S&S FR DSG-7 150',
#  'Sport Limited',
#  '1.5 TGI S&S XcellenCe DSG-7 130',
#  '1.5 TSI S&S FR 150',
#  'Seat 600',
#  '1.5 TSI S&S Style 130',
#  '2.0TDI CR S&S Style DSG-7 150',
#  '2.0TDI S&S Xcellence 150',
#  '1.0 95CV STYLE 5P',
#  '1.5 TGI S&S Style DSG-7 130',
#  '2.0 TSI S&S Cupra Carbon DSG7 290',
#  '2.0 TSI S&S Cupra R DSG 300',
#  '1.5 TGI GNC S&S Style 130',
#  'ST Style Connect',
#  'Seat 600 D Cabriolet',
#  'Signo',
#  '850',
#  '1.6 TDI 105CV CR DPF 3p. Sport',
#  '128 sport',
#  'SportCoupé Cupra 1,8 TSI Start-Stopp',
#  '1.2 TDI',
#  'Ibiza SC 1.2 70 ch',
#  '1.2 tdi 75 ch',
#  'SportCoupé Reference 1,9 TDI',
#  'SC 1.2i 12V 70 Réference',
#  'SportCoupé Chili 1,2',
#  'SC 1.4i 16V 85 I Tech',
#  'ST 1.4 TSI ACT Start&Stop FR',
#  'SportCoupé 1,2',
#  '1.6 TDI ECOMOTIVE REFERENCE EDITION',
#  '1.6 TDI CR STYLE 115 CV',
#  '2.0 TDI SS Style',
#  '1.5 EcoTSI S&S Style Go DSG',
#  'Style Plus',
#  '1.0 95CV',
#  '1.0 TGI 66kW (90CV) FR',
#  '1.0 TSI 85kW (115CV) DSG FR Ecomotive',
#  '1.5 EcoTSI S&S Style DSG',
#  '1.5 TSI 110kW DSG S&S Style Go L',
#  '2.0 TDI 150cv StSp Xcellence',
#  '1.0 TSI 95 CV STYLE',
#  '2.0TDI CR S&S Style 150',
#  '1.0 TSI 70kW (95CV)  Ecomotive Style',
#  '2.0TDI CR S&S X-Perience XM DSG 150',
#  '2.0TDI S&S FR DSG 4Drive 200',
#  '2.0 TDI DSG Style',
#  '2.0 TDI 150CV ST FR DSG',
#  'ST 1.5 eTSI S&S FR DSG-7 150',
#  'ST 1.6TDI 110CV XPERIENCE',
#  'ST 2.0 TSI 221kW 4Drive DSG S&S Cupra R',
#  'Leon ST X-Perience 2.0 16V TDI 184 DSG 6 4Drive',
#  '2.0 tdi 150 cv 4drive st x-perience',
#  '1.9 TDI 105cv DPF DSG Style',
#  'ST 2.0TDI CR S&S FR DSG-7 150',
#  'ST 1.5 TSI S&S FR 150',
#  'ST 2.0 TDI 184cv 4Drive DSG6 St&Sp X-per',
#  'sportstourer 1.5 tgi fr 130cv dsg',
#  'ST 1.5 EcoTSI S&S FR Fast Edition 150',
#  '1.4 TSI 125cv  Style',
#  '4p 1.9 SDi Stella',
#  '2.0 TDI 140cv Style 5p',
#  '1.6 105 CV Sport',
#  '105CV 1.9',
#  '1.4 TDI 80 CV Reference',
#  '2.0 TDI 140 CV Stylance',
#  'ST 2.0 TSI 221kW (300CV) DSG-6 S&S CUPRA',
#  'ST 2.0 TSI 221kW (300CV) St&Sp CUPRA',
#  'ST 2.0 TSI 221kW 4Drive DSG S&S Cupra',
#  'ST 2.0 TDI 184cv DSG-6 St&Sp FR',
#  'ST 1.6 TDI 110cv St&Sp Style Ecomotive',
#  'ST 2.0 TSI 213kW (290CV) DSG-7 S&S Cupra',
#  'ST 2.0 TSi 290cv Cupra "Orange Edition"',
#  'ST 2.0 TDI 110kW (150CV) DSG-6 St&Sp FR',
#  '2.0 TDI 115 CV S&S Reference 4Kids',
#  '1.4 TDI 90CV REFERENCE PLUS',
#  '1.0 TSI XCellence',
#  '1.5 TGI 96kW DSG-7 S&S FR Fast Edition',
#  '1.6 SIGNO 100CV',
#  '2.0 TSI Cupra 300',
#  '2.0 TSI 280cv StSp Cupra',
#  '2.0 tsi 290 dsg7 cupra',
#  '3ª serie 1.5 TGI DSG 5p. Black Edition',
#  '2.0 TDI 150 DSG fr go l',
#  '1.5 TGI 96kW DSG-7 S&S Xcellence',
#  'IV 2.0 TDI 150 FR DSG7',
#  '1.4 Benzina 5 Porte',
#  '1.2 benzina',
#  '1.6 TDI 70kW (95CV) Reference Plus',
#  '2.0 TSI RS DSG',
#  '1.0 TSI Ambition 81kW',
#  '1.6 TDI 85KW AMBITION DSG 5P',
#  '1.5 TSI STYLE 5P',
#  '2.0TDI Ambition 85kW',
#  'Style 1,0 TSI 81 kW 6-Gang mech.',
#  '1.0+MPI+AMBITION+KLIMA+PDC+SHZ+NSW+MAL+',
#  '1.9 TDI/110 CV Ambiente',
#  '2.0 TDI CR 110KW (150CV) Ambition',
#  '2.0TDI Sport DSG 110kW',
#  'SPACEBACK 1.2 TSI 105 TOUR DE FRANCE',
#  '1.5 TSI Ambition 4x2 110kW',
#  '1.0 TSI Sport 81kW',
#  '1.5 TSI Ambition DSG 110kW',
#  '1.5 TSI Style 110kW',
#  'Pequeño Manual de 2 Puertas',
#  '1.5 TSI Ambition',
#  'Felicia',
#  '1.5 TSI Emotion',
#  '2.0 TSI RS 4x4 DSG 180kW',
#  '1.0 TSI Ambition 81kW DSG',
#  '1.5 TSI Emotion DSG',
#  ...]

# %%
categories_safe = {
    'safety_feature': [     'Abs', 
                        'Driver-Side Airbag',
                        'Electronic Stability Control',
                        'Traction Control', 
                        'Isofix', 
                        'Head Airbag', 
                        'Immobilizer', 
                        'Passenger-Side Airbag', 
                        'Side Airbag', 
                        'Emergency Brake Assistant', 
                        'Lane Departure Warning System', 
                        'Distance Warning System', 
                        'Driver Drowsiness Detection', 
                        'Rear Airbag'], # Safety Features
    
    'lighting_feature': [   'Bi-Xenon Headlights',                                                 
                        'Fog Lights', 
                        'Led Daytime Running Lights', 
                        'Full-Led Headlights',                                               
                        'Adaptive Headlights', 
                        'Led Headlights',  
                        'Daytime Running Lights',
                        'Xenon Headlights',
                        'Laser Headlights'], # Lighting Features
    
    'conv_feature': [       'Central Door Lock With Remote Control',
                        'Central Door Lock', 
                        'Power Steering',  
                        'Alarm System', 
                        'Tire Pressure Monitoring System'], # Convenience Features
    
    'driver_feature': [     'Speed Limit Control System', 
                        'Traffic Sign Recognition', 
                        'Adaptive Cruise Control', 
                        'Blind Spot Monitor'], # Driver Assistance Features
    
    'other_feature': [      'Emergency System', 
                        'High Beam Assist', 
                        'Glare-Free High Beam Headlights', 
                        'Night View Assist'] # Other Features
}
# The overlapping expressions should be written in order of their length.

# %%
# Sure, let's query the key-value pairs of the dictionary in the short description.
for category, keywords in categories_safe.items():
    for keyword in keywords:
        result = df.loc[df[df["safety_&_security"].isnull()].index, "short_description"].str.contains(f"(?i){keyword}")
        print(f"{category} {keyword}: {result.value_counts()}")
# Out:
# safety_feature Abs: False    3130
# Name: short_description, dtype: int64
# safety_feature Driver-Side Airbag: False    3130
# Name: short_description, dtype: int64
# safety_feature Electronic Stability Control: False    3130
# Name: short_description, dtype: int64
# safety_feature Traction Control: False    3130
# Name: short_description, dtype: int64
# safety_feature Isofix: False    3130
# Name: short_description, dtype: int64
# safety_feature Head Airbag: False    3130
# Name: short_description, dtype: int64
# safety_feature Immobilizer: False    3130
# Name: short_description, dtype: int64
# safety_feature Passenger-Side Airbag: False    3130
# Name: short_description, dtype: int64
# safety_feature Side Airbag: False    3130
# Name: short_description, dtype: int64
# safety_feature Emergency Brake Assistant: False    3130
# Name: short_description, dtype: int64
# safety_feature Lane Departure Warning System: False    3130
# Name: short_description, dtype: int64
# safety_feature Distance Warning System: False    3130
# Name: short_description, dtype: int64
# safety_feature Driver Drowsiness Detection: False    3130
# Name: short_description, dtype: int64
# safety_feature Rear Airbag: False    3130
# Name: short_description, dtype: int64
# lighting_feature Bi-Xenon Headlights: False    3130
# Name: short_description, dtype: int64
# lighting_feature Fog Lights: False    3130
# Name: short_description, dtype: int64
# lighting_feature Led Daytime Running Lights: False    3130
# Name: short_description, dtype: int64
# lighting_feature Full-Led Headlights: False    3130
# Name: short_description, dtype: int64
# lighting_feature Adaptive Headlights: False    3130
# Name: short_description, dtype: int64
# lighting_feature Led Headlights: False    3130
# Name: short_description, dtype: int64
# lighting_feature Daytime Running Lights: False    3130
# Name: short_description, dtype: int64
# lighting_feature Xenon Headlights: False    3130
# Name: short_description, dtype: int64
# lighting_feature Laser Headlights: False    3130
# Name: short_description, dtype: int64
# conv_feature Central Door Lock With Remote Control: False    3130
# Name: short_description, dtype: int64
# conv_feature Central Door Lock: False    3130
# Name: short_description, dtype: int64
# conv_feature Power Steering: False    3130
# Name: short_description, dtype: int64
# conv_feature Alarm System: False    3130
# Name: short_description, dtype: int64
# conv_feature Tire Pressure Monitoring System: False    3130
# Name: short_description, dtype: int64
# driver_feature Speed Limit Control System: False    3130
# Name: short_description, dtype: int64
# driver_feature Traffic Sign Recognition: False    3130
# Name: short_description, dtype: int64
# driver_feature Adaptive Cruise Control: False    3130
# Name: short_description, dtype: int64
# driver_feature Blind Spot Monitor: False    3130
# Name: short_description, dtype: int64
# other_feature Emergency System: False    3130
# Name: short_description, dtype: int64
# other_feature High Beam Assist: False    3130
# Name: short_description, dtype: int64
# other_feature Glare-Free High Beam Headlights: False    3130
# Name: short_description, dtype: int64
# other_feature Night View Assist: False    3130
# Name: short_description, dtype: int64

# %%
# Because the "Short_Description" column does not contain any values that are present in the "safety_security" dictionary, 
# then we won't be able to utilize the dictionary in this case.

# %%
# After the groupby operation, how many NaN values do I have remaining?
df['safety_&_security'].fillna(df.groupby(['body_type', 'gearbox'])['safety_&_security'].transform(lambda x: x.mode()[0])).isnull().sum()
# Out:
# 89

# %%
df["safety_&_security"] = df['safety_&_security'].fillna(df.groupby(['body_type', 'gearbox'])['safety_&_security'].transform(lambda x: x.mode()[0]))

# %%
handle_missing_values(df , "safety_&_security")
# Out:
# Missing Values in 'safety_&_security':
# Count: 89
# Percentage: 0.31%

# %%
# After the groupby operation, how many NaN values do I have remaining?
df['safety_&_security'].fillna(df.groupby(['comfort_&_convenience'])['safety_&_security'].transform(lambda x: x.mode()[0])).isnull().sum()
# Out:
# 0

# %%
df["safety_&_security"] = df['safety_&_security'].fillna(df.groupby(['comfort_&_convenience'])['safety_&_security'].transform(lambda x: x.mode()[0]))

# %%
handle_missing_values(df , "safety_&_security")
# Out:
# Missing Values in 'safety_&_security':
# Count: 0
# Percentage: 0.00%

# %% [markdown]
# <a id="10"></a>
# <div class="alert alert-info" role="alert">
# <h1>Column name :<span style="color:red"> extras </span></h1>
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Operation : </b> First, let's leverage <span style="color:red"><b>the dictionary we created in Part 1  </b></span>to examine the short_description. If we find any matching values, let's <span style="color:red"><b>replace </b></span> them with their corresponding keys. Then, <span style="color:red"><b>to prevent duplicates </b></span>, let's convert the expressions within each row into sets and then retrieve them back. Also since the "extras" column is associated with <span style="color:red"><b> " body_type ", " type "</b></span> . let's fill in the <span style="color:red"><b> NaN values</b></span> in this column by grouping the data based on these columns and performing the necessary operations.
# </div>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
first_looking("extras")
# Out:
# column name    :  extras
# --------------------------------
# per_of_nulls   :  % 17.96
# num_of_nulls   :  5138
# num_of_uniques :  31
# NaN                                       5138
# wheel                                     3815
# accessory,wheel                           3050
# accessory,wheel,tires,sport_trim          2717
# accessory,wheel,tires                     2268
# accessory,wheel,sport_trim                1954
# tires,sport_trim,other,wheel,accessory    1824
# other,accessory,wheel,tires               1621
# other,accessory,wheel                      952
# wheel,sport_trim                           949
# other,accessory,wheel,sport_trim           914
# accessory                                  746
# wheel,tires                                514
# tires                                      319
# wheel,tires,sport_trim                     288
# accessory,tires                            247
# sport_trim                                 175
# other,wheel,tires                          133
# other,wheel                                130
# accessory,sport_trim                       130
# other                                      113
# other,accessory                            100
# accessory,tires,sport_trim                  97
# other,accessory,tires                       87
# other,wheel,sport_trim                      87
# other,wheel,tires,sport_trim                83
# tires,sport_trim                            57
# other,tires                                 31
# other,accessory,sport_trim                  23
# other,accessory,tires,sport_trim            20
# other,sport_trim                            14
# other,tires,sport_trim                       7
# Name: extras, dtype: int64

# %%
# To be more thorough, let's check if there are any words in the short description 
# that match the key-value pairs of the dictionary, as a precautionary measure.
list(df.loc[df[df["extras"].isnull()].index, "short_description"].unique())
# Out:
# ['CDi',
#  '350+',
#  'S 4Matic+ 8G-DCT',
#  '200CDI BE Line 4M 7G-DCT',
#  '7G-DCT',
#  'e Limousine',
#  '180d 7G-DCT',
#  '180d Sedán 7G-DCT',
#  nan,
#  'd 4Matic (EURO 6d)',
#  'CDI',
#  'Limousine',
#  '250e 8G-DCT',
#  'CDI Elegance',
#  'd (177.003)',
#  '200d 4Matic 8G-DCT',
#  '200CDI BE AMG Line 7G-DCT',
#  'A-CLASS A180 1.3 136 CV 7G-DCT 5P',
#  '200d Sedán 8G-DCT',
#  'progressive mbux, camera, lane assist, pdc',
#  'S AMG 4MATIC+',
#  'CDI Ambition 4U3 Navigatie',
#  '4-Door 63 S 4MATIC+',
#  '180CDI',
#  '250e Sedán 8G-DCT',
#  'CDI Edition Navigatie 4U3',
#  '4Matic 7G-DCT',
#  '200d 7G-DCT',
#  'd 4Matic AMG Line (EURO 6d)',
#  'CDI 100kW ( 136CV ) Urban',
#  '180 d Sensation 7G-DCT',
#  'e A 250e Progressive Sfeerverlichting / NIEUW GERE',
#  'E 280',
#  '220CDI BE AMG Sport 7G-DCT',
#  'd Premium',
#  '220CDI BE Line 4M 7G-DCT',
#  'Edition 1 4Matic 7G-DCT',
#  '180CDI BE AMG Line 7G-DCT',
#  '220d 8G-DCT',
#  'MERCEDES-BENZ Clase GLK Pequeño  Automático de 5',
#  '200d 8G-DCT',
#  'Pequeño Automático de 5 Puertas',
#  '4Matic Coupe 4Matic+ (EURO 6d-TEMP)',
#  '180CDI Autotronic',
#  '180d 8G-DCT',
#  'CDI Premium',
#  '180CDI BE AMG Line',
#  'CDI Style',
#  '220CDI BE AMG Line 7G-DCT',
#  'Biturbo V-Max',
#  'abrio Mercedes-AMG 4MATIC',
#  'MERCEDES-BENZ Clase SL Descapotable  Automático d',
#  'Cabrio 350BlueTec Aut.',
#  'SL *Pagode*3.Besitz/Dt.Fahrzeug/H-Zul.',
#  'MercedesAMG',
#  'Cabrio Benzine Autom. - airco - Leder',
#  'SL Pagode',
#  'Cabrio 7G Plus',
#  'r107 original belgian delivery! first owner car.',
#  '200K',
#  'Cabrio d',
#  'Deutsches Fahrzeug  Sammlerzustand',
#  'SL Vollrestauration',
#  'Cabrio 220CDI 7G Plus',
#  '-CLASS 6.2 COUPE SPORT AUTO 457 2P',
#  'V12 - Origineel Nederlands -',
#  '200 K.',
#  'GE',
#  'SL',
#  'Cabriolet AMG Line',
#  '(R129)',
#  '(R129) 2nd Owner/Collectable',
#  'Cabrio',
#  'cabrio d  Premium Plus 4matic auto',
#  '220 d executive a',
#  '250 d Sport auto',
#  '220 A Cabriolet',
#  'ROADSTER',
#  '190SL',
#  'S Cabriolet Ponton Typ A (W 180)',
#  'd Cabriolet',
#  'D',
#  '-CLASS 4MATIC',
#  'SEb (111)*DEUTSCHES-FAHRZEUG*H-KENNZEICHEN*TOP-ZUS',
#  'SLC W107 KLIMA+EFH+2. HAND+BLUETOOTH',
#  '4Matic+ 7G-DCT',
#  '220CE',
#  'S Coupe',
#  'Mercedes-AMG S 4MATIC+',
#  '4Matic (EURO 6d-TEMP)',
#  '-CLASS 3.0 4MATIC AUTO 333 2P',
#  'C Coupe*DEUTSCHES-FAHRZEUG*AUTOMATIK*H-KENNZEICHEN',
#  'Coupe AMG + NIGHTPACK - LEDER - PANO DAK - 360° -',
#  'SEC',
#  'Compressor',
#  '220d Aut.',
#  'Coupé d (238.314)',
#  'CE Coupe 4fach-elktr. Fensterheber+elktr. Spieg...',
#  'd 4MATIC -',
#  'coupé 4.0 4MATIC 469 2P',
#  'Coupé 400d 4Matic Aut.',
#  'CDI Chrome',
#  'Coupé d AMG LINE',
#  'd (205.314)',
#  'EQ Boost Aut. (9.75)',
#  'CDI (LA) Sport Edition (203.708)',
#  'Coupé 220d',
#  'COUPE AMG -Line',
#  'CDI Inspiration 7G-DCT',
#  '4MATIC',
#  '220d 4Matic 8G-DCT',
#  '300e 4Matic 9G-Tronic',
#  'd 4Matic All-Terrain Estate Avantdarde',
#  'd 4MATIC',
#  'd 4 MATIC 245cv 9 vel. *IVA deducible* *2020* *Nac',
#  '4Matic 8G-DCT',
#  'd 4Matic (253.915)',
#  'e 4Matic',
#  '300 4MATIC',
#  'D ADVANTAGE + PAQ NIGHT',
#  'Coupé 350D 258 CV',
#  '320CDI Edition 10 Aut.',
#  'Mercedes-AMG 4MATIC',
#  'Mercedes-AMG 4MATIC+',
#  'D 2.2 170CV AUT 5P',
#  '300d 4Matic Aut.',
#  'd',
#  'Estate 200CDI BE Edition',
#  'CLASSE B B 180 d BE Edition',
#  '(+)2.0 AVANTGARDE AUTO 211 5P STATE',
#  'd Estate Avantgarde',
#  'de Estate AMG LINE',
#  'CDI Blue Efficiency Estate',
#  'Estate Estate',
#  'd Estate',
#  '(+)2.1 D AMG LINE 5P',
#  'CLA-CLASS 2.1 D DCT SHOOTING BRAKE 136 5P',
#  'B200 CDI AMG AUT 136CV',
#  '580 4Matic',
#  '9G-Tronic',
#  'CDI BlueEfficiency (204.001)',
#  '1.6',
#  'Mercedes-AM53 4MATIC+',
#  '220d 4Matic 9G-Tronic 194',
#  '220CDI BE Avantgarde 7G Plus',
#  '-CLASS 4.7 455 4P',
#  '220d 9G-Tronic 194',
#  'CDI Business',
#  '-CLASS D G TRONIC PLUS AVANTGARDE',
#  'de',
#  'CLA-CLASS 2.1 CDI DCT 170CV 4P',
#  'BlueTEC Sport',
#  'CLS-CLASS 272 4P',
#  'BlueTEC 4Matic (212.011)',
#  'd AMG Line (EURO 6d-TEMP)',
#  '1.5D 85kW(116ch) AUTO * CUIR * ATT REM * GPS *',
#  '1.3CDTI Business75',
#  '1.2T XHL S/S Edition 100',
#  '1.6T PHEV S/S GS-Line Aut. 180',
#  '1.3 ecoFlex Expression',
#  '1.4 Business 90 (4.75)',
#  '1.3CDTi Cosmo',
#  '1.4 66KW (90 CV) EXPRESSION PRO',
#  '1.2 XEL S/S Edition 75',
#  '1.7CDTi Enjoy 100',
#  '1.6CDTi S/S Selective 110',
#  '1.5D DT S/S GS-Line + 100',
#  '1.6CDTi Business + 110',
#  '1.2T S/S Design & Tech 130',
#  '1.0 Edition EcoFlex 90PK WH98944',
#  'E 1.4 Edition KLIMA PDC SITZHEIZUNG',
#  '1.2 Enjoy',
#  '2.0DTi 16v Sport',
#  '1.0T S/S Selective',
#  '1.2 Essentia (146CO2)',
#  '1.4T Selective',
#  'Corsa-e Elegance-e',
#  '1.5D DTH S/S Elegance 130',
#  '1.2T XHT S/S Elegance AT8 100',
#  '2.0CDTi S/S Selective 165',
#  '1.5D DT S/S Edition 100',
#  '2,2 Excellence 4x4 2011',
#  '1.2-16V Njoy 3DRS MOOI NAP',
#  '1.2-16V RHYTHM',
#  '1.4 Twinport 87ch Start/Stop',
#  '1.4 Selection Airco',
#  'TwinTop 1.4 16V Sport',
#  '2.0 CDTi S/S 165 CV Excellence',
#  'Cabrio 1.6T S&S Excellence Aut.',
#  '1.4 Turbo Excellence',
#  '1.4 T S/S Excellence',
#  '1.4T 140cv Excellence S/S #NAVY, BLUETOOTH',
#  'Descapotable Manual de 3 Puertas',
#  'Twin Top 1.9CDTi Enjoy',
#  'Twin Top 1.8 Enjoy',
#  'Astra F Cabrio',
#  'Twin Top 1.6 Enjoy',
#  '2.0 264 turbo cab / suivi complet opel / 1e main',
#  'Roadster',
#  '2.0 Turbo ECOTEC',
#  '2.0 T',
#  '2.0 Turbo',
#  '2.0 Turbo Pack',
#  '2.2 16v VX 220 VX220',
#  'opel astra h cabrio opc',
#  'Twin Top 1.8 (Enjoy)',
#  '1.4-16V cabrio',
#  '1.8-16V Cosmo',
#  'E Cabrio GSi 2,0 i',
#  'Deportivo Manual de 3 Puertas',
#  'GT/J Sport',
#  'C 2.2 de Luxe',
#  '3 Puertas 1.4T GSI',
#  'GTC 2.0 CDTi 195cv Biturbo 3p S/S #NAVY, BLUETOOTH',
#  'Coupe GS',
#  '2.5i V6',
#  'olimpia record coupe',
#  '19 SR',
#  'Commodore 2.5 GS Coupe Automat',
#  'Olimpia 1.5 Coupe  //Top Zustand//',
#  '3.0 E',
#  '1.4',
#  'A Berlinetta 1,9 S',
#  'GT/E gruppo 2',
#  '1900 S Berlina',
#  'V6 190ps',
#  'opel Astra g coupe project',
#  'Olympia',
#  '1900',
#  'GSE (état concours)',
#  '1200 S',
#  'GTC 1.6 t ecotec Cosmo S s&s 180cv',
#  'B Coupe aus 1969',
#  '1.7 CDTi Enjoy',
#  '1.9 N',
#  'B Coupe',
#  'GTE - CONRERO',
#  'Irmscher GSE Oltimer FIA Liebhaber ',
#  '2.0i 16V cat',
#  '2.2 16V Coupe',
#  'Manta-B',
#  'Twip top 140 ,18',
#  'C1 Coupe 1200H',
#  'coupé',
#  'oldtimer 3.0 6cil GSE 180pk manual gears box',
#  '1.8-16V',
#  'AT',
#  'Coupe 2.0 turbo 16v 200cv',
#  'G Coupé Bertone !',
#  'A 1,6S Original 28300 KM Neuwertig',
#  'GTC 1.7 CDTI 101CV 3 porte Enjoy',
#  '5p 1.6i twinport 16v',
#  'H GTC Edition',
#  '1.8 16V Coupe',
#  '200',
#  'B 1,9 S 1 Hand',
#  '1.4i-16V',
#  '1.4i 16V cat',
#  'Calibra 2.0i 16v Special Edition',
#  'ASTRA GTC 1.4',
#  'Astra Coupe 1.8 16v',
#  '3p 1.4i 16v Club',
#  '1.4 90CV GPL Tech Coupé Advance',
#  'GTC 1.4 Edition',
#  '1.4 Edition',
#  'e    1.4i  32jahre alt  h kennzeichen-möglich',
#  '1.3 CDTI Advance 95cv S/S 5 PORTE',
#  '1.4i 16V',
#  '1.3 CDTI b-Color 75cv 5 PORTE',
#  'PHEV 1.6 Turbo GS Line Aut. 4x2 225',
#  '3.0TD LS',
#  '1.5CDTi S&S GS Line Aut. 130',
#  '1.6 Turbo  Auto 4x4 Ultimate',
#  '1.2T S&S GS Line 130',
#  '1.2 96kW (130CV)  S/S Innovation',
#  '1.2i Edition',
#  '2.2DTI Sport',
#  'Mokka-e GS Line-e',
#  'X 1.6 CDTI 110 CV ECOFLEX BUSINESS EDITION',
#  'GS LINE',
#  '1.5D S&S Business Elegance',
#  '1.2 Turbo Selective',
#  'X 1.6 CDTI Excellence',
#  'X EXCELLENCE',
#  'TODOTERRENO 1.6 CDTI EXCELLENCE 120 5P',
#  '1.6 CDTI EXCELLENCE AUTO 2WD 136 5P',
#  '1.2T S&S Ultimate 130',
#  'Crossland 1.2 Turbo Edition S/S (EURO 6d)',
#  '2.2 DTI Caravan Elegance',
#  'INS-ST INNOV. 1.6D 136CV MT6',
#  '1.6 CDTI TURBO D INNOVATION ST 136CV 5P',
#  'SPORT TOURER 1.2 TURBO 145 CV ELEGANCE',
#  '1.6 CDTi 81kW (110CV) Business ST',
#  'Life 1.2 T S/S   XL Selective',
#  'Sports Tourer 2.0 CDTI 130CV Edition Aut',
#  'Life 1.5 CDTI INNOVATION',
#  'Life 1.5 TD 75kW (100CV) S/S   L Selective',
#  'ST 1.5D DVH S&S Business Edition 122',
#  '1.6 CDTI 100KW EXCELLENCE S',
#  '1.4 Turbo S/S 110kW Innovation Auto ST',
#  'Life 1.5 TD 96kW 130cv SS Edition L',
#  'ST  2.0D DVH 130kW AT8 Business Elegance',
#  'ST 1.6CDTi S/S Selective 110',
#  'Meriva 1,4 Ecotec Turbo Edition|1 BESITZER|VOLLSTÄ',
#  'ST 1.6CDTi Selective 110',
#  'Dynamic 1.4 A6',
#  '2.0 turbo  gsi',
#  'Berlina Manual de 5 Puertas',
#  'E 1.3 CDTI Color Edition Aut. +SHZ+PDC+',
#  '1.2 Twinport ecoFLEX Edition Tüv + Insp.',
#  '1.2T SHR 107kW (145CV) Business Elegance',
#  '1.3 CDTi Business 55kW (75CV)',
#  '1.6CDTI S&S Selective 136',
#  'GS  1.5D DVH 90kW MT6 Business Edition',
#  'GS  2.0T SHT 169kW AT9 4x4 GSi',
#  '2.0 T SHT S&S Business Elegance AT9 170',
#  '1.4T Elegance AUT 5p',
#  '1.5D DVH S&S GS-Line AT8 122',
#  '1.6 Turbo S/S GSi Line',
#  'SEDAN 1.6 CDTI 110 HP EXCELLENCE S',
#  '1 an garantie',
#  '1.4 Turbo Edition Start/Stop',
#  '1.6 CDTI 81KW SELECTIVE 110 5P',
#  'GS 1.6 CDTi 100kW Turbo D Business',
#  '1.2T XHL 74kW (100CV) GS-Line',
#  '1.2i Essentia',
#  '1.4 66kW (90CV) Selective Pro',
#  '1.4 Turbo S/S Sportive',
#  'D 1.2 Edition Lenkradh. Ganzjahresr.',
#  '1.6T Hybrid 132kW (180CV)  Auto GS-Line',
#  '1.5D DVC 77KW 105 5P',
#  '1.0i Enjoy CLIMATISATION BLUETOOTH',
#  '1.2T XHL 74kW (100CV)  Auto Elegance',
#  'rs line',
#  '1.5dCi Energy Zen EDC 66kW',
#  '1.5dCi eco2 Energy Business 75',
#  '1.8 TCe GPF RS Trophy EDC 221kW',
#  '1.5 dCi 110CV Nav',
#  '1.5dCi Energy Business 66kW',
#  '1.5 ENERGY dCI 110 CV AUT',
#  'TCe eco2 Energy Dynamique',
#  '1.5dCi Energy Limited S&S 110',
#  '1.5dCi SS Energy Business 55kW',
#  '1.2 III Authentique*Klima*Multilenkrad*',
#  '1.9dCi Extreme',
#  '1.5DCI Pack Authentique 85',
#  '1.2 TCE Energy Dynamique S&S',
#  '1.5dCi Community',
#  '2.0dCi 16v GT',
#  'TCe GPF Energy Zen 66kW',
#  'limited',
#  'Life 40 R90 68kW',
#  'TCe Energy Limited 66kW',
#  '1.5DCI Expression 85',
#  '1.2 TCe Energy Zen EDC 87kW',
#  '1.2 TCE Energy Limited S&S 115',
#  '1.5dCi Blue Business 85kW',
#  '1.5dCi Expression 110',
#  'E-TECH RS Line 117kW',
#  'TCe Zen 67kW',
#  '1.5dCi Blue Business 70kW',
#  '1,0 Liberty Garantie KLIMA FALTDACH TEMPOMAT',
#  '1.3 TCe 140cv Zen Energy',
#  '1.2 16v Dynamique eco2',
#  'SCe 65 Limited R&GO KLIMA Paket',
#  'TCe Energy GLP Limited 66kW',
#  'TCe GPF Energy Limited 66kW',
#  'Life 80',
#  '1.2 16v Authentique',
#  'SCe Energy S&S Intens 52kW',
#  'Limited 1.0 SCe 75 EU6d-T',
#  '1.2 Authentique',
#  'SCe Energy S&S Limited 52kW',
#  'Electric Zen R80 60kW Batería 20kW/h',
#  '1.2  Faltdach. Cityflitzer. Anfängerauto',
#  '5-Deurs 1.5 Diesel 68PK met garantie',
#  '1.2 Expression 73PK LW80134',
#  '1.9D RN',
#  'Q210 Life Quickcharge 22 kWh (AccuHuur) incl. BTW',
#  '1.8-16V Coupé | Black | 1993 | 56.000 KM',
#  '1.5 dCi Parisienne. MOOIE SMETTELOZE AUTO !',
#  '1.5dCi Energy Dynamique EDC 90',
#  '1.5dCi Energy Business 55kW',
#  '1.5 dci 85 dynamique',
#  '1.5 dCi Parisienne NAVI CLIMA DISTRIBUTIE VERV.',
#  '1.8 16v',
#  '80 INTENS WHITE',
#  '1.5dCi Authentique',
#  '1.5 dCi Dynamique Airco|Cruise',
#  '1.5dCi Emotion eco2 75',
#  '1.5dCi Energy Business 81kW',
#  '1.2-16V Miss Sixty Airco luxe bekleding APK N. DIS',
#  '1.5 dCi ECO Expression 90PK | GC14561 | Navi | Air',
#  'Q210 Zen Quickcharge 22 kWh (ex Accu) Full map nav',
#  '1.2-16V Dynamique Airco',
#  '1.6 Exception Aut.',
#  '1.5dCi Expression 110 eco2',
#  'R240 Life 22 kWh (Accuhuur) / incl. BTW / excl. Ov',
#  '1.2 16V Airco, Bluetooth, Nwe APK. Rijklaarprijs',
#  '1ste Eigenaar | Ex Overheids Voertuig |1j Garantie',
#  '1.2-16V Authentique 3e Eigenaar! Airco NAP APK',
#  '1.5DCi Confort Authentique',
#  '2.0T Sport',
#  '1.5dCi Blue R.S. Line EDC 85kW',
#  'E-TECH Híbrido Intens 103kW',
#  '1.2-16V Night & Day',
#  'E-TECH Híbrido Zen 103kW',
#  'TCe Energy GLP Business 66kW',
#  '1.2 16V Dynamique Clima|Cruise|95.585km!',
#  '1.2-16V Night & Day SPORTIEF',
#  'Intens 40 R90 68kW',
#  '1.6-16V Expression',
#  '1.4 16v Community',
#  '1.6 Emotion 110',
#  'dCi 8V 75 CV Start&Stop 5 porte Energy Duel',
#  '1.2 Authentique 75PK | TL18226 | Airco | Cruise |',
#  'tce 120 intens pack trophy + equipe pmr handicap',
#  '1.2 TCE 101pk 5-drs. Airco, Elektr. Panoramadak, U',
#  '0.9 Dynamique Navi*MMI*Clima*Parksensor*Keyless*Ca',
#  '1.3 TCe GPF Intens 103kW',
#  '0.9 TCe 90 Experience R&Go',
#  'R240 Zen 22 kWh (AccuHuur) incl. BTW excl. Overhei',
#  '0.9 TCe 90ch energy Zen',
#  '1.2-16V Expression',
#  '0.9 TCe 95ch Zen',
#  '1.2 Emotion eco2',
#  '1.0 SCe 70 Experience Clima',
#  'LIMITED LIFE 41KW/H',
#  '0.9 TCe 90ch energy Limited Euro6C',
#  '1.0 SCe 70ch Life 2 Boîte Courte Euro6',
#  '1.6 E-Tech 140ch Zen',
#  'Life R240 65kW',
#  'Life (Kauf-Batterie)',
#  '1.0 SCe 70ch Stop\\u0026Start Zen eco²',
#  '1.2 Emotion',
#  'Electric Life R80 Achat Intégral 3CV',
#  '1.2 Yahoo',
#  '1.2 Expression - NAP KM STAND - ELEKTR RAMEN / SPI',
#  '1.0 SCe Expression 70PK | JU84387 | 5-Deurs | Airc',
#  '1.4 RN Orig.NL 54dkm+nap Topstaat!',
#  '1.2 Expression AIRCO. Stuurbekr. 113.000 km',
#  '1.2 16v Expression 75',
#  'Twizy 45 Intens Black Flex',
#  'C.C. 1.5DCi Extreme eco2',
#  '1.5 DCI LMV NAVIGATIE CRUISE CD CV+AB',
#  'life 80 kw r110 batería 40kwh',
#  'Plein Air*Komplettneuaufbau*H-Kennz.',
#  'R4 Cabriolet / Sammlerfahrzeug / 1. Hand',
#  'CC 1.5 dCi Dynamique 110 CV',
#  'C.C. 2.0 Luxe Privilege Aut.',
#  'C.C. 1.5dCi Dynamique',
#  'CC TCe 130 Dynamique 130 CV',
#  'C.C. 1.6 Confort Dynamique',
#  'C.C. 1.5DCi Confort Dynamique eco2',
#  'C.C. 1.9DCi Confort Dynamique',
#  'Sporter Blue dCi 160 CV EDC Exe',
#  'III Phase 3 1.5 dCi eco2 110 cv DYNAMIQUE - GARANT',
#  '1.8-16V | Cabrio | 69.000 KM | 1994 | 1 Swiss Owne',
#  '1.8 Fairway',
#  '1.6-16V Sport',
#  '1.6-16V Priv.Luxe',
#  'renault megane 5 porte dci  110cv',
#  '2.0 Coupe-Cabriolet Aut. Avantage',
#  'Cabriolet 1.6',
#  '4cv * DECOUVRABLE',
#  'Mégane',
#  '2.0 Coupe-Cabriolet Confort Dynamique',
#  'Coupe 2.0 16v T RS 250cv LEGGERE BENE !!!',
#  '3 coupe cabriolet III COUPE CABRIOLET 1.9 DCI 130',
#  'CC 1.5 dCi 110 FAP GT Line EDC 2015',
#  'Mégane C.C. 1.5dCi Dynamique',
#  'SporTour 1.9 dci Dynamique 130cv fap',
#  '1.6-16V Privilège',
#  '1.6 Dynamique',
#  'II CC 1.9 dCi 130 FAP Privilège',
#  '2.0 Coupe-Cabriolet Privilege',
#  '8.5',
#  '1.5 dCi 110CV S-S 4p. Express Ice',
#  'ACL  Cabrio   Rodeo',
#  '1.9 dCi FAP Coupe-Cabriolet Dynamique',
#  '1.6 Coupe-Cabriolet Authenique',
#  'R19 Cabriolet 1.8',
#  '2.0i',
#  '1.2 75CV GPL 5 porte Wave 201407',
#  'FLORIDE ( con hard top)',
#  '1.6-16V Aria',
#  'Cabriolet 2.0',
#  'Megane SporTour 1.5 dci Gt Line 110cv',
#  'GT',
#  'S 300',
#  'S 1.8 TCe 292 HERITAG BLUE ALPINE',
#  'mit Frontscheibe',
#  'Coupé RS 2.0 16v 265 S&S',
#  '1.6i TomTom Edition/ Airco',
#  'Societé Diesel 4 Societé 1.5dCi Energy',
#  'Williams Phase 2',
#  'tce 140 edc fap',
#  'Coupe LimitedEnergy TCe 115 *8-fach bereift*',
#  'COUPE EXPRESSION 1.9DCI',
#  'Mégane Coupé 1.6ie',
#  'tce 140 edc fap - 21b',
#  'A PREPARER',
#  'II 1.5 dCi 80',
#  'M.A. 2.0 Emotion',
#  'Deportivo Automático de 3 Puertas',
#  'Coupé 2.0T',
#  '1.5dCi eco2 Energy Limited 75',
#  'Coupé 2.0dCi Emotion Plus',
#  'CoupÃ© 2.0 dCi 150cv 2p #LIBRO, NAVY, BLUETOOTH',
#  'anterior 1.5dCi Energy Zen 66kW',
#  'Diesel Blue dCi Zen 85kW',
#  'anterior TCe Energy Limited 66kW',
#  'anterior TCe GPF Energy Limited 66kW',
#  'Zen',
#  'TCe 115 Expression Energy SANDS 85 kW (115 CV)',
#  'anterior TCe Limited 55kW',
#  'Expression dCi 110',
#  '1600 S',
#  'Europa Cup',
#  'tce 140 edc fap r.s. line',
#  'Renault Megane 1,5 dCI Energy Limited S&S 95',
#  'Group 4 * Roadlegal *',
#  'GTS',
#  'RS Trophy',
#  'RENAULT ALPINE GTA 19900 EURO PRIVE',
#  '3 coupe III COUPE 2.0 DCI 160 FAP GT EURO5',
#  'A 310',
#  'TURBO 1',
#  'Megane coupe manual 2.0 dCi',
#  'SporTour 2.0 dci 4Control esm 150cv',
#  '3 coupe III COUPE 2.0 DCI 180 FAP GT',
#  '45 ELECTRIQUE',
#  'Coupe Energy dCi 110 FAP Start & Stop GT Line',
#  'TR',
#  'Mégane Sport R.S. 265 Stop&Start Start&Stop',
#  'Tbo',
#  'Cargo incl. accu incl. BTW',
#  '2.0 T RS',
#  'tce 160 edc fap - 21b r.s. line',
#  'GT 18Fuchs/Ablage-/Sichtpaket',
#  'Rs',
#  'Turbo Maxi 2 Gruppo B Omologata Stradale',
#  'Coupe 2.0 16V Turbo GT',
#  'II 3.0 V6 Sport',
#  'Coupe Energy dCi 130 FAP Start & Stop GT Line',
#  'TCe 130 Coupe Dynamique',
#  'V6 TURBO',
#  'tce 160 edc fap - 21b',
#  '1.9 dCi Expression',
#  'Coupe dCi 175 FAP',
#  'ARKANA TCe 140 EDC FAP R.S. Line',
#  'RENAULT CLIO V6 SPORT "PHASE 2"',
#  '1.0 TCE 74KW BUSINESS 5 PORTE',
#  'DCI 180 4 CONTROL',
#  'Coupe 2.0 dCi 150ch Monaco GP',
#  'Technik 80 Z.E14.04.2014',
#  'Coupe 2.0 dci Wave Edition 150cv',
#  'COUPE 1.6 dCi 130 FAP Energy Bose eco²',
#  'Fleischmann',
#  'tce 140 edc fap - 21b r.s. line',
#  'dCi 110 FAP Coupe Dynamique',
#  '1.5dCi Energy eco2 Life 66kW',
#  '1.6 E-Tech R.S.Line 105kW',
#  '1.5 Blue dCi 115cv EDC Zen',
#  'Limited',
#  '1.3 TCe R.S. Line EDC 103kW',
#  'Zen E-TECH Híbrido 105kW(145CV)',
#  '2.0 Blue dCi 190cv X-Tronic 4x4 Zen',
#  '1.3 TCE 103KW ZEN EDC 140 5P',
#  '2.0dCi Blue Initiale Paris X-Tronic 4x4 140kW',
#  '2.0 Blue dCi 184cv X-Tronic Initiale Paris',
#  '1.7dCi Blue Zen 4x2 110kW',
#  '1.6 E-Tech 145cv RS Line',
#  'dci 90',
#  'e-tech 145 - 21',
#  'dCi 110 EDC Intens Energy',
#  '1.3 TCe 140 EDC Business Edition',
#  'Bose Edition 2.0 dCi 150cv 4x4',
#  '1.3 TCe 155ch FAP Intens EDC - 20 GPS Radar Ar',
#  '2.0 dci Initiale Paris 175cv 4x4 x-tronic',
#  'blue dci 115',
#  'tce 160 edc',
#  '1.3 tce Black Edition 140cv Fap - PROMO',
#  '1.3 tce Life 140cv fap',
#  '1.5 dCi 90ch energy Business Euro6c',
#  '1.5 BLUE DCI 115CV BUSINESS',
#  '1.2 VOOR EXPORT',
#  'S.T. 1.5dCi Energy Intens 81kW',
#  'V INITIALE PARIS 1.6 DCI 160CV AT6',
#  'Grand Combi L2H1 Klima 9-Sitzer Tempomat',
#  'S.T E-TECH Intens 117kW',
#  '1.8 TCe SL Icon EDC',
#  '1.6  dCi 130',
#  'SP. T. BUSINESS DCI 55KW 75CV 18',
#  'S.T. 1.5dCi Blue Intens 85kW',
#  'S.T. E-TECH Zen 117kW',
#  'S.T. 2.0dCi Blue Zen EDC 147kW',
#  'Sport Tourer 1.5dCi Energy Zen EDC 66kW',
#  'DoKa Pritsche Fahrgest. L3H1 3,5t 3',
#  'Ini. P. Blue dCi 139 kW (190CV) EDC',
#  '4P 1.6 DCI 130CV',
#  'Mégane IV Estate dCi 110 Energy  Business',
#  'S.T. Initiale Par. En. dCi 118kW TT EDC',
#  'Life',
#  'ZEN ENERGY dCI 81 KW 110 CV EDC 5',
#  'Megane SporTour 1.5 dci Limited 110cv',
#  'Sport Tou. Life En. dCi 55kW (75CV) - 18',
#  'grand scénic dci 130 energy fap eco2',
#  'SPORT TOURER 1.3 TCE ZEN 103KW 140 5P',
#  'Zen Energy dCi 81kW (110CV)',
#  'S.T. 1.6dCi Energy Privilege S&S 130',
#  'S.T. 1.5dCi En. Business S&S 110',
#  'S.T. 1.5dCi Energy Tech',
#  'blue dci 150',
#  'estate dci 130 energy',
#  'Luxe Privilege 2.0 16V EU4',
#  'Zen Blue dCi 88 kW (120CV) - SS',
#  'S.T. 1.8dCi Blue GT Line EDC 110kW',
#  'Mégane IV Estate dCi 110 Energy Business',
#  'ST TCe eco2 Energy Dynamique',
#  'IV ESTATE BUSINESS dCi 110 Energy',
#  'mégane iv estate blue dci 115 - 21b',
#  'E-TECH ZEN 117KW 160 5P',
#  'BUSINESS BLUE DCI 70 KW 95CV',
#  '1.5 DCI TECH ROAD ENERGY 110CV',
#  '1.8 RS Energy Tce 205kW 280cv',
#  'Expression dCi 150',
#  'RS Trophy Energy 162kW (220CV) EDC',
#  'LIMITED BLUE DCI 88 KW 120CV',
#  '4 Energy dCi 55kW (75CV) Business',
#  '1.8 TCE RS TROPHY EDC 221KW 300 5P',
#  'Business Energy dCi 66kW (90CV)',
#  'Zen TCe GPF 74 kW (100CV)',
#  '2.0 Si',
#  '1.8 TCe GPF 300cv - 18 RS Trophy-R',
#  'TCe R.S. Line',
#  'Init. P. Blue dCi 118 kW(160CV) EDC SS',
#  '1.3 TCE INTENS 103KW 140 5P',
#  'INTENS R135 B-Rent',
#  'Life Energy dCi 55kW (75CV)',
#  'TR -Prima G-Kat',
#  'ZEN TCe 115pk',
#  '1.5 Blue dCi 115cv Zen',
#  'Energy TCe 120 EDC Euro 6 Intens',
#  'Business Energy TCe 66kW (90CV) GLP',
#  'Limited Energy TCe 66kw (90CV) eco2',
#  '1.9 dCi/130CV 4p. Dynamique',
#  'Mégane IV Berline Blue 1.5L dCi 115',
#  'Renault 18 Turbo',
#  'BOSE Edition',
#  'Mégane 1.5 dCi/82CV 5 porte Confort Authentique',
#  '1.5 dCi 75CV Wave',
#  '1.2 TCE ENERGY GT LINE 97KW 130 5P',
#  '22 kwh Zen batterie ok',
#  'dCi 8V 75CV S&S Energy   Life',
#  'ii 1.2 lev 16v 75 eco2',
#  '1.6 Plug-in Hybrid E-TECH 160 R.S. Line EDC',
#  'dci 130 energy intens / origine france',
#  '1.5 dci - 90ch   iv berline business',
#  '1.6 E-Tech Híbrido 140cv Intens',
#  '4 IV (BFB) 1.8T 280CH RS EDC',
#  'Intens Energy TCe 100',
#  'dCi 110 Limited',
#  'RS',
#  'CLIO 4 INTENS 1.5 DCI 90 TOIT PANO',
#  '1.2i LEv Yahoo! // Clim // Garantie 1 an',
#  '1.5 BLUE DCI ZEN 85KW 115 5P',
#  '2.0 Expression',
#  '4 Energy dCi 75 eco2 Euro 6 Business',
#  'dCi 8V 90 CV 5 porte ADATTA A NEO PATENTATI',
#  '1.2 TCe 115 SS Energy Expression',
#  'City charge normale R90',
#  '1.5BlueHDi S&S GT EAT8 130',
#  '1.6 Hybrid Allure Pack EAT8 180',
#  '1.6 BlueHDi Active 75',
#  '1.6BlueHDi Business Line 75',
#  '1.2 Puretech S&S Allure Pack 100',
#  'Allure Eléctrico 100kW',
#  '1.5 BlueHDi S&S Active Pack 100',
#  'Pequeño Manual de 5 Puertas',
#  '1.5 BlueHDi S&S GT Pack EAT8 130',
#  '1.2 PureTech S&S Allure Pack 130',
#  '1.5 BlueHDi S&S GT EAT8 130',
#  '1.2 PureTech S&S Active Pack 110',
#  '1.2 PureTech S&S GT Line EAT8 130',
#  'LIKE ES 68',
#  '1.4 VTi 16v Confort',
#  '1.2 Puretech S&S GT Line 100',
#  '12V VTi 82CV 5p. Active',
#  'VTi 52kW (72CV) Allure',
#  '1.2 PureTech Like 68PK AM52901',
#  '1.2 PURE TECH ACTIVE 75 CV',
#  'Allure Long PureTech 110',
#  '1.2 PureTech S&S GT EAT8 130',
#  '1.2 Puretech S&S Active 100',
#  'e-208 136ch Active',
#  '1.6 HDiF XS | CRUISE | AIRCO |',
#  '1.6 VTi XS 5DRS AIRCO MOOI',
#  '1.4 VTi XS CRUISE INRUILKOOPJE !!',
#  '1.6 THP 270ch GTi S7S 5p Tpano GPS Camera',
#  '1.6-16V XT 5HB AUT CLIMA GOED AUTO',
#  '+ 1.4 XS',
#  '1ste Eigenaar 134.000km Garantie+Keuring',
#  '1.6 THP 270ch GTi S/S 5p',
#  '1.6 THP 270ch GTi S/S 5p GPS Camera Radar AV/AR',
#  '1.6-16V Gentry / Automaat / Climate / N.A.P.',
#  '1.6 Hybrid GT EAT8 225',
#  '1.2 Puretech S&S Allure Pack EAT8 100',
#  '+ 1.4 XS airco',
#  '1.6 BlueHDI 5 deurs - Navi',
#  '1.2 VTi Blue Lease Nieuwe APK.',
#  '1.0-12V XS Apple Carplay / Elek. ramen / Toerentel',
#  '1.6 BlueHDi Business Line 120',
#  '1.0-12V XR',
#  '1.5 BlueHDi S&S Allure Pack EAT8 130',
#  '- 1.2 PureTech Blue Lion / Airco / Navi',
#  '+  XS 1.4 AIRCO !! 1e EIGENAAR !!',
#  '1.2 PureTech Blue Lion NAVI, DAB',
#  '1.2 Puretech S&S Like 75',
#  '1.1 XR 48.656 KM NAP 1e eigenaar',
#  '1.2 PureTech Blue Lion 82PK | DG45472 | Navi | Cru',
#  '1.4 XR 2010 | Airco | Cruise Control | Radio CD |',
#  '1.4 Gentry INRUILKOOPJE !!',
#  '1.4Diesel !!!75.000km!!! GARANTIE + KEURING',
#  '1.1 Accent X | Radio / USB | APK tot 14-04-2023!',
#  '1.1 XTX | 5-deurs',
#  'XR 1.1',
#  'VTi 72 Like S\\u0026S 85g 3p',
#  '+ 1.1 XR',
#  '1.2 PureTech 5drs [ Navigatie Airco]',
#  '1.2 VTi Blue Lease / Airco / Navigatie / N.A.P.',
#  '1.4 VTi Active 95PK dealer onderhouden! Panorama d',
#  '1.6 BlueHDi 100ch Active 5p GPS',
#  '+ 1.1 XS / Airco / 5 Deurs / N.A.P.',
#  '1.6 BlueHDi 120ch GT Line S/S EAT6 5p',
#  '1.0 e-VTi Active',
#  '1.2 PureTech Blue Lion | Navigatie | Cruise contro',
#  '1.0 VTi Style (EU6.2)',
#  '1.0 e-VTi Active * LED * AIRCO * 4 SEIZOENSBANDEN',
#  '1.2 e-VTi Active',
#  '1.2 PureTech 100ch S\\u0026S Allure Pack Siege Chau',
#  '1.2 VTi Access 82PK | SP41691 | 5-Deurs | Cruise |',
#  '1.2 VTi Blue Lease Executive | Compleet Onderhoude',
#  '1.4i Urban 75',
#  '1.6HDI X-Line',
#  '1.0-12V SUBLIME',
#  '1.2 PureTech S&S Business Line 110',
#  '1.0 e-VTi Junior*Nette Auto*',
#  'VTi 72 Like S\\u0026S 4cv 5p',
#  '1.2 Puretech S&S Allure Pack EAT8 130',
#  '1.0 e-VTi Active 70PK | YB79646 | Airco | Elektris',
#  '1.2 PureTech Active',
#  '1.5 BlueHDi 130ch S/S Allure EAT6',
#  '1.4-16V Color-line',
#  '1.5 BlueHDi 100ch E6.c Active BVM5 86g 5p',
#  'Street Racing, Airco, Eleckt. Pakket',
#  '1.0 e-VTi Active + Dynamic pakket',
#  '1.0-12V Sublime',
#  '1.0 e-VTi Blue Lion Bluetooth, Start-Stop',
#  'Allure Pack Eléctrico 100kW',
#  '1.0 Active 68PK | DJ27749 | Airco | AUX | LED Dag',
#  '1.2 PureTech Active CLIMA, BT',
#  '1.5 BlueHDi 100ch S/S Active',
#  '1.0 e-VTi Active 5-deurs | Airco',
#  '1.0-12V XR| SPORT| ELEK. RAMEN| LM-VELGEN',
#  '1.2 PureTech Style Top 5p',
#  '1.0 Urban Light Accent Airco|',
#  'VTi 72 Active S\\u0026S 85g 5p',
#  '1.6 16V XT ECC CLIMATCONTROL / CRUISE / AUTOMAAT',
#  '1.0-12V XS Automaat | Airco | Elec. Pakket | Toere',
#  '1.2 Puretech S&S GT Line EAT8 130',
#  '1.2 PureTech 100ch S/S Allure 118g',
#  '1.5 BlueHDi 130ch S/S Allure GPS Camera Car Play K',
#  '1.2 PureTech 100ch S\\u0026S Allure 118g',
#  '1.0 VTi Like',
#  '1.0 e-VTi Active | Airco | Centr. deurvergr. | Ele',
#  '1.2 PureTech Active 5p',
#  '1.0VTi 68cv 3 porte Active',
#  '1.2 PureTech 130ch ¤6.c S/S Active Business Siege',
#  'WAGON Business 1.6 8v e-HDi 115cv S/S',
#  '1.2 PureTech Active, Navigatie',
#  '1.2 Active 82PK | PH09770 | Navi | Parkeersensoren',
#  '1.2 e-VTI Active 82PK | KX72146 | BTW | Parkeersen',
#  '1.2 PureTech 130ch Active Business Siege chauf Cam',
#  '1.0 e-VTi Active|AIRCO|BLEUTH|START/STOP|',
#  '1.0 Envy 68PK | YH49949 | Airco | LED Dagrijverlic',
#  '1.0 e-VTi Active Premium, Airconditioning',
#  '1.5 BlueHDi 130ch S/S Active Business GPS Camera R',
#  '1.2 PureTech Style 5p',
#  '1.0 68CV 3p. Access',
#  '1.0 e-VTi Active Pack Premium, Airconditioning',
#  'CC 1.6 HDI 112 FAP',
#  'CC Sport Pack 1.6 THP 140 Automático',
#  'CC 1.6 HDi 110ch FAP BLUE LION Féline',
#  'Cabriolet ROLAND GARROS Paris Capote électric',
#  'CC 1.6 HDiF 50% deal 1.500,- ACTIE Nieuwe A.P.K /',
#  '206 CC Roland Garros',
#  '1.1i cat Cabriolet CJ',
#  '207 CC 1.6 16v 120ch',
#  'CC 1.6',
#  'Cabriolet 2 l',
#  'CC Sport 1.6 VTI 120',
#  'CC 1.6 VTI 16V 120',
#  'Sport 1.6 HDI 110 FAP',
#  'Cabrio 1.6 THP Sport Pack 115 kW (156 CV)',
#  'CC 1.6 THP Edition Limitada 150CV',
#  'CC Cabrio 2.0 HDI Sport 140CV',
#  'CC Cabrio 1.6 VTi Sport 122CV',
#  'CC 1.6 VTi Active 120 CV',
#  'CC 1.6 VTi 120cv SPORT 2p #BLUETOOTH',
#  'CC HDI 136 FAP',
#  '207 cc 1.6i Cabriolet',
#  'cabriolet $$je recherche en état ou a refaire$$',
#  'CABRIOLET (pininfarina!)',
#  'Cabriolet Injection',
#  'GTI',
#  '1.6-16V',
#  'CC 2.0 Sport 180',
#  'CC HDi FAP 140 Premium',
#  '206CC',
#  'CC FAP 110 (Blue Lion) Filou',
#  'cabrio',
#  'CC 2.0 HDi 16V 140 ch FAP Féline 7',
#  '2.0-16V',
#  '1.6-16V Roland G.',
#  'CC 2.0 16V',
#  'CC',
#  '1.6 Vti Cabrio 2008 Zwart',
#  '<NULL',
#  'CC 135',
#  '2.0 CABRIOLET Lederen bekleding nette kap',
#  'CC 110',
#  'CC e-HDi FAP 110 Start&Stop Active',
#  '2.0-16V CC',
#  'CC 110 Roland Garros',
#  'CC 1.6 HDiF Airco',
#  'CABRIOLET (KF2)',
#  'CC HDi FAP 110 Premium',
#  '1.6-16V T Roland G.',
#  'CC 150 THP Sport',
#  'PEUGEOT 308 CC, 2.0 DIESEL CABRIOLET',
#  'Cabriolet 1.8',
#  '206CC Hardtop Cabriolet',
#  'Automatik Leder',
#  'coupe 2.7 hdi 204ch griffe ba',
#  '1.3i Rallye',
#  'Coupé 2.0l - Garantie 12 mois',
#  '1.6 THP 155cv',
#  '1.6 THP',
#  '2.0 HDi  163 CV',
#  '2.0 HDi 163 CV',
#  'Coupé Ultima Edizione HDi Pack 136',
#  'CoupÃ© 2.2 163cv 2p #LIBRO',
#  '2.7 V6 hdi 24v Feline auto fap',
#  '1,6 THP 160',
#  '3.0-24V V6 Pack',
#  "201 '30",
#  '5p 1.4 vti 16v XS',
#  '16 GTI',
#  'Coupe "S" ( 1974 )',
#  'cc roland garros 1.6hdi 112 fap',
#  '2.0i 16V cat Coupé',
#  '307 3p 1.6 16v XR',
#  'Coupe 165 Sport',
#  'SW 2.0 hdi 16v Tecno Ciel fap',
#  'GTI 1.9 130 CV--ASI ORO--ORIGINALE--PARI AL NUOVO',
#  '3.0i V6 24V cat Coupé Plus',
#  "3.0i V6 24V cat Coupé Plus Settant'anni",
#  's16',
#  '1.6 thp 16v 156cv auto',
#  'COUPE GRIFFE 2.7 V6 HDI 204ch BVA6 1ere MAIN',
#  '2.0 HDi FAP 160',
#  'GTI 1.6 THP S&S 3 porte',
#  'coupe COUPE 2.0 HDI 136 FAP SPORT',
#  '1.6 thp 16v 200cv',
#  '007 2.2-16V Pack ( heerlijke wagen! )',
#  '1.6 155 THP',
#  '3p 1.6 16v XS',
#  'Plus 3p 1.1 X-Line eco-Gpl',
#  '1.5BlueHDi Active Pack S&S 130',
#  '1.6 BlueHDi 88KW (120CV) S&S Allure',
#  'BlueHDI 81kW (110CV) Active',
#  'HYB PHEV 225 Allure Pack e-EAT8',
#  'Active BlueHDI 100 S&S BVM6',
#  '1.2 PureTech S&S Allure Pack EAT8 130',
#  '1.5 BLUE HDI 130 CV EAT8 ALLURE',
#  '1.5 BLUE HDI 130 CV ACTIVE PACK',
#  '1.6EHDI 115CV ALLURE 5P',
#  '300 e-EAT8 Allure Pack',
#  'puretech allure',
#  'ALLURE HDI 130 CV',
#  '1.6 THP 156cv -',
#  '1.2 PureTech 96KW S&S Active Pack',
#  '1.2 PURETECH S&S ACTIVE 130 5P',
#  'BlueHDI 130 S&S EAT8 Allure',
#  '1.5BlueHDi S&S Roadtrip S&S EAT8 130',
#  'BlueHDI 130 S&S EAT8 Allure Pack',
#  'BlueHDI 81kW (110CV) Allure Pack',
#  '1.6BLUEHDI ALLURE S&S 120CV 5P',
#  '1.2 PureTech SS Allure',
#  '1.5 Blue-HDi GT Line',
#  'GT LINE 1.2 PURE TECH 130 CV',
#  'Puretech 130 S&S EAT8 Allure Pack',
#  '300 e-EAT8 GT Pack',
#  'ALLURE',
#  '1.2 PureTech Style 82',
#  'Puretech 100 S&S 6 Vel. MAN Active Pack',
#  '1.6 BlueHDI Style 100',
#  '1.5 BLUEHDI S&S AUTO GT LINE 130CV 5P 7 PLAZAS',
#  'GT-Line BlueHDi 96kW (130CV) S&S EAT8 GT Line',
#  '1.6 BlueHDi 88KW 120CV Allure SS',
#  '1.2 PURETECH 100 S&S ACTIVE PACK 5P',
#  '1.5BlueHDi S&S Allure 100',
#  'BlueHDI 100 S&S BVM6 Allure',
#  '1.5BlueHDi S&S Allure EAT8 130',
#  '1.5 BLUEHDI 96KW ACTIVE S&S 130 5P',
#  '1.5BlueHDi S&S GT Line 100',
#  '1.5 BlueHDi 96kW S&S  EAT8 Allure Pack',
#  'Confort 1.6 HDI 110 FAP',
#  'Active 1.6 BlueHDi 100',
#  '1.5 BlueHDi Active S&S (EU6.3)',
#  '2.0BLUEHDI 133KW GT AUTO S&S 180 5P',
#  '1.5 BLUEHDI 96KW ALLURE S&S 5P',
#  '1.2 PureTech S&S Active Pack 100',
#  '1.2 PureTech S&S Active 100',
#  '1.2 VTI PureTech Active',
#  '1.5BlueHDi S&S Allure Pack EAT8 130',
#  '2.2 HDi 16V 156ch FAP Confort Pack',
#  'HYB PHEV 300 Allure Pack AWD e-EAT8',
#  '1.5 BLUEHDI 96KW S&S ALLURE 5P 7 Plazas',
#  '1.5 BlueHDi 96kW (130CV) S&S Active Pack',
#  'HYB PHEV 300 GT AWD e-EAT8',
#  '225 e-EAT8 Allure Pack',
#  '1.6 e-HDi 92 Allure',
#  '1.2 S&S PureTech Allure Pack EAT8 130',
#  '2.0 bluehdi 150ch s\\u0026amp;s bvm6 allure / suivi',
#  '1.2 PureTech 96KW (130CV) S&S Allure',
#  '1.2 PURETECH 96KW S&S ALLURE 5P',
#  'HYB PHEV 225 Allure e-EAT8',
#  'Puretech 100 S&S BVM6 Active Pack',
#  '1.2 Puretech 130ch S',
#  '1.5 bluehdi Allure s&s 110cv',
#  '1.5bluehdi active s&s 130',
#  'BlueHDi 96kW (130CV) S&S EAT8 Allure',
#  'SW 1.6 Hybrid GT Pack EAT8 225',
#  'SW  HYBRID 225 e-EAT8 GT',
#  '5p Active 1.4 HDi 70 FAP',
#  'SW 1.2 PureTech S&S Active Pack 110',
#  '1.2 PureTech 110cv Active - GPS - APS AR - Cruise ',
#  '1.6 BLUEHDI 88KW BUSINESS LINE SW 120 5P',
#  'SW 1.6 Hybrid Allure Pack EAT8 180',
#  'GT Long BlueHDi  96kW',
#  'SW 2.0 SR Sport 143',
#  '1.5 Blue-HDi Access Standard',
#  '1.2 PureTech (EU6.2)',
#  '1.5 Blue-HDi Access L1',
#  'Active Standard BlueHDi 73kW',
#  'SW GT Line 1.2 PureTech 96KW (130CV)',
#  '1.2 PureTech EAT8 GT Long 7 plazas',
#  'L2 :SOFORT+ Radio+ Klima+ Parkhilfe+ Tempomat',
#  'SW GT HYBRID 180 e-EAT8',
#  'SW ACTIVE 1.6 BLUEHDI 88KW 120CV',
#  'SW PSE Hybrid 360 Automatik 8-Gang',
#  'SW  BlueHDi 130 S&S GT',
#  'SW  PureTech 130 S&S 6 Vel. MAN Style',
#  '2.0 bluehdi 180ch eat6 / suivi entretien complet à',
#  'SW 1.2 PureTech S&S Allure Pack EAT8 130',
#  'standard 1.5 BLUEHDI gt line 130 eat8',
#  '5p XT 2.0 HDI 136 FAP',
#  '1.6 hdi 16v Lee',
#  'SW 2.0 HDi Air-line 2| EXPORT| Meeneemprijs',
#  'SW  BlueHDi 130 S&S EAT8 Style',
#  '2ª serie BlueHDi 130 Stop&Start SW Business',
#  'SW Hybrid 225 GT e-EAT8',
#  '308 BlueHDi 180 EAT6 S&S SW GT',
#  'II 2018 SW 308 SW 1.5 bluehdi Allure s&s 130cv my2',
#  '1.5 BLUEHDI 96KW ALLURE AUTO SW 5P',
#  'SW Active 1.6 8V HDi 93 CV FAP',
#  'SW Allure 1.2 PureTech 96KW (130CV) S&S',
#  'SW 1.4i 16v XR',
#  '5p GT Line 1.2 PureTech 130 S&S',
#  'SW 1.5 bluehdi Active s&s 130cv',
#  'SW  Puretech 130 S&S EAT8 GT',
#  'SW 1.6 bluehdi Business s&s 120cv eat6',
#  '1.5 BLUEHDI 96KW STYLE AUTO SW 5P',
#  'SW Active Pack Puretech 130 S&S MAN',
#  'RXH 2.0 BlueHDi 180CV Autom.',
#  '1.5 BlueHDi 130ch S/S Active Business 7cv Siege Ch',
#  '2ª serie PureTech Turbo 130 S&S SW Allure',
#  'SW 1.6 BlueHDI Blue Lease [ Nav ]',
#  'SW  1.6 BlueHDi 88KW (120CV) Active',
#  'SW 1.4 VTi Confort',
#  'Style 1.6 BlueHDi 120 FAP',
#  'SW  PureTech 130 S&S EAT8 Active Pack',
#  'SW 1.6 BlueHDi Access 100',
#  'SW GT Pack BlueHDi 130 Automatik 8-Gang',
#  'II Ph2 1.5 BlueHDi 130 S\\u0026S GT Line BA8',
#  'ACTPK PT100',
#  'SW 1.6 e-HDi 112ch FAP Business Pack',
#  '1.5 Blue-HDi GT Line Standard',
#  ...]

# %%
categories_2 = {
    'sport_trim': ['Sport Seats', 
                 'Sport Package', 
                 'Sport Suspension',
                 'Shift Paddles', 
                 'Tuned Car'], # sport features
    
    'wheel': [    'Alloy Wheels \(17"\)',
                  'Alloy Wheels \(19"\)', 
                  'Alloy Wheels \(18"\)', 
                  'Alloy Wheels \(16"\)', 
                  'Alloy Wheels \(21"\)', 
                  'Alloy Wheels \(20"\)', 
                  'Alloy Wheels \(22"\)', 
                  'Alloy Wheels \(23"\)',
                  'Alloy Wheels \(13"\)',
                  'Alloy Wheels \(26"\)', 
                  'Alloy Wheels \(10"\)', 
                  'Alloy Wheels \(14"\)',
                  'Alloy Wheels \(15"\)',                  
                  'Steel Wheels',
                  'Alloy Wheels',
                  
                  ], # wheels #'Alloy Wheels' 
                
    
    'accessory': ['Headlight Washer System', 
                   "Smoker'S Package", 
                   'Automatically Dimming Interior Mirror',
                   'Voice Control', 
                   'Cargo Barrier', 
                   'Ski Bag', 
                   'Electronic Parking Brake', 
                   'Touch Screen',
                   'Ambient Lighting', 
                   'Roof Rack', 
                   'Trailer Hitch',
                   'Spoiler',
                   'Handicapped Enabled',
                   'Awning'], # extra accessories
    
    'tires': [    'Emergency Tyre Repair Kit', 
                  'Summer Tyres', 
                  'Winter Package', 
                  'Winter Tyres', 
                  'Emergency Tyre',
                  'All Season Tyres',
                  'Spare Tyre'
                 ], # tires
    
    'other': [    'Catalytic Converter',
                  'Sliding Door',
                  'E10-Enabled',
                  'Biodiesel Conversion',
                  'Range Extender',
                  'Right Hand Drive'
                 ] # other features
}
# spor_ext 0, wheel_ext 1 , access_ext 1

# %%
# Sure, let's query the key-value pairs of the dictionary in the short description.
for category, keywords in categories_2.items():
    for keyword in keywords:
        result = df.loc[df[df["extras"].isnull()].index, "short_description"].str.contains(f"(?i){keyword}")
        print(f"{category} {keyword}: {result.value_counts()}")
# Out:
# sport_trim Sport Seats: False    5057
# Name: short_description, dtype: int64
# sport_trim Sport Package: False    5057
# Name: short_description, dtype: int64
# sport_trim Sport Suspension: False    5057
# Name: short_description, dtype: int64
# sport_trim Shift Paddles: False    5057
# Name: short_description, dtype: int64
# sport_trim Tuned Car: False    5057
# Name: short_description, dtype: int64
# wheel Alloy Wheels \(17"\): False    5057
# Name: short_description, dtype: int64
# wheel Alloy Wheels \(19"\): False    5057
# Name: short_description, dtype: int64
# wheel Alloy Wheels \(18"\): False    5057
# Name: short_description, dtype: int64
# wheel Alloy Wheels \(16"\): False    5057
# Name: short_description, dtype: int64
# wheel Alloy Wheels \(21"\): False    5057
# Name: short_description, dtype: int64
# wheel Alloy Wheels \(20"\): False    5057
# Name: short_description, dtype: int64
# wheel Alloy Wheels \(22"\): False    5057
# Name: short_description, dtype: int64
# wheel Alloy Wheels \(23"\): False    5057
# Name: short_description, dtype: int64
# wheel Alloy Wheels \(13"\): False    5057
# Name: short_description, dtype: int64
# wheel Alloy Wheels \(26"\): False    5057
# Name: short_description, dtype: int64
# wheel Alloy Wheels \(10"\): False    5057
# Name: short_description, dtype: int64
# wheel Alloy Wheels \(14"\): False    5057
# Name: short_description, dtype: int64
# wheel Alloy Wheels \(15"\): False    5057
# Name: short_description, dtype: int64
# wheel Steel Wheels: False    5057
# Name: short_description, dtype: int64
# wheel Alloy Wheels: False    5057
# Name: short_description, dtype: int64
# accessory Headlight Washer System: False    5057
# Name: short_description, dtype: int64
# accessory Smoker'S Package: False    5057
# Name: short_description, dtype: int64
# accessory Automatically Dimming Interior Mirror: False    5057
# Name: short_description, dtype: int64
# accessory Voice Control: False    5057
# Name: short_description, dtype: int64
# accessory Cargo Barrier: False    5057
# Name: short_description, dtype: int64
# accessory Ski Bag: False    5057
# Name: short_description, dtype: int64
# accessory Electronic Parking Brake: False    5057
# Name: short_description, dtype: int64
# accessory Touch Screen: False    5057
# Name: short_description, dtype: int64
# accessory Ambient Lighting: False    5057
# Name: short_description, dtype: int64
# accessory Roof Rack: False    5057
# Name: short_description, dtype: int64
# accessory Trailer Hitch: False    5057
# Name: short_description, dtype: int64
# accessory Spoiler: False    5057
# Name: short_description, dtype: int64
# accessory Handicapped Enabled: False    5057
# Name: short_description, dtype: int64
# accessory Awning: False    5057
# Name: short_description, dtype: int64
# tires Emergency Tyre Repair Kit: False    5057
# Name: short_description, dtype: int64
# tires Summer Tyres: False    5057
# Name: short_description, dtype: int64
# tires Winter Package: False    5057
# Name: short_description, dtype: int64
# tires Winter Tyres: False    5057
# Name: short_description, dtype: int64
# tires Emergency Tyre: False    5057
# Name: short_description, dtype: int64
# tires All Season Tyres: False    5057
# Name: short_description, dtype: int64
# tires Spare Tyre: False    5057
# Name: short_description, dtype: int64
# other Catalytic Converter: False    5057
# Name: short_description, dtype: int64
# other Sliding Door: False    5057
# Name: short_description, dtype: int64
# other E10-Enabled: False    5057
# Name: short_description, dtype: int64
# other Biodiesel Conversion: False    5057
# Name: short_description, dtype: int64
# other Range Extender: False    5057
# Name: short_description, dtype: int64
# other Right Hand Drive: False    5057
# Name: short_description, dtype: int64

# %%
# FINAL CODE
# For all rows where 'extras' is NaN and 'short_description' is not empty,
# we are searching for ALL keywords.

index_no = df.loc[df["extras"].isnull() & df["short_description"].notnull()].index

for category, keywords in categories_2.items():
    for keyword in keywords:
        result_indices = index_no.intersection(df[df["short_description"].str.lower().str.contains(keyword.lower(), na=False)].index)
        df.loc[result_indices, "extras"] = df.loc[result_indices, "extras"].apply(lambda x: x + ", " + category if pd.notnull(x) else category)

# Because the "Short_Description" column does not contain any values that are present in the "safety_security" dictionary, 
# then we won't be able to utilize the dictionary in this case.

# %%
handle_missing_values(df , "extras")
# Out:
# Missing Values in 'extras':
# Count: 5138
# Percentage: 17.96%

# %%
df.columns
# Out:
# Index(['make_model', 'short_description', 'make', 'model', 'location', 'price',
#        'body_type', 'type', 'doors', 'country_version', 'offer_number',
#        'warranty', 'mileage', 'first_registration', 'gearbox', 'fuel_type',
#        'colour', 'paint', 'desc', 'seller', 'seats', 'power', 'engine_size',
#        'gears', 'co_emissions', 'manufacturer_colour', 'drivetrain',
#        'cylinders', 'fuel_consumption', 'comfort_&_convenience',
#        'entertainment_&_media', 'safety_&_security', 'extras', 'empty_weight',
#        'model_code', 'general_inspection', 'full_service_history',
#        'non_smoker_vehicle', 'emission_class', 'emissions_sticker',
#        'upholstery_colour', 'upholstery', 'previous_owner',
#        'energy_efficiency_class', 'co_efficiency', 'location_country',
#        'location_city'],
#       dtype='object')

# %%
# After the groupby operation, how many NaN values do I have remaining?
df['extras'].fillna(df.groupby(['body_type', 'type'])['extras'].transform(lambda x: x.mode()[0])).isnull().sum()
# Out:
# 0

# %%
df["extras"] = df['extras'].fillna(df.groupby(['body_type', 'type'])['extras'].transform(lambda x: x.mode()[0]))

# %%
handle_missing_values(df , "extras")
# Out:
# Missing Values in 'extras':
# Count: 0
# Percentage: 0.00%

# %% [markdown]
# <a id="11"></a>
# <div class="alert alert-info" role="alert">
# <h1>Column name :<span style="color:red"> seller </span></h1>
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Operation : </b> Since the 'seller' column is fully populated, there is <span style="color:red"><b>no need for any operation.</b>
# </div>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
first_looking("seller")
# Out:
# column name    :  seller
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  2
# Dealer            26291
# Private seller     2312
# Name: seller, dtype: int64

# %% [markdown]
# <a id="12"></a>
# <div class="alert alert-info" role="alert">
# <h1>Column name :<span style="color:red"> seats </span></h1>
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Operation : </b> To fill in the missing values in the "seats" column, we can use the "short_description" column . Since the "seats" column is associated with <span style="color:red"><b> " make " " model " " body_type " and " doors "</b></span> . let's fill in the <span style="color:red"><b> NaN values</b></span> in this column by grouping the data based on these columns and performing the necessary operations.
# </div>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
first_looking("seats")
# Out:
# column name    :  seats
# --------------------------------
# per_of_nulls   :  % 10.9
# num_of_nulls   :  3118
# num_of_uniques :  11
# 5.0     18296
# 4.0      5388
# NaN      3118
# 2.0      1181
# 7.0       488
# 8.0        43
# 9.0        35
# 3.0        25
# 6.0        12
# 0.0         9
# 1.0         6
# 17.0        2
# Name: seats, dtype: int64

# %%
# Let's examine the short description of the seats
list(df.loc[df[df["seats"].isnull()].index, "short_description"])
# Out:
# ['CDi',
#  '4MATIC',
#  'e Limousine',
#  nan,
#  'CDI',
#  'Limousine',
#  nan,
#  'CDI Elegance',
#  'd AMG Line (EURO 6d)',
#  'd (177.003)',
#  'd (177.003)',
#  nan,
#  nan,
#  'A-CLASS A180 1.3 136 CV 7G-DCT 5P',
#  'S 4MATIC+',
#  'd Avantgarde Largo',
#  'BlueEfficiency*SHZ*GSD*NAVI*',
#  'd Lease Edition Ambition',
#  'AMG A 35 4MATIC',
#  'Business Solution AMG',
#  'd (177.003)',
#  'CDi',
#  'd (177.003)',
#  'd ACC NAVIGATIE LM VELGEN SPORTSTOELEN LEDER',
#  'd Style + Pneus Hiver',
#  '200d 7G-DCT',
#  'AMG LEDER LED NAVI LMV CRUISE',
#  'd 4Matic AMG Line (EURO 6d)',
#  'd Style + Pneus Hiver',
#  'CDI 100kW ( 136CV ) Urban',
#  'd Progressive',
#  'd Premium',
#  'MERCEDES-BENZ Clase GLK Pequeño  Automático de 5',
#  'Pequeño Automático de 5 Puertas',
#  nan,
#  'CDI Premium',
#  'd (177.003)',
#  'BlueEFFICIENCY Urban',
#  'CDI',
#  'd (177.003)',
#  'CDI Style',
#  'C Roadster',
#  'Biturbo V-Max',
#  'MercedesAMG',
#  '435cv AMG ***SOLO 37.000KMS *** LIBRO OFICIAL',
#  'UNIEKE SL 560 EUROPESE LOOK IN NIEUWSTAAT.AUTOM.',
#  'd Cabriolet',
#  'Cabriolet AMG Line',
#  nan,
#  '200K',
#  'Cabrio CGI BE Avantgarde',
#  'Cabrio d',
#  'Cabriolet AMG Line',
#  '-CLASS 6.2 COUPE SPORT AUTO 457 2P',
#  'CLK Cabrio CLK 55 AMG Deutsches Top Auto',
#  'Cabriolet S 4MATIC',
#  'SL',
#  'AMG Line',
#  'S cabrio BURMESTER | LED | 360° | TRACK PACE',
#  '190SL',
#  'd Cabriolet',
#  'D',
#  'AMG GLC 43 4MATIC Coupé',
#  nan,
#  '-CLASS 4MATIC',
#  'Coupe AMG Line',
#  '4MATIC+ Coupé',
#  'd 4MATIC',
#  'd 4MATIC Coupé AMG Line',
#  'Mercedes-AMG S 4MATIC+',
#  '-CLASS 3.0 4MATIC AUTO 333 2P',
#  'C Coupe*DEUTSCHES-FAHRZEUG*AUTOMATIK*H-KENNZEICHEN',
#  'Coupé',
#  'Coupe AMG + NIGHTPACK - LEDER - PANO DAK - 360° -',
#  'AMG Line',
#  'CDI Coupé',
#  'Coupé CDI',
#  'Compressor',
#  'Coupé',
#  'Coupé',
#  'd 4MATIC',
#  'Matte wrapping',
#  'd 4MATIC -',
#  'coupé 4.0 4MATIC 469 2P',
#  'Coupé 7G-DCT AMG LINE - BURMESTER - SFEERVERLICHTI',
#  'd 4MATIC Coupé',
#  'Coupé d',
#  'd 4MATIC',
#  'CDI Chrome',
#  'e Coupé',
#  'd (205.314)',
#  'Coupé d',
#  'Coupé',
#  'CDI (LA) Sport Edition (203.708)',
#  'Coupé 220d',
#  'Classe E 300d Coupé AMG Line Mercedes-Benz E Klas',
#  'COUPE AMG -Line',
#  'Coupé',
#  'Coupé d 4MATIC',
#  'CDI Inspiration 7G-DCT',
#  'd 4MATIC',
#  '-Klasse GLA 250 Urban 4Matic Xenon Pano AHK Alu 1',
#  '4MATIC',
#  'EQ HEV HYBRID *4 MATIC*GPS*CAMERA*LED*ALU BI COLOR',
#  'd 4Matic All-Terrain Estate Avantdarde',
#  'G Klasse 350d Mercedes-Benz G Klasse 350d - Direct',
#  '4M AMG Line',
#  "7G-DCT AMG + NIGHTPACK - ALU 19' - SFEERVERLICHTIN",
#  'd 4 MATIC 245cv 9 vel. *IVA deducible* *2020* *Nac',
#  'd 4MATIC AMG Line',
#  'CDI',
#  'GLS 400d 4MATIC AMG Line Mercedes-Benz GLS 400d 4M',
#  nan,
#  'd AMG Line',
#  'd 4Matic (253.915)',
#  'BlueTEC 4MATIC',
#  'AMG GLC 43 4MATIC',
#  'e 4Matic',
#  'D ADVANTAGE + PAQ NIGHT',
#  nan,
#  'Coupé 350D 258 CV',
#  'D',
#  'Mercedes-AMG 4MATIC',
#  'd PROGRESSIVE',
#  'd 4MATIC',
#  'd 4Matic (253.915)',
#  'D 2.2 170CV AUT 5P',
#  'e 4MATIC',
#  'd Pack AMG',
#  '316 DOKA+PRITSCHE+KLIMA 7 SITZER 316 CDI',
#  'd',
#  'd break AMG Line',
#  'AMG CLA 35 4MATIC Shooting Brake',
#  '(+)2.0 AVANTGARDE AUTO 211 5P STATE',
#  nan,
#  'Estate',
#  '4MATIC',
#  'd Shooting Brake',
#  'd Estate',
#  'CDI Blue Efficiency Estate',
#  'AMG E 53 4MATIC+ Estate',
#  'd Estate Business Line',
#  'Estate Business Line',
#  'd AMG/rijassist',
#  'd Estate',
#  'Shooting Brake',
#  'T AMG LINE MULTIBEAM WIDESCREEN AHK CAMERA',
#  'de Estate',
#  'd 4M All-Terrain',
#  'd Estate',
#  '(+)2.1 D AMG LINE 5P',
#  'd Estate',
#  'CLA-CLASS 2.1 D DCT SHOOTING BRAKE 136 5P',
#  'd avantgarde',
#  'd Estate Business Line',
#  'B200 CDI AMG AUT 136CV',
#  'Shooting Brake AMG Line 7G-DCT',
#  'CDI BlueEFFICIENCY Edition',
#  'd 4MATIC Estate',
#  'd Estate',
#  'Mercedes-AMG 4M Shooting Brake',
#  'PLUG-IN HYBRID Lang',
#  'CDI BlueEfficiency (204.001)',
#  '1.6',
#  '2.3 16',
#  'd',
#  'Mercedes-AM53 4MATIC+',
#  '-CLASS 4.7 455 4P',
#  '-CLASS 4.7 455 4P',
#  'Mercedes-AMG S 4MATIC+',
#  'Mercedes-AMG S 4MATIC+',
#  '-CLASS 2.1 D 4MATIC AUTO 170CV 4P',
#  'Classe E 200 d',
#  nan,
#  'CDI Business',
#  'd',
#  '-CLASS D G TRONIC PLUS AVANTGARDE',
#  'd',
#  'd',
#  'd',
#  'Mercedes-AMG 4MATIC',
#  'd',
#  'CDI 4M Aut. AMG Line',
#  'de',
#  'S Klasse 580E Lang 4MATIC Mercedes-Benz S Klasse 5',
#  'CLA-CLASS 2.1 CDI DCT 170CV 4P',
#  'CLA-CLASS 2.1 CDI DCT 170CV 4P',
#  'd AMG',
#  'Sedan 9G-Tronic AMG LINE - FULL LED - ALU - BLIS -',
#  'BlueTEC Sport',
#  'Mercedes-AMG 4MATIC',
#  'CLS-CLASS 272 4P',
#  'd AMG Line',
#  'd',
#  'Blue Efficiency Avantgarde',
#  'CDI BE Avantgarde Blue Effic. Ed.',
#  'BlueTEC 4Matic (212.011)',
#  'Business-Solution',
#  'Org. 61.000km Aut. Historie 1A Sammlerzust.',
#  'AMG line',
#  'de',
#  'Mercedes-AMG 4MATIC',
#  'S Klimaaut Sitzheizung Tempomat Recaro',
#  '1.4 66KW (90 CV) EXPRESSION PRO',
#  '1.0 Turbo Rocks elektr. Faltdach I Navi',
#  '1.4 120 Jahre Klima ZV SHZ PDC',
#  'S 1.4 TURBO *LEDER RECARO*INFINITY SOUND*CARPLAY*S',
#  '*Lenkradheizung*PDC hinten* Color Edition',
#  '1.4 120 Jahre S/S Einparkassistent',
#  '1.4 120 Jahre Open Air Klimaautomatik, USB',
#  '1.4 120 Jahre LM+KlimaA+W-Paket+PDC+',
#  '120 Jahre Klimaautomatik, DAB+Radio,',
#  '1.4 66KW (90 CV) EXPRESSION PRO',
#  '1.4 66KW (90 CV) EXPRESSION PRO',
#  '120 Jahre  DAB+, Klimaautomatik, PDC,..',
#  '1.4 120 Jahre Winterpaket*Parksensoren',
#  '120 Jahre Spoilerpaket',
#  '1.4 120 Jahre LM PDC SHZ Lenkradhzg',
#  'Rocks 120 Jahre Klimaautomatik, Navigation',
#  'GTC 2.0 Turbo OPC 280PK/Xenon/Navi/Garantie.',
#  '2.0 T Cosmo',
#  '1.4-16V Executive',
#  '2,2 Excellence 4x4 2011',
#  'GTC 1.6 Turbo 170pk Sport OPC-Line 1e eigenaar/Dea',
#  '1.6 Ultimate Navi Leder Kamera',
#  '1.6 Turbo Ultimate Xenon/Navi/Leder/PDC',
#  'ecoFlex  Ultimate Navi ParkAss.PDC Sitzh',
#  'CABRIO 1.6 BENZINE MT',
#  "Ultimate 20'' Leder Kamera 170PS",
#  '2.0 CDTI Cabriolet Active-Paket',
#  '1.6  Ultimate *Automatik*el.Sitz*Navi*',
#  "1.6 T Ultimate NAV Kamera Xenon 19''Alufelgen",
#  '1.6 Turbo Ultimate **VOLLAUSSTATTUNG**',
#  '1.6 Turbo Ultimate Navi+ParkAss.',
#  '1.6 Kamera BiXenon PDC Sitzhzg+belüftung',
#  '1.6 Turbo Ultimate Xenon 20 Zoll Schild',
#  'AUTOMATIK NAVI.KAME SITZHEIZ KLIMA Xeno',
#  'Ultimate Navi FLA Bel.Sitz elSitz Leder',
#  '1.6 Turbo-T Ultimate-TEMP) FLA SpurH',
#  "1.6 Turbo Ultimate 20''ALU*Sportfahrwerk",
#  '1.4 Open Air Faltdach Klimaautomatik DAB+',
#  'ecoFlex Ultimate 5 Jahre Garantie',
#  'OPEL GT 2.0 T 265 cv garantie 12 mois',
#  '1.6 Ultimate NAV Kamera Bi-Xenon DAB+',
#  'Ultimate1.6 Turbo Navi Leder',
#  'TwinTop 1.4 16V Sport',
#  '1.6 Turbo Ultimate FLA Navi KAM 20 Zoll',
#  'Open Air 120 Jahre Klimaautom., Bluetooth',
#  '2.0 CDTi S/S 165 CV Excellence',
#  '2.0 CDTi S/S 165 CV Excellence',
#  '1.4 Turbo Excellence',
#  '1.4 T S/S Excellence',
#  '1.4 Turbo Excellence',
#  '1.4 Turbo Excellence',
#  '1.4 Turbo Excellence',
#  '1.4T 140cv Excellence S/S #NAVY, BLUETOOTH',
#  '1.4 T S/S Excellence',
#  '1.4 Turbo Excellence',
#  '2.0 CDTi S/S 165 CV Excellence',
#  '1.4T 140cv Excellence S/S #NAVY, BLUETOOTH',
#  'TwinTop 1.6 Cosmo',
#  '1.4 T S/S Excellence',
#  'Ultimate',
#  'Innovation ecoFlex 2.0 Diesel',
#  '1.8-16V Enjoy',
#  '2.0 TURBO',
#  nan,
#  '1.8-16V Cosmo',
#  'B 2.0 GSI 1985 ATS RECARO APK 2023',
#  'Astra GTC Coupé OPC 2.0i 280 CV GTC',
#  '1.4 16V Automatik mit nur 41.900 Kilometer',
#  '3 Puertas 1.4T GSI',
#  'GTC 2.0 CDTi 195cv Biturbo 3p S/S #NAVY, BLUETOOTH',
#  'GTC 2.0 CDTi 195cv Biturbo 3p S/S #NAVY, BLUETOOTH',
#  nan,
#  'Olimpia 1.5 Coupe  //Top Zustand//',
#  '2.0i-16V DTM',
#  nan,
#  'GT/E gruppo 2',
#  'Olympia',
#  '2.0,Klima,1.Hand',
#  nan,
#  nan,
#  nan,
#  'B Coupe aus 1969',
#  'A 4x4 Turbo C20Let*1.Hand*MwSt*',
#  'GTE - CONRERO',
#  'Irmscher GSE Oltimer FIA Liebhaber ',
#  'GTC1.8 Sport Goed onderhouden',
#  nan,
#  '1.3 CDTI . GTC',
#  'B CC Berlinetta H-KENNZEICHEN und Tüv Neu*',
#  '2.0 I Color Edition',
#  '1.3 CDTI Advance 95cv S/S 5 PORTE',
#  '1.3 CDTI b-Color 75cv 5 PORTE',
#  'Verkocht! 1.8 Cosmo OPC-Line',
#  '1.6 CDTI 4X2 EXCELLENCE AUTO',
#  '1.6 Turbo  Auto 4x4 Ultimate',
#  '1.2 96kW (130CV)  S/S Innovation',
#  '2.0 D 120 Jahre FLA LM AkustikGlas',
#  '1.2 81kW (110CV) GS Line',
#  '1.2 TURBO INNOVATION *AUTOMAAT 6-TRAPS*GPS*CARPLAY',
#  'X 1.6 CDTI 110 CV ECOFLEX BUSINESS EDITION',
#  'GS LINE',
#  'GS LINE',
#  'Innovation 1,2 96kW Automatic,Navi,Alu,Klima,SH PD',
#  'X 1.6 CDTI 110 CV ECOFLEX BUSINESS EDITION',
#  '1.2 96kW (130CV) GS Line',
#  'GS LINE',
#  '1.2 Turbo Selective',
#  '1.2 Turbo Selective',
#  'GS LINE',
#  'X 1.6 CDTI Excellence',
#  'X EXCELLENCE',
#  'TODOTERRENO 1.6 CDTI EXCELLENCE 120 5P',
#  '1.6 CDTI EXCELLENCE AUTO 2WD 136 5P',
#  'X 1.6T 88kW (120CV) Ultimate S/S',
#  'CUIR/CAMERA/NAV/PDC',
#  '1.6 CDTI SS 100KW INNOVATION AUTO ST',
#  'INS-ST INNOV. 1.6D 136CV MT6',
#  '1.5 TURBO DYNAMIC SPORTS TOURER *AUTOMAAT*OPC INTE',
#  'A Sports Tourer Business Innovation Navi',
#  '1.6 CDTI TURBO D INNOVATION ST 136CV 5P',
#  '2.0d COSMO SPORTS TOURER *AUTOMAAT*GPS*SENSOREN*CA',
#  'ST 2.0 CDTI Excellence Auto',
#  'SPORT TOURER 1.2 TURBO 145 CV ELEGANCE',
#  '1.6 CDTi 81kW (110CV) Business ST',
#  'Life 1.2 T S/S   XL Selective',
#  'ST 2.0 CDTI Navi Sitzheizung Tempomat',
#  'Life 1.2 T S/S   XL Selective',
#  '1.4 Turbo S/S 110kW Excellence ST',
#  'ST Elegance 1.5D,NAVI,Intellilux,PDC+Kamera',
#  'SPORT TOURER 1.2 TURBO 145 CV ELEGANCE',
#  'K 1.4 Turbo Ultimate Start/Stop (EURO 6d-TEM',
#  'K Sports Tourer Design&Tech Navigation SHZ',
#  'Sports Tourer 2.0 CDTI 130CV Edition Aut',
#  'Life 1.5 CDTI INNOVATION',
#  'Life 1.5 TD 75kW (100CV) S/S   L Selective',
#  '2.8 V6 Turbo 4x4 OPC',
#  '1.6 CDTI 100KW EXCELLENCE S',
#  '1.4 Turbo S/S 110kW Innovation Auto ST',
#  'Life 1.5 TD 96kW 130cv SS Edition L',
#  'ST  2.0D DVH 130kW AT8 Business Elegance',
#  'Dynamic 1.6 Benzine 200 pk!!!',
#  '2.0d INNOVATION GS *ADAPTIVE SUSPENSION*LED*360 CA',
#  '1.7 ecoFlex S/S 130 CV Excellence',
#  '2.0 turbo  gsi',
#  'GS 1.6 Turbo SHT Ultimate Auto',
#  '1.4/PDC/NAV/GARANTIE',
#  '1.2T XHL 74kW (100CV) GS-Line',
#  '1.2T SHR 107kW (145CV) Business Elegance',
#  '1.3 CDTi Business 55kW (75CV)',
#  'GS  1.5D DVH 90kW MT6 Business Edition',
#  'GS  2.0T SHT 169kW AT9 4x4 GSi',
#  '1.4T Elegance AUT 5p',
#  '1.5D DVH 90kW (122CV) GS Line',
#  '1.6 Turbo S/S GSi Line',
#  '1.4 Turbo GLP Elegance',
#  '120 Jahre inkl. Big Deal!!',
#  'SEDAN 1.6 CDTI 110 HP EXCELLENCE S',
#  '1.4 120 Jahre IntelliLink Teilleder PDC',
#  '1.3 CDTi Business 55kW (75CV)',
#  '120 Jahre LM Klimaautom. W-Paket PDC',
#  '1.2 PureTech 100 EAT8',
#  '1.2T SHL 81kW (110CV) GS Line',
#  '1.2T XHL 74kW (100CV) GS-Line',
#  'INNOVATION/NAVI/AIRCO/ALLU',
#  '120 Jahre TOP-Angebot LM+KlimaA+W-Paket+PDC',
#  '1.6 CDTI 81KW SELECTIVE 110 5P',
#  '120 Jahre LM+W-Paket+PDC+',
#  'GS 1.6 CDTi 100kW Turbo D Business',
#  '1.2T XHL 74kW (100CV) GS-Line',
#  '1.4 120 Jahre *LHZ*Temp*SHZ*DAB*Klima*',
#  '1.4T SHT 107kW (145CV) Business Eleg CVT',
#  'ecoFlex 120 Jahre ParkAss.+SpurW+LM+KlimaA+W',
#  '120 Jahre LM W-Paket Leder PDC SHZ',
#  'Rocks 120 Jahre 1.0 Turbo Klima SHZ (237)',
#  '1.4 66kW (90CV) Selective Pro',
#  'GS 1.6 CDTi 100kW Turbo D Selective',
#  'Open Air 120 Jahre 1.4 Sitzheizung - Bluetooth - U',
#  '120 Jahre ecoFlex ParkAss. SpurW LM KlimaA',
#  '1.4 Turbo S/S Sportive',
#  '1.0 Turbo Open Air Turbo Faltdach*SHZ',
#  '1.6T Hybrid 132kW (180CV)  Auto GS-Line',
#  '120 Jahre LM+KlimaA+W-Paket+PDC+',
#  '1.2T XHL 74kW (100CV) GS-Line',
#  '1.5D DVC 77KW 105 5P',
#  '1.2T XHL 74kW (100CV)  Auto Elegance',
#  '1.4 120 Jahre incl. BigDeal & Inspektionspaket',
#  'rs line',
#  '1.5 dCi 110CV Nav',
#  '1.5 ENERGY dCI 110 CV AUT',
#  '1.5 ENERGY dCI 110 CV AUT',
#  '1.5 ENERGY dCI 110 CV AUT',
#  'limited',
#  '1.3 TCe 140cv Zen Energy',
#  'Zen TCe90 X-Tronic Klima Sitzheizung Navi PDC',
#  '1.0 SCe 75 Intens Klimaautomatik DAB PDC',
#  'ELECTRIC ZEN',
#  'V6 3.0i 24v PHASE I UNIQUE Condition',
#  '1.5 dci 85 dynamique',
#  '80 INTENS WHITE',
#  '1.6 TCe GT',
#  'Alpine A110 1.8 Pure auto',
#  'LIMITED LIFE 41KW/H',
#  '1.0 TCe Zen | Navigatie | LM-velgen',
#  'life 80 kw r110 batería 40kwh',
#  'R4 Cabriolet / Sammlerfahrzeug / 1. Hand',
#  'CC 1.5 dCi Dynamique 110 CV',
#  'CC TCe 130 Dynamique 130 CV',
#  '1.2 Expression Cabrio TÜV NEU USB',
#  'Sporter Blue dCi 160 CV EDC Exe',
#  '1.6-16V Priv.Luxe',
#  'III Coupé-Cabriolet Zen',
#  '1.6-16V Sport NIEUWE APK',
#  'III Coupé-Cabriolet Privilège',
#  '1.6-16V Expression',
#  '2.0-16V Tech Line',
#  '3 coupe cabriolet III COUPE CABRIOLET 1.9 DCI 130',
#  '1.6-16V Privilège',
#  '2.0-16V Priv.Luxe',
#  '1.5 dCi 110CV S-S 4p. Express Ice',
#  '2.0-16V Priv.Luxe',
#  '1.6-16V Expression',
#  '1.2 75CV GPL 5 porte Wave 201407',
#  'FLORIDE ( con hard top)',
#  'GTA V 2.5 V6 Turbo consignatie verkoop/Valckenier',
#  'Coupé RS 2.0 16v 265 S&S',
#  'Societé Diesel 4 Societé 1.5dCi Energy',
#  'Coupe LimitedEnergy TCe 115 *8-fach bereift*',
#  'COUPE EXPRESSION 1.9DCI',
#  'M.A. 2.0 Emotion',
#  '1.5dCi eco2 Energy Limited 75',
#  'CoupÃ© 2.0 dCi 150cv 2p #LIBRO, NAVY, BLUETOOTH',
#  'anterior 1.5dCi Energy Zen 66kW',
#  'Diesel Blue dCi Zen 85kW',
#  'anterior TCe Energy Limited 66kW',
#  'anterior TCe GPF Energy Limited 66kW',
#  'Zen',
#  'TCe 115 Expression Energy SANDS 85 kW (115 CV)',
#  'TCe Energy GLP Business 66kW',
#  'anterior TCe Limited 55kW',
#  'CoupÃ© 2.0 dCi 150cv 2p #LIBRO, NAVY, BLUETOOTH',
#  'Expression dCi 110',
#  'tce 140 edc fap r.s. line',
#  '2.0 T RS 265 Cup',
#  '2.0 TCE 2009 RS Uitgevoerd 285PK',
#  'RS Trophy Automatik',
#  'A310 S “Pack“ 3,0 Turbo',
#  '3 coupe III COUPE 2.0 DCI 160 FAP GT EURO5',
#  'A 310',
#  'Coupe 2.0 turbo RS 275cv E6',
#  '3 coupe III COUPE 2.0 DCI 180 FAP GT',
#  '2.0 TCe GT',
#  'tce 160 edc fap - 21b r.s. line',
#  'Turbo Maxi 2 Gruppo B Omologata Stradale',
#  'III Coupé dCi 165 GT',
#  'II 3.0 V6 Sport',
#  '3 COUPE RENAULT SPORT 265 S&S',
#  'ARKANA E-Tech 145 - 21B R.S. Line',
#  'II 1.6i  Lim. 3-trg. Privilege *Klimaa.**',
#  'V6 TURBO',
#  '2.0 RS Turbo 250 cup Recaro',
#  'ARKANA TCe 140 EDC FAP R.S. Line',
#  nan,
#  '1.0 TCE 74KW BUSINESS 5 PORTE',
#  'DCI 180 4 CONTROL',
#  'S',
#  'Technik 80 Z.E14.04.2014',
#  'coach 2000 16 v montecarlo',
#  'II 3.0 V6 Sport',
#  'II 2.0 DCI 150 GT COUPE',
#  'tce 140 edc fap - 21b r.s. line',
#  'Zen dci 90',
#  'Bose Edition DCi 130 4x4',
#  '1.2 TCe 165 LED Navi Kamera Leder',
#  'Intens dCi 130kW (175cv) 4WD',
#  'Zen dCi 96 kW (130CV)',
#  'Zen dCi 130kW (175cv) 4WD',
#  'Business Tce GPF 103kW (140CV)',
#  '1.5 Blue dCi 115cv EDC Zen',
#  'Limited',
#  'Zen TCe 90',
#  'Business Blue dCi 85W (115CV)',
#  'intens dci 110 4x2 auto',
#  'Zen dCi 130kW (175cv) 4WD',
#  'Zen E-TECH Híbrido 105kW(145CV)',
#  '2.0 Blue dCi 190cv X-Tronic 4x4 Zen',
#  'Intens TCe 140 EDC',
#  '1.3 TCE 103KW ZEN EDC 140 5P',
#  'LIMITED Deluxe TCe 140 GPF',
#  '0.9 TCe 90 eco² Intens ENERGY *PDC hi*Tempomat*LED',
#  '2 EXPERIENCE TCe 90',
#  '2.0 Blue dCi 184cv X-Tronic Initiale Paris',
#  'TCE 140 EDC 5JAAR GARANTIE',
#  '1.5 dCi 90 eco² BOSE Edition ENERGY *PDC*Navi*LED*',
#  '1.6 E-Tech 145cv RS Line',
#  '2.0 dci 150 bose edition',
#  '1.6 E-Tech 145cv RS Line',
#  '1.6 E-Tech 145cv RS Line',
#  'dCi 110 EDC Intens Energy',
#  'GPS/Camera/Alu!!slechts 8000km',
#  'Bose Edition 2.0 dCi 150cv 4x4',
#  '1.5 Blue dCi 115cv EDC Zen',
#  '1.3 TCE Version S Aut. *LED SCHEINWERFER!*',
#  'Grandtour dCi 160 LED DAB Navi Kamera',
#  'V INITIALE PARIS 1.6 DCI 160CV AT6',
#  'Intens dci 110',
#  'Sp. Tou. Limited Energy TCe 74kW (100CV)',
#  '1.8 TCe SL Icon EDC',
#  '1.6  dCi 130',
#  'Sp. Tourer Tech Ro. En. Tce 97kW (130CV)',
#  'SP. T. BUSINESS DCI 55KW 75CV 18',
#  'Zen',
#  'S.T. Zen Blue dCi 118Kw (160CV) EDC - SS',
#  'Ini. P. Blue dCi 139 kW (190CV) EDC',
#  'zen dci 90',
#  '4P 1.6 DCI 130CV',
#  'Estate 1.5 dCi Night & Day',
#  'S.T. Initiale Par. En. dCi 118kW TT EDC',
#  'Life',
#  'ZEN ENERGY dCI 81 KW 110 CV EDC 5',
#  'Sport Tou. Life En. dCi 55kW (75CV) - 18',
#  'SPORT TOURER 1.3 TCE ZEN 103KW 140 5P',
#  'S. T. INTENS EN. DCI 81KW 110CV',
#  'S. T. INTENS EN. DCI 81KW 110CV',
#  'Zen Energy dCi 81kW (110CV)',
#  '2418 IV Grandtour intens',
#  'S.T. ZEN TCE GPF 103KW 140CV  18',
#  'S.T. 1.5dCi Energy Tech',
#  'Luxe Privilege 2.0 16V EU4',
#  'Zen Blue dCi 88 kW (120CV) - SS',
#  'Kombi Grandtour Benzin/Alkohol (III) TomTom',
#  'ZEN ENERGY dCI 81 KW 110 CV EDC 5',
#  'E-TECH ZEN 117KW 160 5P',
#  'BUSINESS BLUE DCI 70 KW 95CV',
#  '1.5 DCI TECH ROAD ENERGY 110CV',
#  '1.8 RS Energy Tce 205kW 280cv',
#  'Expression dCi 150',
#  'RS Trophy Energy 162kW (220CV) EDC',
#  'Intens Energy dCi 96kW (130CV)',
#  'LIMITED BLUE DCI 88 KW 120CV',
#  '4 Energy dCi 55kW (75CV) Business',
#  '1.8 TCE RS TROPHY EDC 221KW 300 5P',
#  'Zen',
#  'Limited dCi 110 eco2',
#  'Business Energy dCi 66kW (90CV)',
#  'GT Line Energy dCi 81kW (110CV)',
#  'Zen Energy TCe 130',
#  '1.8 TCe GPF 300cv - 18 RS Trophy-R',
#  'Zen Blue dCi 85 kW (115CV) EDC',
#  'Init. P. Blue dCi 118 kW(160CV) EDC SS',
#  '1.3 TCE INTENS 103KW 140 5P',
#  '1.3 TCE INTENS 103KW 140 5P',
#  'INTENS R135 B-Rent',
#  'Life Energy dCi 55kW (75CV)',
#  'Business TCe 85 kW (115CV) GPF',
#  'TCe Cool & Sound Benzine',
#  'Business Energy dCi 66kW (90CV)',
#  '1.5 Blue dCi 115cv Zen',
#  'Energy TCe 120 EDC Euro 6 Intens',
#  'Business Energy TCe 66kW (90CV) GLP',
#  'limited tce 91 auto',
#  'Life Energy TCe 74kW (100CV)',
#  '1.8 RS Energy Tce 205kW 280cv',
#  '1.8 RS Energy Tce 205kW 280cv',
#  'E-Tech 100% ele. TECHNO EV60 220hp',
#  'Life R110 ZE50 inklusive Batterie Winterpaket',
#  '1.8 TCE RS TROPHY EDC 221KW 300 5P',
#  'BUSINESS BLUE DCI 70 KW 95CV',
#  '1.9 dCi/130CV 4p. Dynamique',
#  'Renault 18 Turbo',
#  'BOSE Edition',
#  'LIMITED BLUE DCI 88 KW 120CV',
#  'BOSE Edition',
#  '1.2 TCE ENERGY GT LINE 97KW 130 5P',
#  '1.2 energy tce 130  limited',
#  '1.5 DCI 110 CARMINAT TOMTOM LIVE',
#  '1.5 dci - 90ch   iv berline business',
#  '1.6 E-Tech Híbrido 140cv Intens',
#  'Limited 1.3 Be 116pk',
#  '4 IV (BFB) 1.8T 280CH RS EDC',
#  '4 IV (BFB) 1.8T 280CH RS EDC',
#  'dCi 110 Limited',
#  'iv rs 300 trophy - malus inclus',
#  '1.5 DCI 110 BUSINESS GARANTIE 12 MOIS',
#  'CLIO 4 INTENS 1.5 DCI 90 TOIT PANO',
#  '1.5 BLUE DCI ZEN 85KW 115 5P',
#  '4 Energy dCi 75 eco2 Euro 6 Business',
#  'Mégane IV 1.5 Blue dCi - 115 - BV EDC -  GT Line P',
#  '1.2 TCe 115 SS Energy Expression',
#  '/ Automatik/ 1 Hd/el.FH/Original zustand/',
#  'LIKE ES 68',
#  '12V VTi 82CV 5p. Active',
#  'VTi 52kW (72CV) Allure',
#  '1.2 PURE TECH ACTIVE 75 CV',
#  'Allure Long PureTech 110',
#  '1.2 PURE TECH ACTIVE 75 CV',
#  '1.2 PURE TECH ACTIVE 75 CV',
#  '1.6 e-THP GTi leer /navigatie',
#  '1ste Eigenaar 134.000km Garantie+Keuring',
#  '- 1.2 PureTech Blue Lion / Airco / Navi',
#  '+  XS 1.4 AIRCO !! 1e EIGENAAR !!',
#  'II Active',
#  '1.4 Essence 75 CV BVA',
#  '1.2 PureTech GT-Line',
#  'WAGON Business 1.6 8v e-HDi 115cv S/S',
#  nan,
#  'CC 1.6 HDI 112 FAP',
#  'CC Sport Pack 1.6 THP 140 Automático',
#  'Cabriolet ROLAND GARROS Paris Capote électric',
#  '1.6 VTi rolland garros',
#  'CC Sport 1.6 VTI 120',
#  'CC 1.6 VTI 16V 120',
#  'Cabrio 1.6 THP Sport Pack 115 kW (156 CV)',
#  'Cabriolet 1.8',
#  'CC Sport 1.6 VTI 120',
#  'Descapotable Manual de 3 Puertas',
#  'CC 1.6',
#  'CC 1.6 THP Edition Limitada 150CV',
#  'CC Cabrio 2.0 HDI Sport 140CV',
#  'CC Cabrio 1.6 VTi Sport 122CV',
#  'CC 1.6 VTi Active 120 CV',
#  'CC 1.6 VTi 120cv SPORT 2p #BLUETOOTH',
#  'CC HDI 136 FAP',
#  'CC 1.6 VTi 120cv SPORT 2p #BLUETOOTH',
#  '2.0-16V',
#  '2.0 HDI 120CV DISTRIB OK',
#  '1.6-16V',
#  'CC / KLIMAAUTOM',
#  'CC 2.0-16V Dynam.L |Clima |Cabrio |Nieuwe APK |NAP',
#  '2.0-16V',
#  nan,
#  '1.6-16V Roland G.',
#  '1.6-16V',
#  'CC 1.6 Roland Garros Automaat',
#  '<NULL',
#  'CC Sport120 *TÜV12/22*2.Hand*8 fach bereift*',
#  '2.0 CABRIOLET Lederen bekleding nette kap',
#  '1.6-16V Roland G.',
#  '2.0-16V',
#  'pack allure 1.5 bluehdi',
#  '2.0-16V',
#  '1.6 VTI 16V FELINE',
#  '2.0-16V',
#  'PEUGEOT 308 CC, 2.0 DIESEL CABRIOLET',
#  '2.0-16V',
#  '2.0-16V',
#  'Automatik Leder',
#  'SPORT THP 156',
#  '3.0 V6 Coupe Platinum',
#  '2433',
#  '1.6 THP 155cv',
#  '1.6 THP 155cv',
#  '1.6 THP 155cv',
#  '2.0 HDi  163 CV',
#  '1.6i Turbo 155PK 1e eigenaar DealerOH Cruise Clima',
#  '2.0 HDi 163 CV',
#  'Coupé Ultima Edizione HDi Pack 136',
#  'CoupÃ© 2.2 163cv 2p #LIBRO',
#  'CoupÃ© 2.2 163cv 2p #LIBRO',
#  'RC',
#  'GTI 16V ( vraie et bleu Miami !! )',
#  '3.0-24V V6 Pack',
#  '16 GTI',
#  'Coupe "S" ( 1974 )',
#  'cc roland garros 1.6hdi 112 fap',
#  'GTI 2.0 16v',
#  'COUPE 2.2E 16V 163CH SPORT',
#  'COUPE GRIFFE 2.7 V6 HDI 204ch BVA6 1ere MAIN',
#  'coupe COUPE 2.7 V6 HDI SPORT PACK BVA',
#  'Active BlueHDi 120cv S&S 5 PORTE BERLINA',
#  'coupe COUPE 2.0 HDI 136 FAP SPORT',
#  '007 2.2-16V Pack ( heerlijke wagen! )',
#  '1.6T Automaat/Leder/Navi/NW Model.',
#  nan,
#  '1.6 BlueHDi 88KW (120CV) S&S Allure',
#  'Style 1.6 BlueHDi 73KW (100CV)',
#  'BlueHDI 81kW (110CV) Active',
#  'GT Line BlueHDI 100 S&S BVM6',
#  'blue hdi allure automaat',
#  'Active BlueHDI 100 S&S BVM6',
#  'GT Pack 1.6 HYBRID 300 e-EAT8',
#  '1.5 BLUE HDI 130 CV EAT8 ALLURE',
#  '1.5 BLUE HDI 130 CV ACTIVE PACK',
#  '1.6 thp gt-line 165 pk automaat',
#  '1.6EHDI 115CV ALLURE 5P',
#  '300 e-EAT8 Allure Pack',
#  'Active BlueHDI 100 S&S BVM6',
#  '1.5 BlueHDi 96kW (130CV) S&S Allure',
#  'puretech allure',
#  'Hybrid 300 e-EAT8 GT',
#  'ALLURE HDI 130 CV',
#  'GT Line 1.5L BlueHDi 96kW (130CV) S&S',
#  '1.6 THP 156cv -',
#  '1.2 PureTech 96KW S&S Active Pack',
#  'GT Line BlueHDi 96kW (130CV) S&S EAT8',
#  '1.5 BLUE HDI 130 CV EAT8 ALLURE',
#  '1.2 PURETECH S&S ACTIVE 130 5P',
#  'BlueHDI 130 S&S EAT8 Allure',
#  '1.2 PURETECH 96KW (130CV) ALLURE S&S',
#  '1.5L BlueHDi 96kW (130CV) S&S GT Line',
#  '1.5 BLUE HDI 130 CV ACTIVE PACK',
#  'Signature 1.2 PureTech 60KW (82CV)',
#  'Signature 1.2 PureTech 60KW (82CV)',
#  'BlueHDI 130 S&S EAT8 Allure Pack',
#  'ALLURE HDI 130 CV',
#  '1.5 BLUE HDI 130 CV ACTIVE PACK',
#  'Active Pack Puretech 100 S&S BVM6',
#  'Allure Pack BlueHDI 81kW (110CV)',
#  'Hybrid 225 e-EAT8 GT Line',
#  'BlueHDI 81kW (110CV) Allure Pack',
#  '1.6BLUEHDI ALLURE S&S 120CV 5P',
#  '1.2 PureTech SS Allure',
#  '1.5 Blue-HDi GT Line',
#  '1.2 PureTech SS Allure',
#  '1.6PureTech GT-Line EAT8 LED/GPS/Camera/PDC 1ste E',
#  '1.5 BLUE HDI 130 CV EAT8 ALLURE',
#  'GT LINE 1.2 PURE TECH 130 CV',
#  'Active BlueHDI 100 S&S BVM6',
#  'Puretech 130 S&S EAT8 Allure Pack',
#  '1.5D GT-LINE *AUTOMAAT*3D COCKPIT*CARPLAY*LED*SENS',
#  '1.5 BlueHDi 96kW (130CV) S&S Allure',
#  '1.6BLUEHDI ALLURE S&S 120CV 5P',
#  'GT LINE 1.2 PURE TECH 130 CV',
#  'Allure Pack BlueHDI 81kW (110CV)',
#  '1.5 BlueHDi 96kW (130CV) S&S Allure EAT8',
#  '1.2 PureTech 96KW (130CV) S&S Allure',
#  'Allure 1.2 PureTech 81KW (110CV) Auto',
#  '300 e-EAT8 GT Pack',
#  '1.5 BlueHDi 96kW (130CV) S&S GT Line',
#  'BlueHDI 81kW (110CV) Allure Pack',
#  'ALLURE',
#  '1.2 PureTech 96KW S&S Active Pack',
#  'GT LINE 1.2 PURE TECH 130 CV',
#  'Puretech 100 S&S 6 Vel. MAN Active Pack',
#  '1.5 BLUEHDI S&S AUTO GT LINE 130CV 5P 7 PLAZAS',
#  'GT-Line BlueHDi 96kW (130CV) S&S EAT8 GT Line',
#  'GT-Line BlueHDi 96kW (130CV) S&S EAT8 GT Line',
#  '1.6 BlueHDi 88KW 120CV Allure SS',
#  'Active Pack BlueHDI 81kW (110CV)',
#  '1.2 PURETECH 100 S&S ACTIVE PACK 5P',
#  'GT-Line 1.6L THP 121kW (165CV) EAT6',
#  'BlueHDI 100 S&S BVM6 Allure',
#  '1.2 PURETECH 96KW (130CV) ALLURE S&S',
#  '1.5 BLUEHDI 96KW ACTIVE S&S 130 5P',
#  'Allure BlueHDi 96kW (130CV) S&S EAT8',
#  '1.5 BlueHDi 96kW S&S  EAT8 Allure Pack',
#  'Allure Pack 1.2 PureTech Man.6',
#  'Confort 1.6 HDI 110 FAP',
#  '2.0BLUEHDI 133KW GT AUTO S&S 180 5P',
#  '1.5 BLUEHDI 96KW ALLURE S&S 5P',
#  '1.5 BLUEHDI 96KW ALLURE S&S 5P',
#  'ALLURE HDI 130 CV',
#  '1.5BlueHDi Allure 7-plaatsen!! GPS/PDC/Camera 1ste',
#  'ALLURE PK ES 130 AUTO',
#  'Active 1.6 Hdi ETG',
#  'Allure',
#  '1.5 BLUEHDI 96KW S&S ALLURE 5P 7 Plazas',
#  '1.6 BlueHDi S\\u0026S - 120 - BV EAT6  Active Busin',
#  'Active Pack 1.2 PT 130 pk',
#  '1.5 BlueHDi 96kW (130CV) S&S Active Pack',
#  'I Allure',
#  'Signature 1.2 PureTech 60KW (82CV)',
#  'GT-line FULL-option*Automaat*Leder*Navi*Camera*...',
#  '225 e-EAT8 Allure Pack',
#  'II Allure',
#  '1.6 e-HDi 92 Allure',
#  'Allure',
#  '1.2 PureTech 96KW (130CV) S&S Allure',
#  '1.2 PURETECH 96KW S&S ALLURE 5P',
#  'Allure Pack BlueHDI 81kW (110CV)',
#  'Puretech 100 S&S BVM6 Active Pack',
#  '1.6 HDi 120 EAT6  Allure',
#  '1.2PureTech GT-Line S&S Carplay/PDC/Camera ***TOPS',
#  '1.5bluehdi active s&s 130',
#  'Allure',
#  'BlueHDi 96kW (130CV) S&S EAT8 Allure',
#  'SW PSE 1.6 HYBRID 360pk',
#  'Business Line BlueHDi 96kW S&S EAT8',
#  'SW  HYBRID 225 e-EAT8 GT',
#  '5p Active 1.4 HDi 70 FAP',
#  'SW 1.6 THP 205 GT LED Navi Kamera Klima',
#  'SW ACTIVE 1.6 BLUEHDI 100 FAP',
#  'SW GT BlueHDi 132kW (180CV) EAT8',
#  'Nuevo  SW Allure 2.0 BlueHDi150 EAT6',
#  '1.6 BLUEHDI 88KW BUSINESS LINE SW 120 5P',
#  '1.6 TURBO ALLURE SW *BTW AFTR.*AUTOMAAT*GPS*SENSOR',
#  'GT Long BlueHDi  96kW',
#  'SW GT BlueHDi 132kW(180CV) S&S EAT8',
#  'SW 1.6 BlueHDi 120 Navi Sitzheizung PDC',
#  '1.5 Blue-HDi Access Standard',
#  'SW Allure 1.5 BlueHDi 96KW (130CV)',
#  '1.5 Blue-HDi Access L1',
#  'SW GT Vrij/ Libre 03/2023',
#  'Active Standard BlueHDi 73kW',
#  'SW GT Line 1.2 PureTech 96KW (130CV)',
#  '1.2 PureTech EAT8 GT Long 7 plazas',
#  'II SW Allure',
#  'SW GT HYBRID 180 e-EAT8',
#  'SW ACTIVE 1.6 BLUEHDI 88KW 120CV',
#  'SW PSE Hybrid 360 Automatik 8-Gang',
#  'SW  BlueHDi 130 S&S GT',
#  'SW  PureTech 130 S&S 6 Vel. MAN Style',
#  '1.2i puretech 130  gt line',
#  'standard 1.5 BLUEHDI gt line 130 eat8',
#  '5p XT 2.0 HDI 136 FAP',
#  'SW 2.0 BlueHDi 150  GT Line',
#  'SW  BlueHDi 130 S&S EAT8 Style',
#  '1.5 BLUEHDI 96KW ALLURE AUTO SW 5P',
#  '1.5BlueHDi Style GPS/Camera/PDC 1ste Eig! **GOEDE',
#  'SW Allure 1.2 PureTech 96KW (130CV) S&S',
#  'SW 1.4i 16v XR',
#  '2,0',
#  '2.0 BlueHDi - 180 - BV EAT8   SW (BREAK) GT LINE',
#  '5p GT Line 1.2 PureTech 130 S&S',
#  'SW  Puretech 130 S&S EAT8 GT',
#  '1.5 BLUEHDI 96KW STYLE AUTO SW 5P',
#  'SW Active Pack Puretech 130 S&S MAN',
#  'gt automatic',
#  'RXH 2.0 BlueHDi 180CV Autom.',
#  'SW  1.6 BlueHDi 88KW (120CV) Active',
#  'Style 1.6 BlueHDi 120 FAP',
#  'SW  PureTech 130 S&S EAT8 Active Pack',
#  'SW GT Pack BlueHDi 130 Automatik 8-Gang',
#  'ACTPK PT100',
#  'SW 1.6 VTi 120pk Clima, Panoramadak, 16" LMV, PDC',
#  'II SW Hybrid 225 e-EAT8 Allure Pack',
#  '1.5 Blue-HDi GT Line Standard',
#  'SW  Hybrid 225 eEAT8 GT',
#  '1.5 BLUEHDI ALLURE 130 standard',
#  '2372 Confort 22,5KWh *gps',
#  '2373 Active 22,5KWh *gps',
#  nan,
#  'Electric Active',
#  '5P PSE HYBRID 360 e-EAT8',
#  '5P PSE HYBRID 360 e-EAT8  Sport Engineered',
#  '403 Oldtimer/ Sammler /Rarität/Black Panther/',
#  'Active',
#  '5p Tech Edition 1.2 PureTech 96KW',
#  '5P GT Line BlueHDi 130kW (180) S&S EAT8',
#  'GTi 200KW (270CV)',
#  '1.5 BLUEHDI 96KW TECH EDITION 5P',
#  '5P Allure BlueHDi 96kW (130) S&S EAT8',
#  '2.0 BLUEHDI AUTO GT 180 CV 4P',
#  'Tech Edition 1.5 BlueHDi',
#  'PureTech 96kW (130CV) EAT8 GT Line',
#  'Active BlueHDi 96kW (130) S&S 6vel MAN',
#  '5p Allure 1.5 BlueHDi 96KW (130CV)',
#  '5P GT PureTech 165kW (225) S&S EAT8',
#  '1.6 HYBRID 225 ALLURE PACK E-AUTO 225 5P',
#  '1.6 PHEV 225 E-EAT8 GT 225 5P',
#  'PureTech 96kW (130CV) EAT8 GT Line',
#  '*NEW MODEL* 1.5D ALLURE *8 TRAPS AUTOMAAT*GPS*SENS',
#  '5p  BlueHDi 130 S&S Active',
#  '5P  BlueHDi 130 S&S EAT8 Allure Pack',
#  '5P  PureTech 130kW (180) S&S EAT8 Active',
#  '1.6 Hybrid 225cv eEAT8  GT Pack',
#  'Active BlueHDi 96kW (130CV) S&S EAT8',
#  'Allure BlueHDi 96kW (130) S&S 6vel MAN',
#  '1.2 PureTech 100 Allure EAT8',
#  'GT Line 1.5 BlueHDi Man.6',
#  'Active 1.6 BlueHDi 88KW (120CV) EAT6',
#  'Allure Vrij/libre 10/2022',
#  'STYLE VTI 72',
#  '1.5 BLUEHDI ACTIVE 100CV 5P 2 PLAZAS',
#  '1.5 BLUEHDI 130 ALLURE AUTO 5P',
#  '16V SR',
#  '5P Tech Edit. PureTech EAT6 81KW (110CV)',
#  'GT Line 1.6 BlueHDi 88KW (120CV)',
#  '5P  BlueHDi 120kW (160) S&S EAT8 GT Line',
#  '5p Style 1.6 BlueHDi 88KW (120CV)',
#  '5p Style 1.6 BlueHDi 88KW (120CV)',
#  'GTi by  SPORT',
#  'PureTech 73kW (100CV) Active Pack',
#  'Business Line BlueHDi 96kW S&S 6vel MAN',
#  '1.5 BLUEHDI 73KW GT LINE 5P',
#  '5P ALLURE 1.2L PureTech 110 S&S',
#  '1.2 PureTech 60KW (82CV)',
#  '5P Signature 1.2L PureTech 60KW (82CV)',
#  '1.5 HDI 100cv',
#  '5P ACCESS 1.2L PureTech 50KW (68CV)',
#  'PureTech 73kW (100CV) Active Pack',
#  'PureTech 73kW (100CV) Active Pack',
#  'Allure 1.2 PureTech 100 EAT8',
#  '2.2 Sport',
#  '1.6 e-HDi 112 CV ca. rob. S&S Active',
#  'GTI BY SPORT 1.6 PURETECH 263 CV 5P',
#  '5P ACCESS 1.6 BLUEHDI 75',
#  '308 ALLURE PACK 1.5 BlueHDi 130  EAT8  PARK ASSIT+',
#  'GT Pack 1.6 PT 225pk EAT8',
#  'GTI 1.6 THP 270 CV S&S 5P',
#  nan,
#  '5P ALLURE 1.2L PureTech 110 S&S',
#  '1.5 BLUEHDI 96KW TECH EDITION 5P',
#  '1.6 BlueHDi S\\u0026S - 120 - BV EAT6  BERLINE Acti',
#  '1.5 BlueHDi Allure S&S 130',
#  'business line bluehdi 130 eat8',
#  '1.6 PureTech GT Line 5p',
#  '2.0 HDi 16V FAP - 136  BERLINE Confort Pack GARANT',
#  '1.5 BLUEHDI 96KW ALLURE 5P',
#  'GT LINE PURETECH 130 EAT8',
#  '5P  PureTech 130 S&S EAT8 Active Pack',
#  '1.6 THP 270  GTi by Peugeot Sport',
#  '1.6 BLUEHDI 88KW BUSINESS LINE 120 5P',
#  '5P  Hybrid 225 eEAT8 GT',
#  '1.9 TD GREEN 5P',
#  '1.5 BlueHDi 130 ALLURE S&S EAT8',
#  '5p  PureTech 110 S&S Allure Pack',
#  'I Active',
#  '1.5 BlueHDi Allure S&S 130',
#  '5P ALLURE 1.4 HDi 68',
#  'GT PACK HYBRIDE',
#  'gt line',
#  '1.5 BLUEHDI 73KW BUSINESS LINE 100 5P',
#  '5P  BlueHDi 120kW (160) S&S EAT8 GT Line',
#  'GT BHDI 130 EAT8 Sportpaket Navi uvm...',
#  '1.5 BlueHDi 130 allure S&S EAT8',
#  'III GT PACK 225',
#  'GT',
#  '5P  Hybrid 180 eEAT8 GT',
#  '5P  BlueHDi 130 S&S EAT8 GT',
#  '1.6 VTi 5P - 155 / 2011',
#  'ii 1.2 puretech s\\u0026s 100 active pack',
#  '1.2PureTech Active Pack S&S *NEW 308 STOCKDEAL*09.',
#  '1.2PureTech Allure Pack LED/Airco/DAB **NIEUWSTAAT',
#  '595',
#  '1.5 HYBRID MHEV DCT GARMIN 130 5P',
#  'BEV HB E ICON 87KW 118CV',
#  'LOUNGE / PANO',
#  'Elektro ICON 42 kWh * PARK PAKET * NAVI * RÜCKFAHR',
#  'Elektro ICON 42 kWh * PARK PAKET * NAVI * RÜCKFAHR',
#  '1.3 MJet 95cv Cargo Base N1',
#  'BEV',
#  'Wenig Km 8-fach TÜV 10.2023',
#  'Icon Elektro 42 kWh * PARK PAKET NAVI RÜCKFAHRK...',
#  '595 esseesse Urban Akrapovic Beats Brembo',
#  nan,
#  '1.3 M-Jet AIRCO CRUISE CONTROLE',
#  nan,
#  '1.4 T-Jet Tur Akrapovic!',
#  'Cross 1.0 100pk Dab+ Navi Camera',
#  'Mirror 1.2l 69ch CLIM',
#  '1.2i 69 sport',
#  'Hybrid *Cruisecontrol*DAB*Airco',
#  '120 pk S-Design Navi Pdc DAB + 18inch',
#  nan,
#  '1.2 GASOLINA 60 CV 5P',
#  '1,2 Lounge * Louis Vuitton *',
#  'Lounge 1.2l 69ch',
#  'LOUNGE FULL OPZIONAL CON TETTO APR ELET PRONTI VIA',
#  'LOUNGE 1.2 69CV 3P',
#  '1.2 70CV LOUNGE 3P',
#  '1.0 Hybrid 51KW (70 CV) Sport',
#  '1.2 8v 51kW (69CV) Lounge',
#  '1.2 8v 51kW (69CV) Lounge',
#  '2.0 Automatik 76\u202fkW (103\u202fPS), Automatik, Fronta...',
#  'Descapotable Manual de 2 Puertas',
#  '1.2 8v 51kW (69CV) Lounge',
#  '522L Cabriolet',
#  'Lusso 1.4l 136ch',
#  nan,
#  'Lusso',
#  'E 3+1 ICON 320KM 87KW',
#  'Lusso',
#  'Lusso',
#  'Lounge 1.2 8v 51KW (69 CV)',
#  'Lusso',
#  'C 1.2 8v 51kW (69CV) Lounge',
#  'C 1.2 8v 69 CV Pop',
#  'C 1.2 8v 69 CV Pop',
#  'C 1.0 Hybrid 70cv Dolcevita',
#  'Lounge 1.2 8v 51KW (69 CV)',
#  '1.2 8v 51kW (69CV) Lounge',
#  'C 1.0 Hybrid 70cv Dolcevita SS Edition',
#  '1.2 8v 51kW (69CV) Lounge',
#  '1.2 8v 51kW (69CV) Lounge',
#  'Lounge 1.2 8v 51KW (69 CV)',
#  '1.2 8v 51kW (69CV) Lounge',
#  'C Lounge 1.2 8v 51KW (69 CV)',
#  'C 320km 118cv Auto. Icon',
#  '1.2 8v 51kW (69CV) Lounge',
#  'C 1.2 8v 51kW (69CV) Lounge',
#  'C 1.2 8v 69 CV Lounge',
#  '1.2 8v 51kW (69CV) Lounge',
#  'C 1.2 8v 51kW (69CV) Lounge',
#  'C 1.2 8v 51kW (69CV) Lounge',
#  'C 1.2 8v 51kW (69CV) S',
#  'C 1.2 8v 51kW (69CV) S',
#  'C 1.2 8v 69 CV Pop',
#  'BEV 24KWH RED 95 2P',
#  '1.2 8v 51kW (69CV) Lounge',
#  '1.2 8v 51kW (69CV) Lounge',
#  '1.2 8v 51kW (69CV) Lounge',
#  'Lusso',
#  'C Lounge 1.2 8v 51KW (69 CV)',
#  '1973 FIAT COUPE',
#  'LOUNGE NAVI CAR PLAY SENSORI PARCHEGGIO',
#  'Coupe Klima',
#  '128 A1 Coupe Moretti 1300',
#  ...]

# %%
# After the groupby operation, how many NaN values do I have remaining?

df.groupby(['make_model', 'body_type'], group_keys = False)['seats'].transform(lambda x: x.fillna(x.mode()[0]) if len(x.mode()) > 0 else x).isnull().sum()
# Out:
# 177

# %%
df["seats"] = df.groupby(['make_model', 'body_type'], group_keys = False)['seats'].transform(lambda x: x.fillna(x.mode()[0]) if len(x.mode()) > 0 else x)

# %%
handle_missing_values(df , "seats")
# Out:
# Missing Values in 'seats':
# Count: 177
# Percentage: 0.62%

# %%
# After the groupby operation, how many NaN values do I have remaining?

df.groupby(['make_model'], group_keys = False)['seats'].transform(lambda x: x.fillna(x.mode()[0]) if len(x.mode()) > 0 else x).isnull().sum()
# Out:
# 34

# %%
df["seats"] = df.groupby(['make_model'], group_keys = False)['seats'].transform(lambda x: x.fillna(x.mode()[0]) if len(x.mode()) > 0 else x)

# %%
handle_missing_values(df , "seats")
# Out:
# Missing Values in 'seats':
# Count: 34
# Percentage: 0.12%

# %%
df.groupby(['body_type'], group_keys = False)['seats'].transform(lambda x: x.fillna(x.mode()[0]) if len(x.mode()) > 0 else x).isnull().sum()
# Out:
# 0

# %%
df.seats = df.groupby(['body_type'], group_keys = False)['seats'].transform(lambda x: x.fillna(x.mode()[0]) if len(x.mode()) > 0 else x)

# %%
handle_missing_values(df , "seats")
# Out:
# Missing Values in 'seats':
# Count: 0
# Percentage: 0.00%

# %%
df.seats = df.seats.astype(int).astype(float)

# %%
# a = df['seats'].fillna(df.groupby(['make', 'model'])['seats'].transform('mean'))
# a

# %%
# a.value_counts()

# %%
# a.isnull().sum()

# %%
# b = pd.concat([a, df[["body_type", "doors", "comfort_&_convenience"]]], axis = 1)
# b

# %% [markdown]
# <a id="13"></a>
# <div class="alert alert-info" role="alert">
# <h1>Column name :<span style="color:red"> empty_weight </span></h1>
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Operation : </b> To fill in the missing values in the "empty_weight" column, we can use the "short_description" column . Since the "empty_weight" column is associated with <span style="color:red"><b> " make " " model " " body_type " and " engine_size "</b></span> . let's fill in the <span style="color:red"><b> NaN values</b></span> in this column by grouping the data based on these columns and performing the necessary operations.
# </div>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
first_looking("empty_weight")
# Out:
# column name    :  empty_weight
# --------------------------------
# per_of_nulls   :  % 37.94
# num_of_nulls   :  10851
# num_of_uniques :  1216
# NaN       10851
# 1395.0      233
# 1055.0      223
# 1423.0      216
# 1165.0      200
#           ...
# 473.0         1
# 2156.0        1
# 826.0         1
# 2232.0        1
# 1391.0        1
# Name: empty_weight, Length: 1217, dtype: int64

# %%
# Let's examine the short description of the seats
list(df.loc[df[df["empty_weight"].isnull()].index, "short_description"])
# Out:
# ['CDi',
#  '350+',
#  'S 4Matic+ 8G-DCT',
#  '4Matic+ 7G-DCT',
#  '4MATIC',
#  'A -Klasse A 180 CDI aus 2-Hand & sehr gepflegt**',
#  'e Limousine',
#  '4Matic+ 7G-DCT',
#  nan,
#  'd 4Matic (EURO 6d)',
#  'S 4Matic+ 8G-DCT',
#  'CDI',
#  'Avantgarde/Park Assis/Navi/Scheckheft/Bi-X',
#  'Limousine',
#  nan,
#  'CDI Elegance',
#  'd AMG Line (EURO 6d)',
#  'Berline - Garantie 48 mois - 316.41 €/mois*',
#  'd (177.003)',
#  'progressive mbux, dab, apple carplay',
#  '-Klasse Navi RDC Klima SHZ DVD CD-W CD MP3 ESP MAL',
#  'd (177.003)',
#  nan,
#  'e AMG MBUX-MEMORY-TOT-SPURHALTE-NAVI',
#  'Business Solution LED GPS PDC CAM Verw. Zetels',
#  nan,
#  'Kompaktlimousine Rückfahrk+Vorrüst AHK+WDG',
#  '/Automatik/TSC/SHZ/ISO/Scheckheft/2.Hand/',
#  'd Progressive+LED+PSD+MBUX High-End+Kamera',
#  'd AMG-Line+Navi+PSD+LED+Rückfahrkamera',
#  'A-CLASS A180 1.3 136 CV 7G-DCT 5P',
#  'S 4MATIC+',
#  'd Avantgarde Largo',
#  'progressive mbux, camera, lane assist, pdc',
#  'progressive led high performance, mbux, lane assis',
#  '4Matic+ 7G-DCT',
#  'S 4Matic+ 8G-DCT',
#  'S 4Matic+ 8G-DCT',
#  'Business Solution AMG',
#  'Business Solution AMG',
#  'Business Solution AMG',
#  'AMG A 35 4MATIC',
#  'Business Solution AMG',
#  'd (177.003)',
#  'Automaat | Leder Interieur | 1j Garantie',
#  'CDi',
#  'd (177.003)',
#  '200 CDi 1.8 CDI Boîte auto',
#  'S 4Matic+ 8G-DCT',
#  'CLASSE  d Fascination 4Matic 7G-DCT',
#  '200 d Fascination 7G-DCT',
#  nan,
#  '4Matic 7G-DCT',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '35 AMG 306ch 4Matic 7G-DCT Speedshift AMG',
#  'AMG-LINE',
#  'd *Tempomat *Sport-Lenkrad *Touchpad *Apple - Carp',
#  'CLASSE  CDI Inspiration',
#  'AMG LINE -PANO',
#  'd Style + Pneus Hiver',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  'Aut. *PDC *Pano *Tempomat *Sportsitze',
#  '200 d 150ch Progressive Line 8G-DCT 8cv',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '200 d Business 7G-DCT',
#  '200d 7G-DCT',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '220 d Fascination 7G-DCT',
#  '35 AMG 306ch 4Matic 7G-DCT Speedshift AMG 19cv',
#  '200 d Inspiration 7G-DCT Euro6c',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  'd Progressive 7G-DCT',
#  '220 190ch Progressive Line 7G-DCT Siege chauf gran',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  'd 4Matic AMG Line (EURO 6d)',
#  '220 d 190ch AMG Line 8G-DCT 10cv GPS Camera Radar ',
#  '180 d 116ch Business Line 7G-DCT',
#  '200 d 150ch Business Line 8G-DCT GPS Camera',
#  '180 d 116ch AMG Line 7G-DCT',
#  '200 d Inspiration 7G-DCT',
#  'Hatch * Carplay | Parkeersenoren | Zetelverw.',
#  '200 163ch Style Line 7G-DCT',
#  '35 AMG 306ch 4Matic 7G-DCT Speedshift AMG TOuvrant',
#  '200 d 150ch AMG Line 8G-DCT 8cv',
#  'd Style + Pneus Hiver',
#  '200 d Fascination Tpano GPS Camera',
#  'CDI 100kW ( 136CV ) Urban',
#  '180 d 116ch AMG Line LED GPS Camera Radar AV/AR',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '180 136ch Progressive Line 7G-DCT 7cv',
#  'd',
#  '180 d Sensation 7G-DCT',
#  '200 d 150ch AMG Line 8G-DCT',
#  '220 190ch Progressive Line 7G-DCT',
#  '180 d Sensation 7G-DCT',
#  '180 136ch Business Line 7G-DCT',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '220 190ch Progressive Line 7G-DCT Ecran 10 GPS Cam',
#  '180 d Intuition 7G-DCT',
#  '160 109ch Style Line',
#  '200 163ch AMG Line 7G-DCT',
#  '160 Inspiration 7G-DCT',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '180 d 116ch Progressive Line 7G-DCT',
#  'Coupé 3.0 CDI V6 DPF 7G-TRONIC BlueEFFICIENCY 265',
#  'S 4Matic+ 8G-DCT',
#  'd Progressive',
#  'E 280',
#  'S 4Matic+ 8G-DCT',
#  'd Premium',
#  'S 4Matic+ 8G-DCT',
#  'S 4Matic+ 8G-DCT',
#  'S 4Matic+ 8G-DCT',
#  '4Matic 7G-DCT',
#  'S 4Matic+ 8G-DCT',
#  '4Matic+ 7G-DCT',
#  '4Matic+ 7G-DCT',
#  '4Matic+ 7G-DCT',
#  'S 4Matic+ 8G-DCT',
#  '4Matic 7G-DCT',
#  'S 4Matic+ 8G-DCT',
#  '4Matic 7G-DCT',
#  '4Matic+ 7G-DCT',
#  'Sedán 4Matic+ 7G-DCT',
#  'MERCEDES-BENZ Clase GLK Pequeño  Automático de 5',
#  '4Matic+ 7G-DCT',
#  'S 4Matic+ 8G-DCT',
#  '4Matic+ 7G-DCT',
#  'Pequeño Automático de 5 Puertas',
#  '4Matic+ 7G-DCT',
#  '4Matic+ 7G-DCT',
#  'S 4Matic+ 8G-DCT',
#  '4Matic Coupe 4Matic+ (EURO 6d-TEMP)',
#  nan,
#  'S 4Matic+ 4Matic (EURO 6d)',
#  'S 4Matic+ 8G-DCT',
#  '180d 8G-DCT',
#  '4Matic+ 7G-DCT',
#  'de 4Matic AMG Line (EURO 6d)',
#  'CDI Premium',
#  'd (177.003)',
#  'BlueEFFICIENCY Urban',
#  'CDI',
#  '4Matic 7G-DCT',
#  'd (177.003)',
#  'S 4Matic+ 8G-DCT',
#  '4Matic+ 7G-DCT',
#  'CDI Style',
#  'Special Edition Xenon Leder Memory Kam',
#  'Aut. Comand+Xen+Airsc+SHZ+PDC+Leder',
#  'Roadster~KAMERA~LEDER~\xa0GT FELGEN~XENON~',
#  'Kompressor AUT. AVANTGARDE *BI-XENON*KLI',
#  'Kompressor AUT. AVANTGARDE *BI-XENON*KLI',
#  'Cabrio~  AMG-LINE PLUS ~ Leder~Comand~LED',
#  'AMG Gepflegt MEMORY BI-XENON NAVI',
#  'C Roadster',
#  'Biturbo V-Max',
#  'Roadster*Magno*Night*SportAga*Distr+*RFK*',
#  'SL 65 V12 612PS AMG Roadster ACC Panorama ABC',
#  'E -Klasse Cabrio E 400 AMG Styling Paket',
#  'abrio Mercedes-AMG 4MATIC',
#  'MERCEDES-BENZ Clase SL Descapotable  Automático d',
#  'SL Autom, Leder, Sitzheiz.',
#  'Sport Edition Autom. COMAND AIRSCARF PDC',
#  '4Matic Cabrio *Swarovski*Nachtsicht*HuD',
#  'SL *Pagode*3.Besitz/Dt.Fahrzeug/H-Zul.',
#  "*LEDER*NAVI*KAMERA'SITZBELÜFTUNG",
#  'Roadster *DEUTSCH* (BOSE/DESIGNO/BI-XE',
#  'Kompressor Xenon SHZ PDC Klimaauto.Leder',
#  '367PS Cabrio Bi-Xenon Keyless-Go MOPF',
#  nan,
#  'MercedesAMG',
#  '*EURO6*NAVI*PDC*CUIR*LED*AIRSCARF*SIEGES CHAUFFANT',
#  'AMG-Night MBUX+360°+Distronic+DIG-LED',
#  'Roadster AMG/BIXENON/BURMESTER/KEYLESS',
#  'PERFORMANCE NIGHT SPORTABGAS BURMESTER',
#  'Cabrio 7G-Tronic+LED+Navi+Leder+H&K+Aircap',
#  'Roadster*Sport-AGA*Burm*Distr+*Night*Keyl',
#  'H&K Navi-Command Airscarf Panorama-Vario',
#  'Cabrio Benzine Autom. - airco - Leder',
#  'd 4M Cabriolet AMG Sport Distr LED Navi',
#  'SLK Roadster 200 Kompressor*Leder*SHZ*Klima',
#  'Roadster Automatik Radio/CD 18" ALU',
#  '435cv AMG ***SOLO 37.000KMS *** LIBRO OFICIAL',
#  'd 4M Cabriolet AMG Sport ABC Distr LED',
#  'Roadster BI-XENON SHZ NAVI PDC VO+HI AUTOMATIK',
#  'd Cabrio AMG-Line 9G-Tronic +LED+Leder+H&K',
#  'SL Pagode',
#  'Cabrio Xenon Leder  SHZ AIRSCRAFT AIRCAP',
#  'Cabrio-AMG PAKKET- Nekverwarming - Windscherm',
#  'K Facelift Sport-Paket Bi-Xenon,Airscarf',
#  'CGI  Roadster BlueEFFICIENCY Sport-Paket',
#  'Roadster Comand+RüKam+LED+PerfAbgas+Distr',
#  'UNIEKE SL 560 EUROPESE LOOK IN NIEUWSTAAT.AUTOM.',
#  'd Cabriolet',
#  'Cabriolet AMG Line',
#  'r107 original belgian delivery! first owner car.',
#  'abrio Mercedes-AMG 4MATIC',
#  'K R 170 KLIMA SITZHEIZUNG LEDER AUTOM',
#  nan,
#  'Roadster Kompressor Original Brabus Umbau',
#  'Cabrio*Avantgarde*Automatik*Leder*SHZ',
#  'd Cabriolet AVANTGARDE',
#  'CABRIO NAVI KAMERA MULTIBEAM AHK SITZKLIMA',
#  'E -Klasse Cabrio E 200 +AMG LINE+NAVI+CAM+',
#  'Cabrio CGI Automatik Nackenheizung',
#  'Roadster Kompressor/Xenon/Navi/Leder',
#  'R107 Cabrio Hardtop + Softtop H-Kennzeichen',
#  'Roadster Leder LED Kurvenlicht Panorama Fernlichta',
#  'S Cabriolet Wide 20" Burm Sitzklima',
#  'Cabriolet AMG Night Edition LED Navi SH',
#  'd Cabrio EU6, d AMG Line 9G-TRONIC',
#  'perfekte Komplettrestaurierung, nur 67.000 km',
#  '4M+ Night+MBUX+Distro+21AMG+360°+HUD',
#  '4M+ Cabriolet Vmax Distr LED HUD Nav',
#  '200K',
#  'R107 Cabrio Hardtop + Softtop US Modell H-Kennzeic',
#  'Kompressor Aut. Cabrio Final Edition',
#  'Kompressor Aut. Cabrio Final Edition',
#  'Cabrio CGI BE Avantgarde',
#  'C63 AMG Burmester|HeadUp|ACC|Perf.-Abgasanlage',
#  'CGI BlueEfficiency AMG Line *2J. Garantie*',
#  'Cabrio AMG Line Navi/Alcantara/Temp/Kamera',
#  '* Klima* Sitzheizung* Alu*',
#  'Kompressor+metallic Lackierung',
#  'Cabrio d',
#  'SL Roadster',
#  'Navi PDC SHZ',
#  'Kompressor Aut. Cabrio Final Edition',
#  'AMG COMAND+ILS+SITZKLIMA+VARIO+BURMESTER',
#  '163 PS Kompressor Cabrio  Final Edition',
#  'd Cabrio 9G-Tronic AMG Line+LED+Navi+Leder+',
#  'Deutsches Fahrzeug  Sammlerzustand',
#  'Cabrio d',
#  'SL Vollrestauration',
#  'Cabrio AMG Line 9G-Tronic+Nav+LED+Airscarf',
#  'Originale 52.000KM Roadster SHZ TEMPO',
#  'E -Klasse Cabrio E 200 AMG Line+Burmester+CAM',
#  'Cabrio AMG-Line*AUTOMATIK*KAMERA*KLIMAAUTOMATIK*',
#  'AMG*Kamera*Burmester*Aircap*Airscarf*Navi*',
#  'Roadster Kompressor SCHWARZ AUTOMATIK KLIMA LEDER',
#  'AMG 9G+NAVI+LED+RFK+VARIO+AMBIENTE',
#  'AMG Paket Kamera SoundSyst Memory HUD 19"',
#  'Cabrio d',
#  'Roadster/TEMPO/SHZ/BOSE Sound/',
#  'Roadster Kompressor Cabrio Leder Klimaaut.',
#  'Kompressor+KLIMA+16-ZOLL+SPORTSITZE+LEDE',
#  'C220d Cabrio AMG Line Navigation Sitzheizung Kamer',
#  'Cabrio AMG Line High-End Info Adv.Park',
#  'd Cabrio Avantgarde Mulitbeam Burmester',
#  'AMG Paket H/K Belüftung Panorama Comand',
#  'BE*AMG-Line*Aut*ILS*Pano*Leder*Shzg*',
#  'Roadster + hardtop',
#  'MOPF II komplett Umrüstung D incl. Tacho',
#  'Navi*Alu19*Leder*',
#  'Cabriolet AMG Line',
#  '-CLASS 6.2 COUPE SPORT AUTO 457 2P',
#  'Classe E AMG 53 4MATIC+',
#  '7G-TRONIC-Facelift-Sportpaket-1.Hd!!!',
#  'Cabrio Avantgarde Xenon Memory Leder',
#  'SL63 AMG Carbon Editie | 1ste Eig | 1j Garantie',
#  'LED  AMG-Night-Paket COMAND  Airscarf',
#  'Carbon Editie - 1e eigenaar - Keuring + Garantie',
#  'Roadster*Distronic*Bose*Sitzk.*2.Besitz*Ö-Auto*',
#  'C43 AMG Cabrio Schalensitze Burmester Head UP 360',
#  'Mercedes- C Roadster',
#  'SL',
#  '(R129) 2nd Owner/Collectable',
#  '/ incl. Garantie / 2 Jahre HU & AU frei',
#  'SL Roadster SL 63 AMG Keramik Top-Zustand',
#  'Sport*MAE Original*Bose*Memory*Xenon*',
#  'Extrem gepflegtes Ex-Pressefahrzeug W 231',
#  'CLK Cabrio CLK 55 AMG Deutsches Top Auto',
#  '(R171) 350 7GTRO',
#  'Cabrio',
#  'V8 Cabrio Aut.',
#  'SL',
#  'Cabrio',
#  'CABRIOLET 2.1 CDI 204CV AUTO GARANTIE 6 MOIS',
#  '220 d executive a',
#  '4M Cabrio AMG Distro+Parktronic+Spiegel',
#  'Cabrio 2.0i AMG - Burmester Aut. || FULL OPTION',
#  '200 AMG Sport 7G-Tronic BVA',
#  'SLK  200 Kompr. | 1.HAND (seit 05) | AIRSCARF',
#  '250 d Sport auto',
#  'Roadster Comand/Memory/19"/TOP',
#  nan,
#  '220 A Cabriolet',
#  'AMG Line',
#  'S cabrio BURMESTER | LED | 360° | TRACK PACE',
#  '190SL',
#  'Cabrio C 63 S AMG*NP.127782,- EURO*VOLL',
#  '4M Cabrio PerfAbgas.+M-LED+Comand+RüKam',
#  'S Cabriolet Ponton Typ A (W 180)',
#  'E Cabrio 220 d Premium auto',
#  nan,
#  'd Cabriolet',
#  'AMG Xenon Bose Leder Designo Navi',
#  'Coupe V8 / SCHIEBEDACH,LUFTFEDERUNG,XENON',
#  'V8 4Matic Autom. - Designo - Topstaat! 1Ste Eig!',
#  'Coupe Speedshift 7G-DCT Perf-Sitze/Carb',
#  'D',
#  'CLA 220d ShootingB 4Matic*AMG*Kamera*Distronic*',
#  'Coupe 4M DESIGNO,AKT.PARKASSIST,LED',
#  '7G-TRONIC 8-fach Navi PDC Klimaaut.',
#  'Coupe AMG Speedshift 7G-DCT',
#  'AMG GTC Edition 50*Designo*Magno*Pano*SitzKlima*',
#  'CDI COUPE AMG SPORT *LEDER*NAVI*LED*AHK*',
#  'AMG GLC 43 4MATIC Coupé',
#  'CLA 45 4M SB AMG SPORT NAVI TEMPOMAT PDC LED EU6',
#  'COUPE CARBONPAK 1+2 KERAMIK BURMESTER',
#  nan,
#  'PERFORMANCE SITZE PANORAMA BURMESTER',
#  '4Matic Coupe Speedshift TCT Navi/Leder/',
#  'd Coupe AMG 9G-Tronic Navi/Leder/Temp/360/',
#  'R COUPE CARBONPAK 1+2 KERAMIK BURMESTER',
#  '-CLASS 4MATIC',
#  'Coupe AMG Line',
#  '4MATIC+ Coupé',
#  'COUPE NIGHT PAKET BURMESTER HA-LENKUNG',
#  '4Matic*KAMERA*NAVI*LED*DESIGNO*SHZ*',
#  '4Matic*KAMERA*NAVI*LED*DESIGNO*SHZ*',
#  'S 4Matic+ 8G-DCT',
#  'oupé Mercedes-AMG 4MATIC',
#  'CE Liebhaberstück',
#  'SEb (111)*DEUTSCHES-FAHRZEUG*H-KENNZEICHEN*TOP-ZUS',
#  'd 4MATIC',
#  'd 4MATIC Coupé AMG Line',
#  '4Matic+ 7G-DCT',
#  'Urban+Navi+Leder',
#  '/Sammlerzustand/PDC/ Bose Sound/SH/',
#  'S 4.0 V8 DCT MATT CARBON KERAMIK V-MAX310',
#  'E300 COUPE AMG-LINE COMAND DISTRO HEAD-UP KEYLES',
#  'CLK Coupe 320/Automatik/Leder/Navi/Alus',
#  '4Matic AMG Speedshift TCT Navi/Leder/',
#  'Coupe *Nachtsicht-Assistent*BI-XENON TV',
#  'S Coupe',
#  'Mercedes-AMG S 4MATIC+',
#  '4M Coupe Panorama*AHK*Fahrassist*LED*',
#  'C 63 S COUPE AMG KEYLESS 360°KAMERA PANO HEAD-UP',
#  'Coupe 4M Standhz. LED Pano Navi SHD',
#  '4Matic (EURO 6d-TEMP)',
#  '-CLASS 3.0 4MATIC AUTO 333 2P',
#  '4M Coupé Performance Optik-Pack AHK',
#  'CGI BlueE. Aut. Elegance LEDER NAVI XENON',
#  'Coupe 4Matic Keramik/Carbon/360/Pano/Bu',
#  'e AMG Line+Pano+',
#  'CLA 45S AMG 4M+*Pano*Distr+*Burm*HuD*Night*360°*',
#  '4M AMG Sport Night 19" AHK MBUX Stand',
#  'd Coupé EXCLUSIVE',
#  '4M Coupé AMG Comand+RüKam+LED+Pano+HUD+18',
#  '53 4M+ V8 Styling Paket AMG Dynamic Pl',
#  'C Coupe*DEUTSCHES-FAHRZEUG*AUTOMATIK*H-KENNZEICHEN',
#  'S 4M+ Coupé AMG Dynamik-Paket 21"',
#  '63 4M+ Performance Night Massage Burm',
#  'C -Klasse Coupe C 200 AMG Line+Pano+Cam+',
#  'COUPE 4M BURMESTER HUD PANO STANDHZ 1HD',
#  'Coupe 4M+ DRIVERS+AKTIV SITZE+360+KERAM',
#  'Coupé PROGRESSIVE',
#  'Coupé',
#  'Coupe AMG + NIGHTPACK - LEDER - PANO DAK - 360° -',
#  'Coupé',
#  'AMG Line',
#  '333PS V6 AMG-Line Coupe 4Matic 9G-Tronic',
#  'Coupe*AMG-Line*MEMORY*SPURHALTEAS*360°CAM',
#  'AMG 4M*Panorama*MultiBeam*Comand*Burmester',
#  'Elegance Aut. Xenon Leder GSD ACC SHZ',
#  'Coupe 4Matic+ 21"AMG, Sternehimmel',
#  '4M Coupé PANO NACHTSICHT 360° KAM. KEYLESS',
#  'CDI Coupé',
#  'Coupé CDI',
#  'Compressor',
#  'CLA45 S AMG SB 4M HEAD-UP MULTIBEAM 360°KAM MBUX',
#  'E-Klasse Coupe 250',
#  'CLK Coupe 320 Elegance Xenon/ PDC /Schiebedach',
#  '4M+ Standhzg+Distro.+360°+Comand+AHK',
#  '220d Aut.',
#  'Coupé',
#  'Coupé AMG -Garantie 48 mois - 412,47 €/mois*',
#  'Coupé',
#  '4M+ designo Facelift Distr LED Nav',
#  'd 4MATIC',
#  'd 4M Coupé AMG-Line Night Standh AHK',
#  'S Coupé Aero Magno Keramik Vmax Dist',
#  'Matte wrapping',
#  "4M Night+Harman+Distro+Comand+Kam+19'",
#  'S 4M+ Coupé V8 Drivers+Comand+DAB+AHK',
#  'd 4MATIC -',
#  'S Coupé Perf.Abgas. Pano Night Driver`s',
#  'E200 Coupe AMG-Line Burmester+Memory+20erLM',
#  '-Klasse Coupe EU6d-T LED Navi Keyless e-Sitze Park',
#  'coupé 4.0 4MATIC 469 2P',
#  'SLC, 1 Hand, Scheunenfund, Oldtimer, Bastler',
#  'E53 AMG 4Matic Coupe Pano+Burmester+Multibeam',
#  'Mercedes-AMG BRABUS 800 GLE 63 S 4MATIC+',
#  'Coupé 7G-DCT AMG LINE - BURMESTER - SFEERVERLICHTI',
#  'AMG Coupe 4M WIDE+COMAND+RFK+LED+NIGHT',
#  'AMG Line 4Matic LED Panorama Head Up 360°',
#  'GLC250d 4M 2x AMG Line Coupé NAVI KAMERA AHK LED',
#  'd 4MATIC Coupé',
#  'Coupé d',
#  'C200 COUPE M-HYBRID AMG LINE LEDER NAVI LED PANO',
#  'AMG Line Panorama*AHK*Night*Ambiente*LED',
#  'd 4MATIC',
#  'Coupe*1.Hand*Deutsches Fahrzeug*Insp.NEU',
#  'CDI Chrome',
#  'e Coupé',
#  'Coupé d AMG LINE',
#  'd (205.314)',
#  'Coupé d',
#  '4M AMG*Kamera*MBUX-High*LED*Sound*7G-DCT',
#  'Mercedes-AMG GLC 63 S 4MATIC+ Coupé+DISTRONIC',
#  'Coupe AMG 9G-Tronic+LED+Navi+Kamera+Leder+',
#  'd 4M Coupé AMG Line',
#  'Coupé',
#  'CDI (LA) Sport Edition (203.708)',
#  'Coupé 220d',
#  'AMG-Line*Panorama*LED*19"*Ambiente*kamer',
#  'AMG*AHK*Panorama*Night*Ambiente*LED*MBUX',
#  'd 4M Coupé AMG Sport Burm3D EBC Stand',
#  'Coupe 4MATIC*AMG LINE*PANO*360°-Kamera*',
#  'Classe E 300d Coupé AMG Line Mercedes-Benz E Klas',
#  'd Edition*AMG LINE*NAVI*CAMERA*TOIT PANO*EURO6*',
#  '-Klasse Coupe CGI BlueEfficiency AMG Navi Dyn. Kur',
#  '-Klasse Coupe CGI BlueEfficiency AMG Navi Dyn. Kur',
#  'COUPE AMG -Line',
#  'Coupé AMG Line Pano Night Navi LED SH',
#  'Coupé',
#  'Komp Sportcoupe  XENON/NAVI/17ZOLL/LEDER',
#  'Coupe 4Matic Night Edition Navi/Distron',
#  'Coupé d AMG LINE',
#  'Coupé d 4MATIC',
#  'CDI Inspiration 7G-DCT',
#  'e 4Matic 7G-Tronic+Navi+Tempomat+',
#  'PERFORMANCE DESIGNO,SCHECKHEFT,STANDHZ',
#  'GLE 63 S AMG 4Matic CARBON*Jungsterne Garantie',
#  '*AMG SPORTPAKET*HARMAN KARDON*COMAND*2xPDC',
#  '4Matic Designo/Standh./Ahk/360°/8-Fach',
#  'CDI 4Matic*Bi-Xenon*Navi*Designo-Lack*SHD',
#  'd 4MATIC*NAVI*T.O PANO*AMG LINE*EURO6*PDC*CAMERA*',
#  '4MATIC',
#  'CDI  Bluetec 4Matic*Bi-Xenon*Euro6*',
#  'Blutec Glasdach Sportpaket Comand BiXenon',
#  'ANDERE AMG UNTERBODEN GESTRAHLT KONSERVIERT/SHZ',
#  '*4Matic*Night Paket *360°*Pano*Comand',
#  'CDI 4-Matic BE *INKL. 2 JAHRE GARANTIE*',
#  '4Matic 557PS Designo Speedshift Plus',
#  'd 4Matic AMG-Line Navi LED Pano Shzg AHK',
#  'GLS400d 4M*AMG*Massage*TV*Burm*7Sitz*Distr+*StHz',
#  '4m panorama, trekhaak, lichte vracht mogelijk !!',
#  'd Exclusive 4Matic 9G-Tronic+COMAND+LED+',
#  '4Matic AMG Line*Teilleder*Navi*LED*20"* AMG',
#  'AMG Line+CAM+Schiebdach+',
#  'GLA250 7G-DCT AMG Line+Bi-Xenon+inkl 2J Garantie',
#  'CDI BE /BI-XENON / NAVI / AHK / SHZ',
#  'd 4MATIC',
#  '4M AMG BANG+O,2xFONDTV,MASSAGE,SOFTCLOSE',
#  '4M AMG Line ILS Pano HUD Airmatic 360',
#  '4MATIC',
#  '4MATIC AMG Line',
#  'CDI Autom. - AMG - GPS - Leder  -Topstaat! 1Ste...',
#  '4MATIC',
#  '4M Magno Aero Performance Standhz.',
#  '1.6 STYLE Leder|Xenon|Navi|Alu|Sitzheiz.',
#  'EQ HEV HYBRID *4 MATIC*GPS*CAMERA*LED*ALU BI COLOR',
#  'd 4M AMG-LINE COMAND AIRMATIC 360°KAMERA',
#  'd 4Matic **Finanzierung**Garantie**9G**',
#  '5.5 507 PS Kompressor lang Designo BRD',
#  'CDI Autom. 4Matic - GPS - Pano - Topstaat!',
#  'd 4Matic AMG PAN-D LED Off-Road-Paket',
#  '4MATIC',
#  'CDI BlueTEC*Pano*Standheizung*Distronic*',
#  'CDI 4Matic AHK+Standhzg.+ACC+Xenon+Pano',
#  '4Matic Aut. *AMG*7-SITZER*EXCLUSIVE*DVD*L',
#  'd AMG Line 4Matic LED PANO R.Cam AHK COMAND',
#  'AMG Kamera BiXenon Memory  H/K GSD Leder',
#  'd 4Matic All-Terrain Estate Avantdarde',
#  'G Klasse 350d Mercedes-Benz G Klasse 350d - Direct',
#  '4M AMG Line',
#  '4M Offroad Exclusive AHK LED Navi Kam',
#  'd 4MATIC',
#  'Mercedes-AMG GLE 53 4MATIC+ PSD+AHK+Memory',
#  '4M Hybride - AMG LINE - Caméra-Garantie 48 mois',
#  'G 350 BlueTec LED BI-XENON*1J. PREMIUM GARANTIE',
#  'd 4Matic AMG 9G-Tronic Navi/Leder/Temp/K',
#  'Progressive SHZ PTS KAMERA NAVI LED',
#  'd 4Matic*ACC*BUR*COMAND*OFF-ROAD*KAM*',
#  'CDI Style Aut. +Navi+Bi-Xenon+Tempomat+',
#  '4MATIC AMG LINE',
#  'BlueTEC 7G Alcantara Standheizung H/K AHK',
#  'G63 Lang Version, DESIGNO Ausstattung schwarz r...',
#  'd AMG 4Matic Aut. +COMAND+LED+Kamera+Amb.',
#  "7G-DCT AMG + NIGHTPACK - ALU 19' - SFEERVERLICHTIN",
#  'GLC43 AMG Coupe 4M ILS+Pano+HUD+Burmester+360*',
#  'Coupé dA 4-Matic AMG Line Pro LEDER/CUIR LED GP',
#  'd 4 MATIC 245cv 9 vel. *IVA deducible* *2020* *Nac',
#  'd 4MATIC AMG Line',
#  'AMG G 63 AMG SPEEDSHIFT 7G-TRONIC',
#  'CDI',
#  '4x4² DESIGNO+STANDHZG+KAMERA+HARMAN+SHDACH',
#  'S Coupe Pano HUD Night 360Kamera Memory 466kW Burm',
#  'Style*Pano*Navi*Leder*LED*APS*',
#  'AMG LINE',
#  'CDI / 4Matic,Xenon,Navi,Allrad,Leder,SHZ',
#  '4Matic*Pano*MBUX*21"*RFK*Spurhalte*',
#  'BURMESTER-EXCLUSIVE-360°',
#  'GLS 400d 4MATIC AMG Line Mercedes-Benz GLS 400d 4M',
#  'AMG Line AHK Standhz. Distronic Widesc.',
#  'd 4MATIC',
#  nan,
#  'd AMG Line',
#  'd 4Matic (253.915)',
#  'night pack, panorama, burmester, memory seats, ful',
#  '4M 9G-TR. COMAND WEBASTO SCHIEBEDACH AHK',
#  'd Urban Aut. AAC XENON NAVI AHK KAMERA',
#  '4M AMG Line Night Navi Kamera LED SHZ',
#  'BlueTEC 4MATIC',
#  'Puch  JAGD-FZG./WINDE/KOFFER/BRAUSE/AHK',
#  '211 PS BlueTec Station AMG Totwinkel Kamer',
#  'd 4M AMG*Distronic*360°*Airmatic*AHK*ILS',
#  '4Matic Sportpaket *Kamera*Alcantara*LED*',
#  '4MATIC - Garantie 48 mois - 661,69 €/mois*',
#  '4M AMG-LINE MBUX PANORAMA 360°KAM DISTRO',
#  'd 4Matic Edition Power Aut. Navi AHK 360Cam',
#  'AMG GLC 43 4MATIC',
#  '4Matic *AHK*AIRMATIC*ACC*STDHZG*KAM*19Z*',
#  'e 4Matic',
#  '4Matic*Pano*MBUX*21"*RFK*Spurhalte*',
#  '300 4MATIC',
#  'Mercedes-AMG BRABUS 800 GLE 63 S 4MATIC+',
#  'd 4Matic*NAVIGATION*PDC*SHZ*ALU*',
#  'd 4Matic*MEMORY STANDHEIZUNG 360°CAM*',
#  '4MATIC',
#  'CDI 4Matic 7G-Tronic+Xenon+Navi+Leder+AHK',
#  '258PS 4Matic LED HIGH Luxury NAV CAM',
#  '525PS V8 Biturbo 4-Matic Panorama H&K',
#  'd 4Matic DoKa 7G Edition Progressive +LED+',
#  '4M Night Standhz LED Kamera Keyles',
#  'd 4M AMG Line Night Pano AHK HUD Stan',
#  'D ADVANTAGE + PAQ NIGHT',
#  'GLC 63 S AMG 4matic+  Night Keyless 21" Sound',
#  'd Progressive 4Matic LED Navi Widescreen',
#  '4M AMG*Pano*AHK*Spur*MBUX*MultiB*Kamera',
#  nan,
#  '4M+ AHK Standhz. Night Pano HUD',
#  'GE lang Cabrio Steyr-D-Puch AHK Automatik Rücksitz',
#  'CDI 4Matic BlueTec*Navi*Klima*StHzg*',
#  'Drivers Exclusive AHK Standhz',
#  'PROGRESSIVE EDITION/360/AHK/NAVI/LED/SITZH',
#  'Coupé 350D 258 CV',
#  'Puch PLANE/AHK/ALLRAD/SCHLIEßANLAGE NEU',
#  '+ Electric Art MBUX+LED+RüKam+El.Heck+18',
#  'DRIVERS+WIDE+STDHZG+360°+AKTIV SITZE',
#  'Mercedes-AMG 4MATIC',
#  '4Matic*Pano*MBUX*21"*RFK*Burmester*',
#  'd 4MATIC - AMG Line - Pano dak',
#  'D',
#  'Mercedes-AMG 4MATIC',
#  'e 4M Distro+Pano+M-LED+Komfort+Advancedp',
#  'Puch PLANE/AHK/ALLRAD/SCHLIEßANLAGE NEU',
#  'd PROGRESSIVE',
#  '200 d GPS PDC Pano Cruise Ctrl BT S&S',
#  'AERO-PAKET*PERFORMANCE SITZ*DESIGNO*',
#  'Mercedes-AMG 4MATIC+',
#  'd 4MATIC',
#  '4Matic*Pano*MBUX*21"*RFK*Spurhalte*',
#  'd 4Matic (253.915)',
#  'd 4M AMG Line+Night+PremiumPlus+Sitzklim',
#  'AMG Pano LED B&O 360Kam Massage AHK TV',
#  'd Style 7G-DCT BI-XENON NAVI RFK SHZ TEMPO',
#  'D 2.2 170CV AUT 5P',
#  'd AMG Line AHK Distr+ Standhz beh. WSS',
#  'BlueTEC XENON SHZ NAVI LUFT AHK*CAM',
#  'G65 AMG+ BRABUS+DISTR+SHD+H&K COMAND+TOTW+KAMERA',
#  'PERFORMANCE DESIGNO,SCHECKHEFT,STANDHZ',
#  'd 4MATIC',
#  '4MATIC 7G NAVI LEDER KAMERA PDC AHK',
#  'e 4MATIC',
#  'd Pack AMG',
#  'd 4M AMG-Line COMAND ILS Leder DTR+ 360°',
#  '316 DOKA+PRITSCHE+KLIMA 7 SITZER 316 CDI',
#  'Urban Business Paket *2 JAHRE GARANTIE*',
#  'CDI BlueTEC*KAMERA*XENON*NAVI*LEDER*',
#  '4M COMAND 360°KAMERA AIRMATIC KEYLESS',
#  'Urban',
#  'CDI 4Matic COMAND LED KEYLESS 360°KAMERA',
#  '4M AMG-LINE COMAND PANO KEYLESS 360° KAM',
#  'd',
#  'd T 4Matic AMG*Standheizung*AmbientLight*',
#  'E350T CDI BlueEff. COMAND SITZKLIMA DISTRONIC',
#  'T CDI 4MATIC Elegance | Airmatic | AHK',
#  'E Break dA Exclusive Ext./AVG Int. Business LEDER/',
#  'd break AMG Line',
#  '4M HUD,KEYLESS,DISTRO,COMAND,STANDHEIZ.',
#  'CDI Break - GPS - Airco - Leder - Goede Staat!',
#  'T CDI*Bi-Xenon*Avantgarde*Standheizung*',
#  'T-Modell/AMG-Line/SHZ/NAVI/PANO/St.HZ/Full',
#  'BREAK |\xa0PANO | DESIGNO | CARBON | CAMERA | LED',
#  'd T Business 9G Aut +LED+AHK+Kamera+Navi',
#  'Shooting Brake d AMG NIGHTPAKET DISTRO',
#  'T 4Matic+ *Hybrid*VirtualC*Night Paket',
#  'T CDI Avantgarde Export',
#  'T 4Matic+ *Hybrid*VirtualC*Night Paket',
#  'CLS 250 Shooting Brake Sport-Paket',
#  'E -Klasse T-Modell E 350 BlueTEC 4Matic AMG LINE',
#  'AMG E 43 4Matic T 9G-TRONIC PDC SHZ NAVI',
#  'Autom. 4Matic - GPS - Topstaat!',
#  'E280 T Kombi Automatik Radio 7-Sitzer Alufelgen',
#  'E -Klasse T-Modell E 250 CDI BlueEfficiency',
#  'E220 :d T 9G-TRONIC Avantgarde*BURMESTER*ACC*',
#  'Shooting Brake 4M AMG KEYLESS,DISTRONIC',
#  'T AHK LED Navi Night-P. Ambiente el.Klappe',
#  'T AVANTGARDE COMAND,CARPLAY,KAMERA,SH,LED',
#  'd T+Navi+Kamera+Pano+Tempomat',
#  'CGI Avantgarde Aut. +COMAND+Bi-Xenon+GSHD',
#  'SB URBAN NAVI/TEMP./AHK/SHZ/DAB+/PDC/USB',
#  'Sport-Paket',
#  'T 4MATIC COMAND SHZ KAMERA NAVI LED',
#  'd T 210KW*ACC*MULTIBEAM*KAM*COMAND*DAB*',
#  'Break dA Business AVG Int. LEDER/CUIR LED GPS PDC',
#  'CDI BlueEfficiency Avantgarde 2J. Garantie',
#  'CDI Avantgarde 4MATIC Bi-Xenon RCam Sitzklima PDC',
#  'T Leder / Navi / Xenon / Klima',
#  'AMG CLA 35 4MATIC Shooting Brake',
#  'T CDI 4Matic*Airmatic*StHz*Distronic',
#  'T 9G AMG LINE*LED*COMAND*KAMERA*BURMESTER*',
#  'S T 4M+ Standhz. Pano Keramikbremse',
#  'C220d 4Matic AHK+Standhzg+LED+Ambiente+Navi',
#  'd 4Matic T 9G-Tronic*Navi*LED*PDC*GRA*',
#  'T-Modell BlueTEC d T Avantgarde',
#  'SB AMG line*Led*Navi*',
#  'SB Urban Night Paket 7G Aut+Xenon+Memory',
#  'T-Modell CDI 4-Matic LED KLIMAAUTO TEMPO',
#  'C 63s AMG T 7G-Tronic+LED+Kamera+Burmester+Pano+',
#  'S T 4M+ ohne OPF Magno Vmax Perf Car',
#  'E250 T-Modell CGI/TSGS/NAVI/ASSIS+/TEMPO/SchaltW',
#  'SB d LED Navi SHZ Einparkh. Parkassis',
#  'd T AMG Line 4Matic Aut. +COMAND+LED+LEDER+',
#  'D T EXCLUSIVE 4MATIC AUTOMATIK (+EURO6+ALLRAD',
#  'BlueTEC AMG-Line',
#  'T d NIGHT WIDESCREEN,360GRAD,MULTIBEAM,AHK',
#  'T d AVANTGARDE COMAND KAMERA MULTIBEAM',
#  'd T Leder 194PS Navi Leder Kamera LED BT',
#  'CGI 4-Matic 7G-Tronic Elegance+BiXen+Navi',
#  'CGI 4-Matic 7G-Tronic Elegance+BiXen+Navi',
#  'd T  Avantgarde / DISTRONIC / LED / SHZ',
#  'C63 S AMG DESIGNO HUD BURMESTER PANO DRIVERSPACK',
#  'E300d T AVANTGARDE AMG-LINE KAMERA WEBASTO PANO',
#  'CLS SB 250d 7G-Tronic 4M AMG-Line +Comand+360°+',
#  'CLASSE B B 180 d BE Edition',
#  'Performance 4Matic T-Modell *Virt.Cockpit|ACC*',
#  'SB 4-MATIC *NAVI,KAMERA,PDC,LED,SHZ*',
#  'T-Modell E 220 d 4Matic All-Terrain',
#  'Shooting Brake 4M NIGHT EXKLUSIV MEMORY',
#  '(+)2.0 AVANTGARDE AUTO 211 5P STATE',
#  'C200 T Exclusive ILS Leder Kamera Navi Tempomat',
#  'C250 CGI T AMG Line 9G Aut+LED+Navi+Kamera+Leder',
#  'T 4-Matic Elegance *Distr.*360°*LED*Navi',
#  'C180 T Exclusive LED Navi Sitzheizung Tempomat',
#  'T d 4M AMG Line Panorama*Standhzg*AHK*360°',
#  'd AMG-Line WideS Multib Airm. HUD Sthz DTR+',
#  '4m sb panorama, night pack, keyless-go, sound',
#  'C220 d T Avantgarde T Avantgarde d',
#  'd T Exclusive Leder Navi',
#  'E -Klasse T-Modell E 220 d 4Matic All-Terrain',
#  'd T Exclusive +LED+Navi+Tempomat+EUR6+',
#  'E43T AMG COMAND DISTRONIC HEAD-UP 360°KAM AIRMAT',
#  nan,
#  'd T *NAVI,LEDER,KAMERA,LED,SHZ*',
#  'Garantie bis 2025/Panorama/Burmester',
#  'Estate',
#  'E300d T 2x AMG-LINE COMAND DISTRONIC AHK 360°KAM',
#  '4MATIC',
#  'Automatik T AMG-LINE/LED/LEDER/MFL/',
#  'd Shooting Brake',
#  'd Estate Avantgarde',
#  'd Estate',
#  'de Estate AMG LINE',
#  'T 4M 9G-TR. AVANTGARDE NAVI 360°KAMERA LED',
#  'CDI Blue Efficiency Estate',
#  'T COMAND Pano Sbel HUD AHK Burm. DTR+',
#  'VITO 116 CDI B.TEC TOURER PRO 8-S |NP50€|57tK|1H',
#  'AMG E 53 4MATIC+ Estate',
#  'd +LED+ T-Mod. +AHK+Amg Line+Pano+DIST+',
#  'C -Klasse T-Modell C 43 AMG 4Matic T',
#  'd T AMG Line PDach Standhzg Navi Nightpaket',
#  'CLS 350 BlueTEC /H&K SOUND/ AMG LINE / MULTIBEAM',
#  'S 4M+ T Vmax Performance AHK Distr L',
#  'd T 9G Avantgarde ~LED~Comand~Leder~AHK',
#  'T 4M+ Dynamic+ Carbon Massage Pano D',
#  'Mercedes-AMG 4MATIC Estate',
#  'CGI T 7-G Exclusive Navi,LED,2.Hand*56tkm*',
#  'lang Avantgarde Sitzklima vo+hi, Pano, Navi/SHD',
#  'EQV 250 Avantgarde Airmatic El Sitze vorne 7-Sitze',
#  'T d 4M AMG Line NP.102.519€*Standhz*Airmat',
#  'Break*MBUX*AVANTGARD*LED*T.O PANO*CUIR*NAVI*EURO6*',
#  'T 4Matic+ LEDER NAVI LED NIGHTPAKET 1HD',
#  'T COMAND PANO DISTRONIC KAMERA MEMORY',
#  'AMG Line',
#  'CGI Avantgarde LED Distronic + GSD AHK R.Cam',
#  'de Navi|Kamera|LED|Sitzhz',
#  'CLS 350 d SB AMG 9G+COMAND+360°+TOTW+LED+DISTR',
#  'SB S 4M+ Pano Night Kamera Navi LE',
#  'E450 T 4M 9G AMG-LINE WIDESCREEN KEYLESS HEAD-UP',
#  'SB S 4M+ Pano Night Kamera Navi LE',
#  'E450 T 4M 9G AMG-LINE WIDESCREEN KEYLESS HEAD-UP',
#  'd Estate Business Line',
#  'd Avantgarde 4Matic|Burmester|LED|COMAND',
#  'Estate Business Line',
#  'd AMG/rijassist',
#  'Estate Estate',
#  'd Estate',
#  'C400 4Matic ILS+ACC+Pano+HUD+AHK+Memory',
#  'Shooting Brake',
#  'd T AMG line Night Edition Navi/Temp/Kamer',
#  'd 4M T AMG Sport Night Burm Distr LED N',
#  'Shooting Brake AMG Line PDC Navi',
#  'E200 T CGI 7G-TRONIC LED Navi Sitzheizung Tempomat',
#  '(BlueTEC) d kompakt 7G-TRONIC Edition',
#  'CDI Urban Style Edition',
#  'CLA45 S AMG SB 4M HEAD-UP MULTIBEAM 360°KAM MBUX',
#  'T AMG 4M*Panorama*AHK*Kamera*Ambiente*LED*',
#  'DE-AMG line-GPS - Garantie 48 mois - 591€/mois*',
#  'd T 9G-TRONIC+LED+Navi+AHK+HuD+SHZ+',
#  'T AMG LINE MULTIBEAM WIDESCREEN AHK CAMERA',
#  'd Estate',
#  'de Estate',
#  'd 4M All-Terrain',
#  'd Estate',
#  'd AMG-Line COMAND Pano Carbon Airm Sbel DTR',
#  '(+)2.1 D AMG LINE 5P',
#  'd Estate',
#  'CLA-CLASS 2.1 D DCT SHOOTING BRAKE 136 5P',
#  'd T-Modell 9G AMG MULTIBEAM 360-K BURMES.',
#  'C Break 180d AVG Ext./AMG Line Int. Pro LEDER/CUIR',
#  'Shooting Brake AMG LINE',
#  'd avantgarde',
#  'T CGI Avantgarde*PDC*SHZ*Navi*',
#  'E 63T AMG 514 PS Avantgarde Airmatic Memory',
#  'C220d T Avantgarde LED Navi Leder Sitzheizung',
#  'd Estate Business Line',
#  'd AMG Night Edition 9G-DCT 194pk',
#  'SB e AMG',
#  'T LEDER NAVI MBEAM PANO CAM DISTRONIC',
#  'B200 CDI AMG AUT 136CV',
#  'Shooting Brake AMG Line 7G-DCT',
#  'd*AVANTGARDE*NAVI*PDC*EURO6*LED*BVA*',
#  'CDI BlueEFFICIENCY Edition',
#  'd 4MATIC Estate',
#  'T Autom. 1.6 +AVANTGARDE+PANORAMA+NAVI+',
#  'E200d Avantgarde T-Modell Navi+Kamera+LED+DAB',
#  'd Estate',
#  'Mercedes-AMG 4M Shooting Brake',
#  '580 4Matic',
#  'Limousine *VOLLAUSSTATTUNG*',
#  'S 310kW(422ch) DCT * CAM RECUL * GPS * SG CHAUFF *',
#  '43 4MATIC+ (MULTI/DAB/360"/BURMESTER/SAGA',
#  '4Matic Lang*VIP*Executiv*BuremsterHighEnd*',
#  'E-Klasse Lim. E 63 AMG S-Modell 4-Matic',
#  '4Matic Lang*Burmester*AMG*Distronic*HeadUp',
#  '580 4Matic',
#  '*SHZ*Alpine*Schiebedach*Tempomat*',
#  'CDI*Lordosenstütze*Bluetooth*Sitzheizung*',
#  'PLUG-IN HYBRID Lang',
#  "e long HYBRID AMG/360°/PANORAMA/3D/20''",
#  'CDI BlueEfficiency (204.001)',
#  'e 4M lang AMG Line Chauffeur-Pak Exklus',
#  '1.6',
#  'CLS CLS 500 BE 4-Matic',
#  'L 4Matic AMG-Line*Multibeam LED*Widescreen',
#  'L Hybrid *Nachtsicht-Assist*TV*Keyless*',
#  'C dA Business Solution LEDER/CUIR LED GPS PDC CAM',
#  'CDI BlueTEC Avantgarde NAVI+ / LEDER / LED',
#  'A45AMG4-Matic*Garantie*HarmanKardon*SportAuspuff',
#  'e Edition 2020 AMG',
#  '4MATIC AMG nieuwprijs: € 98.326',
#  '63 4M+*Sport-AGA*Perf-Sitz*Luft*HuD*Burm*',
#  'Lim. Aut. Navi Sitzhz. Temp. PDC Klimaaut.',
#  '4Matic SOFTCLOSE MEMORY TOUCHPAD*CAM',
#  '2.3 16',
#  'CGI BlueEfficiency Xenon',
#  'A45S AMG*Aero*Driver´s*Burm*Pano*360°*Distr+*HuD',
#  'CGI BlueEfficiency Avantgarde',
#  'd',
#  'Mercedes-AM53 4MATIC+',
#  'AMG ZOLL NACHTSICHT,SITZKLIMA,SERVOSCHLIES',
#  '63 4m+ panorama, night pack, first class rear seat',
#  '7G-TRONIC Navi Leder',
#  '525PS Memory Navi Leder Bi-Xenon BT',
#  'LANG 4M PANO KAMERA KEYLESS WEBASTO LIEGE',
#  '-CLASS 4.7 455 4P',
#  '-CLASS 4.7 455 4P',
#  '-Klasse CGI BlueEfficiency LED Navi e-Sitze Parkle',
#  'd AMG L 4Matic Leder/Distronic/HUD/Pano/Ka',
#  '4M L AMG PANO BURM TV HUD 360° MASSAGE',
#  'd 4Matic AMG*Burmester*360-Kamera*Softclose',
#  'Mercedes-AMG S 4MATIC+',
#  'Mercedes-AMG S 4MATIC+',
#  '-CLASS 2.1 D 4MATIC AUTO 170CV 4P',
#  'AMG Line Aut+Navi+Shz+Kam+LED+EU6+Night+',
#  'E280 Aut. Lim. Elegance Navi Xenon Temp. Sitzhz.',
#  '5.5 557PS BiTurbo Limo Pano ACC Keyless',
#  '4Matic AMG Speedshift 7G-DCT Pano',
#  'T 4Matic AMG-Line ACC Pano Navi Touch  LED',
#  'CDI AMG-Line 4Matic *XENON*NAVI*CAM*PANO',
#  'L AMG / FOND TV / BURM.3D / DESIGNO',
#  '1.6 115kW(156ch) * GPS * CAM RECUL * TOIT PANO *',
#  '4Matic 7G-DCT+LED+Navi+Designo+SHZ+',
#  'CDI/AMG/SH/SW/NAVI/8XR/TEM/SHZ/PDC',
#  'S 4Matic+ Alu LEDMultibeam Head-Up Navi P',
#  '4M 3x AMG NIGHT DESIGNO WIDESCREEN,DISTRO',
#  'Classe E 200 d',
#  nan,
#  'CDI Business',
#  'AMG E 63 S 4M*Fahrass*Burmester*Pano*Memory*360°',
#  'd',
#  '4M Night 19" LED Navi Kamera Sounds.',
#  'Mercedes-AMG S 4MATIC+',
#  '*LEDER*MEMORY*GLASDACH*TOP ZUSTAND*',
#  '-CLASS D G TRONIC PLUS AVANTGARDE',
#  'CDI Elegance KLIMAAUTO TEMPO NAVI SHZ',
#  'CDI 4Matic/Pano/Navi/Off-Road/ AMG Line',
#  'd 4M Multibeam Burmester HUD 360°Cam Distr+',
#  '4M SPORTPAKET AMG 18Z SPURPAKET,STANDHEIZ',
#  '350 amg distronic, memory, keyless go, led',
#  'AMG Kompressor 500 PS 5G Key Distronic DEU',
#  'd',
#  'd LANG AMG 4Matic*CHAUFFEUR*MASSAGE*TV*',
#  'd',
#  'd',
#  '4M L AMG Sport Distr Pano Navi SHD TV L',
#  'AMG C 63 S AMG Speedshift 7G-MCT',
#  '4M L AMG Sport FirstClass Standhz. Dist',
#  'Kompr.*2xSHZ*2xPDC*SCHECKHEFT*TÜV NEU',
#  'Mercedes-AMG 4MATIC',
#  'd',
#  'CDI 4M Aut. AMG Line',
#  '*Navi*Bluetooth*Tempomat*Klima*',
#  '*Navi*Bluetooth*Tempomat*Klima*',
#  'AMG*AmbientLight*StHz*Totwinkel*MBUX*',
#  'de',
#  '1.6i 122cv automatique - Pack AMG - GPS - Caméra d',
#  'E D AUT',
#  'd lang BlueTEC*AMG*Distronic*Burmester*',
#  'd 9G-TRONIC Avantgarde MULTIBEAM LED',
#  'e lang AMG Line Chauffeur-Pak Exklusiv',
#  '350+',
#  'S Klasse 580E Lang 4MATIC Mercedes-Benz S Klasse 5',
#  'd 4MATIC',
#  'CLA-CLASS 2.1 CDI DCT 170CV 4P',
#  'CLA-CLASS 2.1 CDI DCT 170CV 4P',
#  'Toit ouvrant - Climatisation - Garantie 1 an',
#  'd Lim. Avantgarde COMAND ILS Leder ParkA.',
#  'Toit ouvrant - Climatisation - Garantie 1 an',
#  'L AMG 4Matic Navi/Leder/Distronic/Burmeste',
#  'd AMG',
#  '3.0 258 PS BlueTEC / d Pano Distronic Keyl',
#  '+ AMG MBUX+Dig-LED+HUD+Pano+Distronic+21',
#  'Sedan 9G-Tronic AMG LINE - FULL LED - ALU - BLIS -',
#  '+ AMG MBUX+360°+Pano+DIG-LED+HUD+Distro',
#  'E -Klasse Lim. E 320',
#  'BlueTEC Sport',
#  '4M*Fahrass*Pano*Kamera*Burmester*Keyles',
#  'B -Klasse B 200 Turbo Special Edition/ PDC/Tempo',
#  'Aut. Navi Harman-Kardon Bi-Xenon Temp.',
#  'd',
#  '4MATIC',
#  '4M AMG MBUX+360°+HUD+DIG-LED+Burmeste',
#  'Lim. Aut. Navi Klimaaut. Schiebedach Shzng',
#  'A -Klasse A 160 NAVI SHZ',
#  '4M MULTIBEAM 360°KAMERA HEAD-UP KEYLESS',
#  'Mercedes-AMG S 4MATIC+',
#  '350+',
#  'd Automatik+Navi+LED+Kamera',
#  'e Sedan - AMG - Garantie 48 mois - 718€/mois*',
#  'S 4M+ AMG Aerodynamik Night 19" Pano',
#  'Mercedes-AMG 4MATIC',
#  'CLS-CLASS 272 4P',
#  'd AMG Line',
#  'd',
#  '-Klasse +Navi+Kamera+SHZ+PDCv+h.+Klimaauto.+Tempom',
#  'Blue Efficiency Avantgarde',
#  'Limousine 4M*PANO*KAMERA*LED*19ZOLL*',
#  '4M AVANTG. AMG-LINE PANO 360°KAMERA DISTRO',
#  'S 4M+ Performance-Sitz Distr LED Pan',
#  'd 4M Avantggarde Distr Standh HUD Multi',
#  'CDI /1.HD-SH/AHK/TEMP./Park Assis/Sitzh./',
#  'D*Navi*Rückfahrkamera*Sitzheizung*LED*DAB*',
#  'd 4M AVANTGARDE COMAND WIDESCREEN 360°KAM',
#  'CDI BE Avantgarde Blue Effic. Ed.',
#  '/ 1 Hd/ Rentner/Sammlerzustand',
#  'V8 Autom, Leder, Klima, SSD.',
#  '-Klasse BlueTEC d LED Navi e-Sitze Nachtsichtass.',
#  'BlueTEC 4Matic (212.011)',
#  'd 4Matic Alu Multibeam-LED Standh. Head-Up N',
#  'Business-Solution',
#  'Org. 61.000km Aut. Historie 1A Sammlerzust.',
#  'd AMG Line (EURO 6d-TEMP)',
#  'A -Klasse A 200 CDI  *Navi|PDC|SHZ|App-Connect*',
#  'AMG line',
#  'de',
#  '4Matic Lang +1 Hand+Scheck+186t EUR NP',
#  '1.5D 85kW(116ch) AUTO * CUIR * ATT REM * GPS *',
#  'BUSINESS 1.5D 85kW (116ch) BOITE AUTO * CAM RECUL ',
#  '*1.HAND*ORIGINAL ZUSTAND*KEIN ROST',
#  'E450 4M AVANTGARDE WIDESCREEN LED COMAND 360°KAM',
#  'Mercedes-AMG 4MATIC',
#  'd LANG 1.HAND DISTRONIC,HUD,360GRAD,AHK,SH',
#  'd LED Sitzh. Navi Kamera digitales Cockpit PDC',
#  'D Energy 1.2*1.Hand*Alu*lückenlos Scheckheft',
#  'D Satellite/TCS/ISO/ESP/4xALU/Brake Ass/',
#  '1.6T PHEV S/S GS-Line Aut. 180',
#  'Jam 1.4 Benzine 100PK + Navigatie',
#  'E 1.4 Color Edition Sitzheizung',
#  'S Klimaaut Sitzheizung Tempomat Recaro',
#  'F 100PS Color-Elegance mit LED-Licht',
#  "1.4 Turbo S OpenAir 18'' Felgen Recaro NAV Leder",
#  'Active mit Kamera PDC Winterpaket Inkl. Inspektons',
#  '1.4 66KW (90 CV) EXPRESSION PRO',
#  'S 1.4 Turbo Klimaaut. IntelliLink Infinity',
#  'F Edition',
#  'Open Air ecoFlex 115PS +Faltdach+ Allwetter',
#  '1.0 Turbo Rocks elektr. Faltdach I Navi',
#  '1.4 120 Jahre Klima ZV SHZ PDC',
#  'S 1.4 TURBO *LEDER RECARO*INFINITY SOUND*CARPLAY*S',
#  'E 1.4 Turbo GSi Xenon Sitzheizung PDC',
#  'E 1.4 Turbo OPC-LINE SHZ LHZ TEMPOMAT APPLE/ANDROI',
#  'Ultra-All-Inclusive  Corsa E Color Edition',
#  'Enjoy 1.4 Benzine 100PK',
#  '1.4 120 Jahre S/S Einparkassistent',
#  '1.4T Color Edition Navigation,Sitzheizung',
#  'Ultimate KAMERA NAVI LED STANDHZ ACC',
#  'F Edition SITZHEIZUNG PDC  AT',
#  'E 1.4 Turbo Ecoflex 5-Türer +SHZ+GRA+PDC+',
#  'E 1.4 Turbo Color Edition LED PDC Tempomat',
#  'Elegance 100PS AT +LED+KAM+SITZH+KLIMA+PDC',
#  'F 1.5 D Edition - Allwetter/Multimedia/PDC',
#  'E 1.4 Turbo GSi XENON',
#  'S PDC 18-ZOLL SHZ LHZ APP-NAV KLIMAAUTOM',
#  'E 1.4 Turbo OPC Line Bi-Xenon Sitzheizung',
#  'D Color Edition Klima PDC SHZ Lenkradheiz.',
#  'S - Recaro',
#  '1.4 120 Jahre Open Air Klimaautomatik, USB',
#  'F e Elegance',
#  'D Black Edition 5D 1.4B 100PK + Navigatie',
#  'D 1.3 CDTi Edition / Klima / 5-Türig',
#  '1.4 120 Jahre LM+KlimaA+W-Paket+PDC+',
#  'F 1.2 Elegance Automatik LED',
#  'F 1.2 Turbo Elegance -Sitzhzg./Klimaautom.',
#  '120 Jahre Klimaautomatik, DAB+Radio,',
#  '1.0 Turbo OPC-Line Xenon AAC SHZ LHZ PDC',
#  '1.4 Jam Sitzheizung Lenkradheizung PDC',
#  '1.4 66KW (90 CV) EXPRESSION PRO',
#  '1.4 66KW (90 CV) EXPRESSION PRO',
#  'E ON APP-NAVI RÜCKFAHRKAMERA SHZ LHZ NAVI',
#  'CORSA E 1,0T FLEXCARE GARANTIE, SHZ, BEH. WSS, LEN',
#  'F Edition Navi Rü-Kamera SHZ LHZ',
#  'E GSi SITZHEIZUNG PDC APP-NAV XENON',
#  'S 1.4 Turbo Kimaautomatik, PDC, SHZ, Recaro',
#  '-e ELEGANCE NAVI|LED||STANDHEIZUNG|1-PHASEN',
#  '1.0 120 Jahre KLIMA PDC SITZHEIZUNG',
#  'F 1.2 T[Euro6d] S/S 5-T Edition',
#  'F GS Line 1.2 Turbo MATRIX LEDLICHT,NAVI-PRO,KEYLE',
#  '120 Jahre  DAB+, Klimaautomatik, PDC,..',
#  '1.4 Jam Sitzheitung Lenkradheizung Klima',
#  'F Elegance 1.2 Turbo AppleCarPlay AndroidAuto Klim',
#  '1.4 120 Jahre Winterpaket*Parksensoren',
#  'F Elegance 1.2 Turbo LED Rückfahrkam. Fernlichtass',
#  '1.4 Jam Klima Sitzheizung Apple Carplay PDC',
#  '1.2 Selection+KLIMA+14-ZOLL+5-GANG-SCHALTG',
#  '120 Jahre Klimaautomatik, Winterpaket,..',
#  '120 Jahre Spoilerpaket',
#  'F 1.5 CDTI Elegance Panoramadach',
#  'F 1.2 Turbo Elegance - Sitzhzg./RF-Kamera',
#  'E 1.4 Turbo GSi RECARO Bi-Xenon Navi DAB',
#  'F 1.2 T[Euro6d] S/S 5-T Edition',
#  'S 1.4 Turbo KLIMA KURVENLICHT PDC SHZ',
#  'F 1.2 Edition - Sitzhzg./Rückfahrkamera',
#  '-e Elegance KLIMAAUTO KAMERA TEMPOMAT APPLE ANDROI',
#  'F Edition / MULTIMEDIA / SITZHEIZUNG',
#  'Edition 1.2 Turbo LED - Sitzheizung - USB - Tempom',
#  '1.4 Glam Klima Winterpaket PDC Tempomat',
#  'F Edition 1.2 Sitzheizung - Bluetooth - Tempomat',
#  'F 1.2T Automatik ** 1-Hand Opel **',
#  '-e Elegance !!3-PHASEN KLIMAAUTO KAMERA TEMPOMAT A',
#  'F Edition 1.2 Turbo 100PS,LED-SCHEINWERFER,SITZHEI',
#  'F 1.2 Edition LED Sitzheizung',
#  'F GS Line 1.2/TEILLEDER/LED/CAR-PLAY/ALU/PDC',
#  'F GS Line 1.2 Turbo Klima PDC BT DAB (32)',
#  '-e GS-LINE NAVI|SHZ|LED|PDC|ALU|1-PHASEN',
#  '-e Elegance !!LED NAVI WINTERPAKET TEMPOMAT!!',
#  'e Ultimate +11kW+Active+Keyless+R-Kamera+',
#  '-e ELEGANCE NAVI|SHZ|LED|ALU|1-PHASEN',
#  'F Edition 1.2 Turbo 100 PS, Regensensor, Lenkradhe',
#  '-e ELEGANCE NAVI|SHZ|LED|PDC|ALU|1-PHASEN',
#  '-e ELEGANCE NAVI|LED||STANDHEIZUNG|1-PHASEN',
#  'F 1.2 T[Euro6d] S/S 5-T Edition',
#  '-e ELEGANCE NAVI|KAMERA|SHZ|LED|ALU|1-PHASE',
#  ...]

# %%
# After the groupby operation, how many NaN values do I have remaining?
df['empty_weight'].fillna(df.groupby(['make', 'model', "body_type"])['empty_weight'].transform('mean')).isnull().sum()
# Out:
# 703

# %%
df["empty_weight"] = df['empty_weight'].fillna(df.groupby(['make', 'model', "body_type"])['empty_weight'].transform('mean'))

# %%
handle_missing_values(df , "empty_weight")
# Out:
# Missing Values in 'empty_weight':
# Count: 703
# Percentage: 2.46%

# %%
# After the groupby operation, how many NaN values do I have remaining?
df['empty_weight'].fillna(df.groupby(["engine_size"])['empty_weight'].transform('mean')).isnull().sum()
# Out:
# 3

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df['empty_weight'] = df['empty_weight'].fillna(df.groupby(["engine_size"])['empty_weight'].transform('mean'))

# %%
handle_missing_values(df , "empty_weight")
# Out:
# Missing Values in 'empty_weight':
# Count: 3
# Percentage: 0.01%

# %%
# Let's fill the remaining NaN values using interpolate because they are spaced apart from each other.
df[df['empty_weight'].fillna(df.groupby(["engine_size"])['empty_weight'].transform('mean')).isnull() == True].index
# Out:
# Int64Index([716, 5456, 21968], dtype='int64')

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
df['empty_weight'] = df['empty_weight'].interpolate()

# %%
handle_missing_values(df , "empty_weight")
# Out:
# Missing Values in 'empty_weight':
# Count: 0
# Percentage: 0.00%

# %%
# a = df['empty_weight'].fillna(df.groupby(['make', 'model', "body_type"])['empty_weight'].transform("mean"))
# a

# %%
# df["empty_weight"].value_counts()
# a.value_counts()
# a.isnull().sum()
# b = pd.concat([a, df[["model_code", "engine_size", "drivetrain", "body_type"]]], axis = 1)
# b
# b['empty_weight'].fillna(b.groupby(["engine_size"])['empty_weight'].transform("mean")).isnull().sum()

# %% [markdown]
# <a id="38"></a>
# <div class="alert alert-info" role="alert">
# <h1>Column name :<span style="color:red"> gearbox </span></h1>
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Operation : </b> Let's start by assigning the values we found in the <span style="color:red"><b> short_description for the expressions </b></span> in the Gearbox, in order to eliminate the<span style="color:red"><b> NaN values </b></span> . To fill in the missing values in the "gear_box" column, we can use the "short_description" column . Since the "gear_box" column is associated with <span style="color:red"><b> " make_model " </b></span> . let's fill in the <span style="color:red"><b> NaN values</b></span> in this column by grouping the data based on these columns and performing the necessary operations.
# </div>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
first_looking("gearbox")
# Out:
# column name    :  gearbox
# --------------------------------
# per_of_nulls   :  % 0.86
# num_of_nulls   :  247
# num_of_uniques :  3
# Manual            17011
# Automatic         11273
# NaN                 247
# Semi-Automatic       72
# Name: gearbox, dtype: int64

# %%
# Let's examine the short description of the seats
list(df.loc[df[df["gearbox"].isnull()].index, "short_description"])
# Out:
# ['d AMG PANORAMADAK/WIDESCREEN/SFEER/MEMORY/BOMVOL',
#  '35 AMG 306ch 4Matic 7G-DCT Speedshift AMG',
#  '200 d Business 7G-DCT',
#  '220 d Fascination 7G-DCT',
#  '220 190ch Progressive Line 7G-DCT Siege chauf gran',
#  '220 d 190ch AMG Line 8G-DCT 10cv GPS Camera Radar ',
#  '200 d 150ch Business Line 8G-DCT GPS Camera',
#  '200 d Inspiration 7G-DCT',
#  '200 163ch Style Line 7G-DCT',
#  '35 AMG 306ch 4Matic 7G-DCT Speedshift AMG TOuvrant',
#  '180 d Sensation 7G-DCT',
#  '200 d 150ch AMG Line 8G-DCT',
#  '220 190ch Progressive Line 7G-DCT',
#  '220 190ch Progressive Line 7G-DCT Ecran 10 GPS Cam',
#  '180 d Intuition 7G-DCT',
#  'e AMG Line+Pano+',
#  'Classe E 300d Coupé AMG Line Mercedes-Benz E Klas',
#  'GLS 400d 4MATIC AMG Line Mercedes-Benz GLS 400d 4M',
#  '+ EDITION 1-HEADUP-PANO-AIRMATIC-360°',
#  '4M EDITION ONE AMG-DISTR-PREMIUM-PANO-360°',
#  '2.0 Turbo',
#  'Coupe GS',
#  'GTC OPC J 280 cv',
#  nan,
#  nan,
#  'Olympia',
#  nan,
#  nan,
#  'Twip top 140 ,18',
#  'oldtimer 3.0 6cil GSE 180pk manual gears box',
#  'AT',
#  'e    1.4i  32jahre alt  h kennzeichen-möglich',
#  '/ Crossland 1.2 Edition/Autom/Navi',
#  'A Sports Tourer Business Edition/1.Hd',
#  '1.0i SCe Limited * Airco | Bluetooth | Cruise',
#  '1.6 TCe 205ch energy GT EDC',
#  '1.2 TCe 120ch energy Intens EDC 5p Camera GPS',
#  '1.3 TCe 140ch FAP Business EDC -21B GPS Radar AV/A',
#  '1.3 TCe 160ch FAP GT-Line EDC GPS Camera Park Assi',
#  '1.3 TCe 140ch energy Limited EDC GPS Radar AR',
#  '1.6 E-Tech 140ch Zen',
#  '1.6 E-Tech Plug-in 160ch RS Line -21N',
#  '1.5 Blue dCi 115ch Intens EDC',
#  'Sporter Blue dCi 160 CV EDC Exe',
#  '4cv * DECOUVRABLE',
#  '3 coupe cabriolet III COUPE CABRIOLET 1.9 DCI 130',
#  'Edition',
#  'Edition',
#  '1.5 dCi 110CV S-S 4p. Express Ice',
#  '1.2 75CV GPL 5 porte Wave 201407',
#  'S 292 PS Focal, Sport-Abgasanlage',
#  'tce 140 edc fap r.s. line',
#  'Renault Megane 1,5 dCI Energy Limited S&S 95',
#  'RS Trophy Automatik',
#  '3 coupe III COUPE 2.0 DCI 160 FAP GT EURO5',
#  'A 310',
#  '3 coupe III COUPE 2.0 DCI 180 FAP GT',
#  'tce 160 edc fap - 21b r.s. line',
#  'Rs',
#  'III Coupé dCi 165 GT',
#  'II 3.0 V6 Sport',
#  'ARKANA E-Tech 145 - 21B R.S. Line',
#  'ARKANA TCe 140 EDC FAP R.S. Line',
#  nan,
#  'II 3.0 V6 Sport',
#  'tce 140 edc fap - 21b r.s. line',
#  'R.S. Line TCE 160 EDC',
#  '1.5 dCi 110ch energy Intens EDC eco²',
#  '1.5 dCi 110ch energy Business EDC eco²',
#  '1.3 TCe 140ch FAP Intens EDC -21 LED GPS Radar Ar',
#  '1.3 TCe 160ch FAP Black Edition SL EDC',
#  '1.3 TCe 155ch FAP Intens EDC - 20 GPS Radar Ar',
#  '1.6 TCe 205ch energy GT EDC',
#  '1.2 TCe 130ch energy Intens EDC',
#  'E-TECH 100% Electric TECHNO EV60',
#  '1.8 T 300CH RS TROPHY EDC',
#  '208 - 5 PORTE 1.2 PURETECH 75CV ACTIVE',
#  'Cabriolet CC Platinum',
#  '207 CC 1.6 16v 120ch',
#  'Cabriolet 2 l',
#  'CC Platinum',
#  'coupé cabriolet',
#  'Cabriolet CC Platinum *LEDER*KLIMAAUT*89TKM',
#  'cabrio',
#  nan,
#  '1.6 Vti Cabrio 2008 Zwart',
#  '<NULL',
#  'CC Cabriolet',
#  'Cabriolet CC Platinum',
#  'Sport CC Cabrio-Coupe / Diesel -- TOP!!',
#  nan,
#  '16 GTI',
#  '156 THP Coupe',
#  '2000 td',
#  '2.0 BlueHDi GT | Pano | LED | Navi | AHK',
#  'II Ph2 1.5 BlueHDi 130 S\\u0026S GT Line BA8',
#  'Electric Active',
#  'Pop Elektro Standheizung Kundendienst neu',
#  '1.6 MultiJet 120ch Lounge S/S DCT 5p',
#  nan,
#  nan,
#  '2+2',
#  '2400 Vollrestauration',
#  'Fiat - 1500 cabriolet',
#  nan,
#  '2.0 Coupé ',
#  nan,
#  '2000 turbo 16 plus',
#  nan,
#  'ABARTH  1000 ot  valuto  permuta',
#  'Coupé 20V Turbo Plus',
#  nan,
#  "COUPE' 2000",
#  "1100/103 TV COUPE' PININFARINA",
#  'Original Zustand',
#  '2.0 20v turbo Limited edition ( LTD )',
#  '2000 Coupè Bellissimo',
#  'coupé condizioni uniche libretto tagliandi!',
#  'COUPE SL 1100 iscritta ALBO STORICO FIAT 2022',
#  'Coupe',
#  'Action-Topolino Lotus Edition, Modellreihe 2022',
#  '1.2 BENZ LONGE NAVI PDC BLUETOOTH',
#  nan,
#  '1.6 Multijet 16v 120ch Lounge DCT',
#  '1.6 Multijet 120ch Lounge DCT',
#  '1.6 Multijet 16v 120ch Club DCT',
#  '1.6 Multijet 16v 120ch S-Design DCT',
#  '1.3 FireFly Turbo T4 150ch by Harcourt DCT 139g',
#  '1.3 FireFly Turbo T4 150ch Cross DCT',
#  '1.5 FireFly Turbo 130ch S/S Dolcevita Special Edit',
#  '1.5 FireFly Turbo 130ch S/S Sport Pack Hybrid DCT7',
#  '1.5 FireFly Turbo 130ch S/S Sport Pack Hybrid DCT7',
#  '1.0 100 ch S/S sw cross Red MY22',
#  '1.5 FireFly Turbo 130ch S/S Sport Pack Hybrid DCT7',
#  '1.5 FireFly Turbo 130ch S/S Plus Hybrid DCT7 MY22',
#  '128 sport',
#  'Cupra (290 ch ) Full Stock , black Edition Beats ,',
#  'sport coupe',
#  '1.4 Sport 16v',
#  'Ateca 2.0 TDI  FR 150PS DSG 5 J. Garantie',
#  '2.0 TDI 150ch Style 4Drive DSG7 7 places',
#  '1.0 TSI 110ch FR DSG7',
#  'Leon ST 1.5 eTSI Style 150PS DSG 5 J.Garantie',
#  'Leon ST 1.5 eTSI Style 150PS DSG 5 J.Garantie',
#  'Leon ST 1.5 eTSI Style 150PS DSG 5 J.Garantie',
#  'Leon ST 1.5 eTSI Style 150PS DSG 5 J.Garantie',
#  '2.0 TSI 300ch Cupra DSG Toit ouvrant GPS Radar AV/',
#  'Leon 2.0 TDI XCELLENCE DSG Anhängerkupplung',
#  nan,
#  '1,5TSI Style 110KW AHK STHZ SHZ  RFK',
#  'iV 80 Sportline AHK Matrix-LED Navi Kamera',
#  'iV 80 Sportline ab 02.01.2023 verfügbar AHK-Vorb.*',
#  'Stepway 0.9 TCe 90 CV Comfort 2',
#  '1.6 SCe GPL 4x2 Techroad 201902',
#  'Electric Comfort Plus Aut.',
#  '1.3 TCE 150CH FAP CONFORT 4X2 EDC',
#  'TCe90 Laureate | Airco | Bluetooth |',
#  nan,
#  'T BAR TURBO   147 KW  200HP  RARITY  1992',
#  'Tornado',
#  'MR Design Tipptronik',
#  nan,
#  nan,
#  '*francois duval rally sport vintage*pret a rouler*',
#  'MK4 RHD Twin Turbo',
#  'ST',
#  '🤩👌 EXCEPTIONNELLE VOIRE UNIQUE TOYOTA MR2',
#  '1.6 Automatique',
#  'GTi',
#  'Coupé 2 posti 1.6 16 V',
#  nan,
#  '122h EDITION 2WD MY22',
#  '4.0 4x4',
#  '*Targa*Sehr guter zustand* bald H-Zulassung',
#  nan,
#  '3.8 V6 1000CH GENTLEMAN EDITION EURO6D-T',
#  '3.0 v6 targa wit metaal',
#  '240 Z',
#  'R34 GTT GTR Z-Tune RB26',
#  '3.8 V6 Black',
#  '160J    SSS Coupe',
#  "COUPE' 95000 KILOMETRTE carnet entretien",
#  '3.8 V6 550CH BLACK EDITION BVA',
#  '1.0 DIG-T 114ch N-Connecta DCT 2021.5',
#  '3.5 V6',
#  '2.0 Connect Edition',
#  '1.0 DIG-T 117CH TEKNA DCT',
#  '1.3 dig-t 160ch tekna dct',
#  'dig-t 160ch n-connecta dct',
#  '1.0 dig-t 117ch tekna dct',
#  '1.3 DIG-T 160CH TEKNA+ DCT 2019',
#  '1.0 dig-t 114ch tekna dct 2021',
#  '1.6 Hybrid 145ch Première Edition 2022.5',
#  '1.3 DIG-T 160ch Tekna DCT',
#  '1.3 DIG-T 160ch Tekna DCT',
#  'Titanium 1.0 Winter-Paket PDC 5J.FGS',
#  'KA+ 1.2 Cool&Connect+SHZ+PDC+ALU+USB',
#  'Covertibile Automatica - DA COLLEZIONE',
#  'Titanium',
#  'Model A Roadster / Hot Rod',
#  '4.6 V8 GT',
#  'cabrio v8 automaat',
#  nan,
#  'Coupé V8 GT Automatik.Modell 1028000*Tüv Neu',
#  'Cabrio',
#  "Hot rod 1932 V8 d'origine Carte grise française",
#  'Cabrio  VERKAUF IM KUNDENAUFTRAG',
#  'GT',
#  'COSWORTH GRUPPO N REPETTO EX NEW RACE',
#  '5.0 GT Premium Shelby GT350/Digi-Tacho/',
#  '3.7 V6/BRC GAS/KLIMA/XENON/VOLLEDER/AUT.',
#  'Sport 4x4 # AHK # ACC # BLIS # Winter-Paket',
#  'Mustang Mach-e Base',
#  'Hybrid 141ch Executive Sieges/Volant Chauf GPS Cam',
#  '1.4 T-GDi 140ch Creative DCT-7 GPS Camera Car Play',
#  'Hybrid 141ch Creative',
#  'Go',
#  nan,
#  'cw 1.4B 140PS DCT YES! Plus',
#  '1.7 CRDI 141ch Creative 2WD DCT-7',
#  '1.6 CRDI 136ch Hybrid 48V N Line Executive DCT7',
#  'euro 5',
#  'euro 5',
#  '121',
#  nan,
#  'R 2.3 T-5 Prestige Heico Tuning',
#  'JENSEN *UK BUILT*',
#  'Bertone',
#  'Coupé',
#  'ES 1800',
#  'PV444 HS',
#  '121',
#  nan,
#  'R 2.3 T-5 Prestige Heico Tuning',
#  'JENSEN *UK BUILT*',
#  'Bertone',
#  'Coupé',
#  'ES 1800',
#  'PV444 HS',
#  'D4 Kombi Momentum Standheizung',
#  'D4 Inscription *Luft*STHZ*Massage*',
#  'V90 CrossCountry D5 AWD *IntelliSafe*Kamera*',
#  'V90 2.0 d4 Business Plus geartronic',
#  'D4 Kombi Momentum Standheizung',
#  'D4 Inscription *Luft*STHZ*Massage*',
#  'V90 CrossCountry D5 AWD *IntelliSafe*Kamera*',
#  'V90 2.0 d4 Business Plus geartronic']

# %%
df.loc[df[df["gearbox"].isnull()].index, "short_description"].str.contains("(?i)Automatik|(?i)Automatica|(?i)Automati").sum()
# Out:
# 4

# %%
df.loc[df[df["gearbox"].isnull()].index, "short_description"].str.contains("(?i)Manual").sum()
# Out:
# 1

# %%
# Let's retrieve the entries that contain "Automatic" and assign them the label "Automatic".

# The expression "(?i)" in the code disables case sensitivity.

automatic_gear  = df.loc[df[df["gearbox"].isnull()].index, "short_description"].str.contains("(?i)Automatik|(?i)Automatica|(?i)Automati")
automatic_gear
# Out:
# 150      False
# 175      False
# 210      False
# 222      False
# 235      False
#          ...
# 28662    False
# 28838    False
# 28847    False
# 28850    False
# 29054    False
# Name: short_description, Length: 247, dtype: object

# %%
# Let's retrieve the indices of the ones that return True.
automatic_index = automatic_gear[automatic_gear == True].index

# %%
# After the this operation, how many NaN values do I have filling?
automatic_gear[automatic_gear == True].count()
# Out:
# 4

# %%
# Now let's assign "Automatic" to the indices we obtained.
df.loc[automatic_index, "gearbox"] = "Automatic"

# %%
handle_missing_values(df , "gearbox")
# Out:
# Missing Values in 'gearbox':
# Count: 243
# Percentage: 0.85%

# %%
# Let's retrieve the entries that contain "Automatic" and assign them the label "Automatic".

# The expression "(?i)" in the code disables case sensitivity.

manual_gear  = df.loc[df[df["gearbox"].isnull()].index, "short_description"].str.contains("(?i)Manual")
manual_gear
# Out:
# 150      False
# 175      False
# 210      False
# 222      False
# 235      False
#          ...
# 28662    False
# 28838    False
# 28847    False
# 28850    False
# 29054    False
# Name: short_description, Length: 243, dtype: object

# %%
# Let's retrieve the indices of the ones that return True.
manual_index = manual_gear[manual_gear == True].index

# %%
# After the this operation, how many NaN values do I have filling?
manual_gear[manual_gear == True].count()
# Out:
# 1

# %%
# Now let's assign "Manual" to the indices we obtained.
df.loc[manual_index, "gearbox"] = "Manual"

# %%
handle_missing_values(df , "gearbox")
# Out:
# Missing Values in 'gearbox':
# Count: 242
# Percentage: 0.85%

# %%
# After the groupby operation, how many NaN values do I have remaining?
df.groupby(["make_model"])["gearbox"].transform(lambda x: x.mode()[0]).isnull().sum()
# Out:
# 0

# %%
# after of implementation model and first_Registration. The non-null data is cosidered as sufficient to fill na full types.
df.gearbox = df.gearbox.fillna(df.groupby("make_model")["gearbox"].transform(lambda x: x.mode()[0]))
df.gearbox.value_counts()
# Out:
# Manual            17176
# Automatic         11355
# Semi-Automatic       72
# Name: gearbox, dtype: int64

# %%
handle_missing_values(df , "gearbox")
# Out:
# Missing Values in 'gearbox':
# Count: 0
# Percentage: 0.00%

# %% [markdown]
# <a id="14"></a>
# <div class="alert alert-info" role="alert">
# <h1>Column name :<span style="color:red"> fuel_type </span></h1>
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Operation : </b> To fill in the missing values in the "fuel_type" column, we can use the "short_description" column . Since the "fuel_type" column is associated with <span style="color:red"><b> " make " and " body_type </b></span> . let's fill in the <span style="color:red"><b> NaN values</b></span> in this column by grouping the data based on these columns and performing the necessary operations.
# </div>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
first_looking("fuel_type")
# Out:
# column name    :  fuel_type
# --------------------------------
# per_of_nulls   :  % 6.23
# num_of_nulls   :  1781
# num_of_uniques :  5
# Benzine     17318
# Diesel       8722
# NaN          1781
# Others        354
# Lpg           244
# Electric      184
# Name: fuel_type, dtype: int64

# %%
df.loc[df[df["fuel_type"].isnull()].index, "short_description"].str.contains("(?i)[Hh]+.br|(?i)twin|(?i)plug").notnull().sum()
# Out:
# 1775

# %%
# Let's retrieve the entries that contain "Hyrib, hbr " and assign them the label "Hybrid".

# The expression "(?i)" in the code disables case sensitivity.

hybrid_type  = df.loc[df[df["fuel_type"].isnull()].index, "short_description"].str.contains("(?i)[Hh]+.br|(?i)twin|(?i)plug")
hybrid_type
# Out:
# 16       False
# 32       False
# 93       False
# 94       False
# 108      False
#          ...
# 29408     True
# 29409    False
# 29437    False
# 29466     True
# 29474     True
# Name: short_description, Length: 1781, dtype: object

# %%
# Let's retrieve the indices of the ones that return True.
hybrid_index = hybrid_type[hybrid_type == True].index

# %%
# After the this operation, how many NaN values do I have filling?
hybrid_type[hybrid_type == True].count()
# Out:
# 833

# %%
# Now let's assign "Hybrid" to the indices we obtained.
df.loc[hybrid_index, "fuel_type"] = "Hybrid"

# %%
handle_missing_values(df , "fuel_type")
# Out:
# Missing Values in 'fuel_type':
# Count: 948
# Percentage: 3.31%

# %%
# df.loc[df[df["fuel_type"].isnull()].index, "short_description"].str.contains("kwh|kw|elect+").notnull().sum()

# %%
# Let's retrieve the entries that contain "Automatic" and assign them the label "Automatic".

# The expression "(?i)" in the code disables case sensitivity.

electric_type  = df.loc[df[df["fuel_type"].isnull()].index, "short_description"].str.contains("(?i)kwh|(?i)kw|(?i)elect+")
electric_type
# Out:
# 16       False
# 32       False
# 93       False
# 94        True
# 108       True
#          ...
# 29329    False
# 29352    False
# 29370    False
# 29409    False
# 29437    False
# Name: short_description, Length: 948, dtype: object

# %%
# Let's retrieve the indices of the ones that return True.
electric_index = electric_type[electric_type == True].index

# %%
# After the this operation, how many NaN values do I have filling?
electric_type[electric_type == True].count()
# Out:
# 174

# %%
# Now let's assign "Automatic" to the indices we obtained.
df.loc[electric_index, "fuel_type"] = "Electric"

# %%
handle_missing_values(df , "fuel_type")
# Out:
# Missing Values in 'fuel_type':
# Count: 774
# Percentage: 2.71%

# %%
# After the groupby operation, how many NaN values do I have remaining?
df.groupby(["body_type", "make"])["fuel_type"].transform(lambda x: x.mode()[0]).isnull().sum()
# Out:
# 0

# %%
# after of implementation model and first_Registration. The non-null data is cosidered as sufficient to fill na full types.
df.fuel_type = df.fuel_type.fillna(df.groupby(["body_type", "make"])["fuel_type"].transform(lambda x: x.mode()[0]))

# %%
handle_missing_values(df , "fuel_type")
# Out:
# Missing Values in 'fuel_type':
# Count: 0
# Percentage: 0.00%

# %% [markdown]
# <a id="15"></a>
# <div class="alert alert-info" role="alert">
# <h1>Column name :<span style="color:red"> Gears </span></h1>
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Operation : </b> To fill in the missing values in the "gears" column, we can use the "short_description" column . Let's retrieve the entries that contain <span style="color:red"><b>" 7-G, 7G, 7G , 7G- ... " </b></span> and assign them the label . Since the "gears" column is associated with <span style="color:red"><b>  " body_type " and " gearbox "</b></span> . let's fill in the <span style="color:red"><b> NaN values</b></span> in this column by grouping the data based on these columns and performing the necessary operations.
# </div>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
first_looking("gears")
# Out:
# column name    :  gears
# --------------------------------
# per_of_nulls   :  % 33.75
# num_of_nulls   :  9654
# num_of_uniques :  11
# NaN     9654
# 6.0     8409
# 5.0     5335
# 7.0     1738
# 8.0     1690
# 1.0      711
# 9.0      642
# 4.0      255
# 10.0     112
# 0.0       31
# 3.0       24
# 2.0        2
# Name: gears, dtype: int64

# %%
#7G, 7-G

# %%
# Let's examine the short description of the seats
list(df.loc[df[df["gears"].isnull()].index, "short_description"])
# Out:
# ['CDi',
#  '4MATIC',
#  'A -Klasse A 180 CDI aus 2-Hand & sehr gepflegt**',
#  'e Limousine',
#  nan,
#  'CDI',
#  'Avantgarde/Park Assis/Navi/Scheckheft/Bi-X',
#  'Limousine',
#  nan,
#  'CDI Elegance',
#  'd (177.003)',
#  '-Klasse Navi RDC Klima SHZ DVD CD-W CD MP3 ESP MAL',
#  'd (177.003)',
#  nan,
#  nan,
#  'Kompaktlimousine Rückfahrk+Vorrüst AHK+WDG',
#  '/Automatik/TSC/SHZ/ISO/Scheckheft/2.Hand/',
#  'd Progressive+LED+PSD+MBUX High-End+Kamera',
#  'd AMG-Line+Navi+PSD+LED+Rückfahrkamera',
#  'A-CLASS A180 1.3 136 CV 7G-DCT 5P',
#  'S 4MATIC+',
#  'd Avantgarde Largo',
#  '300E',
#  '580 4MATIC AMG Line Premium plus | Rij-assist + |',
#  'S AMG 4MATIC+',
#  '4-Door Coupe 43 4MATIC+ Premium Plus 63 AMG Uitgev',
#  'A35 AMG 4MATIC Premium+ 306PK | Pano | Sfeer | Bur',
#  '4MATIC l Top staat! l Panorama l Camera l Dealer O',
#  'CDI Ambition [ Xenon | Navi | Cruise ]',
#  'A35 AMG 4-MATIC *Pano*Burmester*4AMG Aero*Vol!*',
#  'CDI Air-Lift Schuifdak Harman/Kardon Night Leder U',
#  'AMG A 35 4MATIC',
#  '4MATIC | 381PK | Apple Carplay | Stoelverwarming |',
#  'Premium+ AMG Edition 1 225PK | Pano | Sfeer | Virt',
#  '4-Door 63 S 4MATIC+',
#  'e AMG Line Panodak',
#  'Business Solution AMG',
#  'd (177.003)',
#  'd Led Navigatie Stoelverw. Carplay Leer Zondag a.s',
#  'CDi',
#  'd (177.003)',
#  '200 CDi 1.8 CDI Boîte auto',
#  'CLASSE  d Fascination 4Matic 7G-DCT',
#  'AMG Ambiante verlichting Panodak Camera Zondag a.s',
#  '200 d Fascination 7G-DCT',
#  "Ambition NAVI BT LEDER PDC LED STOELVERW '16",
#  'AMG Stoelkoeling ACC Multibeam LED Burmester Panor',
#  'CDI Edition Navigatie 4U3',
#  'Sport Ambition AMG-Exclusief Pakket',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  'AMG Line, Automaat, LED',
#  '35 AMG 306ch 4Matic 7G-DCT Speedshift AMG',
#  'd Business Solution Plus Upgrade, Automaat, LED, L',
#  'CLASSE  CDI Inspiration',
#  'AMG Night Panodak',
#  'd Lease Edition Ambition AUTOMAAT',
#  'd Style + Pneus Hiver',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  'AMG Memory Multibeam LED Panorama Sfeerverlichting',
#  'Ambition Automaat AMG Pack',
#  '200 d 150ch Progressive Line 8G-DCT 8cv',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '200 d Business 7G-DCT',
#  'Business Solution AMG, Automaat, LED, Navigatie',
#  '200d 7G-DCT',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  'd Business Solution, Automaat, Navigatie',
#  '100 PK Ambition | Cruise | PDC | Airco | NAV | LED',
#  '220 d Fascination 7G-DCT',
#  '35 AMG 306ch 4Matic 7G-DCT Speedshift AMG 19cv',
#  '200 d Inspiration 7G-DCT Euro6c',
#  'Ambition 120 PK - Automaat | Schuif/kantel-dak | C',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '220 190ch Progressive Line 7G-DCT Siege chauf gran',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '220 d 190ch AMG Line 8G-DCT 10cv GPS Camera Radar ',
#  '180 d 116ch Business Line 7G-DCT',
#  '200 d 150ch Business Line 8G-DCT GPS Camera',
#  'Premium Plus | VERWACHT! | BTW Auto | Apple Carpla',
#  '180 d 116ch AMG Line 7G-DCT',
#  '200 d Inspiration 7G-DCT',
#  '200 163ch Style Line 7G-DCT',
#  '35 AMG 306ch 4Matic 7G-DCT Speedshift AMG TOuvrant',
#  '200 d 150ch AMG Line 8G-DCT 8cv',
#  'd Style + Pneus Hiver',
#  '200 d Fascination Tpano GPS Camera',
#  'CDI 100kW ( 136CV ) Urban',
#  '180 d 116ch AMG Line LED GPS Camera Radar AV/AR',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '180 136ch Progressive Line 7G-DCT 7cv',
#  '180 d Sensation 7G-DCT',
#  'e A 250e Progressive Sfeerverlichting / NIEUW GERE',
#  '200 d 150ch AMG Line 8G-DCT',
#  '220 190ch Progressive Line 7G-DCT',
#  '180 d Sensation 7G-DCT',
#  '180 136ch Business Line 7G-DCT',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '180 AMBITION (All-in prijs)',
#  '220 190ch Progressive Line 7G-DCT Ecran 10 GPS Cam',
#  '180 d Intuition 7G-DCT',
#  '160 109ch Style Line',
#  '200 163ch AMG Line 7G-DCT',
#  '160 Inspiration 7G-DCT',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '180 d 116ch Progressive Line 7G-DCT',
#  'd Progressive',
#  'd Premium',
#  '4MATIC SCHAALSTOELEN/PANO/SPOILER',
#  'MERCEDES-BENZ Clase GLK Pequeño  Automático de 5',
#  'Pequeño Automático de 5 Puertas',
#  nan,
#  'CDI Premium',
#  'd (177.003)',
#  'BlueEFFICIENCY Urban',
#  'CDI',
#  'd (177.003)',
#  'CDI Style',
#  'Special Edition Xenon Leder Memory Kam',
#  'Roadster~KAMERA~LEDER~\xa0GT FELGEN~XENON~',
#  'Kompressor AUT. AVANTGARDE *BI-XENON*KLI',
#  'Kompressor AUT. AVANTGARDE *BI-XENON*KLI',
#  'Cabrio~  AMG-LINE PLUS ~ Leder~Comand~LED',
#  'AMG Gepflegt MEMORY BI-XENON NAVI',
#  'C Roadster',
#  'Biturbo V-Max',
#  'SL 43 DIGITAL LIGHT+BURMESTER+DISTRO+HUD+MEMORY',
#  'C Roadster EDITION50/KERAMIK/SITZKLIMA',
#  'C Cabrio COM+Burm+LED+Distr+PerfS+Mem+RFK',
#  'S Cabrio Sitzlüft HeadUp 360° Drivers',
#  'Roadster*Magno*Night*SportAga*Distr+*RFK*',
#  'SL 65 V12 612PS AMG Roadster ACC Panorama ABC',
#  'E -Klasse Cabrio E 400 AMG Styling Paket',
#  'C Roadster Edition 50 SITZKLIMA/MEMORY',
#  'Comand+Airscarf+Airma+BIXen+Memory+19"AMG',
#  'MERCEDES-BENZ Clase SL Descapotable  Automático d',
#  'SL Autom, Leder, Sitzheiz.',
#  'Sport Edition Autom. COMAND AIRSCARF PDC',
#  '4Matic Cabrio *Swarovski*Nachtsicht*HuD',
#  'SL *Pagode*3.Besitz/Dt.Fahrzeug/H-Zul.',
#  "*LEDER*NAVI*KAMERA'SITZBELÜFTUNG",
#  'Roadster *DEUTSCH* (BOSE/DESIGNO/BI-XE',
#  'Kompressor Xenon SHZ PDC Klimaauto.Leder',
#  '367PS Cabrio Bi-Xenon Keyless-Go MOPF',
#  'MercedesAMG',
#  'ANDERE 43 Premium-Navi*360°Ka.*AIRSCARF',
#  'Roadster AMG/BIXENON/BURMESTER/KEYLESS',
#  'PERFORMANCE NIGHT SPORTABGAS BURMESTER',
#  'Cabrio 7G-Tronic+LED+Navi+Leder+H&K+Aircap',
#  'Roadster*Sport-AGA*Burm*Distr+*Night*Keyl',
#  'H&K Navi-Command Airscarf Panorama-Vario',
#  'CABRIOLET AVANTGARDE AUTOMAT+LEDER+ALU',
#  '4M+ Night+AIRSCARF+DISTR+DIGITAL-LIGHT',
#  'Cabrio Benzine Autom. - airco - Leder',
#  'd 4M Cabriolet AMG Sport Distr LED Navi',
#  'Cabrio *Avantgarde*Night*LED*Kamera*Navi*',
#  'AMG+COM+PanoV+LED-ILS+B&O+MILLEMIGLIA417',
#  'SLK Roadster 200 Kompressor*Leder*SHZ*Klima',
#  'S Cabrio Night Distronic+ Burmester',
#  'd 4M Cabrio AMG Line LED Navi Kamera PT',
#  'Roadster Automatik Radio/CD 18" ALU',
#  'd 4M Cabriolet AMG Sport ABC Distr LED',
#  'COM+PanoVario+LED-ILS+AIRSCARF+TotwA+PTS',
#  'd 4M Cabriolet AMG Sport Sitzklima Keyl',
#  'd Cabrio AMG-Line 9G-Tronic +LED+Leder+H&K',
#  '4M Cabrio *AMG*Night*Multibeam*Comand*HUD*',
#  'SL Pagode',
#  'Cabrio Xenon Leder  SHZ AIRSCRAFT AIRCAP',
#  'K Facelift Sport-Paket Bi-Xenon,Airscarf',
#  '4M Cabriolet Distr LED HUD Navi Kame',
#  'CGI  Roadster BlueEFFICIENCY Sport-Paket',
#  'UNIEKE SL 560 EUROPESE LOOK IN NIEUWSTAAT.AUTOM.',
#  'K AUTOMAT+KLIMA+LEDER+XENON+AIRSCARF+TÜV',
#  'd Cabriolet',
#  '4M Cabrio AMG+20"+AIRMATIC+HUD+STANDHZG',
#  'Cabriolet Aircap*Airscarf*LED*Business-Pa.',
#  'Cabrio AMG-Line NAV+LED+KAMERA+18ZO+EU6dT',
#  'Cabriolet AMG Line',
#  'K R 170 KLIMA SITZHEIZUNG LEDER AUTOM',
#  nan,
#  'Cabrio*Avantgarde*Automatik*Leder*SHZ',
#  'Kompr. Roadster Autom,Leder,Airscarf',
#  'CABRIO NAVI KAMERA MULTIBEAM AHK SITZKLIMA',
#  'Cabrio 7G-Tronic,Leder,Distronic,Comand',
#  'E -Klasse Cabrio E 200 +AMG LINE+NAVI+CAM+',
#  'Roadster Kompressor/Xenon/Navi/Leder',
#  'R107 Cabrio Hardtop + Softtop H-Kennzeichen',
#  '4M Night+AIRSCARF+DISTRON+MULTIBEAM+Com',
#  '4M Cabrio 19"+CARBON+MULTIBEAM+COMAND',
#  'Cabrio Navigation+LED-HP+CabKomfort+Kamera',
#  'S Cabriolet Wide 20" Burm Sitzklima',
#  'Cabriolet AMG Night Edition LED Navi SH',
#  'd Cabrio EU6, d AMG Line 9G-TRONIC',
#  '4M+ Cabriolet Vmax Distr LED HUD Nav',
#  '200K',
#  'R107 Cabrio Hardtop + Softtop US Modell H-Kennzeic',
#  'Kompressor Aut. Cabrio Final Edition',
#  'Kompressor Aut. Cabrio Final Edition',
#  'Cabrio CGI BE Avantgarde',
#  'C63 AMG Burmester|HeadUp|ACC|Perf.-Abgasanlage',
#  'CGI BlueEfficiency AMG Line *2J. Garantie*',
#  'Cabrio AMG Line Navi/Alcantara/Temp/Kamera',
#  '* Klima* Sitzheizung* Alu*',
#  'Kompressor+metallic Lackierung',
#  'Cabrio AMG Line LED Navi Kamera Airscar',
#  'd 4M Cabrio AMG Line Burm HUD Multib 36',
#  'Cabrio AMG Line2x+Spur+LED+Kam+Nav+DAB+18"',
#  'Cabrio Night+Drivers+Sp.Abgas+360°+Coma',
#  'Navi PDC SHZ',
#  'Kompressor Aut. Cabrio Final Edition',
#  'Panorama+AIRSCARF+ILS-LED+Parktronic+SHZ',
#  'd Cabrio AMG Line 2x+Burme+Comand+Sistzkli',
#  'AMG COMAND+ILS+SITZKLIMA+VARIO+BURMESTER',
#  'Cabrio 4M Comand+HUD+LED+KAM+High-End+DAB',
#  'ANDERE AMG Night+AIRSCARF+DISTRONIC+DIGITAL-LIGHT',
#  'd Cabrio AMG Line2x+Night+Kam+LED+DAB+Wide',
#  'Cabrio LORINSER UMBAU/AHK/ELEKTR. SITZE',
#  '163 PS Kompressor Cabrio  Final Edition',
#  'd Cabrio 9G-Tronic AMG Line+LED+Navi+Leder+',
#  'Cabrio LORINSER UMBAU/AHK/ELEKTR. SITZE',
#  'Deutsches Fahrzeug  Sammlerzustand',
#  'Cabrio d',
#  'Cabrio AMG Line 9G-Tronic+Nav+LED+Airscarf',
#  'Originale 52.000KM Roadster SHZ TEMPO',
#  'Cabriolet AMG Line',
#  'E -Klasse Cabrio E 200 AMG Line+Burmester+CAM',
#  'SL 63 4M+ HUD*Airscarf*MemoryP*Hinterachsl*Night',
#  'Cabrio AMG/LED/TOTWINKEL/PTS/RFK/AIRSCARF',
#  'd Cabrio AMG+MBUXHighEd+LED-HP+20"+Mem+RFK',
#  'Cabrio *V8*',
#  'AMG*Kamera*Burmester*Aircap*Airscarf*Navi*',
#  'Navi+LED+Air+Panorma+Leder+PDC+9GTronic',
#  'Autom. Top-Zustand aus 2. Hd. Deutsches M.',
#  'AMG 9G+NAVI+LED+RFK+VARIO+AMBIENTE',
#  'AMG Paket Kamera SoundSyst Memory HUD 19"',
#  'Cabrio AMG Line Multib Comand Airscarf',
#  'Cabrio Avantgarde+MBUXHigh+LED-HP+Distr+RK',
#  'Roadster/TEMPO/SHZ/BOSE Sound/',
#  '220 d AMG Line+Alcantara+MulitBeamLED+Keyless',
#  'd AMG-Line+AIRSCARF+AIRCAP+Standhzg+Comand',
#  'Kompressor+KLIMA+16-ZOLL+SPORTSITZE+LEDE',
#  'C220d Cabrio AMG Line Navigation Sitzheizung Kamer',
#  'Cabrio AMG Line 2x+Coma+Multib+DAB+Kam+18"',
#  'Cabrio AMG Line 2x+Comand+Kam+18"+Multibea',
#  'd Cabrio AMG Line 2x+Kam+LED+DAB+Wide+19"',
#  'Cabrio AMG Line High-End Info Adv.Park',
#  'Cabrio AMG Line 2x+Comand+LED+Kam+PDC+DAB',
#  'Cabrio AMG Line 2x+Night+Distr+LED+DAB+18"',
#  'd Cabrio Avantgarde Mulitbeam Burmester',
#  'd 4M Cabrio AMG Line AHK Standhz Multib',
#  'AMG Paket H/K Belüftung Panorama Comand',
#  'BE*AMG-Line*Aut*ILS*Pano*Leder*Shzg*',
#  'MOPF II komplett Umrüstung D incl. Tacho',
#  'Navi*Alu19*Leder*',
#  '-CLASS 6.2 COUPE SPORT AUTO 457 2P',
#  '7G-TRONIC-Facelift-Sportpaket-1.Hd!!!',
#  'Cabrio Avantgarde Xenon Memory Leder',
#  'Roadster AMG Magic Sky H&K Distronic',
#  'LED  AMG-Night-Paket COMAND  Airscarf',
#  '43 AMG / Air Scarf / Harman Kardon / Comand',
#  'Carbon Editie - 1e eigenaar - Keuring + Garantie',
#  '200 K.',
#  'C43 AMG Cabrio Schalensitze Burmester Head UP 360',
#  'Cabriolet AMG Line',
#  '/ incl. Garantie / 2 Jahre HU & AU frei',
#  'Cabrio 1e eigenaar-Dealer onderhouden-Complete his',
#  'SL 600 V12 AUT. ORG. NL.',
#  'SL Roadster SL 63 AMG Keramik Top-Zustand',
#  'Sport*MAE Original*Bose*Memory*Xenon*',
#  '(R171) 350 7GTRO',
#  'Cabrio',
#  'Cabrio',
#  'SL',
#  'Cabrio',
#  '4MATIC+ Cabriolet V-Max 360°*Sitzklima',
#  '4MATIC Cabriolet AMG Night HuD*360°*Sitz-K',
#  'Cabrio 2.0i AMG - Burmester Aut. || FULL OPTION',
#  '200 AMG Sport 7G-Tronic BVA',
#  'CLK Cabrio 230 k evo Elegance',
#  'SLK  200 Kompr. | 1.HAND (seit 05) | AIRSCARF',
#  'Roadster Comand/Memory/19"/TOP',
#  '4M Cabrio AMG+COM+Burm+Mbeam+20+Distr+360°',
#  'AMG Line',
#  '190SL',
#  "AUT NAVI BT AIRWAVE LEDER STOELVERW PDC CRUISE '11",
#  'AMG 7ATG/SHZ/PTS/Pano/AIRSCARF/Comand',
#  'AUT 245pk! 1eEIG YOUNGTIMER XENON LEDER NAVI CRUIS',
#  'K. Season Edition | Navi | Leder',
#  nan,
#  'd Cabriolet',
#  'AMG Xenon Bose Leder Designo Navi',
#  'Coupe V8 / SCHIEBEDACH,LUFTFEDERUNG,XENON',
#  'Coupe Speedshift 7G-DCT Perf-Sitze/Carb',
#  'D',
#  'CLA 220d ShootingB 4Matic*AMG*Kamera*Distronic*',
#  '7G-TRONIC 8-fach Navi PDC Klimaaut.',
#  'Performance Sitz&Abgas 20" Burm LED Pa',
#  'Coupe AMG Speedshift 7G-DCT',
#  'AMG GTC Edition 50*Designo*Magno*Pano*SitzKlima*',
#  'CDI COUPE AMG SPORT *LEDER*NAVI*LED*AHK*',
#  'AMG GLC 43 4MATIC Coupé',
#  'CLA 45 4M SB AMG SPORT NAVI TEMPOMAT PDC LED EU6',
#  'COUPE CARBONPAK 1+2 KERAMIK BURMESTER',
#  nan,
#  'PERFORMANCE SITZE PANORAMA BURMESTER',
#  '4Matic Coupe Speedshift TCT Navi/Leder/',
#  'd Coupe AMG 9G-Tronic Navi/Leder/Temp/360/',
#  'R COUPE CARBONPAK 1+2 KERAMIK BURMESTER',
#  '-CLASS 4MATIC',
#  '63 4M+ Aero Performance Massage 360 Ke',
#  '4MATIC+ Coupé',
#  'COUPE NIGHT PAKET BURMESTER HA-LENKUNG',
#  '4Matic*KAMERA*NAVI*LED*DESIGNO*SHZ*',
#  '4Matic*KAMERA*NAVI*LED*DESIGNO*SHZ*',
#  'CE Liebhaberstück',
#  'SEb (111)*DEUTSCHES-FAHRZEUG*H-KENNZEICHEN*TOP-ZUS',
#  'C oupe AMG Speedshift 7G-DCT LED RFK PDC',
#  'd 4MATIC',
#  'd 4MATIC Coupé AMG Line',
#  'AMG GT S E AMG PERFORMANCE grau magno HUD+CARBON',
#  '43 4M+ MBUX+Mbeam+21"+V8Style+PAbgas+360°',
#  'Urban+Navi+Leder',
#  "S 4M Coupé Edition1 Driver's HUD P",
#  '/Sammlerzustand/PDC/ Bose Sound/SH/',
#  'S 4.0 V8 DCT MATT CARBON KERAMIK V-MAX310',
#  'E300 COUPE AMG-LINE COMAND DISTRO HEAD-UP KEYLES',
#  'CLK Coupe 320/Automatik/Leder/Navi/Alus',
#  'C Aero Performance Dynamic+ Burm Night',
#  '4Matic AMG Speedshift TCT Navi/Leder/',
#  'Coupe *Nachtsicht-Assistent*BI-XENON TV',
#  '4M Coupé AMG Sport Standhz. Distr. LED',
#  'Mercedes-AMG S 4MATIC+',
#  '4M Coupe Panorama*AHK*Fahrassist*LED*',
#  'C 63 S COUPE AMG KEYLESS 360°KAMERA PANO HEAD-UP',
#  '4M *AMG*Comand*Sitzhzg*LED*Schiebedach*',
#  '4M+ Pano+DISTRONIC+HUP+TV+ILS+Swarovski',
#  '4M+ Pano+DISTRONIC+HUP+TV+ILS+Swarovski',
#  'AMG-Paket * Navi * Rückfahrk. * ILS',
#  '63 S 4M+ COM+PD+Burm3+Mbeam+HUD+360+EDIT1',
#  'Coupe 4M Standhz. LED Pano Navi SHD',
#  'GLC 43 4M Coupé **Burmester*360°Kamera*Keyless**',
#  '-CLASS 3.0 4MATIC AUTO 333 2P',
#  '4M Coupé Performance Optik-Pack AHK',
#  '63 S E PERFORMANCE SONDEREDITION+PANO+HUD',
#  '43 Perf-Abg. SHD Burm Wides 360°',
#  'CGI BlueE. Aut. Elegance LEDER NAVI XENON',
#  '4M AMG Line Distr Multib SHD 360°',
#  '4M+ Coupé 20"+PERF.ABGAS+STANDHZG+PANO',
#  'GLE 63 4MATIC Coupé LED*Abst-Tempo*360 Grad*Notruf',
#  'd 4M AMG-Line+Night+DISTRO+MULTIBEAM+Com',
#  'Coupe 4Matic Keramik/Carbon/360/Pano/Bu',
#  'e AMG Line+Pano+',
#  '4M Coupé Comand*Kamera*ParkPaket*Sitzhz',
#  'CLA 45S AMG 4M+*Pano*Distr+*Burm*HuD*Night*360°*',
#  '4M AMG Sport Night 19" AHK MBUX Stand',
#  '53 4M+ V8 Styling Paket AMG Dynamic Pl',
#  'C Coupe*DEUTSCHES-FAHRZEUG*AUTOMATIK*H-KENNZEICHEN',
#  'S 4M+ Coupé AMG Dynamik-Paket 21"',
#  '4M Coupe AMG Line Night Distr. Burm Pan',
#  '63 4M+ Performance Night Massage Burm',
#  'Coupé Burmest+Comand+Pano+DAB+Kam+Distr',
#  'C -Klasse Coupe C 200 AMG Line+Pano+Cam+',
#  'C 63 S AMG Coupé MEMORY/DISTRO/COMAND/MULTIBEAM',
#  '4M Coupé AMG*LED*AHK*Kamera*Navi*ParkPaket',
#  'COUPE 4M BURMESTER HUD PANO STANDHZ 1HD',
#  'Coupe 4M+ DRIVERS+AKTIV SITZE+360+KERAM',
#  'Coupé PROGRESSIVE',
#  '4M Coupé Night Perf-Abg Distr Stan',
#  '43 4M+ /Magno/Standheizung/AHK/',
#  'Coupé',
#  '4M HUD+PERF.ABGAS+STANDHZG+AHK+SHD',
#  'Coupe AMG + NIGHTPACK - LEDER - PANO DAK - 360° -',
#  'Coupé',
#  '333PS V6 AMG-Line Coupe 4Matic 9G-Tronic',
#  'Coupe*AMG-Line*MEMORY*SPURHALTEAS*360°CAM',
#  'AMG 4M*Panorama*MultiBeam*Comand*Burmester',
#  'Elegance Aut. Xenon Leder GSD ACC SHZ',
#  'Coupe 4Matic+ 21"AMG, Sternehimmel',
#  'AMG+MBUXHighE+LED-HP+19"+Night+ParkAss',
#  '4M Coupé PANO NACHTSICHT 360° KAM. KEYLESS',
#  'CDI Coupé',
#  'd 4M AMG-Line+SD+DISTRONIC+MULTIBEAM+Com',
#  'Coupé CDI',
#  'Compressor',
#  'CLA45 S AMG SB 4M HEAD-UP MULTIBEAM 360°KAM MBUX',
#  'd 4M Coupé AMG PLUS/PTS/360/DISTRO/SHD',
#  'CLK Coupe 320 Elegance Xenon/ PDC /Schiebedach',
#  'Coupé',
#  'Coupé d (238.314)',
#  'Coupé',
#  '4M+ designo Facelift Distr LED Nav',
#  'd 4MATIC',
#  'd 4M Coupé AMG-Line Night Standh AHK',
#  'S Coupé Aero Magno Keramik Vmax Dist',
#  'Matte wrapping',
#  "4M Night+Harman+Distro+Comand+Kam+19'",
#  'S 4M+ Coupé V8 Drivers+Comand+DAB+AHK',
#  'd 4M Coupé AMG/Night/Multibeam/AHK/',
#  'E200 Coupe AMG-Line Burmester+Memory+20erLM',
#  'coupé 4.0 4MATIC 469 2P',
#  'SLC, 1 Hand, Scheunenfund, Oldtimer, Bastler',
#  'E53 AMG 4Matic Coupe Pano+Burmester+Multibeam',
#  'Mercedes-AMG BRABUS 800 GLE 63 S 4MATIC+',
#  'Coupé AMG Line 2x+Comand+360°+Multib+Distr',
#  'Coupé 7G-DCT AMG LINE - BURMESTER - SFEERVERLICHTI',
#  'AMG Coupe 4M WIDE+COMAND+RFK+LED+NIGHT',
#  'd Coupé AMG Line 2x+LED+Stahzg+Kam+Nav+18"',
#  'AMG Line 4Matic LED Panorama Head Up 360°',
#  'Coupé AMG LINE+KAM+NAVI+KAM+LED+MILDHYBRID',
#  'GLC250d 4M 2x AMG Line Coupé NAVI KAMERA AHK LED',
#  'S 4M+ Coupé Sitzklima*Drivers P.',
#  'd 4MATIC Coupé',
#  'Coupé d',
#  'C200 COUPE M-HYBRID AMG LINE LEDER NAVI LED PANO',
#  '4M Coupé 19"+PANO+MULTIBEAM+BURMESTER',
#  '4M Coupé 19"+PANO+MULTIBEAM+BURMESTER',
#  'AMG Line Panorama*AHK*Night*Ambiente*LED',
#  '4M+ Coupé NIGHT+20"+PANO+PERF.ABGAS',
#  '63 4M+ HUD Memory Night',
#  '4M AMG Line 2x+Sitzklim+Comand+Night+LED',
#  '4M+ Coupé NIGHT+PANO+PERF.ABGAS+FAHRASS',
#  'd 4MATIC',
#  'Coupe*1.Hand*Deutsches Fahrzeug*Insp.NEU',
#  'd 4M AMG+HUD+AIRMATIC+STANDHZG+AHK+360°',
#  'd 4M Coupé  AMG*NightP*EasyP*HUD*Spiegel',
#  'd 4M AMG+20"+AIRMATIC+HUD+STANDHZG+SHD',
#  'CDI Chrome',
#  'e Coupé',
#  'd (205.314)',
#  'Coupé d',
#  'Coupé AMG Line 2x+Kam+LED+Navi+DAB+SHZ+18"',
#  '4M AMG*Kamera*MBUX-High*LED*Sound*7G-DCT',
#  'CLS 53 4M+ *Limited Edition 1 of 299*DriversPa.*',
#  'Mercedes-AMG GLC 63 S 4MATIC+ Coupé+DISTRONIC',
#  'Coupé AMG PLUS/TOTWINKEL/PTS/RFK/MULTIBEAM',
#  'Coupe AMG 9G-Tronic+LED+Navi+Kamera+Leder+',
#  'd 4M Coupé AMG Line',
#  'Coupé',
#  'Coupé AMG Line+Burmest+LED+KAM+Advance+19"',
#  'CDI (LA) Sport Edition (203.708)',
#  'e AMG+MBUXHighEnd+LED-HP+AParkAssist+RFK',
#  'Coupé 220d',
#  '4M Coupé OrangeArt+Night+Distr+FondTV',
#  'Coupé AMG Line+Night+Wide+LED+Navi+Kam+19"',
#  'AMG-Line*Panorama*LED*19"*Ambiente*kamer',
#  'AMG*AHK*Panorama*Night*Ambiente*LED*MBUX',
#  'd 4M Coupé AMG Sport Burm3D EBC Stand',
#  'Coupe 4MATIC*AMG LINE*PANO*360°-Kamera*',
#  'COUPE AMG -Line',
#  'Coupé AMG Line Pano Night Navi LED SH',
#  'Coupé',
#  '4M Coupe AMG Line Night Distr Burm He',
#  'Komp Sportcoupe  XENON/NAVI/17ZOLL/LEDER',
#  'Coupe 4Matic Night Edition Navi/Distron',
#  'Coupé d 4MATIC',
#  'de 4M Coupé AMG+AIRMATIC+22"+HUD+PANO',
#  'CDI Inspiration 7G-DCT',
#  'e 4Matic 7G-Tronic+Navi+Tempomat+',
#  'GLE 63 S AMG 4Matic CARBON*Jungsterne Garantie',
#  '*AMG SPORTPAKET*HARMAN KARDON*COMAND*2xPDC',
#  '4M+ 3+2 Sitzer 22" Aero Paket Nich',
#  '4Matic Designo/Standh./Ahk/360°/8-Fach',
#  'CDI 4Matic*Bi-Xenon*Navi*Designo-Lack*SHD',
#  'CDI  Bluetec 4Matic*Bi-Xenon*Euro6*',
#  'Blutec Glasdach Sportpaket Comand BiXenon',
#  'ANDERE AMG UNTERBODEN GESTRAHLT KONSERVIERT/SHZ',
#  'CDI BT 4M S-DACH SPUR TOTW PARK AHK ILS',
#  '*4Matic*Night Paket *360°*Pano*Comand',
#  'CDI 4-Matic BE *INKL. 2 JAHRE GARANTIE*',
#  '4Matic 557PS Designo Speedshift Plus',
#  'd 4Matic AMG-Line Navi LED Pano Shzg AHK',
#  'GLS400d 4M*AMG*Massage*TV*Burm*7Sitz*Distr+*StHz',
#  'd 4M *Style*LED*Sitzheizung*Navi*7G-DCT*',
#  'd Exclusive 4Matic 9G-Tronic+COMAND+LED+',
#  '4Matic AMG Line*Teilleder*Navi*LED*20"* AMG',
#  'AMG Line+CAM+Schiebdach+',
#  'GLA250 7G-DCT AMG Line+Bi-Xenon+inkl 2J Garantie',
#  'CDI BE /BI-XENON / NAVI / AHK / SHZ',
#  'd 4MATIC',
#  '4M AMG Line ILS Pano HUD Airmatic 360',
#  '4MATIC AMG Line',
#  '4M Progressive+Pano+DISTRON+HUP+KEYLESS',
#  '4MATIC',
#  '4M Magno Aero Performance Standhz.',
#  '1.6 STYLE Leder|Xenon|Navi|Alu|Sitzheiz.',
#  '250d 4Matic 9G NAV+LED+SHZ+KAMERA+PANO+AHK',
#  'd 4M AMG-LINE COMAND AIRMATIC 360°KAMERA',
#  'GLE 63 4MATIC Coupé LED*Abst-Tempo*360 Grad*Notruf',
#  'd 4Matic **Finanzierung**Garantie**9G**',
#  '5.5 507 PS Kompressor lang Designo BRD',
#  'Progressive 7-Sitzer 20" Pano 360° Ke',
#  '4M AMG/KEYLESS/PTS/360/MEMORY/DISTRO/SHD',
#  'd 4Matic AMG PAN-D LED Off-Road-Paket',
#  'CDI BlueTEC*Pano*Standheizung*Distronic*',
#  'CDI 4Matic AHK+Standhzg.+ACC+Xenon+Pano',
#  '4Matic Aut. *AMG*7-SITZER*EXCLUSIVE*DVD*L',
#  'd AMG Line 4Matic LED PANO R.Cam AHK COMAND',
#  'AMG Kamera BiXenon Memory  H/K GSD Leder',
#  'd 4Matic All-Terrain Estate Avantdarde',
#  '4M AMG-Line+AHK+DISTRONIC+MULTIBEAM+MBUX',
#  '4M AMG Line',
#  '4M AMG Line Night Pano Advanced+',
#  '4M Offroad Exclusive AHK LED Navi Kam',
#  'Sportpaket Navi Vollleder',
#  '4M AMG+22"+STANDHZG+SITZKLIMA+HUD+PANO',
#  '4M AMG/ MBUX/Schiebedach/Multibeam/Distr Navi/SHD',
#  'Mercedes-AMG GLE 53 4MATIC+ PSD+AHK+Memory',
#  'G 350 BlueTec LED BI-XENON*1J. PREMIUM GARANTIE',
#  'd 4Matic AMG 9G-Tronic Navi/Leder/Temp/K',
#  '4M AMG+22"+HUD+CARBON+STANDHZG+PANO+AHK',
#  '250 Progressive/LED/Memory-P./Kamera/Navi/',
#  'Progressive SHZ PTS KAMERA NAVI LED',
#  'd 4Matic*ACC*BUR*COMAND*OFF-ROAD*KAM*',
#  'CDI Style Aut. +Navi+Bi-Xenon+Tempomat+',
#  'd AMG Line+Night 2x+Edelstahlp+Wide+Comand',
#  'BlueTEC 7G Alcantara Standheizung H/K AHK',
#  '4M AMG-Line+AHK+DISTRONIC+MULTIBEAM+MBUX',
#  'd AMG 4Matic Aut. +COMAND+LED+Kamera+Amb.',
#  '4M AMG/DISTRO/KEYLESS/PTS/NIGHT/PANO/SHZ',
#  'd 4M AMG Line 22" Standh Pano AHK Bur',
#  "7G-DCT AMG + NIGHTPACK - ALU 19' - SFEERVERLICHTIN",
#  'd 4MATIC 21"*360°K.*Pano.-D.*AHV*LED*AMG',
#  'GLC43 AMG Coupe 4M ILS+Pano+HUD+Burmester+360*',
#  'd 4M AMG-Line+Pano+AHK+MBUX+LED+Kam+PDC',
#  'd 4M AMG/EXCLUSIVE/DISTRO/STHZ/PANO/AHK',
#  'd 4 MATIC 245cv 9 vel. *IVA deducible* *2020* *Nac',
#  'CDI 4M Sportpaket+NEUER MOTOR+StHz+Coman',
#  'd 4MATIC AMG Line',
#  'AMG G 63 AMG SPEEDSHIFT 7G-TRONIC',
#  'CDI',
#  'd AMG Line Keyless 20"Night Pano AHK',
#  'd 4M AHK Distr Multib Pano 360°',
#  'CDI / 4Matic,Xenon,Navi,Allrad,Leder,SHZ',
#  '4Matic*Pano*MBUX*21"*RFK*Spurhalte*',
#  'BURMESTER-EXCLUSIVE-360°',
#  'SD+AHK+Standhz+DISTRON+TV+MULTIBEAM+Com',
#  'AMG Line AHK Standhz. Distronic Widesc.',
#  nan,
#  'e 4M MBUX+Pano+Burm+Mbeam+AHK+Sitzkl+360',
#  'd 4Matic (253.915)',
#  '4M 9G-TR. COMAND WEBASTO SCHIEBEDACH AHK',
#  'AMG G 63 NIGHT+DISTRONIC+CAM+BURMESTER+',
#  'd Urban Aut. AAC XENON NAVI AHK KAMERA',
#  '4M AMG Line Night Navi Kamera LED SHZ',
#  'BlueTEC 4MATIC',
#  'Puch  JAGD-FZG./WINDE/KOFFER/BRAUSE/AHK',
#  '211 PS BlueTec Station AMG Totwinkel Kamer',
#  'd 4M AMG*Distronic*360°*Airmatic*AHK*ILS',
#  'd 4M AMG+21"+PANO+FAHRASS+AHK+SOUND+360°',
#  '4Matic Sportpaket *Kamera*Alcantara*LED*',
#  '4M AMG-LINE MBUX PANORAMA 360°KAM DISTRO',
#  '4M MBUX+NavP+Mbeam+Sthg+AHK+Distr+RFK',
#  'd 4Matic Edition Power Aut. Navi AHK 360Cam',
#  'AMG GLC 43 4MATIC',
#  '4Matic *AHK*AIRMATIC*ACC*STDHZG*KAM*19Z*',
#  'd AMG/20"/Multibeam/Burmester/360°K/AHK/',
#  'd AMG/20"/Multibeam/Burmester/360°K/AHK/',
#  'e 4Matic',
#  nan,
#  '4Matic*Pano*MBUX*21"*RFK*Spurhalte*',
#  'Mercedes-AMG BRABUS 800 GLE 63 S 4MATIC+',
#  'd 4Matic*NAVIGATION*PDC*SHZ*ALU*',
#  'd 4Matic*MEMORY STANDHEIZUNG 360°CAM*',
#  'CDI 4Matic 7G-Tronic+Xenon+Navi+Leder+AHK',
#  '258PS 4Matic LED HIGH Luxury NAV CAM',
#  '525PS V8 Biturbo 4-Matic Panorama H&K',
#  'd 4Matic DoKa 7G Edition Progressive +LED+',
#  '4M Night Standhz LED Kamera Keyles',
#  'd 4M AMG Line Night Pano AHK HUD Stan',
#  'D ADVANTAGE + PAQ NIGHT',
#  'GLC 63 S AMG 4matic+  Night Keyless 21" Sound',
#  'd Progressive 4Matic LED Navi Widescreen',
#  '4M AMG*Pano*AHK*Spur*MBUX*MultiB*Kamera',
#  'AMG NIGHT AHK MBEAM SOUND DIGDISP DIST',
#  nan,
#  '4M+ AHK Standhz. Night Pano HUD',
#  'CDI 4Matic BlueTec*Navi*Klima*StHzg*',
#  '4M AMGLine+Exclusive ext+ILS+AHK+Trittbr',
#  'Drivers Exclusive AHK Standhz',
#  'Coupé 350D 258 CV',
#  'Puch PLANE/AHK/ALLRAD/SCHLIEßANLAGE NEU',
#  '+ Electric Art MBUX+LED+RüKam+El.Heck+18',
#  '4M Progressive Distr LED Navi Kamera',
#  'DRIVERS+WIDE+STDHZG+360°+AKTIV SITZE',
#  'd 4M *Comand*Standhzg*360°*LED*Sitzhzg*',
#  '4Matic*Pano*MBUX*21"*RFK*Burmester*',
#  'D',
#  'Mercedes-AMG 4MATIC',
#  'Puch PLANE/AHK/ALLRAD/SCHLIEßANLAGE NEU',
#  'd 4M AMG PANORAMA HUD ABC DIST MBEAM 20"',
#  '200 d GPS PDC Pano Cruise Ctrl BT S&S',
#  'AERO-PAKET*PERFORMANCE SITZ*DESIGNO*',
#  'AERO-PAKET*PERFORMANCE SCHALENSITZE*',
#  'd 4M Sitzklim+Burmes+Pano+22"+PremPlusp.',
#  'd 4M AMG-PLUS+20"+PANO+FAHRASS+MEMORY',
#  'd 4MATIC',
#  '4Matic*Pano*MBUX*21"*RFK*Spurhalte*',
#  'd 4Matic (253.915)',
#  'Exclusiv+Edelstahlp+Distro+Designo+Fond TV',
#  'd 4M AMG Line+Night+PremiumPlus+Sitzklim',
#  'AMG Pano LED B&O 360Kam Massage AHK TV',
#  'd 4M AMG+20"+PANO+AHK+FAHRASS+BURMESTER',
#  'd Style 7G-DCT BI-XENON NAVI RFK SHZ TEMPO',
#  'D 2.2 170CV AUT 5P',
#  'd 4M *AMG*Sitzklima*AHK*Standhzg*LED*HUD',
#  'd AMG Line AHK Distr+ Standhz beh. WSS',
#  'BlueTEC XENON SHZ NAVI LUFT AHK*CAM',
#  '4MATIC 7G NAVI LEDER KAMERA PDC AHK',
#  'd 4M AMG+Burmester+Fahrassist.',
#  'e 4MATIC',
#  'd 4M AMG-Line COMAND ILS Leder DTR+ 360°',
#  'Urban Business Paket *2 JAHRE GARANTIE*',
#  'CDI BlueTEC*KAMERA*XENON*NAVI*LEDER*',
#  '4M COMAND 360°KAMERA AIRMATIC KEYLESS',
#  'Urban',
#  'CDI 4Matic COMAND LED KEYLESS 360°KAMERA',
#  'Edition 55+SD+AHK+DISTRON+TV+MULTIBEAM',
#  '4M AMG-LINE COMAND PANO KEYLESS 360° KAM',
#  'd',
#  'd T 4Matic AMG*Standheizung*AmbientLight*',
#  'E350T CDI BlueEff. COMAND SITZKLIMA DISTRONIC',
#  'T CDI 4MATIC Elegance | Airmatic | AHK',
#  'T CDI*Bi-Xenon*Avantgarde*Standheizung*',
#  'CDI Shooting Brake',
#  'T-Modell/AMG-Line/SHZ/NAVI/PANO/St.HZ/Full',
#  'd T Business 9G Aut +LED+AHK+Kamera+Navi',
#  'd !!!VERKAUF NUR AN GEWERBE!!! +AVANTGARDE',
#  'T 4Matic+ *Hybrid*VirtualC*Night Paket',
#  'T CDI Avantgarde Export',
#  'T 4Matic+ *Hybrid*VirtualC*Night Paket',
#  'CLS 250 Shooting Brake Sport-Paket',
#  '53 AMG 4M+ Sitzklima*Drivers P.*Burmester',
#  'E -Klasse T-Modell E 350 BlueTEC 4Matic AMG LINE',
#  'd T *Navi*LED*Sitzhzg*Park-Paket*9G-TRONIC',
#  'AMG E 43 4Matic T 9G-TRONIC PDC SHZ NAVI',
#  'BlueTEC dT 4M AMG-Line NAV+LED+AHK+HEAD-UP',
#  'd T *Avantgarde*Night*LED*Kamera*MBUX*Navi',
#  '350 Fahrassist.*Pano.-Dach*360°*Night*Memory',
#  'E280 T Kombi Automatik Radio 7-Sitzer Alufelgen',
#  'E -Klasse T-Modell E 250 CDI BlueEfficiency',
#  'SB S Exklusiv Vmax Distr LED Navi',
#  'Shooting Brake  BE 4Matic Bluetooth',
#  'CDI Avantgarde 7G-Tronic,AHK,Navig,Sportsitze',
#  'd T+Navi+Kamera+Pano+Tempomat',
#  'd T *Navi*Sitzhzg*9G-TRONIC*LED*Park-Paket',
#  'CGI Avantgarde Aut. +COMAND+Bi-Xenon+GSHD',
#  'SB URBAN NAVI/TEMP./AHK/SHZ/DAB+/PDC/USB',
#  'Sport-Paket',
#  'T 4MATIC COMAND SHZ KAMERA NAVI LED',
#  'd T 210KW*ACC*MULTIBEAM*KAM*COMAND*DAB*',
#  'CDI BlueEfficiency Avantgarde 2J. Garantie',
#  'S 4M+ Drivers-P+DISTRONIC+MULTIBEAM+Com',
#  'CDI Avantgarde 4MATIC Bi-Xenon RCam Sitzklima PDC',
#  'T Leder / Navi / Xenon / Klima',
#  'AMG CLA 35 4MATIC Shooting Brake',
#  'T CDI 4Matic*Airmatic*StHz*Distronic',
#  'T 9G AMG LINE*LED*COMAND*KAMERA*BURMESTER*',
#  'S T 4M+ Standhz. Pano Keramikbremse',
#  'd T *Navi*AHK*Sitzhzg*LED*Park-Paket*9G-TR',
#  'C220d 4Matic AHK+Standhzg+LED+Ambiente+Navi',
#  'd T Avantgarde AHK Comand LED Kamera SH',
#  'd T *LED*AHK*Navi*Sitzheizung*Park-Paket*',
#  'SB Urban Night Paket 7G Aut+Xenon+Memory',
#  'T-Modell CDI 4-Matic LED KLIMAAUTO TEMPO',
#  'C 63s AMG T 7G-Tronic+LED+Kamera+Burmester+Pano+',
#  'S T 4M+ ohne OPF Magno Vmax Perf Car',
#  'E250 T-Modell CGI/TSGS/NAVI/ASSIS+/TEMPO/SchaltW',
#  'SB d LED Navi SHZ Einparkh. Parkassis',
#  'd T AMG Line 4Matic Aut. +COMAND+LED+LEDER+',
#  'D T EXCLUSIVE 4MATIC AUTOMATIK (+EURO6+ALLRAD',
#  'BlueTEC AMG-Line',
#  'T d AVANTGARDE COMAND KAMERA MULTIBEAM',
#  'd T Leder 194PS Navi Leder Kamera LED BT',
#  'd T *LED*Navi*Sitzhzg*Park-Paket*9G-TRONIC',
#  'CGI 4-Matic 7G-Tronic Elegance+BiXen+Navi',
#  'CGI 4-Matic 7G-Tronic Elegance+BiXen+Navi',
#  'T 4Matic 9G NAV+LED+ACC+PANO+19ZOLL+SHZ',
#  'd T  Avantgarde / DISTRONIC / LED / SHZ',
#  'C63 S AMG DESIGNO HUD BURMESTER PANO DRIVERSPACK',
#  'E300d T AVANTGARDE AMG-LINE KAMERA WEBASTO PANO',
#  'CLS SB 250d 7G-Tronic 4M AMG-Line +Comand+360°+',
#  'CLASSE B B 180 d BE Edition',
#  'CDI T-Modell Elegance  Navi/Pano.-Dach/SHD/Autom.',
#  '4M T Comand*Multibeam*Standhzg*Pano*HUD',
#  'BI TURBO 4MATIC - LEDER/ALCANTARA - LED - NAVI - 1',
#  'T-Modell E 220 d 4Matic All-Terrain',
#  'd T BlueTec Avantgarde NAV+LED+KAMERA+SHZ',
#  '(+)2.0 AVANTGARDE AUTO 211 5P STATE',
#  'C200 T Exclusive ILS Leder Kamera Navi Tempomat',
#  'C250 CGI T AMG Line 9G Aut+LED+Navi+Kamera+Leder',
#  'T 4-Matic Elegance *Distr.*360°*LED*Navi',
#  'C180 T Exclusive LED Navi Sitzheizung Tempomat',
#  'T d 4M AMG Line Panorama*Standhzg*AHK*360°',
#  'd AMG-Line WideS Multib Airm. HUD Sthz DTR+',
#  '7G-DCT KLIMA+EPH+TEMPOMAT+BI-XENON+SITZHEIZUNG',
#  'C220 d T Avantgarde T Avantgarde d',
#  'd T Exclusive Leder Navi',
#  'E -Klasse T-Modell E 220 d 4Matic All-Terrain',
#  'AMG 4M Sitzklima*Burmester*Fahrassist.',
#  'd T 9G Avantgarde NAV+LED+ACC+VCOCKPIT+SHZ',
#  'd T Exclusive +LED+Navi+Tempomat+EUR6+',
#  'd Urban*LED*Park-Pilot*7G-DCT*Night*Sitzhz',
#  'E43T AMG COMAND DISTRONIC HEAD-UP 360°KAM AIRMAT',
#  nan,
#  '+ AMG*Sitzklima*Burmester*Distronic*Night',
#  'd T 4M Exclusive+COM+Mbeam+Sthzg+Distr+360',
#  'Estate',
#  'E300d T 2x AMG-LINE COMAND DISTRONIC AHK 360°KAM',
#  '4MATIC',
#  'Automatik T AMG-LINE/LED/LEDER/MFL/',
#  'd Shooting Brake',
#  'd Estate',
#  'T 4M 9G-TR. AVANTGARDE NAVI 360°KAMERA LED',
#  'BlueTEC d T AMG-Line NAV+LED+AHK+PANO+ACC',
#  '450+ 360°Kam*Pano.-D.*20"LMR*AIRMATIC*Memory',
#  'CDI Blue Efficiency Estate',
#  'T COMAND Pano Sbel HUD AHK Burm. DTR+',
#  'VITO 116 CDI B.TEC TOURER PRO 8-S |NP50€|57tK|1H',
#  'AMG E 53 4MATIC+ Estate',
#  'd +LED+ T-Mod. +AHK+Amg Line+Pano+DIST+',
#  'e T AMG/PTS/RFK/NAVI PREMIUM/MBUX/DISTRO',
#  'e T Avantgarde LED Navi Kamera Spurh.-A',
#  'C -Klasse T-Modell C 43 AMG 4Matic T',
#  'CLS 350 BlueTEC /H&K SOUND/ AMG LINE / MULTIBEAM',
#  'S 4M+ T Vmax Performance AHK Distr L',
#  'd T 9G Avantgarde ~LED~Comand~Leder~AHK',
#  'T 4M+ Dynamic+ Carbon Massage Pano D',
#  'CGI T 7-G Exclusive Navi,LED,2.Hand*56tkm*',
#  'lang Avantgarde Sitzklima vo+hi, Pano, Navi/SHD',
#  'EQV 250 Avantgarde Airmatic El Sitze vorne 7-Sitze',
#  'T d 4M AMG Line NP.102.519€*Standhz*Airmat',
#  'T 4Matic+ LEDER NAVI LED NIGHTPAKET 1HD',
#  'de T AMG Line Widesc. Burmester Pano Co',
#  'T COMAND PANO DISTRONIC KAMERA MEMORY',
#  'T AMG/Navi/DigitalLight/Night/R-Kamera/19" Autom.',
#  'd T SPORTST PAN-DACH DISTRONIC STHZG HAF',
#  'CGI Avantgarde LED Distronic + GSD AHK R.Cam',
#  'T d AVANTGARDE/NIGHT/SHD/AHK/LED/NAVI/RFK',
#  'de Navi|Kamera|LED|Sitzhz',
#  'CLS 350 d SB AMG 9G+COMAND+360°+TOTW+LED+DISTR',
#  'SB S 4M+ Pano Night Kamera Navi LE',
#  'E450 T 4M 9G AMG-LINE WIDESCREEN KEYLESS HEAD-UP',
#  'SB S 4M+ Pano Night Kamera Navi LE',
#  'E450 T 4M 9G AMG-LINE WIDESCREEN KEYLESS HEAD-UP',
#  'BlueTEC d T Avantgarde NAV+LED+AHK+KAMERA',
#  'd Estate Business Line',
#  'Estate Business Line',
#  'T d AVANTGARDE/LED/NIGHT/DISTRONIC/AHK/SHZ',
#  'T d 4M AMG/PTS/360/WIDESCREEN/SHZ/NIGHT',
#  'd AMG/rijassist',
#  'Td LED SHZ 2x PDC Navigation ToT Winkel Garantie',
#  'd Estate',
#  '4M T AMG/MULTIBEAM/WIDE/360/SHD/DISTRO/SHZ',
#  'C400 4Matic ILS+ACC+Pano+HUD+AHK+Memory',
#  'de Hybrid T AMG-Line 9G -Tronic Panorama Comand',
#  'd T AMG line Night Edition Navi/Temp/Kamer',
#  '4M T AMG/DISTRO/DIGITAL LIGHT/NAVI/SHZ/AHK',
#  'd 4M T AMG Sport Night Burm Distr LED N',
#  'e T-Modell Avantgarde',
#  'S SB 4M+ Night Pano Aero 360° 19"',
#  'Shooting Brake AMG Line PDC Navi',
#  'T BT STANDHEIZUNG LED ILS PARKASS NAVI SHZ',
#  'E200 T CGI 7G-TRONIC LED Navi Sitzheizung Tempomat',
#  '(BlueTEC) d kompakt 7G-TRONIC Edition',
#  'CDI Urban Style Edition',
#  'CLA45 S AMG SB 4M HEAD-UP MULTIBEAM 360°KAM MBUX',
#  'T AMG 4M*Panorama*AHK*Kamera*Ambiente*LED*',
#  'd T 9G-TRONIC+LED+Navi+AHK+HuD+SHZ+',
#  'T d AVANTGARDE/PTS/RFK/NAVI/DISTRO/AHK/LED',
#  'T AMG LINE MULTIBEAM WIDESCREEN AHK CAMERA',
#  'd T COMAND RFK TOTWINKEL MULTIBEAM STANDHZ',
#  'T 4M AMG Line 2x+Night+Comand+Distr+19"',
#  'de Estate',
#  'd 4M All-Terrain',
#  'd Estate',
#  'd AMG-Line COMAND Pano Carbon Airm Sbel DTR',
#  '4M *Progressive*LED*Sitzheizg*Kamera*MBUX*',
#  'd T 4M  AMG+20"+STANDHZG+HUD+AIRMATIC+PANO',
#  'd AVANTGARDE Ext.+Night+Pano+AHK+MULTIBEAM',
#  '(+)2.1 D AMG LINE 5P',
#  'd Estate',
#  'de T AMG Line DISTRONIC 360° 1. Hand 19"',
#  'e T Avantgarde Pano AHK Sitzklima Navi',
#  'CLA-CLASS 2.1 D DCT SHOOTING BRAKE 136 5P',
#  'd T 4M All-Terrain 20"-AMG+HUD+PANO+STANDHZG',
#  'd T-Modell 9G AMG MULTIBEAM 360-K BURMES.',
#  'T CGI Avantgarde*PDC*SHZ*Navi*',
#  'd T AVANTGARDE LED HP KAMERA NAVI SHZ AMB',
#  'E 63T AMG 514 PS Avantgarde Airmatic Memory',
#  'T AMG/NAVIGTION/LED/AHK/TOTWINKEL/KAMERA',
#  'C220d T Avantgarde LED Navi Leder Sitzheizung',
#  'T e Avantgarde+Spur+Multibea+AHK+Navi+18"',
#  'd Estate Business Line',
#  'SB e AMG',
#  'T LEDER NAVI MBEAM PANO CAM DISTRONIC',
#  'T AMG Line 2x+LED+Nav+HUD+PSD+Distro+Stahz',
#  'B200 CDI AMG AUT 136CV',
#  'CDI BlueEFFICIENCY Edition',
#  'd T Avantgarde *Glasdach*Burmester*',
#  'Sport Utility Automatik *BIXENON*PANO*',
#  'e T AMG-LINE/PANO/D-LIGHT/PTS/360/AHK/SHZ',
#  'd 4MATIC Estate',
#  'T d 4M All Terrain Avantgarde+Exclusiv+20"',
#  'T CDI Avantg 7G-Tr,4Matic,Final Edition Sportpaket',
#  'd T Avantgarde NAV+LED+DISTRONIC+KAMERA+SH',
#  'd T Avantgarde*Navi*LED*Kamera*Tempomat',
#  'T Autom. 1.6 +AVANTGARDE+PANORAMA+NAVI+',
#  'E200d Avantgarde T-Modell Navi+Kamera+LED+DAB',
#  'd Estate',
#  'd T AMG/PTS/RFK/DIGITAL LIGHT/DISTRO/AHK',
#  'Mercedes-AMG 4M Shooting Brake',
#  'AMG CGI T (205.240) 1,6 Ltr. - 115 kW KAT Klima...',
#  '580 4MATIC AMG HYPERSCREEN+DIGITAL LIGHT+HUD',
#  'Limousine *VOLLAUSSTATTUNG*',
#  '580 4M AMG+21"+AHK+AR-HUD+SITZKLIMA+PANO+360',
#  'S 310kW(422ch) DCT * CAM RECUL * GPS * SG CHAUFF *',
#  '43 4MATIC+ (MULTI/DAB/360"/BURMESTER/SAGA',
#  '4Matic Lang*VIP*Executiv*BuremsterHighEnd*',
#  'E-Klasse Lim. E 63 AMG S-Modell 4-Matic',
#  '4Matic Lang*Burmester*AMG*Distronic*HeadUp',
#  '*SHZ*Alpine*Schiebedach*Tempomat*',
#  '4M lang AMG Line Exklusiv-Pak Standhz P',
#  'CDI*Lordosenstütze*Bluetooth*Sitzheizung*',
#  'PLUG-IN HYBRID Lang',
#  "e long HYBRID AMG/360°/PANORAMA/3D/20''",
#  'CDI BlueEfficiency (204.001)',
#  'e 4M lang AMG Line Chauffeur-Pak Exklus',
#  '1.6',
#  'CLS CLS 500 BE 4-Matic',
#  'e lang AMG Line Distr Pano HUD DigitalL',
#  'E 63 AMG E 63 S AMG 4M+ MBUXHighE+PD+Burm+Mbeam+Dr',
#  'L 4Matic AMG-Line*Multibeam LED*Widescreen',
#  'L Hybrid *Nachtsicht-Assist*TV*Keyless*',
#  'CDI BlueTEC Avantgarde NAVI+ / LEDER / LED',
#  'A45AMG4-Matic*Garantie*HarmanKardon*SportAuspuff',
#  '4MATIC AMG nieuwprijs: € 98.326',
#  '450+ NIGHT+20"+PANO+FAHRASS+DIG.LIGHT+360°',
#  '63 4M+*Sport-AGA*Perf-Sitz*Luft*HuD*Burm*',
#  'Lim. Aut. Navi Sitzhz. Temp. PDC Klimaaut.',
#  '4Matic SOFTCLOSE MEMORY TOUCHPAD*CAM',
#  'e AMG+MBUXAdvanced+LED-HP+NightP+SpurA+PTS',
#  'A45S AMG*Aero*Driver´s*Burm*Pano*360°*Distr+*HuD',
#  'CGI BlueEfficiency Avantgarde',
#  'd',
#  'Mercedes-AM53 4MATIC+',
#  '7G-TRONIC Navi Leder',
#  '525PS Memory Navi Leder Bi-Xenon BT',
#  '4M+ Comand*Multibeam*Sitzklima*Pano*HUD',
#  'LANG 4M PANO KAMERA KEYLESS WEBASTO LIEGE',
#  '-CLASS 4.7 455 4P',
#  '-CLASS 4.7 455 4P',
#  '580 4M AMG+21"+HA-LENKUNG+AR-HUD+SITZKLIMA',
#  'Electric/Distr/KeyG/360/Memory/Burmeste Navi/LED',
#  '580 4M ElectricArt*Pano*MBUX*KeylessG*Memory',
#  'd AMG L 4Matic Leder/Distronic/HUD/Pano/Ka',
#  'AMG 4M 21"+HYPERSCREEN+SITZKLIMA+CARBON',
#  'd 4Matic AMG*Burmester*360-Kamera*Softclose',
#  'e Lim Progressive+MBUXAdvanced+SpurAss+PTS',
#  'd 4M Distr LED Pano Navi SHD Luftf. Kam',
#  '4-MATIC Automatik *PANO*HARMAN-KARDON*',
#  'Mercedes-AMG S 4MATIC+',
#  'Mercedes-AMG S 4MATIC+',
#  '450+ Electric Art DIGITAL LIGHT+DISTRO+Pano',
#  '-CLASS 2.1 D 4MATIC AUTO 170CV 4P',
#  'AMG Line Aut+Navi+Shz+Kam+LED+EU6+Night+',
#  'E280 Aut. Lim. Elegance Navi Xenon Temp. Sitzhz.',
#  '5.5 557PS BiTurbo Limo Pano ACC Keyless',
#  '4Matic AMG Speedshift 7G-DCT Pano',
#  'T 4Matic AMG-Line ACC Pano Navi Touch  LED',
#  'CDI AMG-Line 4Matic *XENON*NAVI*CAM*PANO',
#  'L AMG / FOND TV / BURM.3D / DESIGNO',
#  '4M+ Lim. Sitzklima*Burmester',
#  'e Limo Progressive AHK Navi Spurh.-Ass.',
#  '1.6 115kW(156ch) * GPS * CAM RECUL * TOIT PANO *',
#  '4M+ MBUX/MULTIBEAM/SHD/360°/NIGHT PAKET',
#  'CDI BT 4M Avantgarde+ILS+Comand+SD+8-fach',
#  '4Matic 7G-DCT+LED+Navi+Designo+SHZ+',
#  '450+ ELECTRIC ART/DISTRO/MBUX/PANO/360/PTS',
#  'CDI/AMG/SH/SW/NAVI/8XR/TEM/SHZ/PDC',
#  'S 4Matic+ Alu LEDMultibeam Head-Up Navi P',
#  nan,
#  'CDI Business',
#  'AMG E 63 S 4M*Fahrass*Burmester*Pano*Memory*360°',
#  '450+ PANO+DIG.LIGHT+KEYLESS+FAHRASS+360°',
#  'd',
#  '4M Night 19" LED Navi Kamera Sounds.',
#  '*LEDER*MEMORY*GLASDACH*TOP ZUSTAND*',
#  'S 4M+ Drivers-P+Night+Pano+DISTR+HUP+TV',
#  '-CLASS D G TRONIC PLUS AVANTGARDE',
#  'CDI Elegance KLIMAAUTO TEMPO NAVI SHZ',
#  'e Lim Progressive+MBUX+LED-HP+Mem+KeyG+RFK',
#  'Pano/Distr/KeyG/360/Memory/Burmester Navi/Klima',
#  'CDI 4Matic/Pano/Navi/Off-Road/ AMG Line',
#  '4M  AMG+21"+FOND-TV+CHAUFFEUR+HUD+STANDHZG',
#  'e lang *AMG*ChauffeurP*ParkP*MemoryP*Pano*',
#  'AMG/Pano/Distr/KeyG/360/AHK/Mem/Burmest Navi/LED',
#  'de AMG/MULTIBEAM/MBUX/DISTRONIC/PANO/SHZ',
#  'd 4M Multibeam Burmester HUD 360°Cam Distr+',
#  'AMG Kompressor 500 PS 5G Key Distronic DEU',
#  'd',
#  'd LANG AMG 4Matic*CHAUFFEUR*MASSAGE*TV*',
#  'd',
#  'd',
#  '4M L AMG Sport Distr Pano Navi SHD TV L',
#  '450  AMG+NIGHT+21"+FONDSITZ-PAKET+PANO+HUD',
#  '4M Pano+DISTRON+HUP+MULTIBEAM+Com+360°-Kam',
#  'AMG C 63 S AMG Speedshift 7G-MCT',
#  '350 Electric Art+Pano+AIRMATIC+DISTRON+OLED',
#  '4M L AMG Sport FirstClass Standhz. Dist',
#  'Kompr.*2xSHZ*2xPDC*SCHECKHEFT*TÜV NEU',
#  'Mercedes-AMG 4MATIC',
#  '53 4M+ *AMG*DAB*MBUX*EasyP*Pano*OLED*NightP*',
#  'd',
#  'CDI 4M Aut. AMG Line',
#  'e Lim Progressive+MBUX+NavPr+LED+Sound+RFK',
#  '4M AVANTGARDE/NAVI/SITZKLIMA/DISTRO/LED',
#  'AVANTGARDE/NAVI/LED/MBUX/MEMORY/HIGH END',
#  '*Navi*Bluetooth*Tempomat*Klima*',
#  'AVANTGARDE/NAVI/LED/MBUX/MEMORY/HIGH END',
#  '*Navi*Bluetooth*Tempomat*Klima*',
#  'S 4M+ Drivers-P+Night+MULTIBEAM+Burmest',
#  'AMG*AmbientLight*StHz*Totwinkel*MBUX*',
#  '4 Matic Autom. LED~NAVI~SHZ~2xPDC~ALU',
#  'de',
#  '350 NIGHT+PREMIUM+21"+PANO+AHK+SITZKLIMA',
#  '1.6i 122cv automatique - Pack AMG - GPS - Caméra d',
#  '+ EDITION 1-HEADUP-PANO-AIRMATIC-360°',
#  'AVANTGARDE AUTOMAT+KLIMA+XENON+ALU+AHK',
#  'E D AUT',
#  'e Lim Progressive+MBUXHigh+LED+18+Sound+RK',
#  '4MATIC DIGITAL LIGHT+HUD+BURMESTER+PANO',
#  '4M AMG/DISTRO/PTS/360/DIGITAL LIGHT/PANO',
#  '4M AMG/DISTRO/PTS/360/DIGITAL LIGHT/PANO',
#  'e Limousine AMG/NAVI/LED/MBUX/PTS/SHZ',
#  'd lang BlueTEC*AMG*Distronic*Burmester*',
#  'd 9G-TRONIC Avantgarde MULTIBEAM LED',
#  'e lang AMG Line Chauffeur-Pak Exklusiv',
#  'CLA-CLASS 2.1 CDI DCT 170CV 4P',
#  'CLA-CLASS 2.1 CDI DCT 170CV 4P',
#  '350 4M grau magno PROGRESSIVE+AHK+PANO+TOTW',
#  '4M+ Night Distr Burm Pano Kamera Mul',
#  'd Lim. Avantgarde COMAND ILS Leder ParkA.',
#  'L AMG 4Matic Navi/Leder/Distronic/Burmeste',
#  'e Lim Progressive+MBUX+NavP+LED+ASound+RFK',
#  'd AMG',
#  '3.0 258 PS BlueTEC / d Pano Distronic Keyl',
#  'd +DISTRONIC+Gr.Tank+MBUX+5 Fahrassistsys',
#  'AMG  4M /21"/Digital Light/Pano-D',
#  '4M *Night*Sitzhzg*Kamera*Standhzg*LED*',
#  '+ AMG MBUX+Dig-LED+HUD+Pano+Distronic+21',
#  'Sedan 9G-Tronic AMG LINE - FULL LED - ALU - BLIS -',
#  '+ AMG MBUX+360°+Pano+DIG-LED+HUD+Distro',
#  'e Limousine AMG LINE/KAMERA/NAVI/PTS/LED',
#  '+ AMG/AIRMATIC/NAVI/DISTRO/PANO/360/SOUND',
#  'E -Klasse Lim. E 320',
#  'BlueTEC Sport',
#  '4M*Fahrass*Pano*Kamera*Burmester*Keyles',
#  'B -Klasse B 200 Turbo Special Edition/ PDC/Tempo',
#  'e Lim AMG+MBUXAdvanced+LED-HP+Spur+ParkAss',
#  'Aut. Navi Harman-Kardon Bi-Xenon Temp.',
#  'e AMG Line+Exclusive+Night+LED+Kam+Nav+18"',
#  '4M AMG MBUX+360°+HUD+DIG-LED+Burmeste',
#  'Lim. Aut. Navi Klimaaut. Schiebedach Shzng',
#  'e AMG+20"+EXKLUSIV+AR-HUD+HA-LENKUNG+PANO',
#  'A -Klasse A 160 NAVI SHZ',
#  '4M MULTIBEAM 360°KAMERA HEAD-UP KEYLESS',
#  'e Lim AMG+MBUXAdvancedP+NightP+Spur+Kamera',
#  'S 4M+ AMG Aerodynamik Night 19" Pano',
#  'Mercedes-AMG 4MATIC',
#  'CLS-CLASS 272 4P',
#  'd',
#  'e Lim Progressive+MBUXAdvanced+SpurA+ParkA',
#  'Blue Efficiency Avantgarde',
#  'e Lim Progressive+MBUX+NavP+LED+ASound+RFK',
#  'Limousine 4M*PANO*KAMERA*LED*19ZOLL*',
#  '4M AVANTG. AMG-LINE PANO 360°KAMERA DISTRO',
#  '+ EDITION1+AMG+AIRMATIC+PANO+HUD+MEMORY',
#  'S 4M+ Performance-Sitz Distr LED Pan',
#  'd 4M Avantggarde Distr Standh HUD Multi',
#  '-Klasse B 220 d Progressive Panorama Kamera AHK',
#  'CDI /1.HD-SH/AHK/TEMP./Park Assis/Sitzh./',
#  'd 4M AVANTGARDE COMAND WIDESCREEN 360°KAM',
#  'e Lim MBUXAdvancedPaket+SpurAss+ParkAssist',
#  'CDI BE Avantgarde Blue Effic. Ed.',
#  'e Lim Progressive+MBUX+NavPr+LED+Sound+RFK',
#  '/ 1 Hd/ Rentner/Sammlerzustand',
#  'V8 Autom, Leder, Klima, SSD.',
#  '4M AMG/DISTRO/PTS/360/MEMORY/DIGITAL LIGHT',
#  'BlueTEC 4Matic (212.011)',
#  'ElectricArt/PanoDa/Distr/KeyG/360/Memor Navi/LED',
#  'd 4Matic Alu Multibeam-LED Standh. Head-Up N',
#  'Business-Solution',
#  '450+  AMG+NIGHT+20"+PANO+AHK+HUD+KEYLESS+360',
#  'Org. 61.000km Aut. Historie 1A Sammlerzust.',
#  '4M Avantgarde+Comand+Distr+SHD+Multibe+AHK',
#  'e AMG Line*Night*Pano*Head-Up*AHK*Keyless*',
#  'de',
#  '4M EDITION ONE AMG-DISTR-PREMIUM-PANO-360°',
#  '+   ELECTRIC ART+20"+SITZKLIMA+AHK+KEYL.',
#  ...]

# %%
handle_missing_values(df , "gears")
# Out:
# Missing Values in 'gears':
# Count: 9654
# Percentage: 33.75%

# %%
# Let's retrieve the entries that contain "7-G, 7G, 7G , 7G-" and assign them the label .

# The expression "(?i)" in the code disables case sensitivity.

found_gears  = df.loc[df[df["gears"].isnull()].index, "short_description"].str.extract("(\d{1,2})[-]*G[ +-]").astype(float)
found_gears.value_counts()
# Out:
# 7.0    74
# 9.0    32
# 8.0     5
# 2.0     2
# 5.0     1
# 6.0     1
# dtype: int64

# %%
found_gears = found_gears.dropna()

# %%
# found_gears.values.tolist()

# %%
handle_missing_values(df , "gears")
# Out:
# Missing Values in 'gears':
# Count: 9654
# Percentage: 33.75%

# %%
# After the this operation, how many NaN values do I have filling?
found_gears[found_gears.notnull()].count()
# Out:
# 0    115
# dtype: int64

# %%
df.loc[found_gears.index , "gears"] = found_gears.values.tolist()

# %%
handle_missing_values(df , "gears")
# Out:
# Missing Values in 'gears':
# Count: 9539
# Percentage: 33.35%

# %%
# After the groupby operation, how many NaN values do I have remaining?
df.groupby(["gearbox", "body_type"])["gears"].transform(lambda x: x.mode()[0]).isnull().sum()
# Out:
# 0

# %%
df['gears'].fillna(df.groupby(["gearbox", "body_type"])["gears"].transform(lambda x: x.mode()[0]), inplace = True)

# %%
handle_missing_values(df , "gears")
# Out:
# Missing Values in 'gears':
# Count: 0
# Percentage: 0.00%

# %% [markdown]
# <a id="16"></a>
# <div class="alert alert-info" role="alert">
# <h1>Column name :<span style="color:red"> first_registration </span></h1>
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Operation : </b> To fill in the missing values in the "first_registration" column, we can use the "short_description" column . Since the "first_registration" column is associated with <span style="color:red"><b> " make " and " model "</b></span> . let's fill in the <span style="color:red"><b> NaN values</b></span> in this column by grouping the data based on these columns and performing the necessary operations.
# </div>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
first_looking("first_registration")
# Out:
# column name    :  first_registration
# --------------------------------
# per_of_nulls   :  % 0.01
# num_of_nulls   :  2
# num_of_uniques :  83
# 2019.0    3666
# 2018.0    3486
# 2022.0    3082
# 2021.0    2867
# 2020.0    2472
#           ...
# 2023.0       1
# 1929.0       1
# 1950.0       1
# 1928.0       1
# 2202.0       1
# Name: first_registration, Length: 84, dtype: int64

# %%
# After the groupby operation, how many NaN values do I have remaining?
df['first_registration'].fillna(df.groupby(['make', 'model'])['first_registration'].transform(lambda x: x.mode()[0])).isnull().sum()
# Out:
# 0

# %%
# groups of nan values have sufficient non-null data to create insight for null values.
# Since number of Nan values in First_Registration  is two. Nan values are identified according to Make and Model columns and fillna implemented.
df['first_registration'].fillna(df.groupby(['make', 'model'])['first_registration'].transform(lambda x: x.mode()[0]), inplace = True)

# %%
handle_missing_values(df , "first_registration")
# Out:
# Missing Values in 'first_registration':
# Count: 0
# Percentage: 0.00%

# %%
df.first_registration.value_counts()
# Out:
# 2019.0    3667
# 2018.0    3486
# 2022.0    3082
# 2021.0    2868
# 2020.0    2472
#           ...
# 1929.0       1
# 1956.0       1
# 2202.0       1
# 1928.0       1
# 1950.0       1
# Name: first_registration, Length: 83, dtype: int64

# %%
df[(df["make_model"] == "Renault Clio") & (df["body_type"] == "Sedan")& (df["gears"] == 6.0) &(df["gearbox"] == "Manual") ]["first_registration"].unique()
# Out:
# array([2018., 2021., 2022., 2017., 2020., 2019., 2002., 1992., 2005.,
#        2015., 2202., 2016.])

# %%
df[df.first_registration == 2202.0][["make_model","body_type", "gears", "gearbox"]]
# Out:
#         make_model body_type  gears gearbox
# 7058  Renault Clio     Sedan    6.0  Manual

# %%
# Although we attempt to reduce the data, we cannot make a precise comment about the value entered as 2202 in this context.
# Let's drop this index

# %%
df = df.drop(index = 7508)

# %%
selected_columns = ['price', 'make_model', 'model', 'first_registration', 'engine_size', 'model_code']
filters = {'make_model', 'body_type', 'gearbox', 'gears', 'engine_size' }
select_rows(df, selected_columns, filters )
# Out:
# Dropdown(description='gears:', options=(5.0, 9.0, 8.0, 7.0, 6.0, 1.0, 4.0, 3.0, 0.0, 2.0, 10.0), value=5.0)
# Dropdown(description='gearbox:', options=('Manual', 'Automatic', 'Semi-Automatic'), value='Manual')
# Dropdown(description='make_model:', options=('Mercedes-Benz A 160', 'Mercedes-Benz EQE 350', 'Mercedes-Benz A …
# Dropdown(description='body_type:', options=('Compact', 'Convertible', 'Coupe', 'Off-Road/Pick-up', 'Station wa…
# Dropdown(description='engine_size:', options=(1.4, 0.0, 1.9, 2.1, 1.7, 1.3, 2.0, 1.5, 1.6, 1.8, 3.9, 0.3, 2.9,…
# Button(description='Selection', style=ButtonStyle())

# %% [markdown]
# <a id="17"></a>
# <div class="alert alert-info" role="alert">
# <h1>Column name :<span style="color:red"> doors </span></h1>
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Operation : </b> To fill in the missing values in the "doors" column, we can use the "short_description" column . Since the "doors" column is associated with <span style="color:red"><b> " body_type "</b></span> . let's fill in the <span style="color:red"><b> NaN values</b></span> in this column by grouping the data based on these columns and performing the necessary operations.
# </div>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
first_looking("doors")
# Out:
# column name    :  doors
# --------------------------------
# per_of_nulls   :  % 1.24
# num_of_nulls   :  356
# num_of_uniques :  6
# 5.0    17467
# 2.0     5513
# 4.0     3000
# 3.0     2259
# NaN      356
# 6.0        5
# 1.0        2
# Name: doors, dtype: int64

# %%
# Let's examine the short description of the seats
list(df.loc[df[df["doors"].isnull()].index, "short_description"])
# Out:
# ['UNIEKE SL 560 EUROPESE LOOK IN NIEUWSTAAT.AUTOM.',
#  'SL Vollrestauration',
#  'SL',
#  'Cabrio',
#  '190SL',
#  'C Coupe*DEUTSCHES-FAHRZEUG*AUTOMATIK*H-KENNZEICHEN',
#  'Coupe AMG + NIGHTPACK - LEDER - PANO DAK - 360° -',
#  'EQ HEV HYBRID *4 MATIC*GPS*CAMERA*LED*ALU BI COLOR',
#  '316 DOKA+PRITSCHE+KLIMA 7 SITZER 316 CDI',
#  'd 4M All-Terrain',
#  'd avantgarde',
#  '2.3 16',
#  'Org. 61.000km Aut. Historie 1A Sammlerzust.',
#  'S 1.4 TURBO *LEDER RECARO*INFINITY SOUND*CARPLAY*S',
#  '1.0 Turbo Glam Winterpaket Temp LED-Himmel',
#  'CABRIO 1.6 BENZINE MT',
#  nan,
#  'Innovation ecoFlex 2.0 CDTI/Nav/Leder/Xe',
#  nan,
#  'Olimpia 1.5 Coupe  //Top Zustand//',
#  nan,
#  'GT/E gruppo 2',
#  nan,
#  nan,
#  'GTE - CONRERO',
#  'Irmscher GSE Oltimer FIA Liebhaber ',
#  'J GTC Innovation,1.Hand,Xeno20 Zoll, Video',
#  nan,
#  '1.3 CDTI . GTC',
#  '1.3 CDTI Advance 95cv S/S 5 PORTE',
#  '1.3 CDTI b-Color 75cv 5 PORTE',
#  '2.0 D 120 Jahre FLA LM AkustikGlas',
#  '1.2 TURBO INNOVATION *AUTOMAAT 6-TRAPS*GPS*CARPLAY',
#  'Innovation 1,2 96kW Automatic,Navi,Alu,Klima,SH PD',
#  '1.5 TURBO DYNAMIC SPORTS TOURER *AUTOMAAT*OPC INTE',
#  '2.0d COSMO SPORTS TOURER *AUTOMAAT*GPS*SENSOREN*CA',
#  '2.0d INNOVATION GS *ADAPTIVE SUSPENSION*LED*360 CA',
#  'Zen TCe90 X-Tronic Klima Sitzheizung Navi PDC',
#  'Life 80',
#  'ELECTRIC ZEN',
#  '80 INTENS WHITE',
#  'V Intens RS Line TCe 130 EDC LED Navi PDC',
#  'Alpine A110 1.8 Pure auto',
#  'R4 Cabriolet / Sammlerfahrzeug / 1. Hand',
#  'Sporter Blue dCi 160 CV EDC Exe',
#  '1.5 dCi 110CV S-S 4p. Express Ice',
#  '1.2 75CV GPL 5 porte Wave 201407',
#  'R.S. TCe 280 GPF EDC',
#  'tce 140 edc fap r.s. line',
#  'A310 S “Pack“ 3,0 Turbo',
#  'Mégane Coupé 1.5 dCi 110CV Dynamique',
#  'A 310',
#  'Coupe 2.0 turbo RS 275cv E6',
#  '45 ELECTRIQUE',
#  'tce 160 edc fap - 21b r.s. line',
#  'Rs',
#  'Megane 1.5 dci Luxe 110cv',
#  'II 3.0 V6 Sport',
#  '3 COUPE RENAULT SPORT 265 S&S',
#  'ARKANA E-Tech 145 - 21B R.S. Line',
#  'V6 TURBO',
#  'ARKANA TCe 140 EDC FAP R.S. Line',
#  nan,
#  '1.0 TCE 74KW BUSINESS 5 PORTE',
#  'DCI 180 4 CONTROL',
#  'coach 2000 16 v montecarlo',
#  'Komfort-/Sicht-/Ablagenpaket',
#  'II 3.0 V6 Sport',
#  'II 2.0 DCI 150 GT COUPE',
#  'tce 140 edc fap - 21b r.s. line',
#  'Komfort-/Sicht-/Ablagenpaket',
#  'Black Edition 1.6 dCi 130 Energy',
#  'Business 1.5 dCi 90 Energy eco2',
#  'Intens Double Cab 4x4 360 Kamera PDC',
#  'DoKa Pritsche Fahrgest. L3H1 3,5t 3',
#  'Kombi Grandtour Benzin/Alkohol (III) TomTom',
#  'E-Tech 100% ele. TECHNO EV60 220hp',
#  'iv rs trophy 300hp - sans malus',
#  'Initiale Paris 1.6 dCi 160 Energy EDC6',
#  'TCe160 EDC Init. Paris LED ACC MEMORY',
#  '4 IV (BFB) 1.8T 280CH RS EDC',
#  '4 IV (BFB) 1.8T 280CH RS EDC',
#  'Initiale 1.6 16V 110',
#  '1ste Eigenaar 134.000km Garantie+Keuring',
#  '1.4 Essence 75 CV BVA',
#  'WAGON Business 1.6 8v e-HDi 115cv S/S',
#  '2.0 HDI 120CV DISTRIB OK',
#  nan,
#  nan,
#  '<NULL',
#  '1.6 VTI 16V FELINE',
#  'Automatik Leder',
#  'coupe 2.7 hdi 204ch griffe ba',
#  'GTI 16V ( vraie et bleu Miami !! )',
#  '2.0 HDi 163',
#  'GTI 2.0 16v',
#  'COUPE GRIFFE 2.7 V6 HDI 204ch BVA6 1ere MAIN',
#  'Active BlueHDi 120cv S&S 5 PORTE BERLINA',
#  nan,
#  'SW GT HYBRID 180 e-EAT8',
#  'SW PSE Hybrid 360 Automatik 8-Gang',
#  'SW GT Pack BlueHDi 130 Automatik 8-Gang',
#  'ACTPK PT100',
#  nan,
#  'Active',
#  'Pop Elektro Standheizung Kundendienst neu',
#  'LOUNGE / PANO',
#  'Wenig Km 8-fach TÜV 10.2023',
#  'Abarth 595 Tourismo 1.4 Turbo-Jet 165 BVA',
#  nan,
#  nan,
#  'Dynamic 1.4 16v Starjet 95',
#  'Hybrid *Cruisecontrol*DAB*Airco',
#  nan,
#  'LOUNGE FULL OPZIONAL CON TETTO APR ELET PRONTI VIA',
#  nan,
#  '1.0 70CV HYBRID CABRIO LOUNGE CARPLAY CLIMA BICOLO',
#  '1973 FIAT COUPE',
#  'LOUNGE NAVI CAR PLAY SENSORI PARCHEGGIO',
#  '1.2 SPORT NAVI CAR PLAY CERCHIO 16 PDC BLUETOOTH',
#  '2300 S Coupe',
#  '1800',
#  'Fiat - 1500 cabriolet',
#  'Coupé 20V Turbo Leder Radio CD Brembo  2. Hand His',
#  nan,
#  nan,
#  'S COUPE',
#  '2000 turbo 16 plus',
#  'Fiat 124 ac COUPE’ 124 sport',
#  nan,
#  "COUPE' 2000",
#  'COUPE',
#  'Turbo 20 valvole',
#  "1100/103 TV COUPE' PININFARINA",
#  '4x4 Sisley',
#  'Lombardy my car sporting very rare',
#  '2.0 20v turbo Limited edition ( LTD )',
#  '2000 Coupè Bellissimo',
#  'coupé condizioni uniche libretto tagliandi!',
#  '1000 OT  4 FARI',
#  'Vignale',
#  'Action-Topolino Lotus Edition, Modellreihe 2022',
#  'ufficiale 1971',
#  nan,
#  'MY21 1.0 GSE Hyb. Dolcevita',
#  nan,
#  '1.3 MultiJet Lounge 95cv S&S EU6 5 PORTE BERLINA',
#  'Cross My21 0.9 Twinair Turbo 85cv S&S 4x4 Cross',
#  '1.3 MULTIJET 95 CV URBAN LOOK  - 4° SERIE',
#  'Lounge 1.6 Multijet 120',
#  'FIREFLY TURBO LIFE 100',
#  'HATCHBACK LIFE',
#  '2.0 TDI DSG Style',
#  '86.000 km.  1st eigenaar.  •Garantie•',
#  '1,5TSI FR 6-Gang Winter Paket',
#  '1.2 benzina',
#  'Style+LED+PDC+CLIMATRONIC+KAMERA+BOLERO',
#  'Ambition 2.0TDI DSG NAV ACC KEYLESS Navi',
#  'Sportline 2.0 TSI DSG 4x4- 1.Hand,AHK,PDC Klima',
#  '1.0L PDC, Bremsass, Android, Apple',
#  '3ª SERIE 2.0 TDI DSG EXECUTIVE',
#  'TCe 90  Easy-R Comfort AUTOMATIK 1Hd.',
#  'Stepway 0.9 TCe 90 CV Comfort 2',
#  '1.6 SCe GPL 4x2 Techroad 201902',
#  '1.0 BENZINE-LPG *BTW AFTREKBAAR*SENSOREN-A*AIRCO*',
#  'Benzine, Handgeschakeld + 1Jaar garantie en pechbi',
#  'TCe90 Laureate | Airco | Bluetooth |',
#  'Comfort TCe 110 7-Sitzer',
#  'Stepway 1.6 8V 85CV',
#  'Comfort TCE 90 CVT',
#  'GR PERFORMANCE 1.6T *260pk*LED*CARPLAY*CAMERA*AIRC',
#  'Yaris - 1,5 l Hybrid, 5-türig, Active Dr',
#  nan,
#  'COUPE 2.0 D-4S 200 BVA PACK TRD',
#  'WAGON Hybrid Business',
#  'Tbar',
#  '*francois duval rally sport vintage*pret a rouler*',
#  'Coupé',
#  'MK4 RHD Twin Turbo',
#  'ST',
#  '2000cc Valuto permute',
#  nan,
#  '1982 Rouge Diesel 5 portes Manuelle 4.3 Turbo SUV/',
#  '4.0 Fj70',
#  '4.0 Fj73',
#  '1988 Gris Essence 3 portes Manuelle 4.0 SUV/4&#215',
#  'Fj55 1978',
#  '4.0 4x4',
#  '4.5 Fzj73',
#  '1.8 BENZINE // NAVIGATIE',
#  '1.2 Style',
#  '1.0 LES BLEUS',
#  '350 Z V6 *WENIG KM* TOP-ZUSTAND*',
#  nan,
#  'S15 Spec R AERO / Perlmutt white / NETTO 29.000€',
#  'R34 GTR Vspec / Limited #51/80 / Nismo',
#  'R33 Gtst',
#  '(2) COUPE 3.7 V6 344 NISMO',
#  'S15 Spec S now in holland',
#  '300 ZX  TARGA  1 Hand  Automatik  Leder   BOSE',
#  'H-Kennzeichen',
#  'TEKNA DC 2.3dCi 190PK 7AT',
#  'N-Vision 1.6 dCi Navi Keyless Parklenkass. Rückfah',
#  'Acenta 1.6 dCi 130',
#  'Stagea RS Four S / RB25DET / 4WD / Manual / Rar...',
#  'Evalia Premium Klima Standh. AHK Kamera 1. Hand',
#  '1.5 DCI 110 CONNECT EDITION 360',
#  'TOWNSTAR 1.3 DIG-T KOMBI N-DESIGN |NAVIGATION|',
#  'Evalia 40 kWh EL Combi Comfort Plus 5prs.',
#  'N-Connecta + Design pack',
#  'N-Connecta',
#  'N-Connecta 1.3 DCT',
#  '1.3 DIG-T MHEV 158 pk Tekna Plus',
#  'N-Connecta',
#  'N-Connecta',
#  'N-Connecta',
#  '1,0 IG-T 92pk MT N-Design *4jaar garantie',
#  '1,0 IG-T 92pk MT N-Design',
#  '1,0 IG-T 92pk MT N-Design *4 jaar garantie',
#  '1.2 Benzine M5 70PK',
#  'GT 305 CV',
#  'BADLANDS 2 PORTE 4X4',
#  'V6 Cabrio',
#  '1966 FORD CABRIOLET',
#  '1966 FORD CABRIOLET V8',
#  '1965 Ford 64 1/2 Convertible V8',
#  '1965 FORD CABRIOLET PONY',
#  '1967 FORD CABRIOLET CODE A V8',
#  '1965 FORD V8',
#  'CABRIOLET',
#  'CABRIOLET',
#  'CABRIOLET',
#  'CABRIOLET',
#  'CABRIOLET',
#  'CABRIOLET',
#  'CABRIOLET',
#  'CABRIOLET',
#  'CABRIOLET',
#  'COBRA 427 PIGEON PERFORMANCE',
#  'V8 Hot Rod*Typisiert*',
#  '5.0 GT V8 Convertible Premium-Paket III MagneRide',
#  nan,
#  'T ROADSTER  open tourer *CABRIOLET* *1928*',
#  'GALAXIE SKYLINER V8 H ZULASSUNG',
#  "Hot rod 1932 V8 d'origine Carte grise française",
#  'Cabrio',
#  'cabriolet',
#  nan,
#  '1969 FORD FASTBACK MACH1',
#  '1967 FORD COUPE V8',
#  '2021 Ford Shelby GT500',
#  '1970 FORD FASTBACK MACH1',
#  '1966 FORD COUPE GREEN APPLE',
#  'COUPE',
#  'FASTBACK',
#  '1966 FORD COUPE V8',
#  '1967 FORD COUPE V8',
#  'COUPE V8 289CI',
#  '1969 FORD COUPE V8',
#  'COUPE V8',
#  'COUPE',
#  'COUPE',
#  'ELEANOR GT500',
#  '1965 FORD COUPE',
#  'COUPE V8',
#  '1968 FORD FASTBACK V8',
#  'COUPE',
#  'COUPE',
#  'COUPE',
#  'COUPE',
#  'COUPE',
#  'COUPE',
#  'Cougar 5,7 Ford Racing Motor,H-Zulassung',
#  'COUPE',
#  'COUPE V8',
#  'COUPE',
#  '2.3 Ecoboost 317ch BVA Cuir Ventilé + Chauff',
#  'Ranger 3.2/Automaat/BTW/Black Pak/Garantie/Full',
#  'Trend',
#  'ST-LINE 1.0i EcoBoost met 125 PK! STOCKWAGEN!',
#  'ST Edition LED Technologie-Paket B+O-Sound sofort!',
#  '36.702km - NIEUWSTAAT',
#  'AWD STD RANGE',
#  'Titanium X 2.0 EcoBlue mHEV met 150 PK',
#  'Titanium X 2.0 EcoBlue mHEV met 150 PK',
#  'Titanium X 2.0 EcoBlue mHEV met 150 PK',
#  'Camper 350L Big Nugget 2.0 TDCi met 130 PK!',
#  'Turbo 100PS 48V Intro Edition Plus Paket+Navipaket',
#  'FL N Performance DCT Navi Komfortp Panoramadach Qu',
#  'N Performance DCT Navi N-Sportschalensitze Querver',
#  'Sportplus 1,6 GDI 140PS',
#  'N Performance Navi Assistenzpaket Dachlackierung',
#  '20 coupe1.0 t gdi 120 creative',
#  'PRIME Benziner Schalter FAHRSCHULAUTO+AHK',
#  '1.6 Turbo Trend 1. Hand',
#  'Turbo Automatik Trend Navi Kamera',
#  '1,6 T-GDI Plug-in-Hybrid SEVEN',
#  'Full-option *Leder*Zetelverw*...',
#  '1.6 GDI XTech',
#  'N Performance DCT Schalensitze Assistpaket',
#  'Facelift (MJ21) Elektro STYLE-Paket',
#  'Klima,elektr. Fenster, elektr Spiegel',
#  nan,
#  'Elektro 72KWH Project 45 4WD Solardach',
#  nan,
#  'FL 1.4 BENZIN 5-GANG M/T YES!PLUS (2017)',
#  'Style Plug-In FLA SpurH LM LED 2xKlima Nav',
#  '1.6 D Momentum',
#  '1.6 D Momentum',
#  'euro 5',
#  '2.0  - ONLINE AUCTION',
#  'euro 5',
#  '2.0  - ONLINE AUCTION',
#  'D2 Business 5 PORTE BERLINA',
#  'P 1800 E Automatik Restauriert',
#  nan,
#  'JENSEN *UK BUILT*',
#  'D2 Business 5 PORTE BERLINA',
#  'P1800S meccanica revisonata - ASI CRS',
#  'ES 1800',
#  'D2 Business 5 PORTE BERLINA',
#  'D2 Business 5 PORTE BERLINA',
#  'D2 Business 5 PORTE BERLINA',
#  'P 1800 E Automatik Restauriert',
#  nan,
#  'JENSEN *UK BUILT*',
#  'D2 Business 5 PORTE BERLINA',
#  'P1800S meccanica revisonata - ASI CRS',
#  'ES 1800',
#  'D2 Business 5 PORTE BERLINA',
#  'D2 Business 5 PORTE BERLINA',
#  'II Inscription D4 AWD Geartronic',
#  'II Inscription D4 AWD Geartronic',
#  'B4 R-DESIGN HEV HYBRID DIESEL *BTW AFTREKBAAR*LED*',
#  '2.0 D3 Euro 6 150 pk',
#  '2.0 T8 Plug-in Hybrid Inscription',
#  'B5 Mild Hybrid AWD FACELIFT',
#  'B4 R-DESIGN HEV HYBRID DIESEL *BTW AFTREKBAAR*LED*',
#  '2.0 D3 Euro 6 150 pk',
#  '2.0 T8 Plug-in Hybrid Inscription',
#  'B5 Mild Hybrid AWD FACELIFT',
#  '2.4 D4 4x4 Ocean Race Automaat',
#  'T6 Recharge R Design PANO/GOOGLE',
#  'T6  Recharge R Design PANO/GOOGLE',
#  'T8 Recharge R Design + LUCHTVERING/PANO/B&W/...',
#  '2.4 D 4x4 Automaat Summum 1 ste eigenaar',
#  'T3 Momentum Core',
#  'T6 Plug-in Hybride R Design GOOGLE',
#  'B5 Mild Hybrid Inscription FACELIFT GOOGLE',
#  '1.5 T3 R Design + PANO DAK/360 CAM/...',
#  'T2 Core MODEL 2023 !!!',
#  '2.0 B4 Mild Hybrid Inscription',
#  '2.0 D4 R Design automaat Facelift',
#  '2.0 D4 Inscription + GEKOELDE ZETELS',
#  '2.0 T5 Summum Automaat',
#  '2.0 D4 R Design Automaat + PANO DAK/STYLING PACK/.']

# %%
df.doors.value_counts()
# Out:
# 5.0    17467
# 2.0     5513
# 4.0     3000
# 3.0     2259
# 6.0        5
# 1.0        2
# Name: doors, dtype: int64

# %%
 df.groupby(["body_type"])["doors"].transform(lambda x: x.fillna(x.mode()[0])).value_counts()
# Out:
# 5.0    17624
# 2.0     5712
# 4.0     3000
# 3.0     2259
# 6.0        5
# 1.0        2
# Name: doors, dtype: int64

# %%
# After the groupby operation, how many NaN values do I have remaining?
df.groupby(["body_type"])["doors"].transform(lambda x: x.fillna(x.mode()[0])).isnull().sum()
# Out:
# 0

# %%
df['doors'].fillna(df.groupby([ "body_type"])["doors"].transform(lambda x: x.mode()[0]), inplace = True)

# %%
handle_missing_values(df , "doors")
# Out:
# Missing Values in 'doors':
# Count: 0
# Percentage: 0.00%

# %% [markdown]
# <a id="18"></a>
# <div class="alert alert-info" role="alert">
# <h1>Column name :<span style="color:red"> drivetrain </span></h1>
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Operation : </b> To fill in the missing values in the "drivetrain" column, we can use the "short_description" column . Since the "drivetrain" column is associated with <span style="color:red"><b> " body_type " and " gearbox "</b></span> . let's fill in the <span style="color:red"><b> NaN values</b></span> in this column by grouping the data based on these columns and performing the necessary operations.
# </div>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
first_looking("drivetrain")
# Out:
# column name    :  drivetrain
# --------------------------------
# per_of_nulls   :  % 40.96
# num_of_nulls   :  11715
# num_of_uniques :  3
# Front    12063
# NaN      11715
# 4WD       3252
# Rear      1572
# Name: drivetrain, dtype: int64

# %%
df.columns
# Out:
# Index(['make_model', 'short_description', 'make', 'model', 'location', 'price',
#        'body_type', 'type', 'doors', 'country_version', 'offer_number',
#        'warranty', 'mileage', 'first_registration', 'gearbox', 'fuel_type',
#        'colour', 'paint', 'desc', 'seller', 'seats', 'power', 'engine_size',
#        'gears', 'co_emissions', 'manufacturer_colour', 'drivetrain',
#        'cylinders', 'fuel_consumption', 'comfort_&_convenience',
#        'entertainment_&_media', 'safety_&_security', 'extras', 'empty_weight',
#        'model_code', 'general_inspection', 'full_service_history',
#        'non_smoker_vehicle', 'emission_class', 'emissions_sticker',
#        'upholstery_colour', 'upholstery', 'previous_owner',
#        'energy_efficiency_class', 'co_efficiency', 'location_country',
#        'location_city'],
#       dtype='object')

# %%
# Let's examine the short description of the seats
list(df.loc[df[df["drivetrain"].isnull()].index, "short_description"])
# Out:
# ['CDi',
#  '350+',
#  '4MATIC',
#  'A -Klasse A 180 CDI aus 2-Hand & sehr gepflegt**',
#  'e Limousine',
#  nan,
#  'd 4Matic (EURO 6d)',
#  'CDI',
#  'Avantgarde/Park Assis/Navi/Scheckheft/Bi-X',
#  'Limousine',
#  nan,
#  'CDI Elegance',
#  'd AMG Line (EURO 6d)',
#  'd (177.003)',
#  'd (177.003)',
#  nan,
#  nan,
#  'Kompaktlimousine Rückfahrk+Vorrüst AHK+WDG',
#  '/Automatik/TSC/SHZ/ISO/Scheckheft/2.Hand/',
#  'd Progressive+LED+PSD+MBUX High-End+Kamera',
#  'd AMG-Line+Navi+PSD+LED+Rückfahrkamera',
#  'A-CLASS A180 1.3 136 CV 7G-DCT 5P',
#  'S 4MATIC+',
#  'd Avantgarde Largo',
#  'BlueEfficiency*SHZ*GSD*NAVI*',
#  'CDI Ambition 4U3 Navigatie',
#  'd Lease Edition Ambition',
#  'CDI Ambition [ Xenon | Navi | Cruise ]',
#  '4MATIC [ Panorama Xenon Leder ]',
#  'AMG A 35 4MATIC',
#  'Premium Night Aut. [ Burmester Widescreen Half-Led',
#  'd (177.003)',
#  'Automaat | Leder Interieur | 1j Garantie',
#  'CDi',
#  'd (177.003)',
#  '200 CDi 1.8 CDI Boîte auto',
#  'CLASSE  d Fascination 4Matic 7G-DCT',
#  '200 d Fascination 7G-DCT',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '35 AMG 306ch 4Matic 7G-DCT Speedshift AMG',
#  'd *Tempomat *Sport-Lenkrad *Touchpad *Apple - Carp',
#  'CLASSE  CDI Inspiration',
#  'd ACC NAVIGATIE LM VELGEN SPORTSTOELEN LEDER',
#  'A160 My First Star - Navi',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  'Aut. *PDC *Pano *Tempomat *Sportsitze',
#  '200 d 150ch Progressive Line 8G-DCT 8cv',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '200 d Business 7G-DCT',
#  '200d 7G-DCT',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '220 d Fascination 7G-DCT',
#  'AMG LEDER LED NAVI LMV CRUISE',
#  'AMG Aut. [ LED Navi Camera ]',
#  '35 AMG 306ch 4Matic 7G-DCT Speedshift AMG 19cv',
#  '200 d Inspiration 7G-DCT Euro6c',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '220 190ch Progressive Line 7G-DCT Siege chauf gran',
#  'CDI Ambition [ Xenon Climate Navi Cruise LM Velgen',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  'd 4Matic AMG Line (EURO 6d)',
#  '220 d 190ch AMG Line 8G-DCT 10cv GPS Camera Radar ',
#  '180 d 116ch Business Line 7G-DCT',
#  '200 d 150ch Business Line 8G-DCT GPS Camera',
#  '180 d 116ch AMG Line 7G-DCT',
#  '200 d Inspiration 7G-DCT',
#  '200 163ch Style Line 7G-DCT',
#  '35 AMG 306ch 4Matic 7G-DCT Speedshift AMG TOuvrant',
#  '200 d 150ch AMG Line 8G-DCT 8cv',
#  '200 d Fascination Tpano GPS Camera',
#  'CDI 100kW ( 136CV ) Urban',
#  '180 d 116ch AMG Line LED GPS Camera Radar AV/AR',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '180 136ch Progressive Line 7G-DCT 7cv',
#  'd',
#  '180 d Sensation 7G-DCT',
#  'e A 250e Progressive Sfeerverlichting / NIEUW GERE',
#  '200 d 150ch AMG Line 8G-DCT',
#  '220 190ch Progressive Line 7G-DCT',
#  '180 d Sensation 7G-DCT',
#  '180 136ch Business Line 7G-DCT',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '180 AMBITION (All-in prijs)',
#  '220 190ch Progressive Line 7G-DCT Ecran 10 GPS Cam',
#  '180 d Intuition 7G-DCT',
#  '160 109ch Style Line',
#  '200 163ch AMG Line 7G-DCT',
#  '160 Inspiration 7G-DCT',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '180 d 116ch Progressive Line 7G-DCT',
#  'Coupé 3.0 CDI V6 DPF 7G-TRONIC BlueEFFICIENCY 265',
#  'd Progressive',
#  'd Premium',
#  'A35 AMG 4-Matic |306PK|FULL OPTIES|',
#  'MERCEDES-BENZ Clase GLK Pequeño  Automático de 5',
#  'Pequeño Automático de 5 Puertas',
#  '4Matic Coupe 4Matic+ (EURO 6d-TEMP)',
#  nan,
#  'S 4Matic+ 4Matic (EURO 6d)',
#  'de 4Matic AMG Line (EURO 6d)',
#  'CDI Premium',
#  'd (177.003)',
#  'BlueEFFICIENCY Urban',
#  'CDI',
#  'd (177.003)',
#  'CDI Style',
#  'Roadster',
#  'Special Edition Xenon Leder Memory Kam',
#  'Roadster~KAMERA~LEDER~\xa0GT FELGEN~XENON~',
#  'Kompressor AUT. AVANTGARDE *BI-XENON*KLI',
#  'Kompressor AUT. AVANTGARDE *BI-XENON*KLI',
#  'Cabrio~  AMG-LINE PLUS ~ Leder~Comand~LED',
#  'AMG Gepflegt MEMORY BI-XENON NAVI',
#  'Roadster COMAND/Burmester/Memory/Kamera Autom.',
#  '*wenig KM/viele Extras/Junger Stern*',
#  'C Roadster',
#  'C Roadster  | AMG Dynamic Plus Paket |',
#  'Biturbo V-Max',
#  'GT S Roadster KAMERA+BURMESTER+MEMORY+AIRSCARF',
#  'SL 43 DIGITAL LIGHT+BURMESTER+DISTRO+HUD+MEMORY',
#  'C Roadster EDITION50/KERAMIK/SITZKLIMA',
#  'C Cabrio COM+Burm+LED+Distr+PerfS+Mem+RFK',
#  'Roadster*Magno*Night*SportAga*Distr+*RFK*',
#  'SL 65 V12 612PS AMG Roadster ACC Panorama ABC',
#  'E -Klasse Cabrio E 400 AMG Styling Paket',
#  'C Roadster Edition 50 SITZKLIMA/MEMORY',
#  'Comand+Airscarf+Airma+BIXen+Memory+19"AMG',
#  'abrio Mercedes-AMG 4MATIC',
#  'MERCEDES-BENZ Clase SL Descapotable  Automático d',
#  'SL Autom, Leder, Sitzheiz.',
#  'Sport Edition Autom. COMAND AIRSCARF PDC',
#  'SL *Pagode*3.Besitz/Dt.Fahrzeug/H-Zul.',
#  "*LEDER*NAVI*KAMERA'SITZBELÜFTUNG",
#  '200 Kompressor+Leder-Nappa+Klimaautomatik+Airscarf',
#  'Roadster *DEUTSCH* (BOSE/DESIGNO/BI-XE',
#  'GT Roadster BURMESTER+SITZKLIMA+DISTRO+MEMORY',
#  'Kompressor Xenon SHZ PDC Klimaauto.Leder',
#  '367PS Cabrio Bi-Xenon Keyless-Go MOPF',
#  'ROADSTER LEDER|NAVI|DVD|AIRSCRAF|KLIMA',
#  nan,
#  'MercedesAMG',
#  'Roadster+PerfSitze braun+P-Abgas+HiFi',
#  'ANDERE 43 Premium-Navi*360°Ka.*AIRSCARF',
#  'Roadster AMG Performance Sitzklima Comand',
#  'Cabrio AMG Line Navi Leder LM PDC KAM LED',
#  'AMG-Night MBUX+360°+Distronic+DIG-LED',
#  'Roadster AMG/BIXENON/BURMESTER/KEYLESS',
#  'PERFORMANCE NIGHT SPORTABGAS BURMESTER',
#  'Cabrio 7G-Tronic+LED+Navi+Leder+H&K+Aircap',
#  'Roadster*Sport-AGA*Burm*Distr+*Night*Keyl',
#  'H&K Navi-Command Airscarf Panorama-Vario',
#  'C 63 S Cabrio DRIVERP+DISTRO+KAMERA+AIRSCARF+LED',
#  'CDI DPF Cabrio BlueEFFICIENCY 7G-TRONIC',
#  'Cabriolet AMG Line/COMAND/Distronic/360° Styling',
#  'Cabrio *Avantgarde*Night*LED*Kamera*Navi*',
#  'AMG+COM+PanoV+LED-ILS+B&O+MILLEMIGLIA417',
#  'SLK Roadster 200 Kompressor*Leder*SHZ*Klima',
#  'AMG/Navi/LED/Distr/R-Kam/Night/Burmester Autom.',
#  'Roadster Automatik Radio/CD 18" ALU',
#  '435cv AMG ***SOLO 37.000KMS *** LIBRO OFICIAL',
#  'COM+PanoVario+LED-ILS+AIRSCARF+TotwA+PTS',
#  'd Cabrio AMG-Line 9G-Tronic +LED+Leder+H&K',
#  'Cabrio Xenon Leder  SHZ AIRSCRAFT AIRCAP',
#  "Cabrio*Comand*Perf.-Abgas*Night*Driver's",
#  'K Facelift Sport-Paket Bi-Xenon,Airscarf',
#  'Roadster Comand+RüKam+LED+PerfAbgas+Distr',
#  'd Cabriolet',
#  'Cabriolet Aircap*Airscarf*LED*Business-Pa.',
#  'Cabriolet AMG Line',
#  '9G AMG+HiFi+COMAND+Distro+MemoSitze+ILS',
#  'abrio Mercedes-AMG 4MATIC',
#  'K R 170 KLIMA SITZHEIZUNG LEDER AUTOM',
#  nan,
#  'Roadster Kompressor Original Brabus Umbau',
#  'CDI BLUE EFFICIENCY AIRSCARF|NAVI|LEDER',
#  'Cabrio*Avantgarde*Automatik*Leder*SHZ',
#  'AMG C 63 S Cabrio Night-P/Drivers P/360°/Comand',
#  'CABRIO NAVI KAMERA MULTIBEAM AHK SITZKLIMA',
#  'E -Klasse Cabrio E 200 +AMG LINE+NAVI+CAM+',
#  'CGI Cabrio 7G AT Avantgarde',
#  'Roadster Kompressor/Xenon/Navi/Leder',
#  "Cabrio*'Perf.-Abgas*NightP*Driver's Pack*",
#  'Cabrio Navigation+LED-HP+CabKomfort+Kamera',
#  'C 63 S AMG Cabrio Performance Sitze/Lenkrad/AGA',
#  '200K',
#  'Kompressor Aut. Cabrio Final Edition',
#  'Kompressor Aut. Cabrio Final Edition',
#  'Cabrio CGI BE Avantgarde',
#  'C63 AMG Burmester|HeadUp|ACC|Perf.-Abgasanlage',
#  'CGI BlueEfficiency AMG Line *2J. Garantie*',
#  'Cabrio AMG Line Navi/Alcantara/Temp/Kamera',
#  'C 63 Cabrio BURMESTER+MULTIB+360°+AIRSCARF+DISTR',
#  '* Klima* Sitzheizung* Alu*',
#  'Kompressor+metallic Lackierung',
#  'Cabrio d',
#  'SL Roadster',
#  'Cabrio AMG Line2x+Spur+LED+Kam+Nav+DAB+18"',
#  'Cabrio Night+Drivers+Sp.Abgas+360°+Coma',
#  'Navi PDC SHZ',
#  'Kompressor Aut. Cabrio Final Edition',
#  'Panorama+AIRSCARF+ILS-LED+Parktronic+SHZ',
#  'Cabrio 9G-TRONIC AMG Line Multibeam',
#  'd Cabrio AMG Line 2x+Burme+Comand+Sistzkli',
#  'AMG COMAND+ILS+SITZKLIMA+VARIO+BURMESTER',
#  'd Cabrio AMG mit Akustikverdeck',
#  'Cabrio Navi/7G-Tronic/Aircap/Airscarf/SHZ Autom.',
#  'ANDERE AMG Night+AIRSCARF+DISTRONIC+DIGITAL-LIGHT',
#  'd Cabrio AMG Line2x+Night+Kam+LED+DAB+Wide',
#  '163 PS Kompressor Cabrio  Final Edition',
#  'd Cabrio 9G-Tronic AMG Line+LED+Navi+Leder+',
#  'Deutsches Fahrzeug  Sammlerzustand',
#  'Cabrio d',
#  'Cabrio AMG Line 9G-Tronic+Nav+LED+Airscarf',
#  'Originale 52.000KM Roadster SHZ TEMPO',
#  'E -Klasse Cabrio E 200 AMG Line+Burmester+CAM',
#  'Cabrio AMG-Line*AUTOMATIK*KAMERA*KLIMAAUTOMATIK*',
#  'Cabrio AMG AHK+MULTIBEAM+360°+AIRSCARF+SHZ',
#  'Cabrio AMG/LED/TOTWINKEL/PTS/RFK/AIRSCARF',
#  'd Cabrio AMG+MBUXHighEd+LED-HP+20"+Mem+RFK',
#  'AMG*Kamera*Burmester*Aircap*Airscarf*Navi*',
#  'Navi+LED+Air+Panorma+Leder+PDC+9GTronic',
#  'AMG 9G+NAVI+LED+RFK+VARIO+AMBIENTE',
#  'Cabrio Avantgarde+MBUXHigh+LED-HP+Distr+RK',
#  'Cabriolet AMG Line 360°/Totw./Comand/LED Styling',
#  'C 180 Cabrio 9G-TRONIC AMG Line',
#  'C 200 Cabrio 9G-TRONIC AMG Line',
#  'Cabriolet AMG-Line/Navi/LED/Kamera/PDC uvm Autom.',
#  'Cabrio d',
#  'Cabrio AMG Line 9G/Kamera/Navi/LED/Ambient Autom.',
#  'Cabriolet AMGLine/LED/Airscarf/Navi/Kamera Autom.',
#  'Roadster/TEMPO/SHZ/BOSE Sound/',
#  'Roadster Kompressor Cabrio Leder Klimaaut.',
#  'Cabriolet AMG Line/9G/LED/KAMERA/Navi/SHZ Styling',
#  'Cabrio AMG Line Leder + Verdeck Rot/360°/ Autom.',
#  'Avantgarde Cabrio AHK+AIRSCARF+KAMERA+DAB',
#  'd AMG-Line+AIRSCARF+AIRCAP+Standhzg+Comand',
#  'Kompressor+KLIMA+16-ZOLL+SPORTSITZE+LEDE',
#  'C220d Cabrio AMG Line Navigation Sitzheizung Kamer',
#  'Cabriolet AMG Line/Kamera/LED/9G/Navi/SHZ Styling',
#  'Cabriolet AMG LED 19" Navi Kamera AMG Line',
#  'Cabrio AMG Line 2x+Coma+Multib+DAB+Kam+18"',
#  'Cabrio AMG Line 2x+Comand+Kam+18"+Multibea',
#  'd Cabrio AMG Line 2x+Kam+LED+DAB+Wide+19"',
#  'Cabrio AMG Line 2x+Comand+LED+Kam+PDC+DAB',
#  'Cabrio AMG Line 2x+Night+Distr+LED+DAB+18"',
#  'E E  Cabrio E DSG *LED*Navi*Harman*AHK*Leder*Park',
#  'AMG Paket H/K Belüftung Panorama Comand',
#  'BE*AMG-Line*Aut*ILS*Pano*Leder*Shzg*',
#  'CDI Roadster COMAND LEDER',
#  'MOPF II komplett Umrüstung D incl. Tacho',
#  'Navi*Alu19*Leder*',
#  '-CLASS 6.2 COUPE SPORT AUTO 457 2P',
#  'V12 - Origineel Nederlands -',
#  '7G-TRONIC-Facelift-Sportpaket-1.Hd!!!',
#  'Cabrio Avantgarde Xenon Memory Leder',
#  'Kompressor Cabrio, Leder, 120 KW',
#  'Roadster AMG Magic Sky H&K Distronic',
#  'Cabriolet 4MATIC',
#  'LED  AMG-Night-Paket COMAND  Airscarf',
#  '43 AMG / Air Scarf / Harman Kardon / Comand',
#  'Carbon Editie - 1e eigenaar - Keuring + Garantie',
#  '200 K.',
#  'C43 AMG Cabrio Schalensitze Burmester Head UP 360',
#  'C SW 200 d  auto',
#  'GE',
#  '(R129)',
#  nan,
#  '(R129) 2nd Owner/Collectable',
#  '/ incl. Garantie / 2 Jahre HU & AU frei',
#  'SL 600 V12 AUT. ORG. NL.',
#  'SL Roadster SL 63 AMG Keramik Top-Zustand',
#  'Kompressor  1PROPRIETARIO ! TAGLIANDI MERCEDESBENZ',
#  'Sport*MAE Original*Bose*Memory*Xenon*',
#  '(R171) 350 7GTRO',
#  'Cabriolet S 4MATIC',
#  'SL',
#  'cabrio d  Premium Plus 4matic auto',
#  'CABRIOLET 2.1 CDI 204CV AUTO GARANTIE 6 MOIS',
#  '220 d executive a',
#  '200 AMG Sport 7G-Tronic BVA',
#  'SLK  200 Kompr. | 1.HAND (seit 05) | AIRSCARF',
#  'Roadster Comand/Memory/19"/TOP',
#  'C 63 S AMG Cabrio *AMG-DRIVERS*PERF-ABGAS*VOLL*',
#  'ROADSTER',
#  'V6 231pk Automaat Prest. Plus NL-auto',
#  'SL 500 V8',
#  'AMG Line',
#  '190SL',
#  'AMG 7ATG/SHZ/PTS/Pano/AIRSCARF/Comand',
#  'AMG | Airco | Cruise | Stoelverwarming',
#  'CDI BlueEfficiency E -Klasse Cabrio (BM 207)',
#  'd Cabriolet',
#  'Leder AD Dyn. Kurvenlicht Klimasitze e-Sitze Nacht',
#  'Coupe Speedshift 7G-DCT Perf-Sitze/Carb',
#  'D',
#  'Coupe AMG Speedshift 7G-DCT',
#  'S Coupe EDITION1 PERF. AGA DIST. 19°',
#  '7G-TRONIC 8-fach Navi PDC Klimaaut.',
#  'Coupe AMG Speedshift 7G-DCT',
#  'AMG GTC Edition 50*Designo*Magno*Pano*SitzKlima*',
#  'CDI COUPE AMG SPORT *LEDER*NAVI*LED*AHK*',
#  'AMG GLC 43 4MATIC Coupé',
#  'COUPE CARBONPAK 1+2 KERAMIK BURMESTER',
#  nan,
#  'PERFORMANCE SITZE PANORAMA BURMESTER',
#  'd Coupe AMG 9G-Tronic Navi/Leder/Temp/360/',
#  'R COUPE CARBONPAK 1+2 KERAMIK BURMESTER',
#  '-CLASS 4MATIC',
#  '4MATIC+ Coupé',
#  'COUPE NIGHT PAKET BURMESTER HA-LENKUNG',
#  'oupé Mercedes-AMG 4MATIC',
#  'CE Liebhaberstück',
#  'C oupe AMG Speedshift 7G-DCT LED RFK PDC',
#  'd 4MATIC Coupé AMG Line',
#  'Urban+Navi+Leder',
#  '/Sammlerzustand/PDC/ Bose Sound/SH/',
#  'C 63 S AMG/Com/Multibeam/Perf.Sitze/Klappe/PanoD',
#  'S 4.0 V8 DCT MATT CARBON KERAMIK V-MAX310',
#  'E300 COUPE AMG-LINE COMAND DISTRO HEAD-UP KEYLES',
#  'CLK Coupe 320/Automatik/Leder/Navi/Alus',
#  'Coupe *Nachtsicht-Assistent*BI-XENON TV',
#  'S Coupe',
#  'Mercedes-AMG S 4MATIC+',
#  'C 63 S COUPE AMG KEYLESS 360°KAMERA PANO HEAD-UP',
#  '4Matic (EURO 6d-TEMP)',
#  '-CLASS 3.0 4MATIC AUTO 333 2P',
#  'CGI BlueE. Aut. Elegance LEDER NAVI XENON',
#  'Coupe PerfSitze+Magno+Night',
#  'CGI COUPE AVANTGARDE LEDER|KLIMA|SHZG|PDC',
#  'e AMG Line+Pano+',
#  'Coupe Aerodynamik-P. Performance Sitze Pano Faceli',
#  'C 63 S AMG COM/Pano/Night/Perf. Sitze/Burmester',
#  'C Coupe*DEUTSCHES-FAHRZEUG*AUTOMATIK*H-KENNZEICHEN',
#  'Coupé Burmest+Comand+Pano+DAB+Kam+Distr',
#  'C -Klasse Coupe C 200 AMG Line+Pano+Cam+',
#  'd Coupe AMG 19"Zoll Night Paket Comand Distronic',
#  'C 63 S AMG Coupé MEMORY/DISTRO/COMAND/MULTIBEAM',
#  'd Cp AMG+Beam+COM+HiFi+PANO+Distr+Wide',
#  'Kompressor Sportcoupe KLIMAAUTOMATIK',
#  'C 63 S AMG COM/Pano/Distr/KeyGO/Memory/Klappe LED',
#  'Coupé',
#  'Coupe AMG + NIGHTPACK - LEDER - PANO DAK - 360° -',
#  'Coupe  AMG Multibeam Navi 360° Tieferlegung',
#  'Coupe*AMG-Line*MEMORY*SPURHALTEAS*360°CAM',
#  'Elegance Aut. Xenon Leder GSD ACC SHZ',
#  'AMG+MBUXHighE+LED-HP+19"+Night+ParkAss',
#  'CDI Coupé',
#  'Coupé CDI',
#  'Compressor',
#  'E-Klasse Coupe 250',
#  'CLK Coupe 320 Elegance Xenon/ PDC /Schiebedach',
#  'd Coupe AMG+Pano+Standhzg+LED+HiFi',
#  'Coupé',
#  'Coupe AMG Panoramadach Navi LED HuD',
#  'Coupé',
#  'd 4MATIC',
#  'Matte wrapping',
#  'd 4MATIC -',
#  'S Coupé Perf.Abgas. Pano Night Driver`s',
#  'E200 Coupe AMG-Line Burmester+Memory+20erLM',
#  'coupé 4.0 4MATIC 469 2P',
#  'SLC, 1 Hand, Scheunenfund, Oldtimer, Bastler',
#  'd AMG/Navi/PanoD/R-Kam/Multibeam/Totwinkel Autom.',
#  'AMG/Navi/Pano/Night/R-Kam/Totwinkel/LEDILS Autom.',
#  'Coupé AMG Line 2x+Comand+360°+Multib+Distr',
#  'Coupé 7G-DCT AMG LINE - BURMESTER - SFEERVERLICHTI',
#  'd Coupé AMG Line 2x+LED+Stahzg+Kam+Nav+18"',
#  'AMG Line 4Matic LED Panorama Head Up 360°',
#  'AMG Plus/Comand/Night/Multibeam/R-Kamera Autom.',
#  'A 180 d Lim. Tleder Nav Tmat Bt Alu16 EURO6',
#  'd 4MATIC Coupé',
#  'AMG C 63 Coupé Burmes./360°/Pano/Abgasanl/Memory',
#  'Coupé d',
#  'C 63 Coupé Night-P/Panorama/Totw./360°/Multibeam',
#  'C200 COUPE M-HYBRID AMG LINE LEDER NAVI LED PANO',
#  'd Coupe AMG Night Multibeam Comand',
#  'AMG Line Panorama*AHK*Night*Ambiente*LED',
#  'AMG C 63 S Coupé Night/Aero-Paket/360°/Drivers P',
#  'd 4MATIC',
#  'Coupe*1.Hand*Deutsches Fahrzeug*Insp.NEU',
#  'CDI Chrome',
#  'e Coupé',
#  'Coupé d AMG LINE',
#  'd (205.314)',
#  'Coupé d',
#  'Coupé AMG Line 2x+Kam+LED+Navi+DAB+SHZ+18"',
#  'A 180 Edition BlueEff. Tleder Tmat EU6d-T',
#  'Mercedes-AMG C 63 Coupé COMAND/MultibeamLED/360°',
#  'AMG C 63 S Coupé Night-P/Drivers P/360°/Panorama',
#  'Coupé AMG PLUS/TOTWINKEL/PTS/RFK/MULTIBEAM',
#  'Coupe AMG 9G-Tronic+LED+Navi+Kamera+Leder+',
#  'Coupé',
#  'Coupé AMG Line+Burmest+LED+KAM+Advance+19"',
#  'AMG/MBUXHE/LED/Night/KeyGo/Burmester/PTS AMG Line',
#  'CDI (LA) Sport Edition (203.708)',
#  'e AMG+MBUXHighEnd+LED-HP+AParkAssist+RFK',
#  'Coupé 220d',
#  'Coupé AMG Line+Night+Wide+LED+Navi+Kam+19"',
#  'AMG-Line*Panorama*LED*19"*Ambiente*kamer',
#  'AMG*AHK*Panorama*Night*Ambiente*LED*MBUX',
#  'COUPE AMG -Line',
#  'd Coupe 9G AMG*NightP*Memory*AssistenzP*',
#  'd AMG Plus/Comand/Multibeam/PanoD/Night Autom.',
#  'Coupé',
#  'Coupé d AMG LINE',
#  'Coupé d 4MATIC',
#  'CDI Inspiration 7G-DCT',
#  'e 4Matic 7G-Tronic+Navi+Tempomat+',
#  'd 4-Matic 9G-TRONIC PACK AMG TOE CUIR LED CAME 360',
#  'CDI BT 4M S-DACH SPUR TOTW PARK AHK ILS',
#  'GLA250 7G-DCT AMG Line+Bi-Xenon+inkl 2J Garantie',
#  'CDI BE /BI-XENON / NAVI / AHK / SHZ',
#  'd 4MATIC',
#  'b*SPORT*NAVI*PDC*AUT AC*LIKE NEW*',
#  '4MATIC',
#  '1.6 STYLE Leder|Xenon|Navi|Alu|Sitzheiz.',
#  'EQ HEV HYBRID *4 MATIC*GPS*CAMERA*LED*ALU BI COLOR',
#  '4MATIC',
#  'd 4Matic All-Terrain Estate Avantdarde',
#  'CDI*Navi*Keyless*Kamera*MFL*ZVF*SHZ*Tempo*Isofix*',
#  '4M AMG Line',
#  'd 4MATIC',
#  '250 Progressive/LED/Memory-P./Kamera/Navi/',
#  'CDI Style Aut. +Navi+Bi-Xenon+Tempomat+',
#  "7G-DCT AMG + NIGHTPACK - ALU 19' - SFEERVERLICHTIN",
#  'd 4 MATIC 245cv 9 vel. *IVA deducible* *2020* *Nac',
#  'd 4MATIC AMG Line',
#  'CDI',
#  'd 4MATIC',
#  nan,
#  'd 4Matic (253.915)',
#  'd Urban Aut. AAC XENON NAVI AHK KAMERA',
#  'BlueTEC 4MATIC',
#  'AMG GLC 43 4MATIC',
#  'e 4Matic',
#  '300 4MATIC',
#  'CDI BE *ANHÄNGERKUPPLUNG*NAVI*PTS',
#  'D ADVANTAGE + PAQ NIGHT',
#  'AMG NIGHT AHK MBEAM SOUND DIGDISP DIST',
#  nan,
#  'Coupé 350D 258 CV',
#  '+ Electric Art MBUX+LED+RüKam+El.Heck+18',
#  'Mercedes-AMG 4MATIC',
#  '*AMG*Comand*Kamera*LED*Sitzhzg*7G-DCT*',
#  'D',
#  'Mercedes-AMG 4MATIC',
#  'd 4M AMG PANORAMA HUD ABC DIST MBEAM 20"',
#  'Urban AHK | Bi-Xenon | NAVI',
#  'Mercedes-AMG 4MATIC+',
#  'd 4MATIC',
#  '+Allwetter+R.Kamera+Xenon+Leder+Parktronic+CarGara',
#  'd 4Matic (253.915)',
#  'AMG Pano LED B&O 360Kam Massage AHK TV',
#  'Style',
#  'd Style 7G-DCT BI-XENON NAVI RFK SHZ TEMPO',
#  'D 2.2 170CV AUT 5P',
#  'AMG MBUX-High LED Easy-Pack AHK',
#  'd 4MATIC',
#  'e 4MATIC',
#  '316 DOKA+PRITSCHE+KLIMA 7 SITZER 316 CDI',
#  'Urban Business Paket *2 JAHRE GARANTIE*',
#  'Urban',
#  'd',
#  'E350T CDI BlueEff. COMAND SITZKLIMA DISTRONIC',
#  'T CDI*Bi-Xenon*Avantgarde*Standheizung*',
#  'T-Modell/AMG-Line/SHZ/NAVI/PANO/St.HZ/Full',
#  'd T Business 9G Aut +LED+AHK+Kamera+Navi',
#  'd !!!VERKAUF NUR AN GEWERBE!!! +AVANTGARDE',
#  'T CDI Avantgarde Export',
#  'CLS 250 Shooting Brake Sport-Paket',
#  'd T *Navi*LED*Sitzhzg*Park-Paket*9G-TRONIC',
#  'd T *Avantgarde*Night*LED*Kamera*MBUX*Navi',
#  '350 Fahrassist.*Pano.-Dach*360°*Night*Memory',
#  'E280 T Kombi Automatik Radio 7-Sitzer Alufelgen',
#  'E -Klasse T-Modell E 250 CDI BlueEfficiency',
#  'b*NAVI*LED*LEDER*PDC*AUTOMAAT*',
#  'd break 7G-TRONIC AMG Line! Leder, Led, Navi, Top!',
#  'd T+Navi+Kamera+Pano+Tempomat',
#  'd T *Navi*Sitzhzg*9G-TRONIC*LED*Park-Paket',
#  'CGI Avantgarde Aut. +COMAND+Bi-Xenon+GSHD',
#  'SB URBAN NAVI/TEMP./AHK/SHZ/DAB+/PDC/USB',
#  'Sport-Paket',
#  'd T 210KW*ACC*MULTIBEAM*KAM*COMAND*DAB*',
#  'CDI BlueEfficiency Avantgarde 2J. Garantie',
#  'T Leder / Navi / Xenon / Klima',
#  'AMG CLA 35 4MATIC Shooting Brake',
#  'd Edition Marco Polo Airmatic AHK MBUX',
#  'T 9G AMG LINE*LED*COMAND*KAMERA*BURMESTER*',
#  'd T *Navi*AHK*Sitzhzg*LED*Park-Paket*9G-TR',
#  'd T *LED*AHK*Navi*Sitzheizung*Park-Paket*',
#  'SB Urban Night Paket 7G Aut+Xenon+Memory',
#  'C 63s AMG T 7G-Tronic+LED+Kamera+Burmester+Pano+',
#  'E250 T-Modell CGI/TSGS/NAVI/ASSIS+/TEMPO/SchaltW',
#  'd T AMG Line 4Matic Aut. +COMAND+LED+LEDER+',
#  'BlueTEC AMG-Line',
#  'T d AVANTGARDE COMAND KAMERA MULTIBEAM',
#  'd T Leder 194PS Navi Leder Kamera LED BT',
#  'd T *LED*Navi*Sitzhzg*Park-Paket*9G-TRONIC',
#  'T Avantgarde Automatik *Navi Leder Kamera',
#  'd T BlueTEC EURO6 Leder Nav Shz Temp',
#  'd T  Avantgarde / DISTRONIC / LED / SHZ',
#  'C63 S AMG DESIGNO HUD BURMESTER PANO DRIVERSPACK',
#  'E300d T AVANTGARDE AMG-LINE KAMERA WEBASTO PANO',
#  'CLASSE B B 180 d BE Edition',
#  'CDI T-Modell Elegance  Navi/Pano.-Dach/SHD/Autom.',
#  'BI TURBO 4MATIC - LEDER/ALCANTARA - LED - NAVI - 1',
#  'T 7G-TRONIC Avantgarde',
#  'C 63 S T COMAND/HUD/Distr/PanoDach/360/BBS/KW LED',
#  'T Avantgarde Automatik Navi Kamera Keyless',
#  '(+)2.0 AVANTGARDE AUTO 211 5P STATE',
#  'C200 T Exclusive ILS Leder Kamera Navi Tempomat',
#  'C250 CGI T AMG Line 9G Aut+LED+Navi+Kamera+Leder',
#  'C180 T Exclusive LED Navi Sitzheizung Tempomat',
#  'd Marco Polo Edition Navi MBUX Markise',
#  'd T AMG AHK+STANDHZG+MULTIBEAM+DISTRO+360°',
#  'd AMG-Line WideS Multib Airm. HUD Sthz DTR+',
#  '7G-DCT KLIMA+EPH+TEMPOMAT+BI-XENON+SITZHEIZUNG',
#  'C220 d T Avantgarde T Avantgarde d',
#  'd T Exclusive Leder Navi',
#  'd T Exclusive +LED+Navi+Tempomat+EUR6+',
#  'd Urban*LED*Park-Pilot*7G-DCT*Night*Sitzhz',
#  nan,
#  '+ AMG*Sitzklima*Burmester*Distronic*Night',
#  'Estate',
#  'E300d T 2x AMG-LINE COMAND DISTRONIC AHK 360°KAM',
#  '4MATIC',
#  'Automatik T AMG-LINE/LED/LEDER/MFL/',
#  'd Shooting Brake',
#  'd Estate Avantgarde',
#  'd Estate',
#  'de Estate AMG LINE',
#  'T 4M 9G-TR. AVANTGARDE NAVI 360°KAMERA LED',
#  'T AMG Line',
#  '450+ 360°Kam*Pano.-D.*20"LMR*AIRMATIC*Memory',
#  'T AMG Line',
#  'CDI Blue Efficiency Estate',
#  'C220d AMG 194pk/ch',
#  'VITO 116 CDI B.TEC TOURER PRO 8-S |NP50€|57tK|1H',
#  'AMG E 53 4MATIC+ Estate',
#  'd Marco Polo Navi MBUX 360° 2xStandh. AHK',
#  'b*AMG*NAVI*PDC*LIKE NEW*',
#  'C200d T Avantgarde *Kamera*Park*LED*Navi*LM*',
#  'T d Automatik*Leder*Navi*Panorama*',
#  'd +LED+ T-Mod. +AHK+Amg Line+Pano+DIST+',
#  'e T AMG/PTS/RFK/NAVI PREMIUM/MBUX/DISTRO',
#  'd T AMG Line PDach Standhzg Navi Nightpaket',
#  'SB e AMG+NIght+LED+Pano+SoundSyst+',
#  'T BT Avantgarde Comand Air Distro ILS Pano',
#  'd T 9G Avantgarde ~LED~Comand~Leder~AHK',
#  'Mercedes-AMG 4MATIC Estate',
#  'CGI T 7-G Exclusive Navi,LED,2.Hand*56tkm*',
#  'C 63 S AMG T +AHK+Pano+PerfAbgas+Distro',
#  'd T LED+AHK+DISTRO+COMAND+KAMERA+PTS+SHZ',
#  'd T LED+AHK+DISTRO+COMAND+KAMERA+PTS+SHZ',
#  'T COMAND PANO DISTRONIC KAMERA MEMORY',
#  'T AMG/Navi/DigitalLight/Night/R-Kamera/19" Autom.',
#  'd T SPORTST PAN-DACH DISTRONIC STHZG HAF',
#  'CGI Avantgarde LED Distronic + GSD AHK R.Cam',
#  'CGI Classic elSitz AHK KlimaA PDC',
#  'T d AVANTGARDE/NIGHT/SHD/AHK/LED/NAVI/RFK',
#  'de Navi|Kamera|LED|Sitzhz',
#  'd Estate Business Line',
#  'd T AVANTGARDE LEDER|NAVI|KAMERA',
#  'Estate Business Line',
#  'Td 9G-Tronic*Avantgarde*Teilleder*Navi*LED Avantga',
#  'Kompressor*Tempomat*Klimaaut.*RCD*SHZ*MFL*ZV*Airba',
#  'T d AVANTGARDE/LED/NIGHT/DISTRONIC/AHK/SHZ',
#  'd AMG/rijassist',
#  'Estate Estate',
#  'd Estate',
#  'd T 9G AMG*NightP*Stdhzg*Digital-Light*AHK*',
#  'Shooting Brake',
#  'd T AMG line Night Edition Navi/Temp/Kamer',
#  'K BlueEff.*SHZ*Isofix*Klimaautomatik*ZVFB*Verglasu',
#  'CLA Shooting Brake 200 7G-DCT Urban',
#  'Shooting Brake AMG Line PDC Navi',
#  'T AMG LED+360°+STANDHZG+AIRMATIC+AMBIENTE',
#  'T BT STANDHEIZUNG LED ILS PARKASS NAVI SHZ',
#  'PACK AMG PACK SPORT 1ER PROPRIETAIRE',
#  'E200 T CGI 7G-TRONIC LED Navi Sitzheizung Tempomat',
#  '(BlueTEC) d kompakt 7G-TRONIC Edition',
#  'CDI Urban Style Edition',
#  'd T 9G Avantgarde*Pano*Distronic*AHK*360°',
#  'd T 9G-TRONIC+LED+Navi+AHK+HuD+SHZ+',
#  'T d AVANTGARDE/PTS/RFK/NAVI/DISTRO/AHK/LED',
#  'T AMG LINE MULTIBEAM WIDESCREEN AHK CAMERA',
#  'd T COMAND RFK TOTWINKEL MULTIBEAM STANDHZ',
#  'd Estate',
#  'de Estate',
#  'd 4M All-Terrain',
#  'd Infotainment-Paket Advanced|LED|Navi',
#  'd Estate',
#  'd AMG-Line COMAND Pano Carbon Airm Sbel DTR',
#  'd AVANTGARDE Ext.+Night+Pano+AHK+MULTIBEAM',
#  '(+)2.1 D AMG LINE 5P',
#  'd Estate',
#  'CLA 200 SB AMG Line Navi/Panorama/AHK/Kamera/LED',
#  'T d 9G Avantgarde*High-End Infotainment*',
#  'CLA-CLASS 2.1 D DCT SHOOTING BRAKE 136 5P',
#  'd T-Modell 9G AMG MULTIBEAM 360-K BURMES.',
#  'de AMG Line ACC|Pano|Leder|COMAND|LED',
#  'T LED-Scheinwerfer|Navi|Kamera|PDC|SHZ',
#  'T CGI Avantgarde*PDC*SHZ*Navi*',
#  'd T AVANTGARDE LED HP KAMERA NAVI SHZ AMB',
#  'E 63T AMG 514 PS Avantgarde Airmatic Memory',
#  'T AMG/NAVIGTION/LED/AHK/TOTWINKEL/KAMERA',
#  'TCGI Xenon/AHK/Standheizung/Navi/Distron. Autom.',
#  'C220d T Avantgarde LED Navi Leder Sitzheizung',
#  'T e Avantgarde+Spur+Multibea+AHK+Navi+18"',
#  'd Estate Business Line',
#  'de T AMG AHK+PANO+BURMESTER+DITSR+AMBIENTE',
#  'T LEDER NAVI MBEAM PANO CAM DISTRONIC',
#  'T AMG Line 2x+LED+Nav+HUD+PSD+Distro+Stahz',
#  'B200 CDI AMG AUT 136CV',
#  '9G Tronic - AMG LINE - NAVI - CAMERA - 12M GARANTI',
#  'C 300 e T 9G AMG*Pano*Distronic*Digital-Light*AHK*',
#  '!!FULL!! /AMG-PACK/OPEN DAK/KEYLESS/LED/MEMORY/',
#  'CDI BlueEFFICIENCY Edition',
#  'd T Avantgarde *Glasdach*Burmester*',
#  'T 9G AMG*SpiegelP*Pano*Kamera*AHK*',
#  'd T Aut LED Nav Shz Business Plus EURO6d',
#  'e T AMG-LINE/PANO/D-LIGHT/PTS/360/AHK/SHZ',
#  'd 4MATIC Estate',
#  'T Autom. 1.6 +AVANTGARDE+PANORAMA+NAVI+',
#  'E200d Avantgarde T-Modell Navi+Kamera+LED+DAB',
#  'd Estate',
#  'd LED|Navi|Infotainment-Paket High-End',
#  'd T AMG/PTS/RFK/DIGITAL LIGHT/DISTRO/AHK',
#  'Mercedes-AMG 4M Shooting Brake',
#  'AMG CGI T (205.240) 1,6 Ltr. - 115 kW KAT Klima...',
#  'CLA Shooting Brake 180 Urban',
#  'e T 9G AMG*Pano-SD*NightP*SpiegelP*AHK*360°',
#  'Limousine *VOLLAUSSTATTUNG*',
#  'S 310kW(422ch) DCT * CAM RECUL * GPS * SG CHAUFF *',
#  '*SHZ*Alpine*Schiebedach*Tempomat*',
#  'BE CGI  AMG-Optic-/Styling-Paket 1',
#  'CDI*Lordosenstütze*Bluetooth*Sitzheizung*',
#  "e long HYBRID AMG/360°/PANORAMA/3D/20''",
#  'CDI BlueEfficiency (204.001)',
#  '1.6',
#  'CLS CLS 500 BE 4-Matic',
#  'L Hybrid *Nachtsicht-Assist*TV*Keyless*',
#  'e Edition 2020 AMG',
#  '450+ NIGHT+20"+PANO+FAHRASS+DIG.LIGHT+360°',
#  'CDI  EURO 6',
#  'Lim. Aut. Navi Sitzhz. Temp. PDC Klimaaut.',
#  'e AMG+MBUXAdvanced+LED-HP+NightP+SpurA+PTS',
#  'CGI BlueEfficiency Avantgarde',
#  'd',
#  'Mercedes-AM53 4MATIC+',
#  '7G-TRONIC Navi Leder',
#  '525PS Memory Navi Leder Bi-Xenon BT',
#  '-CLASS 4.7 455 4P',
#  '-CLASS 4.7 455 4P',
#  'Electric/Distr/KeyG/360/Memory/Burmeste Navi/LED',
#  'e Lim Progressive+MBUXAdvanced+SpurAss+PTS',
#  'Mercedes-AMG S 4MATIC+',
#  'Mercedes-AMG S 4MATIC+',
#  '450+ Electric Art DIGITAL LIGHT+DISTRO+Pano',
#  '-CLASS 2.1 D 4MATIC AUTO 170CV 4P',
#  'AMG Line Aut+Navi+Shz+Kam+LED+EU6+Night+',
#  'E280 Aut. Lim. Elegance Navi Xenon Temp. Sitzhz.',
#  '5.5 557PS BiTurbo Limo Pano ACC Keyless',
#  'i 7G-TRONIC LED PERFOR. MBUX CARPLAY CAM. CUIR GAR',
#  'AMG Autom. Leder ACC Xenon VOLL',
#  '1.6 115kW(156ch) * GPS * CAM RECUL * TOIT PANO *',
#  '4Matic 7G-DCT+LED+Navi+Designo+SHZ+',
#  '450+ ELECTRIC ART/DISTRO/MBUX/PANO/360/PTS',
#  'AMG PACK*EU6d*19.000 Kilométres!!!CARPASS*',
#  'CDI/AMG/SH/SW/NAVI/8XR/TEM/SHZ/PDC',
#  nan,
#  'CDI Business',
#  '450+ PANO+DIG.LIGHT+KEYLESS+FAHRASS+360°',
#  'D*NAVI*LED*URBAN-Line*',
#  'd',
#  'Mercedes-AMG S 4MATIC+',
#  '*LEDER*MEMORY*GLASDACH*TOP ZUSTAND*',
#  '-CLASS D G TRONIC PLUS AVANTGARDE',
#  'CDI Elegance KLIMAAUTO TEMPO NAVI SHZ',
#  'e Lim Progressive+MBUX+LED-HP+Mem+KeyG+RFK',
#  'e lang *AMG*ChauffeurP*ParkP*MemoryP*Pano*',
#  'CLA 180 AMG coupe',
#  'AMG/Pano/Distr/KeyG/360/AHK/Mem/Burmest Navi/LED',
#  'de AMG/MULTIBEAM/MBUX/DISTRONIC/PANO/SHZ',
#  'AMG Kompressor 500 PS 5G Key Distronic DEU',
#  'd',
#  'de / EQ POWER-PLUG IN HYBRID / SCHIEBDACH',
#  'd',
#  'd',
#  '450  AMG+NIGHT+21"+FONDSITZ-PAKET+PANO+HUD',
#  'CGI BE Limousine Elegance Automatik LM',
#  'AMG C 63 S AMG Speedshift 7G-MCT',
#  '350 Electric Art+Pano+AIRMATIC+DISTRON+OLED',
#  'Kompr.*2xSHZ*2xPDC*SCHECKHEFT*TÜV NEU',
#  'Mercedes-AMG 4MATIC',
#  'EXCLUSIVE/Navi/SHD/Multibeam/R-Kamera/Totw Autom.',
#  'd',
#  'CDI 4M Aut. AMG Line',
#  'e Lim Progressive+MBUX+NavPr+LED+Sound+RFK',
#  'C 63 MULTIBEAM+PANO+BURMESTER+MEMORY+AMBIENTE',
#  'de / EQ POWER-PLUG IN HYBRID / SCHIEBDACH',
#  'AVANTGARDE/NAVI/LED/MBUX/MEMORY/HIGH END',
#  '9G-TRONIC Avantgarde, TOTW, Kamera',
#  '*Navi*Bluetooth*Tempomat*Klima*',
#  'AVANTGARDE/NAVI/LED/MBUX/MEMORY/HIGH END',
#  '*Navi*Bluetooth*Tempomat*Klima*',
#  'de AMG Line HuD|Pano|LED|Park-Assistent',
#  'AMG*AmbientLight*StHz*Totwinkel*MBUX*',
#  'de',
#  '350 NIGHT+PREMIUM+21"+PANO+AHK+SITZKLIMA',
#  '1.6i 122cv automatique - Pack AMG - GPS - Caméra d',
#  'e Lim Progressive+MBUXHigh+LED+18+Sound+RK',
#  'e Limousine AMG/NAVI/LED/MBUX/PTS/SHZ',
#  'd lang BlueTEC*AMG*Distronic*Burmester*',
#  'd 9G-TRONIC Avantgarde MULTIBEAM LED',
#  'CDI BlueTEC  in nieuwstaat',
#  '350+',
#  'd 4MATIC',
#  'CLA-CLASS 2.1 CDI DCT 170CV 4P',
#  'CLA-CLASS 2.1 CDI DCT 170CV 4P',
#  'd Lim. Avantgarde COMAND ILS Leder ParkA.',
#  'e Lim Progressive+MBUX+NavP+LED+ASound+RFK',
#  'd AMG',
#  '3.0 258 PS BlueTEC / d Pano Distronic Keyl',
#  'Avantgarde BlueTec Hybrid BT',
#  '+ AMG MBUX+Dig-LED+HUD+Pano+Distronic+21',
#  'Sedan 9G-Tronic AMG LINE - FULL LED - ALU - BLIS -',
#  '+ AMG MBUX+360°+Pano+DIG-LED+HUD+Distro',
#  'e Limousine AMG LINE/KAMERA/NAVI/PTS/LED',
#  '+ AMG/AIRMATIC/NAVI/DISTRO/PANO/360/SOUND',
#  'E -Klasse Lim. E 320',
#  'BlueTEC Sport',
#  'B -Klasse B 200 Turbo Special Edition/ PDC/Tempo',
#  'e Lim AMG+MBUXAdvanced+LED-HP+Spur+ParkAss',
#  'Aut. Navi Harman-Kardon Bi-Xenon Temp.',
#  'd',
#  'e AMG Line+Exclusive+Night+LED+Kam+Nav+18"',
#  '4MATIC',
#  'Lim. Aut. Navi Klimaaut. Schiebedach Shzng',
#  'd L ILS+PANO+DISTRO+360°+SITZKLIMA+DESIGNO',
#  'e AMG+20"+EXKLUSIV+AR-HUD+HA-LENKUNG+PANO',
#  'A -Klasse A 160 NAVI SHZ',
#  'Mercedes-AMG S 4MATIC+',
#  'e Lim AMG+Night+HighEnd+AR+PANO+HiFi',
#  'e Lim AMG+MBUXAdvancedP+NightP+Spur+Kamera',
#  '350+ AMG Line',
#  'C 63 ILS+BURMESTER+KAMERA+KEYLESS+TEMPOMAT+SHZ',
#  'Mercedes-AMG 4MATIC',
#  'CLS-CLASS 272 4P',
#  'BE AVANTGARDE,Glasdak,Cruisecontrol,Navi,Sensoren',
#  'AMG*NightP*Digital-Light*AHK*',
#  'd',
#  '350+ AMG*Urban Guard*Digital-Light*Pano*',
#  'e Lim Progressive+MBUXAdvanced+SpurA+ParkA',
#  'Blue Efficiency Avantgarde',
#  'Electric Art*Digital-Light*Pano-SD*',
#  'Business Solution AMG (EU6d-TEMP)',
#  'e Lim Progressive+MBUX+NavP+LED+ASound+RFK',
#  '+ EDITION1+AMG+AIRMATIC+PANO+HUD+MEMORY',
#  'Style+LED+Premium MBUX+Park+Sitzhzg',
#  'Electric Art*Digital-Light*Pano-SD*',
#  '9G Avantgarde*NightP*Digital-Light*Fahrassis',
#  'Multibeam Comand Sonnenschutz-Paket',
#  'CDI /1.HD-SH/AHK/TEMP./Park Assis/Sitzh./',
#  'e Lim MBUXAdvancedPaket+SpurAss+ParkAssist',
#  'CDI BE Avantgarde Blue Effic. Ed.',
#  'e Lim Progressive+MBUX+NavPr+LED+Sound+RFK',
#  '/ 1 Hd/ Rentner/Sammlerzustand',
#  'V8 Autom, Leder, Klima, SSD.',
#  'BlueTEC 4Matic (212.011)',
#  'e 9G*AMG*NightP*Digital-Light*Pano*HUD*360°',
#  'ElectricArt/PanoDa/Distr/KeyG/360/Memor Navi/LED',
#  'Business-Solution',
#  '450+  AMG+NIGHT+20"+PANO+AHK+HUD+KEYLESS+360',
#  'Org. 61.000km Aut. Historie 1A Sammlerzust.',
#  'd AMG Line (EURO 6d-TEMP)',
#  'e AMG Line*Night*Pano*Head-Up*AHK*Keyless*',
#  'de',
#  '+   ELECTRIC ART+20"+SITZKLIMA+AHK+KEYL.',
#  'e L 9G*AMG*Chauffeur-Paket*DigitalLight*Pano*HUD*',
#  'e AVANTGARDE+NIGHT+PANO+AHK+SOUND+KAMERA',
#  '1.5D 85kW(116ch) AUTO * CUIR * ATT REM * GPS *',
#  'BUSINESS 1.5D 85kW (116ch) BOITE AUTO * CAM RECUL ',
#  '*1.HAND*ORIGINAL ZUSTAND*KEIN ROST',
#  'e AVANTGARDE+NIGHT+PANO+SOUND+LEDER+KAMERA',
#  'Mercedes-AMG 4MATIC',
#  'd Urban+Navi+AHK+Nightp+LED+KAM+Memory+18"',
#  'AMG-Line BlueEfficiency SR&WR Pano SHZ',
#  '4Matic Edition Avantgarde LED Kamera SHZ',
#  '9G-TRONIC AMG Line, AHK',
#  'D Satellite/TCS/ISO/ESP/4xALU/Brake Ass/',
#  'Aut. 1.4 Color  CARPLAY SHZ LHZ PDC KLIMA',
#  'E Edition ecoFlex *Klima*OPC-line*PDC*WPK*',
#  'E ecoFlex 120 Jahre *beh.Front*RKamera*PDC',
#  'S 1.4 Turbo Sportpaket PDC AC/Auto EFH',
#  'E 1.6 OPC BiXenon*Klimaautomatik*Recaro',
#  'S Klimaaut Sitzheizung Tempomat Recaro',
#  'F 100PS Color-Elegance mit LED-Licht',
#  "1.4 Turbo S OpenAir 18'' Felgen Recaro NAV Leder",
#  '1.0 Turbo Jam ecoFlex *Intellilink4.0*PDC*',
#  'Active mit Kamera PDC Winterpaket Inkl. Inspektons',
#  '1.4 66KW (90 CV) EXPRESSION PRO',
#  'S 1.4 Turbo Klimaaut. IntelliLink Infinity',
#  'F Edition',
#  'Open Air ecoFlex 115PS +Faltdach+ Allwetter',
#  '1.0 Turbo Rocks elektr. Faltdach I Navi',
#  '1.4 120 Jahre Klima ZV SHZ PDC',
#  'E 1.4 Turbo',
#  'E 1.4 Selection Klima*Scheckheftgepflegt',
#  'S 1.4 TURBO *LEDER RECARO*INFINITY SOUND*CARPLAY*S',
#  'E 1.4 Turbo GSi Xenon Sitzheizung PDC',
#  'E 1.4 Turbo 120 Jahre Klimaanlage, USB',
#  'Ultra-All-Inclusive  Corsa E Color Edition',
#  '*Lenkradheizung*PDC hinten* Color Edition',
#  '1.4 120 Jahre S/S Einparkassistent',
#  '1.4 Turbo S PDC|Tempomat|Klimaautomatik',
#  '1.4Unlimited ecoFlex **Intellilink4.0**City-Modus*',
#  'D 1.2 Edition',
#  'F 1.2 Edition Sitz-/Lenkh PDC Kamera',
#  'S 1.4T Recarositze,Infinity,Victory Felgen!',
#  '1.4T Color Edition Navigation,Sitzheizung',
#  'E ON 1.4 *Einparkhilfe*AppleCarplay*Bluetooth USB',
#  'F Edition SITZHEIZUNG PDC  AT',
#  'E 1.4 Turbo Ecoflex 5-Türer +SHZ+GRA+PDC+',
#  'E 1.4 Turbo Color Edition LED PDC Tempomat',
#  '1.4T Color Edition Sitzheizung,Carplay,uvm',
#  'Elegance 100PS AT +LED+KAM+SITZH+KLIMA+PDC',
#  'E 1.4 Turbo GSi (EURO 6d-TEMP) Dist.',
#  'F 1.5 D Edition - Allwetter/Multimedia/PDC',
#  'F Elegance Automatik*SHZ*AAC',
#  'E 1.4 Turbo GSi XENON',
#  'S PDC 18-ZOLL SHZ LHZ APP-NAV KLIMAAUTOM',
#  'E 1.4 Turbo OPC Line Bi-Xenon Sitzheizung',
#  'D Color Edition Klima PDC SHZ Lenkradheiz.',
#  'S - Recaro',
#  '1.4 120 Jahre Open Air Klimaautomatik, USB',
#  'Jam Allwetter CARPLAY SHZ LHZ PDC',
#  'F e Elegance',
#  'E 1,4 Turbo 120 JAHRE 3-türig Bluetooth,',
#  '1.4 EU6d-T Edition ecoFlex S/S',
#  'D 1.3 CDTi Edition / Klima / 5-Türig',
#  '1.4 120 Jahre LM+KlimaA+W-Paket+PDC+',
#  '1.0 120 Jahre PDC,SHZ,DAB+,Tempomat,BT,LM',
#  'Comfort 1.0',
#  '1.4 120 Jahre Kamera,IntelliLink,SHZ,PDC',
#  'F 1.2 Turbo Elegance -Sitzhzg./Klimaautom.',
#  '1.0 Edition *Klimaanlage*USB*Bluetooth*',
#  'F Edition Kamera Sitzheizung Klima',
#  '120 Jahre Klimaautomatik, DAB+Radio,',
#  '1.0 Turbo OPC-Line Xenon AAC SHZ LHZ PDC',
#  '1.4 Jam Sitzheizung Lenkradheizung PDC',
#  '1.4 66KW (90 CV) EXPRESSION PRO',
#  '1.4 66KW (90 CV) EXPRESSION PRO',
#  'E ON APP-NAVI RÜCKFAHRKAMERA SHZ LHZ NAVI',
#  'F Edition Navi Rü-Kamera SHZ LHZ',
#  '1.4 OPEN AIR 120 JAHRE Faltdach, Klima, PDC',
#  'E GSi SITZHEIZUNG PDC APP-NAV XENON',
#  'F 1.2 Turbo GS Line Navi Klimaautomatik',
#  'S 1.4 Turbo Kimaautomatik, PDC, SHZ, Recaro',
#  '-e ELEGANCE NAVI|LED||STANDHEIZUNG|1-PHASEN',
#  'F 1.2 T[Euro6d] S/S 5-T Edition',
#  'E 1.4 Selection *USB*KIima*elektr. FH*',
#  '1.0 Edition Klima Bluetooth Telefon Garantie',
#  '120 Jahre  DAB+, Klimaautomatik, PDC,..',
#  '1.4 Jam Sitzheitung Lenkradheizung Klima',
#  '1.2T Elegance LED,2xKamera,Multimedia,SHZ',
#  '1.4 120 Jahre Winterpaket*Parksensoren',
#  'E 120 Jahre Edition LM+W-Paket+PDC+KAM',
#  'F 1.2 Edition FLA KAM LED PDC SHZ SpurH',
#  '1.4 Jam Klima Sitzheizung Apple Carplay PDC',
#  'F 1.2T Ultimate LED Alcantara Navi Kamera',
#  'F 1.2 Edition PDC*SHZ+Lenkradheiz*Klima',
#  '1.2 Selection+KLIMA+14-ZOLL+5-GANG-SCHALTG',
#  '120 Jahre Klimaautomatik, Winterpaket,..',
#  '1.2T Elegance LED,2xKamera,IntelliLink,PDC',
#  '1.4 JAM Bremsass beh.Lenk Sitzh. Bluetooth',
#  'E 1.4 Edition KLIMA PDC SITZHEIZUNG',
#  'F  Edition Rückfahrkamera / Navigation',
#  '120 Jahre Spoilerpaket',
#  'E 1.4 ACTIVE 5türig Sitz-u. Lenkradheizung',
#  'F 1.2 Turbo Elegance - Sitzhzg./RF-Kamera',
#  '1.4 Jam Klima*Berganfahr*AppleCar/Android',
#  'E 1.4 Turbo GSi RECARO Bi-Xenon Navi DAB',
#  'F 1.2 T[Euro6d] S/S 5-T Edition',
#  'E 1.4 120 Jahre SHZ KAMERA INTELLILINK',
#  'F 1.2 Edition LHZ.PDC,SHZ, Klima',
#  'F 1.2 Edition - Sitzhzg./Rückfahrkamera',
#  'F Edition PDC+SpurH+',
#  '1.0 120 JAHRE inkl. 5 Jahre Garantie (G5)',
#  'F Edition / MULTIMEDIA / SITZHEIZUNG',
#  '1.4 Glam Klima Winterpaket PDC Tempomat',
#  'F 1.2 Edition PDC*SHZ+Lenkradheiz*Klima',
#  'E 1.2 Edition *Klima*USB*SHZ+Lenkrad*',
#  'E 1.4 120 Jahre **Sitzheizung**PDC**',
#  'E 1.4 Selection',
#  '1.0 120 Jahre Allwetterreifen, DAB Radio',
#  '1.0 LPG Innovation *Navigationssystem*',
#  'F 1.2T Automatik ** 1-Hand Opel **',
#  'E 1.4 Selection Radio KLima ZV',
#  'Rocks Cool & Sound-Paket|Bluetooth|SHZ|PDC',
#  'GS - Line Navigation, Sitzheizung, Rückfahrkamera',
#  '100PS Color Edition *Klima*WSS+Lkrd+SHz*PDC',
#  'E 120J *SHZ* *LHZ* *CarPlay* *InteliLink*',
#  '-e GS-LINE NAVI|SHZ|LED|PDC|ALU|1-PHASEN',
#  'F 1.2 Turbo Ultimate FLA+Massage+Alcantara',
#  '-e ELEGANCE NAVI|SHZ|LED|ALU|1-PHASEN',
#  '-e ELEGANCE NAVI|SHZ|LED|PDC|ALU|1-PHASEN',
#  '-e ELEGANCE NAVI|LED||STANDHEIZUNG|1-PHASEN',
#  'F 1.2 Edition *DAB+*Sitzhzg*Beh.Lenk*PDC*',
#  'F e Edition LM Klima Bluetooth Navi PDC',
#  'F 1.2 T[Euro6d] S/S 5-T Edition',
#  '-e ELEGANCE NAVI|KAMERA|SHZ|LED|ALU|1-PHASE',
#  'S 1.4 Turbo Klimaautomatik Tempomat USB',
#  'E Selection',
#  '-e ELEGANCE NAVI|KAMERA|SHZ|LED|ALU|1-PHASE',
#  '-e ELEGANCE NAVI|SHZ|LED|KAMERA|ALU|1-PHASE',
#  'F Edition Navi Rü-Kamera SHZ LHZ',
#  'Exklusiv Parkhilfe*Sitzheizung*uvm',
#  '-e ELEGANCE NAVI|SHZ|KAMERA|1-PHASEN',
#  '1.4 120 Jahre LM PDC SHZ Lenkradhzg',
#  'E 120 Jahre 1.2 Parktronic + Winterpaket',
#  "1.4T  'Color Edition' *Klima*Lkrd+SHz*PDC*",
#  'F 1.2 Turbo Ultimate FLA+Massage+Alcantara',
#  'F 1.2 Edition - PDC/Sitzhzg./Multimedia',
#  'F 1.2 Edition **DAB**Allwetterreifen**Radio BT**Te',
#  'F 1.2 Turbo Elegance - Style Paket/Sitzhzg',
#  'Basis AIRBAG RADIO',
#  'F Edition',
#  '1.0 Turbo Glam Winterpaket Temp LED-Himmel',
#  'F 1.2 Edition (EURO 6d) ParkAss. SpurH PDC',
#  'F 1.2 Turbo GS Line **PDC*Sitzheizung**',
#  'F 1.2 Edition Kamera*CarPlay*Winterpaket',
#  '1.4 Edition  Klima',
#  'Jam Sitzheizung Bluetooth',
#  '-e Edition Elektromotor Allwetter PDC',
#  'F 1.2 Edition (EURO 6d) SpurH Bremsass',
#  'F 1.2 Turbo Ultimate FLA ParkAss. Massage',
#  '1.2 Jam *Klima*USB*Bluetooth*Alufelgen',
#  'E 1.4 Color Edition DAB*IntelliLink*KlimaA',
#  'F 1.2 Edition (EURO 6d) FLA SpurH LED LM',
#  'F 1.2 Edition (EURO 6d) SpurH Bremsass',
#  '1.2 Kamera Sicht-Paket PDC',
#  'E 1.2 Edition W-Paket PDC',
#  'F 1.5 Diesel-T Elegance-TEMP) FLA SpurH',
#  'Open Air 120 Jahre Ecoflex *Faltdach*Navi*',
#  'e Edition !!3-PHASEN SPURASSIST KLIMAAUTO SITZHZG!',
#  'F 1.2 Elegance LED Sitzheizung PDC',
#  'E Selection Klimaanlage, Bluetooth,',
#  'E 1.2 Selection Klima',
#  'E 1.2 Selection Klima',
#  'F 1.2 Edition (EURO 6d) SpurH Bremsass',
#  '-e EDITION NAVI|SHZ|1-PHASEN|KAMERA|PDC',
#  'Slam - Winter P./Freispr./Allwetter',
#  'E 1.4 120 Jahre PDC Klima SHZ LMF',
#  'F 1.2 Edition (EURO 6d) FLA ParkAss. SpurH',
#  '1.2 Jam IntelliLink Sitz-/Lenkradh',
#  'F 1.2 Edition SpurH PDC Bremsass Spurw.',
#  'F 1.2 Edition Lenkradheizung',
#  'F Edition Radio BT*Klima*Spurass.*',
#  'B 1.4 L Automatik*Leder*Klima*GSD*25TKM',
#  'Rocks 120 Jahre Klimaautomatik, Navigation',
#  'E 1.4 120 Jahre IntelliLink/DAB/SHZ/PDC/LM',
#  'E 1.2 Selection Klimaanlage, Bluetooth,USB',
#  'E 1.2 Selection Klimaanlage, Lederlenkrad',
#  '1.2 Jam Sitzheizung Lenkradheizung Klima',
#  'F 1.2 Edition PDC*Klima*SHZ+Lenkrad*DAB',
#  'D Sport LENKRADHEIZUNG SHZ OPC LINE',
#  '1.2 Selection',
#  'D 1.0 ecoFlex*Klima*ZVF*Radio*ABS*Servolenkung*Iso',
#  'F 1.2 Edition',
#  'Edition Start/Stop',
#  'Jam ecoFlex',
#  '1.4 Twinport 87ch Unlimited Start/Stop',
#  'GTC 2.0 Turbo OPC 280PK/Xenon/Navi/Garantie.',
#  '2.0 T Cosmo',
#  '1.4 OPC LINE / COLOR EDITION / AIRCO / NAVI / CRUI',
#  '2.0 T Executive. Automaat Bovag-Garantie',
#  '1.3 CDTI ECOFLEX.S ED. / AIRCO / CRUISE / APK 06-2',
#  '1.4 Turbo GSi LM Carbon Xenon Lhz Shz Inkl. Inspek',
#  '1.4-16V Executive',
#  'E ecoFlex 120 Jahre Klimaanlage, Bluetooth',
#  '1.4 Twinport 87ch Unlimited Start/Stop',
#  'GRAND SPORT 1.5 T 165pk Business Executive [ Full',
#  '2,2 Excellence 4x4 2011',
#  '1.2-16V Njoy 3DRS MOOI NAP',
#  'drive ecoFlex E',
#  '1.2-16V RHYTHM',
#  '1.4 Twinport 87ch Start/Stop',
#  '1.4 Turbo Innovation | AUT. | CAMERA | CLIMA | CRU',
#  'GTC 1.6 Turbo 170pk Sport OPC-Line 1e eigenaar/Dea',
#  '1.2 Ecoflex Business Edition LPG G3 [ Cruise Contr',
#  '2.0 Turbo Roadster Cabrio Klima Leder 1Hand Europa',
#  '2.0 CDTI Innovation Bi-Xenon Navi R.Cam PDC SHZ',
#  '1.4 Turbo Cosmo Xenon/Navi/Leder/Clima/Cruise..',
#  'Innovation ecoFlex FLA BiXenon Leder LM',
#  'ecoFlex  Edition EURO 6',
#  '1.6 Turbo Innovation ecoFlex',
#  '2.0 CDTI Innovation ecoFlex S/S Leder',
#  ...]

# %%
df.loc[df[df["drivetrain"].isnull()].index, "short_description"].str.contains("4[ -]*Matic", case = False).value_counts()
# Out:
# False    11557
# True        79
# Name: short_description, dtype: int64

# %%
# Let's retrieve the entries that contain "Hyrib, hbr " and assign them the label "Hybrid".

# The expression "(?i)" in the code disables case sensitivity.

matic_train  = df.loc[df[df["drivetrain"].isnull()].index, "short_description"].str.contains("4[ -]*Matic", case = False)
matic_train
# Out:
# 0        False
# 1        False
# 8         True
# 15       False
# 16       False
#          ...
# 29459    False
# 29462    False
# 29463    False
# 29468    False
# 29477    False
# Name: short_description, Length: 11715, dtype: object

# %%
# Let's retrieve the indices of the ones that return True.
matic_index = matic_train[matic_train == True].index

# %%
# After the this operation, how many NaN values do I have filling?
matic_train[matic_train == True].count()
# Out:
# 79

# %%
# Now let's assign "Hybrid" to the indices we obtained.
df.loc[matic_index, "drivetrain"] = "4WD"

# %%
handle_missing_values(df , "drivetrain")
# Out:
# Missing Values in 'drivetrain':
# Count: 11636
# Percentage: 40.68%

# %%
# Let's retrieve the entries that contain "Hyrib, hbr " and assign them the label "Hybrid".

# The expression "(?i)" in the code disables case sensitivity.

front_train  = df.loc[df[df["drivetrain"].isnull()].index, "short_description"].str.contains("Front", case = False)
front_train
# Out:
# 0        False
# 1        False
# 15       False
# 16       False
# 23         NaN
#          ...
# 29459    False
# 29462    False
# 29463    False
# 29468    False
# 29477    False
# Name: short_description, Length: 11636, dtype: object

# %%
# Let's retrieve the indices of the ones that return True.
front_index = front_train[front_train == True].index

# %%
# After the this operation, how many NaN values do I have filling?
front_train[front_train == True].count()
# Out:
# 16

# %%
# Now let's assign "Hybrid" to the indices we obtained.
df.loc[front_index, "drivetrain"] = "Front"

# %%
handle_missing_values(df , "drivetrain")
# Out:
# Missing Values in 'drivetrain':
# Count: 11620
# Percentage: 40.63%

# %%
# After the groupby operation, how many NaN values do I have remaining?
df.groupby(["body_type", "gearbox"])["drivetrain"].transform(lambda x: x.fillna(x.mode()[0])).isnull().sum()
# Out:
# 0

# %%
df['drivetrain'].fillna(df.groupby([ "body_type", "gearbox"])["drivetrain"].transform(lambda x: x.mode()[0]), inplace = True)

# %%
handle_missing_values(df , "drivetrain")
# Out:
# Missing Values in 'drivetrain':
# Count: 0
# Percentage: 0.00%

# %% [markdown]
# <a id="19"></a>
# <div class="alert alert-info" role="alert">
# <h1>Column name :<span style="color:red"> colour </span></h1>
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Operation : </b> To fill in the missing values in the "colour" column, we can use the "short_description" column . Since the "colour" column is associated with <span style="color:red"><b> " manufacturer_colour " , " body_type " and " location_country "</b></span> . let's fill in the <span style="color:red"><b> NaN values</b></span> in this column by grouping the data based on these columns and performing the necessary operations.
# </div>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
first_looking("colour")
# Out:
# column name    :  colour
# --------------------------------
# per_of_nulls   :  % 6.0
# num_of_nulls   :  1715
# num_of_uniques :  14
# Black     6471
# Grey      5994
# White     5182
# Blue      3476
# Red       2239
# NaN       1715
# Silver    1620
# Green      450
# Brown      435
# Orange     287
# Beige      278
# Yellow     230
# Violet      98
# Bronze      65
# Gold        62
# Name: colour, dtype: int64

# %%
# Let's examine the short description of the seats
list(df.loc[df[df["colour"].isnull()].index, "short_description"])
# Out:
# ['350+',
#  'd 4Matic (EURO 6d)',
#  'd AMG Line (EURO 6d)',
#  '200CDI BE AMG Line 7G-DCT',
#  '200 d Fascination 7G-DCT',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '35 AMG 306ch 4Matic 7G-DCT Speedshift AMG',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '200 d 150ch Progressive Line 8G-DCT 8cv',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '200 d Business 7G-DCT',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '220 d Fascination 7G-DCT',
#  '35 AMG 306ch 4Matic 7G-DCT Speedshift AMG 19cv',
#  '200 d Inspiration 7G-DCT Euro6c',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '220 190ch Progressive Line 7G-DCT Siege chauf gran',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  'd 4Matic AMG Line (EURO 6d)',
#  '220 d 190ch AMG Line 8G-DCT 10cv GPS Camera Radar ',
#  '180 d 116ch Business Line 7G-DCT',
#  '200 d 150ch Business Line 8G-DCT GPS Camera',
#  '180 d 116ch AMG Line 7G-DCT',
#  '200 d Inspiration 7G-DCT',
#  '200 163ch Style Line 7G-DCT',
#  '35 AMG 306ch 4Matic 7G-DCT Speedshift AMG TOuvrant',
#  '200 d 150ch AMG Line 8G-DCT 8cv',
#  '200 d Fascination Tpano GPS Camera',
#  '180 d 116ch AMG Line LED GPS Camera Radar AV/AR',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '180 136ch Progressive Line 7G-DCT 7cv',
#  'd',
#  '180 d Sensation 7G-DCT',
#  '200 d 150ch AMG Line 8G-DCT',
#  '220 190ch Progressive Line 7G-DCT',
#  '180 d Sensation 7G-DCT',
#  '180 136ch Business Line 7G-DCT',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '220 190ch Progressive Line 7G-DCT Ecran 10 GPS Cam',
#  '180 d Intuition 7G-DCT',
#  '160 109ch Style Line',
#  '200 163ch AMG Line 7G-DCT',
#  '160 Inspiration 7G-DCT',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '180 d 116ch Progressive Line 7G-DCT',
#  'Coupé 3.0 CDI V6 DPF 7G-TRONIC BlueEFFICIENCY 265',
#  '4Matic 7G-DCT',
#  '180CDI Polar Star',
#  '4Matic Coupe 4Matic+ (EURO 6d-TEMP)',
#  'S 4Matic+ 4Matic (EURO 6d)',
#  'de 4Matic AMG Line (EURO 6d)',
#  'C Roadster',
#  'abrio Mercedes-AMG 4MATIC',
#  nan,
#  'd 4M Cabriolet AMG Sport ABC Distr LED',
#  'abrio Mercedes-AMG 4MATIC',
#  'Cabrio d',
#  'Navi PDC SHZ',
#  'Cabrio 220CDI 7G Plus',
#  'Cabrio d',
#  '(R171) 350 7GTRO',
#  '220 d executive a',
#  '190SL',
#  'oupé Mercedes-AMG 4MATIC',
#  '320CDI Aut.',
#  'S Coupe',
#  '4Matic (EURO 6d-TEMP)',
#  '-CLASS 3.0 4MATIC AUTO 333 2P',
#  'Coupé d AMG LINE',
#  'Coupé d AMG LINE',
#  '300d 4Matic Aut.',
#  '4MATIC',
#  '4MATIC',
#  'd 4Matic All-Terrain Estate Avantdarde',
#  'd 4MATIC',
#  'd 4MATIC',
#  '300 4MATIC',
#  '4MATIC',
#  'Mercedes-AMG 4MATIC',
#  '4Matic+ Aut.',
#  'Mercedes-AMG 4MATIC+',
#  'd 4MATIC',
#  'T CDI Avantgarde Export',
#  'Estate 200CDI BE Edition',
#  'd Estate Avantgarde',
#  'de Estate AMG LINE',
#  'Mercedes-AMG 4MATIC Estate',
#  'Estate Estate',
#  'd Estate',
#  'Estate 200d 9G-Tronic',
#  '580 4Matic',
#  '4Matic 7G Plus',
#  'CDI Business',
#  'Mercedes-AMG S 4MATIC+',
#  'CDI 4Matic/Pano/Navi/Off-Road/ AMG Line',
#  '350+',
#  'd 4MATIC',
#  'd',
#  '4MATIC',
#  'Mercedes-AMG S 4MATIC+',
#  'd AMG Line (EURO 6d-TEMP)',
#  'S 1.4 Turbo Sportpaket PDC AC/Auto EFH',
#  'D 1.2 Edition',
#  '1.4 JAM Bremsass beh.Lenk Sitzh. Bluetooth',
#  'F 1.2 Edition (EURO 6d) SpurH Bremsass',
#  'F 1.2 Edition SpurH PDC Bremsass Spurw.',
#  'F 1.2 Edition Lenkradheizung',
#  'Corsa-e Elegance-e',
#  '1.4 Twinport 87ch Unlimited Start/Stop',
#  '1.4 Twinport 87ch Unlimited Start/Stop',
#  '2,2 Excellence 4x4 2011',
#  '1.4 Twinport 87ch Start/Stop',
#  '1.6 Turbo Ultimate Navi+ParkAss.',
#  '2.0 CDTI 165ch Cosmo Start\\u0026Stop',
#  '1.6T Innovation Bi-Xenon Navi Teilleder',
#  '1.4 Turbo Excellence',
#  '1.4 Turbo Excellence',
#  '1.4 Turbo Excellence',
#  '1.4 Turbo Excellence',
#  '1.4 Turbo Excellence',
#  'Twin Top 1.8 Enjoy',
#  'Innovation ecoFlex Allu Tüv Garagenwagen',
#  'Twin Top Sport',
#  'TwinTop 1.8-16V Linea Nera',
#  '2.0 CDTI 165CH COSMO PACK AUTOMATIQUE',
#  'J GTC Basis',
#  'Edition H GTC (Rentnerfahrzeug aus 1. Hand)',
#  '2.0 Turbo OPC+Rückfahrkamera+Navi+',
#  'J GTC Edition 1-Hand Scheckheft SR+WR',
#  'J GTC 2.0 CDTI Active/NAVI/SHZ/USB/EU5',
#  'J GTC Innovation,1.Hand,Xeno20 Zoll, Video',
#  'H GTC Sport Navi/PDC/18-Zoll/Scheckheft!',
#  '2.0 Turbo OPC+Rückfahrkamera+Navi+',
#  'J GTC Innovation ***LÜCKENLOS GEWARTET***',
#  'J GTC Edition 1.4 ~ KLIMA ~ MFL ~ PDC',
#  'H GTC CATCH ME*1.HD*Klima*PDC*TÜV NEU',
#  '1.3 CDTI Advance 95cv S/S 5 PORTE',
#  'B CC - 2.0E - 22tkm ! -perfekt original',
#  '1.3 CDTI b-Color 75cv 5 PORTE',
#  'J GTC Sport *88.000km*',
#  'Corsa 3p 1.3 cdti b-Color 75cv',
#  '1,2 GS Line',
#  'B Sports Tourer 2.0 Turbo INNOVATION **AHK**Navi**',
#  'ST 1.6CDTi S/S Selective 110',
#  '1.5 D 130ch Ultimate BVA8',
#  '1.5 D 122ch Elegance BVA 112g',
#  '1.5 D 110ch GS Line',
#  '5ª serie 1.6 CDTi 136CV aut. Sports Tourer Dynamic',
#  '1.4  Automatik Navi Klima',
#  'Grand Spor t 2.0 Autom.',
#  '2.0 ECOTEC DI Turbo Aut. Innovation',
#  'A 2.0 CDTI Sport OPC Paket Parkass. AHK',
#  '1.2 Jam Klima MFL Tempomat',
#  '120 Jahre LM+W-Paket+PDC+',
#  '120 Jahre LM W-Paket Leder PDC SHZ',
#  'K 5-trg. 1.2 Turbo Parkass,LED,DAB',
#  'C 2.0 T GTS Edition 1.Hd Klimaautomatik',
#  'rs line',
#  '1.8 TCe GPF RS Trophy EDC 221kW',
#  '1.5dCi Expression 110',
#  '1.3 TCe 140cv Zen Energy',
#  '1.2 16v Dynamique eco2',
#  '1.8 TCe GPF RS Trophy EDC 221kW',
#  'Electric Zen R80 60kW Batería 20kW/h',
#  '1.3 TCe GT-Line / 1e Eigenaar / Navi / Climate / P',
#  '1.6 TCe 205ch energy GT EDC',
#  '1.5 dCi 110ch energy Business eco² GPS Radar Av/Ar',
#  '1.5dCi Blue R.S. Line EDC 85kW',
#  '1.6 dCi 130ch energy Intens',
#  '1.5 Blue dCi 115ch Intens GPS Camera Radar AV/AR',
#  '0.9 TCe 95ch Signature',
#  '1.2 TCe 120ch energy Intens EDC 5p Camera GPS',
#  '0.9 TCe 90ch energy Intens 5p Euro6c',
#  '1.3 TCe GPF Intens 103kW',
#  '1.3 TCe 140ch FAP Business EDC -21B GPS Radar AV/A',
#  '0.9 TCe 90ch energy Zen',
#  '1.3 TCe 160ch FAP GT-Line EDC GPS Camera Park Assi',
#  '0.9 TCe 95ch Zen',
#  '1.5 dCi 90ch energy Limited 5p',
#  '0.9 TCe 90ch energy Limited Euro6C',
#  '1.3 TCe 140ch energy Limited EDC GPS Radar AR',
#  '1.0 SCe 70ch Life 2 Boîte Courte Euro6',
#  '1.6 E-Tech 140ch Zen',
#  '1.0 SCe 70ch Stop\\u0026Start Zen eco²',
#  'Electric Life R80 Achat Intégral 3CV',
#  '1.5 Blue dCi 95ch Business GPS Radar Av/Ar',
#  '0.9 TCe 75ch energy Trend 5p Euro6c',
#  '1.6 E-Tech Plug-in 160ch RS Line -21N',
#  '1.5 Blue dCi 115ch Business -21B',
#  '1.5 Blue dCi 115ch Intens EDC',
#  '0.9 TCe 95ch Zen',
#  '1.5 DCI 110CH FAP DYNAMIQUE ECO²',
#  '1.2 TCE Dynamique',
#  'Megane Grandtour 1.5 dci Dynamique 105cv',
#  '2.0 DCI 150CH PRIVILEGE',
#  'Megane SporTour 1.5 dci Limited 95cv',
#  'II CC 1.9 dCi 130 FAP Privilège',
#  'III Cabriolet 1.5dCi Luxe Automatik',
#  '1.5 dCi 110ch energy FAP eco²',
#  'tce 140 edc fap',
#  'tce 140 edc fap',
#  'TCe 140 EDC FAP - 21B R.S. Line',
#  'tce 140 edc fap - 21b',
#  'A PREPARER',
#  'CoupÃ© 2.0 dCi 150cv 2p #LIBRO, NAVY, BLUETOOTH',
#  'Zen',
#  'CoupÃ© 2.0 dCi 150cv 2p #LIBRO, NAVY, BLUETOOTH',
#  'Coupé Monaco GP TCe 180*1.Hand*Panorama*',
#  'TURBO 1',
#  '1.3 tce intens 140cv edc fap',
#  'tce 160 edc fap - 21b',
#  '2.0 dCi 150ch Black Edition',
#  '1.0 TCE 74KW BUSINESS 5 PORTE',
#  'tce 160 edc fap - 21b',
#  '1.3 tce intens 140cv edc fap',
#  'tce 140 edc fap - 21b r.s. line',
#  '2.0 Blue dCi 190cv X-Tronic 4x4 Zen',
#  '1.5dCi Energy Zen 81kW',
#  '2.0dCi Blue Initiale Paris X-Tronic 4x4 140kW',
#  'TCe 90 Intens Easy-Link 9,3 Zoll',
#  'dci 90',
#  'e-tech 145 - 21',
#  '1.5 dCi 110ch energy Business',
#  '1.5 dCi 110ch energy Intens EDC eco²',
#  '1.5 Blue dCi 115ch Intens',
#  '1.5 dCi 110ch energy Business EDC eco²',
#  '1.6 dCi 130ch energy Intens Toit Pano Bose Sound S',
#  '1.3 TCe 140ch FAP Intens EDC -21 LED GPS Radar Ar',
#  '2.3 dCi 190ch Double Cabine Zen',
#  '1.3 TCe 140ch FAP RS Line EDC -21B',
#  '1.5 Blue dCi 115ch Intens',
#  '1.3 TCe 160ch FAP Black Edition SL EDC',
#  '1.3 TCe 155ch FAP Intens EDC - 20 GPS Radar Ar',
#  '1.5 dCi Energy Initiale Paris',
#  '1.5 Blue dCi 115ch Business 131g',
#  '1.6 E-Tech 145ch RS Line',
#  'e-tech 145 - 21',
#  '2.0 dCi 175ch energy Initiale Paris X-Tronic',
#  '1.5 dCi 110ch energy Intens EDC eco²',
#  '1.5 Blue dCi 115ch Business',
#  'blue dci 115',
#  '2.0 dCi 175ch energy Initiale Paris X-Tronic Cuir',
#  'tce 160 edc',
#  '1.2 TCe 130ch energy Intens EDC',
#  '1.5 dCi 90ch energy Business eco²',
#  '1.5 Blue dCi 115ch Business 131g',
#  '1.5 dCi 110ch energy Business eco²',
#  '1.3 TCe 140ch FAP RS Line EDC -21B',
#  '1.5 dCi 90ch energy Business Euro6c',
#  '1.6 E-Tech 145ch Intens -21B',
#  'tce 160 edc',
#  '2.0 dCi 175ch Intens X-Tronic - 18',
#  '1.0 TCe 100ch Intens GPL -21',
#  'IV/1.Hd-SH/Assis+/Cam./TSGS/NAVI/PDC+',
#  'S.T. 2.0dCi Blue Zen EDC 147kW',
#  'tce 160 edc',
#  '1.5 dCi 110ch energy Limited eco² 2015',
#  '1.2 TCe 120ch energy Intens EDC Euro6 2015',
#  '1.5 dCi 110ch energy Business',
#  '1.6 TCe 205ch energy GT EDC',
#  '1.2 TCe 130ch energy Intens EDC',
#  '1.5 dCi 90ch energy Business EDC Euro6c',
#  'Sporter dCi 8V 110 CV EDC Energy Business',
#  'grand scénic dci 130 energy fap eco2',
#  '1.5 Blue dCi 115ch RS Line EDC',
#  '1.5 dCi 110ch energy Zen EDC',
#  '1.5 dCi 110ch energy Limited',
#  '1.6 dCi 160ch energy Intens EDC',
#  '1.6 dCi 130ch energy Intens GPS Radar Av/Ar HUD S/',
#  '1.5 dCi 110ch energy Limited',
#  '1.5 dCi 90ch energy Business Euro6c',
#  'blue dci 150',
#  'estate dci 130 energy',
#  '1.6 dCi 160ch energy Intens EDC',
#  '2.0 Blue dCi 200ch Business Intens EDC - 19',
#  '1.5 Blue dCi 95ch Life',
#  'S.T. 1.8dCi Blue GT Line EDC 110kW',
#  '1.5 dCi 110ch energy Business EDC',
#  '1.3 TCe 115ch energy Business',
#  '1.3 TCe 140ch FAP Intens 120g',
#  '1.7 Blue dCi 150ch Business',
#  '1.5 dCi 90ch energy Business',
#  '1.6 E-Tech Plug-in 160ch RS Line -21N',
#  '1.7 Blue dCi 150ch Business Intens',
#  '2.0 Blue dCi 190ch Initiale Paris EDC',
#  '1.5 Blue dCi 95ch Business',
#  '1.5 Blue dCi 115ch Business - 20',
#  'IV ESTATE BUSINESS Blue dCi 115',
#  '1.5 dCi 75ch energy Business Euro6c',
#  'mégane iv estate blue dci 115 - 21b',
#  '1.2 TCe 130ch energy Intens',
#  '1.5 Blue dCi 115ch Business - 20',
#  'Zen TCe GPF 74 kW (100CV)',
#  'Zen TCe GPF 74 kW (100CV)',
#  'Zen TCe GPF 74 kW (100CV)',
#  'Zen TCe GPF 74 kW (100CV)',
#  'Zen TCe GPF 74 kW (100CV)',
#  'Zen TCe GPF 74 kW (100CV)',
#  'Zen TCe GPF 74 kW (100CV)',
#  'Zen TCe GPF 74 kW (100CV)',
#  'EXPERIENCE-Selection R110 Z.E.50 mit CCS',
#  'Zen TCe GPF 74 kW (100CV)',
#  'Zen TCe GPF 74 kW (100CV)',
#  'Grand Coupé TCe 140 Navi+Head-Up+Keyless',
#  'Zen TCe GPF 74 kW (100CV)',
#  'Zen TCe GPF 74 kW (100CV)',
#  'Limited Energy TCe 66kw (90CV) eco2',
#  '3.0 V6 255CH 3P 62500HT',
#  'II Phase 2 (VP) 1.5 dCi S&S 90 cv',
#  '2.0 Blue dCi 160ch Intens EDC - 19',
#  '1.6 dCi 130ch energy Intens',
#  '1.6 dCi 160ch energy Intens EDC',
#  'ii 1.2 lev 16v 75 eco2',
#  '1.6 TCe 205ch energy GT EDC',
#  'Zen TCe GPF 74 kW (100CV)',
#  '1.0 TCe 100ch Evolution GPL',
#  '1.6 dCi 130ch energy Zen EDC',
#  '1.8 T 300CH RS TROPHY EDC',
#  '2.0 Blue dCi 200ch Initiale Paris EDC - 19',
#  'Intens R110 MY19',
#  'dCi 110 Limited',
#  '1.5 dCi 110ch energy Zen',
#  '1.6 dCi 160ch energy Initiale Paris EDC',
#  '1.5 dCi 110ch energy Business',
#  'Initiale 1.6 16V 110',
#  '2.0 Blue dCi 160ch Intens EDC',
#  '2.0 Blue dCi 190ch Initiale Paris EDC',
#  '1.6 dCi 130ch energy Limited EDC',
#  '1.6 dCi 130ch energy Business EDC',
#  '2.0 Blue dCi 160ch Intens EDC',
#  '2.0 Blue dCi 190ch Initiale Paris EDC',
#  'Life charge normale Type 2',
#  'Mégane IV 1.5 Blue dCi - 115 - BV EDC -  GT Line P',
#  '1.6 dCi 130ch energy Intens',
#  'Zen charge normale R90',
#  'Zen charge normale R90',
#  'City charge normale R90',
#  '2.0 Blue dCi 190ch Initiale Paris EDC',
#  'Intens charge normale Type 2',
#  'Zen TCe GPF 74 kW (100CV)',
#  '2.0 Blue dCi 160ch Intens EDC',
#  'Life charge normale Type 2',
#  nan,
#  '1.2 PURE TECH ACTIVE 75 CV',
#  '1.2 PURE TECH ACTIVE 75 CV',
#  '1.2 PURE TECH ACTIVE 75 CV',
#  'e-208 136ch Active',
#  '1.6 THP 270ch GTi S7S 5p Tpano GPS Camera',
#  '1.6 THP 270ch GTi S/S 5p Tpano Siege chauf GPS Cam',
#  '1.6 THP 270ch GTi S/S 5p',
#  '1.6 BlueHDi 120ch Outdoor S/S',
#  '1.6 THP 270ch GTi S/S 5p GPS Camera Radar AV/AR',
#  '2.0 BlueHDi 180ch S/S GT EAT8 Tpano Siege chauf/ma',
#  'VTi 72 Allure 5p',
#  '1.6 BlueHDi 120ch GT Line S/S 5p GPS Camera',
#  'e-208 136ch GT Line Siege Chauf LED GPS Camera Rad',
#  'BlueHDi 130ch S/S Standard GT Line EAT8',
#  'VTi 72 Like S\\u0026S 85g 3p',
#  '1.6 THP 208ch GTi S/S 3p GPS Car Play',
#  '1.6 BlueHDi 100ch Active 5p GPS',
#  '1.6 BlueHDi 120ch GT Line S/S EAT6 5p',
#  '1.6 BlueHDi 100ch Style 5p Radar Ar',
#  '1.2 PureTech 130 GT P2 Sportpaket FLA Pano',
#  '1.4 Essence 75 CV BVA',
#  '1.2 PureTech 100ch S\\u0026S Allure Pack Siege Chau',
#  'PHEV 180ch Allure Pack e-EAT8 GPS Camera',
#  'VTi 72 Like S\\u0026S 4cv 5p',
#  'VTi 72 Allure S\\u0026S 4cv 5p',
#  '1.5 BlueHDi 130ch S/S Allure EAT6',
#  '1.5 BlueHDi 100ch E6.c Active BVM5 86g 5p',
#  '1.5 BlueHDi 100ch E6.c GT Line S/S BVM5 5p',
#  '1.5 BlueHDi 100ch S/S Active',
#  '1.2 PureTech Style Top 5p',
#  'VTi 72 Active S\\u0026S 85g 5p',
#  '1.2 PureTech 68ch E6.c Like 5p',
#  '1.2 PureTech 100ch S/S Style LED GPS Radar Ar',
#  '1.5 BlueHDi 100ch E6.c S/S Style GPS Camera JA17',
#  '1.2 PureTech 100ch S/S Allure 118g',
#  '1.5 BlueHDi 130ch S/S Allure GPS Camera Car Play K',
#  '1.2 PureTech 100ch S\\u0026S GT Line GPS Camera Car',
#  '1.2 PureTech 100ch S\\u0026S Allure 118g',
#  '1.0 12v Urban Move 5p',
#  'PureTech 110ch S/S Standard GT Line 119g GPS Camer',
#  '1.2 PureTech Active 5p',
#  '1.2 PureTech 130ch S/S Allure EAT6 Siege chauf',
#  '1.2 PureTech 130ch ¤6.c S/S Active Business Siege',
#  'WAGON Business 1.6 8v e-HDi 115cv S/S',
#  '1.5 BlueHDi 100ch S/S Allure',
#  '1.2 PureTech 100ch S/S Active',
#  '1.2 PureTech 75ch S/S Like',
#  '1.2 PureTech 130ch S\\u0026S GT Line EAT8 7cv',
#  '1.2 PureTech 130ch Active Business Siege chauf Cam',
#  '1.2 PureTech 110ch Allure S/S 5p',
#  '1.2 PureTech 82ch Style 5p GPS Radar Ar',
#  '1.5 BlueHDi 130ch S/S Active Business GPS Camera R',
#  '1.2 PureTech Style 5p',
#  '1.2 PureTech 100ch S/S Allure Business',
#  '2.0 16V',
#  'Cabriolet 2 l',
#  'Sport 1.6 HDI 110 FAP',
#  'Cabrio 1.6 THP Sport Pack 115 kW (156 CV)',
#  'CC 1.6 VTi 120cv SPORT 2p #BLUETOOTH',
#  'CC HDI 136 FAP',
#  'CC 1.6 VTi 120cv SPORT 2p #BLUETOOTH',
#  '2.0 HDI 120CV DISTRIB OK',
#  'CC 2.0 HDi 16V 140 ch FAP Féline 7',
#  nan,
#  '1.6 E-HDI112 FAP SPORT',
#  'CC Cabrio Allure 1.6 Turbo XENON~LEDER~NAVI~',
#  '2.0 HDI FAP SPORT PACK',
#  'CC 2.0 HDI Cabrio Allure',
#  '1.6 VTI 16V FELINE',
#  'Coupé 2.2',
#  '2.7 V6 HDI GRIFFE BAA FAP',
#  '1.6 THP 155cv',
#  'Coupe 2.0i pack',
#  '2.7 V6 HDI FELINE BAA FAP',
#  '1.6 200 THP',
#  'Active BlueHDi 120cv S&S 5 PORTE BERLINA',
#  '2.7 V6 HDI 204 CH FELINE BA *CUIR*GPS*',
#  'CC Platinum Klimaautomatik HU AU 07.2024 Leder',
#  '207 3p 1.6 thp 16v Le Mans Series n°319',
#  '207 3p 1.6 hdi 16v X-Line c/esp',
#  '1.6 155 THP Automatik',
#  '1.6 155 THP Xenon Voll-Leder WR',
#  '1.5 BlueHDi 130 Active Navi SHZ PDC Kamera',
#  '1.2 PureTech 130 Active Navi,Rückfahrkamera',
#  '1.6 e-HDi FAP 115 Allure *KlimaA*Navi*PDC',
#  '1.2 PureTech Allure KlimaA PDC Kamera ALU',
#  '1.6 PureTech 180 Allure FLA+Pano+360+SpurH',
#  'Elektromotor GT *LED*PDC*Stizheizung*',
#  '2.0 BlueHDI GT Navi LED Pano 7-Sitze Focal',
#  'Allure Pack,ACC,SPURH,LED,KAM,TOTW,SHZ,APP',
#  'Allure Pack,ACC,SPURH,LED,KAM,TOTW,SHZ,APP',
#  '2.0BlueHDi S&S GT EAT6 180',
#  'BlueHDi 130 EAT8 Allure',
#  'Active 1.6 BlueHDi 100',
#  'Active 1.6 BlueHDi 100',
#  'Allure Pack,ACC,SPURH,LED,KAM,TOTW,SHZ,APP',
#  '2.0BLUEHDI 133KW GT AUTO S&S 180 5P',
#  'Active 1.6 BlueHDi 100',
#  'Active 1.6 BlueHDi 100',
#  '2.0 BlueHDi 180ch GT S\\u0026S EAT6',
#  '2.0 BlueHDi 180ch S\\u0026S GT Line EAT8',
#  '1.2 PureTech 130ch S\\u0026S Style EAT8',
#  '1.2 PureTech 130ch S\\u0026S Style EAT8',
#  '2.0 bluehdi 150ch s\\u0026amp;s bvm6 allure / suivi',
#  'e-2008 136ch GT Line',
#  '2.0 BlueHDi 150ch GT Line S/S TOuvrant/Pano GPS Ra',
#  '1.6 THP 16v 165ch Allure S/S EAT6 Tpano HUD Camera',
#  'SW 2.0 SR Sport 143',
#  'SW Allure/ Gr. Panorama/Lückenlos SH/1 Hand/',
#  '1.2 PureTech EAT8 GT Long 7 plazas',
#  'SW  Active Navigation / Rückfahrkamera',
#  'HYBRID4 300ch GT Pack e-EAT8',
#  '1.5 BlueHDi 130ch S\\u0026S GT EAT8',
#  'e-2008 136ch GT',
#  'SW GT  Pano SpurH Alcantara LM LED KeyLess',
#  'BlueHDi 130ch Long GT Line 7pl +opts',
#  'e-2008 136ch GT',
#  '2.0 BlueHDi 180ch S\\u0026S Roadtrip EAT8',
#  '3ª serie BlueHDi 130 S&S SW Allure',
#  'BlueHDi 130 S&S SW Allure MY 20',
#  '1.2 PureTech 130ch E6.c S\\u0026S Allure EAT8',
#  '5p GT Line 1.2 PureTech 130 S&S',
#  '1.2 PureTech 130ch E6.c S/S GT Line EAT8 Tpano GPS',
#  '1.2 PureTech 130ch S\\u0026S Allure Business EAT8 C',
#  'PureTech 225ch S\\u0026S First Edition EAT8 119g',
#  'BlueHDi 130ch S\\u0026S GT EAT8',
#  'SW 1.6 bluehdi Business s&s 120cv eat6',
#  '1.2 PureTech 130ch Allure S/S EAT6 Tpano Camera GP',
#  '2.0 BlueHDi 180ch FAP EAT6',
#  'SW 1.6 bluehdi Business s&s 120cv eat6',
#  '1.5 BlueHDi 130ch S\\u0026S GT Pack EAT8',
#  '1.5 BlueHDi 130ch S/S Active Business 7cv Siege Ch',
#  'HYBRID 225ch GT Line e-EAT8 +opts',
#  '1.5 BlueHDi 110ch S\\u0026S Allure',
#  'BlueHDi 180ch S\\u0026S GT Line EAT8',
#  'PHEV 180ch Allure Pack e-EAT8',
#  '1.5 BlueHDi 130ch S\\u0026S Style',
#  'PHEV 225ch GT Pack e-EAT8',
#  'e-2008 136ch GT Pack +T.O',
#  '1.5 BLUEHDI 130CH S\\u0026S ALLURE EAT8',
#  '1.5 BlueHDi 130ch S\\u0026S Active Business',
#  'BlueHDi 130ch S\\u0026S Allure Pack EAT8',
#  '1.5 BlueHDi 130ch S\\u0026S GT EAT8',
#  'HYBRID 225ch GT e-EAT8',
#  '308 SW 1.5 bluehdi Active s',
#  '1.2 PURETECH 130CH S\\u0026S GT EAT8',
#  '1.2 PureTech 130ch S\\u0026S GT EAT8',
#  '2.0 BlueHDi 180ch FAP EAT6',
#  'HYBRID 225ch GT e-EAT8',
#  '1.5 BlueHDi 130ch S\\u0026S Active Business',
#  '1.2 PURETECH 130CH S\\u0026S STANDARD EAT8 ATTELAGE',
#  'HYBRID 225ch GT e-EAT8',
#  '1.6 BlueHDi 120ch GT Line S\\u0026S',
#  'HYBRID4 360ch e-EAT8 PEUGEOT SPORT ENGINEERED',
#  'PureTech 180ch S\\u0026S Allure Business EAT8',
#  'PHEV 180ch Allure Pack e-EAT8',
#  '1.2 PureTech 130ch S\\u0026S Allure Pack EAT8',
#  'PHEV 225ch GT Pack e-EAT8',
#  'PHEV 180ch Allure Pack e-EAT8',
#  '1.2 PureTech 110ch Allure S\\u0026S',
#  'II Ph2 1.5 BlueHDi 130 S\\u0026S GT Line BA8',
#  'HYBRID4 360ch e-EAT8 PSE 2500km',
#  'HYBRID 225ch GT e-EAT8',
#  '1.5 BlueHDi 130ch S\\u0026S Active Business',
#  '1.5 BlueHDi 130ch S\\u0026S Allure Business',
#  'BlueHDi 130ch Active EAT8 T.O+ADML',
#  'PureTech 100ch Style GPS',
#  'II SW Hybrid 225 e-EAT8 Allure Pack',
#  'PHEV 180ch Allure Pack e-EAT8',
#  '1.5 BlueHDi 100ch E6.c S\\u0026S Style',
#  '1.2 PureTech 130ch S\\u0026S Allure Pack',
#  'PHEV 180ch Allure Pack e-EAT8',
#  '1.5 BlueHDi 130ch S\\u0026S Active Business',
#  '1.2 PureTech 110ch E6.3 S\\u0026S Style',
#  '1.2 PureTech 110ch E6.3 S\\u0026S Active Business',
#  'e-2008 136ch Active',
#  'BlueHDi 180 EAT6 S&S SW Allure',
#  '1.6 ESSENCE ALLURE PACK 155CV BVA POUR ALGERIE UNI',
#  '1.2 PURETECH 130CH ACTIVE BUSINESS S\\u0026S',
#  '1.2 PureTech 130ch E6.3 S/S Active',
#  '1.2 PureTech 130ch S\\u0026S Style',
#  '1.2 PureTech 130ch S/S Active Business EAT8',
#  'e-2008 136ch GT',
#  'e-2008 136ch GT',
#  'e-2008 136ch GT',
#  '1.2 PureTech 130ch S\\u0026S Allure Pack EAT8',
#  'e-2008 136ch GT',
#  '1.5 BlueHDi 130ch S\\u0026S Allure EAT8',
#  'HYBRID 225ch Allure Pack e-EAT8',
#  'PHEV 180ch Allure e-EAT8',
#  'HYBRID 225ch GT e-EAT8',
#  '1.2 PureTech 130ch S\\u0026S Allure Pack',
#  '1.2 PureTech 130ch S\\u0026S Allure Pack EAT8',
#  '1.2 PureTech 130ch S\\u0026S Allure EAT8',
#  '1.2 PureTech 130ch S\\u0026S Allure EAT8',
#  '1.5 BlueHDi 130ch S\\u0026S Active Pack EAT8',
#  '1.2 PureTech 130ch S\\u0026S GT EAT8',
#  '5P ACCESS 1.2L PureTech 82',
#  'Active BlueHDi 96kW (130CV) S&S EAT8',
#  '5P ACCESS 1.2L PureTech 82',
#  'TOP 1.0 VTi TOP! Collection Klima*Sitzhzg*LM',
#  '1.2 Navi PDC Klima Temp',
#  '1.0 VTi Allure Klimaautom.*Sitzhzg.*LM*',
#  '1.0 Filou 70 Klimaanlage, incl. Winterräder',
#  '1.0 VTi TOP! Collection Schiebedach',
#  '1.6 THP 270CH GTI S\\u0026S 5P COUPE FRANCHE',
#  'HYBRID4 360ch e-EAT8 PEUGEOT SPORT ENGINEERED',
#  'Allure FLA SpurH LM KAM LED Navi SD elSitz',
#  '1.2 PureTech 130ch S\\u0026S GT EAT8',
#  '308 ALLURE PACK 1.5 BlueHDi 130  EAT8  PARK ASSIT+',
#  '5P Allure Pack Puretech 130 S&S MAN',
#  'BlueHDi 160ch S\\u0026S Allure EAT8',
#  '1.2 PureTech 82ch Active 5p',
#  '2.0 BlueHDi 180ch FAP Féline EAT6',
#  'PHEV 225ch GT Pack e-EAT8',
#  '1.0 PureTech Like 3p',
#  'HYBRID 225ch GT e-EAT8 10cv',
#  'BlueHDi 130ch S\\u0026S Allure EAT8 7cv',
#  '1.9 TD GREEN 5P',
#  '1.5 BlueHDi 130ch S\\u0026S Allure Pack EAT8',
#  'e-208 136ch Allure',
#  'BlueHDi 180ch S\\u0026S GT EAT8',
#  'HYBRID4 360ch e-EAT8 PEUGEOT SPORT ENGINEERED',
#  'HYBRID4 360ch e-EAT8 PEUGEOT SPORT ENGINEERED',
#  '1.2 PureTech 130ch S\\u0026S Allure Pack EAT8',
#  '2.0 BlueHDi 180ch S\\u0026S GT EAT8',
#  'BlueHDi 160ch S\\u0026S GT Line EAT8',
#  'BlueHDi 130ch S/S Allure EAT8',
#  '1.2 PureTech 130ch S\\u0026S Allure Pack',
#  '1.4 HDI70 URBAN 3P',
#  '2.0 BlueHDi 150ch Allure GAR 1an',
#  '1.2 PureTech 130ch S\\u0026S GT Line EAT8 7cv',
#  'e-208 136ch GT Pack',
#  'e-208 136ch Active',
#  '1.5 BlueHDi 130ch S\\u0026S GT Line EAT8 7cv',
#  'BlueHDi 130ch S\\u0026S Active Pack EAT8',
#  '5P Active Pack PureTech 130 S&S EAT8',
#  'HYBRID 225ch Allure e-EAT8',
#  'e-208 136ch GT',
#  'PureTech 180ch S\\u0026S GT Line EAT8',
#  '1.6 THP 16v 165ch Allure S\\u0026S',
#  'e-208 136ch GT',
#  'PHEV 225ch GT Pack e-EAT8',
#  '1.2 PT 130 Allure Pack ACC Geschwindigkeit.',
#  '1.6 BlueHDi 120ch Active Business S\\u0026S EAT6 5p',
#  'e-208 136ch GT Line',
#  'puretech 68ch bvm5',
#  'e-208 136ch Style',
#  'BlueHDi 130ch S\\u0026S Active Business EAT8 7cv',
#  'HYBRID 225ch GT Pack e-EAT8',
#  '1.2 PureTech 110ch GT Line S\\u0026S 3p',
#  '1.6 BlueHDi 120ch S\\u0026S GT Line EAT6',
#  'BEV HB E ICON 87KW 118CV',
#  '1.3 MJet 95cv Cargo Base N1',
#  '500e 87Kw Icon',
#  '1.2 Lounge',
#  '1.3 Mjt Cross 4x4 E5+',
#  '1.0 Hybrid Dolcevita 52kW',
#  'e 95ch Action Plus',
#  'Abarth 595 Tourismo 1.4 Turbo-Jet 165 BVA',
#  '1.6 MultiJet 120ch Lounge S/S DCT 5p',
#  '1.0 FireFly Turbo 100ch S/S Life Plus 5p GPS Camer',
#  '1.6 MultiJet 120ch Easy 4p GPS Camera',
#  '1.6 Multijet II Business',
#  '1.3 Multijet 16v 95ch DPF S/S Lounge TPano GPS Rad',
#  'Dynamic 1.4 16v Starjet 95',
#  'e 118ch Passion',
#  '1.2 8v 69ch Popstar',
#  '1.0 HYBRID DOLCEVITA KM ZERO UFFICIALE!',
#  '1.3 Multijet II Mirror',
#  '0.9 8v TwinAir 105ch S/S S',
#  'RED 24 kWh Airco',
#  '110F',
#  nan,
#  '1.2 8v 69ch S',
#  '1.2 8v 69ch S\\u0026S Lounge  Euro6D',
#  'C 69 LOUNGE 1,2',
#  '1.3 Multijet 16v 95ch DPF S\\u0026S Lounge 97g',
#  'GIANNINI',
#  '1.4 95ch S/S Lounge MY19 5p GPS Camera',
#  '1.0 70ch BSG S\\u0026S Dolcevita TPano Radar Ar',
#  '1.0 70ch BSG S\\u0026S Dolcevita TPano Radar ar',
#  '500Ce 87Kw Icon',
#  'Sport1.0GSE+Navi+PDC hi+Klimaut+Alu16+Beats',
#  'Sport1.0GSE+Navi+PDC hi+Klimaut+Alu16+Beats',
#  '1.2 Star Dualogic+16J+TFT+Apple!',
#  '1.2 Star Dualogic+Sitzheizung+Apple!',
#  '1.0 Star Mild Hybrid Apple+Klimaautomatik+PDC!',
#  '1.0 70ch BSG S\\u0026S Dolcevita',
#  '1.0 Hybrid Dolcevita 52kW',
#  '1973 FIAT COUPE',
#  'S COUPE',
#  '1500 VIGNALE 1Â° SERIE',
#  'Lombardy my car sporting very rare',
#  'NAVI KLIMA MFL',
#  '1.3 MultiJet Lounge 95cv S&S EU6 5 PORTE BERLINA',
#  'Cross 1.6 MultiJet 88kW (120CV) 4x2',
#  'Sport 1.3 Firefly T4 110KW S&S DCT',
#  '1.MULTIJET URBAN FWD',
#  '2.0Mjt City Cross 4x4 103kW',
#  '1.MULTIJET URBAN FWD',
#  'Urban 1.3 MultiJet 70KW (95 CV) 4x2 S&S',
#  '1.6 Multijet 16v 120ch Lounge DCT',
#  '1.6 Multijet 120ch Lounge DCT',
#  '1.6 Multijet 16v 120ch Club DCT',
#  '1.6 Multijet 16v 120ch S-Design DCT',
#  '1.3 FireFly Turbo T4 150ch by Harcourt DCT 139g',
#  '1.6 Multijet 130ch Cross GPS Radar Av/Ar Car Play',
#  '1.0 FireFly Turbo T3 120ch Urban',
#  '1.3 FireFly Turbo T4 150ch Sport DCT',
#  '1.3 FireFly Turbo T4 150ch Cross DCT',
#  '1.6 Multijet 120ch Cross GPS Camera Car Play Keyle',
#  '1.6 MultiJet 130ch S/S Plus GPS Camera Car Play',
#  '1.0 FireFly Turbo T3 120ch Connect Edition',
#  '1.6 Multijet 16v 120ch S-Design GPS Radar Ar S/S',
#  '1.6 Multijet 130ch Sport TOuvrant Pano GPS Camera ',
#  '1.4 MultiAir 16v 140ch Popstar',
#  '1.0 FireFly Turbo T3 120ch S-Design',
#  '1.3 FireFly Turbo T4 150ch Cross DCT',
#  '1.6 Multijet 120ch City Cross',
#  '1.6 Multijet 120ch City Cross GPS Camera',
#  '1.0 T3 Urban 120cv',
#  '1.0 FireFly Turbo 100ch S/S GPS Radar AR',
#  '1.3 Multijet 95ch Opening Edition GPS Camera Apple',
#  '1.3 MJT Pick-up / PREZZO IVA ESCLUSA',
#  '1.4 MultiAir 16v 140ch Lounge',
#  'Red 1.5 Hybrid 97kW (130cv) DCT',
#  'Red 1.5 Hybrid 97kW (130cv) DCT',
#  'Sport 1.3 Firefly T4 110KW S&S DCT',
#  'Dolcevita SS Edition 1.0 Firefly T3 88KW',
#  '1.6 E-Torq Pop 4x2 81kW',
#  '1.6 E-Torq Pop 4x2 81kW',
#  'Pop Star Org.12600 KM',
#  'Sport 1,0 Firefly T3 88KW (120 CV) S&S',
#  'Cross 1.6 Mjet 96KW (130 CV) S&S',
#  'Sport 1,0 Firefly T3 88KW (120 CV) S&S',
#  'Sport 1,0 Firefly T3 88KW (120 CV) S&S',
#  'Lounge 1,0 Firefly T3 88KW (120 CV) S&S',
#  'Sport 1,0 Firefly T3 88KW (120 CV) S&S',
#  '1.6 E-Torq Pop 4x2 81kW',
#  'SW 1.6 Multijet II Easy',
#  '1.6 Multijet  Business Nav RKam Shz DAB EU6d-T',
#  '1.5 FireFly Turbo 130ch S/S Dolcevita Special Edit',
#  '1.5 FireFly Turbo 130ch S/S Sport Pack Hybrid DCT7',
#  'SW 1.6 Multijet II Easy',
#  '1.3 mjt 16v Lounge 80cv',
#  '1.5 FireFly Turbo 130ch S/S Sport Pack Hybrid DCT7',
#  '1.6 MultiJet 120ch Lounge S/S DCT MY20',
#  'station wagon 1,4 t-jet 120cv gpl easy 2017 sw',
#  '1.6 Multijet 130ch Yacht Club Capri',
#  'SW 1.6 Multijet II Mirror DDCT',
#  '1.0 100 ch S/S sw cross Red MY22',
#  '1.0 FireFly Turbo 100ch S/S (RED) MY22',
#  '1.3 MultiJet 95ch Easy S/S MY19 LED GPS Camera Car',
#  '1.3 MultiJet 95ch Ligue 1 Conforama S/S MY19',
#  'STATION WAGON 1.0 100cv CityLife',
#  '1.5 FireFly Turbo 130ch S/S Sport Pack Hybrid DCT7',
#  '1.3 Mjt S&S SW Pop',
#  'Urban 1.6 16v Multijet II 120CV S&S',
#  'SW 1.6 Multijet II Pop Business',
#  'Pop Star 1.3 16v Multijet II 95CV auto.',
#  'Urban 1.6 16v Multijet II 120CV S&S',
#  'SW 1.6 Multijet II Lounge',
#  'Pop Star 1.3 16v Multijet II 95CV auto.',
#  'SW 1.3 Multijet II Mirror',
#  'SW 1.3 Multijet 70kW (95CV) Mirror',
#  'SW 1.3 Multijet II Mirror',
#  'Kombi 1.0 T3 Life',
#  'SW 1.0 Life',
#  '1.4 16v 70kW (95CV) Cross',
#  'Hatchback 1.4 *Kam*Navi*Temp*Klima*',
#  '1.2 8v 69 CV Lounge',
#  'City Cross 1.0 LED APPLECAR ANDROID RFK DAB',
#  '1.2 Lounge 69cv EU6',
#  '1.2 Lounge 69cv EU6',
#  'e 118ch La Prima',
#  '4 porte II 2016 4p 1.6 mjt Lounge 120cv',
#  'e 118ch La Prima by Bocelli 3+1',
#  '1.4 95ch Pop 5p',
#  '1.5 FireFly Turbo 130ch S/S Plus Hybrid DCT7 MY22',
#  'e 118ch La Prima by Bocelli',
#  'Ritmo 130 TC 3 porte Abarth',
#  '1.4 95ch Easy 4p',
#  'III 2012 1.3 mjt Street s&s 95cv 5p',
#  'e 118ch La Prima',
#  '1.6 Mjt S&S 5 porte Red',
#  '5p Street 1.3 multijet 95cv s&s 5 porte - e',
#  '4 porte II 2016 4p 1.3 mjt Easy 95cv my17',
#  '1.4 95ch Pop 4p',
#  '1.4 95ch Tipo MY19 5p',
#  '1.6 MultiJet 120ch Mirror S/S MY19 5p',
#  '1.4 95ch S/S Elysia MY20 5p',
#  '1.6 MultiJet 120ch Pop S/S 5p',
#  'HATCHBACK LIFE',
#  '5p Street 1.3 multijet 95cv s&s 5 porte - e',
#  '1.3 mjt 16v 4x4 s&s 95cv',
#  '1.6TDI CR S&S Reference 115',
#  '1.4 EcoTSI ACT 150ch FR Start/Stop',
#  '2.0TDI S&S Xcellence 150',
#  '2.0 TDI 150ch FAP Premium Start/Stop',
#  '1.0 MPI S&S Style - Navigation, DAB+ Alufelgen',
#  '1.2 TSI 110ch Reference S/S',
#  '1.6TDI CR S&S Reference Plus 115',
#  '1.6TDI CR Style DPF',
#  'Style',
#  '1.2 tdi 75 ch',
#  '2.0 TDI DSG FR*LED*Navi*Beats*Tempo*PDC*Climatroni',
#  '2.0 TDI 150ch Style 4Drive DSG7 7 places',
#  'FR 1,0TSI 115PS 3*J.Gar/LED/Navi/Parkas.',
#  '2.0 TDI DSG Style',
#  '1.0 TSI 110ch FR DSG7',
#  'ST 2.0 TSI 221kW 4Drive DSG S&S Cupra R',
#  'ST Cupra300 4Drive-LED-Pano-Navi-beats-RFK-',
#  '2.0 TSI 300ch Cupra DSG Toit ouvrant GPS Radar AV/',
#  'Sportstourer FR 1.5 eTSI DSG VollLED/Navi/Rückf',
#  '2.0 TSI 290ch Cupra DSG7',
#  'ST CNG 1.5 TGI Style | CNG en Benzine | Navi | LED',
#  'Ibiza STChili&Style1,2TSI Finanzierung möglich!',
#  '2.0 TSI 300ch Cupra 4Drive DSG7 Euro6d-T',
#  '1.8 TSI 180ch Start\\u0026Stop 4DRIVE DSG',
#  'ST 1.4 TSI Start&Stop Style',
#  'ST 2.0 TSI 221kW 4Drive DSG S&S Cupra R',
#  'ST 2.0TDI CR Reference 143',
#  '2.0 TSI Cupra S&S',
#  '1.4 TSI ACT FR * NAVI * VOLL-LED * WINTERPAKET * P',
#  'Ibiza Xcellence 1,6 TDI, Navi, PDC, Keyless',
#  '3ª serie 1.6 TDI 105 CV 5p. Start/Stop Style',
#  '1.5 eTSI 150ch FR DSG7',
#  '1.0 EcoTSI 110ch FR DSG7',
#  '1.0 EcoTSI 115ch Start/Stop FR Euro6d-T',
#  '1.5 eTSI 150ch FR DSG7',
#  'Fun 1.0 MPI Klima,FSE, Bluetooth, MP3-Radio',
#  'Cool Edition DAB Klima Allwetter Radio ZV',
#  '1.9TDI Classic',
#  '1.5 TSI Ambition 4x2 110kW',
#  '1.0 MPI 60ch Drive 125 ans Euro6d-T 3cv',
#  'Pequeño Manual de 2 Puertas',
#  '2.0TDI RS DSG',
#  '2.0TDI RS DSG',
#  'DIESEL',
#  'Combi 2.0TDI CR Style',
#  '1.5 TSI 110kW (150CV) DSG STYLE',
#  '1.5 TSI 110KW (150CV) Like',
#  '1.5 TSI 110KW (150CV) Like',
#  '1.0 TSI Ambition 81kW',
#  '1.5 TSI 150ch Monte-Carlo DSG7 Euro6d-T EVAP',
#  '1.4 TSI ACT 150ch Style',
#  '1.4 TSI PHEV iV 245ch RS DSG6e Euro6d-AP',
#  '1.6 TDI 116ch SCR Active Euro6d-T',
#  'Stepway TCe Comfort 67kW',
#  '1.5 dCi 75ch Ambiance',
#  '1.0 SCe 75ch Access - 19',
#  '1.0 SCe 75ch Confort - 19',
#  '1.0 SCe 75 Essentiel',
#  '1.5dCi Ambiance 75',
#  '1.5dCi Laureate 66kW',
#  '1.2 Ambiance 75',
#  '1.2 Base 75',
#  '1.5 Blue dCi Stepway Comfort 70kW',
#  '1.5dCi Ambiance 75',
#  '1.5 Blue dCi 115cv 7Pl - 18 Comfort',
#  '1.5dCi Ambiance 75',
#  '1.2 Ambiance',
#  'Van Ambiance dCi 90 EU6',
#  '1.5 Blue dCi Stepway Essential 70kW',
#  '1.2 Base 75',
#  '0.9 TCE SL Trotamundos 66kW',
#  '1.2 Base',
#  '0.9 TCE Laureate 66kW',
#  'SCe 75 Acces sofort lieferbar',
#  '1.5dCi Laureate 90',
#  '1.2 Laureate 75',
#  '1.5 Blue dCi Prestige 4x2 85kW',
#  '1.5 Blue dCi Prestige 4x2 85kW',
#  'Confort Plus - Achat Intégral Camera GPS',
#  '1.5 dCi 110ch Black Touch 4X2',
#  '1.0 ECO-G 100ch Evasion',
#  'DUSTER 1.3  TCE 150 EDC PRESTIGE +  2WD CAMERA 360',
#  'DUSTER 1.3  TCE 150 EDC PRESTIGE +  2WD CAMERA 360',
#  '1.5 Blue dCi 115ch Prestige 108g 4x2 - 19',
#  '1.5 dCi 110ch Prestige 4X2 Camera GPS',
#  '1.2 TCe 125ch Prestige 4X2',
#  '1.5 dCi 110ch Prestige 4X2 EDC',
#  '1.5 dCi 90ch Silver Line 2017 4X2',
#  'blue dci 115 4x2',
#  '1.5 Blue dCi 115ch Prestige 4x2',
#  '0.9 TCe 90ch Stepway',
#  'blue dci 115 4x2',
#  '1.5 Blue dCi 115ch Prestige 108g 4x2 - 19',
#  '1.0 ECO-G 100ch 15 ans 4x2 - E6U',
#  '1.5 dCi 110ch Black Touch 2017 4X2',
#  '1.3 TCe 130ch FAP Essentiel 4x2',
#  '1.5 dCi 110ch Black Touch 2017 4X2',
#  '1.5 Blue dCi 115ch Prestige 4x2 - 20',
#  '1.2 TCe 125ch Prestige 4X2 GPS Radar Ar',
#  '0.9 TCe 90ch Stepway Camera GPS',
#  '1.5 Blue dCi 115ch Prestige 4x2',
#  '1.5 dCi 110ch Prestige 4X2',
#  '1.5 dCi 110ch Prestige 4X2 EDC',
#  'blue dci 115 4x2',
#  '1.5 dCi 110ch SL 10 ans 4X2',
#  '1.0 ECO-G 100ch Prestige + 4x2',
#  'blue dci 115 4x2',
#  '1.5 Blue dCi 115ch Essentiel 4x2',
#  '1.5 Blue dCi 95ch 4x2',
#  '1.5 dCi 110ch Prestige 4X2',
#  '1.5 dCi 110ch Prestige 4X2 GPS Camera',
#  '1.0 SCe 75ch Urban Stepway -18',
#  '1.2 TCe 125ch Confort 4X2',
#  '1.5 dCi 110ch Confort 4X2 EDC',
#  '1.5 Blue dCi 115ch Prestige 4x2 - 20',
#  'blue dci 115 4x2',
#  '1.5 Blue dCi 115ch Techroad 4x2',
#  '1.5 Blue dCi 115ch Prestige 4x2 E6U',
#  '1.3 TCe 150ch FAP Prestige 4x2 EDC',
#  '1.5 Blue dCi 115ch Prestige 4x2',
#  '1.5 Blue dCi 115ch Techroad 4x2',
#  'dCi 110 EDC 4x2 Explorer',
#  '1.5 Blue dCi 115ch Prestige 4x2 - 20',
#  '1.3 TCe 150ch FAP Prestige  4x2 - 20',
#  '1.5 dCi 110ch Black Touch 2017 4X2 EDC',
#  '1.5 Blue dCi 115ch Prestige 4x4',
#  'dCi 110 EDC 4x2 Black Touch 2017',
#  '1.3 TCe 150ch FAP Prestige 4x2',
#  '1.3 TCe 150ch FAP Prestige 4x2 EDC',
#  '1.3 TCe 150ch FAP Prestige 4x2',
#  '1.5Blue dCi Essential 4x4 85kW',
#  '1.5 dCi 110ch Black Touch 4X4',
#  '1.0 TCe 100ch Stepway',
#  '1.5 dCi 110 4x4 Tarif HT',
#  '1.5 Blue dCi Comfort 4x4 85kW',
#  '1.5 Blue dCi Comfort 4x4 85kW',
#  '1.5Blue dCi Prestige 4x4 85kW',
#  '1.5 Blue dCi Comfort 4x2 85kW',
#  '1.5Blue dCi Prestige 4x2 85kW',
#  '1.5Blue dCi Comfort 4x2 85kW',
#  '1.5 dCi 90ch Blackline',
#  '1.5dCi SL Nómada 66kW',
#  '1.5 DCI 110CH PRESTIGE 4X4 EURO6',
#  '1.5 Blue dCi 95ch Stepway - 20',
#  'MCV 1.2 16V 75 Ambiance',
#  '1.3 TCe SL Xplore',
#  'Break 1.5dCi Laureate 7pl. 85',
#  '1.3 TCe SL Xplore',
#  '1.3 TCe SL Xplore',
#  '1.3 TCe SL Xplore',
#  '1.3 TCe SL Xplore',
#  'MCV 0.9 TCe 90 CV S&S Lauréate',
#  '1.5 dCi 110cv Laureate 5p 7plz # BLUETOOTH,LIBRO R',
#  '1.5 dCi 110cv Laureate 5p 7plz # BLUETOOTH,LIBRO R',
#  'Stepway 1.6 75kW (100CV) 7Pl - 18',
#  '1.5 BLUE DCI 115CH PRESTIGE 4X2 - 20',
#  '1.5 BLUE DCI 115CH EXTREME 4X4',
#  '1.5 BLUE DCI 115CH EXTREME 4X4',
#  '1.5 BLUE DCI 115CH CONFORT 4X4 E6U',
#  '1.5 DCI 110CH PRESTIGE 4X2 EURO6',
#  '1.5 DCI 85CH AMBIANCE 4X2',
#  '1.3 TCE 150CH FAP CONFORT 4X2 EDC',
#  '1.5 DCI 90CH FAP 4X2',
#  '1.5 DCI 110CH LAUREATE PLUS 4X2',
#  'Laureate TCE 66kW (90CV)',
#  'Laureate TCE 66kW (90CV)',
#  'Laureate TCE 66kW (90CV)',
#  'Laureate TCE 66kW (90CV)',
#  'Laureate TCE 66kW (90CV)',
#  'Laureate TCE 66kW (90CV)',
#  'Laureate TCE 66kW (90CV)',
#  'Laureate TCE 66kW (90CV)',
#  'Laureate TCE 66kW (90CV)',
#  'Laureate TCE 66kW (90CV)',
#  'Laureate TCE 66kW (90CV)',
#  'Laureate TCE 66kW (90CV)',
#  'Laureate TCE 66kW (90CV)',
#  'Laureate TCE 66kW (90CV)',
#  'Laureate TCE 66kW (90CV)',
#  'Laureate TCE 66kW (90CV)',
#  '1.5 Blue dCi 75ch Confort',
#  '1.5 dCi 75ch Ambiance',
#  'Stepway 1.6 8V 85CV',
#  '0.9 TCe 90ch Stepway Easy-R',
#  '1.0 SCe 75ch 4cv',
#  'Laureate TCE 66kW (90CV)',
#  '0.9 TCe 90ch Stepway',
#  '0.9 TCe 90ch Ambiance Euro6c',
#  '1.5 dCi 90ch Stepway',
#  'tce 90',
#  '0.9 TCe 90ch Stepway',
#  '0.9 TCe 90ch Stepway Easy-R -18',
#  '1.5 dCi 75ch Ambiance',
#  '1.0 SCe 75ch Ambiance 4cv',
#  'tce 90',
#  'Ambiance dCi 55kW (75CV)',
#  '0.9 TCe 90ch Confort',
#  '0.9 TCe 90ch Techroad',
#  '0.9 TCe 90ch Techroad',
#  'Laureate TCE 66kW (90CV)',
#  '0.9 TCe 90ch Advance Euro6c',
#  '1.0 SCe 75ch Evasion',
#  '1.0 TCe 90ch Stepway Confort -22',
#  '1.0 TCe 90ch Stepway Confort -22',
#  '1.0 ECO-G 100ch Stepway Confort -22',
#  'Stepway 0.9 TCe 12V 90 CV Start&Stop',
#  'Laureate TCE 66kW (90CV)',
#  'Laureate TCE 66kW (90CV)',
#  'Laureate TCE 66kW (90CV)',
#  'Stepway TCE 66kW (90CV)',
#  'Stepway TCE 66kW (90CV)',
#  'Stepway TCE 66kW (90CV)',
#  'Stepway TCE 66kW (90CV)',
#  '1.2 SL Eficacia',
#  '1.2 16v 75cv Ambiance 4p',
#  '1.2 16v 75cv Ambiance 4p',
#  '1.2 SL Eficacia',
#  '1.2 SL Eficacia',
#  'Stepway TCE 90 EU6',
#  'Stepway TCE 90 EU6',
#  'Stepway TCE 90 EU6',
#  '1,0l Pulse neues Modell AYGO X 2022',
#  '1,0 x-play X-Business-Paket, Klima., ZV',
#  '1.0 70 x-play',
#  '1.0 70 x-wave',
#  '1.0 70 x-wave',
#  '1.0 70 x-wave',
#  '1.0 70 x-wave',
#  '1.0 70 x-wave',
#  '1.0 70 x-wave',
#  '1.0 70 x-wave',
#  '1.0 70 x-wave',
#  '1.0 70 x-wave',
#  '1.0 70 x-wave',
#  '1.0 70 x-wave',
#  '1.0 70 x-wave',
#  '1.0 70 x-wave',
#  '1.0 70 x-wave',
#  '1.0 70 x-wave',
#  '1.0 70 x-wave',
#  'CoolBlue',
#  '1.0 VVT-i 69ch x-play 5p',
#  '1,5-Dual-VVT-iE Team Deutschland',
#  '1.2 Turbo 116ch Design RC18 GPS Camera',
#  '1,5-Dual-VVT-iE Team Deutschland',
#  'MR Design Tipptronik',
#  '1.8-16v VVT-i',
#  'Cabriolet 1.5',
#  '140 VVT-i SMT bva',
#  'Cabriolet 1.5',
#  'COUPE 2.0 D-4S 200 BVA PACK TRD',
#  '3.0 340ch GR LEGEND PREMIUM PACK Camera GPS Sieges',
#  'WAGON Hybrid Business',
#  '/ W2 Targa',
#  '1.8',
#  'GR 2.0 Pure',
#  'MK4 see full spec list 1256 HP hi boost',
#  'MR2 Roadster 1.8',
#  '122h EDITION 2WD MY22',
#  ...]

# %%
# it is concluded that manufacturer colour and colour of an automobile directly related.
# since manufacturer colours has been entered in local languaages of manufacturer countries reclass has been performed.
color_dict = {
    "Black": ["negro", "preto", "schwarz", "zwart", "nero", "onyx schwarz", "obsidianschwarz", "noir", "scharz", "zwarte"],
    "Blue": ["azul", "blau", "blauw", "azul medianoche", "tiefsee blau", "blu", "denim blue", "blauw metallic", "race-blau metallic", "race-blau", "dark knight", "azul marino"],
    "Yellow": ["amarillo", "geel"],
    "Gray": ["gris", "grijs", "grau", "grijs metallic", "schwarz metallic", "gris plata", "quarz-grau metallic", "selenitgrau", "licht grau", "graphitgrau", "granate", "stahlgrau", "kosmosschwarz", "titan-grau", "grafitgrau", "graumet.", "gris oscuro", "gris clara"],
    "Red": ["rojo", "rosso", "race-rot", "rot", "lava rot", "desire rot", "reinrot", "ruby rot", "corrida-rot", "power red", "roz"],
    "White": ["blanco", "wit", "weiss", "perlmutt-weiss", "schneeweiß", "weiss metallic", "magnetic-tech", "polarweiß", "blanc nacre", "blanc", "ice white", "laser-weiss", "candy weiss", "business grau", "arctic white", "candy-weiss", "ice white", "niebieski", "biały"],
    "Silver": ["plata", "silber", "argent", "platin-grau", "argent", "argentato", "platinsilber", "plata metalizado", "plateado", "argent silber", "zilver metallic", "zilver"],
    "Green": ["verde", "grün", "groen", "green", "verde oscuro"],
    "Brown": ["marrón", "bruin", "braun"],
    "Orange": ["naranja", "oranje"],
    "Purple": ["morado", "paars"],
    "Pink": ["rosa", "roze"],
    "Beige": ["beige"],
    "Gold": ["oro", "goud"],
    "Bronze": ["bronce"],
}

# %%
# manufacturer column has been cleaned and only name of the color has been extracted.
pattern = "(" + "|".join([re.escape(color) for colors in color_dict.values() for color in colors]) + ")"

# %%
match = df.manufacturer_colour.str.extract(pattern, flags=re.IGNORECASE)[0]
match
# Out:
# 0               NaN
# 1             Negro
# 2              grau
# 3          Amarillo
# 4               NaN
#             ...
# 29474           NaN
# 29475         Grijs
# 29476           NaN
# 29477    Denim Blue
# 29478         Grijs
# Name: 0, Length: 28602, dtype: object

# %%
# colours in multiple languages has been matched in one type.
for category, keywords in color_dict.items():
    for keyword in keywords:
        result = df.loc[df[df["colour"].isnull()].index, "manufacturer_colour"].str.contains(f"(?i){keyword}")
        print(f"{category} {keyword}: {result.value_counts()}")
# Out:
# Black negro: False    1390
# True       83
# Name: manufacturer_colour, dtype: int64
# Black preto: False    1473
# Name: manufacturer_colour, dtype: int64
# Black schwarz: False    1468
# True        5
# Name: manufacturer_colour, dtype: int64
# Black zwart: False    1473
# Name: manufacturer_colour, dtype: int64
# Black nero: False    1463
# True       10
# Name: manufacturer_colour, dtype: int64
# Black onyx schwarz: False    1472
# True        1
# Name: manufacturer_colour, dtype: int64
# Black obsidianschwarz: False    1473
# Name: manufacturer_colour, dtype: int64
# Black noir: False    1344
# True      129
# Name: manufacturer_colour, dtype: int64
# Black scharz: False    1473
# Name: manufacturer_colour, dtype: int64
# Black zwarte: False    1473
# Name: manufacturer_colour, dtype: int64
# Blue azul: False    1418
# True       55
# Name: manufacturer_colour, dtype: int64
# Blue blau: False    1462
# True       11
# Name: manufacturer_colour, dtype: int64
# Blue blauw: False    1473
# Name: manufacturer_colour, dtype: int64
# Blue azul medianoche: False    1449
# True       24
# Name: manufacturer_colour, dtype: int64
# Blue tiefsee blau: False    1473
# Name: manufacturer_colour, dtype: int64
# Blue blu: False    1449
# True       24
# Name: manufacturer_colour, dtype: int64
# Blue denim blue: False    1470
# True        3
# Name: manufacturer_colour, dtype: int64
# Blue blauw metallic: False    1473
# Name: manufacturer_colour, dtype: int64
# Blue race-blau metallic: False    1473
# Name: manufacturer_colour, dtype: int64
# Blue race-blau: False    1473
# Name: manufacturer_colour, dtype: int64
# Blue dark knight: False    1471
# True        2
# Name: manufacturer_colour, dtype: int64
# Blue azul marino: False    1473
# Name: manufacturer_colour, dtype: int64
# Yellow amarillo: False    1473
# Name: manufacturer_colour, dtype: int64
# Yellow geel: False    1473
# Name: manufacturer_colour, dtype: int64
# Gray gris: False    1193
# True      280
# Name: manufacturer_colour, dtype: int64
# Gray grijs: False    1473
# Name: manufacturer_colour, dtype: int64
# Gray grau: False    1463
# True       10
# Name: manufacturer_colour, dtype: int64
# Gray grijs metallic: False    1473
# Name: manufacturer_colour, dtype: int64
# Gray schwarz metallic: False    1473
# Name: manufacturer_colour, dtype: int64
# Gray gris plata: False    1473
# Name: manufacturer_colour, dtype: int64
# Gray quarz-grau metallic: False    1473
# Name: manufacturer_colour, dtype: int64
# Gray selenitgrau: False    1473
# Name: manufacturer_colour, dtype: int64
# Gray licht grau: False    1473
# Name: manufacturer_colour, dtype: int64
# Gray graphitgrau: False    1473
# Name: manufacturer_colour, dtype: int64
# Gray granate: False    1469
# True        4
# Name: manufacturer_colour, dtype: int64
# Gray stahlgrau: False    1473
# Name: manufacturer_colour, dtype: int64
# Gray kosmosschwarz: False    1473
# Name: manufacturer_colour, dtype: int64
# Gray titan-grau: False    1473
# Name: manufacturer_colour, dtype: int64
# Gray grafitgrau: False    1473
# Name: manufacturer_colour, dtype: int64
# Gray graumet.: False    1473
# Name: manufacturer_colour, dtype: int64
# Gray gris oscuro: False    1470
# True        3
# Name: manufacturer_colour, dtype: int64
# Gray gris clara: False    1473
# Name: manufacturer_colour, dtype: int64
# Red rojo: False    1461
# True       12
# Name: manufacturer_colour, dtype: int64
# Red rosso: False    1469
# True        4
# Name: manufacturer_colour, dtype: int64
# Red race-rot: False    1473
# Name: manufacturer_colour, dtype: int64
# Red rot: False    1465
# True        8
# Name: manufacturer_colour, dtype: int64
# Red lava rot: False    1473
# Name: manufacturer_colour, dtype: int64
# Red desire rot: False    1473
# Name: manufacturer_colour, dtype: int64
# Red reinrot: False    1473
# Name: manufacturer_colour, dtype: int64
# Red ruby rot: False    1473
# Name: manufacturer_colour, dtype: int64
# Red corrida-rot: False    1473
# Name: manufacturer_colour, dtype: int64
# Red power red: False    1473
# Name: manufacturer_colour, dtype: int64
# Red roz: False    1472
# True        1
# Name: manufacturer_colour, dtype: int64
# White blanco: False    1313
# True      160
# Name: manufacturer_colour, dtype: int64
# White wit: False    1472
# True        1
# Name: manufacturer_colour, dtype: int64
# White weiss: False    1464
# True        9
# Name: manufacturer_colour, dtype: int64
# White perlmutt-weiss: False    1473
# Name: manufacturer_colour, dtype: int64
# White schneeweiß: False    1472
# True        1
# Name: manufacturer_colour, dtype: int64
# White weiss metallic: False    1473
# Name: manufacturer_colour, dtype: int64
# White magnetic-tech: False    1473
# Name: manufacturer_colour, dtype: int64
# White polarweiß: False    1473
# Name: manufacturer_colour, dtype: int64
# White blanc nacre: False    1465
# True        8
# Name: manufacturer_colour, dtype: int64
# White blanc: False    1161
# True      312
# Name: manufacturer_colour, dtype: int64
# White ice white: False    1470
# True        3
# Name: manufacturer_colour, dtype: int64
# White laser-weiss: False    1473
# Name: manufacturer_colour, dtype: int64
# White candy weiss: False    1472
# True        1
# Name: manufacturer_colour, dtype: int64
# White business grau: False    1473
# Name: manufacturer_colour, dtype: int64
# White arctic white: False    1473
# Name: manufacturer_colour, dtype: int64
# White candy-weiss: False    1473
# Name: manufacturer_colour, dtype: int64
# White ice white: False    1470
# True        3
# Name: manufacturer_colour, dtype: int64
# White niebieski: False    1473
# Name: manufacturer_colour, dtype: int64
# White biały: False    1473
# Name: manufacturer_colour, dtype: int64
# Silver plata: False    1458
# True       15
# Name: manufacturer_colour, dtype: int64
# Silver silber: False    1471
# True        2
# Name: manufacturer_colour, dtype: int64
# Silver argent: False    1467
# True        6
# Name: manufacturer_colour, dtype: int64
# Silver platin-grau: False    1473
# Name: manufacturer_colour, dtype: int64
# Silver argent: False    1467
# True        6
# Name: manufacturer_colour, dtype: int64
# Silver argentato: False    1473
# Name: manufacturer_colour, dtype: int64
# Silver platinsilber: False    1472
# True        1
# Name: manufacturer_colour, dtype: int64
# Silver plata metalizado: False    1473
# Name: manufacturer_colour, dtype: int64
# Silver plateado: False    1467
# True        6
# Name: manufacturer_colour, dtype: int64
# Silver argent silber: False    1473
# Name: manufacturer_colour, dtype: int64
# Silver zilver metallic: False    1473
# Name: manufacturer_colour, dtype: int64
# Silver zilver: False    1473
# Name: manufacturer_colour, dtype: int64
# Green verde: False    1472
# True        1
# Name: manufacturer_colour, dtype: int64
# Green grün: False    1472
# True        1
# Name: manufacturer_colour, dtype: int64
# Green groen: False    1473
# Name: manufacturer_colour, dtype: int64
# Green green: False    1473
# Name: manufacturer_colour, dtype: int64
# Green verde oscuro: False    1473
# Name: manufacturer_colour, dtype: int64
# Brown marrón: False    1435
# True       38
# Name: manufacturer_colour, dtype: int64
# Brown bruin: False    1473
# Name: manufacturer_colour, dtype: int64
# Brown braun: False    1471
# True        2
# Name: manufacturer_colour, dtype: int64
# Orange naranja: False    1470
# True        3
# Name: manufacturer_colour, dtype: int64
# Orange oranje: False    1473
# Name: manufacturer_colour, dtype: int64
# Purple morado: False    1473
# Name: manufacturer_colour, dtype: int64
# Purple paars: False    1473
# Name: manufacturer_colour, dtype: int64
# Pink rosa: False    1471
# True        2
# Name: manufacturer_colour, dtype: int64
# Pink roze: False    1472
# True        1
# Name: manufacturer_colour, dtype: int64
# Beige beige: False    1461
# True       12
# Name: manufacturer_colour, dtype: int64
# Gold oro: False    1472
# True        1
# Name: manufacturer_colour, dtype: int64
# Gold goud: False    1473
# Name: manufacturer_colour, dtype: int64
# Bronze bronce: False    1473
# Name: manufacturer_colour, dtype: int64

# %%
# colours in multiple languages has been reclasses in one language.
# # aşağıdaki kod sadece bir key ekleyebiliyor . 

for category, keywords in color_dict.items():
    for keyword in keywords:
        result_indices =   df.loc[(df["colour"].isnull()) & (df["manufacturer_colour"].str.contains(f"(?i){keyword}"))].index
        df.loc[result_indices, "colour"] = category

# %%
# # colours in multiple languages has been reclasses in one language.

# index_no = df.loc[df["colour"].isnull() & df["manufacturer_colour"].notnull()].index

# for category, keywords in color_dict.items():
#     for keyword in keywords:
#         result_indices = index_no.intersection(df[df["manufacturer_colour"].str.lower().str.contains(keyword.lower(), na=False)].index)
#         df.loc[result_indices, "colour"] = df.loc[result_indices, "colour"].apply(lambda x: x + ", " + category if pd.notnull(x) else category)

# %%
handle_missing_values(df, "colour")
# Out:
# Missing Values in 'colour':
# Count: 677
# Percentage: 2.37%

# %%
df.location_country
# Out:
# 0        ES
# 1        ES
# 2        ES
# 3        ES
# 4        ES
#          ..
# 29474    ES
# 29475    NL
# 29476    BE
# 29477    NL
# 29478    NL
# Name: location_country, Length: 28602, dtype: object

# %%
# Since remaning nan values is 2.4 %,
# groupby has been perfomed according to model and location_country year and filled accordingly

# It has been conluded that location country has affect on owners judgement because of wheather conditions.
# After the groupby operation, how many NaN values do I have remaining?
df.colour.fillna(df.groupby(["location_country", "body_type"])["colour"].transform(lambda x: x.mode()[0])).isnull().sum()
# Out:
# 0

# %%
# Since remaning nan values is 2.4 %, groupby has been perfomed according to model and production year and filled accordingly
df.colour.fillna(df.groupby(["location_country", "body_type"])["colour"].transform(lambda x: x.mode()[0]), inplace = True)

# %%
handle_missing_values(df, "colour")
# Out:
# Missing Values in 'colour':
# Count: 0
# Percentage: 0.00%

# %%
df.colour.value_counts()
# Out:
# Black     7055
# Grey      6019
# White     5736
# Blue      3568
# Red       2263
# Silver    1645
# Brown      475
# Green      452
# Gray       352
# Orange     290
# Beige      289
# Yellow     230
# Violet      98
# Bronze      65
# Gold        63
# Pink         2
# Name: colour, dtype: int64

# %% [markdown]
# <a id="20"></a>
# <div class="alert alert-info" role="alert">
# <h1>Column name :<span style="color:red"> manufacturer_colour </span></h1>
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Operation : </b> To fill in the missing values in the "manufacturer_colour" column, we can use the "short_description" column . Since the "manufacturer_colour" column is associated with <span style="color:red"><b> " colour "</b></span> . let's fill in the <span style="color:red"><b> NaN values</b></span> in this column by grouping the data based on these columns and performing the necessary operations.
# </div>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
first_looking("manufacturer_colour")
# Out:
# column name    :  manufacturer_colour
# --------------------------------
# per_of_nulls   :  % 23.91
# num_of_nulls   :  6839
# num_of_uniques :  4174
# NaN                               6839
# Blanco                            1329
# Gris                               719
# Negro                              590
# Azul                               583
#                                   ...
# Colore Esterno Jet Black             1
# Colore Esterno (Arctic White (       1
# Colore Esterno (Giallo Ocra)         1
# Blu Venetia                          1
# Demin Blue                           1
# Name: manufacturer_colour, Length: 4175, dtype: int64

# %%
# paint, upholstey_colour

# %%
# Let's examine the short description of the seats
list(df.loc[df[df["manufacturer_colour"].isnull()].index, "short_description"])
# Out:
# ['CDi',
#  '200CDI BE Line 4M 7G-DCT',
#  '4MATIC',
#  '200CDI BE Line 4M 7G-DCT',
#  'e Limousine',
#  '4Matic+ 7G-DCT',
#  '180d 7G-DCT',
#  '180d Sedán 7G-DCT',
#  nan,
#  'S 4Matic+ 8G-DCT',
#  'CDI',
#  '4Matic 7G-DCT',
#  'Limousine',
#  nan,
#  '180d 7G-DCT',
#  '180d 7G-DCT',
#  '180d 7G-DCT',
#  '200CDI BE Style',
#  '200CDI BE Urban 7G-DCT',
#  nan,
#  '7G-DCT',
#  nan,
#  '200CDI BE AMG Line 7G-DCT',
#  '200d 7G-DCT',
#  'S 4MATIC+',
#  nan,
#  '4Matic+ 7G-DCT',
#  '300E',
#  'S 4Matic+ 8G-DCT',
#  'S Coupe Edition 1',
#  '4Matic 7G-DCT',
#  'AMG A 35 4MATIC',
#  '180CDI',
#  '180CDI Exclusive Edition',
#  'CDi',
#  'S 4Matic+ 8G-DCT',
#  '7G-DCT',
#  '-Edition BlueEfficiency',
#  '250e 8G-DCT',
#  'Classe A 1.9 116ch A 180 d',
#  '180d 7G-DCT',
#  '200d 7G-DCT',
#  'Classe A 1.5 109ch A 180 CDI BlueEfficiency',
#  'Classe A 1.5 116ch A 180 d',
#  'A Class 180 1.5 115ch A 180 d',
#  'Classe A 1.5 90ch A 160 CDI / d',
#  'Classe A 1.5 116ch A 180 d',
#  'Classe A 1.3 109ch A 160',
#  'S 4Matic+ 8G-DCT',
#  'BENZINA + GPL NUOVO + UNICO PROPRIEATARIO',
#  'd Progressive',
#  '4Matic 7G-DCT',
#  '220CDI BE AMG Sport 7G-DCT',
#  'd Premium',
#  '4Matic+ 7G-DCT',
#  '4Matic 7G-DCT',
#  '220CDI BE AMG Sport 7G-DCT',
#  '180CDI Elegance',
#  '7G-DCT',
#  '4Matic 7G-DCT',
#  '180CDI BE AMG Line 7G-DCT',
#  'S 4Matic+ 8G-DCT',
#  '4Matic 7G-DCT',
#  '4Matic+ 7G-DCT',
#  'Sedán 4Matic+ 7G-DCT',
#  'MERCEDES-BENZ Clase GLK Pequeño  Automático de 5',
#  '4Matic+ 7G-DCT',
#  '200d 8G-DCT',
#  '200CDI Avantgarde',
#  '4Matic+ 7G-DCT',
#  '4Matic 7G-DCT',
#  '180d 7G-DCT',
#  '180d',
#  '180CDI Polar Star',
#  'Pequeño Automático de 5 Puertas',
#  '4Matic+ 7G-DCT',
#  '4Matic+ 7G-DCT',
#  'e 8G-DCT AMG Line',
#  '7G-DCT',
#  '200d 7G-DCT',
#  'Edition 1 4Matic 7G-DCT',
#  '4Matic 7G-DCT',
#  '200CDI BE AMG Line 7G-DCT',
#  '7G-DCT',
#  '250e Sedán 8G-DCT',
#  '200d 8G-DCT',
#  '200d 8G-DCT',
#  'S 4Matic+ 8G-DCT',
#  '7G-DCT',
#  '200d 8G-DCT',
#  '180d 8G-DCT',
#  '4Matic+ 7G-DCT',
#  'CDI Premium',
#  '4Matic 7G-DCT',
#  '180d 7G-DCT',
#  '200d 8G-DCT',
#  '4Matic 7G-DCT',
#  '200d 8G-DCT',
#  '4Matic 7G-DCT',
#  '7G-DCT',
#  '200CDI BE Urban 7G-DCT',
#  '180CDI BE AMG Line 7G-DCT',
#  '200d 7G-DCT',
#  'S 4Matic+ 8G-DCT',
#  '4Matic+ 7G-DCT',
#  '180CDI BE AMG Line',
#  '180d 7G-DCT',
#  'Biturbo V-Max',
#  'Cabrio CGI BE Aut.',
#  'CDI pack AMG  * Capteurs, Gps, Sg chauff, ...',
#  'Leder Verw/gevent* Radio/CD* Navi* Dual Airco* PDC',
#  'MERCEDES-BENZ Clase SL Descapotable  Automático d',
#  'SL Autom, Leder, Sitzheiz.',
#  'Cabrio 350BlueTec Aut.',
#  nan,
#  'SL *Pagode*3.Besitz/Dt.Fahrzeug/H-Zul.',
#  'Kompressor Xenon SHZ PDC Klimaauto.Leder',
#  '*EURO6*NAVI*PDC*CUIR*LED*AIRSCARF*SIEGES CHAUFFANT',
#  'PERFORMANCE NIGHT SPORTABGAS BURMESTER',
#  '435cv AMG ***SOLO 37.000KMS *** LIBRO OFICIAL',
#  'AMG - BOITE AUTO ✅ GARANTIE ✅ LED - BLUETOOTH',
#  'Cabrio-AMG PAKKET- Nekverwarming - Windscherm',
#  'UNIEKE SL 560 EUROPESE LOOK IN NIEUWSTAAT.AUTOM.',
#  'K AUTOMAT+KLIMA+LEDER+XENON+AIRSCARF+TÜV',
#  'd Cabriolet',
#  'Cabrio 7G Plus',
#  'Cabriolet AMG Line',
#  'Cabrio 350CDI BE 7G Plus',
#  'R107 Cabrio Hardtop + Softtop H-Kennzeichen',
#  '200K',
#  '* Klima* Sitzheizung* Alu*',
#  nan,
#  'Cabrio 220CDI 7G Plus',
#  'Autom. Top-Zustand aus 2. Hd. Deutsches M.',
#  'Cabrio 9G-Tronic',
#  'AUTOMATIQUE - GARANTIE 12 MOIS - GPS-XENON-DESIGNO',
#  'Navi*Alu19*Leder*',
#  'Cabriolet AMG Line',
#  'Classe E AMG 53 4MATIC+',
#  'CLASSE S CABRIOLET Speedshift MCT  4Matic+',
#  'Classe   9G-Tronic Executive',
#  'CILINDRATA 2.000 Sport AUTOMATICA PELLE NAVI FULL',
#  '200 K.',
#  'C SW 200 d  auto',
#  'GE',
#  'cilindrata 2.000 Sport AUTOMATICA PELLE NAVI FULL',
#  nan,
#  'Cab.4M 9G+AIRMATIC+Carbon+AMG Line+360°Kamera',
#  '(cgi be) Sport AUTO *90.000 KM*',
#  'Kompressor  1PROPRIETARIO ! TAGLIANDI MERCEDESBENZ',
#  'Sport*MAE Original*Bose*Memory*Xenon*',
#  'Extrem gepflegtes Ex-Pressefahrzeug W 231',
#  'Cabrio',
#  'BiXenon-Leder-Navi-Sitz Lüftung uvm.',
#  'V8 Cabrio Aut.',
#  'C Roadster',
#  'Cabrio',
#  'cabrio d  Premium Plus 4matic auto',
#  'Cabrio 2.0i AMG - Burmester Aut. || FULL OPTION',
#  'Cabrio',
#  'CLK Cabrio 230 k evo Elegance',
#  nan,
#  'E Cabrio 250 cdi be Executive',
#  'cilindrata 2.000 Sport AUTOMATICA PELLE NAVI FULL',
#  'Cabrio 9G-Tronic (9.75)',
#  'Roadster Speedshift 7G-DCT,Burmester,Abgsoundsyst.',
#  '220 A Cabriolet',
#  'ROADSTER',
#  'AMG Line',
#  'S cabrio BURMESTER | LED | 360° | TRACK PACE',
#  '190SL',
#  'S Cabriolet Ponton Typ A (W 180)',
#  'Neu ohne Zulassung - Vollaustattung - sofort',
#  nan,
#  'd Cabriolet',
#  'Coupé R',
#  'AMG GLC 43 4MATIC Coupé',
#  nan,
#  nan,
#  'PERFORMANCE SITZE PANORAMA BURMESTER',
#  'BlueEFFICIENCY Coupé * Sitzhzg.* Teilleder',
#  'Coupe AMG Line',
#  'Coupé 462',
#  '4MATIC+ Coupé',
#  'S 4Matic+ 8G-DCT',
#  '220d Urban 7G-DCT 177',
#  'CE Liebhaberstück',
#  nan,
#  'd 4MATIC',
#  'd 4MATIC Coupé AMG Line',
#  'BiTurbo 4MATIC* HEATED SEATS * CAMERA * FULL LED *',
#  '43 4-Matic+|CAMERA*XENON*PACK NIGHT*LED*BURMESTER*',
#  '220CE',
#  'AMG-Paket * Navi * Rückfahrk. * ILS',
#  'CGI BlueE. Aut. Elegance LEDER NAVI XENON',
#  '220CDI AMG Line 7G-DCT',
#  '250d ECO Aut.',
#  'Aut.',
#  'Shooting Brake 7G-Tronic LED,Leder,GSD',
#  '220CDI AMG Line 7G-DCT',
#  'Coupé S 4Matic Aut.',
#  'Coupé',
#  'AMG Line',
#  'Coupé 350CDI BE Aut.',
#  'Aut.',
#  'Coupé 4M Aut.',
#  '220CDI AMG Line 7G-DCT',
#  'Coupé',
#  '*AMG-LINE*LED*MBUX*NAVI*PDC*CAMERA*EURO6*',
#  'Matte wrapping',
#  'Coupé 7G-DCT AMG LINE - BURMESTER - SFEERVERLICHTI',
#  '350d 4Matic Aut.',
#  'Coupé 250d 4Matic Aut.',
#  'Coupé 400d 4Matic Aut.',
#  'Coupé 400d 4Matic Aut.',
#  'CDI Chrome',
#  'e Coupé',
#  'Coupé 220d 4Matic Aut.',
#  'Aut.',
#  '200d Urban',
#  '220CDI',
#  'K',
#  'Aut.',
#  'Classe E 300d Coupé AMG Line Mercedes-Benz E Klas',
#  'd Edition*AMG LINE*NAVI*CAMERA*TOIT PANO*EURO6*',
#  'COUPE AMG -Line',
#  'Coupé 220d 9G-Tronic',
#  'Coupé',
#  'Coupé 4Matic 9G-Tronic',
#  'Coupé 350CDI BE Aut.',
#  '4-Matic PANO- A.M.G- LUCHTVERING -MASSAGESTOELEN',
#  'CDI Inspiration 7G-DCT',
#  '320CDI Aut.',
#  '4M Aut.',
#  'Aut.',
#  'd 4MATIC*NAVI*T.O PANO*AMG LINE*EURO6*PDC*CAMERA*',
#  'd 4-Matic 9G-TRONIC PACK AMG TOE CUIR LED CAME 360',
#  '300d 4Matic Aut.',
#  '220d 4Matic 9G-Tronic',
#  'Aut.',
#  '220d 4Matic 8G-DCT',
#  'Hybride Pack AMG 1°EIG. FULL OPTIES NEW STAAT!',
#  'S DIS * 4x Sitzh * AIR * 360°',
#  'd 4MATIC',
#  'b*SPORT*NAVI*PDC*AUT AC*LIKE NEW*',
#  '400CDI',
#  '4MATIC',
#  '250BlueTec 4M 7G Plus',
#  '1.6 Essence Euro6b 8.951km réels Garantie 12M',
#  'EQ HEV HYBRID *4 MATIC*GPS*CAMERA*LED*ALU BI COLOR',
#  'd 4Matic Standhzg. * DIS * LED * Navi',
#  '4Matic 9G-Tronic',
#  '4Matic 9G-Tronic',
#  '420CDI Aut.',
#  'e 4Matic',
#  '320CDI 4M Aut.',
#  '4Matic 9G-Tronic',
#  '4Matic Aut. *AMG*7-SITZER*EXCLUSIVE*DVD*L',
#  'G Klasse 350d Mercedes-Benz G Klasse 350d - Direct',
#  '4M AMG Line',
#  'd*EUR 6!*AMG*NAV*DVD*FULL*LIKE NEW*',
#  'd +DAB +Lane Assist +Sfeerverlichting +Camera +...',
#  'd + Camera + Sfeerverlichting + Zetelverw. + DAB',
#  'GLS 400d 4MATIC AMG Line Mercedes-Benz GLS 400d 4M',
#  nan,
#  'd AMG Line',
#  'AMG GLC 43 4MATIC',
#  nan,
#  '220d 4Matic Aut.',
#  '1.6i - NAVI / LED / LEDER / PANO OPENDAK /TREKHAAK',
#  'e Coupe - 4-Matic PHEV',
#  '250d 4Matic Aut.',
#  '320CDI Edition 10 Aut.',
#  'd 4MATIC - AMG Line - Pano dak',
#  'D',
#  'd 4MATIC',
#  '4Matic Aut.',
#  'UNIEK!AMG 63-PAKKET XENON,PANO,AUTOM,LEDER,EURO 6',
#  '4MATIC 7G NAVI LEDER KAMERA PDC AHK',
#  '4Matic 9G-Tronic',
#  'd Pack AMG',
#  'd 9G-Tronic AMG 4 MATIC - LEDER - PANODAK - LED -',
#  '316 DOKA+PRITSCHE+KLIMA 7 SITZER 316 CDI',
#  'd',
#  'e Plug-In Hybrid 49g Co2',
#  '* 2016 * Navi * Xenon * Euro6b * Garantie',
#  'd break AMG Line',
#  'BREAK |\xa0PANO | DESIGNO | CARBON | CAMERA | LED',
#  'T CDI Avantgarde Export',
#  'd - WIDESCREEN - KeylessGo - AdaptCruise - Camera',
#  'd Toit Ouvrant , Clim , Navi , Bluethoot , Cruise',
#  'CDI 4-Matic',
#  'b*NAVI*LED*LEDER*PDC*AUTOMAAT*',
#  'D - BOITE AUTO - MBUX - LED ✅ GARANTIE 1 AN ✅',
#  'd break 7G-TRONIC AMG Line! Leder, Led, Navi, Top!',
#  'Estate 200CDI BE Edition',
#  'Shooting Brake 200d',
#  'AMG CLA 35 4MATIC Shooting Brake',
#  'Break Avantgarde * Camera * Navi * Automaat',
#  'Estate S 4Matic+ 9G-Tronic',
#  'S T Pano HUD Camera Adaptive Cruise LED High Perf',
#  'SB AMG line*Led*Navi*',
#  'AMG line-Leder+Alcantara-Elekt koffer-Automaat (9)',
#  'Estate 4Matic 7G Plus',
#  'Estate 200d 9G-Tronic',
#  'BI TURBO 4MATIC - LEDER/ALCANTARA - LED - NAVI - 1',
#  'Estate 4Matic 7G Plus',
#  'SB * RACE * Pano * Camera * Navi * 381pk',
#  'd  Facelift - Automaat/GPS/Camera',
#  nan,
#  '4MATIC',
#  'd Estate',
#  'AMG-line-LED-Leder-Pan.sunroof- 9GTRONIC AUT',
#  'C220d AMG 194pk/ch',
#  'AMG E 53 4MATIC+ Estate',
#  'b*AMG*NAVI*PDC*LIKE NEW*',
#  'T AVANTGARDE AUTOMAT+KLIMA+NAV+LED+KAMERA+',
#  'Break*MBUX*AVANTGARD*LED*T.O PANO*CUIR*NAVI*EURO6*',
#  'Estate 220d',
#  'd 4-Matic',
#  'd Estate Business Line',
#  'd AMG/rijassist',
#  'd Estate',
#  'Estate 220d 9G-Tronic',
#  'Shooting Brake',
#  'PACK AMG PACK SPORT 1ER PROPRIETAIRE',
#  'de Estate',
#  'd Estate',
#  'd T-Modell 9G AMG MULTIBEAM 360-K BURMES.',
#  'd avantgarde',
#  'd Estate Business Line',
#  '9G Tronic - AMG LINE - NAVI - CAMERA - 12M GARANTI',
#  'Shooting Brake AMG Line 7G-DCT',
#  '!!FULL!! /AMG-PACK/OPEN DAK/KEYLESS/LED/MEMORY/',
#  'd*AVANTGARDE*NAVI*PDC*EURO6*LED*BVA*',
#  'CDI BlueEFFICIENCY Edition',
#  'd Estate',
#  'L d HYBRID Amg Line Toit Pano Full Etat Neuf',
#  '9G-Tronic',
#  'd 4Matic DIS * 4x Sitzlüftung * Pano *',
#  'S 4Matic+ 9G-Tronic',
#  'PLUG-IN HYBRID Lang',
#  'L Aut.',
#  'CDI  EURO 6',
#  '2.3 16',
#  '7G Plus',
#  '220CDI BE Avantgarde 7G Plus',
#  'Progressive Line * Apple Carplay * Lane Assist *',
#  '200CDI Avantgarde 7G Plus',
#  'AMG-line* Navi* Halfleder* Panodak* Camera* Xenon',
#  'i 7G-TRONIC LED PERFOR. MBUX CARPLAY CAM. CUIR GAR',
#  '220d 9G-Tronic 194',
#  'MODEL 2017  EURO6 Norme LEZ2030 !DEPOT VENTE!',
#  'AMG PACK*EU6d*19.000 Kilométres!!!CARPASS*',
#  'CDI/AMG/SH/SW/NAVI/8XR/TEM/SHZ/PDC',
#  'd 9G-TRONIC AMG Line/nightpakket/2019/60.000km',
#  'Classe E 200 d',
#  nan,
#  'D*NAVI*LED*URBAN-Line*',
#  'CLA 180 AMG coupe',
#  '220CDI BE Elegance Aut.',
#  '220BlueTec 7G Plus (4.75)',
#  'AMG + Camera + Lane Assist + Zetelverw. + ...',
#  '4Matic 9G-Tronic',
#  '220CDI Avantgarde Aut.',
#  'AMG + Camera + Carplay + Night pakket + Multibeam',
#  'd AMG PACK ~ AUTOMAAT ~ GARANTIE ~ ***  NEW ***',
#  'Keyless + Head-Up + Carplay + DAB + Lane Assist+..',
#  'i - AMG PACK - CAMERA - Garantie',
#  '220CDI BE Avantgarde Edition',
#  'de',
#  'CDI BlueTEC  in nieuwstaat',
#  'S Klasse 580E Lang 4MATIC Mercedes-Benz S Klasse 5',
#  'leder - zetelverwarming - widescreen - progressive',
#  '320CDI Avantgarde 7G',
#  'AMG /verwarmd leder/gps/ cruise control/camera',
#  'd AMG',
#  '220CDI Avantgarde Aut.',
#  'Sedan 9G-Tronic AMG LINE - FULL LED - ALU - BLIS -',
#  'BlueTEC Sport',
#  '350+',
#  'd AMG Line',
#  'd',
#  'd HYBRID - leder - navigatie - led - Burmester',
#  'Business Solution AMG (EU6d-TEMP)',
#  '/ 1 Hd/ Rentner/Sammlerzustand',
#  'V8 Autom, Leder, Klima, SSD.',
#  '220d 9G-Tronic 194',
#  'Business-Solution',
#  'AMG line',
#  'de',
#  'd Business Solution | GARANTIE 12M',
#  'AMG /verwarmd leder/gps/ cruise control/camera',
#  '*1.HAND*ORIGINAL ZUSTAND*KEIN ROST',
#  'GTC 2.0 T OPC',
#  '1.7CDTI Cosmo',
#  '1.3 ecoFlex Expression',
#  '1.6CDTi S/S GSi Line 160',
#  '1.3CDTi Cosmo',
#  'S 1.4 TURBO *LEDER RECARO*INFINITY SOUND*CARPLAY*S',
#  '1.6 16v Energy MTA 115',
#  '1.7CDTi Enjoy 100',
#  '1.4 * Teilleder * Sitzhzg. * Klimaauto. *',
#  '1.2T S/S Design & Tech 130',
#  '1.2T S/S GS Line 110',
#  '1.4 XEL S&S Jam',
#  '1.3CDTi C Mon ecoFlex',
#  '1.4 XER S&S Rocks',
#  '1.4 XEL Jam Aut.',
#  'B 1.4 L Automatik*Leder*Klima*GSD*25TKM',
#  '1.2T XHT S/S Elegance AT8 100',
#  '2.0CDTi S/S Selective 165',
#  '2.0 T Cosmo',
#  '1.5D DT S/S Edition 100',
#  '1.5D DT S/S Edition 100',
#  '1.2-16V Rhythm',
#  'GTC 1.6 16v Sport',
#  'K 1.4 150ch 120 Jahre Start/Stop',
#  '1.4T S/S Dynamic 150',
#  'Opel Astra GTC 1.4 Turbo Sport',
#  '1.3 CDTi EcoFlex S/S Cosmo 2012 I 1ste eig I Airco',
#  '1.4 Turbo Cosmo Xenon/Navi/Leder/Clima/Cruise..',
#  'CABRIO 1.6 BENZINE MT',
#  '1.6  ecoFLEX S/S Innovation -MAYEN',
#  '1.4i Turbo COSMO *XENON*LEDER*GPS*',
#  'Cabrio 2.0CDTi S',
#  'OPEL GT 2.0 T 265 cv garantie 12 mois',
#  '2.0 Turbo 16V',
#  '1.4 Turbo Cosmo',
#  '1.6 DI Turbo Automatik Ultimate',
#  '1.4 TwinTop Klima,PDC,SHZ',
#  'TwinTop 1.4 16V Sport',
#  'Astra SW 1.9 cdti Cosmo 120cv 6m',
#  'Roadster ***Herbstaktion***',
#  'Cabrio 1.6T S&S Excellence Aut.',
#  nan,
#  'Cabrio 1.6T S&S Excellence Aut.',
#  'Cabrio 1.6T S&S Excellence Aut.',
#  '1.4T 140cv Excellence S/S #NAVY, BLUETOOTH',
#  'Descapotable Manual de 3 Puertas',
#  '1.4 16v Rosso',
#  'Cabrio 1.6T S&S Excellence',
#  '1.4T 140cv Excellence S/S #NAVY, BLUETOOTH',
#  'Cabrio 2.0CDTi S&S Excellence 165',
#  'Twin Top 1.9CDTi Enjoy',
#  '1.4 Turbo (ecoFLEX) Start/Stop Edition',
#  'Twin Top 1.8 Enjoy',
#  'Astra F Cabrio',
#  'Twin Top 1.6 Enjoy',
#  '1.3CDTi Sport Premium',
#  'GT 2.0 turbo 16v roadster 260cv',
#  '*** 2.0L, 264 pk, slechts 14162 km!! ***',
#  nan,
#  '1.4 Turbo 103kW ecoFLEX Edition 1 HAND',
#  '2.0 T',
#  'GT 2.0 turbo 16v roadster 264cv',
#  nan,
#  '1.8 COSMO*OPC*LEDER*AFL*WEINIG KM*KEYLESS*CABRIO',
#  '2.0 turbo',
#  nan,
#  '2.0 CDTi CABRIO,LEDER,NAVI,CAMERA,AUTO AIRCO,ENZ',
#  nan,
#  'Cosmo 2,0d/VOLLLEDER/SITZHEIZUNG/KAMERA',
#  'Roadster',
#  '2.0 T Cosmo',
#  '2.0L Turbo Benz./ Airco/ Leder/ 28.022 km!!/...',
#  '2.0 Turbo ECOTEC',
#  nan,
#  '2,0 Turbo',
#  '1.6 Turbo SIDI 170CV aut. Innovation',
#  '2.0 turbo 16v roadster c/pelle 260cv',
#  '2.0 T',
#  '2.0 Turbo ECOTEC',
#  '2.0 Turbo Cabriolet 92.000Km',
#  '2.0 Turbo',
#  'GT',
#  '2.0 Turbo ECOTEC',
#  'Black out versie met Alcantara dash',
#  'Twin Top 2.0 Turbo Endless Summer nicht fahrbereit',
#  nan,
#  '2.0 Turbo Pack',
#  'Twintop 1.9 CDTI - 150 FAP 111',
#  '2.0 16v Turbo VX 220 VX220',
#  'Twintop 1.9 CDTI - 150 FAP 111',
#  '1.8-16V Enjoy',
#  '2.0 Turbo',
#  '2.0 CDTI ECOTEC 170CV Start',
#  '2.0 CDTi Cosmo S',
#  'Roadster-Speedster',
#  'CDTi 16v  EXPORT OU MARCHAND',
#  '225 PS , original LHD, 2 owner car, hardtop',
#  '1.4i Turbo Cosmo S&S Full Options',
#  '2.2 16v VX 220 VX220',
#  'Cabrio 2.0i nieuwe apk',
#  'Twin Top 1.8 Sport opc',
#  'Cascada 2.0 cdti Cosmo s',
#  nan,
#  '2.0 Turbo 16V',
#  '2,0 Turbo - Garantie - Navi - Eintausch',
#  '1.6 SIDI Turbo Automatik Innovation',
#  'Twin Top 1.4 Sport',
#  '1.3 DT CDTi 16v Linea Rossa',
#  '1.6 turbo benzina 180 cavalli',
#  '2.0 CDTI ecoFLEX Start/Stop Edition',
#  'Twin Top 1.9 CDTI Edition',
#  nan,
#  '2.0 Turbo Roadster',
#  'Cabrio 2.2 16V',
#  '1.9 CDTi Enjoy',
#  'Twin Top 1.6 Cosmo lpg',
#  'Roadster - Topzustand - Tüv neu - wenig KM',
#  'Twin Top 1.8 Sport',
#  '1.6 Turbo Automatik Edition . AHK.',
#  'Twin Top 1.8 (Enjoy). Klima. Alufelgen',
#  '1.4 Turbo (ecoFLEX) Start/Stop Innovation',
#  'Twin Top Sport',
#  'Twin Top 1.8 Cosmo',
#  '1.6 (ECOTEC) DI Turbo (ecoFLEX) Start/Stop Edition',
#  'Twin Top 1.6 Turbo Endless Summer',
#  'Cabrio 1.8i Bertone Edition',
#  nan,
#  'E Cabrio',
#  'SE 16v Limited Edition',
#  '1.6 Turbo Innovation S',
#  '2.0 turbo 16v roadster 260cv',
#  '2.0 Turbo 16V',
#  'Twin Top 1.8 Edition',
#  '2.0 CDTI Automatik Innovation',
#  '2.0 Turbo',
#  '2.0 D (CDTi ecoFLEX) Start/Stop Innovation',
#  '1.6 Turbo Innovation S',
#  'TwinTop 1.8-16V Linea Nera',
#  '1.4 Turbo_GARANTIE_ECRAN_CLIM_GPS_EU5B_CUIR_',
#  'Twin Top 1.6 Turbo Endless Summer super zustand',
#  '1.4-16V Cosmo',
#  '1.9 CDTi,CLIM,PRETE A ETRE IMMATRICULÉE👍',
#  'Twin Top 1.8 Edition Leder, Navi, usw.',
#  '1.6-16V bertone',
#  'opel astra h cabrio opc',
#  'Astra Cabrio 2.0 turbo 200cv BERTONE',
#  '2.0 - 264 Turbo Ecotec',
#  'Twin Top 1.8 (Enjoy)',
#  'Twin Top 1.8 Edition',
#  '2.2 dti 16v Bertone',
#  'Twin Top 1.6 Turbo Endless Summer Leder',
#  nan,
#  '1.4-16V cabrio',
#  'Twin Top 1.9 CDTI Edition',
#  '1.8-16V Cosmo',
#  '1.9 CDTi Cosmo FAP',
#  'E Cabrio GSi 2,0 i',
#  '2.0 CDTi Cosmo',
#  '2.2 16v VX 220',
#  'Deportivo Manual de 3 Puertas',
#  '2,0 OPC, GTC, NAVI, LEDER, BI-XENON, ALU',
#  'Astra GTC Coupé OPC 2.0i 280 CV GTC',
#  'Astra GTC 1.6 cdti Cosmo s',
#  'C 2.2 de Luxe',
#  nan,
#  nan,
#  'Grand Sport2.0 Direct InjTurbo, GSI, 4x4',
#  'Deportivo Manual de 3 Puertas',
#  '2,0 16V  TÜV/AU NEU',
#  'GTC 2.0 CDTi 195cv Biturbo 3p S/S #NAVY, BLUETOOTH',
#  'GTC 2.0 CDTi 195cv Biturbo 3p S/S #NAVY, BLUETOOTH',
#  '1.6 Enjoy - OPC Line',
#  'Coupé 1.8 16v Bertone Edition',
#  'Coupé 1.8 16v Bertone Edition',
#  nan,
#  'Coupe GS',
#  '2.0 16V Turbo Coupe',
#  'MANTA STINGRAY-RESTAURATIONSOBJEKT-AUTOMATIK',
#  '2.5i V6',
#  'GTC OPC J 280 cv',
#  'GTC 1.4 Twinport ecoFLEX',
#  'olimpia record coupe',
#  '19 SR',
#  'Commodore 2.5 GS Coupe Automat',
#  '2.5E',
#  nan,
#  '2.0i 16v',
#  '2.0S',
#  'Olimpia 1.5 Coupe  //Top Zustand//',
#  '*H-Kennzeichen*Oldtimer*TÜV Neu*',
#  '1.6 Turbo Coupé OPC',
#  '3.0 E',
#  nan,
#  '1.4',
#  'A Berlinetta 1,9 S',
#  'V6',
#  '3.0 Originalzustand DE FAHRZEUG',
#  'GT/E gruppo 2',
#  '1900 S Berlina',
#  'V6 190ps',
#  '2.0 16V Turbo Coupe',
#  'opel Astra g coupe project',
#  nan,
#  nan,
#  'GTC 1.7CDTi 111Years 110 111 Years',
#  '2.0 16v sport automaat',
#  'Olympia',
#  'GTC',
#  '1.6 Turbo OPC*RECARO *GARANZIA COMPLETA* PERMUTE',
#  'GT1900 AL',
#  '3.0 V6 Individual Throttle Bodies',
#  '2.0i cat',
#  'Opel GT 1900',
#  'GSE (état concours)',
#  '2.0,Klima,1.Hand',
#  'Coupé 2,0 Turbo 16V',
#  nan,
#  'Rallye 16S',
#  '1200 S',
#  'Super gepflegter Oldtimer',
#  'Turbo 4x4  H-Kennzeichen Großer Service',
#  nan,
#  'GTC 1.6 t ecotec Cosmo S s&s 180cv',
#  'GT-A-L',
#  nan,
#  '1900',
#  '2.0i XEV 16v',
#  'Color Selection VII',
#  nan,
#  '2.8 S',
#  'B Coupe aus 1969',
#  nan,
#  'GTC 2.0 cdti ecotec Cosmo S s&s 165cv',
#  'A 4x4 Turbo C20Let*1.Hand*MwSt*',
#  'GTC OPC 2.0cc 280CV BENZINA',
#  'GTC 1.7 CDTI - 125 FAP Sport',
#  '2.0i',
#  'GTC 1.3 cdti Enjoy *NEOPATENTATI*',
#  'Astra GTC 1.7 cdti Enjoy 125cv 6m fap',
#  '1.7 CDTi 111 y. Ed.',
#  '2.0 i gt/e 110cv',
#  '1.3 CDTI 75cv Van autocarro 2 posti - IVA esposta',
#  nan,
#  nan,
#  '1.7 CDTi Enjoy',
#  '2.0 16V Turbo Coupe',
#  'H GTC 1.6',
#  nan,
#  '1.9 N',
#  '2.8 S',
#  'Astra GTC 1.7 cdti Cosmo 125cv 6m fap',
#  'B Coupe',
#  'Olympia',
#  'GTC 2.0 CDTI ecoFLEX Start/Stop Innovation',
#  'Irmscher GSE Oltimer FIA Liebhaber ',
#  '2.0 16V Turbo Coupe',
#  'V6',
#  '2.0i 16V cat',
#  nan,
#  '2.2 16V Coupe',
#  'GTC 1.6 180CV',
#  '1.8 16V Coupe',
#  'Manta-B',
#  'Twip top 140 ,18',
#  'Astra H GTC Opc Line',
#  '2.8, 1. Hand, original 68.115km',
#  '2.0i Orig.20.700KM ,Schibdach,Sammlerstk',
#  '2.0 16V Turbo Coupe',
#  '2.0i 16V - Rostfrei - 1. Hand - TÜV NEU',
#  '2.0i-16V',
#  'GTC 1.8 16V Coupe / TÜV NEU!',
#  'C1 Coupe 1200H',
#  '1,8 E Coupe Berlina Automatik  1 Hand Schiebedach',
#  'B LS Fastback',
#  'coupé',
#  '2.0 GSi / Look Manta 400 /  Rally / Oldtimer /',
#  'Classic',
#  'GSI !! 1.8i !! ZERO CORROSION !!',
#  '1.6 Turbo Coupé OPC',
#  '2.0i 16V cat',
#  'oldtimer 3.0 6cil GSE 180pk manual gears box',
#  'GTC1.8 Sport Goed onderhouden',
#  '1.3 CDTi Enjoy',
#  '1.8 16V Coupe',
#  nan,
#  'GTC 1.6 t ecotec Cosmo S s&s 180cv',
#  '1200 S  Allestimento Irmscher',
#  nan,
#  '1.8-16V',
#  '1.8-16V',
#  'AT',
#  'Berlinetta',
#  '1.3 CDTI . GTC',
#  'Coupe 2.0 turbo 16v 200cv',
#  'B GSI - Hatchback - Same Owner since 1990',
#  '1.0 Turbo Cosmo - OPC LINE - Winterpakket.',
#  '2.0i 16V cat',
#  'Color Selection III',
#  'B 2.0 GT/E,IRMSCHER,SERVO,H-ZULASSUNG,SPANIEN',
#  '1.4 Turbo ecoFLEX Start/Stop Color Edition',
#  'GTC 1.8 Edition',
#  'GTC 2.0 CDTI ecoFLEX Start/Stop Innovation',
#  nan,
#  '1.8 16V Coupe Edition 90 Jahre Bertone',
#  '1.6i 16V Sports',
#  nan,
#  '2.0i 16V Turbo 4x4',
#  'Astra Coupé 2.0T 16v Bertone Edition',
#  '2.0i 16V cat Color Edition',
#  '2.2 16V Coupe',
#  'GTC J 1.4 Turbo',
#  'GTC 1.7 CDTI Cosmo',
#  'GTC 1.7 CDTI 101CV 3 porte Enjoy',
#  'Coupe 1.8 16v',
#  'B CC Berlinetta H-KENNZEICHEN und Tüv Neu*',
#  '5p 1.6i twinport 16v',
#  'Astra G OPC 1, 2.0 16V',
#  'GTC',
#  'H GTC Edition 1.6 Twinport*KLIMA*ALU*PDC*',
#  '2,0i',
#  '2.2 16V UNICA',
#  '2.2 16V Coupe',
#  '1.8 16V Coupe',
#  '1.9 CDTI DPF',
#  '2.0 16V C20XE Irmscher',
#  'A GTE Gelb Leder',
#  '1.8-16V',
#  '1.6 CDTi DPF ecoFLEX Sports GTC Start/Stop Edition',
#  '200',
#  'Calibra 2.0 16v',
#  'Coupé 2.2 16V Classic Line',
#  'B 1,9 S 1 Hand',
#  '1.4 Turbo 150CV Start',
#  '1.8 16V Coupe',
#  '1.6 Executive',
#  '2.0i',
#  'GTC 1.9 CDTI - 150 Cosmo',
#  'ASTRA GTC 1,4 5-GANG TEMPOMAT',
#  '1.6 GTC',
#  '1.4i 16V cat',
#  'Calibra 2.0i 16v Special Edition',
#  '1.4 Turbo Edition Sport e85',
#  'GTC Sportwagen/Coupé',
#  '1.4i 16V - Tobacco - 1 Hd. - 159 TKm',
#  '(AUS ERSTER HAND,SEHR GUTER ZUSTAND)',
#  'Color Selection VI',
#  'GTC 1.8',
#  'ASTRA GTC 1.4',
#  'Astra Coupe 1.8 16v',
#  '3p 1.4i 16v Club',
#  '1.4-16V',
#  '1.4 Edition',
#  '1.4 Edition',
#  'E Gsi',
#  '1.6i 16V',
#  'GTC 1.8 Temptation',
#  '2.0i H-ZULASSUNG',
#  'Tigra 1.4 16v',
#  'GTC 1.6 SIDI Turbo ecoFLEX Start/Stop Innovation',
#  'Astra GTC 1.4 twinport Enjoy esp FL',
#  'TwinTop 1.4 16V Sport',
#  'G CC',
#  '2.2 16V Coupe',
#  '1.4i 16V',
#  '2.2 16V Coupe Linea Blu',
#  '1.6i 16V',
#  '1.4-16V Sport',
#  'GTC 1,4 Turbo Ecotec Sport Start/Stop System',
#  '2.0 Turbo OPC',
#  '1.4i 16V',
#  'B CC - 2.0E - 22tkm ! -perfekt original',
#  'Corsa 3p 1.2 Club Gpl-tech 85cv  OK NEOPATENTATI',
#  'GTC 1.7 CDTI 125 Sport 3p',
#  'Coupé 2,0 Turbo 16V',
#  '1.8 Sport',
#  '1.8i Bertone Edition',
#  '5p 1.7 dti 16v Elegance',
#  'GTC',
#  'TwinTop 1.9 16V CDTI 150CV Cosmo',
#  'Verkocht! 1.8 Cosmo OPC-Line',
#  'Tigra 1.6 16v Star Silver 32000 km',
#  '1,4i-16V',
#  'GTC 1.8 Sport',
#  '3.0TD LS',
#  '1.4 Turbo ecoFLEX Navi * Bi-Xenon',
#  '1.6CDTi S&S Selective 120',
#  '1.6 D Start/Stop Business**1ste eig**Topstaat!!',
#  '1.6CDTi S&S Excellence 4x2 Aut.',
#  '1.6 Turbo Ultimate (EU6.2)',
#  '1.2 TURBO INNOVATION *AUTOMAAT 6-TRAPS*GPS*CARPLAY',
#  '1.4 Turbo # CUIR, TEL, GPS, FULL OPTIONS',
#  '2.0CDTI S&S Aut. 4x4 210',
#  '1.2 Turbo GS Line S/S',
#  '2.2DTI Sport RS',
#  '1.2 Turbo ECOTEC 120 Years Edit. (EU6.3)',
#  'Innovation 1,2 96kW Automatic,Navi,Alu,Klima,SH PD',
#  'X 1.2T S&S Innovation 130',
#  'Innovation 1,2 96KW Automatic,Navi,Alu,Klima,SH,PD',
#  'CUIR/CAMERA/NAV/PDC',
#  "GS Line, 1.2 DI Turbo, 96 kW, 18', Navi, Matrix LE",
#  '1.4 TURBO COSMO !! 51000 KM !! GPS CUIR CAMERA JA',
#  '2.2 DTI Caravan Elegance',
#  '2.0 CDTi--CUIR--GPS--AIRCO--GARANTIE 12 MOIS--',
#  'Turbo S/S Innovation+Leder',
#  '1.5 TURBO DYNAMIC SPORTS TOURER *AUTOMAAT*OPC INTE',
#  '1.6 CDTi Navigation , Clim , Feux auto , Tel',
#  '2.0d COSMO SPORTS TOURER *AUTOMAAT*GPS*SENSOREN*CA',
#  'ST 1.4T S/S Excellence 150 Aut.',
#  nan,
#  '1.6 D Start/Stop Sports Tourer Active',
#  '1.7 DTH CDTi Essentia *CORRECTE STAAT - CARPASS*',
#  '2.8 V6 Turbo Sports Tourer 4x4 Automatik',
#  '1.6 CDTi 136CV aut. SW Dynamic Euro 6B+FAP',
#  '1.6 CDTI EF Bus. Ex.',
#  '1.6 D (CDTI) L1H1 S',
#  'Crossland 1.5 ECOTEC D 110 CV Start&Stop Design &',
#  'Astra Sports Tourer 1.7 cdti Elective 130cv',
#  '1.6CDTi 136pk Innovation Pack Business',
#  'Sports Tourer 2.0 cdti Cosmo auto',
#  'SW 2.0 CDTi 170 CV Aut. 8 Innovation In Garanzia',
#  '1.4 Turbo Sports Tourer EFH+AHK+Navi+Euro6+Klima',
#  'Astra Sports Tourer 1.6 cdti Innov. - Leggere Bene',
#  '1.6 CDTi LED CarPlay AUTOMAAT *GARANTIE*',
#  'Grandland 1.2 Turbo 12V 130 CV GS Line',
#  'Sports Tourer 2.0 Diesel Aut. Innovation',
#  'Astra Sports Tourer 1.6 cdti Business s',
#  '4ª serie 1.4 Turbo 140CV Sports Tourer Cosmo',
#  'Opel Movano B Kasten/Kombi GKa L4H3 4,5t 17 Sitze',
#  'CDTi BiTurbo ECOTEC S/S Innovation',
#  '1.6 CDTI Sports Tourer Aut. Business Edition',
#  '1.5 diesel Elegance',
#  'Opel Movano B Kasten/Kombi GKa L4H3 4,5t 17 Sitze',
#  'ST 1,6 CDTI Edition - Topzustand!',
#  'ST 1,3 Ecotec CDTI*2.Besitz*AHK*Pickerl NEU*TOP*',
#  'AUTOM./VOLL-LED/SCHIEBED/AGR-SITZE/AHK/5J.GARANTIE',
#  'Crossland 1.2 12V Start&Stop Edition',
#  'Dynamic 1.6 Benzine 200 pk!!!',
#  '5ª serie 1.6 CDTi 136CV aut. Sports Tourer Innovat',
#  '1.8 Elegance',
#  'ST 1,6 BiTurbo CDTI Innovation St./St.',
#  '2017 1.6 CDTi 110 CV S&S 5p. Innovation IPER-FULL',
#  '2.0 CDTI 160CV Sports Tourer Cosmo Navi',
#  'ST 2,0 CDTI ecoflex Cosmo Start/Stop System',
#  '5ª serie 1.6 CDTi 136CV aut. Sports Tourer Dynamic',
#  '2.0d INNOVATION GS *ADAPTIVE SUSPENSION*LED*360 CA',
#  '2.0 Turbo 4x4 GSi',
#  'LED * Massage * Sitzhzg. * Navi',
#  '2.0 turbo  gsi',
#  'Berlina Manual de 5 Puertas',
#  'B Grand Sport 2,0 D 125 kW Innovation,Kamera,Navi,',
#  'Turbo Innovation AUT',
#  '1.4/PDC/NAV/GARANTIE',
#  '1.0 Turbo LED DE JOUR CRUISE CONTROL CAPTEURS CLIM',
#  '1.4 Turbo Xenon PDC SHZ Tempomat Alu',
#  '2.0T Cosmo 4x4',
#  '1.2 - GAR 1 AN - 163,04€/mois* - CONTRÔLE OK',
#  '2.0 CDTI Navi * Sitzhzg. * 1. Hand *',
#  '1.2 Twinport ecoFLEX Edition Tüv + Insp.',
#  '1.6CDTI S&S Selective 136',
#  '1.4 Turbo Black Edition Start/Stop',
#  '2.0T Innovation 4x4',
#  '2.0 CDTi ecoFLEX OPC Line Full Options',
#  '1.4 Turbo Innovation ecoFlex Cabriolet',
#  '1.2Turbo S/S*Leder*Navi*Camera*AGR Zetel',
#  nan,
#  '1.2Turbo Innovation*Navi*Camera',
#  '1.2 PureTech 100 EAT8',
#  '1.2T 130pk Elegance*AlcantaraLeder*Navi*Camera',
#  '1 an garantie',
#  nan,
#  'K 1.6 CDTI Edition S/S (EURO 6d-TEMP)',
#  '2.0CDTI Sport 4x4 160',
#  'INNOVATION/NAVI/AIRCO/ALLU',
#  '1.2 S/S Edition *Navi via App*Parkeersensoren*Crui',
#  '1.0i Enjoy CLIMATISATION BLUETOOTH',
#  '1.4i Active',
#  '2.0 CDTi TOIT OUVRANT XENON CAPTEURS GPS ** FULL**',
#  'rs line',
#  '1.5dCi eco2 Energy Business 75',
#  '1.5 dCi 110CV Nav',
#  'TCe eco2 Energy Dynamique',
#  '1.5dCi Energy Limited S&S 110',
#  '1.9dCi Extreme',
#  '1.2 TCE Energy Dynamique S&S',
#  '2.0dCi 16v GT',
#  'TCe GPF Energy Zen 66kW',
#  'limited',
#  '1.0 TCe Limited',
#  'Life 40 R90 68kW',
#  'TCe Energy Limited 66kW',
#  '1.5DCI Expression 85',
#  '1.2 TCe Energy Zen EDC 87kW',
#  '1.6dCi Energy GT 118kW',
#  '1.2 16v Dynamique',
#  '1.5dCi Blue Business 85kW',
#  '1.5dCi Expression 110',
#  'TCe Energy Limited 66kW',
#  'E-TECH RS Line 117kW',
#  'TCe Zen 67kW',
#  '1.2 16v Dynamique eco2',
#  'SCe 65 Limited R&GO KLIMA Paket',
#  'TCe GPF Energy Limited 66kW',
#  'Life 80',
#  'SCe Energy S&S Intens 52kW',
#  'Electric Zen R80 60kW Batería 20kW/h',
#  'Authentique 1.2 Tüv + Inspektion neu',
#  '1.2  Faltdach. Cityflitzer. Anfängerauto',
#  '1.9D RN',
#  'V6 3.0i 24v PHASE I UNIQUE Condition',
#  '1.5dCi Energy Dynamique EDC 90',
#  'Ver.+TÜF alles mitversichert bis 50 T  KM.',
#  '1.5 dci 85 dynamique',
#  '1.8 16v',
#  '1.3 TCe GT-Line / 1e Eigenaar / Navi / Climate / P',
#  '1.5dCi Emotion eco2 75',
#  'IV 1.5 95ch Business',
#  'Intens Q210',
#  '1.5dCi Energy Business 55kW',
#  '1.5dCi SS Energy Business 55kW',
#  '1.5dCi Energy Business 55kW',
#  'Expression',
#  '1.6 TCe GT',
#  'IV 1.3 140ch Business',
#  '1.5dCi eco2 Energy Business 75',
#  'V 1.5 116ch Intens',
#  '1.5DCi Confort Authentique',
#  '2.0T Sport',
#  '1.5dCi Blue R.S. Line EDC 85kW',
#  '1.2 100ch Life',
#  'E-TECH Híbrido Intens 103kW',
#  '1.5dCi Energy Business 81kW',
#  'Blue dCi 85 Business',
#  'Blue dCi 85 Business',
#  'E-TECH Híbrido Zen 103kW',
#  'IV 1.3 140ch Business',
#  'IV 0.9 90ch Business',
#  'Intens 40 R90 68kW',
#  'IV 0.9 76ch Limited',
#  'IV 1.5 75ch Business',
#  'Zen R110 Flex BATTERIA NOLEGGIO RICARICA FAST',
#  '1.4 16v Community',
#  'IV 1.5 116ch Intens',
#  'TCe 90 ZEN',
#  '1.3 TCe GPF Intens 103kW',
#  '1.0 sce Intens 69cv edc my18',
#  '1.0 73ch Intens',
#  '1.2 Emotion eco2',
#  '1.0 SCe 75ch Zen - 20',
#  'TCe 90 Intens Navi PDC Kamera',
#  '1.0 71ch Limited',
#  '1.2 Emotion eco2',
#  'COMPLETE INTENS R135',
#  '1.2 Yahoo',
#  '1.2 16v Expression 75',
#  'Twizy 45 Intens Black Flex',
#  '1.2 TCe Energy Floride / Gps, Cuir, Sg chauff, ...',
#  'C.C. 2.0 Luxe Privilege',
#  'C.C. 1.5DCi Extreme eco2',
#  'C.C. 1.6dCi Energy S&S GT-Line',
#  '1.9 TÜV neu Automatik Klimaanlage Sitzheizung',
#  '1.2 TCE Dynamique',
#  'Plein Air*Komplettneuaufbau*H-Kennz.',
#  'Cabriolet Dynamique 2.0 dCi FAP,Klimaaut,',
#  '1.2 Tce Dynamique',
#  'R4 Cabriolet / Sammlerfahrzeug / 1. Hand',
#  'C.C. 2.0 Confort Dynamique',
#  'Descapotable Manual de 3 Puertas',
#  'C.C. 2.0 Luxe Privilege Aut.',
#  'C.C. 1.5dCi Dynamique',
#  'C.C. 1.5dCi Energy Dynamique S&S',
#  'C.C. 1.5dCi Dynamique',
#  'C.C. 1.6 Confort Dynamique',
#  'C.C. 1.6 Confort Dynamique',
#  'C.C. 1.5DCi Confort Dynamique eco2',
#  'C.C. 1.9DCi Confort Dynamique',
#  'Megane Grandtour 1.5 dci Dynamique 105cv',
#  '1.8-16V Fairway',
#  'Megane Coupe 2.0 turbo RS 265cv my14',
#  'Sporter Blue dCi 160 CV EDC Exe',
#  nan,
#  '1.6 dCi Energy GT-Line ** GARANTIE 12 MOIS **',
#  'Privilege',
#  '1.6 Dynamique',
#  '1.9 dCi /SHZ/Tempomat/Vollleder',
#  'CC 1.2TCe-130 06/15 -noir metal- airco/GPS/cruise',
#  '1.8 Fairway',
#  '1.5✅DIESEL✅FLORIDA✅GPS✅CT✅GARANTIE✅',
#  '1.6-16V Sport',
#  'Megane Coupe 1.5 dci Wave 110cv',
#  '2.0 Turbo Coupe-Cabriolet Exception',
#  'D53 Cabriolet',
#  'TCe 180 Coupe-Cabriolet Monaco GP',
#  '1.6-16V Priv.Luxe',
#  'Coupe 2.0 16v Cup  RS 250cv',
#  '2.0 Turbo Coupe-Cabriolet Top Zahnriemen Tüv',
#  nan,
#  '3p 2.0 16v RS Sport F1 Team',
#  'renault megane 5 porte dci  110cv',
#  'Mégane C.C. 2.0 Luxe Privilege',
#  'Coupé-Cabriolet 1.9 dCi FAP ~ gepflegt ~',
#  'III Coupé-Cabriolet Zen',
#  '1.8 Cabriolet',
#  '1.6-16V Sport NIEUWE APK',
#  '1.1 Benzine Tce 100 Dynamique',
#  '1.4 TCe Dynamique',
#  '1.5 dCi_CABRIO_JANTES_EURO5_GPS_CLIM_BLUETOOTH',
#  ...]

# %%
list(df["manufacturer_colour"].value_counts().index)
# Out:
# ['Blanco',
#  'Gris',
#  'Negro',
#  'Azul',
#  'Rojo',
#  'Grijs Metallic',
#  'Zwart Metallic',
#  'Schwarz',
#  'Zwart',
#  'Wit',
#  'Grijs',
#  'Bianco',
#  'Schwarz-Magic Perleffekt',
#  'Blauw Metallic',
#  'Nero',
#  'Onyx Schwarz',
#  'Obsidianschwarz',
#  'Onyx Black / Metallic',
#  'Grau',
#  'Blanc',
#  'Grigio',
#  'Gris Plata',
#  '-',
#  'Noir',
#  'Frost-Weiß',
#  'Magnetic-Grau (Metallic)',
#  'Blauw',
#  'Weiß',
#  'Obsidianschwarz Metallic',
#  'Quarz-Grau Metallic',
#  'Beige',
#  'Obsidian-Schwarz Metallic',
#  'Perlmutt-Schwarz',
#  'Obsidianschwarz - Metalliclack',
#  'Magnetic-Grau Metallic',
#  'Weiss',
#  'Mitternachtsschwarz',
#  'Onyx Black',
#  'Blu',
#  'Blau',
#  'Marrón',
#  'Rosso',
#  'Plata',
#  'Schneeweiß',
#  'Selenitgrau',
#  'Rood',
#  'Grigio Scuro',
#  'Iridium-Schwarz Metallic',
#  'Magnetic Grau',
#  'Polar White',
#  'Wit Metallic',
#  'Verde',
#  'Osmium Grey / Metallic',
#  'Quarz Grau',
#  'Rot',
#  'Chroma-Blau Metallic',
#  'Schneeweiss/Summitwhite/Arctic',
#  'Denim Blue',
#  'Bleu',
#  'Rood Metallic',
#  'Ice White',
#  'Rouge',
#  'Phantom Black',
#  'Diamant Schwarz/Karbon Schwarz',
#  'Onyx Black Metallic',
#  'Blanco Perlado',
#  'Mysticschwarz Mica',
#  'Black Solid / Solid',
#  'Nevada Weiss',
#  'Candy Weiss',
#  'Sternen-Schwarz',
#  'Moon-Weiss Metallic',
#  'Naranja',
#  'Gletscherweiss',
#  'Diamant Schwarz',
#  'Candy-Weiss',
#  'Argento',
#  'Polar-Silber Metallic',
#  'Selenitgrau Metallic',
#  'Black',
#  'Magnetic Grau Metallic',
#  'Plateado',
#  'Silber',
#  'Black Solid (Stone) / Solid',
#  'Polarweiß',
#  'Race-Blau Metallic',
#  'Chili Rot/Kardio Rot',
#  'Race-Rot',
#  'Phantom Black / Mic',
#  'Magnetic-Grau',
#  'Tiefsee Blau',
#  'Marlingrau Metallic',
#  'Brilliant White (M)',
#  'Black-Magic Perleffekt',
#  'Polar White / Sol',
#  'Steel-Grau',
#  'Gris Claro',
#  'Karbonschw Graphitschw Midnigh',
#  'Licht Grau M2',
#  'Black (M)',
#  'Osmium Grey',
#  'Midnight Schwarz Metallic',
#  'Bruin Metallic',
#  'Denim Blue / Metallic',
#  'Arktisweiss',
#  'Obsidian-Schwarz',
#  'Nautic Blau',
#  'Nachtschwarz',
#  'Quarz-Grau',
#  'Platingrau',
#  'Donker Zwart Metallic',
#  'Gris C',
#  'Reinrot',
#  'Negro Azabache',
#  'Desire Rot',
#  'Graphitgrau Metallic',
#  'Cavansitblau',
#  'Azul Medianoche',
#  'Black-Pearl-Schwarz',
#  'Schneeweiss',
#  'Lava Rot',
#  'Schwarz - Unilack',
#  'Onyx Schwarz Metallic',
#  'Pine Grey / Metallic',
#  'Grau / Shadowgrey',
#  'Black Stone',
#  'Gris Artense',
#  'Iridium-Silber - Metalliclack',
#  'Mondstein Grau',
#  'Brilliant-Silber Metallic',
#  'Black Pearl (M)',
#  'Onyx Schwarz-Metallic',
#  'Zilver Metallic',
#  'Wit Parelmoer',
#  'Crystal White / Metallic',
#  'Szary',
#  'Laser-Weiss',
#  'Kometen-Grau',
#  'Savile Grey / Metallic',
#  'Graphitgrau',
#  'Magnetic Tech',
#  'Energy-Blau',
#  'Lackierung Schwarz Perla Nera/',
#  'Tiefquarz Grau/Quarz Silber',
#  'Business Grau Metallic',
#  'Savile Grey',
#  'Jade Weiss/Arktis Weiss',
#  'Black Magic Perleffekt',
#  'Mystery Blau',
#  'Midnight Schwarz',
#  'Polarweiss',
#  'Blanc Nacré',
#  'Argon Silber/Ice Silver (M2)',
#  'Licht Grau',
#  'Czarny',
#  'Gris F',
#  'Donker Grijs Metallic',
#  'Noir Perla Nera',
#  'Cavansitblau Metallic',
#  'Black Sapphire Metallic',
#  '"Nevada" Weiss',
#  'Bianco Gelato',
#  'Selenitgrau - Metalliclack',
#  'Donker Blauw Metallic',
#  'Noire',
#  'Crystal White Pearl',
#  'Graphite Grau Metallic',
#  'Marlingrau',
#  'Agate Black Metallic',
#  'Lava-Blau Metallic',
#  'Velvet Rot Metallic',
#  '"Candy" Weiss',
#  'Colore Esterno (Carrara Grau)',
#  'Black Sapphire / Metallic',
#  'Pirineos Grau',
#  'X-Blanco',
#  'Lightning-Grau',
#  'Platin-Grau Metallic',
#  'Engine Red / Sol',
#  'Iridium Schwarz Mica',
#  'Orange',
#  'Iridium-Schwarz',
#  'Grau Metallic',
#  'Argon Silber',
#  'Pine Grey Metallic',
#  'Iridiumsilber Metallic',
#  'Arktis Blau (M2)',
#  'Saphirschwarz  Mi2',
#  'Grijs Met Metallic',
#  'Granate',
#  'Antracite',
#  'Blanco Glaciar',
#  'Titan-Grau',
#  'Gris Platinium',
#  'Dynamic-Blau Metallic',
#  'Nevada Weiß',
#  'Iridium-Schwarz Mica',
#  'Polarweiss - Unilack',
#  'Magic Schwarz',
#  'Pure Rot',
#  'Sleek Silver',
#  'Phantom Black (Mica)',
#  'White',
#  'Amarillo',
#  'Black Solid',
#  'Moonstone-Grau',
#  'Vulcanorot',
#  'Metalstreamgrau Metallic',
#  'Silver Metallic / Metallic',
#  'Black Magic',
#  'Braun',
#  'Schwarz / Phantomblack',
#  'Blazer-Blau',
#  'Perla Nera Schwarz Metallic',
#  'Perla Nera Schwarz',
#  'Platinum Grey / Metallic',
#  'Feuerrot',
#  'Rodium Grau',
#  'Arktis-Weiß',
#  'Mountaingrau',
#  'Corrida-Rot',
#  'Karbonschwarz',
#  'Colore Esterno (Gelato Weiss)',
#  'Kontrast Grau/Quarz Silber',
#  'Biały',
#  'Stahlgrau',
#  'Gris Oscuro',
#  'Polar White (Sólido)',
#  'Licht Grijs Metallic',
#  'Bruin',
#  'Perlmutt Weiss',
#  'Blanc Nacre',
#  'Bleu F',
#  'Niebieski',
#  'Geel',
#  'Dezir-Rot',
#  'Blanco Glaciar (Opaco)',
#  'Kosmosschwarz',
#  'Graphit Grau',
#  'Azzurro',
#  'Graumet.',
#  'Chili Rot',
#  'Kosmosschwarz Metallic',
#  'Gelato Weiß',
#  'Mondstein Grau/E:Vulkan Grau',
#  'Power Orange',
#  'Perl Blau',
#  'Negro Obsidiana',
#  'Bronce',
#  'Black Sapphire Metallic (Zwart',
#  'Shadow Grey',
#  'Liquid-Weiß',
#  'Ginger Beige Metallic/Dach Nig',
#  'Dark Knight',
#  'Ice White, Solid / Solid',
#  'Iridiumsilber',
#  'Azul Marino (Opaco)',
#  'Black Stone Solid / Solid',
#  'Osmium Grey /',
#  'Sunset Red',
#  'Engine Red',
#  'Gun Metallic (M)',
#  'Ironblaumet.',
#  'Titanium-Grau',
#  'Ruby-Rot (Metallic)',
#  'Marron',
#  'Rojo Sólido',
#  'Indigo Blau',
#  'Shimmering Silver',
#  'Oranje Metallic',
#  'Colore Esterno (Vesuvio Schwar',
#  'Passione Rot',
#  'Onyx Black-Metallic 717',
#  'Panther-Schwarz Metallic',
#  'Thunder Grey / Metallic',
#  'Magic Blue',
#  'Quarz Grau Metallic',
#  'Titanium-Grau Metallic',
#  'Groen Metallic',
#  'Silver (M)',
#  'Urban Silber',
#  'Perlmutt-Weiß',
#  'Schwarz Metallic',
#  'Fusion Red',
#  'Ung. Schwarz - Unilack',
#  'Grau Eclipse',
#  'Tenoritgrau Metalliclack',
#  'Jade Weiss',
#  'Gris Osmium',
#  'Mysticschwarzmet.',
#  'Schnee Weiss',
#  'Frozen White',
#  'Gray',
#  'Onyx-Schwarz',
#  'Palladiumsilber',
#  'Lack Weiss Perlglänzend/Metall',
#  'Blau Cosmos',
#  'Diamantweiss - Metalliclack',
#  'Topas Blau',
#  'Teal Blue / Met',
#  'Pianosaweiß',
#  'Pine Grey',
#  'Polar-Silber',
#  'Black Pearl-Schwarz Metallic',
#  'Ice White / Solid',
#  '"Magic" Schwarz',
#  'Chroma-Blau',
#  '"Mystery" Blau',
#  'Crystal White Pearl / Metallic',
#  'Moon-Weiss',
#  'Mahogany Brown (P2/So)',
#  'Blanco Polar',
#  '"Pirineos" Grau',
#  'Black-Magic-Perleffekt',
#  'Brillantsilber Metallic',
#  'Kaolin-Weiß',
#  'Grau "Comete"',
#  'Calcitweiss - Unilack',
#  'Andere',
#  'Blau Metallic',
#  'Highland Grey',
#  'Thunder Grey Metallic',
#  'Grau Cassiopee',
#  'Blazer Blau',
#  'Lucid-Rot Metallic',
#  'Rubin Rot',
#  'Czerwony',
#  'Hightechsilber',
#  'Velvet Rot',
#  'Nero Etoile',
#  'Bianco Madreperla',
#  'Candy Weiß',
#  'Denim Blue Metallic',
#  'Cavansitblau - Metalliclack',
#  'Candy-Weiß',
#  'Saphirschwarz  Mineraleffekt',
#  'Magnetic',
#  'Perlmuttschwarzmet.',
#  'Blau Marine',
#  'Platinsilber Metallic',
#  'Schnee Weiß (Uni)',
#  'Beige Metallic',
#  'Blanco Gelato',
#  'Colore Esterno (Pompei Grau)',
#  'Mysticschwarz',
#  'Farbe Schwarz Obsidien/Metalli',
#  'Grijs Mica',
#  'White Solid',
#  'Starsilber Iii  M2',
#  'Black Pearl-Schwarz',
#  'Passion Red Solid / Solid',
#  'Onyx Zwart',
#  'Quarz Silber',
#  'Lucid-Rot',
#  'Argent',
#  'Plat.Anthr./Rogrey/0J:Silbergr',
#  'Diamant Blau(M2) / Diam Silb',
#  'Arden Blau (P2/So)',
#  'Grün',
#  'Zwart Met Metallic',
#  'Polarsilber',
#  'Onyxschwarz',
#  'Dark Knight / Mic',
#  'Black Sapphire',
#  'Onyx Black Metallic (Zwart Met',
#  'Osmium Grey Metallic (Grijs Me',
#  'Denim Blue Metalizado',
#  'Hightechsilber Metallic',
#  'Performance Blue',
#  'Otros',
#  'Gris Platine',
#  'Platinum Grey',
#  'Arancione',
#  'Zwart Mica',
#  'Black Metallic',
#  'Cinema Schwarz',
#  'Raceblaumet.',
#  'Stahlblau',
#  'Stahl-Grau',
#  'Blackmagicmet.',
#  'Steel Grey',
#  '"Universo" Schwarz',
#  'Magnetitschwarz - Metalliclack',
#  'Pure White',
#  'Palladiumsilber - Metalliclack',
#  'Silver',
#  'Tenoritgrau',
#  'Frostweiß',
#  'Designo Diamantweiß Bright',
#  'Schiefer-Grau',
#  'Dynamic-Blau',
#  'Gris Selenita',
#  'Paars Metallic',
#  'Colore Esterno',
#  'Pompei Grau',
#  'Gris / Plata',
#  'Cappuccino-Beige Metallic',
#  'Noir Cinema',
#  'Abalone Weiss (P3S)',
#  'Grau Comete',
#  'Fire Red',
#  'Magnetic Metallic',
#  'Bursting Blue / Metallic',
#  'Silbermet.',
#  'Kardio Rot',
#  'Noir Métal',
#  'Denim Blue-Metallic 723',
#  'Rojo Tokio',
#  'Osmium Grey Metallic',
#  'Ocean Blue (Perl)',
#  'Candyweiss',
#  'Blanco (Sólido)',
#  'Nitro-Blau',
#  'Osmium Grey-Metallic 714',
#  'Graphite Grau',
#  'Uranograu',
#  '"Rodium" Grau',
#  'Space',
#  'Nevada Weiß Metallic',
#  'Magnetic-Braun Metallic',
#  'Perla Nera-Schwarz',
#  'Tiefquarz',
#  'Performance Blue / Sol',
#  'Gelb',
#  'Alpine Blau',
#  'Highland Grey Metallic',
#  'Micron Grey',
#  'New Red (M)',
#  'Rouge Braun',
#  'Iron-Blau',
#  'Stahl Grau',
#  'Espresso Braun',
#  'Chroma Blau Metallic',
#  'Micron Grey / Met',
#  'Phantom Black (M)',
#  'Shimmering Silver / Met',
#  'Amazon Grey / Met',
#  'Oro',
#  'Arktis Weiß',
#  'Amazon Grey',
#  'Silky Bronze',
#  'Lackierung Aluminium-Grau/Meta',
#  'Passion Red',
#  'Passion Red Solid',
#  'Shadow Black',
#  'Bleu C',
#  'Tiefquarz Grau',
#  'Diamant Schwarz (Metallic)',
#  'Manhattangrau',
#  'Lackierung Schwarz Perla Nera',
#  'Flamenco Red / Metallic',
#  'Grigio Artense',
#  'Oranje',
#  'Technic Grau',
#  'Brillantblau',
#  'Diamantweiß',
#  'Nachtschwarz - Unilack',
#  'Zilver',
#  'Plata Iridio',
#  'Groen',
#  'Black Stone 019',
#  'Fjordblau Metallic',
#  'Bursting Blue',
#  'Kristallschwarz',
#  'Gun Metallic',
#  'Osmium Grau',
#  'Pebble Grey',
#  'Gris Squale',
#  'Glacier',
#  'Desire Rot Metallic',
#  'Czarny Metaliczny',
#  'Blau Mediterraneo',
#  'Nero Metallizzato',
#  'Valencia Orange',
#  'Platinum Silver / Mic',
#  'Colore Esterno (Lattementa Grü',
#  'Bianco Perla',
#  'Gelato Weiss',
#  'Taklamakan-Orange',
#  'Perl Blau/Voltaic Blue',
#  'Licht Wit',
#  'Bordeaux',
#  'Spektralblau Metallic',
#  'Race Red',
#  'Manufaktur Opalithweiß Bright',
#  'Dezir-Rot Metallic, Black Pear',
#  'Performance-Blau Metallic',
#  'Jaune',
#  'Blanco Sólido',
#  'Gris Highland',
#  'Schwarz-Metallic',
#  'Bright Silver',
#  'Smaragd Gruen (Mi)',
#  'Blanc Digital Métallisé',
#  'Black Pearl',
#  'Metaalkleur Onyx Black (717)',
#  'Black Sapphire Metallic / Meta',
#  'Maple Braun Metallic',
#  'Brilliant-Silber',
#  'Negro Onyx Metalizado',
#  'Celestial Blue Pearl',
#  'Schwarz Obsidianschwarz Metall',
#  'Moon-Weiß',
#  'Oxygenblau Mica',
#  'Titanium Grey / Metallic',
#  'Diamant Schwarz Metallic',
#  'Schwarz Magic Perleffekt',
#  'Saphir Grau',
#  'Black Solid (Stone)',
#  'Quarz Silber Metallic',
#  'Giallo',
#  'Fusion Red Metallic',
#  'Denim Blauw',
#  'Snow / Metallic',
#  'Noir Etoilé',
#  'Mussel Blue',
#  '"Magnetic Tech"',
#  '714 (Grijs Metallic)',
#  'Magnetic Grey',
#  'Magic Blue / Metallic',
#  'Birch Light / Metallic',
#  'Calcitweiss',
#  'Ice White Solid / Solid',
#  'Barents Blue Pearl',
#  'Silver Metallic (Grijs Metalli',
#  'Nautic Blue Pearl (Blauw Metal',
#  'Power Rot/Traffic Red Ral3020',
#  'Argonsilber',
#  'Red',
#  'Lightning Yellow',
#  'Manganbronze Metallic',
#  'Teal Blue',
#  'Bl - Blanco',
#  'Cool Red / Sol',
#  'Schwarz Perla Nera',
#  'Liquid Weiss',
#  'Gris Osmium Metalizado',
#  'Negro Perla Nera (Metalizado)',
#  'Race Rot',
#  'Rouge Elixir',
#  'Juniper Blue Metallic/Dach Nig',
#  'Kometengraumet.',
#  'Vesuvio Schwarz Metallic',
#  'Szary Metaliczny',
#  'Onyx Schwarz (Metallic)',
#  'Beige Dune',
#  'Blanc Glacier',
#  'Gris-Negro',
#  'Quarzgrau Metallic',
#  'Iron Blau',
#  'Platin-Grau',
#  'Magnetitschwarz',
#  'Nero-Schwarz',
#  'Brilliantblau',
#  'Noir Etoile',
#  'Business Grau',
#  'Phantom Black / Met',
#  'Chilli Red Perleffekt/Dach Nig',
#  '"Emocion" Rot',
#  'Obsidian Schwarz Metallic',
#  'Schaumweiß',
#  'Mountaingrau Metallic',
#  'Chili Red / Night Sky Black',
#  'Platiniumgrau',
#  'Inscription Crystal White-Pear',
#  'Donker Zwart',
#  'Vertigo Blau',
#  'Precision Grey (M)',
#  'Tungsten-Silber',
#  'Aurora Grey',
#  'Reflexsilber',
#  'Sonnengelb',
#  'Magnetic Grau M',
#  'Bronze Metallic',
#  'Gris Fighter Jet',
#  'Midnight Black Metallic',
#  'Dark Night',
#  'Bleu Vertigo',
#  'Sleek Silver / Met',
#  'Denim Blue Metallic (Blauw Met',
#  'Race Blau',
#  'Grey',
#  'Night Shade (M)',
#  'Grigio Metallizzato',
#  'Gris Fonce',
#  'Emerald-Grün Metallic',
#  'Fiery Red',
#  'Obsidianschwarz - Lack',
#  'Sodalithblau Metallic',
#  'Licht Grau Metallic',
#  'Pannacotta  M2',
#  'Bronze',
#  'Brilliant White',
#  'Bronzo',
#  'Gris Comète',
#  'Denim Blau-Metallic',
#  'Platinium-Grau',
#  'Royal Blau',
#  'Mineralweiss/Ice Grey (M2)',
#  'Velocity-Blau Metallic',
#  'Agate-Black',
#  'Magnetic-Grau ()',
#  'Plata Brillante (Metalizado)',
#  'Techo Negro',
#  'Magnetic-Grau-Metallic',
#  'Rot Passione',
#  'Quartzgraumet.',
#  'Vesuvio Schwarz',
#  'Casablanca/Arctic/Eis Weiss',
#  'Diamantschwarz',
#  'Crystal Weiß-Perleffekt',
#  'Blanc Banquise',
#  'Sunset Red / Mic',
#  'Platin Grau Metallic',
#  'Rose Gold',
#  'Polar Silber Metallic',
#  'Marrone',
#  'California-Gelb',
#  'Nerzbraun',
#  'Jade Weiß',
#  'Kalaharirotmet.',
#  'Moon Rock',
#  'Phoenix Orange Metallic',
#  'Matcha Green',
#  'Highland-Grau',
#  'Oxford White',
#  'White Sand',
#  'Arktis Blau',
#  'Karbonschwarz Metallic',
#  'Carrara Grau',
#  'Blanc Gelato',
#  '717 Onyx Black Metallic',
#  'Cream White',
#  'Rosso Passione',
#  'Atacama-Orange',
#  'Phantom Black Mineraleffekt',
#  'Tenoritgrau Metallic',
#  'Platinum Silver',
#  'Blanco Candy (Sólido)',
#  'Abalone Weiss',
#  'P2 - Rojo',
#  'Silver / Metallic',
#  'Black-Stone',
#  'Cosmoszwart',
#  'Agate Black',
#  'Kobalt Blau/Vertigo Blau',
#  'Dragon Red',
#  'Panther-Blau Metallic',
#  'Caspian Blue Metallic',
#  'Rojo Fuego (Sólido)',
#  'Manhattangrau Metallic',
#  'Argonsilber Metallic',
#  'Schwarzmet.',
#  'Lackierung Platinium-Grau/Meta',
#  'Black Sapphire Metallic (Donke',
#  'Licht Grijs',
#  'Switchblade Silver Met (G)',
#  'Schwarz Perla Nera/Metallic',
#  'Moon-Weiß Perleffekt',
#  'Shadow Black (Mica)',
#  'Blanc Lipizan',
#  'Obsidian Black Metallic',
#  'Luna',
#  'Diamantweiss',
#  'P71Z - Verde Rally Metalizado',
#  'Blanco Perlado (Perlado)',
#  'Artense Silber Metallic',
#  'Spektralblau',
#  'Candy-Rot Metallic',
#  'Lack Weiss Banquise/Deckende L',
#  'Bleu Horizon',
#  'Laser Weiß',
#  'Black Sapphire (Zwart Metallic',
#  'Perlmutt Weiß',
#  'Colore Esterno (Passione Rot)',
#  'Tiefschwarz',
#  '019 Black Solid',
#  'Typhoon Silver',
#  'Kobalt Blau',
#  'Venezia Blau',
#  'Champion Blue / Met',
#  'Designo Selenitgrau Magno',
#  'Colore Esterno (Moda Grau)',
#  'Obsidianschwarz - Metallic',
#  'Iridium Schwarz',
#  'Dive In Jeju',
#  'Blau Sansibar',
#  'Ford Performance Blue',
#  'Gris Montagne Métallisé',
#  'Perlmutt-Weiß Metallic',
#  'Azul Denim',
#  'Designo Graphitgrau Magno',
#  'Perlmuttweiß',
#  'Gris Maestro (Metalizado)',
#  'Iridium Schwarz Metallic',
#  'Frost Weiß',
#  'Polar Silber',
#  'Nero Scorpione',
#  'Tropical-Orange Metallic',
#  'Blu Dipinto Di Blu',
#  'Phantom Black Metallic',
#  'Serenity White',
#  'Azul Cavansita',
#  'Creamy White',
#  'Mineral Grau',
#  'Steel Gray',
#  'Ozean Grün',
#  'Cosmos Blau',
#  'Varios',
#  'Grigio Colosseo',
#  '714 Osmium Grey (Grijs Metalli',
#  'Delphinsilber Metallic',
#  '614 Ice White',
#  'Artense Silber',
#  'New Silver (M)',
#  'Cashmere Brown',
#  'Indium Grau',
#  'Rodiumgrijs',
#  'Gletscherweiss (Weiß)',
#  'Diamantweiß Bright',
#  'Valencia-Orange',
#  'Lava Blau',
#  'Intense Blue',
#  'Indisch Grau Metallic',
#  'Iridiumschwarz',
#  'Blau "Mediterraneo"',
#  'Blanche',
#  'Azul Cosmos',
#  'Blu Notte',
#  'Mountaingrau Magno',
#  'Mountaingrau - Metalliclack',
#  'Universo Schwarz',
#  'Mountaingrau - Met.',
#  'Micron Gray / Met',
#  'Brillantblau Metalliclack',
#  'Manufaktur Diamantweiß Bright',
#  'Blanco (Suave)',
#  'Tonnerre Grau',
#  'Negro Midnight (Metalizado)',
#  'Dark Grey',
#  'Bianco Pastello',
#  'Perl-Blau',
#  'Race Blau Metallic',
#  'Licht Blauw Metallic',
#  'Savile Grau-Metallic',
#  'Black-Magic',
#  'Sunny Yellow (Uni)',
#  'Amarillo Sol',
#  'Velverot',
#  'Titaniumblau Mica Metallic',
#  'Kontrast Grau',
#  'Cavansitblau - Lack',
#  'Bright Silver / Metallic',
#  'Iridium-Silber - Lack',
#  'Silverdawn',
#  'Schnee Weiß',
#  'Graphite-Grau Metallic',
#  'Polarsilber Metallic',
#  'Sterlingsilber Metallic',
#  'Kosmosschwarz - Metalliclack',
#  'Brun Vison',
#  '714 Osmium Grey Metallic',
#  'Tokio-Rot Perleffekt',
#  'Kristall Silber',
#  'Bursting Blue Metallic',
#  'Metro  M2',
#  '717 Onyx Black (Zwart Metallic',
#  'Kalahari-Rot Metallic',
#  'Amazon Blue',
#  'Brilliant Silver',
#  'Maple Brown',
#  'Arden Blau',
#  'Graumetallic',
#  'Race-Blau',
#  'Gris Montaña',
#  'Ice Gray',
#  'Black Stone, Solid / Solid',
#  'Gris Grafito (Met)',
#  'Fire Red (Uni)',
#  'Karbonschwarz  U2',
#  'Perlmutt-Schwarz-Metallic',
#  'Mondstein Grau (Metallic)',
#  'Rallye-Grün Metallic',
#  'Designo Hyazinthrot',
#  'Denimblau',
#  'Signal Rot',
#  'Titanblau Metallic',
#  'Schwarz Metallic (Schwarz)',
#  'Onyx Black/Metallic',
#  'Thunder Grey /',
#  'Tiefsee Blau Metallic',
#  'Fusion-Rot',
#  'Marine-Blau',
#  'Gris Grafito',
#  'Metaalkleur 717 Onyx Black',
#  'Electric Silver / Metallic',
#  'Silbergrau Metallic',
#  'Gris Comete',
#  'Samtrot (P2)/Berry Red (P2)',
#  'Metaalkleur 727 Pebble Grey',
#  'White Solid Ice White / Solid',
#  'Luminous Sand',
#  'Manganbronze',
#  'Fusion Red / Metallic',
#  'Metaalkleur 723 Denim Blue',
#  'Nevada Weiss Metallic',
#  'Iconic-Silber',
#  'Brilliant White Metallic',
#  'Orientbraun - Metalliclack',
#  'Aluminium Silb/Kristall Silb',
#  'Cyber Grey',
#  'Dark Blue',
#  'Asphalt Blau Metallic',
#  'Diamantsilber - Metalliclack',
#  'Mystic Magenta',
#  'Black Pearl Metallic',
#  'Vert F',
#  'Star-Weiß Metallic',
#  'Silky Bronze / Met',
#  'Gray Metallic (Grijs Metallic)',
#  'Indiumgrau Metallic',
#  'Other',
#  'Bleu Cosmos',
#  '"Eclipse" Orange',
#  'Orangefarben Cayenne',
#  'Rood Parelmoer',
#  'Noir Cosmos Métallisé',
#  'Gris Mineral',
#  'Precision Grey Metallic',
#  'Atlas White / Sol',
#  'Rauchgrau Mica',
#  'Weiss Glacier',
#  'Grigio Platinum\xa0',
#  'Karminarot Metallic',
#  'Blu Scuro',
#  'Magma Rot (B)',
#  'Bronze Metallic Braunmet.',
#  'Savile Grey Metallic',
#  'Deepblackperl.',
#  'Selenitgrau Magno',
#  'Selenite Grey',
#  'Noir Metal',
#  'Quartz Grey',
#  'Urban Silber Metallic',
#  'Perlmutt Weiss Metallic',
#  'Amarillo Grabber',
#  'Pfeffer-Beige',
#  'Star Dust Metallic',
#  'Manufaktur Mountaingrau Magno',
#  'Montana-Grün Metallic',
#  'Platin Grau',
#  'Fiery Red / Mic',
#  'Magneticgraumet.',
#  'Glacier White',
#  'Twister-Orange Metallic',
#  'Licht Beige Metallic',
#  'Mystery Blue',
#  'Matte Grey',
#  'Gray Metallic',
#  'Midnight Black',
#  'Graphit-Grau Metallic',
#  'Gris Magnetic (Metalizado)',
#  'Silver Metallic',
#  'Mystery Blau Metallic',
#  'Kein Klartext Gefunden',
#  'Emocion Rot',
#  'Prominence Red',
#  'Orient-Rot/Velvet Red Met',
#  'Shadow Grey / Sol',
#  'Moon Rock (Grau)',
#  'Gris Kng + Orange Epy',
#  'Black (Zwart Metallic)',
#  'Arktikweiß',
#  'Ice White 614',
#  'Diamantweiss Bright',
#  'Azul Chrome',
#  'Blauw Mica',
#  'Rot Amore',
#  'Freedome Blue',
#  'Braun Metallic',
#  'Ruby-Rot Metallic',
#  'Performance-Blau',
#  '717 Onyx Schwarz-Metallic',
#  'Torino-Braun Metallic',
#  'Smaragd Grün',
#  'Weiss Gelato',
#  'Kallaitgrün',
#  'Blizzard-Grau Metallic',
#  'Anthrazit',
#  'Dipinto Di Blu Blau',
#  'Metaalkleur Thunder Grey (728)',
#  'Moon Rock / Met',
#  'Caspian Blue',
#  'Platinum Grey Metalizado',
#  'Arktik-Weiß',
#  'Atlas White',
#  'Grau Selenitgrau Metallic',
#  'Pulse Red / Mic',
#  'Platinumbronze Metallic',
#  'Phantomblackmet.',
#  'Colore Esterno (Jet Black (Met',
#  'Platinum Grey-Metallic 731',
#  'Crna Metalik',
#  'Frostweiss',
#  'Sicilia Orange',
#  'Gravity Gold',
#  'Dark Knight Metallic',
#  'Palladiumsilber Metallic',
#  'Blazer Blue',
#  'Olivine Grey / Mic',
#  'Highland-Grau Metallic',
#  'Olivine Grey',
#  'Rot Metallic',
#  'Urban Grey',
#  'Onyxschwarz Metallic',
#  'Celestial Blue',
#  'Kona-Blau Metallic',
#  'Mojavesilber Metallic',
#  'White Metallic',
#  'Colore Esterno (Rosso Passione',
#  'Juniper Blue / Night Sky Black',
#  'Carbonized Gray',
#  'Orange Atacama',
#  'Donker Groen Metallic',
#  'Nautic Blau Metallic',
#  'Jet Black (M)',
#  'Carbonized-Grau Metallic',
#  'Designo Platin Magno',
#  'Gris Perle',
#  'Bleu Alpine',
#  'Kometen-Grau Metallic',
#  'Gris Grafito (Metalizado)',
#  'Brilliantblau Metallic',
#  'Grau Pompei Metallic',
#  'Brillantblau Metallic',
#  'Passion Red Metalizado',
#  'Stahl-Grau Metallic, Black Pea',
#  'Kosmos-Blau Metallic',
#  '019 Techno Grün',
#  'Weiss Nacre (Weiß)',
#  'Grau Met.',
#  'Atacamaorangemet.',
#  'Atoll-Blau',
#  'Blanco Gelato (Sólido)',
#  'Gunmetal Grey Metalizado',
#  'Jadeweiss, Dachfarbe Schwarz',
#  'Onyx-Schwarz Metalli',
#  'Inferno Orange Metallic',
#  'Jadeweiss',
#  'Gris Moda',
#  'Grise',
#  'Iconic-Silber Metallic',
#  'Blauw Met Metallic',
#  'Pebble Grey Metallic',
#  'Midnight Black Metalizado',
#  'Nero Perla',
#  'Opal Blau (Met)',
#  'Elixir Rot',
#  'Stone Brown Met (058P)',
#  'Fancy-Grau',
#  'Gris Artense (Metalizado)',
#  'Hyazinthrot',
#  'Diamant Blau',
#  'Gris Acier',
#  'Olympic White (G)',
#  'Mineral-Silber Metallic',
#  'Metaalkleur 714 Osmium Grey',
#  'Grigio Magnetico',
#  'Cosmic-Silber Metallic',
#  'Geel Metallic',
#  'Noire Perla',
#  'Blackmagic Perleffekt',
#  'Onyx',
#  'Cuprite',
#  'Sodalithblau Metallic / Dach S',
#  'Brilliant Silber Metallic',
#  'Satin Steel Gray Met-4 (501B)',
#  'Lichtsilber Metallic',
#  'Pacific Blue (M)',
#  'Velvetrotmet.',
#  'Nagoyablau Metallic',
#  'Precious Schwarz',
#  'Basaltgrau',
#  'Metropolis-Weiß Metallic',
#  'Gris Urban',
#  'Magnetic Braun',
#  'Silber Metallic',
#  'Licht Wit Metallic',
#  'Bleu Fonce',
#  'Brillantsilber - Metalliclack',
#  'Blanc Nevada',
#  'Grigio Chiaro',
#  'Dunkelgrün',
#  'Titansilber Mica Metallic',
#  'Obsidianschwarz-Metallic',
#  'Fantastic-Rot Metallic',
#  'Deep-Schwarz Perleffekt',
#  'Cenote-Blau Metallic',
#  'Quarz Silber / Silber',
#  'Blanco Classic',
#  ...]

# %%
df.manufacturer_colour.unique()
# Out:
# array([nan, 'Negro Obsidiana', 'Mountaingrau Magno', ...,
#        'Blackberry Metallic (Paars Met', 'Tropic Green', 'Demin Blue'],
#       dtype=object)

# %%
# After the groupby operation, how many NaN values do I have remaining?
df['manufacturer_colour'].fillna(df.groupby(["colour"])['manufacturer_colour'].transform(lambda x: x.mode()[0])).isnull().sum()
# Out:
# 0

# %%
df['manufacturer_colour'].fillna(df.groupby(["colour"])['manufacturer_colour'].transform(lambda x: x.mode()[0]), inplace = True)

# %%
handle_missing_values(df, "manufacturer_colour")
# Out:
# Missing Values in 'manufacturer_colour':
# Count: 0
# Percentage: 0.00%

# %% [markdown]
# <a id="21"></a>
# <div class="alert alert-info" role="alert">
# <h1>Column name :<span style="color:red"> paint </span></h1>
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Operation : </b> To fill in the missing values in the "paint" column, we can use the "short_description" column . Since the "paint" column is associated with <span style="color:red"><b> " manufacturer_colour "</b></span> . let's fill in the <span style="color:red"><b> NaN values</b></span> in this column by grouping the data based on these columns and performing the necessary operations.
# </div>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
first_looking("paint")
# Out:
# column name    :  paint
# --------------------------------
# per_of_nulls   :  % 49.35
# num_of_nulls   :  14116
# num_of_uniques :  2
# Metallic     14485
# NaN          14116
# Uni/basic        1
# Name: paint, dtype: int64

# %%
# Let's examine the short description of the seats
list(df.loc[df[df["paint"].isnull()].index, "short_description"])
# Out:
# ['350+',
#  'S 4Matic+ 8G-DCT',
#  '4Matic+ 7G-DCT',
#  '4MATIC',
#  '200CDI Autotronic',
#  'BE AMG Line 7G-DCT',
#  '200CDI BE Line 4M 7G-DCT',
#  'e Limousine',
#  '4Matic 7G-DCT',
#  '180d 7G-DCT',
#  nan,
#  nan,
#  'd 4Matic (EURO 6d)',
#  '180d 7G-DCT',
#  'S 4Matic+ 8G-DCT',
#  'CDI',
#  '4Matic 7G-DCT',
#  'Limousine',
#  nan,
#  '250e 8G-DCT',
#  'CDI Elegance',
#  '7G-DCT (4.75)',
#  '180d 7G-DCT',
#  'd AMG Line (EURO 6d)',
#  'd (177.003)',
#  '180d 7G-DCT',
#  '7G-DCT',
#  '180d 7G-DCT',
#  '180d 7G-DCT',
#  '180d 7G-DCT',
#  '180d 7G-DCT',
#  'AUTOMATIK NAV LED KAMERA PARK-ASSIST SHZ DIG-DISPL',
#  '200CDI BE Urban 7G-DCT',
#  'd (177.003)',
#  '180d 7G-DCT',
#  '180d Sedán 7G-DCT',
#  nan,
#  '180d 7G-DCT',
#  '200d 4Matic 8G-DCT',
#  '180d 7G-DCT',
#  nan,
#  '200CDI BE AMG Line 7G-DCT',
#  '200CDI BE AMG Line 7G-DCT',
#  'A-CLASS A180 1.3 136 CV 7G-DCT 5P',
#  '200d Sedán 8G-DCT',
#  'S 4MATIC+',
#  'd Avantgarde Largo',
#  '180d Sedán 7G-DCT',
#  'AMG Line AUTOMATIK NAV LED KAMERA NIGHT PAKET SHZ',
#  '180d 7G-DCT',
#  'Avantgarde',
#  'Avantgarde',
#  'Sport 4Matic 7G-DCT',
#  '7G-DCT',
#  '4Matic+ 7G-DCT',
#  '300E',
#  '4-Door Coupe 43 4MATIC+ Premium AMG, NIEUWSTAAT!!',
#  '4-Door GT 63 S CARBON AERO 5-ZITS HUD',
#  '180CDI Avantgarde Aut.',
#  '580 4MATIC AMG Line Premium plus | Rij-assist + |',
#  'S 4Matic+ 8G-DCT',
#  'S 4Matic+ 8G-DCT',
#  'A35 AMG 4MATIC Premium+ 306PK | Pano | Sfeer | Bur',
#  'AMG/ NIGHT PAKKET/ PANO/ AMG SPOILER',
#  'd Business Solution Automaat - Cruise - Navi - Hal',
#  '4Matic 7G-DCT',
#  'CDI Air-Lift Schuifdak Harman/Kardon Night Leder U',
#  'AMG A 35 4MATIC',
#  '4MATIC 280kW/381pk DCT7 NIGHT PAKKET + PANORAMADAK',
#  'Premium+ AMG Edition 1 225PK | Pano | Sfeer | Virt',
#  'D AMG Pakket / Panoramadak / Navigatie / N.A.P.',
#  'd (177.003)',
#  'Automaat | Leder Interieur | 1j Garantie',
#  'CDi',
#  'd (177.003)',
#  'Ambition | Harman | ACC | Pano | CAM | AMG-Line',
#  '200 CDi 1.8 CDI Boîte auto',
#  'S 4Matic+ 8G-DCT',
#  'CLASSE  d Fascination 4Matic 7G-DCT',
#  '200 d Fascination 7G-DCT',
#  '250e 8G-DCT',
#  '180d 7G-DCT',
#  '250e Sedán 8G-DCT',
#  '180d 7G-DCT',
#  '220d 7G-DCT',
#  '250e 8G-DCT',
#  'CDI Edition Navigatie 4U3',
#  nan,
#  '4Matic 7G-DCT',
#  '180d 7G-DCT',
#  'Ambition | Automaat | Stoelverwarming | Navigaties',
#  'Sport Ambition AMG-Exclusief Pakket',
#  'AMG 123PK | Pano | Sfeer | Grote Navi | Camera | G',
#  'Solution AMG PANORAMADAK, NAVIGATIE, ECC AIRCO,',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '180d 7G-DCT',
#  '35 AMG 306ch 4Matic 7G-DCT Speedshift AMG',
#  '200d 7G-DCT',
#  'AMG-LINE',
#  'Classe A 1.5 109ch A 180 CDI BlueEfficiency',
#  'd *Tempomat *Sport-Lenkrad *Touchpad *Apple - Carp',
#  'd Business Solution Plus Upgrade, Automaat, LED, L',
#  'CLASSE  CDI Inspiration',
#  'Edition Navigatie 4U3',
#  'AMG Night Panodak',
#  '7G-DCT',
#  '180d 7G-DCT',
#  'AMG LINE -PANO',
#  'd Lease Edition Ambition AUTOMAAT',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  'Aut. *PDC *Pano *Tempomat *Sportsitze',
#  'Ambition Automaat AMG Pack',
#  '200 d 150ch Progressive Line 8G-DCT 8cv',
#  'AMG Sport 7G Automaat BiXenon Becker Map Pilot Nav',
#  'AMG PANORAMADAK/WIDESCREEN/SFEER/AUTOMAAT/ BOMVOL',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '200 d Business 7G-DCT',
#  '200  Sport',
#  '200d 7G-DCT',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  'd Business Solution, Automaat, Navigatie',
#  '100 PK Ambition | Cruise | PDC | Airco | NAV | LED',
#  '220d 7G-DCT',
#  'Business Solution Automaat, Navi, Bluetooth/Tel, M',
#  '220 d Fascination 7G-DCT',
#  'Business Solution AMG I AVANTAGE I AUTOMAAT I MBUX',
#  '35 AMG 306ch 4Matic 7G-DCT Speedshift AMG 19cv',
#  '200 d Inspiration 7G-DCT Euro6c',
#  'Ambition 120 PK - Automaat | Schuif/kantel-dak | C',
#  'Classe  d (cdi) Premium auto FL E6',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '220 190ch Progressive Line 7G-DCT Siege chauf gran',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  'd 4Matic AMG Line (EURO 6d)',
#  '220 d 190ch AMG Line 8G-DCT 10cv GPS Camera Radar ',
#  '180 d 116ch Business Line 7G-DCT',
#  '200 d 150ch Business Line 8G-DCT GPS Camera',
#  'Premium Plus | VERWACHT! | BTW Auto | Apple Carpla',
#  '180 d 116ch AMG Line 7G-DCT',
#  '200 d Inspiration 7G-DCT',
#  '200 163ch Style Line 7G-DCT',
#  '35 AMG 306ch 4Matic 7G-DCT Speedshift AMG TOuvrant',
#  '200 d 150ch AMG Line 8G-DCT 8cv',
#  '200 d Fascination Tpano GPS Camera',
#  'CDI 100kW ( 136CV ) Urban',
#  '180 d 116ch AMG Line LED GPS Camera Radar AV/AR',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '180 136ch Progressive Line 7G-DCT 7cv',
#  'd',
#  '180 d Sensation 7G-DCT',
#  'e A 250e Progressive Sfeerverlichting / NIEUW GERE',
#  '200 d 150ch AMG Line 8G-DCT',
#  '220 190ch Progressive Line 7G-DCT',
#  '180 d Sensation 7G-DCT',
#  'e Advantage LED / Navi / Aut / Cam / Half leder /',
#  '180 136ch Business Line 7G-DCT',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '220 190ch Progressive Line 7G-DCT Ecran 10 GPS Cam',
#  '180 d Intuition 7G-DCT',
#  '160 109ch Style Line',
#  '200 163ch AMG Line 7G-DCT',
#  '160 Inspiration 7G-DCT',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '180 d 116ch Progressive Line 7G-DCT',
#  'Coupé 3.0 CDI V6 DPF 7G-TRONIC BlueEFFICIENCY 265',
#  'AMG AUT/ PANO/ LEDER/ CLIMA/ CRUISE',
#  'S 4Matic+ 8G-DCT',
#  'BENZINA + GPL NUOVO + UNICO PROPRIEATARIO',
#  'A 45 AMG 4Matic Automatic',
#  'S 4Matic+ 8G-DCT',
#  '4Matic 7G-DCT',
#  'd Premium',
#  '220CDI BE Line 4M 7G-DCT',
#  '4Matic 7G-DCT',
#  'Edition 1 4Matic 7G-DCT',
#  '4Matic 7G-DCT',
#  'S 4Matic+ 8G-DCT',
#  'S 4Matic+ 8G-DCT',
#  '220d 7G-DCT',
#  '4Matic 7G-DCT',
#  '4Matic+ 7G-DCT',
#  'S 4Matic+ 8G-DCT',
#  '180CDI Elegance',
#  '7G-DCT',
#  '4Matic 7G-DCT',
#  '4Matic 7G-DCT',
#  '180CDI BE AMG Line 7G-DCT',
#  '4MATIC SCHAALSTOELEN/PANO/SPOILER',
#  'S 4Matic+ 8G-DCT',
#  '4Matic 7G-DCT',
#  '220d 8G-DCT',
#  '4Matic+ 7G-DCT',
#  'S 4Matic+ 8G-DCT',
#  '200d 8G-DCT',
#  '200d 8G-DCT',
#  '180d 7G-DCT',
#  '4Matic+ 7G-DCT',
#  '4Matic 7G-DCT',
#  '200CDI BE Urban',
#  '250e Sedán 8G-DCT',
#  '180CDI Polar Star',
#  'Pequeño Automático de 5 Puertas',
#  '4Matic+ 7G-DCT',
#  '4Matic+ 7G-DCT',
#  'S 4Matic+ 8G-DCT',
#  '4Matic Coupe 4Matic+ (EURO 6d-TEMP)',
#  '200d',
#  'Edition 1 4Matic 7G-DCT',
#  nan,
#  '4Matic 7G-DCT',
#  '220CDI BE AMG Line 7G-DCT',
#  '200CDI BE AMG Line 7G-DCT',
#  '7G-DCT (4.75)',
#  '200d',
#  '7G-DCT',
#  'S 4Matic+ 4Matic (EURO 6d)',
#  nan,
#  '200d',
#  '180CDI Autotronic',
#  '200d 8G-DCT',
#  '200d 8G-DCT',
#  '200d 8G-DCT',
#  'Sport 4Matic 7G-DCT',
#  '4Matic+ 7G-DCT',
#  'de 4Matic AMG Line (EURO 6d)',
#  'Edition 1 4Matic 7G-DCT',
#  '180d 7G-DCT',
#  'CDI Premium',
#  '4Matic 7G-DCT',
#  '180d 7G-DCT',
#  'd (177.003)',
#  '180d 7G-DCT',
#  '7G-DCT',
#  '200CDI BE Urban 7G-DCT',
#  'BlueEFFICIENCY Urban',
#  'CDI',
#  '200d 8G-DCT',
#  '7G-DCT (4.75)',
#  '200d 8G-DCT',
#  '4Matic 7G-DCT',
#  '200d',
#  '200CDI BE Urban 7G-DCT',
#  '200CDI BE Urban',
#  '180CDI BE AMG Line 7G-DCT',
#  'Edition 1 4Matic 7G-DCT',
#  'd (177.003)',
#  'S 4Matic+ 8G-DCT',
#  '4Matic+ 7G-DCT',
#  '180d',
#  'CDI Style',
#  '180d 7G-DCT',
#  'C *** CERAMIC BRAKES / BURMESTER / BELGIAN CAR ***',
#  'Roadster',
#  'Mercedes- Keramik/Carbon/Burmester/Night Distronic',
#  'C Roadster',
#  'C Roadster  | AMG Dynamic Plus Paket |',
#  'Biturbo V-Max',
#  'AMG SPORT COMAND,HARMAN/K,DISTRONIC,SH',
#  'Cabrio CGI BE Aut.',
#  'SL 43 DIGITAL LIGHT+BURMESTER+DISTRO+HUD+MEMORY',
#  'C Roadster EDITION50/KERAMIK/SITZKLIMA',
#  'Roadster*Magno*Night*SportAga*Distr+*RFK*',
#  'C Roadster Edition 50 SITZKLIMA/MEMORY',
#  'abrio Mercedes-AMG 4MATIC',
#  'MERCEDES-BENZ Clase SL Descapotable  Automático d',
#  'Cabrio 350BlueTec Aut.',
#  'Cabrio 4Matic 9G Navi+Leder+LED+DAB+el.Sitze+Sound',
#  'PRO KERAMIK-TRACK PACKAGE-CARBON I & II',
#  'SL *Pagode*3.Besitz/Dt.Fahrzeug/H-Zul.',
#  nan,
#  'MercedesAMG',
#  '*PANORAMADACH,AIRSCARF,PDC,LEDER,NAVI*',
#  'Cabrio 220d 9G-Tronic (4.75)',
#  'Cabrio AMG Line LED Aircap LM19',
#  'CABRIOLET AVANTGARDE AUTOMAT+LEDER+ALU',
#  'Cabrio Benzine Autom. - airco - Leder',
#  'AMG+COM+PanoV+LED-ILS+B&O+MILLEMIGLIA417',
#  '435cv AMG ***SOLO 37.000KMS *** LIBRO OFICIAL',
#  'Roadster BI-XENON SHZ NAVI PDC VO+HI AUTOMATIK',
#  'UNIEKE SL 560 EUROPESE LOOK IN NIEUWSTAAT.AUTOM.',
#  'd Cabriolet',
#  'Cabrio 7G Plus',
#  'Cabriolet AMG Line',
#  'r107 original belgian delivery! first owner car.',
#  'abrio Mercedes-AMG 4MATIC',
#  nan,
#  'Cabrio 350CDI BE 7G Plus',
#  '4M Night+AIRSCARF+DISTRON+MULTIBEAM+Com',
#  'Cabrio Navigation+LED-HP+CabKomfort+Kamera',
#  'C 63 S AMG Cabrio Performance Sitze/Lenkrad/AGA',
#  'd Cabrio EU6, d AMG Line 9G-TRONIC',
#  '4M+ Night+MBUX+Distro+21AMG+360°+HUD',
#  '200K',
#  'Cabrio 220CDI BE 7G Plus',
#  'AMG Line/FinalEdition/Airscarf/Memory Navi/Klima',
#  'Cabrio CGI BE Avantgarde',
#  'C63 AMG Burmester|HeadUp|ACC|Perf.-Abgasanlage',
#  'Cabrio AMG Line LED Navi Kamera Airscar',
#  'Cabrio d',
#  'Cabrio AMG Line2x+Spur+LED+Kam+Nav+DAB+18"',
#  'Cabrio 9G-TRONIC AMG Line Multibeam',
#  'd Cabrio AMG Line 2x+Burme+Comand+Sistzkli',
#  'ANDERE AMG Night+AIRSCARF+DISTRONIC+DIGITAL-LIGHT',
#  'Deutsches Fahrzeug  Sammlerzustand',
#  'Cabrio d',
#  'SL Vollrestauration',
#  'Cabriolet AMG Line',
#  'SL 63 4M+ HUD*Airscarf*MemoryP*Hinterachsl*Night',
#  'd Cabrio AMG+MBUXHighEd+LED-HP+20"+Mem+RFK',
#  'AMG*Kamera*Burmester*Aircap*Airscarf*Navi*',
#  'Cabrio 220CDI 7G Plus',
#  'Cabrio Avantgarde+MBUXHigh+LED-HP+Distr+RK',
#  'Cabriolet AMG Line 360°/Totw./Comand/LED Styling',
#  'C 180 Cabrio 9G-TRONIC AMG Line',
#  'C 200 Cabrio 9G-TRONIC AMG Line',
#  'Cabrio d',
#  'Cabrio AMG Line Leder + Verdeck Rot/360°/ Autom.',
#  'd AMG-Line+AIRSCARF+AIRCAP+Standhzg+Comand',
#  'Cabriolet AMG LED 19" Navi Kamera AMG Line',
#  'Cabrio AMG Line 2x+Night+Distr+LED+DAB+18"',
#  'Cabrio 9G-Tronic',
#  'Roadster + hardtop',
#  'MOPF II komplett Umrüstung D incl. Tacho',
#  '-CLASS 6.2 COUPE SPORT AUTO 457 2P',
#  'CLASSE S CABRIOLET Speedshift MCT  4Matic+',
#  'Roadster 4.0 Facelift - Airscarf - Touchpad',
#  'Kompressor Cabrio, Leder, 120 KW',
#  'Cabriolet 4MATIC',
#  'LED  AMG-Night-Paket COMAND  Airscarf',
#  'Carbon Editie - 1e eigenaar - Keuring + Garantie',
#  '200 K.',
#  'C SW 200 d  auto',
#  'GE',
#  'SL',
#  '(R129)',
#  '(R129) 2nd Owner/Collectable',
#  'Sport*MAE Original*Bose*Memory*Xenon*',
#  '(R171) 350 7GTRO',
#  'C Roadster',
#  'SL',
#  'Cabrio',
#  'cabrio d  Premium Plus 4matic auto',
#  'CABRIOLET 2.1 CDI 204CV AUTO GARANTIE 6 MOIS',
#  '220 d executive a',
#  '4M Cabrio AMG Distro+Parktronic+Spiegel',
#  'Cabrio 2.0i AMG - Burmester Aut. || FULL OPTION',
#  '200 AMG Sport 7G-Tronic BVA',
#  '250 d Sport auto',
#  'E Cabrio 250 cdi be Executive',
#  'Cabrio 9G-Tronic (9.75)',
#  'Cabriolet 4MATIC PERFORMANCE SEATS 36838KM!',
#  'Cabrio 220CDI BE',
#  '220 A Cabriolet',
#  'ROADSTER',
#  'AMG Line',
#  'S cabrio BURMESTER | LED | 360° | TRACK PACE',
#  '190SL',
#  'Cabrio C 63 S AMG*NP.127782,- EURO*VOLL',
#  'CDI BlueEfficiency E -Klasse Cabrio (BM 207)',
#  'Roadster Aut.',
#  'Roadster 4.0 | Performance-uitlaat | Night-Pakket',
#  nan,
#  'd Cabriolet',
#  'Coupe Speedshift 7G-DCT Perf-Sitze/Carb',
#  'D',
#  'S Coupe EDITION1 PERF. AGA DIST. 19°',
#  'Coupé R',
#  'Performance Sitz&Abgas 20" Burm LED Pa',
#  'Aut.',
#  'AMG GTC Edition 50*Designo*Magno*Pano*SitzKlima*',
#  '350CDI BE (9.75) Aut.',
#  'AMG GLC 43 4MATIC Coupé',
#  'CLA 45 4M SB AMG SPORT NAVI TEMPOMAT PDC LED EU6',
#  nan,
#  nan,
#  '4Matic Coupe Speedshift TCT Navi/Leder/',
#  'Aut.',
#  '-CLASS 4MATIC',
#  'Coupé 462',
#  '4MATIC+ Coupé',
#  '4Matic*KAMERA*NAVI*LED*DESIGNO*SHZ*',
#  '4Matic*KAMERA*NAVI*LED*DESIGNO*SHZ*',
#  'S 4Matic+ 8G-DCT',
#  'oupé Mercedes-AMG 4MATIC',
#  'Burmester+PerformanceAGA+Pano+++',
#  '220d Urban 7G-DCT 177',
#  'd 4MATIC',
#  'Coupe AMG Leder Navi Kamera Widescreen PDC',
#  'd 4MATIC Coupé AMG Line',
#  'AMG GT S E AMG PERFORMANCE grau magno HUD+CARBON',
#  nan,
#  '4Matic+ 7G-DCT',
#  'Coupé 4Matic (14.75) Aut.',
#  '320CDI Aut.',
#  'S 4.0 V8 DCT MATT CARBON KERAMIK V-MAX310',
#  'E300 COUPE AMG-LINE COMAND DISTRO HEAD-UP KEYLES',
#  '220CE',
#  'S Coupe',
#  'Mercedes-AMG S 4MATIC+',
#  '4M *AMG*Comand*Sitzhzg*LED*Schiebedach*',
#  '63 S 4M+ COM+PD+Burm3+Mbeam+HUD+360+EDIT1',
#  '4Matic (EURO 6d-TEMP)',
#  'GLC 43 4M Coupé **Burmester*360°Kamera*Keyless**',
#  '-CLASS 3.0 4MATIC AUTO 333 2P',
#  '350CDI BE 4M Aut.',
#  'Coupé 4M Aut.',
#  '63 S E PERFORMANCE SONDEREDITION+PANO+HUD',
#  'Aut.',
#  '43 Perf-Abg. SHD Burm Wides 360°',
#  'GLE 63 4MATIC Coupé LED*Abst-Tempo*360 Grad*Notruf',
#  'Coupe PerfSitze+Magno+Night',
#  '220CDI AMG Line 7G-DCT',
#  '53 4M+ Night-P/Panor/360°/Burm./Abgasan. Navi',
#  '200K',
#  '250d ECO Aut.',
#  'CLA 45S AMG 4M+*Pano*Distr+*Burm*HuD*Night*360°*',
#  'd Coupe 4M 3x AMG BURMESTER,COMAND,STANDHZ',
#  'S 4M+ Coupé AMG Dynamik-Paket 21"',
#  'C -Klasse Coupe C 200 AMG Line+Pano+Cam+',
#  'CLA 35 4MATIC KAMERA+DISTRO+AMBIENTE+KEYLESS+SHZ',
#  'CLA 45 4M Coupé Pano/Sound/Parktronic/Verkehrass',
#  'd Coupe AMG 19"Zoll Night Paket Comand Distronic',
#  '4M Coupé AMG*LED*AHK*Kamera*Navi*ParkPaket',
#  '4M*NightP*Burmester*Memory*360°',
#  '200K',
#  'Coupé PROGRESSIVE',
#  'Coupé 9G-Tronic',
#  '43 4M+ /Magno/Standheizung/AHK/',
#  'C 63 S AMG COM/Pano/Distr/KeyGO/Memory/Klappe LED',
#  'Coupé',
#  'Coupé 220d 4Matic 9G-Tronic',
#  'AMG Line',
#  'Aut.',
#  'Coupe*AMG-Line*MEMORY*SPURHALTEAS*360°CAM',
#  'C250 Cp. AMG+DISTR+PANO+BURM+LED AMBIE+TOTW+360°',
#  'AMG 4M*Panorama*MultiBeam*Comand*Burmester',
#  'Coupé 350CDI BE Aut.',
#  'S Coupe PANO+HEAD-UP+KAM360+DIGI-TACHO',
#  'GLC-Coupe 400 d 4Matic 9G-TRONIC AMG Line',
#  'Aut.',
#  'CDI Coupé',
#  'SEC',
#  'Aut.',
#  'Coupé CDI',
#  'Compressor',
#  'Mercedes-AMG CLS 53 4MATIC+ Navi/SHD/Styling/LED',
#  'CLA45 S AMG SB 4M HEAD-UP MULTIBEAM 360°KAM MBUX',
#  '*** BRABUS 730 / CARBON CERAMIC / FULL OPTION ***',
#  '220d 4Matic 7G-DCT',
#  'Coupe 3x AMG DIAMANTGRILL,KAMERA,PANORAMA',
#  'Coupé 4M Aut.',
#  'Coupé',
#  'Coupé d (238.314)',
#  'Coupe AMG Panoramadach Navi LED HuD',
#  'Coupé',
#  'd 4MATIC',
#  'Matte wrapping',
#  'S 4M+ Coupé V8 Drivers+Comand+DAB+AHK',
#  'd 4MATIC -',
#  'S Coupé Perf.Abgas. Pano Night Driver`s',
#  '350CDI BE (9.75) Aut.',
#  '350d 4Matic Aut.',
#  '-Klasse Coupe EU6d-T LED Navi Keyless e-Sitze Park',
#  '4M*Perf.-Sitze*Pano*NightP*HUD*360°',
#  'Coupé S 4Matic Aut.',
#  'coupé 4.0 4MATIC 469 2P',
#  'SLC, 1 Hand, Scheunenfund, Oldtimer, Bastler',
#  'AMG Line 4Matic LED Panorama Head Up 360°',
#  '320CDI Avantgarde 7G',
#  '53 4M+ Night-Pak./Panorama/Multibeam/360° Navi',
#  'S 4M+ Coupé Sitzklima*Drivers P.',
#  'd 4MATIC Coupé',
#  'Coupé d',
#  'C 63 Coupé Night-P/Panorama/Totw./360°/Multibeam',
#  '350d 4Matic Aut.',
#  '43 4M+ Night-P/360°/Panor/Burm./Abgasanl. Navi',
#  'Coupé e 4Matic',
#  'AMG Line Panorama*AHK*Night*Ambiente*LED',
#  'Coupé 4Matic Aut.',
#  nan,
#  'd 4MATIC',
#  'Coupé 400d 4Matic Aut.',
#  'GT53 4M AMG+SHD+STHZG+DISTR+LED BURM+360°+HUD+9G',
#  'CDI Chrome',
#  'Coupé 4Matic Aut.',
#  '220d 4Matic 7G-DCT',
#  'e Coupé',
#  'Coupé d AMG LINE',
#  'd (205.314)',
#  'Coupé d',
#  'Coupé AMG Line 2x+Kam+LED+Navi+DAB+SHZ+18"',
#  'A 180 Edition BlueEff. Tleder Tmat EU6d-T',
#  'CLS 53 4M+ *Limited Edition 1 of 299*DriversPa.*',
#  'Coupé 220d 4Matic Aut.',
#  'EQ Boost Aut. (9.75)',
#  'Mercedes-AMG C 63 Coupé COMAND/MultibeamLED/360°',
#  'Coupé 9G-Tronic',
#  'AMG C 63 S Coupé Night-P/Drivers P/360°/Panorama',
#  'Coupé 220d 4Matic 9G-Tronic',
#  'Coupé',
#  '200d Urban',
#  '350d 4Matic Aut.',
#  'Coupé 350d 4Matic Aut.',
#  'CDI (LA) Sport Edition (203.708)',
#  'Coupé 220d',
#  'Coupé 4Matic Aut.',
#  'AMG-Line*Panorama*LED*19"*Ambiente*kamer',
#  '220CDI',
#  'K',
#  'AMG*AHK*Panorama*Night*Ambiente*LED*MBUX',
#  'Coupé Progressive/MBUX/PTC/8fach bereift Navi',
#  'Aut.',
#  'd 4M Coupé AMG Panor./AHK/360°/Led beige Navi',
#  'Coupe 4MATIC*AMG LINE*PANO*360°-Kamera*',
#  'd Edition*AMG LINE*NAVI*CAMERA*TOIT PANO*EURO6*',
#  'COUPE AMG -Line',
#  'Coupé 220d 4Matic Aut.',
#  'd Coupe 9G AMG*NightP*Memory*AssistenzP*',
#  'Coupé 220d 9G-Tronic',
#  'Coupé AMG Line Pano Night Navi LED SH',
#  'Coupé',
#  'Coupé 4Matic 9G-Tronic',
#  'Coupé 350CDI BE Aut.',
#  'Coupe 4Matic EU6d-T',
#  'Coupé d AMG LINE',
#  'Coupé d 4MATIC',
#  '350d 4Matic Aut.',
#  'CDI Inspiration 7G-DCT',
#  'e 4Matic 7G-Tronic+Navi+Tempomat+',
#  '320CDI Aut.',
#  'AMG Pano, AHK, 360° Kamera, ACC, 21", Widescreen',
#  '4M Aut.',
#  'AIRMATIC+AHK+MEMORY+DIGITAL-TACHO+LED',
#  'Aut.',
#  'CDI 4Matic*Bi-Xenon*Navi*Designo-Lack*SHD',
#  '4MATIC',
#  '220d 4Matic Aut.',
#  'CDI 4-Matic BE *INKL. 2 JAHRE GARANTIE*',
#  'CDI (BlueEFFICIENCY) 7G-TRONIC',
#  '220d 4Matic Aut.',
#  '220d 4Matic 9G-Tronic',
#  'd 4Matic AMG-Line Navi LED Pano Shzg AHK',
#  '220d 4Matic 9G-Tronic',
#  'Aut.',
#  '220d 4Matic Aut.',
#  '220d 4Matic 8G-DCT',
#  'd 4M *Style*LED*Sitzheizung*Navi*7G-DCT*',
#  '4M Aut.',
#  'Aut.',
#  'd Exclusive 4Matic 9G-Tronic+COMAND+LED+',
#  'd 4MATIC',
#  '4M AMG Line ILS Pano HUD Airmatic 360',
#  "AMG Limited Edition ''1 of 463'' Platin-Magno",
#  '4MATIC',
#  'b*SPORT*NAVI*PDC*AUT AC*LIKE NEW*',
#  'Mercedes-AMG GLE 53 4MATIC+ Pano/360°/Night/AHK',
#  '400CDI',
#  '4MATIC',
#  '250BlueTec 4M 7G Plus',
#  'EQ HEV HYBRID *4 MATIC*GPS*CAMERA*LED*ALU BI COLOR',
#  '250d 4Matic 9G NAV+LED+SHZ+KAMERA+PANO+AHK',
#  'd 4M AMG-LINE COMAND AIRMATIC 360°KAMERA',
#  'GLE 63 4MATIC Coupé LED*Abst-Tempo*360 Grad*Notruf',
#  'd 4Matic **Finanzierung**Garantie**9G**',
#  'CDI Autom. 4Matic - GPS - Pano - Topstaat!',
#  'Progressive 7-Sitzer 20" Pano 360° Ke',
#  '4Matic 9G-Tronic',
#  '4MATIC',
#  '4Matic 9G-Tronic',
#  'd 4M 7 SITZE AMG 20ZOLL 360GRAD,KEYLESS',
#  'CDI 4Matic AHK+Standhzg.+ACC+Xenon+Pano',
#  '420CDI Aut.',
#  '4Matic 9G-Tronic Navi RFK',
#  '4Matic 9G-Tronic',
#  '4Matic 9G-Tronic',
#  'd AMG Line 4Matic LED PANO R.Cam AHK COMAND',
#  'd 4Matic All-Terrain Estate Avantdarde',
#  'G Klasse 350d Mercedes-Benz G Klasse 350d - Direct',
#  'CDI*Navi*Keyless*Kamera*MFL*ZVF*SHZ*Tempo*Isofix*',
#  '4M AMG Line',
#  '220d 4Matic Aut.',
#  '4M AMG Line Night Pano Advanced+',
#  'd*EUR 6!*AMG*NAV*DVD*FULL*LIKE NEW*',
#  'd 4MATIC',
#  '220d 4Matic Aut.',
#  '4Matic 9G-Tronic',
#  '4M AMG NIGHT 7SITZ+PANO+360+21Z+AIRMATIC',
#  '4M AMG/ MBUX/Schiebedach/Multibeam/Distr Navi/SHD',
#  'G 350 BlueTec LED BI-XENON*1J. PREMIUM GARANTIE',
#  'd +DAB +Lane Assist +Sfeerverlichting +Camera +...',
#  'd + Camera + Sfeerverlichting + Zetelverw. + DAB',
#  '220d 4Matic Aut.',
#  '200CDI BE 7G Plus',
#  'AMG **Designo Magno** AHK Multibeam',
#  'd 4 MATIC 245cv 9 vel. *IVA deducible* *2020* *Nac',
#  'd 4MATIC AMG Line',
#  'CDI',
#  '4x4² DESIGNO+STANDHZG+KAMERA+HARMAN+SHDACH',
#  '4Matic 8G-DCT',
#  '4Mat MAGNO*PANO*BURMESTER*HEAD-UP*ACC AMG Sport',
#  '4Matic*Pano*MBUX*21"*RFK*Spurhalte*',
#  '350e 4Matic',
#  'SD+AHK+Standhz+DISTRON+TV+MULTIBEAM+Com',
#  'd 4MATIC',
#  '4MATIC Navi/SHD/Totwinkel/ElectricArt/ Klima/LED',
#  nan,
#  '4Matic 7-Sitzer AHK Comand ILS Kamera Assist',
#  '350BlueTec 4M 7G Plus',
#  'd 4Matic (253.915)',
#  '350d 4Matic Aut.',
#  '4M 9G-TR. COMAND WEBASTO SCHIEBEDACH AHK',
#  'BlueTEC 4MATIC',
#  'de 4MATIC KAMERA+DISTRO+SITZHZ+KEYLESS',
#  'Puch  JAGD-FZG./WINDE/KOFFER/BRAUSE/AHK',
#  '220d 4Matic Aut.',
#  '4Matic Sportpaket *Kamera*Alcantara*LED*',
#  '4M AMG Multibeam MBUX-AR',
#  '350d 4Matic Aut.',
#  'd 4Matic AMG-Line Leder,Navi,LED,Head-up',
#  'AMG GLC 43 4MATIC',
#  'e 4Matic',
#  'd 4Matic Exclusive*Leder*Navi*PDC*18"* Exclusive',
#  '4Matic*Pano*MBUX*21"*RFK*Spurhalte*',
#  '220d 4Matic Aut.',
#  '300 4MATIC',
#  'd 4Matic*NAVIGATION*PDC*SHZ*ALU*',
#  '220d 4Matic Aut.',
#  'd 4M LED|AHK|Nav|eSITZE|CarPlay|ParkPaket',
#  '4MATIC',
#  '4M Night Standhz LED Kamera Keyles',
#  'D ADVANTAGE + PAQ NIGHT',
#  'd 4Matic 9G-Tronic*AMG Line*Pano*Head-Up AMG',
#  nan,
#  '220d 4Matic Aut.',
#  'GE lang Cabrio Steyr-D-Puch AHK Automatik Rücksitz',
#  'CDI 4Matic BlueTec*Navi*Klima*StHzg*',
#  '1.6i - NAVI / LED / LEDER / PANO OPENDAK /TREKHAAK',
#  'd 4Matic 9G-Tronic*AMG Line Int.*Pano*LE AMG',
#  'Coupé 350D 258 CV',
#  'Puch PLANE/AHK/ALLRAD/SCHLIEßANLAGE NEU',
#  '320CDI Edition 10 Aut.',
#  'Mercedes-AMG 4MATIC',
#  '4Matic*Pano*MBUX*21"*RFK*Burmester*',
#  '320CDI Aut.',
#  'D',
#  'Mercedes-AMG 4MATIC',
#  '4Matic Aut.',
#  'e 4M Distro+Pano+M-LED+Komfort+Advancedp',
#  'Puch PLANE/AHK/ALLRAD/SCHLIEßANLAGE NEU',
#  '4Matic+ Aut.',
#  'd 4M AMG PANORAMA HUD ABC DIST MBEAM 20"',
#  'd 4Matic Leder,LED,Navi,360°-Kamera,PDC',
#  '300d 4Matic Aut.',
#  'd 4M Sitzklim+Burmes+Pano+22"+PremPlusp.',
#  'Mercedes-AMG 4MATIC+',
#  'd 4MATIC',
#  '4Matic*Pano*MBUX*21"*RFK*Spurhalte*',
#  'Urban AHK  Rückfahrkamera Score',
#  '200d 7G-DCT',
#  'd 4Matic (253.915)',
#  '220d 4Matic 7G-DCT',
#  '280CDI Aut.',
#  'de 4M 9G AMG*NightP*HighEnd Infotain*360°',
#  'Diesel+Euro6+voll foliert+Teil-Leder+Navi+Alu+',
#  '350d 4Matic Aut.',
#  'AMG Pano LED B&O 360Kam Massage AHK TV',
#  'Style',
#  'd 4Matic DISTRONIC|AHK|Navi|ParkPaket',
#  'd Style 7G-DCT BI-XENON NAVI RFK SHZ TEMPO',
#  'D 2.2 170CV AUT 5P',
#  'AMG MBUX-High LED Easy-Pack AHK',
#  'G65 AMG+ BRABUS+DISTR+SHD+H&K COMAND+TOTW+KAMERA',
#  'd 4MATIC',
#  'd 4Matic 9G-TRONIC+LED+Advanced Info',
#  '4MATIC 7G NAVI LEDER KAMERA PDC AHK',
#  'AMG-Line LED Navi Leder StHZG Panorama',
#  'e 4MATIC',
#  'd 4M AMG-Line COMAND ILS Leder DTR+ 360°',
#  '316 DOKA+PRITSCHE+KLIMA 7 SITZER 316 CDI',
#  '4M COMAND 360°KAMERA AIRMATIC KEYLESS',
#  'CDI 4Matic COMAND LED KEYLESS 360°KAMERA',
#  '300d 4Matic Aut.',
#  'Edition 55+SD+AHK+DISTRON+TV+MULTIBEAM',
#  'e 4Matic 7G-Tronic*Navi*Distronic*',
#  '* 2016 * Navi * Xenon * Euro6b * Garantie',
#  'CDI Break - GPS - Airco - Leder - Goede Staat!',
#  'T 4M AMG NIGHT HUD,BURMESTER,360GRAD,PANO',
#  'BREAK |\xa0PANO | DESIGNO | CARBON | CAMERA | LED',
#  'd T Business 9G Aut +LED+AHK+Kamera+Navi',
#  'SHB 4-M AMG, NAVI, APPLE/ANDROID, BURMESTER, PANO',
#  'T 4M COMAND,AHK,SCHECKHEFT,SCHIEBEDACH,18Z',
#  'Shooting Brake d AMG NIGHTPAKET DISTRO',
#  'T 4Matic+ *Hybrid*VirtualC*Night Paket',
#  'T CDI Avantgarde Export',
#  'T 4Matic+ *Hybrid*VirtualC*Night Paket',
#  'd Toit Ouvrant , Clim , Navi , Bluethoot , Cruise',
#  'AMG E 43 4Matic T 9G-TRONIC PDC SHZ NAVI',
#  'CDI 4-Matic',
#  'Autom. 4Matic - GPS - Topstaat!',
#  'b*NAVI*LED*LEDER*PDC*AUTOMAAT*',
#  'T AHK LED Navi Night-P. Ambiente el.Klappe',
#  'CDI Avantgarde 7G-Tronic,AHK,Navig,Sportsitze',
#  'SB URBAN NAVI/TEMP./AHK/SHZ/DAB+/PDC/USB',
#  'Estate 200CDI BE Edition',
#  'd 4Matic T 9G Avantgarde+AHK+COMAND+LED',
#  'Shooting Brake 200d 7G-DCT',
#  'AMG CLA 35 4MATIC Shooting Brake',
#  '-Klasse T-Modell Avantgarde Automatik LED RFK Busi',
#  'd 4Matic T 9G-Tronic*Navi*LED*PDC*GRA*',
#  'SB AMG line*Led*Navi*',
#  'SB Urban Night Paket 7G Aut+Xenon+Memory',
#  'T-Modell CDI 4-Matic LED KLIMAAUTO TEMPO',
#  'SB FACELIFT*AMG,NAVI,LEDER,SHZ,ISOFIX* AMG-LINE',
#  'SB d LED Navi SHZ Einparkh. Parkassis',
#  'd T 3x AMG WIDESCREEN,BURMESTER,360GRAD,SH',
#  'd T AMG NIGHT PANORAMA,KAMERA,KEYLESS,1.HD',
#  'E300d T AVANTGARDE AMG-LINE KAMERA WEBASTO PANO',
#  'e Break AMG Line - NP: € 72.565 !! STOCK !!',
#  'Performance 4Matic T-Modell *Virt.Cockpit|ACC*',
#  'T 7G-TRONIC Avantgarde',
#  'Estate 4Matic 7G Plus',
#  'T d Avantgarde Automatik EU6d',
#  'SB 4-MATIC *NAVI,KAMERA,PDC,LED,SHZ*',
#  'T-Modell E 220 d 4Matic All-Terrain',
#  '(+)2.0 AVANTGARDE AUTO 211 5P STATE',
#  'T d 4M AMG Line Panorama*Standhzg*AHK*360°',
#  '4m sb panorama, night pack, keyless-go, sound',
#  'd T Exclusive Leder Navi',
#  'AMG 4M Sitzklima*Burmester*Fahrassist.',
#  'd T 9G Avantgarde NAV+LED+ACC+VCOCKPIT+SHZ',
#  'd Urban*LED*Park-Pilot*7G-DCT*Night*Sitzhz',
#  'E43T AMG COMAND DISTRONIC HEAD-UP 360°KAM AIRMAT',
#  nan,
#  'Estate',
#  '4MATIC',
#  'd 4Matic Avantgarde Distronic|LED|AHK|Navi',
#  'd Shooting Brake',
#  'd Estate Avantgarde',
#  'd Estate',
#  'de Estate AMG LINE',
#  '4M T AMG/Comand/Pano/360/Night/Burmester Autom.',
#  'd Marco Polo Edition Allrad AHK 2,5 t Dis.',
#  'T AMG Line',
#  'T AMG Line',
#  'CDI Blue Efficiency Estate',
#  'd 4Matic T 9G-TRONIC AMG Line',
#  '4 Matic*Shooting Brake*M-Beam*AERO* Klima Navi',
#  'VITO 116 CDI B.TEC TOURER PRO 8-S |NP50€|57tK|1H',
#  'e T PLUGIN HYBRID KOMBI AUTOMATIK 7 GANG NAVI BURM',
#  'AMG E 53 4MATIC+ Estate',
#  'b*AMG*NAVI*PDC*LIKE NEW*',
#  'C200d T Avantgarde *Kamera*Park*LED*Navi*LM*',
#  'T AVANTGARDE AUTOMAT+KLIMA+NAV+LED+KAMERA+',
#  'SB e AMG+NIght+LED+Pano+SoundSyst+',
#  'Mercedes-AMG 4MATIC Estate',
#  'T d 4M AMG Line NP.102.519€*Standhz*Airmat',
#  'd T LED+AHK+DISTRO+COMAND+KAMERA+PTS+SHZ',
#  'T 4Matic+ LEDER NAVI LED NIGHTPAKET 1HD',
#  'de T AMG Line Widesc. Burmester Pano Co',
#  'd T LED+AHK+DISTRO+COMAND+KAMERA+PTS+SHZ',
#  'Estate 220d',
#  'd Estate Business Line',
#  'd Avantgarde 4Matic|Burmester|LED|COMAND',
#  'Estate 220d 9G-Tronic',
#  'T d AVANTGARDE/LED/NIGHT/DISTRONIC/AHK/SHZ',
#  'd AMG/rijassist',
#  'd Avantgarde lang Allrad Standheizung LED',
#  'd Avantgarde lang Allrad Standheizung LED',
#  'Estate Estate',
#  'Td LED SHZ 2x PDC Navigation ToT Winkel Garantie',
#  'd Estate',
#  'd T 4MATIC AMG LED+DISTRO+COMAND+AMBIENTE',
#  'Estate 220d 9G-Tronic',
#  'Shooting Brake',
#  'd T AMG line Night Edition Navi/Temp/Kamer',
#  'Estate 7G Plus',
#  'S SB 4M+ Night Pano Aero 360° 19"',
#  'd 4Matic *BURMESTER,NAVI,KAMERA,LEDER,AZV*',
#  'T LEDER+NAVI+PANO+AKTIV PARKEN+AHK+TÜV',
#  'd + AMG +Burmester + Panodak + Memory + 360 + ...',
#  'E200 T CGI 7G-TRONIC LED Navi Sitzheizung Tempomat',
#  'CDI Urban Style Edition',
#  'CLA45 S AMG SB 4M HEAD-UP MULTIBEAM 360°KAM MBUX',
#  'd T 9G-TRONIC+LED+Navi+AHK+HuD+SHZ+',
#  'Estate 220d 9G-Tronic',
#  'T AMG LINE MULTIBEAM WIDESCREEN AHK CAMERA',
#  'd Estate',
#  'de Estate',
#  'd Estate',
#  '(+)2.1 D AMG LINE 5P',
#  'd Estate',
#  'Estate 200d 9G-Tronic',
#  'CLA-CLASS 2.1 D DCT SHOOTING BRAKE 136 5P',
#  'Shooting Brake BT Aut.',
#  'T LED-Scheinwerfer|Navi|Kamera|PDC|SHZ',
#  'T CGI Avantgarde*PDC*SHZ*Navi*',
#  'd Estate Business Line',
#  'T AMG Line 2x+LED+Nav+HUD+PSD+Distro+Stahz',
#  'B200 CDI AMG AUT 136CV',
#  '!!FULL!! /AMG-PACK/OPEN DAK/KEYLESS/LED/MEMORY/',
#  'CDI BlueEFFICIENCY Edition',
#  'd T 9G-TRONIC NAVI RFK SHZ LED Hig.Perf.',
#  'd T Aut LED Nav Shz Business Plus EURO6d',
#  'd 4MATIC Estate',
#  'T d 4M All Terrain Avantgarde+Exclusiv+20"',
#  'd Estate',
#  'Mercedes-AMG 4M Shooting Brake',
#  '580 4Matic',
#  'd Urban 135PK VR57954',
#  '43 4MATIC+ (MULTI/DAB/360"/BURMESTER/SAGA',
#  '7G Plus',
#  '9G-Tronic',
#  '580 4Matic',
#  'PLUG-IN HYBRID Lang',
#  'CDI BlueEfficiency (204.001)',
#  '1.6',
#  'E 63 AMG E 63 S AMG 4M+ MBUXHighE+PD+Burm+Mbeam+Dr',
#  'BE Elegance 7G Plus',
#  'CGI 4Matic Avantgarde Leder Navi Distr Cam',
#  'BE Elegance 7G Plus',
#  '4MATIC LANG NIGHT|PANO|AIR|360°|BURMESTER',
#  '4Matic 7G Plus',
#  'e AMG+MBUXAdvanced+LED-HP+NightP+SpurA+PTS',
#  'A45S AMG*Aero*Driver´s*Burm*Pano*360°*Distr+*HuD',
#  'd',
#  'Mercedes-AM53 4MATIC+',
#  '4M Lim AMG Line Standhz/Pano/360°/Airmatic Navi',
#  '7G Plus',
#  '220d 4Matic 9G-Tronic 194',
#  '525PS Memory Navi Leder Bi-Xenon BT',
#  '220CDI BE Avantgarde 7G Plus',
#  '-CLASS 4.7 455 4P',
#  '-CLASS 4.7 455 4P',
#  'SE',
#  'd AMG L 4Matic Leder/Distronic/HUD/Pano/Ka',
#  'e Lim Progressive+MBUXAdvanced+SpurAss+PTS',
#  'Mercedes-AMG S 4MATIC+',
#  'Mercedes-AMG S 4MATIC+',
#  '4M Aut.',
#  '-CLASS 2.1 D 4MATIC AUTO 170CV 4P',
#  'BT',
#  'T 4Matic AMG-Line ACC Pano Navi Touch  LED',
#  '200CDI Avantgarde 7G Plus',
#  '220d 9G-Tronic 194',
#  '4Matic 7G-DCT+LED+Navi+Designo+SHZ+',
#  nan,
#  'CDI Business',
#  'AMG E 63 S 4M*Fahrass*Burmester*Pano*Memory*360°',
#  'D*NAVI*LED*URBAN-Line*',
#  'd',
#  'Mercedes-AMG S 4MATIC+',
#  '-CLASS D G TRONIC PLUS AVANTGARDE',
#  '220CDI BE Avantgarde',
#  'e Lim Progressive+MBUX+LED-HP+Mem+KeyG+RFK',
#  'Pano/Distr/KeyG/360/Memory/Burmester Navi/Klima',
#  'CLA 180 AMG coupe',
#  '220BlueTec 7G Plus (4.75)',
#  'AMG + Camera + Lane Assist + Zetelverw. + ...',
#  'd',
#  'd',
#  'Aut.',
#  'd',
#  '4Matic 9G-Tronic',
#  '220CDI Avantgarde Aut.',
#  'AMG + Camera + Carplay + Night pakket + Multibeam',
#  'S 4Matic+ 9G-Tronic',
#  '220d 9G-Tronic 194',
#  '350d 4Matic 9G-Tronic',
#  'Mercedes-AMG 4MATIC',
#  'Keyless + Head-Up + Carplay + DAB + Lane Assist+..',
#  'd',
#  '350d 4Matic 9G-Tronic',
#  'CDI 4M Aut. AMG Line',
#  'lang 4-Matic Autom. Leder Airmatic Kamera Distroni',
#  'd 4Matic AMG*Leder*Navi*LED*Kamera* AMG',
#  'e Lim Progressive+MBUX+NavPr+LED+Sound+RFK',
#  'e Largo',
#  '*Navi*Bluetooth*Tempomat*Klima*',
#  '*Navi*Bluetooth*Tempomat*Klima*',
#  '220CDI BE Avantgarde Edition',
#  'de AMG Line HuD|Pano|LED|Park-Assistent',
#  '220CDI BE Aut.',
#  'AMG*AmbientLight*StHz*Totwinkel*MBUX*',
#  '4 Matic Autom. LED~NAVI~SHZ~2xPDC~ALU',
#  'de',
#  'e Lim Progressive+MBUXHigh+LED+18+Sound+RK',
#  '4MATIC DIGITAL LIGHT+HUD+BURMESTER+PANO',
#  'e Limousine AMG/NAVI/LED/MBUX/PTS/SHZ',
#  '350+',
#  'd 4MATIC',
#  '320CDI Avantgarde 7G',
#  'CLA-CLASS 2.1 CDI DCT 170CV 4P',
#  'CLA-CLASS 2.1 CDI DCT 170CV 4P',
#  '350 4M grau magno PROGRESSIVE+AHK+PANO+TOTW',
#  'd Lim. Avantgarde COMAND ILS Leder ParkA.',
#  'd AMG',
#  'd +DISTRONIC+Gr.Tank+MBUX+5 Fahrassistsys',
#  '4M *Night*Sitzhzg*Kamera*Standhzg*LED*',
#  'A45 S 4M AMG+DISTR+PANO+BURM+AMBIE AERO+360++HUD',
#  '+ AMG MBUX+360°+Pano+DIG-LED+HUD+Distro',
#  'e Limousine AMG LINE/KAMERA/NAVI/PTS/LED',
#  'BlueTEC Sport',
#  'e Lim AMG+MBUXAdvanced+LED-HP+Spur+ParkAss',
#  'd',
#  '220d 9G-Tronic (4.75)',
#  '4MATIC',
#  'A -Klasse A 160 NAVI SHZ',
#  'Mercedes-AMG S 4MATIC+',
#  'e Lim AMG+MBUXAdvancedP+NightP+Spur+Kamera',
#  'S 4M+ AMG Aerodynamik Night 19" Pano',
#  'C 63 ILS+BURMESTER+KAMERA+KEYLESS+TEMPOMAT+SHZ',
#  'Mercedes-AMG 4MATIC',
#  'CLS-CLASS 272 4P',
#  'AMG*NightP*Digital-Light*AHK*',
#  '4M Aut.',
#  'd',
#  'e Lim Progressive+MBUXAdvanced+SpurA+ParkA',
#  'Blue Efficiency Avantgarde',
#  'Business Solution AMG (EU6d-TEMP)',
#  '+ EDITION1+AMG+AIRMATIC+PANO+HUD+MEMORY',
#  'CDI Avantgarde',
#  '220d 9G-Tronic (4.75)',
#  'e Lim MBUXAdvancedPaket+SpurAss+ParkAssist',
#  'CDI BE Avantgarde Blue Effic. Ed.',
#  'e Lim Progressive+MBUX+NavPr+LED+Sound+RFK',
#  'BT Edition 1 Aut.',
#  '350d 4M Largo 9G-Tronic (9.75)',
#  'BlueTEC 4Matic (212.011)',
#  'Business-Solution',
#  'Org. 61.000km Aut. Historie 1A Sammlerzust.',
#  'd AMG Line (EURO 6d-TEMP)',
#  'A -Klasse A 200 CDI  *Navi|PDC|SHZ|App-Connect*',
#  '220d 9G-Tronic (4.75)',
#  'de',
#  'e AVANTGARDE+NIGHT+PANO+AHK+SOUND+KAMERA',
#  'e AVANTGARDE+NIGHT+PANO+SOUND+LEDER+KAMERA',
#  'MBUXHE/Pano/Multibeam/Burmester/Night AMG Line',
#  'Mercedes-AMG 4MATIC',
#  'Limo MBUXHE/AMG Aero/360/Multibeam/HUD AMG Line',
#  '400d 4Matic Largo 9G-Tronic',
#  'd Urban+Navi+AHK+Nightp+LED+KAM+Memory+18"',
#  'AMG-Line BlueEfficiency SR&WR Pano SHZ',
#  '1.3CDTI Business75',
#  'GTC 2.0 T OPC',
#  '1.3CDTI Business75',
#  'D Energy 1.2*1.Hand*Alu*lückenlos Scheckheft',
#  '1.2T XHL S/S Edition 100',
#  '1.7CDTI Cosmo',
#  '1.6CDTi S/S Dynamic 136',
#  '1.6T PHEV S/S GS-Line Aut. 180',
#  'Aut. 1.4 Color  CARPLAY SHZ LHZ PDC KLIMA',
#  '1.3 CDTI DPF (ecoFLEX) Selection',
#  '1.6CDTi S/S Dynamic 136',
#  'Glam Pano.-Dach/Klima/MF-Lenkrad/BC/eFH. Tempomat',
#  '1.4 Business 90 (4.75)',
#  '1.6CDTi S/S GSi Line 160',
#  '1.4 66KW (90 CV) EXPRESSION PRO',
#  'E 1.4 Selection Klima*Scheckheftgepflegt',
#  'S 1.4 TURBO *LEDER RECARO*INFINITY SOUND*CARPLAY*S',
#  'E 1.4 Turbo GSi Xenon Sitzheizung PDC',
#  '1.2 XEL S/S Edition 75',
#  '1.7CDTi Enjoy 100',
#  '1.2 XEL S/S Edition 75',
#  '1.4 Selection 100PK YY22344',
#  '*Lenkradheizung*PDC hinten* Color Edition',
#  'D 1.2 Edition',
#  '1.5D DT S/S GS-Line + 100',
#  '1.4T S/S Dynamic 125',
#  '1.6CDTi Business + 110',
#  '1.4 Active Automatik EU6 Klima PDC Sitzheizung Tem',
#  '1.4 Business 90 (4.75)',
#  '1.2T S/S Design & Tech 130',
#  '1.4 XEL S&S Glam',
#  '1.2 XEL S/S Edition 75',
#  '1.0 Edition EcoFlex 90PK WH98944',
#  'E 1.4 Turbo GSi XENON',
#  'E 1.4 Turbo OPC Line Bi-Xenon Sitzheizung',
#  'D Color Edition Klima PDC SHZ Lenkradheiz.',
#  'E Turbo GSi Klima/Xenon/Sitzheizung/DAB Sitzhzg.',
#  'D Black Edition 5D 1.4B 100PK + Navigatie',
#  '1.4 EU6d-T Edition ecoFlex S/S',
#  '1.4 XEL S&S Glam',
#  'Comfort 1.0',
#  'F 1.2 Turbo Elegance -Sitzhzg./Klimaautom.',
#  'EU6d F 1.2 Edition/Klima/Lenkradheizung/Tempomat/S',
#  '1.4 66KW (90 CV) EXPRESSION PRO',
#  '1.4 66KW (90 CV) EXPRESSION PRO',
#  'GTC 1.6CDTi S/S Sportive',
#  '120 Jahre ecoFlex 1.4 Turbo EU6d-T/Sitzheizung/Tem',
#  'F 1.2 EU6d/Tempomat/Spurhalteassistent/Klimaanlage',
#  'E 1.4 Selection *USB*KIima*elektr. FH*',
#  '1.4 Slam PDC SHZ ONSTAR INTELLILINK LED',
#  '1.0 Edition Klima Bluetooth Telefon Garantie',
#  '1.4 XEL S&S Jam',
#  'F Elegance 1.2 Turbo LED Rückfahrkam. Fernlichtass',
#  '1.4 Jam Klima Sitzheizung Apple Carplay PDC',
#  'S 1.4 Turbo KLIMA ONSTAR INTELLILINK LED',
#  '1.2 Enjoy',
#  ...]

# %%
# in manufacturer color paint type is also mentioned along with color.
# manufacturer color which is customized by producer is highly probable that owner would be using same paint type.   
df[df.manufacturer_colour.str.extract("(\s*pearl\w*)", flags= re.IGNORECASE).notnull().values.flatten()]["manufacturer_colour"]
# Out:
# 4844                Black Pearl-Schwarz
# 4868       Black Pearl-Schwarz Metallic
# 4876                Black Pearl-Schwarz
# 4878                        Black Pearl
# 4880       Black Pearl-Schwarz Metallic
#                       ...
# 29095    Crystal White Pearl / Metallic
# 29115    Crystal White Pearl / Metallic
# 29142    Titanium Grey Pearl / Metallic
# 29276      Oyster Grey Pearl / Metallic
# 29436               Crystal White Pearl
# Name: manufacturer_colour, Length: 205, dtype: object

# %%
df[df.manufacturer_colour.str.extract("(\s*metal\w*)", flags= re.IGNORECASE).notnull().values.flatten()]["manufacturer_colour"]
# Out:
# 5             Diamant Schwarz  Metallic
# 10                       Grijs Metallic
# 13                       Grijs Metallic
# 23               Mountain Grey Metallic
# 29         Kosmosschwarz - Metalliclack
#                       ...
# 29433             Onyx Black / Metallic
# 29455          714 Osmium Grey Metallic
# 29460              Argento Metallizzato
# 29462    Blackberry Metallic (Paars Met
# 29477    Denim Blue Metallic (Blauw Met
# Name: manufacturer_colour, Length: 5036, dtype: object

# %%
df.loc[df.loc[df.manufacturer_colour.str.extract("(metal\w+)", flags= re.IGNORECASE ).notnull().values.flatten()].index, "paint"] = "Metallic"

# %%
handle_missing_values(df, "paint")
# Out:
# Missing Values in 'paint':
# Count: 13793
# Percentage: 48.22%

# %%
df.loc[df.loc[df.manufacturer_colour.str.extract("(solid\w*)", flags= re.IGNORECASE).notnull().values.flatten()].index, "paint"] = "Uni/basic"

# %%
handle_missing_values(df, "paint")
# Out:
# Missing Values in 'paint':
# Count: 13607
# Percentage: 47.57%

# %%
df.loc[df.loc[df.manufacturer_colour.str.extract("(\s*pearl\w*)", flags= re.IGNORECASE).notnull().values.flatten()].index, "paint"] = "Pearlescent"

# %%
handle_missing_values(df, "paint")
# Out:
# Missing Values in 'paint':
# Count: 13588
# Percentage: 47.51%

# %%
df.loc[df.desc.str.extract("(matte)", flags= re.IGNORECASE).notnull().values.flatten()].index
# Out:
# Int64Index([    8,    16,    30,    31,    41,    55,    58,    65,    72,
#                76,
#             ...
#             29255, 29267, 29283, 29288, 29350, 29367, 29399, 29400, 29446,
#             29455],
#            dtype='int64', length=2018)

# %%
# Some of nan values in paint column mentioned in description column 
# matte keyword is searched and filled according to desc 
df.loc[df.loc[df.desc.str.extract("(matte)", flags= re.IGNORECASE).notnull().values.flatten()].index, "paint"] = "Matte"

# %%
handle_missing_values(df, "paint")
# Out:
# Missing Values in 'paint':
# Count: 13157
# Percentage: 46.00%

# %%
# metal keyword is searched and filled according to desc 
df.loc[df.loc[df.desc.str.extract("(metal\w+)", flags= re.IGNORECASE).notnull().values.flatten()].index, "paint"] = "Metallic"

# %%
handle_missing_values(df, "paint")
# Out:
# Missing Values in 'paint':
# Count: 11437
# Percentage: 39.99%

# %%
# remaining nan values are considered as solid = Uni/basic since this type is the most commonly used paint type other than metallic
df.paint.fillna("Uni/basic", inplace = True)

# %%
handle_missing_values(df, "paint")
# Out:
# Missing Values in 'paint':
# Count: 0
# Percentage: 0.00%

# %% [markdown]
# <a id="22"></a>
# <div class="alert alert-info" role="alert">
# <h1>Column name :<span style="color:red"> country_version </span></h1>
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Operation : </b> To fill in the missing values in the "country_version" column, we can use the "short_description" column . Since the "country_version" column is associated with <span style="color:red"><b>" make_model " , " first_registration " , " body_type "  and " drivetrain "</b></span> . let's fill in the <span style="color:red"><b> NaN values</b></span> in this column by grouping the data based on these columns and performing the necessary operations.
# </div>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
first_looking("country_version")
# Out:
# column name    :  country_version
# --------------------------------
# per_of_nulls   :  % 40.99
# num_of_nulls   :  11723
# num_of_uniques :  25
# NaN               11723
# Germany            7938
# Spain              6372
# Italy               679
# Belgium             641
# European Union      340
# Netherlands         301
# Austria             266
# France              101
# United States        57
# Czechia              47
# Poland               31
# Hungary              21
# Denmark              21
# Romania              12
# Japan                12
# Switzerland           9
# Luxembourg            9
# Sweden                6
# Slovenia              5
# Slovakia              4
# Croatia               3
# Bulgaria              1
# Malta                 1
# Canada                1
# Mexico                1
# Name: country_version, dtype: int64

# %%
# Let's examine the short description of the country_version 
list(df.loc[df[df["country_version"].isnull()].index, "short_description"])
# Out:
# ['4MATIC',
#  'CDI 90PK NK77971',
#  'd 116PK RZ47072',
#  'e Limousine',
#  nan,
#  'CDI',
#  'Avantgarde/Park Assis/Navi/Scheckheft/Bi-X',
#  'Limousine',
#  nan,
#  'Berline - Garantie 48 mois - 316.41 €/mois*',
#  'CDI BlueEfficiency Standard 110PK MZ74192',
#  'progressive mbux, dab, apple carplay',
#  '-Klasse Navi RDC Klima SHZ DVD CD-W CD MP3 ESP MAL',
#  'AUTOMATIK NAV LED KAMERA PARK-ASSIST SHZ DIG-DISPL',
#  nan,
#  nan,
#  'S 4MATIC+',
#  'AMG Line AUTOMATIK NAV LED KAMERA NIGHT PAKET SHZ',
#  'progressive mbux, camera, lane assist, pdc',
#  'progressive led high performance, mbux, lane assis',
#  'CDI Blueefficiency Edition Style 110PK EF53658',
#  'C Coupe (BM 190)',
#  '300E',
#  '4-Door Coupe 43 4MATIC+ Premium AMG, NIEUWSTAAT!!',
#  '4-Door GT 63 S CARBON AERO 5-ZITS HUD',
#  '4-Door Coupe 53 4MATIC+ Premium | AMG Trackpace |',
#  '580 4MATIC AMG Line Premium plus | Rij-assist + |',
#  '450+ AMG Line 108kWh',
#  'S AMG 4MATIC+',
#  '4-Door Coupe 43 4MATIC+ Premium Plus 63 AMG Uitgev',
#  'A35 AMG 4MATIC Premium+ 306PK | Pano | Sfeer | Bur',
#  'Business Solution AMG',
#  '4-Door Coupe 43 4MATIC+ Premium Plus PANO, BURMEST',
#  '4MATIC PERFORMANCE AERO PACK/SCHAAL/PANO/MEMORY VO',
#  '4MATIC l Top staat! l Panorama l Camera l Dealer O',
#  'AMG/ NIGHT PAKKET/ PANO/ AMG SPOILER',
#  'CDI Ambition 4U3 Navigatie',
#  'd Business Solution Automaat - Cruise - Navi - Hal',
#  '4MATIC STOELVERWARMING/AERO/381PK/BOMVOL',
#  '350 AMG Line 90kWh Premium Pack',
#  'd Lease Edition Ambition',
#  'CDI Ambition [ Xenon | Navi | Cruise ]',
#  'A35 AMG 4-MATIC *Pano*Burmester*4AMG Aero*Vol!*',
#  '4MATIC [ Panorama Xenon Leder ]',
#  'Business Solution AMG',
#  'Business Solution AMG',
#  'AMG Sport Prestige Automaat (NAVIGATIE, TELEFOON,',
#  '4MATIC Edition 1 MEMORY/PANO/LEER/H&K/BOMVOL',
#  'CDI Air-Lift Schuifdak Harman/Kardon Night Leder U',
#  'AMG A 35 4MATIC',
#  '4MATIC | 381PK | Apple Carplay | Stoelverwarming |',
#  '4MATIC 280kW/381pk DCT7 NIGHT PAKKET + PANORAMADAK',
#  'Premium Night Aut. [ Burmester Widescreen Half-Led',
#  'Premium+ AMG Edition 1 225PK | Pano | Sfeer | Virt',
#  '4-Door 63 S 4MATIC+',
#  'Premium Plus | AMG Line | Lederen bekleding | LED',
#  '4MATIC | Pano | Navi | PDC | Cruise |',
#  'D AMG Pakket / Panoramadak / Navigatie / N.A.P.',
#  'e AMG Line Panodak',
#  'AMG Edition Sport Automaat (SCHUIFDAK, APPLE CARPL',
#  'Business Solution AMG',
#  'Automaat | Leder Interieur | 1j Garantie',
#  'd Led Navigatie Stoelverw. Carplay Leer Zondag a.s',
#  'A35 AMG 4MATIC Advantage',
#  'Ambition | Harman | ACC | Pano | CAM | AMG-Line',
#  '200 CDi 1.8 CDI Boîte auto',
#  'CLASSE  d Fascination 4Matic 7G-DCT',
#  'AMG Ambiante verlichting Panodak Camera Zondag a.s',
#  '200 d Fascination 7G-DCT',
#  '-Edition BlueEfficiency',
#  'd AMG PANORAMADAK/WIDESCREEN/SFEER/MEMORY/BOMVOL',
#  "Ambition NAVI BT LEDER PDC LED STOELVERW '16",
#  'd AMG / Panorama dak / Leder / Navi / Pdc / Led /',
#  'AMG Stoelkoeling ACC Multibeam LED Burmester Panor',
#  'AMG PANORAMADAK/ WIDESCREEN/ SFEER/ AUTOMAAT/ BOMV',
#  'CDI Edition Navigatie 4U3',
#  nan,
#  'Ambition | Automaat | Stoelverwarming | Navigaties',
#  'Sport Ambition AMG-Exclusief Pakket',
#  'AMG 123PK | Pano | Sfeer | Grote Navi | Camera | G',
#  'AMG Sport Automaat (APPLE CARPLAY, GROOT NAVI, CLI',
#  'Solution AMG PANORAMADAK, NAVIGATIE, ECC AIRCO,',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  'AMG Line, Automaat, LED',
#  'Ambition',
#  '35 AMG 306ch 4Matic 7G-DCT Speedshift AMG',
#  'Business Solution AMG Upgrade | NAVIGATIE | CAMERA',
#  'Sport Ambition 211PK/AMG/Nieuwstaat/Alcantara/Lede',
#  'Business Solution AMG PANO/MEMORY/WIDESCREEN/LEER/',
#  'Automaat AMG Sportpakket-Leder-Navigatie-Full Led-',
#  'AMG-LINE',
#  'Prestige 122PK | FG02071 | Navi | Climate | Half L',
#  'd Business Solution Plus Upgrade, Automaat, LED, L',
#  'CLASSE  CDI Inspiration',
#  'Edition Navigatie 4U3',
#  'AMG Night Panodak',
#  'd ACC NAVIGATIE LM VELGEN SPORTSTOELEN LEDER',
#  'BlueEFFICIENCY Ambition',
#  'AMG LINE -PANO',
#  'd Style + Pneus Hiver',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  'Ambition Automaat Bi-Xenon, Airco, Cruise, PDC, AM',
#  'AMG Memory Multibeam LED Panorama Sfeerverlichting',
#  'Ambition Automaat AMG Pack',
#  '200 d 150ch Progressive Line 8G-DCT 8cv',
#  'Sport Automaat (SCHUIFDAK, GROOT NAVIGATIE, PARKEE',
#  'AMG Sport 7G Automaat BiXenon Becker Map Pilot Nav',
#  'AMG PANORAMADAK/WIDESCREEN/SFEER/AUTOMAAT/ BOMVOL',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '200 d Business 7G-DCT',
#  'Business Solution AMG, Automaat, LED, Navigatie',
#  '200  Sport',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  'd Business Solution, Automaat, Navigatie',
#  '100 PK Ambition | Cruise | PDC | Airco | NAV | LED',
#  'Business Solution Automaat, Navi, Bluetooth/Tel, M',
#  'BlueEfficiency 122PK | PK10244 | Navi | Bi-Xenon |',
#  '220 d Fascination 7G-DCT',
#  'AMG LEDER LED NAVI LMV CRUISE',
#  'AMG Aut. [ LED Navi Camera ]',
#  'Business Solution AMG I AVANTAGE I AUTOMAAT I MBUX',
#  'My First Star',
#  'AMG/ PANO/ NIGHT/ CAMERA/ VOL!',
#  '35 AMG 306ch 4Matic 7G-DCT Speedshift AMG 19cv',
#  '200 d Inspiration 7G-DCT Euro6c',
#  'Ambition 120 PK - Automaat | Schuif/kantel-dak | C',
#  'Classe  d (cdi) Premium auto FL E6',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  'd Progressive 7G-DCT',
#  '220 190ch Progressive Line 7G-DCT Siege chauf gran',
#  'CDI Ambition [ Xenon Climate Navi Cruise LM Velgen',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '220 d 190ch AMG Line 8G-DCT 10cv GPS Camera Radar ',
#  '180 d 116ch Business Line 7G-DCT',
#  '200 d 150ch Business Line 8G-DCT GPS Camera',
#  'Premium Plus | VERWACHT! | BTW Auto | Apple Carpla',
#  '180 d 116ch AMG Line 7G-DCT',
#  '200 d Inspiration 7G-DCT',
#  'Hatch * Carplay | Parkeersenoren | Zetelverw.',
#  '200 163ch Style Line 7G-DCT',
#  '35 AMG 306ch 4Matic 7G-DCT Speedshift AMG TOuvrant',
#  '200 d 150ch AMG Line 8G-DCT 8cv',
#  'd Style + Pneus Hiver',
#  '200 d Fascination Tpano GPS Camera',
#  '180 d 116ch AMG Line LED GPS Camera Radar AV/AR',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '180 136ch Progressive Line 7G-DCT 7cv',
#  '180 d Sensation 7G-DCT',
#  'e A 250e Progressive Sfeerverlichting / NIEUW GERE',
#  '200 d 150ch AMG Line 8G-DCT',
#  '220 190ch Progressive Line 7G-DCT',
#  '180 d Sensation 7G-DCT',
#  'e Advantage LED / Navi / Aut / Cam / Half leder /',
#  '180 136ch Business Line 7G-DCT',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  'Business Solution AMG | Navigatie | Dealer Onderho',
#  '7G-DCT Business Solution AMG (Koop nu online!)',
#  '220 190ch Progressive Line 7G-DCT Ecran 10 GPS Cam',
#  '180 d Intuition 7G-DCT',
#  '160 109ch Style Line',
#  '200 163ch AMG Line 7G-DCT',
#  '160 Inspiration 7G-DCT',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '180 d 116ch Progressive Line 7G-DCT',
#  'Coupé 3.0 CDI V6 DPF 7G-TRONIC BlueEFFICIENCY 265',
#  'AMG AUT/ PANO/ LEDER/ CLIMA/ CRUISE',
#  'BENZINA + GPL NUOVO + UNICO PROPRIEATARIO',
#  '136 CV "40.335 KM!!!" VETTURA UFFICIALE ITALIANA',
#  'A35 AMG 4MATIC Edition 1 |Pano | kuipstoelen | sfe',
#  'A 45 AMG 4Matic Automatic',
#  'd Progressive',
#  'E 280',
#  'A35 AMG 4-Matic |306PK|FULL OPTIES|',
#  '4MATIC SCHAALSTOELEN/PANO/SPOILER',
#  'e 8G-DCT AMG Line',
#  'Special Edition Xenon Leder Memory Kam',
#  'CABRIO 3x AMG SPORT COMAND,KEYLESS,KAMERA',
#  'Aut. Comand+Xen+Airsc+SHZ+PDC+Leder',
#  'Roadster~KAMERA~LEDER~\xa0GT FELGEN~XENON~',
#  'AMG Gepflegt MEMORY BI-XENON NAVI',
#  'Roadster Edition50 1 500 Designo',
#  'C Roadster',
#  'C Roadster  | AMG Dynamic Plus Paket |',
#  'GT S Roadster KAMERA+BURMESTER+MEMORY+AIRSCARF',
#  'SL 43 DIGITAL LIGHT+BURMESTER+DISTRO+HUD+MEMORY',
#  'CDI pack AMG  * Capteurs, Gps, Sg chauff, ...',
#  'C Roadster EDITION50/KERAMIK/SITZKLIMA',
#  'C Cabrio COM+Burm+LED+Distr+PerfS+Mem+RFK',
#  'S Cabrio Sitzlüft HeadUp 360° Drivers',
#  'C Roadster Edition 50 SITZKLIMA/MEMORY',
#  'Comand+Airscarf+Airma+BIXen+Memory+19"AMG',
#  'SL Autom, Leder, Sitzheiz.',
#  'Autom. Leder Airscarf Xenon Navi 2. Hand',
#  'Cabrio 4Matic 9G Navi+Leder+LED+DAB+el.Sitze+Sound',
#  'SL *Pagode*3.Besitz/Dt.Fahrzeug/H-Zul.',
#  'C 43 4MATIC Cabrio ILS+BURMESTER+DISTRO+AIRSCARF',
#  "*LEDER*NAVI*KAMERA'SITZBELÜFTUNG",
#  'Roadster *DEUTSCH* (BOSE/DESIGNO/BI-XE',
#  'GT Roadster BURMESTER+SITZKLIMA+DISTRO+MEMORY',
#  'Kompressor Xenon SHZ PDC Klimaauto.Leder',
#  '4M CABRIO AMG ENERGIZING+MBUX-HIGH+KOMFORT',
#  'Cabrio 4M Sportabgas LED HUD Kamera 19"',
#  'ANDERE 43 Premium-Navi*360°Ka.*AIRSCARF',
#  'Roadster AMG Performance Sitzklima Comand',
#  'Roadster AMG/BIXENON/BURMESTER/KEYLESS',
#  'PERFORMANCE NIGHT SPORTABGAS BURMESTER',
#  'CABRIOLET AVANTGARDE AUTOMAT+LEDER+ALU',
#  'C 63 S Cabrio DRIVERP+DISTRO+KAMERA+AIRSCARF+LED',
#  'Cabrio Benzine Autom. - airco - Leder',
#  'd 4M Cabriolet AMG Sport Distr LED Navi',
#  'Cabrio *Avantgarde*Night*LED*Kamera*Navi*',
#  '-Klasse Cabrio Cabriolet AMG-Line',
#  'AMG+COM+PanoV+LED-ILS+B&O+MILLEMIGLIA417',
#  'SLK Roadster 200 Kompressor*Leder*SHZ*Klima',
#  'S Cabrio Night Distronic+ Burmester',
#  'd 4M Cabrio AMG Line LED Navi Kamera PT',
#  'd 4M Cabriolet AMG Sport ABC Distr LED',
#  'AMG - BOITE AUTO ✅ GARANTIE ✅ LED - BLUETOOTH',
#  'COM+PanoVario+LED-ILS+AIRSCARF+TotwA+PTS',
#  'd 4M Cabriolet AMG Sport Sitzklima Keyl',
#  'Roadster Sport Comand.ILS.H&K erst72261KM',
#  'Cabrio CGI AMG ILS Airscraft Navi Leder PDC',
#  '4M Cabrio *AMG*Night*Multibeam*Comand*HUD*',
#  'SL Pagode',
#  'Cabriolet  4Matic+ ABSOLUTE VOLLAUSTATTUNG',
#  '4M Cabriolet Distr LED HUD Navi Kame',
#  'Roadster Comand+RüKam+LED+PerfAbgas+Distr',
#  'K AUTOMAT+KLIMA+LEDER+XENON+AIRSCARF+TÜV',
#  'd Cabriolet',
#  '4M Cabrio AMG+20"+AIRMATIC+HUD+STANDHZG',
#  'Cabriolet Aircap*Airscarf*LED*Business-Pa.',
#  'Cabrio AMG-Line NAV+LED+KAMERA+18ZO+EU6dT',
#  'Cabriolet AMG Line',
#  'r107 original belgian delivery! first owner car.',
#  'CABRIOLET AMG+DESIGN+LEDER+XENON+AIRSCARF+',
#  'Cabrio CGI Automatik Nackenheizung',
#  'Roadster Kompressor/Xenon/Navi/Leder',
#  'R107 Cabrio Hardtop + Softtop H-Kennzeichen',
#  'Roadster Leder LED Kurvenlicht Panorama Fernlichta',
#  '4M Cabrio 19"+CARBON+MULTIBEAM+COMAND',
#  'Cabrio Navigation+LED-HP+CabKomfort+Kamera',
#  'S Cabriolet Wide 20" Burm Sitzklima',
#  'AMG Alu+COMAND+XENON+PDC+TEMPOMAT+PTS',
#  'Cabriolet AMG Night Edition LED Navi SH',
#  'Cabrio *LED ILS*',
#  'C 63 S AMG Cabrio Performance Sitze/Lenkrad/AGA',
#  'perfekte Komplettrestaurierung, nur 67.000 km',
#  '4M+ Night+MBUX+Distro+21AMG+360°+HUD',
#  '4M+ Cabriolet Vmax Distr LED HUD Nav',
#  'R107 Cabrio Hardtop + Softtop US Modell H-Kennzeic',
#  'Cabrio AMG Line Navi/Alcantara/Temp/Kamera',
#  'C 63 Cabrio BURMESTER+MULTIB+360°+AIRSCARF+DISTR',
#  '* Klima* Sitzheizung* Alu*',
#  'Cabrio AMG Line LED Navi Kamera Airscar',
#  'd 4M Cabrio AMG Line Burm HUD Multib 36',
#  'SL Roadster',
#  'Cabrio AMG Line2x+Spur+LED+Kam+Nav+DAB+18"',
#  'Cabrio Night+Drivers+Sp.Abgas+360°+Coma',
#  'Kompressor Aut. Cabrio Final Edition',
#  'd Cabrio AMG Line 2x+Burme+Comand+Sistzkli',
#  'Cabrio 4M Comand+HUD+LED+KAM+High-End+DAB',
#  'd Cabrio AMG Line2x+Night+Kam+LED+DAB+Wide',
#  'Cabrio LORINSER UMBAU/AHK/ELEKTR. SITZE',
#  'Cabrio LORINSER UMBAU/AHK/ELEKTR. SITZE',
#  'Deutsches Fahrzeug  Sammlerzustand',
#  'Cabrio AMG Line 9G-Tronic+Nav+LED+Airscarf',
#  nan,
#  'Originale 52.000KM Roadster SHZ TEMPO',
#  'Cabriolet AMG Line',
#  'E -Klasse Cabrio E 200 AMG Line+Burmester+CAM',
#  'SL 63 4M+ HUD*Airscarf*MemoryP*Hinterachsl*Night',
#  'Cabrio AMG AHK+MULTIBEAM+360°+AIRSCARF+SHZ',
#  'Cabrio AMG/LED/TOTWINKEL/PTS/RFK/AIRSCARF',
#  'd Cabrio AMG+MBUXHighEd+LED-HP+20"+Mem+RFK',
#  'Cabrio *V8*',
#  'Navi+LED+Air+Panorma+Leder+PDC+9GTronic',
#  'Autom. Top-Zustand aus 2. Hd. Deutsches M.',
#  'AMG Paket Kamera SoundSyst Memory HUD 19"',
#  'Cabrio AMG Line Multib Comand Airscarf',
#  'Cabrio Avantgarde+MBUXHigh+LED-HP+Distr+RK',
#  'Klima Sitzheizung Navi',
#  '220 d AMG Line+Alcantara+MulitBeamLED+Keyless',
#  'Avantgarde Cabrio AHK+AIRSCARF+KAMERA+DAB',
#  'Cabrio AMG Line 2x+Coma+Multib+DAB+Kam+18"',
#  'Cabrio AMG Line 2x+Comand+Kam+18"+Multibea',
#  'd Cabrio AMG Line 2x+Kam+LED+DAB+Wide+19"',
#  'Cabrio AMG Line High-End Info Adv.Park',
#  'Cabrio AMG Line 2x+Comand+LED+Kam+PDC+DAB',
#  'Cabrio AMG Line 2x+Night+Distr+LED+DAB+18"',
#  'd Cabrio Avantgarde Mulitbeam Burmester',
#  'd 4M Cabrio AMG Line AHK Standhz Multib',
#  'AMG Paket H/K Belüftung Panorama Comand',
#  'AUTOMATIQUE - GARANTIE 12 MOIS - GPS-XENON-DESIGNO',
#  'Navi*Alu19*Leder*',
#  'Cabriolet AMG Line',
#  'Cabriolet CDI Blueefficiency 164PK RG05871',
#  'Classe E AMG 53 4MATIC+',
#  'V12 - Origineel Nederlands -',
#  'Roadster 4.0 Facelift - Airscarf - Touchpad',
#  'H/K-L7 MEMORY AIRWAVE CAMERA NAVI LEDER STOELVERW',
#  'SL63 AMG Carbon Editie | 1ste Eig | 1j Garantie',
#  'Roadster AMG Magic Sky H&K Distronic',
#  'Cabriolet 4MATIC',
#  'Carbon Editie - 1e eigenaar - Keuring + Garantie',
#  'CILINDRATA 2.000 Sport AUTOMATICA PELLE NAVI FULL',
#  '200 K.',
#  'Performance Package - Carbon',
#  'Roadster*Distronic*Bose*Sitzk.*2.Besitz*Ö-Auto*',
#  'C SW 200 d  auto',
#  'GE',
#  'cilindrata 2.000 Sport AUTOMATICA PELLE NAVI FULL',
#  'Mercedes- C Roadster',
#  'Cabriolet AMG Line',
#  'cat Sport*AIR SCARF*SOSPENS ATTIVE*SEDILI RISC*HAR',
#  '(R129)',
#  nan,
#  '(R129) 2nd Owner/Collectable',
#  'Cab.4M 9G+AIRMATIC+Carbon+AMG Line+360°Kamera',
#  'Cabrio 1e eigenaar-Dealer onderhouden-Complete his',
#  'SL Roadster SL 63 AMG Keramik Top-Zustand',
#  'auto',
#  'Cabriolet 4Matic',
#  'Kompressor  1PROPRIETARIO ! TAGLIANDI MERCEDESBENZ',
#  'Sport*MAE Original*Bose*Memory*Xenon*',
#  'Extrem gepflegtes Ex-Pressefahrzeug W 231',
#  '(R171) 350 7GTRO',
#  'Cabrio',
#  'Cabriolet S 4MATIC',
#  'C Roadster',
#  'Cabrio',
#  'SL',
#  'Cabriolet Elegance lpg revisie moterblok',
#  'cabrio d  Premium Plus 4matic auto',
#  'CABRIOLET 2.1 CDI 204CV AUTO GARANTIE 6 MOIS',
#  '220 d executive a',
#  '4MATIC+ Cabriolet V-Max 360°*Sitzklima',
#  '4MATIC Cabriolet AMG Night HuD*360°*Sitz-K',
#  '4M Cabrio AMG Distro+Parktronic+Spiegel',
#  'Cabrio  eq-boost 4matic + auto my20',
#  '| 48.000KM | Orig. NL | BOSE',
#  nan,
#  '200 AMG Sport 7G-Tronic BVA',
#  'Cabrio',
#  'CLK Cabrio 230 k evo Elegance',
#  '250 d Sport auto',
#  'Cabriolet Premium Plus 1e Eigenaar, AMG-pakket, Bu',
#  nan,
#  'cilindrata 2.000 Sport AUTOMATICA PELLE NAVI FULL',
#  '4M Cabrio AMG+COM+Burm+Mbeam+20+Distr+360°',
#  'Cabriolet 4MATIC PERFORMANCE SEATS 36838KM!',
#  'Roadster Speedshift 7G-DCT,Burmester,Abgsoundsyst.',
#  '220 A Cabriolet',
#  'ROADSTER',
#  'V6 231pk Automaat Prest. Plus NL-auto',
#  'SL 500 V8',
#  'Kompressor',
#  'AMG Line',
#  'S cabrio BURMESTER | LED | 360° | TRACK PACE',
#  '190SL',
#  "AUT NAVI BT AIRWAVE LEDER STOELVERW PDC CRUISE '11",
#  '4M Cabrio PerfAbgas.+M-LED+Comand+RüKam',
#  'AUT 245pk! 1eEIG YOUNGTIMER XENON LEDER NAVI CRUIS',
#  'K. Season Edition | Navi | Leder',
#  'S Cabriolet Ponton Typ A (W 180)',
#  'Neu ohne Zulassung - Vollaustattung - sofort',
#  'AMG | Airco | Cruise | Stoelverwarming',
#  'Cabrio  eq-boost 4matic + auto my20',
#  'K. Cabrio / Leder / Airco / Stoelverwarming',
#  'CDI BlueEfficiency E -Klasse Cabrio (BM 207)',
#  'Roadster Aut.',
#  'Roadster 4.0 | Performance-uitlaat | Night-Pakket',
#  'E Cabrio 220 d Premium auto',
#  nan,
#  'd Cabriolet',
#  'Leder AD Dyn. Kurvenlicht Klimasitze e-Sitze Nacht',
#  'V8 4Matic Autom. - Designo - Topstaat! 1Ste Eig!',
#  'S Coupe EDITION1 PERF. AGA DIST. 19°',
#  '7G-TRONIC 8-fach Navi PDC Klimaaut.',
#  'COUPE 4-M *AMG-LINE*, NAVI, PANODAK, BT, LED, 360',
#  'Performance Sitz&Abgas 20" Burm LED Pa',
#  'Coupe AMG Speedshift 7G-DCT',
#  'AMG GLC 43 4MATIC Coupé',
#  'COUPE CARBONPAK 1+2 KERAMIK BURMESTER',
#  'PERFORMANCE SITZE PANORAMA BURMESTER',
#  'd Coupe AMG 9G-Tronic Navi/Leder/Temp/360/',
#  'R COUPE CARBONPAK 1+2 KERAMIK BURMESTER',
#  'Coupe PERFORMANCE Package+PANO+H&K+LEDER',
#  'Coupe AMG Line',
#  '63 4M+ Aero Performance Massage 360 Ke',
#  '4MATIC+ Coupé',
#  'COUPE NIGHT PAKET BURMESTER HA-LENKUNG',
#  'Burmester+PerformanceAGA+Pano+++',
#  'CE Liebhaberstück',
#  'SEb (111)*DEUTSCHES-FAHRZEUG*H-KENNZEICHEN*TOP-ZUS',
#  'C oupe AMG Speedshift 7G-DCT LED RFK PDC',
#  'd 4MATIC',
#  'E 500 AMG-Paket Harman Kardon APS Comand',
#  'Coupe AMG Leder Navi Kamera Widescreen PDC',
#  'd 4MATIC Coupé AMG Line',
#  'AMG GT S E AMG PERFORMANCE grau magno HUD+CARBON',
#  '4Matic digi Tacho ACC el. Pano 20" Sound Head-Up',
#  'Coupe 3x AMG HARMAN/K,DISTRO,STANDHEIZ,ILS',
#  '43 4M+ MBUX+Mbeam+21"+V8Style+PAbgas+360°',
#  'Urban+Navi+Leder',
#  "S 4M Coupé Edition1 Driver's HUD P",
#  '/Sammlerzustand/PDC/ Bose Sound/SH/',
#  'CLK Coupe 320/Automatik/Leder/Navi/Alus',
#  'C Aero Performance Dynamic+ Burm Night',
#  'Coupe *Nachtsicht-Assistent*BI-XENON TV',
#  '4M Coupé AMG Sport Standhz. Distr. LED',
#  'Coupé 184PK AL88634',
#  '4M *AMG*Comand*Sitzhzg*LED*Schiebedach*',
#  '63 S 4M+ COM+PD+Burm3+Mbeam+HUD+360+EDIT1',
#  'Coupe 4M Standhz. LED Pano Navi SHD',
#  'GLC 43 4M Coupé **Burmester*360°Kamera*Keyless**',
#  '4M Coupé Performance Optik-Pack AHK',
#  '63 S E PERFORMANCE SONDEREDITION+PANO+HUD',
#  'Coupe AMG-Line Panorama Burmester Night',
#  '43 Perf-Abg. SHD Burm Wides 360°',
#  'CGI BlueE. Aut. Elegance LEDER NAVI XENON',
#  '4M AMG Line Distr Multib SHD 360°',
#  '4M+ Coupé 20"+PERF.ABGAS+STANDHZG+PANO',
#  'GLE 63 4MATIC Coupé LED*Abst-Tempo*360 Grad*Notruf',
#  'Coupe 4Matic AMG Magic Sky Burmester Nacht',
#  'e AMG Line+Pano+',
#  '4M Coupé Comand*Kamera*ParkPaket*Sitzhz',
#  'Coupe AMG LED+Navi+StandHZG+Keyless+e-Sitze+Parkle',
#  '4M AMG Sport Night 19" AHK MBUX Stand',
#  'COUPE AMG FINAL AUTOMAT+KLIMA+NAV+PANO+ALU',
#  '4M Coupé AMG Comand+RüKam+LED+Pano+HUD+18',
#  '53 4M+ V8 Styling Paket AMG Dynamic Pl',
#  'C Coupe*DEUTSCHES-FAHRZEUG*AUTOMATIK*H-KENNZEICHEN',
#  'S 4M+ Coupé AMG Dynamik-Paket 21"',
#  '4M Coupe AMG Line Night Distr. Burm Pan',
#  'Coupé AMG Line 155PK MU20418',
#  '63 4M+ Performance Night Massage Burm',
#  'C 43 4MATIC Coupé ILS+PANO+STANDHZ+BURMESTE+360°',
#  'GLC 63 4MATIC Coupé AHK+SH-DACH+360°+DISTRO+MEMO',
#  'Coupé Burmest+Comand+Pano+DAB+Kam+Distr',
#  'C -Klasse Coupe C 200 AMG Line+Pano+Cam+',
#  'CLA 35 4MATIC KAMERA+DISTRO+AMBIENTE+KEYLESS+SHZ',
#  'd Coupe AMG 19"Zoll Night Paket Comand Distronic',
#  'C 63 S AMG Coupé MEMORY/DISTRO/COMAND/MULTIBEAM',
#  'GLC 63 S 4MATIC Coupé SH-DACH+DISTR+360°+DRIVERP',
#  '4M Coupé AMG*LED*AHK*Kamera*Navi*ParkPaket',
#  'COUPE 4M BURMESTER HUD PANO STANDHZ 1HD',
#  '4M Coupé Night Perf-Abg Distr Stan',
#  '43 4M+ /Magno/Standheizung/AHK/',
#  'Coupé',
#  '4M HUD+PERF.ABGAS+STANDHZG+AHK+SHD',
#  'Coupe AMG + NIGHTPACK - LEDER - PANO DAK - 360° -',
#  'Coupé',
#  'AMG Line',
#  'Coupe*AMG-Line*MEMORY*SPURHALTEAS*360°CAM',
#  'AMG+MBUXHighE+LED-HP+19"+Night+ParkAss',
#  'Coupé AMG Line 185PK FE41259',
#  'd 4M Coupé AMG PLUS/PTS/360/DISTRO/SHD',
#  'CLK Coupe 320 Elegance Xenon/ PDC /Schiebedach',
#  '4M+ Standhzg+Distro.+360°+Comand+AHK',
#  'Coupé',
#  '4MATIC AMG MULTIBEAM+DISTRO+SHDACH+AHK',
#  '4MATIC Coupé BURMESTER+DISTRO+SITZKLIMA',
#  '4M+ designo Facelift Distr LED Nav',
#  'd 4M Coupé AMG-Line Night Standh AHK',
#  'S Coupé Aero Magno Keramik Vmax Dist',
#  'Matte wrapping',
#  "4M Night+Harman+Distro+Comand+Kam+19'",
#  'S 4M+ Coupé V8 Drivers+Comand+DAB+AHK',
#  'S Coupé Perf.Abgas. Pano Night Driver`s',
#  'd 4M Coupé AMG/Night/Multibeam/AHK/',
#  'E200 Coupe AMG-Line Burmester+Memory+20erLM',
#  '-Klasse Coupe EU6d-T LED Navi Keyless e-Sitze Park',
#  'Coupe Navi LED PDC Leder Cam Temp. 64581KM',
#  'E53 AMG 4Matic Coupe Pano+Burmester+Multibeam',
#  'Coupé AMG Line 2x+Comand+360°+Multib+Distr',
#  'Coupé 7G-DCT AMG LINE - BURMESTER - SFEERVERLICHTI',
#  'd Coupé AMG Line 2x+LED+Stahzg+Kam+Nav+18"',
#  'AMG Line 4Matic LED Panorama Head Up 360°',
#  'Coupé AMG LINE+KAM+NAVI+KAM+LED+MILDHYBRID',
#  'd 4MATIC Coupé AMG MULTIB+BURME+PANO+AHK',
#  'S 4M+ Coupé Sitzklima*Drivers P.',
#  'd 4MATIC Coupé',
#  'C200 COUPE M-HYBRID AMG LINE LEDER NAVI LED PANO',
#  '4M Coupé 19"+PANO+MULTIBEAM+BURMESTER',
#  '4M Coupé 19"+PANO+MULTIBEAM+BURMESTER',
#  '4M+ Coupé NIGHT+20"+PANO+PERF.ABGAS',
#  '63 4M+ HUD Memory Night',
#  '4M AMG Line 2x+Sitzklim+Comand+Night+LED',
#  '4M+ Coupé NIGHT+PANO+PERF.ABGAS+FAHRASS',
#  'Coupe Avantg.Widesc.Leder Pano.LED Night',
#  'd 4M AMG+HUD+AIRMATIC+STANDHZG+AHK+360°',
#  'd 4M Coupé  AMG*NightP*EasyP*HUD*Spiegel',
#  'd 4M AMG+20"+AIRMATIC+HUD+STANDHZG+SHD',
#  'e Coupé',
#  'd Coupé AMG MULTIBEAM+COMAND+360°+PANO+19"',
#  'Coupé AMG Line 2x+Kam+LED+Navi+DAB+SHZ+18"',
#  'CLS 53 4M+ *Limited Edition 1 of 299*DriversPa.*',
#  'Coupé AMG PLUS/TOTWINKEL/PTS/RFK/MULTIBEAM',
#  'd 4M Coupé AMG Line',
#  'd 4MATIC AMG MULTIBEAM+BURMESTER+SH-DACH',
#  'Coupé AMG Line+Burmest+LED+KAM+Advance+19"',
#  'e AMG+MBUXHighEnd+LED-HP+AParkAssist+RFK',
#  'd 4MATIC Coupé AMG AHK+SH-DACH+COMAND',
#  'd 4MATIC AMG MULTIB+SH-DACH+HUD+BURMESTE',
#  '4M Coupé OrangeArt+Night+Distr+FondTV',
#  'Coupé AMG Line+Night+Wide+LED+Navi+Kam+19"',
#  'd 4M Coupé AMG Sport Burm3D EBC Stand',
#  'Coupe 4MATIC*AMG LINE*PANO*360°-Kamera*',
#  'Classe E 300d Coupé AMG Line Mercedes-Benz E Klas',
#  'Coupé AMG Line Pano Night Navi LED SH',
#  'Coupé',
#  '4M Coupe AMG Line Night Distr Burm He',
#  'Coupe 4Matic Night Edition Navi/Distron',
#  'de 4M Coupé AMG+AIRMATIC+22"+HUD+PANO',
#  'GLE 63 S AMG 4Matic CARBON*Jungsterne Garantie',
#  'AMG Pano, AHK, 360° Kamera, ACC, 21", Widescreen',
#  '4M+ 3+2 Sitzer 22" Aero Paket Nich',
#  'CDI Voll Voll VOll TV Standheizung',
#  'ANDERE AMG UNTERBODEN GESTRAHLT KONSERVIERT/SHZ',
#  '4Matic 557PS Designo Speedshift Plus',
#  'BlueTec 4Matic CDI DPF Off-Road-Styling-Paket',
#  'd 4M *Style*LED*Sitzheizung*Navi*7G-DCT*',
#  'Hybride Pack AMG 1°EIG. FULL OPTIES NEW STAAT!',
#  '4m panorama, trekhaak, lichte vracht mogelijk !!',
#  'd Exclusive 4Matic 9G-Tronic+COMAND+LED+',
#  '4Matic AMG Line*Teilleder*Navi*LED*20"* AMG',
#  'AMG Line+CAM+Schiebdach+',
#  'd 4MATIC AMG BURMESTER+PANO+AHK+DISTRO',
#  'CDI BE /BI-XENON / NAVI / AHK / SHZ',
#  'd 4MATIC',
#  '4M AMG Line ILS Pano HUD Airmatic 360',
#  'd 4Matic AMG Line 163PK YW79474',
#  'b*SPORT*NAVI*PDC*AUT AC*LIKE NEW*',
#  'CDI Autom. - AMG - GPS - Leder  -Topstaat! 1Ste...',
#  'BLUE TEC 4MATIC AMG PANO|HARMAN|LUFT|LEDER',
#  '4MATIC',
#  '4M Magno Aero Performance Standhz.',
#  'EQ HEV HYBRID *4 MATIC*GPS*CAMERA*LED*ALU BI COLOR',
#  '250d 4Matic 9G NAV+LED+SHZ+KAMERA+PANO+AHK',
#  'GLE 63 4MATIC Coupé LED*Abst-Tempo*360 Grad*Notruf',
#  'CDI Autom. 4Matic - GPS - Pano - Topstaat!',
#  'Progressive 7-Sitzer 20" Pano 360° Ke',
#  '4M AMG/KEYLESS/PTS/360/MEMORY/DISTRO/SHD',
#  'd 4Matic AMG PAN-D LED Off-Road-Paket',
#  'CDI 4Matic AHK+Standhzg.+ACC+Xenon+Pano',
#  'AMG Kamera BiXenon Memory  H/K GSD Leder',
#  'G Klasse 350d Mercedes-Benz G Klasse 350d - Direct',
#  '4M AMG Line',
#  '4M AMG Line Night Pano Advanced+',
#  '4M Offroad Exclusive AHK LED Navi Kam',
#  'd*EUR 6!*AMG*NAV*DVD*FULL*LIKE NEW*',
#  'Sportpaket Navi Vollleder',
#  '4M AMG+22"+STANDHZG+SITZKLIMA+HUD+PANO',
#  'G 350 BlueTec LED BI-XENON*1J. PREMIUM GARANTIE',
#  'd 4Matic AMG 9G-Tronic Navi/Leder/Temp/K',
#  '4M AMG+22"+HUD+CARBON+STANDHZG+PANO+AHK',
#  '250 Progressive/LED/Memory-P./Kamera/Navi/',
#  'Progressive SHZ PTS KAMERA NAVI LED',
#  'CDI Style Aut. +Navi+Bi-Xenon+Tempomat+',
#  'd AMG Line+Night 2x+Edelstahlp+Wide+Comand',
#  'd AMG 4Matic Aut. +COMAND+LED+Kamera+Amb.',
#  'D 4-MATIC, AUTOM, NAVI, APPLE/ANDROID, DRIVER ASS',
#  '4M AMG/DISTRO/KEYLESS/PTS/NIGHT/PANO/SHZ',
#  'd 4M AMG Line 22" Standh Pano AHK Bur',
#  "7G-DCT AMG + NIGHTPACK - ALU 19' - SFEERVERLICHTIN",
#  'd 4MATIC 21"*360°K.*Pano.-D.*AHV*LED*AMG',
#  'GLC43 AMG Coupe 4M ILS+Pano+HUD+Burmester+360*',
#  'd 4M AMG/EXCLUSIVE/DISTRO/STHZ/PANO/AHK',
#  'CDI 4M Sportpaket+NEUER MOTOR+StHz+Coman',
#  'AMG G 63 AMG SPEEDSHIFT 7G-TRONIC',
#  '4x4² DESIGNO+STANDHZG+KAMERA+HARMAN+SHDACH',
#  'd AMG Line Keyless 20"Night Pano AHK',
#  'd 4M AHK Distr Multib Pano 360°',
#  'CDI / 4Matic,Xenon,Navi,Allrad,Leder,SHZ',
#  'GLC 43 4MATIC ILS+PANO+STANDHZ+DISTRO+KAMERA+SHZ',
#  'GLS 400d 4MATIC AMG Line Mercedes-Benz GLS 400d 4M',
#  'AMG Line AHK Standhz. Distronic Widesc.',
#  nan,
#  'GLC 43 4MATIC AHK+PANO+ILS+BURMESTER+DISTRO+MEMO',
#  'e 4M MBUX+Pano+Burm+Mbeam+AHK+Sitzkl+360',
#  '4Matic 7-Sitzer AHK Comand ILS Kamera Assist',
#  'd 4MATIC AHK+PANO+BURMESTE+DISTRO+MULTIB',
#  'd AMG Line',
#  'night pack, panorama, burmester, memory seats, ful',
#  'AMG G 63 NIGHT+DISTRONIC+CAM+BURMESTER+',
#  'GLC 43 4MATIC LED+PANO+HUD+DISTRO+KAMERA+AIRBODY',
#  '4M AMG Line Night Navi Kamera LED SHZ',
#  'de 4MATIC KAMERA+DISTRO+SITZHZ+KEYLESS',
#  'Puch  JAGD-FZG./WINDE/KOFFER/BRAUSE/AHK',
#  'd 4M AMG+21"+PANO+FAHRASS+AHK+SOUND+360°',
#  '4M MBUX+NavP+Mbeam+Sthg+AHK+Distr+RFK',
#  'Pack AMG - Toit ouvrant - Possibilité leasing',
#  'AMG GLC 43 4MATIC',
#  'd AMG/20"/Multibeam/Burmester/360°K/AHK/',
#  'd AMG/20"/Multibeam/Burmester/360°K/AHK/',
#  nan,
#  'GLC 63 S 4MATIC EDITION1 DRIVERP+DISTRO+360°+ILS',
#  'd 4Matic*NAVIGATION*PDC*SHZ*ALU*',
#  'd 4Matic*MEMORY STANDHEIZUNG 360°CAM*',
#  '258PS 4Matic LED HIGH Luxury NAV CAM',
#  '525PS V8 Biturbo 4-Matic Panorama H&K',
#  '4M Night Standhz LED Kamera Keyles',
#  'd 4M AMG Line Night Pano AHK HUD Stan',
#  nan,
#  '4M+ AHK Standhz. Night Pano HUD',
#  'BlueTEC 4MATIC 7G-TRONIC',
#  'GE lang Cabrio Steyr-D-Puch AHK Automatik Rücksitz',
#  'e Coupe - 4-Matic PHEV',
#  '4M AMGLine+Exclusive ext+ILS+AHK+Trittbr',
#  'Drivers Exclusive AHK Standhz',
#  'PROGRESSIVE EDITION/360/AHK/NAVI/LED/SITZH',
#  'GLC 43 4MATIC ILS+AHK+STANDHZ+DISTRO+360°+COMAND',
#  'Puch PLANE/AHK/ALLRAD/SCHLIEßANLAGE NEU',
#  '+ Electric Art MBUX+LED+RüKam+El.Heck+18',
#  '4M Progressive Distr LED Navi Kamera',
#  'GLB 35 4MATIC AHK+MULTIBEAM+KAMERA+DISTRO+SHZ',
#  'D 4Matic+LED+360° Kamera+AHK+ACC+Navi+Leder',
#  'd 4M *Comand*Standhzg*360°*LED*Sitzhzg*',
#  '*AMG*Comand*Kamera*LED*Sitzhzg*7G-DCT*',
#  'D',
#  'e 4M Distro+Pano+M-LED+Komfort+Advancedp',
#  'Puch PLANE/AHK/ALLRAD/SCHLIEßANLAGE NEU',
#  'Urban AHK | Bi-Xenon | NAVI',
#  'd 4M Sitzklim+Burmes+Pano+22"+PremPlusp.',
#  'd 4M AMG-PLUS+20"+PANO+FAHRASS+MEMORY',
#  'd 4MATIC',
#  'Urban AHK  Rückfahrkamera Score',
#  'Exclusiv+Edelstahlp+Distro+Designo+Fond TV',
#  'd 4M AMG Line+Night+PremiumPlus+Sitzklim',
#  'AMG Pano LED B&O 360Kam Massage AHK TV',
#  'd 4M AMG+20"+PANO+AHK+FAHRASS+BURMESTER',
#  'GLC 63 4MATIC ILS+COMAND+DAB+PANO+AHK+EASY-PACK',
#  'd 4M *AMG*Sitzklima*AHK*Standhzg*LED*HUD',
#  'd AMG Line AHK Distr+ Standhz beh. WSS',
#  'BlueTEC XENON SHZ NAVI LUFT AHK*CAM',
#  'd 4MATIC AMG Line 170PK AK19401',
#  'd 4M AMG+Burmester+Fahrassist.',
#  '4MATIC AMG MULTIB+AHK+PANO+AMBIENTE+PTS',
#  'd Pack AMG',
#  'd 9G-Tronic AMG 4 MATIC - LEDER - PANODAK - LED -',
#  '316 DOKA+PRITSCHE+KLIMA 7 SITZER 316 CDI',
#  'd 4MATIC Avantgarde AHK+MEMO+KAMERA+MBUX',
#  'd break AMG Line',
#  'CDI Break - GPS - Airco - Leder - Goede Staat!',
#  'SHB 4-M AMG, NAVI, APPLE/ANDROID, BURMESTER, PANO',
#  'CLS 250 Shooting Brake Sport-Paket',
#  '53 AMG 4M+ Sitzklima*Drivers P.*Burmester',
#  'd T *Navi*LED*Sitzhzg*Park-Paket*9G-TRONIC',
#  'T Avantgarde 4-Matic voll voll voll',
#  'BlueTEC dT 4M AMG-Line NAV+LED+AHK+HEAD-UP',
#  'CDI 4-Matic',
#  'Shooting Brake d AMG DESIGNO COMAND,ILS',
#  'd T *Avantgarde*Night*LED*Kamera*MBUX*Navi',
#  'Autom. 4Matic - GPS - Topstaat!',
#  '350 Fahrassist.*Pano.-Dach*360°*Night*Memory',
#  'SB S Exklusiv Vmax Distr LED Navi',
#  'b*NAVI*LED*LEDER*PDC*AUTOMAAT*',
#  'T AHK LED Navi Night-P. Ambiente el.Klappe',
#  'Shooting Brake  BE 4Matic Bluetooth',
#  'T AVANTGARDE AUTOMAT+KLIMA+LEDER+XENON+NAV',
#  'd break 7G-TRONIC AMG Line! Leder, Led, Navi, Top!',
#  'd T *Navi*Sitzhzg*9G-TRONIC*LED*Park-Paket',
#  'CGI Avantgarde Aut. +COMAND+Bi-Xenon+GSHD',
#  'Sport-Paket',
#  'Marco Polo Allrad 360 Grad Kamera Panorama',
#  'T Leder / Navi / Xenon / Klima',
#  'S T Navi Sitzh. LED 360 Kamera Memory ACC Leder',
#  'AMG CLA 35 4MATIC Shooting Brake',
#  'Shooting Brake Sport 4MATIC Amg Line 210PK LK10691',
#  'd Edition Marco Polo Airmatic AHK MBUX',
#  'Break Avantgarde * Camera * Navi * Automaat',
#  'S T 4M+ Standhz. Pano Keramikbremse',
#  'Edition Marco Polo Allrad Schiebedach',
#  'S T Pano HUD Camera Adaptive Cruise LED High Perf',
#  'd T *Navi*AHK*Sitzhzg*LED*Park-Paket*9G-TR',
#  'C220d 4Matic AHK+Standhzg+LED+Ambiente+Navi',
#  'd T Avantgarde AHK Comand LED Kamera SH',
#  'd T *LED*AHK*Navi*Sitzheizung*Park-Paket*',
#  'SB AMG line*Led*Navi*',
#  'T-Modell CDI 4-Matic LED KLIMAAUTO TEMPO',
#  'S T 4M+ ohne OPF Magno Vmax Perf Car',
#  'SB d LED Navi SHZ Einparkh. Parkassis',
#  'd T AMG Line 4Matic Aut. +COMAND+LED+LEDER+',
#  'BlueTEC AMG-Line',
#  'd T *LED*Navi*Sitzhzg*Park-Paket*9G-TRONIC',
#  'T 4Matic 9G NAV+LED+ACC+PANO+19ZOLL+SHZ',
#  'd T  Avantgarde / DISTRONIC / LED / SHZ',
#  'C63 S AMG DESIGNO HUD BURMESTER PANO DRIVERSPACK',
#  '4M T Comand*Multibeam*Standhzg*Pano*HUD',
#  'BI TURBO 4MATIC - LEDER/ALCANTARA - LED - NAVI - 1',
#  'Performance 4Matic T-Modell *Virt.Cockpit|ACC*',
#  'd T BlueTec Avantgarde NAV+LED+KAMERA+SHZ',
#  'T d Widescreen Kamera Totwinkel Navi Sitzh.',
#  'T AVANTGARDE+KLIMA+NAVI+LED+TEILLEDER+ALU+',
#  'd Marco Polo Edition Navi MBUX Markise',
#  'd Avantgarde lang Allrad Standheizung AHK',
#  'd T AMG AHK+STANDHZG+MULTIBEAM+DISTRO+360°',
#  '4m sb panorama, night pack, keyless-go, sound',
#  'd T Exclusive Leder Navi',
#  'T AUTOMAT+KLIMA+NAVI+LED+ALLWETTER+AHK+TÜV',
#  'AMG 4M Sitzklima*Burmester*Fahrassist.',
#  'd T 9G Avantgarde NAV+LED+ACC+VCOCKPIT+SHZ',
#  'E 63 S 4M T-Modell STANDHZG+PANO+360°+BURMESTER',
#  'd T Exclusive +LED+Navi+Tempomat+EUR6+',
#  'd Urban*LED*Park-Pilot*7G-DCT*Night*Sitzhz',
#  '+ AMG*Sitzklima*Burmester*Distronic*Night',
#  'CLA 35 4MATIC SB MULTIBEAM+PANO+DISTRO+AMBIENTE',
#  'Garantie bis 2025/Panorama/Burmester',
#  'd T 4M Exclusive+COM+Mbeam+Sthzg+Distr+360',
#  'd Estate',
#  'BlueTEC d T AMG-Line NAV+LED+AHK+PANO+ACC',
#  'd Marco Polo Edition Allrad AHK 2,5 t Dis.',
#  '450+ 360°Kam*Pano.-D.*20"LMR*AIRMATIC*Memory',
#  'AMG E 53 4MATIC+ Estate',
#  'd Marco Polo Navi MBUX 360° 2xStandh. AHK',
#  'b*AMG*NAVI*PDC*LIKE NEW*',
#  'T AVANTGARDE AUTOMAT+KLIMA+NAV+LED+KAMERA+',
#  'e T AMG/PTS/RFK/NAVI PREMIUM/MBUX/DISTRO',
#  'e T Avantgarde LED Navi Kamera Spurh.-A',
#  'C -Klasse T-Modell C 43 AMG 4Matic T',
#  'CLS 350 BlueTEC /H&K SOUND/ AMG LINE / MULTIBEAM',
#  'S 4M+ T Vmax Performance AHK Distr L',
#  'T AMG-Line NAV+LED+HEAD-UP+PANO+19ZO+NIGHT',
#  'T 4M+ Dynamic+ Carbon Massage Pano D',
#  'd T LED+AHK+DISTRO+COMAND+KAMERA+PTS+SHZ',
#  'T 4Matic+ LEDER NAVI LED NIGHTPAKET 1HD',
#  'de T AMG Line Widesc. Burmester Pano Co',
#  'd T LED+AHK+DISTRO+COMAND+KAMERA+PTS+SHZ',
#  'd T 4MATIC All-Terrain Avantgarde AHK+PANO',
#  'CLA 45 S 4MATIC Shooting Brake LEDER+PANO+360°',
#  'CDI 4matic AMG-Line*LED*Leder+Navi*1.Hd.',
#  'T d AVANTGARDE/NIGHT/SHD/AHK/LED/NAVI/RFK',
#  'SB S 4M+ Pano Night Kamera Navi LE',
#  'SB S 4M+ Pano Night Kamera Navi LE',
#  'BlueTEC d T Avantgarde NAV+LED+AHK+KAMERA',
#  'd Estate Business Line',
#  'd T 4MATIC AMG AHK+PANO+HUD+360°+DISTRONIC',
#  'Estate Business Line',
#  'd T 4MATIC AMG DISTRO+360°+MEMO+WIDESCREEN',
#  'T d AVANTGARDE/LED/NIGHT/DISTRONIC/AHK/SHZ',
#  'T d 4M AMG/PTS/360/WIDESCREEN/SHZ/NIGHT',
#  'd AMG/rijassist',
#  'd Avantgarde lang Allrad Standheizung LED',
#  'd Avantgarde lang Allrad Standheizung LED',
#  'd Estate',
#  '4M T AMG/MULTIBEAM/WIDE/360/SHD/DISTRO/SHZ',
#  'C400 4Matic ILS+ACC+Pano+HUD+AHK+Memory',
#  'd T 4MATIC AMG LED+DISTRO+COMAND+AMBIENTE',
#  'Shooting Brake',
#  'de Hybrid T AMG-Line 9G -Tronic Panorama Comand',
#  'd T AMG line Night Edition Navi/Temp/Kamer',
#  '4M T AMG/DISTRO/DIGITAL LIGHT/NAVI/SHZ/AHK',
#  'd 4M T AMG Sport Night Burm Distr LED N',
#  '-Klasse T-Modell CDI Avantgarde BlueTEC PANO+LED+L',
#  'e T-Modell Avantgarde',
#  'S SB 4M+ Night Pano Aero 360° 19"',
#  'T AMG LED+360°+STANDHZG+AIRMATIC+AMBIENTE',
#  'T LEDER+NAVI+PANO+AKTIV PARKEN+AHK+TÜV',
#  'T AVANTGARDE AUTOMAT+KLIMA+NAVI+XENON+TÜV+',
#  'T d AVANTGARDE/PTS/RFK/NAVI/DISTRO/AHK/LED',
#  'T AMG LINE MULTIBEAM WIDESCREEN AHK CAMERA',
#  'CLA 45 S 4MATIC SB MULTIBEAM+PANO+BURMEST+KAMERA',
#  'T 4M AMG Line 2x+Night+Comand+Distr+19"',
#  'de Estate',
#  'd 4M All-Terrain',
#  'd Estate',
#  '4M *Progressive*LED*Sitzheizg*Kamera*MBUX*',
#  'd T 4M  AMG+20"+STANDHZG+HUD+AIRMATIC+PANO',
#  'T 4MATIC Avantgarde AHK+PANO+ILS+HUD+DISTR',
#  'd Estate',
#  'e T Avantgarde Pano AHK Sitzklima Navi',
#  'd T 4M All-Terrain 20"-AMG+HUD+PANO+STANDHZG',
#  'd T-Modell 9G AMG MULTIBEAM 360-K BURMES.',
#  'd avantgarde',
#  'T AMG/NAVIGTION/LED/AHK/TOTWINKEL/KAMERA',
#  'T e Avantgarde+Spur+Multibea+AHK+Navi+18"',
#  'd Estate Business Line',
#  'd AMG Night Edition 9G-DCT 194pk',
#  'de T AMG AHK+PANO+BURMESTER+DITSR+AMBIENTE',
#  'SB e AMG',
#  'T LEDER NAVI MBEAM PANO CAM DISTRONIC',
#  'T AMG Line 2x+LED+Nav+HUD+PSD+Distro+Stahz',
#  '9G Tronic - AMG LINE - NAVI - CAMERA - 12M GARANTI',
#  'Shooting Brake AMG Line 7G-DCT',
#  'T CGI BE Avantgarde AHK WR Navi PTS Sitzh.',
#  'CDI BlueEFFICIENCY Edition',
#  'd T Avantgarde *Glasdach*Burmester*',
#  'e T AMG-LINE/PANO/D-LIGHT/PTS/360/AHK/SHZ',
#  'T d 4M All Terrain Avantgarde+Exclusiv+20"',
#  'd T Avantgarde NAV+LED+DISTRONIC+KAMERA+SH',
#  'd T Avantgarde*Navi*LED*Kamera*Tempomat',
#  'E200d Avantgarde T-Modell Navi+Kamera+LED+DAB',
#  'd Estate',
#  'd T AMG/PTS/RFK/DIGITAL LIGHT/DISTRO/AHK',
#  "4-Matic Maybach * TV's * 360 ° * Burmester",
#  '580 4MATIC AMG HYPERSCREEN+DIGITAL LIGHT+HUD',
#  'd Urban 135PK VR57954',
#  '580 4M AMG+21"+AHK+AR-HUD+SITZKLIMA+PANO+360',
#  'd AMG Line135PK XB34390',
#  '43 4MATIC+ (MULTI/DAB/360"/BURMESTER/SAGA',
#  'E-Klasse Lim. E 63 AMG S-Modell 4-Matic',
#  'E LANG PLUG-IN HYBR *AMG-LINE*,  Pano, Burmester',
#  '4M lang AMG Line Exklusiv-Pak Standhz P',
#  'PLUG-IN HYBRID Lang',
#  'e 4M lang AMG Line Chauffeur-Pak Exklus',
#  'CLS CLS 500 BE 4-Matic',
#  'e lang AMG Line Distr Pano HUD DigitalL',
#  'E 63 AMG E 63 S AMG 4M+ MBUXHighE+PD+Burm+Mbeam+Dr',
#  'L 4Matic AMG-Line*Multibeam LED*Widescreen',
#  'S 63 AMG L 4 Matic Multibeam LED Night-Paket Panor',
#  'CGI 4Matic Avantgarde Leder Navi Distr Cam',
#  '4MATIC AMG nieuwprijs: € 98.326',
#  '450+ NIGHT+20"+PANO+FAHRASS+DIG.LIGHT+360°',
#  'd 4M AMG PANO WIDE BURM DIST. 360°',
#  'CDI  EURO 6',
#  'CGI 155PK TK52548',
#  '4Matic SOFTCLOSE MEMORY TOUCHPAD*CAM',
#  '2.3 16',
#  'CGI BlueEfficiency Xenon',
#  'e AMG+MBUXAdvanced+LED-HP+NightP+SpurA+PTS',
#  '63 4m+ panorama, night pack, first class rear seat',
#  '7G-TRONIC Navi Leder',
#  'HYBRID DESIGNO KEYLESSGO,SERVOSCHLIESSUNG',
#  '4M AMG Pano HeadUp Carbon LederExcluvBurme',
#  '525PS Memory Navi Leder Bi-Xenon BT',
#  '4M+ Comand*Multibeam*Sitzklima*Pano*HUD',
#  'SE',
#  'd BlueTEC Avantgarde 164PK SL58272',
#  '580 4M AMG+21"+HA-LENKUNG+AR-HUD+SITZKLIMA',
#  '-Klasse CGI BlueEfficiency LED Navi e-Sitze Parkle',
#  '580 4M ElectricArt*Pano*MBUX*KeylessG*Memory',
#  'd AMG L 4Matic Leder/Distronic/HUD/Pano/Ka',
#  '4M L AMG PANO BURM TV HUD 360° MASSAGE',
#  'AMG 4M 21"+HYPERSCREEN+SITZKLIMA+CARBON',
#  'e Lim Progressive+MBUXAdvanced+SpurAss+PTS',
#  'd 4M Distr LED Pano Navi SHD Luftf. Kam',
#  'Progressive Line * Apple Carplay * Lane Assist *',
#  '450+ Electric Art DIGITAL LIGHT+DISTRO+Pano',
#  '4Matic AMG Speedshift 7G-DCT Pano',
#  'L AMG / FOND TV / BURM.3D / DESIGNO',
#  '4M+ Lim. Sitzklima*Burmester',
#  'e Limo Progressive AHK Navi Spurh.-Ass.',
#  'AMG Autom. Leder ACC Xenon VOLL',
#  '4M+ MBUX/MULTIBEAM/SHD/360°/NIGHT PAKET',
#  'CDI BT 4M Avantgarde+ILS+Comand+SD+8-fach',
#  'CGI Avantgarde Aut NAV+XEN+SHZ+PANO+H&K+2Hd',
#  'MODEL 2017  EURO6 Norme LEZ2030 !DEPOT VENTE!',
#  '450+ ELECTRIC ART/DISTRO/MBUX/PANO/360/PTS',
#  'S 4Matic+ Alu LEDMultibeam Head-Up Navi P',
#  'd 9G-TRONIC AMG Line/nightpakket/2019/60.000km',
#  'Classe E 200 d',
#  nan,
#  '450+ PANO+DIG.LIGHT+KEYLESS+FAHRASS+360°',
#  'D*NAVI*LED*URBAN-Line*',
#  '4M Night 19" LED Navi Kamera Sounds.',
#  'CDI Elegance KLIMAAUTO TEMPO NAVI SHZ',
#  'e Lim Progressive+MBUX+LED-HP+Mem+KeyG+RFK',
#  '4M  AMG+21"+FOND-TV+CHAUFFEUR+HUD+STANDHZG',
#  'e lang *AMG*ChauffeurP*ParkP*MemoryP*Pano*',
#  'de AMG/MULTIBEAM/MBUX/DISTRONIC/PANO/SHZ',
#  '*AMG-LINE*, AIRMATIC, BURMESTER, APPLE/ANDROID,LED',
#  '350 amg distronic, memory, keyless go, led',
#  'AMG  Performance Package',
#  '4M L AMG Sport Distr Pano Navi SHD TV L',
#  '450  AMG+NIGHT+21"+FONDSITZ-PAKET+PANO+HUD',
#  'Lang AMG Air-Balance Multibeam Chauffeur-P',
#  '4M L AMG Sport FirstClass Standhz. Dist',
#  'Kompr.*2xSHZ*2xPDC*SCHECKHEFT*TÜV NEU',
#  '53 4M+ *AMG*DAB*MBUX*EasyP*Pano*OLED*NightP*',
#  'lang 4-Matic Autom. Leder Airmatic Kamera Distroni',
#  'e Lim Progressive+MBUX+NavPr+LED+Sound+RFK',
#  'C 63 MULTIBEAM+PANO+BURMESTER+MEMORY+AMBIENTE',
#  '4M AVANTGARDE/NAVI/SITZKLIMA/DISTRO/LED',
#  'AVANTGARDE/NAVI/LED/MBUX/MEMORY/HIGH END',
#  'AVANTGARDE/NAVI/LED/MBUX/MEMORY/HIGH END',
#  '4 Matic Autom. LED~NAVI~SHZ~2xPDC~ALU',
#  'de',
#  '350 NIGHT+PREMIUM+21"+PANO+AHK+SITZKLIMA',
#  'AVANTGARDE AUTOMAT+KLIMA+XENON+ALU+AHK',
#  'e Lim Progressive+MBUXHigh+LED+18+Sound+RK',
#  '4MATIC DIGITAL LIGHT+HUD+BURMESTER+PANO',
#  '4M AMG/DISTRO/PTS/360/DIGITAL LIGHT/PANO',
#  '4M AMG/DISTRO/PTS/360/DIGITAL LIGHT/PANO',
#  'e Limousine AMG/NAVI/LED/MBUX/PTS/SHZ',
#  'e lang AMG Line Chauffeur-Pak Exklusiv',
#  'S Klasse 580E Lang 4MATIC Mercedes-Benz S Klasse 5',
#  'CDI Style AHK Navi 8xbereift RFK _GARANTIE',
#  '350 4M grau magno PROGRESSIVE+AHK+PANO+TOTW',
#  'AMG /verwarmd leder/gps/ cruise control/camera',
#  'Toit ouvrant - Climatisation - Garantie 1 an',
#  '4M+ Night Distr Burm Pano Kamera Mul',
#  'Toit ouvrant - Climatisation - Garantie 1 an',
#  'e Lim Progressive+MBUX+NavP+LED+ASound+RFK',
#  'd AMG',
#  'd +DISTRONIC+Gr.Tank+MBUX+5 Fahrassistsys',
#  'AMG  4M /21"/Digital Light/Pano-D',
#  '4M *Night*Sitzhzg*Kamera*Standhzg*LED*',
#  'Sedan 9G-Tronic AMG LINE - FULL LED - ALU - BLIS -',
#  'e Limousine AMG LINE/KAMERA/NAVI/PTS/LED',
#  '+ AMG/AIRMATIC/NAVI/DISTRO/PANO/360/SOUND',
#  'e Lim AMG+MBUXAdvanced+LED-HP+Spur+ParkAss',
#  'e AMG Line+Exclusive+Night+LED+Kam+Nav+18"',
#  '4M AMG MBUX+360°+HUD+DIG-LED+Burmeste',
#  'Lim. Aut. Navi Klimaaut. Schiebedach Shzng',
#  'd L ILS+PANO+DISTRO+360°+SITZKLIMA+DESIGNO',
#  'e AMG+20"+EXKLUSIV+AR-HUD+HA-LENKUNG+PANO',
#  'A -Klasse A 160 NAVI SHZ',
#  'e Lim AMG+MBUXAdvancedP+NightP+Spur+Kamera',
#  'S 4M+ AMG Aerodynamik Night 19" Pano',
#  'C 63 ILS+BURMESTER+KAMERA+KEYLESS+TEMPOMAT+SHZ',
#  'A 35 4MATIC MULTIBEAM+DISTRO+AMBIENTE+NIGHT+MBUX',
#  'BE AVANTGARDE,Glasdak,Cruisecontrol,Navi,Sensoren',
#  'd AMG Line',
#  'd',
#  'e Lim Progressive+MBUXAdvanced+SpurA+ParkA',
#  'e Lim Progressive+MBUX+NavP+LED+ASound+RFK',
#  '+ EDITION1+AMG+AIRMATIC+PANO+HUD+MEMORY',
#  'S 4M+ Performance-Sitz Distr LED Pan',
#  'd 4M Avantggarde Distr Standh HUD Multi',
#  'D*Navi*Rückfahrkamera*Sitzheizung*LED*DAB*',
#  'e Lim MBUXAdvancedPaket+SpurAss+ParkAssist',
#  '-Klasse e-Sitze Holzausst. Multif.Lenkrad RDC Klim',
#  'e Lim Progressive+MBUX+NavPr+LED+Sound+RFK',
#  '-Klasse BlueTEC d LED Navi e-Sitze Nachtsichtass.',
#  '4M AMG/DISTRO/PTS/360/MEMORY/DIGITAL LIGHT',
#  '-Klasse EU6d-T Mercedes Benz Klasse LED Navi Keyle',
#  '4Matic 360 Grad AHK',
#  'd 4Matic Alu Multibeam-LED Standh. Head-Up N',
#  'Business-Solution',
#  '450+  AMG+NIGHT+20"+PANO+AHK+HUD+KEYLESS+360',
#  '4M Avantgarde+Comand+Distr+SHD+Multibe+AHK',
#  'A -Klasse A 200 CDI  *Navi|PDC|SHZ|App-Connect*',
#  'AMG line',
#  'e AMG Line*Night*Pano*Head-Up*AHK*Keyless*',
#  'de',
#  '+   ELECTRIC ART+20"+SITZKLIMA+AHK+KEYL.',
#  'e AVANTGARDE+NIGHT+PANO+AHK+SOUND+KAMERA',
#  'd 4M Lim. lang Sitzklima*Burmester',
#  'AMG /verwarmd leder/gps/ cruise control/camera',
#  'e AVANTGARDE+NIGHT+PANO+SOUND+LEDER+KAMERA',
#  'd Urban+Navi+AHK+Nightp+LED+KAM+Memory+18"',
#  'd 4M AMG Line Distr Standh Pano 360° Bu',
#  'd LED Sitzh. Navi Kamera digitales Cockpit PDC',
#  '4MATIC AMG SPURASSYST+KAMERA+AMBIENTE+PTS',
#  'D Energy 1.2*1.Hand*Alu*lückenlos Scheckheft',
#  'OPC PERFORMANCE XENON+RECARO+TEILLEDER+ALU OPC',
#  '1.4 Advance EcoFlex 90PK RZ85711',
#  'E 1.6 Turbo OPC Recarositze - CarPlay - Sportpaket',
#  'Jam 1.4 Benzine 100PK + Navigatie',
#  'E 1.4 Color Edition Sitzheizung',
#  'E S 1.4 Turbo OPC-Line Recaro Sportsitze/Bi-Xenon/',
#  '1.2 Graphite 85PK NV47289',
#  'S 1.4 TURBO *LEDER RECARO*INFINITY SOUND*CARPLAY*S',
#  'E 1.4 Turbo OPC-LINE SHZ LHZ TEMPOMAT APPLE/ANDROI',
#  '1.4 Selection 100PK YY22344',
#  'Enjoy 1.4 Benzine 100PK',
#  'INNOVATION 5-TÜREN+KLIMA+TEILLEDER+ALU+TOP',
#  'F Edition SITZHEIZUNG PDC  AT',
#  '1.0 Edition EcoFlex 90PK WH98944',
#  '1.4 Energy KLIMA PDC SITZHEIZUNG',
#  'D Color Edition Klima PDC SHZ Lenkradheiz.',
#  'D Black Edition 5D 1.4B 100PK + Navigatie',
#  '1.0 Innovation START&STOP 105PK NA57433',
#  'F Edition 1.2 Turbo Multif.Lenkrad Knieairbag Klim',
#  'F Edition Navi Rü-Kamera SHZ LHZ',
#  '1.0 120 Jahre KLIMA PDC SITZHEIZUNG',
#  '1.4 Slam PDC SHZ ONSTAR INTELLILINK LED',
#  '1.0 Jam USB KLIMA KURVENLICHT PDC EURO6',
#  '1.2 75PK MT20972',
#  'F Elegance 1.2 Turbo AppleCarPlay AndroidAuto Klim',
#  'S 1.4 Turbo KLIMA ONSTAR INTELLILINK LED',
#  'Selection+Klima+AllwReifen+Isofix+Garantie',
#  'E 1.4 Edition KLIMA PDC SITZHEIZUNG',
#  'E 1.4 ACTIVE 5türig Sitz-u. Lenkradheizung',
#  'F 1.5 CDTI Elegance Panoramadach',
#  'S 1.4 Turbo KLIMA KURVENLICHT PDC SHZ',
#  'E 1.4 120 Jahre SHZ KAMERA INTELLILINK',
#  '1.0 120 JAHRE inkl. 5 Jahre Garantie (G5)',
#  'Edition 1.2 Turbo LED - Sitzheizung - USB - Tempom',
#  'F Edition 1.2 Sitzheizung - Bluetooth - Tempomat',
#  '1.2 Jam 70PK ZK66252',
#  'E 1.4 Turbo Color Edition*PDC*SHZ*Winter-Paket*Kli',
#  'F 1.2 Edition LED Sitzheizung',
#  'F GS Line 1.2/TEILLEDER/LED/CAR-PLAY/ALU/PDC',
#  'F GS Line 1.2 Turbo Klima PDC BT DAB (32)',
#  '1.0 Turbo Glam PDC SHZ INTELLILINK LED',
#  'E ALLWETTER KLIMA MULTIFLENRKAD BLUETOOTH/FREISPRE',
#  'F Elegance Matrix-LED*Kamera*SHZ*PDC*Klima*Navigat',
#  'F Edition Navi Rü-Kamera SHZ LHZ',
#  'F 1.2 Direct Injektion GS Line LED',
#  '1.0 Innovation KLIMA PDC SHZ ONSTAR',
#  'Basis AIRBAG RADIO',
#  'F Elegance 1.2 Turbo Multifunktionslenkrad - PDC',
#  'F Edition LED SHZ LHZ BLUETOOTH PDC DAB ALU KLIMA',
#  '1.4 120 Jahre KLIMA PDC SHZ KAMERA',
#  '1.2 Jam KLIMA INTELLILINK',
#  'GTC 1.7 CDTi Innovation 110PK BU96881',
#  '1.6 Selective 115PK PV36852',
#  ...]

# %%
df.columns
# Out:
# Index(['make_model', 'short_description', 'make', 'model', 'location', 'price',
#        'body_type', 'type', 'doors', 'country_version', 'offer_number',
#        'warranty', 'mileage', 'first_registration', 'gearbox', 'fuel_type',
#        'colour', 'paint', 'desc', 'seller', 'seats', 'power', 'engine_size',
#        'gears', 'co_emissions', 'manufacturer_colour', 'drivetrain',
#        'cylinders', 'fuel_consumption', 'comfort_&_convenience',
#        'entertainment_&_media', 'safety_&_security', 'extras', 'empty_weight',
#        'model_code', 'general_inspection', 'full_service_history',
#        'non_smoker_vehicle', 'emission_class', 'emissions_sticker',
#        'upholstery_colour', 'upholstery', 'previous_owner',
#        'energy_efficiency_class', 'co_efficiency', 'location_country',
#        'location_city'],
#       dtype='object')

# %%
# After the groupby operation, how many NaN values do I have remaining?
df.groupby(['make_model', 'first_registration'], group_keys = False)['country_version'].transform(lambda x: x.fillna(x.mode()[0]) if len(x.mode()) > 0 else x).isnull().sum()
# Out:
# 1559

# %%
# The 'country_version' indicates the region where the car is manufactured.
# Since cars are often produced according to the specific requirements of the region they are manufactured in,
# let's consider the make_model and first_registration of the car in relation to the region it is produced in.
df.country_version = df.groupby(['make_model', 'first_registration'], group_keys = False)['country_version'].transform(lambda x: x.fillna(x.mode()[0]) if len(x.mode()) > 0 else x)

# %%
handle_missing_values(df, "country_version")
# Out:
# Missing Values in 'country_version':
# Count: 1559
# Percentage: 5.45%

# %%
# After the groupby operation, how many NaN values do I have remaining?
df.groupby(['make_model', 'body_type'], group_keys = False)['country_version'].transform(lambda x: x.fillna(x.mode()[0]) if len(x.mode()) > 0 else x).isnull().sum()
# Out:
# 270

# %%
# The 'country_version' indicates the region where the car is manufactured.
# Since cars are often produced according to the specific requirements of the region they are manufactured in,
# let's consider the make_model and body_type of the car in relation to the region it is produced in.

df['country_version'] = df.groupby(['make_model', 'body_type'], group_keys = False)['country_version'].transform(lambda x: x.fillna(x.mode()[0]) if len(x.mode()) > 0 else x)

# %%
handle_missing_values(df, "country_version")
# Out:
# Missing Values in 'country_version':
# Count: 270
# Percentage: 0.94%

# %%
# After the groupby operation, how many NaN values do I have remaining?
df.groupby(['drivetrain', 'body_type'], group_keys = False)['country_version'].transform(lambda x: x.fillna(x.mode()[0]) if len(x.mode()) > 0 else x).isnull().sum()
# Out:
# 0

# %%
# The 'country_version' indicates the region where the car is manufactured.
# Since cars are often produced according to the specific requirements of the region they are manufactured in,
# let's consider the drive_train and body_type of the car in relation to the region it is produced in.

df['country_version'] = df.groupby(['drivetrain', 'body_type'], group_keys = False)['country_version'].transform(lambda x: x.fillna(x.mode()[0]) if len(x.mode()) > 0 else x)

# %%
handle_missing_values(df, "country_version")
# Out:
# Missing Values in 'country_version':
# Count: 0
# Percentage: 0.00%

# %% [markdown]
# <a id="23"></a>
# <div class="alert alert-info" role="alert">
# <h1>Column name :<span style="color:red"> full_service_history </span></h1>
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Operation : </b> To fill in the missing values in the "full_service_history" column, we can use the "short_description" column . it is concluded that in order to have a<span style="color:red"><b> valid warranty</b></span> , Vehicle owners should have their vehicles serviced at an <span style="color:red"><b> authorized service centre</b></span>. Therefore, having a valid warranty also means having full service history.
# </div>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
first_looking("full_service_history")
# Out:
# column name    :  full_service_history
# --------------------------------
# per_of_nulls   :  % 56.08
# num_of_nulls   :  16041
# num_of_uniques :  1
# NaN    16041
# Yes    12561
# Name: full_service_history, dtype: int64

# %%
# it is concluded that in order to have a valid warranty, 
# Vehicle owners should have their vehicles serviced at an authorized service centre. 
# Therefore, having a valid warranty also means having full service history.

# %%
# index number of notnull waranty index
df[df["warranty"].notnull()]["warranty"].index
# Out:
# Int64Index([    0,     1,     2,     3,     4,     7,     9,    10,    11,
#                12,
#             ...
#             29464, 29465, 29466, 29467, 29469, 29470, 29472, 29474, 29476,
#             29477],
#            dtype='int64', length=15773)

# %%
# Nan values which have filled warranty column are cosidered as Yes
df.loc[df[df["warranty"].notnull()]["warranty"].index, "full_service_history"] = "Yes"

# %%
# remaining nan values are considered as No
df.full_service_history.fillna("No", inplace = True)

# %%
handle_missing_values(df, "full_service_history" )
# Out:
# Missing Values in 'full_service_history':
# Count: 0
# Percentage: 0.00%

# %% [markdown]
# <a id="24"></a>
# <div class="alert alert-info" role="alert">
# <h1>Column name :<span style="color:red"> mileage </span></h1>
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Operation : </b> The "mileage" column contains only one missing value. Let's fill it using the <span style="color:red"><b> "make", "first_registration", and "location_country"</b></span> columns.
# </div>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
first_looking("mileage")
# Out:
# column name    :  mileage
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  1
# num_of_uniques :  14167
# 10.0        583
# 1.0         171
# 50.0        133
# 100.0       119
# 5000.0      118
#            ...
# 53739.0       1
# 101759.0      1
# 72645.0       1
# 27955.0       1
# 230047.0      1
# Name: mileage, Length: 14168, dtype: int64

# %%
# since there is only one null item in Mileage we can detect in dataframe easily
df[df["mileage"].isnull()]
# Out:
#       make_model                            short_description  make model  \
# 10870  Fiat 500X  1.5 Hybrid Cabrio Automaat Yacht Club Capri  Fiat  500X
#
#                                      location    price         body_type  \
# 10870  Cruquiusweg 35,  2102 LS HEEMSTEDE, NL  41570.0  Off-Road/Pick-up
#
#                 type  doors country_version  ... non_smoker_vehicle  \
# 10870  Demonstration    5.0     Netherlands  ...                NaN
#
#       emission_class  emissions_sticker  upholstery_colour    upholstery  \
# 10870            NaN                NaN            text_up  leather_hols
#
#       previous_owner energy_efficiency_class co_efficiency location_country  \
# 10870            NaN                     NaN           NaN               NL
#
#       location_city
# 10870     Heemstede
#
# [1 rows x 47 columns]

# %%
#since all other rows is already filled and there is a direct affect on milage from age and location of the automobile. The value is filled according to that
df["mileage"].fillna(df.groupby(["make", "first_registration", "location_country"])["mileage"].transform(lambda x: x.median()), inplace =True)

# %%
handle_missing_values(df, "mileage")
# Out:
# Missing Values in 'mileage':
# Count: 0
# Percentage: 0.00%

# %% [markdown]
# <a id="25"></a>
# <div class="alert alert-info" role="alert">
# <h1>Column name :<span style="color:red"> previous_owner </span></h1>
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Operation : </b> To fill in the missing values in the "previous_owner" column, we can use the "short_description" column .
# Let's extract the number of previous owners from the "previous_owner" column. Since the "previous_owner" column is associated with <span style="color:red"><b> " make " and "  first_registration " </b></span> . let's fill in the <span style="color:red"><b> NaN values</b></span> in this column by grouping the data based on these columns and performing the necessary operations.
# </div>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
first_looking("previous_owner")
# Out:
# column name    :  previous_owner
# --------------------------------
# per_of_nulls   :  % 51.01
# num_of_nulls   :  14590
# num_of_uniques :  11730
# NaN                     14590
# 50 km-06/2022-1            64
# 10 km-08/2022-1            59
# 10 km-07/2022-1            45
# 10 km-09/2022-1            38
#                         ...
# 65,000 km-10/2006-1         1
# 71,000 km-04/2013-1         1
# 134,000 km-11/2006-1        1
# 79,585 km-05/2012-1         1
# 230,047 km-07/2002-5        1
# Name: previous_owner, Length: 11731, dtype: int64

# %%
# In the 'previous_owner' column, information about the mileage, first registration, and 
# details of the previous owner of the vehicle are provided. 
# Let's extract the details of the previous owner in this context.

df.previous_owner = df.previous_owner.str.extract("(\d+)$").astype(float)

# %%
first_looking("previous_owner")
# Out:
# column name    :  previous_owner
# --------------------------------
# per_of_nulls   :  % 51.01
# num_of_nulls   :  14590
# num_of_uniques :  10
# NaN    14590
# 1.0     9745
# 2.0     3224
# 3.0      698
# 4.0      185
# 5.0       69
# 6.0       37
# 7.0       22
# 8.0       16
# 9.0       14
# 0.0        2
# Name: previous_owner, dtype: int64

# %%
# Let's assign NaN (Not a Number) to the 2 rows that appear as 0
df.previous_owner.replace(0.0, np.nan, inplace = True)

# %%
first_looking("previous_owner")
# Out:
# column name    :  previous_owner
# --------------------------------
# per_of_nulls   :  % 51.02
# num_of_nulls   :  14592
# num_of_uniques :  9
# NaN    14592
# 1.0     9745
# 2.0     3224
# 3.0      698
# 4.0      185
# 5.0       69
# 6.0       37
# 7.0       22
# 8.0       16
# 9.0       14
# Name: previous_owner, dtype: int64

# %%
# it is concluded that make, first_registration and milage is the main factors in determining number of previous owner.
# "make", "first_registration", "mileage", "previous_owner" columns are assigned to df_prw
df_prw = df[["make", "first_registration", "mileage", "previous_owner"]]

# %%
df_prw = df_prw.copy()

df_prw.loc[df_prw["mileage"] <= 50000, "mile_class"] = "0-50k"
df_prw.loc[(50000 < df_prw["mileage"]) & (df_prw["mileage"] <= 100000), "mile_class"] = "50k-100k"
df_prw.loc[(100000 < df_prw["mileage"])& ( df_prw["mileage"] <= 200000), "mile_class"] = "100k-200k"
df_prw.loc[(200000 < df_prw["mileage"]) & (df_prw["mileage"] <= 300000), "mile_class"] = "200k-300k"
df_prw.loc[(300000 < df_prw["mileage"]) & (df_prw["mileage"] <= 500000), "mile_class"] = "300k-500k"
df_prw.loc[500000 < df_prw["mileage"], "mile_class"] = "above 500k"

# %%
# Let's use it to ignore the warning.
# pd.options.mode.chained_assignment = None

# %%
# previous owner shows how many time owner the car changed. 
#It is concluded that mileage, model and age of the car have direct effect upon number of previous owner of the car
df_prw.groupby(["make", "first_registration", "mile_class" ])["previous_owner"].value_counts(dropna = False)
# Out:
# make   first_registration  mile_class  previous_owner
# Dacia  1975.0              50k-100k    NaN                1
#        2007.0              100k-200k   1.0                2
#                                        NaN                1
#                            200k-300k   1.0                1
#        2008.0              100k-200k   NaN                4
#                                                          ..
# Volvo  2021.0              0-50k       NaN               61
#                                        2.0               12
#                            50k-100k    1.0                4
#        2022.0              0-50k       1.0               50
#                                        NaN               41
# Name: previous_owner, Length: 3475, dtype: int64

# %%
df.previous_owner.value_counts()
# Out:
# 1.0    9745
# 2.0    3224
# 3.0     698
# 4.0     185
# 5.0      69
# 6.0      37
# 7.0      22
# 8.0      16
# 9.0      14
# Name: previous_owner, dtype: int64

# %%
# After the groupby operation, how many NaN values do I have remaining?
df_prw.groupby(["make", "first_registration", "mile_class" ])["previous_owner"].transform(lambda x: round(x.median(), 0)).isnull().sum()
# Out:
# 774

# %%
# df.previous_owner.describe()

# %%
# nan values are filled according to "make", "first_registration", "mile_class" 
df.previous_owner.fillna(df_prw.groupby(["make", "first_registration", "mile_class" ])["previous_owner"].transform(lambda x: round(x.median(), 0)), inplace = True)

# %%
handle_missing_values(df, "previous_owner" )
# Out:
# Missing Values in 'previous_owner':
# Count: 774
# Percentage: 2.71%

# %%
# After the groupby operation, how many NaN values do I have remaining?
df_prw.groupby([ "first_registration", "make" ])["previous_owner"].transform(lambda x: round(x.median(), 0)).isnull().sum()
# Out:
# 191

# %%
# nan values are filled according to "make", "first_registration",  
df.previous_owner.fillna(df_prw.groupby(["make", "first_registration" ])["previous_owner"].transform(lambda x: round(x.median(), 0)), inplace = True)

# %%
handle_missing_values(df, "previous_owner" )
# Out:
# Missing Values in 'previous_owner':
# Count: 191
# Percentage: 0.67%

# %%
# After the groupby operation, how many NaN values do I have remaining?
df_prw.groupby(["first_registration" ])["previous_owner"].transform(lambda x : round(x.median(), 0)).isnull().sum()
# Out:
# 20

# %%
# nan values are filled according to "first_registration"
df.previous_owner.fillna(df_prw.groupby(["first_registration" ])["previous_owner"].transform(lambda x: round(x.median(),0)), inplace = True)

# %%
handle_missing_values(df, "previous_owner" )
# Out:
# Missing Values in 'previous_owner':
# Count: 20
# Percentage: 0.07%

# %%
# nan values are filled according to "make"
df.previous_owner.fillna(df_prw.groupby(["make" ])["previous_owner"].transform(lambda x: round(x.median(), 0)), inplace = True)

# %%
handle_missing_values(df, "previous_owner" )
# Out:
# Missing Values in 'previous_owner':
# Count: 0
# Percentage: 0.00%

# %% [markdown]
# <a id="26"></a>
# <div class="alert alert-info" role="alert">
# <h1>Column name :<span style="color:red"> warranty </span></h1>
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Operation : </b> To fill in the missing values in the "warranty" column, we can use the "short_description" column . Let's update the "Warranty" column as <span style="color:red"><b> " Yes " or " No "</b></span> .  Since the "warranty" column is associated with <span style="color:red"><b>  " body_type "  and " drivetrain "</b></span> . let's fill in the <span style="color:red"><b> NaN values</b></span> in this column by grouping the data based on these columns and performing the necessary operations.
# </div>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
first_looking("warranty")
# Out:
# column name    :  warranty
# --------------------------------
# per_of_nulls   :  % 44.85
# num_of_nulls   :  12829
# num_of_uniques :  65
# NaN           12829
# 12 months      9541
# Yes            2318
# 24 months      1512
# 60 months       968
#               ...
# 55 months         1
# 99 months         1
# 122 months        1
# 44 months         1
# 4 months          1
# Name: warranty, Length: 66, dtype: int64

# %%
# Let's assign NaN values to those labeled as "0 months" and fill them in.

df.warranty = df.warranty.replace('0 months', np.nan).apply(lambda x :'Yes'  if (isinstance(x, str) and ('months' in x)) else x)

# %%
handle_missing_values(df, "warranty" )
# Out:
# Missing Values in 'warranty':
# Count: 12962
# Percentage: 45.32%

# %%
df.warranty.value_counts(dropna = False)
# Out:
# Yes    15640
# NaN    12962
# Name: warranty, dtype: int64

# %%
df.groupby(['make_model', 'location_country']).warranty.apply(lambda x: x.mode()[0] if len(x.mode()) > 0 else None)
# Out:
# make_model    location_country
# Dacia         DE                  None
# Dacia Dokker  BE                   Yes
#               DE                   Yes
#               ES                   Yes
#               FR                   Yes
#                                   ...
# Volvo XC70    NL                   Yes
# Volvo XC90    BE                   Yes
#               DE                   Yes
#               ES                   Yes
#               IT                   Yes
# Name: warranty, Length: 1878, dtype: object

# %%
# After the groupby operation, how many NaN values do I have remaining?
df.groupby(['make_model', 'location_country'], group_keys = False)['warranty'].transform(lambda x: x.fillna(x.mode()[0]) if len(x.mode()) > 0 else x).isnull().sum()
# Out:
# 1580

# %%
df.warranty = df.groupby(['make_model', 'location_country'], group_keys = False)['warranty'].transform(lambda x: x.fillna(x.mode()[0]) if len(x.mode()) > 0 else x)

# %%
handle_missing_values(df, "warranty" )
# Out:
# Missing Values in 'warranty':
# Count: 1580
# Percentage: 5.52%

# %%
# Let's fill the remaining values with "No".
df.warranty.replace(np.NaN, 'No', inplace = True)

# %%
handle_missing_values(df, "warranty" )
# Out:
# Missing Values in 'warranty':
# Count: 0
# Percentage: 0.00%

# %% [markdown]
# <a id="27"></a>
# <div class="alert alert-info" role="alert">
# <h1>Column name :<span style="color:red"> general_inspection </span></h1>
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Operation : </b> To fill in the missing values in the "general_inspection" column, we can use the "short_description" column . the "general_inspection" column  <span style="color:red"><b>will be dropped </b></span>   as it will  not be used..
# </div>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
handle_missing_values(df, "general_inspection" )
# Out:
# Missing Values in 'general_inspection':
# Count: 16353
# Percentage: 57.17%

# %%
df.general_inspection.value_counts()
# Out:
# New        5882
# 05/2023     286
# 08/2023     279
# 03/2023     268
# 06/2023     266
#            ...
# 09/2017       1
# 08/2013       1
# 08/2020       1
# 08/2018       1
# 03/2021       1
# Name: general_inspection, Length: 91, dtype: int64

# %%
# the "general_inspection" column will be dropped as it will not be used.
handle_missing_values(df, "general_inspection")
# Let's drop the "general_inspection" column since no operation will be performed on it.
# Out:
# Missing Values in 'general_inspection':
# Count: 16353
# Percentage: 57.17%

# %% [markdown]
# <a id="28"></a>
# <div class="alert alert-info" role="alert">
# <h1>Column name :<span style="color:red"> upholstery </span></h1>
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Operation : </b> To fill in the missing values in the "upholstery" column, we can use the "short_description" column . Since the "upholstery" column is associated with <span style="color:red"><b>  " body_type " , " make_model ", " comfort_&_convenience ", " first_registration "  and " drivetrain "</b></span> . let's fill in the <span style="color:red"><b> NaN values</b></span> in this column by grouping the data based on these columns and performing the necessary operations.
# </div>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
first_looking("upholstery")
# Out:
# column name    :  upholstery
# --------------------------------
# per_of_nulls   :  % 34.97
# num_of_nulls   :  10002
# num_of_uniques :  3
# NaN             10002
# fabric_hols      8940
# leather_hols     8269
# special_hols     1391
# Name: upholstery, dtype: int64

# %%
# Let's examine the short description of the country_version 
list(df.loc[df[df["upholstery"].isnull()].index, "short_description"])
# Out:
# ['CDi',
#  '350+',
#  'S 4Matic+ 8G-DCT',
#  '4Matic+ 7G-DCT',
#  '200CDI BE Line 4M 7G-DCT',
#  '7G-DCT',
#  '200CDI Autotronic',
#  '4Matic 7G-DCT',
#  'BE AMG Line 7G-DCT',
#  '200CDI BE Line 4M 7G-DCT',
#  'e Limousine',
#  '4Matic+ 7G-DCT',
#  '180d 7G-DCT',
#  '4Matic 7G-DCT',
#  '180d 7G-DCT',
#  '180d Sedán 7G-DCT',
#  nan,
#  'd 4Matic (EURO 6d)',
#  '180d 7G-DCT',
#  'S 4Matic+ 8G-DCT',
#  'CDI',
#  '4Matic 7G-DCT',
#  'Limousine',
#  '250e 8G-DCT',
#  'CDI Elegance',
#  '7G-DCT (4.75)',
#  nan,
#  '180d 7G-DCT',
#  'd AMG Line (EURO 6d)',
#  'd (177.003)',
#  '180d 7G-DCT',
#  '7G-DCT',
#  '180d 7G-DCT',
#  '180d 7G-DCT',
#  '180d 7G-DCT',
#  '180d 7G-DCT',
#  '200CDI BE Style',
#  '200CDI BE Urban 7G-DCT',
#  'd (177.003)',
#  '180d 7G-DCT',
#  '180d Sedán 7G-DCT',
#  nan,
#  '180d 7G-DCT',
#  '7G-DCT',
#  'e AMG MBUX-MEMORY-TOT-SPURHALTE-NAVI',
#  '200d 4Matic 8G-DCT',
#  '180d 7G-DCT',
#  nan,
#  '200CDI BE AMG Line 7G-DCT',
#  '200CDI BE AMG Line 7G-DCT',
#  '200d 7G-DCT',
#  'A-CLASS A180 1.3 136 CV 7G-DCT 5P',
#  '200d Sedán 8G-DCT',
#  'S 4MATIC+',
#  'd Avantgarde Largo',
#  '180d Sedán 7G-DCT',
#  '180d 7G-DCT',
#  'Avantgarde',
#  nan,
#  'Avantgarde',
#  'Sport 4Matic 7G-DCT',
#  '7G-DCT',
#  '4Matic+ 7G-DCT',
#  '180CDI Avantgarde Aut.',
#  'S 4Matic+ 8G-DCT',
#  'S 4Matic+ 8G-DCT',
#  'CDI Ambition 4U3 Navigatie',
#  'd Lease Edition Ambition',
#  'CDI Ambition [ Xenon | Navi | Cruise ]',
#  '4Matic 7G-DCT',
#  'AMG A 35 4MATIC',
#  '180CDI',
#  '180CDI Exclusive Edition',
#  'd (177.003)',
#  'd Led Navigatie Stoelverw. Carplay Leer Zondag a.s',
#  'CDi',
#  'd (177.003)',
#  '200 CDi 1.8 CDI Boîte auto',
#  'S 4Matic+ 8G-DCT',
#  'CLASSE  d Fascination 4Matic 7G-DCT',
#  '200 d Fascination 7G-DCT',
#  '250e 8G-DCT',
#  '180d 7G-DCT',
#  '7G-DCT',
#  '250e Sedán 8G-DCT',
#  '180d 7G-DCT',
#  '220d 7G-DCT',
#  '250e 8G-DCT',
#  '4Matic 7G-DCT',
#  'Classe A 1.9 116ch A 180 d',
#  '180d 7G-DCT',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '180d 7G-DCT',
#  '35 AMG 306ch 4Matic 7G-DCT Speedshift AMG',
#  '250e 8G-DCT',
#  '200d 7G-DCT',
#  'Classe A 1.5 109ch A 180 CDI BlueEfficiency',
#  'Classe A 1.5 116ch A 180 d',
#  'CLASSE  CDI Inspiration',
#  'A Class 180 1.5 115ch A 180 d',
#  '7G-DCT',
#  '180d 7G-DCT',
#  'A160 My First Star - Navi',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '200 d 150ch Progressive Line 8G-DCT 8cv',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '200 d Business 7G-DCT',
#  'Classe A 1.5 90ch A 160 CDI / d',
#  '200d 7G-DCT',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '220d 7G-DCT',
#  '220 d Fascination 7G-DCT',
#  'Business Solution AMG I AVANTAGE I AUTOMAAT I MBUX',
#  'Classe A 1.3 109ch A 160',
#  '200 d Inspiration 7G-DCT Euro6c',
#  'Classe  d (cdi) Premium auto FL E6',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '220 190ch Progressive Line 7G-DCT Siege chauf gran',
#  'CDI Ambition [ Xenon Climate Navi Cruise LM Velgen',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  'd 4Matic AMG Line (EURO 6d)',
#  '220 d 190ch AMG Line 8G-DCT 10cv GPS Camera Radar ',
#  '180 d 116ch Business Line 7G-DCT',
#  '200 d 150ch Business Line 8G-DCT GPS Camera',
#  'Premium Plus | VERWACHT! | BTW Auto | Apple Carpla',
#  '180 d 116ch AMG Line 7G-DCT',
#  '200 d Inspiration 7G-DCT',
#  '200 163ch Style Line 7G-DCT',
#  '35 AMG 306ch 4Matic 7G-DCT Speedshift AMG TOuvrant',
#  '200 d 150ch AMG Line 8G-DCT 8cv',
#  '200 d Fascination Tpano GPS Camera',
#  'CDI 100kW ( 136CV ) Urban',
#  '180 d 116ch AMG Line LED GPS Camera Radar AV/AR',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '180 136ch Progressive Line 7G-DCT 7cv',
#  'd',
#  '180 d Sensation 7G-DCT',
#  '200 d 150ch AMG Line 8G-DCT',
#  '220 190ch Progressive Line 7G-DCT',
#  '180 d Sensation 7G-DCT',
#  '180 136ch Business Line 7G-DCT',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '180 AMBITION (All-in prijs)',
#  '220 190ch Progressive Line 7G-DCT Ecran 10 GPS Cam',
#  '180 d Intuition 7G-DCT',
#  '160 109ch Style Line',
#  '200 163ch AMG Line 7G-DCT',
#  '160 Inspiration 7G-DCT',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '180 d 116ch Progressive Line 7G-DCT',
#  'S 4Matic+ 8G-DCT',
#  'S 4Matic+ 8G-DCT',
#  '4Matic 7G-DCT',
#  '220CDI BE AMG Sport 7G-DCT',
#  'd Premium',
#  '220CDI BE Line 4M 7G-DCT',
#  'S 4Matic+ 8G-DCT',
#  '4Matic 7G-DCT',
#  'Edition 1 4Matic 7G-DCT',
#  '4Matic 7G-DCT',
#  'S 4Matic+ 8G-DCT',
#  'A35 AMG 4-Matic |306PK|FULL OPTIES|',
#  'S 4Matic+ 8G-DCT',
#  '4Matic 7G-DCT',
#  'S 4Matic+ 8G-DCT',
#  '4Matic+ 7G-DCT',
#  '220d 7G-DCT',
#  '4Matic 7G-DCT',
#  '4Matic+ 7G-DCT',
#  '4Matic+ 7G-DCT',
#  'S 4Matic+ 8G-DCT',
#  '220CDI BE AMG Sport 7G-DCT',
#  '180CDI Elegance',
#  '7G-DCT',
#  '4Matic 7G-DCT',
#  '4Matic 7G-DCT',
#  '180CDI BE AMG Line 7G-DCT',
#  '4Matic 7G-DCT',
#  'S 4Matic+ 8G-DCT',
#  '4Matic 7G-DCT',
#  '4Matic 7G-DCT',
#  '220d 8G-DCT',
#  '4Matic 7G-DCT',
#  '4Matic+ 7G-DCT',
#  'Sedán 4Matic+ 7G-DCT',
#  'MERCEDES-BENZ Clase GLK Pequeño  Automático de 5',
#  '4Matic+ 7G-DCT',
#  'S 4Matic+ 8G-DCT',
#  '200d 8G-DCT',
#  '200d 8G-DCT',
#  '180d 7G-DCT',
#  '200CDI Avantgarde',
#  '4Matic+ 7G-DCT',
#  '4Matic 7G-DCT',
#  '180d 7G-DCT',
#  '200CDI BE Urban',
#  '250e Sedán 8G-DCT',
#  '180d',
#  '180CDI Polar Star',
#  'Pequeño Automático de 5 Puertas',
#  '4Matic+ 7G-DCT',
#  '4Matic+ 7G-DCT',
#  '7G-DCT',
#  'S 4Matic+ 8G-DCT',
#  '4Matic Coupe 4Matic+ (EURO 6d-TEMP)',
#  '200d 7G-DCT',
#  '200d',
#  'Edition 1 4Matic 7G-DCT',
#  nan,
#  '4Matic 7G-DCT',
#  '220CDI BE AMG Line 7G-DCT',
#  '200CDI BE AMG Line 7G-DCT',
#  '7G-DCT (4.75)',
#  '200d',
#  '7G-DCT',
#  'S 4Matic+ 4Matic (EURO 6d)',
#  '4Matic 7G-DCT',
#  nan,
#  '180d 7G-DCT',
#  '200d',
#  '250e Sedán 8G-DCT',
#  '180CDI Autotronic',
#  '200d 8G-DCT',
#  '200d 8G-DCT',
#  'S 4Matic+ 8G-DCT',
#  '7G-DCT',
#  '200d 8G-DCT',
#  'Sport 4Matic 7G-DCT',
#  '180d 8G-DCT',
#  '4Matic+ 7G-DCT',
#  'de 4Matic AMG Line (EURO 6d)',
#  'Edition 1 4Matic 7G-DCT',
#  '220d 8G-DCT',
#  '180d 7G-DCT',
#  'CDI Premium',
#  '4Matic 7G-DCT',
#  '180d 7G-DCT',
#  'd (177.003)',
#  '180d 7G-DCT',
#  '7G-DCT',
#  '200CDI BE Urban 7G-DCT',
#  'BlueEFFICIENCY Urban',
#  'CDI',
#  '200d 8G-DCT',
#  '4Matic 7G-DCT',
#  '7G-DCT (4.75)',
#  '200d 8G-DCT',
#  '200d 8G-DCT',
#  '4Matic 7G-DCT',
#  '200d',
#  '7G-DCT',
#  '200CDI BE Urban 7G-DCT',
#  '200CDI BE Urban',
#  '180CDI BE AMG Line 7G-DCT',
#  '4Matic 7G-DCT',
#  'Edition 1 4Matic 7G-DCT',
#  'd (177.003)',
#  '200d 7G-DCT',
#  'S 4Matic+ 8G-DCT',
#  '4Matic+ 7G-DCT',
#  '180CDI BE AMG Line',
#  '180d',
#  'CDI Style',
#  '220CDI BE AMG Line 7G-DCT',
#  '180d 7G-DCT',
#  'd 4M AMG/Com/ILS/Distr/KeyG/360/Standh/ABC Autom.',
#  'Mercedes- Keramik/Carbon/Burmester/Night Distronic',
#  'AMG/Comand/Distr/KeyGO/Sitzklima/Memory Distronic',
#  'Roadster COMAND/Burmester/Memory/Kamera Autom.',
#  'C Roadster',
#  'Biturbo V-Max',
#  'Cabrio CGI BE Aut.',
#  'abrio Mercedes-AMG 4MATIC',
#  'MERCEDES-BENZ Clase SL Descapotable  Automático d',
#  'Cabrio 350BlueTec Aut.',
#  nan,
#  'MercedesAMG',
#  'S COMAND APS/Distronic/Styling Autom./Klima/LED',
#  'Cabrio 220d 9G-Tronic (4.75)',
#  'AMG PLUS/COM/Multib/Burmester/Memory/Leder Autom.',
#  'Cabriolet AMG Line/COMAND/Distronic/360° Styling',
#  'AMG/Navi/LED/Distr/R-Kam/Night/Burmester Autom.',
#  'd 4M Cabrio AMG Line LED Navi Kamera PT',
#  '435cv AMG ***SOLO 37.000KMS *** LIBRO OFICIAL',
#  'd 4M Cabriolet AMG Sport Sitzklima Keyl',
#  'AMG Plus/Com/Multibeam/Burm/Night/Memory Autom.',
#  '4M Cabriolet Distr LED HUD Navi Kame',
#  'Cabrio 7G Plus',
#  'abrio Mercedes-AMG 4MATIC',
#  nan,
#  'AMG C 63 S Cabrio Night-P/Drivers P/360°/Comand',
#  'Cabrio 350CDI BE 7G Plus',
#  '200K',
#  'Cabrio 220CDI BE 7G Plus',
#  'AMG Line/FinalEdition/Airscarf/Memory Navi/Klima',
#  'Cabrio CGI BE Avantgarde',
#  'AMG Distronic/360°/Aircap/Distronic/Totw. Navi',
#  'C400 4M CABRIO AMG+DISTR BURMEST+360°+HUD+AIRSCA',
#  'AMG C 43 4M Cabrio Night-Pak/Burm/360°/Abgasanl.',
#  'Cabrio d',
#  'Cabrio Navi/7G-Tronic/Aircap/Airscarf/SHZ Autom.',
#  'Cabrio d',
#  'SL Vollrestauration',
#  '4M Cabrio. AMG Line/Multibeam/Rückfahrkam. Klima',
#  'Cabrio 220CDI 7G Plus',
#  'Cabrio AMG Line Multib Comand Airscarf',
#  'Cabriolet AMG Line 360°/Totw./Comand/LED Styling',
#  'Cabriolet AMG-Line/Navi/LED/Kamera/PDC uvm Autom.',
#  'Cabrio d',
#  'Cabrio AMG Line 9G/Kamera/Navi/LED/Ambient Autom.',
#  'Cabriolet AMGLine/LED/Airscarf/Navi/Kamera Autom.',
#  'Cabriolet AMG Line/9G/LED/KAMERA/Navi/SHZ Styling',
#  'Cabrio AMG Line Leder + Verdeck Rot/360°/ Autom.',
#  'Cabriolet AMG Line/Kamera/LED/9G/Navi/SHZ Styling',
#  'Cabriolet AMG LED 19" Navi Kamera AMG Line',
#  'Avantgarde (EURO 6d)',
#  'd Cabrio Avantgarde Mulitbeam Burmester',
#  'd 4M Cabrio AMG Line AHK Standhz Multib',
#  'Cabrio 9G-Tronic',
#  'CDI Roadster COMAND LEDER',
#  '-CLASS 6.2 COUPE SPORT AUTO 457 2P',
#  'GE',
#  'Cabriolet AMG Line',
#  '(R129) 2nd Owner/Collectable',
#  'COMAND+BURMESTER+MEMORY+AIRSCARF+ILS COMAND APS',
#  '(R171) 350 7GTRO',
#  'cabrio d  Premium Plus 4matic auto',
#  '220 d executive a',
#  '200 AMG Sport 7G-Tronic BVA',
#  'Cabrio',
#  'Cabrio 9G-Tronic (9.75)',
#  'Cabrio 9G-Tronic (9.75)',
#  'Cabrio 220CDI BE',
#  'ROADSTER',
#  '190SL',
#  'CDI BlueEfficiency E -Klasse Cabrio (BM 207)',
#  'd Cabriolet',
#  'D',
#  'Coupé R',
#  'Aut.',
#  '350CDI BE (9.75) Aut.',
#  'AMG GLC 43 4MATIC Coupé',
#  nan,
#  nan,
#  'Aut.',
#  '-CLASS 4MATIC',
#  'Coupé 462',
#  'Coupé 220d 9G-Tronic',
#  'S 4Matic+ 8G-DCT',
#  'oupé Mercedes-AMG 4MATIC',
#  '220d Urban 7G-DCT 177',
#  nan,
#  'd 4M AMG/COM/SHD/ABC/Mem/360/KeyGo/Distr Autom.',
#  nan,
#  '4Matic+ 7G-DCT',
#  'Coupé 4Matic (14.75) Aut.',
#  '320CDI Aut.',
#  'C 63 S AMG/Com/Multibeam/Perf.Sitze/Klappe/PanoD',
#  'GT 63 S AMG 4M+ Com/SHD/360/KeyG/Massage/Sitzkil',
#  'GT 63 S AMG 4M+ Com/SHD/360/KeyG/Massage/Sitzkil',
#  '220CE',
#  'S Coupe',
#  'Mercedes-AMG S 4MATIC+',
#  'e Coupé AMG MBUX LED Head-Up Parkpilot AMG Line',
#  '4Matic (EURO 6d-TEMP)',
#  'Aut.',
#  '-CLASS 3.0 4MATIC AUTO 333 2P',
#  '350CDI BE 4M Aut.',
#  'Coupé 4M Aut.',
#  'Aut.',
#  '4M AMG Line Distr Multib SHD 360°',
#  'Aut.',
#  'MBUX/SHD/Distr/Burm/360/Memory/KeyGo Navi/Autom.',
#  'S63 4M +COUPE+AMG+BURM+HUD+ILS 360°+AMBIEN+MEMO',
#  '220CDI AMG Line 7G-DCT',
#  '53 4M+ Night-P/Panor/360°/Burm./Abgasan. Navi',
#  '200K',
#  '250d ECO Aut.',
#  'd AMG/MBUX/SHD/HUD/ABC/KeyG/360/Standhzg Navi/LED',
#  'Aut.',
#  'C 63 S AMG COM/Pano/Night/Perf. Sitze/Burmester',
#  'C 43 4M Coupé Pano-Dach/Burmester/ACC/Mulibeam++',
#  '4M Coupe AMG Line Night Distr. Burm Pan',
#  '220CDI AMG Line 7G-DCT',
#  'C300d4MCp.AMG+DISTR+PANO+BURM 360°+AMBIE+MEM+HUD',
#  'CLA 45 4M Coupé Pano/Sound/Parktronic/Verkehrass',
#  'Coupé S 4Matic Aut.',
#  'Progressive MBUX/LED/Volldigital/SHZ+++ Navi',
#  '200K',
#  'Coupé 9G-Tronic',
#  'C 63 S AMG COM/Pano/Distr/KeyGO/Memory/Klappe LED',
#  'Coupe AMG + NIGHTPACK - LEDER - PANO DAK - 360° -',
#  'Coupé 220d 4Matic 9G-Tronic',
#  'Aut.',
#  'C250 Cp. AMG+DISTR+PANO+BURM+LED AMBIE+TOTW+360°',
#  'Coupé 350CDI BE Aut.',
#  '4M AMG/Com/Multibeam/Burm/Pano/AHK/Totwink Autom.',
#  'Aut.',
#  'CDI Coupé',
#  'SEC',
#  'Aut.',
#  'Coupé CDI',
#  'Com/SHD/Distr/360/Burm/Multibeam/Memo Navi/Autom.',
#  'Compressor',
#  'Mercedes-AMG CLS 53 4MATIC+ Navi/SHD/Styling/LED',
#  'C4004M Cp. AMG+DISTR+BURM+TOTW AMBIENTE+360°+LED',
#  'GLC 63 S Keramik/Com/HUD/SHD/Distr/Mem/360/KeyGo',
#  '220d 4Matic 7G-DCT',
#  'Coupé 4M Aut.',
#  '220CDI AMG Line 7G-DCT',
#  '220d Aut.',
#  'Coupé',
#  'AMG PLUS/Com/Night/Distr/PanoD/Standheizu Autom.',
#  'E200Cp. AMG+WIDE+PANO+AMBIEN HUD+MEMORY+TOTW+LED',
#  'Coupé',
#  'd 4MATIC',
#  '270CDI',
#  'd 4MATIC -',
#  '350CDI BE (9.75) Aut.',
#  '350d 4Matic Aut.',
#  'Coupé S 4Matic Aut.',
#  'coupé 4.0 4MATIC 469 2P',
#  'd AMG/Navi/PanoD/R-Kam/Multibeam/Totwinkel Autom.',
#  'AMG/Navi/Pano/Night/R-Kam/Totwinkel/LEDILS Autom.',
#  'AMG Plus/Comand/Night/Multibeam/R-Kamera Autom.',
#  '320CDI Avantgarde 7G',
#  '53 4M+ Night-Pak./Panorama/Multibeam/360° Navi',
#  'd 4MATIC Coupé',
#  'AMG C 63 Coupé Burmes./360°/Pano/Abgasanl/Memory',
#  'Coupé d',
#  'C 63 Coupé Night-P/Panorama/Totw./360°/Multibeam',
#  '350d 4Matic Aut.',
#  '43 4M+ Night-P/360°/Panor/Burm./Abgasanl. Navi',
#  'Coupé e 4Matic',
#  'd Coupé AMG/Panodach/Stdhzg/Airmatic+++++ Navi',
#  'Coupé 4Matic Aut.',
#  nan,
#  'AMG C 63 S Coupé Night/Aero-Paket/360°/Drivers P',
#  'd 4MATIC',
#  'Coupé 250d 4Matic Aut.',
#  'Coupé 400d 4Matic Aut.',
#  'Coupé 400d 4Matic Aut.',
#  'GT53 4M AMG+SHD+STHZG+DISTR+LED BURM+360°+HUD+9G',
#  'd 4M AMG HUD/360°/Burmester/Memory/STHzg Navi',
#  'CDI Chrome',
#  'Coupé 4Matic Aut.',
#  '220d 4Matic 7G-DCT',
#  'Mercedes-AMG CLS 53 4M+ DISTRONIC Carbon AHK SHD',
#  'e Coupé',
#  'Coupé d AMG LINE',
#  'd (205.314)',
#  'Coupé d',
#  'Coupé 220d 4Matic Aut.',
#  'EQ Boost Aut. (9.75)',
#  'Mercedes-AMG C 63 Coupé COMAND/MultibeamLED/360°',
#  'd 4M Coupé AMG Line/Pano/360°/AHK/Totwin Navi',
#  'Coupé 9G-Tronic',
#  'd AMG PLUS/Com/SHD/Distroni/Standheizung Navi/LED',
#  'AMG C 63 S Coupé Night-P/Drivers P/360°/Panorama',
#  'AMG C 43 4M Coupé Night-P/Panorama/360°/Abgasanl',
#  'E300d Cp. AMG+DISTR+PANO+BURM MEM+AMBIE+ILS+360°',
#  'Aut.',
#  'Coupé 220d 4Matic 9G-Tronic',
#  'Coupé',
#  '200d Urban',
#  '350d 4Matic Aut.',
#  'Coupé 350d 4Matic Aut.',
#  'AMG/MBUXHE/LED/Night/KeyGo/Burmester/PTS AMG Line',
#  'CDI (LA) Sport Edition (203.708)',
#  'Coupé 220d',
#  'Coupé 4Matic Aut.',
#  'AMG GLC 63 4M+ Coupé Night-P/SHD/Kamer/AHK/Abgas',
#  '220CDI',
#  'K',
#  'Coupé Progressive/MBUX/PTC/8fach bereift Navi',
#  'Aut.',
#  'd 4M Coupé AMG Panor./AHK/360°/Led beige Navi',
#  'COUPE AMG -Line',
#  'Coupé 220d 4Matic Aut.',
#  'Coupé 220d 9G-Tronic',
#  'd AMG Plus/Comand/Multibeam/PanoD/Night Autom.',
#  'de 4M AMG/Com/LED/SHD/KeyG/360/Distr/AHK Navi',
#  'Coupé 4Matic 9G-Tronic',
#  '4M Coupe AMG Line Night Distr Burm He',
#  'Coupé 350CDI BE Aut.',
#  'Coupé d AMG LINE',
#  'Coupé d 4MATIC',
#  '350d 4Matic Aut.',
#  'CDI Inspiration 7G-DCT',
#  '320CDI Aut.',
#  '4Matic 9G-Tronic',
#  '4M Aut.',
#  'Aut.',
#  'AMG GLE 53 4M+ Night-P/360°/Panorama/AHK/Distron',
#  '4MATIC',
#  '300d 4Matic Aut.',
#  '220d 4Matic Aut.',
#  '220d 4Matic Aut.',
#  '220d 4Matic 9G-Tronic',
#  '220d 4Matic 9G-Tronic',
#  'Aut.',
#  '220d 4Matic Aut.',
#  '220d 4Matic 8G-DCT',
#  'G63 AMG Schiebedach*Fond-Entertain*Harman-Kardon',
#  '4M Aut.',
#  'Aut.',
#  'GLC 63 S AMG Distr/KeyG/360/Memory/HUD/AHKPanoDa',
#  '4MATIC',
#  'd AMG 4M 7-Sitze*Fond-Entertainment*Pano AMG Line',
#  'Mercedes-AMG GLE 53 4MATIC+ Pano/360°/Night/AHK',
#  '400CDI',
#  '250BlueTec 4M 7G Plus',
#  '300d 4Matic Aut.',
#  '300e 4Matic 9G-Tronic',
#  'Progressive 7-Sitzer 20" Pano 360° Ke',
#  '4Matic 9G-Tronic',
#  '4MATIC',
#  '4Matic 9G-Tronic',
#  '420CDI Aut.',
#  'e 4Matic',
#  '320CDI 4M Aut.',
#  '4Matic 9G-Tronic',
#  '4MATIC AMG AHK STANDHZG DISTRONIC LED AMG Line',
#  '4Matic 9G-Tronic',
#  'd 4Matic All-Terrain Estate Avantdarde',
#  'd 4Matic 9G-Tronic',
#  '220d 4Matic Aut.',
#  'd 4M AMG/MBUX/PanoDach/AHK/Standheizung Navi/LED',
#  'd 4MATIC',
#  '220d 4Matic Aut.',
#  '4Matic 9G-Tronic',
#  '4M AMG/ MBUX/Schiebedach/Multibeam/Distr Navi/SHD',
#  'AMG+AHK+STANDHZ+DISTR +360°+COMAND+ILS AMG Line',
#  '220d 4Matic Aut.',
#  '200CDI BE 7G Plus',
#  'd 4M AMG/HUD/KeyG/AHK/TV/Airma/Mem/360° Navi/LED',
#  'd 4 MATIC 245cv 9 vel. *IVA deducible* *2020* *Nac',
#  'd 4MATIC AMG Line',
#  'CDI',
#  '4Matic 8G-DCT',
#  'AMG/Distr/Pano/Multibeam/AHK/Mem/Sitzkli Navi/LED',
#  '4Mat MAGNO*PANO*BURMESTER*HEAD-UP*ACC AMG Sport',
#  '350e 4Matic',
#  'd 4MATIC',
#  '4MATIC Navi/SHD/Totwinkel/ElectricArt/ Klima/LED',
#  '350BlueTec 4M 7G Plus',
#  'd 4Matic (253.915)',
#  '350d 4Matic Aut.',
#  'BlueTEC 4MATIC',
#  'de AMG 4Mat Distr./AHK/LED/360°/Pano/Mem Navi',
#  '220d 4Matic Aut.',
#  '350d 4Matic Aut.',
#  'd 4MATIC AMG Line/Navi/SHD/Distronic/LED Styling',
#  'AMG GLC 43 4MATIC',
#  'AMG-Line SHD/Distronic/360°/Mutibeam/Burm. LED',
#  'e 4Matic',
#  '220d 4Matic Aut.',
#  '300 4MATIC',
#  'd Edition 463 COMAND/SHD/Distronic/Designo Autom.',
#  'GLC 63 S Com/ILS/KeyG/Distr/360/HUD/Night/Burmes',
#  '220d 4Matic Aut.',
#  '4MATIC',
#  '258PS 4Matic LED HIGH Luxury NAV CAM',
#  'D ADVANTAGE + PAQ NIGHT',
#  'LA -Klasse GLA 220 d 4Matic 170 PS',
#  nan,
#  'd 4M AMG Line AHK/Navi/Burmes/Night/Pano Styling',
#  '220d 4Matic Aut.',
#  '250d 4Matic Aut.',
#  'd 4MATIC AMG/Com/LED/Night/R-Kam/19"/PTS Navi',
#  'Coupé 350D 258 CV',
#  'GLC 63 4M+ Pano/AHK/Multibeam/Burmester/AHK/Keyl',
#  '250d 4Matic Aut.',
#  '320CDI Edition 10 Aut.',
#  'Mercedes-AMG 4MATIC',
#  '320CDI Aut.',
#  'Mercedes-AMG 4MATIC',
#  '4Matic Aut.',
#  'd 4M AMG PLUS/Com/LED/Night/Pano/Standhz Navi',
#  'AMG-Line 4Mat. Pano*Keyless*360°*AHK*ACC',
#  '4Matic+ Aut.',
#  'Com/Distr/KeyG/360/Night/280Km/h/AHK Navi/Autom.',
#  '300d 4Matic Aut.',
#  '4M AMG PLUS/Com/LED/R-Kam/Mem/AHK/Night Navi',
#  'Mercedes-AMG 4MATIC+',
#  'd 4MATIC',
#  '200d 7G-DCT',
#  'd 4Matic (253.915)',
#  '220d 4Matic 7G-DCT',
#  '280CDI Aut.',
#  '350d 4Matic Aut.',
#  'D 2.2 170CV AUT 5P',
#  '4m AMG-L/LED-ILS/AHK/Navi/Park+Kam/Spur Autom./BC',
#  'G65 AMG+ BRABUS+DISTR+SHD+H&K COMAND+TOTW+KAMERA',
#  'd 4MATIC',
#  '4Matic Aut.',
#  '4M Navi/SHD/360°/AHK/Burmester/Ambiente Klima',
#  'e 4MATIC',
#  '4Matic 9G-Tronic',
#  'AMG G 63 COMAND/SHD/Night/360°/AHK/Standhzg LED',
#  'AMG/Comand/LED-Licht/Night/Totwinkelass Navi',
#  'Urban',
#  '300d 4Matic Aut.',
#  'd',
#  'Estate 200CDI BE Edition',
#  'Shooting Brake 200d',
#  'Shooting Brake 200d 7G-DCT',
#  'Estate S 4Matic+ 9G-Tronic',
#  'Estate 4Matic 7G Plus',
#  'Estate 200d 9G-Tronic',
#  'CLASSE B B 180 d BE Edition',
#  'CDI T-Modell Elegance  Navi/Pano.-Dach/SHD/Autom.',
#  'Estate 4Matic 7G Plus',
#  'C 63 S T COMAND/HUD/Distr/PanoDach/360/BBS/KW LED',
#  '(+)2.0 AVANTGARDE AUTO 211 5P STATE',
#  'C180 T Exclusive LED Navi Sitzheizung Tempomat',
#  '7G-DCT KLIMA+EPH+TEMPOMAT+BI-XENON+SITZHEIZUNG',
#  'd 4MT AMG/MBUXHighEnd/Night/Burm/Multibeam Navi',
#  nan,
#  'Estate',
#  '4MATIC',
#  'd Shooting Brake',
#  '4M T AVANTGARDE/ILS/Com/Pano/AHK/Burmester Autom.',
#  'd Estate Avantgarde',
#  'd Estate',
#  'de Estate AMG LINE',
#  '4M T AMG/Comand/Pano/360/Night/Burmester Autom.',
#  'CDI Blue Efficiency Estate',
#  'Mercedes-AMG 4MATIC Estate',
#  'lang Avantgarde Sitzklima vo+hi, Pano, Navi/SHD',
#  'EQV 250 Avantgarde Airmatic El Sitze vorne 7-Sitze',
#  'd T Avantgarde Widescr*Pano*el. Sitze*LED*',
#  'Estate 220d',
#  'T AMG/Navi/DigitalLight/Night/R-Kamera/19" Autom.',
#  'd Estate Business Line',
#  'Estate 220d 9G-Tronic',
#  'Estate Business Line',
#  'Estate Estate',
#  'Estate 220d 9G-Tronic',
#  'Shooting Brake',
#  'CLA 45 AMG SB MBUXHighEnd/Night/PanoD/HUD/Burmes',
#  'e T-Modell Avantgarde',
#  'Estate 7G Plus',
#  'CDI Urban Style Edition',
#  'Estate 220d 9G-Tronic',
#  'd Estate',
#  'de Estate',
#  'd 4M All-Terrain',
#  'd Estate',
#  '(+)2.1 D AMG LINE 5P',
#  'de T AMG Line DISTRONIC 360° 1. Hand 19"',
#  'CLA 200 SB AMG Line Navi/Panorama/AHK/Kamera/LED',
#  'Estate 200d 9G-Tronic',
#  'CLA-CLASS 2.1 D DCT SHOOTING BRAKE 136 5P',
#  'Shooting Brake BT Aut.',
#  'TCGI Xenon/AHK/Standheizung/Navi/Distron. Autom.',
#  'B200 CDI AMG AUT 136CV',
#  'CDI BlueEFFICIENCY Edition',
#  'd 4MATIC Estate',
#  'Mercedes-AMG 4M Shooting Brake',
#  '580 4Matic',
#  '7G Plus',
#  '9G-Tronic',
#  '580 4Matic',
#  'S 4Matic+ 9G-Tronic',
#  '9G-Tronic',
#  'L Aut.',
#  'CDI BlueEfficiency (204.001)',
#  '1.6',
#  'BE Elegance 7G Plus',
#  'BE Elegance 7G Plus',
#  '4Matic 7G Plus',
#  'd',
#  'Mercedes-AM53 4MATIC+',
#  '4M Lim AMG Line Standhz/Pano/360°/Airmatic Navi',
#  '7G Plus',
#  '220d 4Matic 9G-Tronic 194',
#  '220CDI BE Avantgarde 7G Plus',
#  'S 7G Plus',
#  '-CLASS 4.7 455 4P',
#  'S 63 4M L COMAND/DriverPackage/STANDH/Pano/HUD++',
#  '-CLASS 4.7 455 4P',
#  'Electric/Distr/KeyG/360/Memory/Burmeste Navi/LED',
#  'Mercedes-AMG S 4MATIC+',
#  'Mercedes-AMG S 4MATIC+',
#  '4M Aut.',
#  '-CLASS 2.1 D 4MATIC AUTO 170CV 4P',
#  'BT',
#  '200CDI Avantgarde 7G Plus',
#  'd AMG lang Pano*Digital Light*Fond-Entertai',
#  '220d 9G-Tronic 194',
#  nan,
#  'CDI Business',
#  'd',
#  'Mercedes-AMG S 4MATIC+',
#  '-CLASS D G TRONIC PLUS AVANTGARDE',
#  '220CDI BE Avantgarde',
#  'Pano/Distr/KeyG/360/Memory/Burmester Navi/Klima',
#  'AMG/Pano/Distr/KeyG/360/AHK/Mem/Burmest Navi/LED',
#  '220CDI BE Elegance Aut.',
#  '220BlueTec 7G Plus (4.75)',
#  'd',
#  'd',
#  'Aut.',
#  'd',
#  '4Matic 9G-Tronic',
#  '220CDI Avantgarde Aut.',
#  'S 4Matic+ 9G-Tronic',
#  '220d 9G-Tronic 194',
#  '350d 4Matic 9G-Tronic',
#  'Mercedes-AMG 4MATIC',
#  'EXCLUSIVE/Navi/SHD/Multibeam/R-Kamera/Totw Autom.',
#  'd',
#  '350d 4Matic 9G-Tronic',
#  'CDI 4M Aut. AMG Line',
#  'e Largo',
#  'Mercedes-AMG E 63 4M DISTRONIC+Bang&Olufson+Kame',
#  '220CDI BE Avantgarde Edition',
#  '220CDI BE Aut.',
#  'C350e AVATGARDE+DISTR+PANO+LED BURMES+AMBIE+360°',
#  'de',
#  'e Progressive MBUX LED 360° Parkpilot ... Klima',
#  '350+',
#  'd 4MATIC',
#  '320CDI Avantgarde 7G',
#  'CLA-CLASS 2.1 CDI DCT 170CV 4P',
#  'CLA-CLASS 2.1 CDI DCT 170CV 4P',
#  '220CDI Avantgarde Aut.',
#  'A45 S 4M AMG+DISTR+PANO+BURM+AMBIE AERO+360++HUD',
#  '4M Pano.-D./Aerodyn/Auspuffklappe/LED++ Styling',
#  'BlueTEC Sport',
#  'd',
#  '220d 9G-Tronic (4.75)',
#  '4MATIC',
#  'Mercedes-AMG S 4MATIC+',
#  '350+',
#  'C 63 ILS+BURMESTER+KAMERA+KEYLESS+TEMPOMAT+SHZ',
#  'Mercedes-AMG 4MATIC',
#  'CLS-CLASS 272 4P',
#  '4M Aut.',
#  'd',
#  'Blue Efficiency Avantgarde',
#  'd 4M Avantggarde Distr Standh HUD Multi',
#  'CDI Avantgarde',
#  '220d 9G-Tronic (4.75)',
#  'CDI BE Avantgarde Blue Effic. Ed.',
#  'BT Edition 1 Aut.',
#  '350d 4M Largo 9G-Tronic (9.75)',
#  '220d 9G-Tronic 194',
#  'BlueTEC 4Matic (212.011)',
#  'ElectricArt/PanoDa/Distr/KeyG/360/Memor Navi/LED',
#  'd AMG Line (EURO 6d-TEMP)',
#  '220d 9G-Tronic (4.75)',
#  'MBUXHE/Pano/Multibeam/Burmester/Night AMG Line',
#  'Mercedes-AMG 4MATIC',
#  'Limo MBUXHE/AMG Aero/360/Multibeam/HUD AMG Line',
#  '400d 4Matic Largo 9G-Tronic',
#  '4M AMG/Com/DAB/FAS+/LED-ILS/Pano/Standheiz Autom.',
#  '1.3CDTI Business75',
#  'GTC 2.0 T OPC',
#  '1.3CDTI Business75',
#  '1.2T XHL S/S Edition 100',
#  '1.7CDTI Cosmo',
#  '1.6CDTi S/S Dynamic 136',
#  '1.6T PHEV S/S GS-Line Aut. 180',
#  '1.3 ecoFlex Expression',
#  '1.6CDTi S/S Dynamic 136',
#  'Glam Pano.-Dach/Klima/MF-Lenkrad/BC/eFH. Tempomat',
#  '1.4 Business 90 (4.75)',
#  '1.6CDTi S/S GSi Line 160',
#  '1.3CDTi Cosmo',
#  '1.4 66KW (90 CV) EXPRESSION PRO',
#  'E 1.4 Turbo GSi Xenon Sitzheizung PDC',
#  '1.2 XEL S/S Edition 75',
#  '1.6 16v Energy MTA 115',
#  '1.7CDTi Enjoy 100',
#  '1.6CDTi S/S Selective 110',
#  '1.2 XEL S/S Edition 75',
#  'Jam Klima/BC/autom. Parkassistent/LM MF-Lenkrad',
#  '1.5D DT S/S GS-Line + 100',
#  '1.4T S/S Dynamic 125',
#  '1.6CDTi Business + 110',
#  '1.4 Business 90 (4.75)',
#  '1.2T S/S Design & Tech 130',
#  '1.4 XEL S&S Glam',
#  '1.2 XEL S/S Edition 75',
#  'E Turbo GSi Klima/Xenon/Sitzheizung/DAB Sitzhzg.',
#  '1.2T S/S GS Line 110',
#  '1.4 XEL S&S Glam',
#  '1.4 66KW (90 CV) EXPRESSION PRO',
#  '1.4 66KW (90 CV) EXPRESSION PRO',
#  'GTC 1.6CDTi S/S Sportive',
#  '1.4 XEL S&S Jam',
#  '1.2 Enjoy',
#  '1.3CDTi C Mon ecoFlex',
#  '1.6T S/S GSi Line 200',
#  '1.4 Business 90 (4.75)',
#  '1.4 XER S&S Rocks',
#  'E 120 Jahre Sitzhzg./Parkpilot/LM MF-Lenkrad/BC',
#  '2.0DTi 16v Sport',
#  'Jam Klima/MF-Lenkrad/Chrompaket/BC/eFH. Tempomat',
#  'E Selection Klima/eFH./ZV/Tagfahrlicht',
#  'F Edition Klima/Sitzhzg./eFH./Parkpilot/BC',
#  'F Edition Klima /Sitzheizung /Parkpilot  Sitzhzg.',
#  'Edition AppleCarPlay/EPH hinten/Sitzhzg/BC Klima',
#  'F Edition Klima/Sitzhzg./eFH./Parkpilot',
#  '2.0DTi 16v Sport',
#  'E 120 Jahre Klima/NSW/Parkpilot/Sitzheiz. BC/eFH.',
#  'Selection Klima/eFH./ZV Rücksitzlehne klappbar',
#  '1.0T S/S Selective',
#  '1.2 Essentia (146CO2)',
#  '1.4 XEL Jam Aut.',
#  'Edition Multimedia Navi/Rü-Kam./Parkpilot Klima',
#  '1.4T Selective',
#  'Corsa-e Elegance-e',
#  '1.5D DTH S/S Elegance 130',
#  'Edition Start/Stop',
#  'Jam ecoFlex',
#  '1.2T XHT S/S Elegance AT8 100',
#  '2.0CDTi S/S Selective 165',
#  '2.0 T Cosmo',
#  '1.5D DT S/S Edition 100',
#  '1.4 Turbo Edition 50% deal 4.125,- ACTIE Automaat',
#  '1.3 CDTi EcoFlex Cosmo INRUILKOOPJE !!',
#  '1.5D DT S/S Edition 100',
#  '1.4 OPC LINE / COLOR EDITION / AIRCO / NAVI / CRUI',
#  '1.3 CDTi EcoFlex S/S Edition Navi|Airco|LMV|Trekha',
#  '1.3 CDTI ECOFLEX.S ED. / AIRCO / CRUISE / APK 06-2',
#  '1.3 CDTI Business+ AUTOMAAT NAVI 98.000 KM NAP',
#  '1.4-16V Executive',
#  '2.5 V6 Pearl',
#  '2,2 Excellence 4x4 2011',
#  'GTC 1.6 16v Sport',
#  '1.2-16V Njoy 3DRS MOOI NAP',
#  '1.2-16V RHYTHM',
#  '1.4 Twinport 87ch Start/Stop',
#  '1.4T S/S Dynamic 150',
#  '2.0 Turbo ECOTEC',
#  '2.0 CDTI 165ch Cosmo Start\\u0026Stop',
#  '2.0 Turbo 16V',
#  'TwinTop 1.8 Cosmo CABRIO NAVI CRUISE 102.000 KM !',
#  '1,4 Turbo Ecoflex Cosmo Start/Stop System',
#  'TwinTop 1.4 16V Sport',
#  'Linea Ros. Cabrio, TÜV, Kundenauftrag, Dach oF.',
#  'Astra SW 1.9 cdti Cosmo 120cv 6m',
#  '2.0 CDTi S/S 165 CV Excellence',
#  '2.0 CDTi S/S 165 CV Excellence',
#  'Cabrio 1.6T S&S Excellence Aut.',
#  '1.4 Turbo Excellence',
#  '1.4 T S/S Excellence',
#  '1.4 Turbo Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.6T S&S Excellence Aut.',
#  'Cabrio 1.6T S&S Excellence Aut.',
#  '1.4 Turbo Excellence',
#  '1.4 Turbo Excellence',
#  '1.4T 140cv Excellence S/S #NAVY, BLUETOOTH',
#  '1.4 T S/S Excellence',
#  'Descapotable Manual de 3 Puertas',
#  'Cabrio 1.4T S&S Excellence',
#  '1.4 16v Rosso',
#  '1.3CDTi Enjoy',
#  '1.4 Turbo Excellence',
#  'Cabrio 1.6T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  '2.0 CDTi S/S 165 CV Excellence',
#  '1.4T 140cv Excellence S/S #NAVY, BLUETOOTH',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 2.0CDTi S&S Excellence 165',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Twin Top 1.9CDTi Enjoy',
#  '1.4 T S/S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  '1.4 Turbo (ecoFLEX) Start/Stop Edition',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Twin Top 1.9CDTi Cosmo',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Twin Top 1.8 Enjoy',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Cabrio 1.4T S&S Excellence',
#  'Sport Twin Top',
#  'Twin Top 1.6 Enjoy',
#  'Sport Twin Top',
#  'Ultimate',
#  'Twin Top 1.8 Cosmo',
#  'Twin Top 1.6 Enjoy',
#  '1.3CDTi Sport Premium',
#  '2.0 264 turbo cab / suivi complet opel / 1e main',
#  nan,
#  nan,
#  'Roadster',
#  '2.0 turbo 16v roadster c/pelle 260cv',
#  '2.0 Turbo ECOTEC',
#  'Black out versie met Alcantara dash',
#  'Twintop 1.9 CDTI - 150 FAP 111',
#  '2.0 16v Turbo VX 220 VX220',
#  'Twintop 1.9 CDTI - 150 FAP 111',
#  '1.8-16V Enjoy',
#  '2.2 16v VX 220 VX220',
#  'Cabrio 2.0i nieuwe apk',
#  'TwinTop 1.8 Cosmo - Airco - Schade',
#  'Twin Top 1.8 Sport opc',
#  '2.0 Turbo 16V',
#  '1.6 turbo benzina 180 cavalli',
#  'Twin Top 1.9 CDTI Edition',
#  nan,
#  'Cabrio 2.2 16V',
#  'Twin Top 1.6 Cosmo lpg',
#  'Twin Top 1.8 Sport',
#  '1.6 Turbo Automatik Edition . AHK.',
#  'Twin Top 1.8 (Enjoy). Klima. Alufelgen',
#  'Twin Top Sport',
#  'Cabrio 1.8i Bertone Edition',
#  'E Cabrio',
#  'SE 16v Limited Edition',
#  '2.0 turbo 16v roadster 260cv',
#  '2.0 CDTI 165CH COSMO PACK AUTOMATIQUE',
#  '1.4-16V Cosmo',
#  '1.9 CDTi,CLIM,PRETE A ETRE IMMATRICULÉE👍',
#  'Twin Top 1.8 (Enjoy)',
#  'Twin Top 1.8 Edition',
#  'Twin Top 1.6 Turbo Endless Summer Leder',
#  '1.4-16V cabrio',
#  ...]

# %%
upholstery_dict = {
    'fabric_hols' : ["Cloth",
                     "Velour",

                ],
    
    'leather_hols' : ['Full leather',
                      'Part leather'
                ],
    
    'special_hols' : ['Other',
                      'alcantara',
                         ]

}

# %%
# Sure, let's query the key-value pairs of the dictionary in the short description.
for category, keywords in upholstery_dict.items():
    for keyword in keywords:
        result = df.loc[df[df["upholstery"].isnull()].index, "short_description"].str.contains(f"(?i){keyword}", case = False)
        print(f"{category} {keyword}: {result.value_counts()}")
# Out:
# fabric_hols Cloth: False    9925
# Name: short_description, dtype: int64
# fabric_hols Velour: False    9925
# Name: short_description, dtype: int64
# leather_hols Full leather: False    9925
# Name: short_description, dtype: int64
# leather_hols Part leather: False    9925
# Name: short_description, dtype: int64
# special_hols Other: False    9925
# Name: short_description, dtype: int64
# special_hols alcantara: False    9924
# True        1
# Name: short_description, dtype: int64

# %%
# # The code below can only add a single key.

for category, keywords in upholstery_dict.items():
    for keyword in keywords:
        result_indices =   df.loc[(df["upholstery"].isnull()) & (df["short_description"].str.contains(f"(?i){keyword}", case = False))].index
        df.loc[result_indices, "upholstery"] = category

# %%
handle_missing_values(df, "upholstery" )
# Out:
# Missing Values in 'upholstery':
# Count: 10001
# Percentage: 34.97%

# %%
df.columns
# Out:
# Index(['make_model', 'short_description', 'make', 'model', 'location', 'price',
#        'body_type', 'type', 'doors', 'country_version', 'offer_number',
#        'warranty', 'mileage', 'first_registration', 'gearbox', 'fuel_type',
#        'colour', 'paint', 'desc', 'seller', 'seats', 'power', 'engine_size',
#        'gears', 'co_emissions', 'manufacturer_colour', 'drivetrain',
#        'cylinders', 'fuel_consumption', 'comfort_&_convenience',
#        'entertainment_&_media', 'safety_&_security', 'extras', 'empty_weight',
#        'model_code', 'general_inspection', 'full_service_history',
#        'non_smoker_vehicle', 'emission_class', 'emissions_sticker',
#        'upholstery_colour', 'upholstery', 'previous_owner',
#        'energy_efficiency_class', 'co_efficiency', 'location_country',
#        'location_city'],
#       dtype='object')

# %%
# After the groupby operation, how many NaN values do I have remaining?

df.groupby(['make_model','body_type'], group_keys = False)['upholstery'].transform(lambda x: x.fillna(x.mode()[0] if len(x.mode()) > 0 else np.nan)).isnull().sum()
# Out:
# 552

# %%
df.upholstery = df.groupby(['make_model', 'body_type'], group_keys = False)['upholstery'].transform(lambda x: x.fillna(x.mode()[0] if len(x.mode()) > 0 else np.nan))

# %%
handle_missing_values(df, "upholstery" )
# Out:
# Missing Values in 'upholstery':
# Count: 552
# Percentage: 1.93%

# %%
df.drivetrain.sample(5)
# Out:
# 12453    Front
# 28087    Front
# 19491    Front
# 23185    Front
# 6096       4WD
# Name: drivetrain, dtype: object

# %%
# Since the upholstery of the car may vary depending on the production year, and the "comfort_&convenience" column contains 
# information related to upholstery, we should fill the missing values in 
# the "upholstery" column using the information from the "comfort&_convenience" column.

# After the groupby operation, how many NaN values do I have remaining?

df.groupby(['first_registration','comfort_&_convenience'], group_keys = False)['upholstery'].transform(lambda x: x.fillna(x.mode()[0] if len(x.mode()) > 0 else np.nan)).isnull().sum()
# Out:
# 11

# %%
df.upholstery = df.groupby(['first_registration','comfort_&_convenience'], group_keys = False)['upholstery'].transform(lambda x: x.fillna(x.mode()[0] if len(x.mode()) > 0 else np.nan))

# %%
handle_missing_values(df, "upholstery" )
# Out:
# Missing Values in 'upholstery':
# Count: 11
# Percentage: 0.04%

# %%
# After the groupby operation, how many NaN values do I have remaining?

df.groupby(['body_type'], group_keys = False)['upholstery'].transform(lambda x: x.fillna(x.mode()[0] if len(x.mode()) > 0 else np.nan)).isnull().sum()
# Out:
# 0

# %%
df.upholstery = df.groupby(['body_type'], group_keys = False)['upholstery'].transform(lambda x: x.fillna(x.mode()[0] if len(x.mode()) > 0 else np.nan))

# %%
handle_missing_values(df, "upholstery" )
# Out:
# Missing Values in 'upholstery':
# Count: 0
# Percentage: 0.00%

# %%
df.upholstery.value_counts()
# Out:
# fabric_hols     14877
# leather_hols    12094
# special_hols     1631
# Name: upholstery, dtype: int64

# %% [markdown]
# <a id="29"></a>
# <div class="alert alert-info" role="alert">
# <h1>Column name :<span style="color:red"> upholstery_colour </span></h1>
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Operation : </b> To fill in the missing values in the "upholstery_colour" column, we can use the "short_description" column . Since the "upholstery_colour" column is associated with <span style="color:red"><b>  " body_type " , " make_model ", " comfort_&_convenience ", " first_registration "  and " drivetrain "</b></span> . let's fill in the <span style="color:red"><b> NaN values</b></span> in this column by grouping the data based on these columns and performing the necessary operations.
# </div>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
first_looking("upholstery_colour")
# Out:
# column name    :  upholstery_colour
# --------------------------------
# per_of_nulls   :  % 49.08
# num_of_nulls   :  14038
# num_of_uniques :  3
# NaN           14038
# prim_up       12543
# special_up     1280
# text_up         741
# Name: upholstery_colour, dtype: int64

# %%
# Let's examine the short description of the country_version 
list(df.loc[df[df["upholstery_colour"].isnull()].index, "short_description"])
# Out:
# ['CDi',
#  '350+',
#  'S 4Matic+ 8G-DCT',
#  '4Matic+ 7G-DCT',
#  '200CDI BE Line 4M 7G-DCT',
#  '7G-DCT',
#  '200CDI Autotronic',
#  '4Matic 7G-DCT',
#  'BE AMG Line 7G-DCT',
#  '200CDI BE Line 4M 7G-DCT',
#  '4Matic+ 7G-DCT',
#  '180d 7G-DCT',
#  '4Matic 7G-DCT',
#  '180d 7G-DCT',
#  '180d Sedán 7G-DCT',
#  nan,
#  'd 4Matic (EURO 6d)',
#  '180d 7G-DCT',
#  'S 4Matic+ 8G-DCT',
#  '4Matic 7G-DCT',
#  '250e 8G-DCT',
#  'CDI Elegance',
#  '7G-DCT (4.75)',
#  nan,
#  '180d 7G-DCT',
#  'd AMG Line (EURO 6d)',
#  'd (177.003)',
#  '-Klasse Navi RDC Klima SHZ DVD CD-W CD MP3 ESP MAL',
#  '180d 7G-DCT',
#  '7G-DCT',
#  '180d 7G-DCT',
#  '180d 7G-DCT',
#  '180d 7G-DCT',
#  '180d 7G-DCT',
#  'AUTOMATIK NAV LED KAMERA PARK-ASSIST SHZ DIG-DISPL',
#  '200CDI BE Style',
#  '200CDI BE Urban 7G-DCT',
#  'd (177.003)',
#  '180d 7G-DCT',
#  '180d Sedán 7G-DCT',
#  '180d 7G-DCT',
#  '7G-DCT',
#  '200d 4Matic 8G-DCT',
#  '180d 7G-DCT',
#  'Kompaktlimousine Rückfahrk+Vorrüst AHK+WDG',
#  '200CDI BE AMG Line 7G-DCT',
#  '200CDI BE AMG Line 7G-DCT',
#  '200d 7G-DCT',
#  'A-CLASS A180 1.3 136 CV 7G-DCT 5P',
#  '200d Sedán 8G-DCT',
#  'd Avantgarde Largo',
#  '180d Sedán 7G-DCT',
#  'AMG Line AUTOMATIK NAV LED KAMERA NIGHT PAKET SHZ',
#  '180d 7G-DCT',
#  'Avantgarde',
#  nan,
#  'Avantgarde',
#  'Sport 4Matic 7G-DCT',
#  '7G-DCT',
#  '4Matic+ 7G-DCT',
#  '4-Door Coupe 43 4MATIC+ Premium AMG, NIEUWSTAAT!!',
#  '4-Door GT 63 S CARBON AERO 5-ZITS HUD',
#  '180CDI Avantgarde Aut.',
#  'S 4Matic+ 8G-DCT',
#  'S 4Matic+ 8G-DCT',
#  'A35 AMG 4MATIC Premium+ 306PK | Pano | Sfeer | Bur',
#  'AMG/ NIGHT PAKKET/ PANO/ AMG SPOILER',
#  'CDI Ambition 4U3 Navigatie',
#  'd Business Solution Automaat - Cruise - Navi - Hal',
#  'd Lease Edition Ambition',
#  'CDI Ambition [ Xenon | Navi | Cruise ]',
#  '4MATIC [ Panorama Xenon Leder ]',
#  '4Matic 7G-DCT',
#  'Premium Night Aut. [ Burmester Widescreen Half-Led',
#  'Premium+ AMG Edition 1 225PK | Pano | Sfeer | Virt',
#  '4-Door 63 S 4MATIC+',
#  'e AMG Line Panodak',
#  '180CDI',
#  '180CDI Exclusive Edition',
#  'd (177.003)',
#  'd Led Navigatie Stoelverw. Carplay Leer Zondag a.s',
#  'CDi',
#  'd (177.003)',
#  'Ambition | Harman | ACC | Pano | CAM | AMG-Line',
#  '200 CDi 1.8 CDI Boîte auto',
#  'S 4Matic+ 8G-DCT',
#  'CLASSE  d Fascination 4Matic 7G-DCT',
#  '200 d Fascination 7G-DCT',
#  '250e 8G-DCT',
#  '180d 7G-DCT',
#  '7G-DCT',
#  '250e Sedán 8G-DCT',
#  '180d 7G-DCT',
#  '220d 7G-DCT',
#  '250e 8G-DCT',
#  '4Matic 7G-DCT',
#  'Classe A 1.9 116ch A 180 d',
#  '180d 7G-DCT',
#  'Sport Ambition AMG-Exclusief Pakket',
#  'AMG 123PK | Pano | Sfeer | Grote Navi | Camera | G',
#  'Solution AMG PANORAMADAK, NAVIGATIE, ECC AIRCO,',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  'Ambition',
#  '180d 7G-DCT',
#  '35 AMG 306ch 4Matic 7G-DCT Speedshift AMG',
#  'Business Solution AMG Upgrade | NAVIGATIE | CAMERA',
#  '250e 8G-DCT',
#  '200d 7G-DCT',
#  'Classe A 1.5 109ch A 180 CDI BlueEfficiency',
#  'd *Tempomat *Sport-Lenkrad *Touchpad *Apple - Carp',
#  'Classe A 1.5 116ch A 180 d',
#  'CLASSE  CDI Inspiration',
#  'A Class 180 1.5 115ch A 180 d',
#  '7G-DCT',
#  'd ACC NAVIGATIE LM VELGEN SPORTSTOELEN LEDER',
#  '180d 7G-DCT',
#  'd Lease Edition Ambition AUTOMAAT',
#  'A160 My First Star - Navi',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '200 d 150ch Progressive Line 8G-DCT 8cv',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '200 d Business 7G-DCT',
#  'Classe A 1.5 90ch A 160 CDI / d',
#  'Classe A 1.5 116ch A 180 d',
#  '200d 7G-DCT',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '100 PK Ambition | Cruise | PDC | Airco | NAV | LED',
#  '220d 7G-DCT',
#  '220 d Fascination 7G-DCT',
#  'AMG LEDER LED NAVI LMV CRUISE',
#  'AMG Aut. [ LED Navi Camera ]',
#  'Business Solution AMG I AVANTAGE I AUTOMAAT I MBUX',
#  'Classe A 1.3 109ch A 160',
#  'AMG/ PANO/ NIGHT/ CAMERA/ VOL!',
#  '35 AMG 306ch 4Matic 7G-DCT Speedshift AMG 19cv',
#  '200 d Inspiration 7G-DCT Euro6c',
#  'Ambition 120 PK - Automaat | Schuif/kantel-dak | C',
#  'Classe  d (cdi) Premium auto FL E6',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '220 190ch Progressive Line 7G-DCT Siege chauf gran',
#  'CDI Ambition [ Xenon Climate Navi Cruise LM Velgen',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  'd 4Matic AMG Line (EURO 6d)',
#  '220 d 190ch AMG Line 8G-DCT 10cv GPS Camera Radar ',
#  '180 d 116ch Business Line 7G-DCT',
#  '200 d 150ch Business Line 8G-DCT GPS Camera',
#  'Premium Plus | VERWACHT! | BTW Auto | Apple Carpla',
#  '180 d 116ch AMG Line 7G-DCT',
#  '200 d Inspiration 7G-DCT',
#  '200 163ch Style Line 7G-DCT',
#  '35 AMG 306ch 4Matic 7G-DCT Speedshift AMG TOuvrant',
#  '200 d 150ch AMG Line 8G-DCT 8cv',
#  '200 d Fascination Tpano GPS Camera',
#  'CDI 100kW ( 136CV ) Urban',
#  '180 d 116ch AMG Line LED GPS Camera Radar AV/AR',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '180 136ch Progressive Line 7G-DCT 7cv',
#  'd',
#  '180 d Sensation 7G-DCT',
#  'e A 250e Progressive Sfeerverlichting / NIEUW GERE',
#  '200 d 150ch AMG Line 8G-DCT',
#  '220 190ch Progressive Line 7G-DCT',
#  '180 d Sensation 7G-DCT',
#  '180 136ch Business Line 7G-DCT',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  'Business Solution AMG | Navigatie | Dealer Onderho',
#  '180 AMBITION (All-in prijs)',
#  '220 190ch Progressive Line 7G-DCT Ecran 10 GPS Cam',
#  '180 d Intuition 7G-DCT',
#  '160 109ch Style Line',
#  '200 163ch AMG Line 7G-DCT',
#  '160 Inspiration 7G-DCT',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '180 d 116ch Progressive Line 7G-DCT',
#  'AMG AUT/ PANO/ LEDER/ CLIMA/ CRUISE',
#  'S 4Matic+ 8G-DCT',
#  'A35 AMG 4MATIC Edition 1 |Pano | kuipstoelen | sfe',
#  'S 4Matic+ 8G-DCT',
#  '4Matic 7G-DCT',
#  '220CDI BE AMG Sport 7G-DCT',
#  'd Premium',
#  '220CDI BE Line 4M 7G-DCT',
#  'S 4Matic+ 8G-DCT',
#  '4Matic 7G-DCT',
#  'Edition 1 4Matic 7G-DCT',
#  '4Matic 7G-DCT',
#  'S 4Matic+ 8G-DCT',
#  'A35 AMG 4-Matic |306PK|FULL OPTIES|',
#  'S 4Matic+ 8G-DCT',
#  '4Matic 7G-DCT',
#  'S 4Matic+ 8G-DCT',
#  '4Matic+ 7G-DCT',
#  '220d 7G-DCT',
#  '4Matic 7G-DCT',
#  '4Matic+ 7G-DCT',
#  '4Matic+ 7G-DCT',
#  'S 4Matic+ 8G-DCT',
#  '220CDI BE AMG Sport 7G-DCT',
#  '180CDI Elegance',
#  '7G-DCT',
#  '4Matic 7G-DCT',
#  '4Matic 7G-DCT',
#  '180CDI BE AMG Line 7G-DCT',
#  '4Matic 7G-DCT',
#  '4MATIC SCHAALSTOELEN/PANO/SPOILER',
#  'S 4Matic+ 8G-DCT',
#  '4Matic 7G-DCT',
#  '4Matic 7G-DCT',
#  '220d 8G-DCT',
#  '4Matic 7G-DCT',
#  '4Matic+ 7G-DCT',
#  'Sedán 4Matic+ 7G-DCT',
#  'MERCEDES-BENZ Clase GLK Pequeño  Automático de 5',
#  '4Matic+ 7G-DCT',
#  'S 4Matic+ 8G-DCT',
#  '200d 8G-DCT',
#  '200d 8G-DCT',
#  '180d 7G-DCT',
#  '200CDI Avantgarde',
#  '4Matic+ 7G-DCT',
#  '4Matic 7G-DCT',
#  '180d 7G-DCT',
#  '200CDI BE Urban',
#  '250e Sedán 8G-DCT',
#  '180d',
#  '180CDI Polar Star',
#  'Pequeño Automático de 5 Puertas',
#  '4Matic+ 7G-DCT',
#  '4Matic+ 7G-DCT',
#  '7G-DCT',
#  'S 4Matic+ 8G-DCT',
#  '4Matic Coupe 4Matic+ (EURO 6d-TEMP)',
#  '200d 7G-DCT',
#  '200d',
#  'Edition 1 4Matic 7G-DCT',
#  nan,
#  '4Matic 7G-DCT',
#  '220CDI BE AMG Line 7G-DCT',
#  '200CDI BE AMG Line 7G-DCT',
#  '7G-DCT (4.75)',
#  '200d',
#  '7G-DCT',
#  'S 4Matic+ 4Matic (EURO 6d)',
#  '4Matic 7G-DCT',
#  nan,
#  '180d 7G-DCT',
#  '200d',
#  '250e Sedán 8G-DCT',
#  '180CDI Autotronic',
#  '200d 8G-DCT',
#  '200d 8G-DCT',
#  'S 4Matic+ 8G-DCT',
#  '7G-DCT',
#  '200d 8G-DCT',
#  'Sport 4Matic 7G-DCT',
#  '180d 8G-DCT',
#  '4Matic+ 7G-DCT',
#  'de 4Matic AMG Line (EURO 6d)',
#  'Edition 1 4Matic 7G-DCT',
#  '220d 8G-DCT',
#  '180d 7G-DCT',
#  'CDI Premium',
#  '4Matic 7G-DCT',
#  '180d 7G-DCT',
#  'd (177.003)',
#  '180d 7G-DCT',
#  '7G-DCT',
#  '200CDI BE Urban 7G-DCT',
#  'BlueEFFICIENCY Urban',
#  'CDI',
#  '200d 8G-DCT',
#  '4Matic 7G-DCT',
#  '7G-DCT (4.75)',
#  '200d 8G-DCT',
#  '200d 8G-DCT',
#  '4Matic 7G-DCT',
#  '200d',
#  '7G-DCT',
#  '200CDI BE Urban 7G-DCT',
#  '200CDI BE Urban',
#  '180CDI BE AMG Line 7G-DCT',
#  '4Matic 7G-DCT',
#  'Edition 1 4Matic 7G-DCT',
#  'd (177.003)',
#  '200d 7G-DCT',
#  'S 4Matic+ 8G-DCT',
#  '4Matic+ 7G-DCT',
#  '180CDI BE AMG Line',
#  '180d',
#  'CDI Style',
#  '220CDI BE AMG Line 7G-DCT',
#  '180d 7G-DCT',
#  'Special Edition Xenon Leder Memory Kam',
#  'COMAND KEYLESS,LEDILS,HARMAN/K,DISTRO',
#  'CABRIO 3x AMG SPORT COMAND,KEYLESS,KAMERA',
#  'd AMG LINE COMAND,SCHECKHEFT,HARMAN/K.',
#  'AMG SPORT DESIGNO-LEDER,COMAND,MAGICSKY',
#  'Aut. Comand+Xen+Airsc+SHZ+PDC+Leder',
#  '*AIRSCARF,LEDER,SHZ,LED,GLASDACH*',
#  'C Roadster',
#  'Biturbo V-Max',
#  'AMG SPORT COMAND,HARMAN/K,DISTRONIC,SH',
#  'Cabrio CGI BE Aut.',
#  '4M Leder,Carbon,Night,Multibeam,HuD,360°',
#  'Roadster AMG SPORT SCHECKHEFT,COMAND,H/K',
#  'CDI AMG COMAND,HARMAN/K,PANO,SCHECKHEFT',
#  'abrio Mercedes-AMG 4MATIC',
#  'MERCEDES-BENZ Clase SL Descapotable  Automático d',
#  'Cabrio 350BlueTec Aut.',
#  'Cabrio AMG DISTRO+HEAD-UP+KAM360+BURMESTER',
#  'ROADSTER LEDER|NAVI|DVD|AIRSCRAF|KLIMA',
#  '4M CABRIO AMG ENERGIZING+MBUX-HIGH+KOMFORT',
#  nan,
#  'Cabrio 4M Sportabgas LED HUD Kamera 19"',
#  'MercedesAMG',
#  '*PANORAMADACH,AIRSCARF,PDC,LEDER,NAVI*',
#  'Cabrio 220d 9G-Tronic (4.75)',
#  'DESIGNO PANO+LED-ILS+AIRSCARF+TOTWINKEL+',
#  'CABRIOLET AVANTGARDE AUTOMAT+LEDER+ALU',
#  '*LEDER,AIRSCARF,KLIMA,SHZ,PDC*',
#  '-Klasse Cabrio Cabriolet AMG-Line',
#  '435cv AMG ***SOLO 37.000KMS *** LIBRO OFICIAL',
#  'Roadster BI-XENON SHZ NAVI PDC VO+HI AUTOMATIK',
#  'BlueEFFICIENCY CGI LEDER NAVI',
#  'Roadster Sport Comand.ILS.H&K erst72261KM',
#  'Cabrio CGI AMG ILS Airscraft Navi Leder PDC',
#  'SL Pagode',
#  'Cabriolet  4Matic+ ABSOLUTE VOLLAUSTATTUNG',
#  'AMG 18ZOLL ILS,COMAND,AIRSCARF,VARIODACH',
#  'K AUTOMAT+KLIMA+LEDER+XENON+AIRSCARF+TÜV',
#  'Cabrio 7G Plus',
#  'r107 original belgian delivery! first owner car.',
#  'abrio Mercedes-AMG 4MATIC',
#  nan,
#  'Roadster Kompressor Original Brabus Umbau',
#  'CDI BLUE EFFICIENCY AIRSCARF|NAVI|LEDER',
#  'CABRIOLET AMG+DESIGN+LEDER+XENON+AIRSCARF+',
#  'Cabrio 350CDI BE 7G Plus',
#  'Cabrio CGI Automatik Nackenheizung',
#  'Roadster Leder LED Kurvenlicht Panorama Fernlichta',
#  'CABRIO AMG DISTRO+KAMERA+MEMORY+BURMESTER',
#  'd Cabrio 4MATIC AMG 360GRAD,SPURPAKET,SH',
#  '200K',
#  'Cabrio 220CDI BE 7G Plus',
#  'Cabrio CGI BE Avantgarde',
#  'CGI BE *AIRSCARF,LEDER,NAVI,PDC,LED,SHZ*',
#  'Cabrio d',
#  'SL Roadster',
#  'Deutsches Fahrzeug  Sammlerzustand',
#  'Cabrio d',
#  nan,
#  'Roadster Kompressor SCHWARZ AUTOMATIK KLIMA LEDER',
#  'Cabrio 220CDI 7G Plus',
#  nan,
#  'Klima Sitzheizung Navi',
#  'Cabrio d',
#  '220 d AMG Line+Alcantara+MulitBeamLED+Keyless',
#  'SCHECKHEFT,NAVIGATION,PANORAMA,METALLIC',
#  'E E  Cabrio E DSG *LED*Navi*Harman*AHK*Leder*Park',
#  'Cabrio 9G-Tronic',
#  '-CLASS 6.2 COUPE SPORT AUTO 457 2P',
#  'Cabriolet 4MATIC',
#  '43 AMG / Air Scarf / Harman Kardon / Comand',
#  'CDI BlueEfficiency AMG Line Kamera Airscar',
#  '200 K.',
#  'C SW 200 d  auto',
#  'GE',
#  'Cabriolet AMG Line',
#  '(R129) 2nd Owner/Collectable',
#  'SL 600 V12 AUT. ORG. NL.',
#  'Automatik*Massagesitz*Airscarf*AMG-Paket*',
#  'BiXenon-Leder-Navi-Sitz Lüftung uvm.',
#  'Cabrio Multibeam Perf.Sitz PAGA Sitzlü.',
#  'Cabrio',
#  'cabrio d  Premium Plus 4matic auto',
#  '220 d executive a',
#  '200 AMG Sport 7G-Tronic BVA',
#  '250 d Sport auto',
#  'Cabrio 9G-Tronic (9.75)',
#  'Cabrio 9G-Tronic (9.75)',
#  'Cabrio 220CDI BE',
#  'ROADSTER',
#  'V6 231pk Automaat Prest. Plus NL-auto',
#  '190SL',
#  'Cabrio C 63 S AMG*NP.127782,- EURO*VOLL',
#  'K. Season Edition | Navi | Leder',
#  'Cabrio Multibeam Perf.Sitz PAGA Sitzlü.',
#  'Roadster Aut.',
#  'Roadster 4.0 | Performance-uitlaat | Night-Pakket',
#  'Leder AD Dyn. Kurvenlicht Klimasitze e-Sitze Nacht',
#  'D',
#  'S Coupe EDITION1 PERF. AGA DIST. 19°',
#  'Coupe 4M DESIGNO,AKT.PARKASSIST,LED',
#  'Coupé R',
#  'Aut.',
#  '350CDI BE (9.75) Aut.',
#  nan,
#  nan,
#  'Aut.',
#  '-CLASS 4MATIC',
#  'BlueEFFICIENCY Coupé * Sitzhzg.* Teilleder',
#  'Coupé 462',
#  'Coupé 220d 9G-Tronic',
#  'S 4Matic+ 8G-DCT',
#  'oupé Mercedes-AMG 4MATIC',
#  'Burmester+PerformanceAGA+Pano+++',
#  '220d Urban 7G-DCT 177',
#  'd Coupe 4M 3x AMG WIDESCREEN,AIRMATIC,HUD',
#  nan,
#  '4M COUPE AMG NIGHT MEMORY+KEYLES+COMAND+',
#  'E 500 AMG-Paket Harman Kardon APS Comand',
#  'Coupe AMG Leder Navi Kamera Widescreen PDC',
#  'd 4M AMG DISTRO+KAM360+HEADUP+WIDESCREEN',
#  nan,
#  '4Matic+ 7G-DCT',
#  'Coupe 3x AMG HARMAN/K,DISTRO,STANDHEIZ,ILS',
#  'Coupé 4Matic (14.75) Aut.',
#  '320CDI Aut.',
#  '4Matic Leder - 4xSitzheizung - Navi - Lenkradheizu',
#  '220CE',
#  'COUPE AMG DISTRONIC+KAM360+PANO+WIDESCREEN',
#  'COUPE AMG DISTRONIC+KAM360+PANO+WIDESCREEN',
#  'S Coupe',
#  'Mercedes-AMG S 4MATIC+',
#  'Burmaster Keramikbremsen Leder Alcantara Pano Navi',
#  'd 4M AMG DISTRO+PANO+KAM360+WIDESCREEN',
#  'AMG-Paket * Navi * Rückfahrk. * ILS',
#  '4Matic (EURO 6d-TEMP)',
#  'Aut.',
#  '-CLASS 3.0 4MATIC AUTO 333 2P',
#  'CGI BlueEfficiencyasse Coupe 1.8 Leder Panorama Ho',
#  '350CDI BE 4M Aut.',
#  'Coupé 4M Aut.',
#  'Coupe AMG-Line Panorama Burmester Night',
#  'Aut.',
#  'Aut.',
#  'CGI COUPE AVANTGARDE LEDER|KLIMA|SHZG|PDC',
#  'Coupe 4Matic AMG Magic Sky Burmester Nacht',
#  '220CDI AMG Line 7G-DCT',
#  '200K',
#  'd 4M AMG DISTRO+KAM360+MEMORY+WIDESCREEN',
#  '250d ECO Aut.',
#  'Coupe AMG LED+Navi+StandHZG+Keyless+e-Sitze+Parkle',
#  'Aut.',
#  'COUPE AMG FINAL AUTOMAT+KLIMA+NAV+PANO+ALU',
#  'd Coupe 4M 3x AMG BURMESTER,COMAND,STANDHZ',
#  'Shooting Brake 7G-Tronic LED,Leder,GSD',
#  '220CDI AMG Line 7G-DCT',
#  'Coupé 4Matic*Leder*Navi*LED*Kamera*',
#  'Coupé S 4Matic Aut.',
#  '200K',
#  'Coupe AMG DISTRO+PANO+KAMERA+WIDESCREEN+EQ',
#  'Coupé 9G-Tronic',
#  'Coupe 3x AMG DISTRO+PANO+KAMERA+WIDESCREEN',
#  'Coupé 220d 4Matic 9G-Tronic',
#  'Coupe 3x AMG NIGHTPAKET PANO,KAMERA,SH',
#  'Aut.',
#  'Coupé 350CDI BE Aut.',
#  'S Coupe PANO+HEAD-UP+KAM360+DIGI-TACHO',
#  'Aut.',
#  'CDI Coupé',
#  'SEC',
#  'Aut.',
#  'Coupé CDI',
#  'COUPE 4MATIC PANO|HEADUP|NIGHT|STANDHZ|DISTR',
#  'Compressor',
#  '220d 4Matic 7G-DCT',
#  'Coupe 3x AMG DIAMANTGRILL,KAMERA,PANORAMA',
#  'Coupé 4M Aut.',
#  '220CDI AMG Line 7G-DCT',
#  '220d Aut.',
#  'd Coupe AVANTGARDE COMAND,MULTIBEAM,PANO',
#  'Coupé d (238.314)',
#  'Coupé',
#  'd 4MATIC',
#  '270CDI',
#  'DESIGNO HEADUP,COMAND,BURMESTER,360GRAD',
#  'd 4MATIC -',
#  '350CDI BE (9.75) Aut.',
#  '350d 4Matic Aut.',
#  '-Klasse Coupe EU6d-T LED Navi Keyless e-Sitze Park',
#  'Coupe Navi LED PDC Leder Cam Temp. 64581KM',
#  'Coupé S 4Matic Aut.',
#  'coupé 4.0 4MATIC 469 2P',
#  '320CDI Avantgarde 7G',
#  'Coupé d',
#  '350d 4Matic Aut.',
#  'Coupé e 4Matic',
#  'Coupe Avantg.Widesc.Leder Pano.LED Night',
#  'Coupé 4Matic Aut.',
#  nan,
#  'd 4MATIC',
#  'Coupé 250d 4Matic Aut.',
#  'Coupé 400d 4Matic Aut.',
#  'Coupé 400d 4Matic Aut.',
#  'CDI Chrome',
#  'Coupé 4Matic Aut.',
#  '220d 4Matic 7G-DCT',
#  'Coupé d AMG LINE',
#  'd (205.314)',
#  'Coupé d',
#  'Coupé 220d 4Matic Aut.',
#  'EQ Boost Aut. (9.75)',
#  'Coupé 9G-Tronic',
#  'Aut.',
#  'Coupé 220d 4Matic 9G-Tronic',
#  'Coupé',
#  '200d Urban',
#  '350d 4Matic Aut.',
#  'Coupé 350d 4Matic Aut.',
#  'CDI (LA) Sport Edition (203.708)',
#  'e AMG+MBUXHighEnd+LED-HP+AParkAssist+RFK',
#  'Coupé 220d',
#  'Coupé 4Matic Aut.',
#  '220CDI',
#  'K',
#  'Aut.',
#  '-Klasse Coupe CGI BlueEfficiency AMG Navi Dyn. Kur',
#  '-Klasse Coupe CGI BlueEfficiency AMG Navi Dyn. Kur',
#  'COUPE AMG -Line',
#  'Coupé 220d 4Matic Aut.',
#  'Coupé 220d 9G-Tronic',
#  'Coupe d 4Matic AMG-LINE',
#  'Coupé 4Matic 9G-Tronic',
#  'Coupé 350CDI BE Aut.',
#  'Coupe 4Matic EU6d-T',
#  'Coupé d AMG LINE',
#  'Coupé d 4MATIC',
#  '350d 4Matic Aut.',
#  'CDI Inspiration 7G-DCT',
#  '4M PANO+360+AHK+DISTRO+MEMORY+BICOLOR',
#  '320CDI Aut.',
#  'PERFORMANCE DESIGNO,SCHECKHEFT,STANDHZ',
#  '4M AMG 7 SITZE FONDTV,STANDHZ,KEYLESS,EU6',
#  '4Matic 9G-Tronic',
#  '4M Aut.',
#  'CDI Voll Voll VOll TV Standheizung',
#  'AIRMATIC+AHK+MEMORY+DIGITAL-TACHO+LED',
#  'Aut.',
#  '4M AMG PANO+FOND-TV+360+AHK+STANDHEIZUNG',
#  'CDI 4M AMG EU6 BANG-O+KAMERA+AHK+AIRMATIC',
#  '4MATIC',
#  'CDI BE *KAMERA,GLASDACH,NAVI,LEDER,PDC,SHZ',
#  '300d 4Matic Aut.',
#  '220d 4Matic Aut.',
#  '220d 4Matic Aut.',
#  '220d 4Matic 9G-Tronic',
#  '220d 4Matic 9G-Tronic',
#  'Aut.',
#  '220d 4Matic Aut.',
#  'BlueTec 4Matic CDI DPF Off-Road-Styling-Paket',
#  '220d 4Matic 8G-DCT',
#  '4M Aut.',
#  'Aut.',
#  '4M AMG SPORT COMAND,H/K,360GRAD,MEMORY',
#  '4Matic AMG Line*Teilleder*Navi*LED*20"* AMG',
#  'S DIS * 4x Sitzh * AIR * 360°',
#  '4M AMG BANG+O,2xFONDTV,MASSAGE,SOFTCLOSE',
#  '4MATIC',
#  '400CDI',
#  'BLUE TEC 4MATIC AMG PANO|HARMAN|LUFT|LEDER',
#  '4M AMG 20Z SPURPAKET,AHK,DESIGNO,KAMERA',
#  '250BlueTec 4M 7G Plus',
#  'PERFORMANCE SCHECKHEFT,MEMORY,AIRMATIC',
#  'CDI *LEDER,NAVI,PDC,AZV,SHZ,STANDHEIZUNG',
#  'BT 4M AMG 7 SITZE TRITTBRETTER,AHK,PANO',
#  'AMG LINE S.DACH|BURMSTER|360°|NIGHT PAKET',
#  '300d 4Matic Aut.',
#  'd 4M AMG SPORT HUD,KEYLESS,360GRAD,PANO',
#  'd 4Matic Standhzg. * DIS * LED * Navi',
#  '300e 4Matic 9G-Tronic',
#  '4Matic 9G-Tronic',
#  '4MATIC',
#  '4Matic 9G-Tronic',
#  'd 4M 7 SITZE AMG 20ZOLL 360GRAD,KEYLESS',
#  '420CDI Aut.',
#  'e 4Matic',
#  '320CDI 4M Aut.',
#  '4Matic 9G-Tronic',
#  '4Matic 9G-Tronic',
#  'd 4Matic All-Terrain Estate Avantdarde',
#  'd 4Matic 9G-Tronic',
#  '220d 4Matic Aut.',
#  'd 4MATIC',
#  '220d 4Matic Aut.',
#  '4Matic 9G-Tronic',
#  '4M AMG NIGHT 7SITZ+PANO+360+21Z+AIRMATIC',
#  'Progressive SHZ PTS KAMERA NAVI LED',
#  '220d 4Matic Aut.',
#  '200CDI BE 7G Plus',
#  'd 4 MATIC 245cv 9 vel. *IVA deducible* *2020* *Nac',
#  'd 4MATIC AMG Line',
#  'CDI',
#  'S Coupe Pano HUD Night 360Kamera Memory 466kW Burm',
#  '4Matic 8G-DCT',
#  'Style*Pano*Navi*Leder*LED*APS*',
#  '350e 4Matic',
#  'd 4MATIC',
#  '4Matic 7-Sitzer AHK Comand ILS Kamera Assist',
#  '350BlueTec 4M 7G Plus',
#  'd 4Matic (253.915)',
#  '350d 4Matic Aut.',
#  'BlueTEC 4MATIC',
#  '220d 4Matic Aut.',
#  '350d 4Matic Aut.',
#  'd 4Matic AMG-Line Leder,Navi,LED,Head-up',
#  'e 4Matic',
#  'd 4Matic Exclusive*Leder*Navi*PDC*18"* Exclusive',
#  '220d 4Matic Aut.',
#  '300 4MATIC',
#  '220d 4Matic Aut.',
#  'd 4Matic 9G-Tronic*Kamera*Navi*LED*19"*',
#  '4MATIC',
#  '4M AMG 19ZOLL DISTRONIC,SPURPAKET,MEMORY',
#  'D ADVANTAGE + PAQ NIGHT',
#  'd 4Matic 9G-Tronic*AMG Line*Pano*Head-Up AMG',
#  '220d 4Matic Aut.',
#  'DESIGNO*AMG SPORT*DISTR*PANO*STNDH*AHK*HK7',
#  'GE lang Cabrio Steyr-D-Puch AHK Automatik Rücksitz',
#  '250d 4Matic Aut.',
#  'd 4Matic 9G-Tronic*AMG Line Int.*Pano*LE AMG',
#  'Coupé 350D 258 CV',
#  '250d 4Matic Aut.',
#  '320CDI Edition 10 Aut.',
#  'Mercedes-AMG 4MATIC',
#  '320CDI Aut.',
#  'Mercedes-AMG 4MATIC',
#  '4Matic Aut.',
#  '4Matic+ Aut.',
#  'd 4Matic Leder,LED,Navi,360°-Kamera,PDC',
#  '300d 4Matic Aut.',
#  'AERO-PAKET*PERFORMANCE SITZ*DESIGNO*',
#  'AERO-PAKET*PERFORMANCE SCHALENSITZE*',
#  'Mercedes-AMG 4MATIC+',
#  'Urban AHK  Rückfahrkamera Score',
#  '200d 7G-DCT',
#  'd 4M AMG DESIGNO BURMESTER,HUD,360GRAD',
#  'd 4Matic (253.915)',
#  '220d 4Matic 7G-DCT',
#  '280CDI Aut.',
#  'Diesel+Euro6+voll foliert+Teil-Leder+Navi+Alu+',
#  '350d 4Matic Aut.',
#  'd Style 7G-DCT BI-XENON NAVI RFK SHZ TEMPO',
#  'D 2.2 170CV AUT 5P',
#  'PERFORMANCE DESIGNO,SCHECKHEFT,STANDHZ',
#  'd 4MATIC',
#  '4Matic Aut.',
#  'DISTRONIC-NIGHT-MANUFAKTUR-MASSAGE-360°',
#  'AMG-Line LED Navi Leder StHZG Panorama',
#  'e 4MATIC',
#  '4Matic 9G-Tronic',
#  '316 DOKA+PRITSCHE+KLIMA 7 SITZER 316 CDI',
#  'Urban',
#  '300d 4Matic Aut.',
#  'BT AMG 360GRAD,MEMORY,SOFTCLOSE,HARMAN/K',
#  'e 4Matic 7G-Tronic*Navi*Distronic*',
#  'd 4Matic',
#  'd',
#  '4M HUD,KEYLESS,DISTRO,COMAND,STANDHEIZ.',
#  'Shooting Brake CDI AIRMATIC,SCHECKHEFT',
#  'T 4M AMG NIGHT HUD,BURMESTER,360GRAD,PANO',
#  'T 4M COMAND,AHK,SCHECKHEFT,SCHIEBEDACH,18Z',
#  '4Matic AVANT*WIDESCREEN,360°,BURMESTER* AVANTGARD',
#  'Shooting Brake d AMG NIGHTPAKET DISTRO',
#  'T Avantgarde 4-Matic voll voll voll',
#  'Shooting Brake d AMG DESIGNO COMAND,ILS',
#  'Shooting Brake d 4M AMG 19ZOLL 360GRAD',
#  'Shooting Brake 4M AMG KEYLESS,DISTRONIC',
#  'T AHK LED Navi Night-P. Ambiente el.Klappe',
#  'T AVANTGARDE COMAND,CARPLAY,KAMERA,SH,LED',
#  'T AVANTGARDE AUTOMAT+KLIMA+LEDER+XENON+NAV',
#  'T 3x AMG NIGHT 360GRAD,DISTRONIC,STANDHEIZ',
#  'Estate 200CDI BE Edition',
#  'Shooting Brake 200d',
#  'Shooting Brake 200d 7G-DCT',
#  'S T Navi Sitzh. LED 360 Kamera Memory ACC Leder',
#  'Estate S 4Matic+ 9G-Tronic',
#  'T d 4M AMG DISTR+STDHZG+PANO+360+WIDESCREN',
#  '-Klasse T-Modell Avantgarde Automatik LED RFK Busi',
#  'd 4Matic T 9G-Tronic*Navi*LED*PDC*GRA*',
#  'T-Modell BlueTEC d T Avantgarde',
#  'SB FACELIFT*AMG,NAVI,LEDER,SHZ,ISOFIX* AMG-LINE',
#  'T d Avantgarde Automatik EU6d-T Navi LED',
#  'T d 9G-Tronic Navi,LED,Kamera,Sitzheizung',
#  'T d 9G-Tronic Navi,LED,Kamera,Sitzheizung',
#  'd T 3x AMG WIDESCREEN,BURMESTER,360GRAD,SH',
#  'd T AMG NIGHT PANORAMA,KAMERA,KEYLESS,1.HD',
#  'T d NIGHT WIDESCREEN,360GRAD,MULTIBEAM,AHK',
#  'Estate 4Matic 7G Plus',
#  'Estate 200d 9G-Tronic',
#  'T d Avantgarde Automatik EU6d Navi LED PDC',
#  'Estate 4Matic 7G Plus',
#  'T d Avantgarde Automatik EU6d',
#  'SB 4-MATIC *NAVI,KAMERA,PDC,LED,SHZ*',
#  'Shooting Brake 4M NIGHT EXKLUSIV MEMORY',
#  '(+)2.0 AVANTGARDE AUTO 211 5P STATE',
#  'T d Widescreen Kamera Totwinkel Navi Sitzh.',
#  'T AVANTGARDE+KLIMA+NAVI+LED+TEILLEDER+ALU+',
#  'C180 T Exclusive LED Navi Sitzheizung Tempomat',
#  'T AUTOMAT+KLIMA+NAVI+LED+ALLWETTER+AHK+TÜV',
#  'T AVANTGARDE STANDHZ,SCHECKHEFT,PARKASSIST',
#  nan,
#  'd T *NAVI,LEDER,KAMERA,LED,SHZ*',
#  'Garantie bis 2025/Panorama/Burmester',
#  'Estate',
#  '4MATIC',
#  'd Shooting Brake',
#  'd Estate Avantgarde',
#  'de Estate AMG LINE',
#  'CDI Blue Efficiency Estate',
#  'e T PLUGIN HYBRID KOMBI AUTOMATIK 7 GANG NAVI BURM',
#  'T AVANTGARDE AUTOMAT+KLIMA+NAV+LED+KAMERA+',
#  'T d Automatik*Leder*Navi*Panorama*',
#  'T d Automatik EU6d-T Navi LED Klima PDC',
#  'Mercedes-AMG 4MATIC Estate',
#  'EQV 250 Avantgarde Airmatic El Sitze vorne 7-Sitze',
#  'Estate 220d',
#  'T d DISTRO+PANO+KAMERA360+MEMORY+WIDESCREN',
#  'Estate 220d 9G-Tronic',
#  'd T AVANTGARDE LEDER|NAVI|KAMERA',
#  'Td 9G-Tronic*Avantgarde*Teilleder*Navi*LED Avantga',
#  'Estate Estate',
#  '4Matic T 9G-TRON PANO Designo High-End Infotainmnt',
#  'Estate 220d 9G-Tronic',
#  '-Klasse T-Modell CDI Avantgarde BlueTEC PANO+LED+L',
#  'T d Automatik Business Plus EU6d-T LED Navi PDC',
#  'Estate 7G Plus',
#  'T d AMG DISTR+KAM360+PANO+HEADUP+WIDESCREN',
#  'd 4Matic *BURMESTER,NAVI,KAMERA,LEDER,AZV*',
#  'T LEDER+NAVI+PANO+AKTIV PARKEN+AHK+TÜV',
#  'T AVANTGARDE AUTOMAT+KLIMA+NAVI+XENON+TÜV+',
#  'CDI Urban Style Edition',
#  'Estate 220d 9G-Tronic',
#  'd Estate',
#  'd T 4M  AMG+20"+STANDHZG+HUD+AIRMATIC+PANO',
#  '(+)2.1 D AMG LINE 5P',
#  'Estate 200d 9G-Tronic',
#  'CLA-CLASS 2.1 D DCT SHOOTING BRAKE 136 5P',
#  'Shooting Brake BT Aut.',
#  'T d 9G-Tronic AMG Line*Navi*LED*Kamera* AMG',
#  'T d 4M AMG AHK+DISTR+PANO+KAMERA+WIDESCREN',
#  'T d 9G-Tronic Avantgarde*Pano*Leder*Navi* Avantgar',
#  'B200 CDI AMG AUT 136CV',
#  'C-Klasse C200 AMG 1.6 CDI T-Modell d T EU6d-',
#  'T CGI BE Avantgarde AHK WR Navi PTS Sitzh.',
#  'd T Avantgarde *Glasdach*Burmester*',
#  'Sport Utility Automatik *BIXENON*PANO*',
#  'd 4MATIC Estate',
#  'd T Avantgarde*Navi*LED*Kamera*Tempomat',
#  'Mercedes-AMG 4M Shooting Brake',
#  '580 4Matic',
#  '4Matic AVANTGARDE*NAVI,LEDER,LED,USB* AVANTGARDE',
#  '7G Plus',
#  '9G-Tronic',
#  '580 4Matic',
#  'd 4Matic DIS * 4x Sitzlüftung * Pano *',
#  'S 4Matic+ 9G-Tronic',
#  'BE CGI  AMG-Optic-/Styling-Paket 1',
#  '9G-Tronic',
#  'S 4M+ Night,MBUX,360°,Pano,HuD,StHzg',
#  'L Aut.',
#  'CDI BlueEfficiency (204.001)',
#  '1.6',
#  'BE Elegance 7G Plus',
#  'CGI 4Matic Avantgarde Leder Navi Distr Cam',
#  'BE Elegance 7G Plus',
#  'e Edition 2020 AMG',
#  'd 4M AMG PANO WIDE BURM DIST. 360°',
#  'CDI  EURO 6',
#  'SPORTPAKET AIRMATIC,MEMORY,PANO,DISTRONIC',
#  '4MATIC LANG NIGHT|PANO|AIR|360°|BURMESTER',
#  '4Matic 7G Plus',
#  'CGI BlueEfficiency Xenon',
#  'd',
#  'Mercedes-AM53 4MATIC+',
#  'AMG ZOLL NACHTSICHT,SITZKLIMA,SERVOSCHLIES',
#  'HYBRID DESIGNO KEYLESSGO,SERVOSCHLIESSUNG',
#  '7G Plus',
#  '220d 4Matic 9G-Tronic 194',
#  '4M AMG Pano HeadUp Carbon LederExcluvBurme',
#  '4-MATIC*LUFT*HEAD-U*S-CLOSE*AHK*360°KEYLES',
#  '220CDI BE Avantgarde 7G Plus',
#  'S 7G Plus',
#  '-CLASS 4.7 455 4P',
#  '-CLASS 4.7 455 4P',
#  '-Klasse CGI BlueEfficiency LED Navi e-Sitze Parkle',
#  '4M L AMG PANO BURM TV HUD 360° MASSAGE',
#  '4-MATIC Automatik *PANO*HARMAN-KARDON*',
#  'Mercedes-AMG S 4MATIC+',
#  'Mercedes-AMG S 4MATIC+',
#  '4M Aut.',
#  '-CLASS 2.1 D 4MATIC AUTO 170CV 4P',
#  'BT',
#  '200CDI Avantgarde 7G Plus',
#  'd 4M AMG DISTRO+PANO+KAM360+WIDESCREEN',
#  'i 7G-TRONIC LED PERFOR. MBUX CARPLAY CAM. CUIR GAR',
#  '220d 9G-Tronic 194',
#  'd 4M AMG DISTRO+KAM360+HEADUP+WIDESCREEN',
#  'S 4Matic+ Alu LEDMultibeam Head-Up Navi P',
#  'AMG 20ZOLL NACHTSICHT,TV,KAMERA,HARMAN/K.',
#  '4M 3x AMG NIGHT DESIGNO WIDESCREEN,DISTRO',
#  'd 4M AMG DISTRO+KAM360+MEMORY+WIDESCREEN',
#  'CDI Business',
#  '*BI-XENON,NAVI,LEDER,PDC,SHZ,LED*',
#  '4M AVANTGARDE WIDESCREEN,HUD,MEMORY,PANO',
#  'd',
#  'Mercedes-AMG S 4MATIC+',
#  '-CLASS D G TRONIC PLUS AVANTGARDE',
#  '220CDI BE Avantgarde',
#  '4M SPORTPAKET AMG 18Z SPURPAKET,STANDHEIZ',
#  '220CDI BE Elegance Aut.',
#  '220BlueTec 7G Plus (4.75)',
#  'd',
#  'd',
#  'Aut.',
#  'd',
#  '4Matic 9G-Tronic',
#  '220CDI Avantgarde Aut.',
#  'S 4Matic+ 9G-Tronic',
#  'CDI 7G-TRONIC   24000Km !!   VOLL !!',
#  '220d 9G-Tronic 194',
#  '350d 4Matic 9G-Tronic',
#  'Kompr.*2xSHZ*2xPDC*SCHECKHEFT*TÜV NEU',
#  'Mercedes-AMG 4MATIC',
#  'd',
#  'd AMG 19Z WIDESCREEN,AIRMATIC,HUD,360GRAD',
#  '350d 4Matic 9G-Tronic',
#  'CDI 4M Aut. AMG Line',
#  'd 4Matic AMG*Leder*Navi*LED*Kamera* AMG',
#  'e Largo',
#  '220CDI BE Avantgarde Edition',
#  '220CDI BE Aut.',
#  '+ EDITION 1-HEADUP-PANO-AIRMATIC-360°',
#  'AVANTGARDE AUTOMAT+KLIMA+XENON+ALU+AHK',
#  'd 4-MATIC*PANO*LUFT*M-BEAM*MASSAGE*SPUR*1H',
#  '350+',
#  'd 4MATIC',
#  '320CDI Avantgarde 7G',
#  'CLA-CLASS 2.1 CDI DCT 170CV 4P',
#  'CLA-CLASS 2.1 CDI DCT 170CV 4P',
#  'Avantgarde BlueTec Hybrid BT',
#  'CGI BE *FACELIFT,KLIMA,NAVI,PDC,LED,SHZ*',
#  '220CDI Avantgarde Aut.',
#  'BlueTEC Sport',
#  'AVANTGARDE WIDESCREEN,DISTRO,KAMERA,SH,LED',
#  'd',
#  '220d 9G-Tronic (4.75)',
#  '4MATIC',
#  'Mercedes-AMG S 4MATIC+',
#  '350+',
#  'd Automatik+Navi+LED+Kamera',
#  'Mercedes-AMG 4MATIC',
#  'CLS-CLASS 272 4P',
#  '4M Aut.',
#  '-Klasse +Navi+Kamera+SHZ+PDCv+h.+Klimaauto.+Tempom',
#  'Blue Efficiency Avantgarde',
#  'd 4M AMG 20ZOLL SCHECKHEFT MULTIBEAM,1.HD',
#  'CDI Avantgarde',
#  'D*Navi*Rückfahrkamera*Sitzheizung*LED*DAB*',
#  '220d 9G-Tronic (4.75)',
#  '-Klasse e-Sitze Holzausst. Multif.Lenkrad RDC Klim',
#  'CDI BE Avantgarde Blue Effic. Ed.',
#  '-Klasse BlueTEC d LED Navi e-Sitze Nachtsichtass.',
#  'BT Edition 1 Aut.',
#  '350d 4M Largo 9G-Tronic (9.75)',
#  '220d 9G-Tronic 194',
#  '-Klasse EU6d-T Mercedes Benz Klasse LED Navi Keyle',
#  'BlueTEC 4Matic (212.011)',
#  '4Matic 360 Grad AHK',
#  'd 4Matic Alu Multibeam-LED Standh. Head-Up N',
#  'd AMG Line (EURO 6d-TEMP)',
#  'BT NACHTSICHT,360GRAD,KEYLESS,HUD,DISTRO',
#  '220d 9G-Tronic (4.75)',
#  '4M EDITION ONE AMG-DISTR-PREMIUM-PANO-360°',
#  '*1.HAND*ORIGINAL ZUSTAND*KEIN ROST',
#  'Mercedes-AMG 4MATIC',
#  '400d 4Matic Largo 9G-Tronic',
#  'd LANG 1.HAND DISTRONIC,HUD,360GRAD,AHK,SH',
#  'd LED Sitzh. Navi Kamera digitales Cockpit PDC',
#  '1.3CDTI Business75',
#  'GTC 2.0 T OPC',
#  '1.3CDTI Business75',
#  'D Energy 1.2*1.Hand*Alu*lückenlos Scheckheft',
#  'OPC PERFORMANCE XENON+RECARO+TEILLEDER+ALU OPC',
#  '1.2T XHL S/S Edition 100',
#  '1.7CDTI Cosmo',
#  '1.6CDTi S/S Dynamic 136',
#  '1.6T PHEV S/S GS-Line Aut. 180',
#  '1.3 ecoFlex Expression',
#  '1.3 CDTI DPF (ecoFLEX) Selection',
#  '1.6CDTi S/S Dynamic 136',
#  'E 1.6 Turbo OPC Recarositze - CarPlay - Sportpaket',
#  '1.4 Business 90 (4.75)',
#  '1.6CDTi S/S GSi Line 160',
#  '1.3CDTi Cosmo',
#  '1.4 66KW (90 CV) EXPRESSION PRO',
#  'E S 1.4 Turbo OPC-Line Recaro Sportsitze/Bi-Xenon/',
#  'E 1.4 Turbo GSi Xenon Sitzheizung PDC',
#  '1.2 XEL S/S Edition 75',
#  '1.6 16v Energy MTA 115',
#  'E 1.4 Turbo OPC-LINE SHZ LHZ TEMPOMAT APPLE/ANDROI',
#  '1.7CDTi Enjoy 100',
#  '1.6CDTi S/S Selective 110',
#  '1.2 XEL S/S Edition 75',
#  '1.5D DT S/S GS-Line + 100',
#  'INNOVATION 5-TÜREN+KLIMA+TEILLEDER+ALU+TOP',
#  '1.4T S/S Dynamic 125',
#  '1.6CDTi Business + 110',
#  '1.4 Active Automatik EU6 Klima PDC Sitzheizung Tem',
#  '1.4 Business 90 (4.75)',
#  '1.4 * Teilleder * Sitzhzg. * Klimaauto. *',
#  '1.2T S/S Design & Tech 130',
#  '1.4 XEL S&S Glam',
#  'E ON 1.4 *Einparkhilfe*AppleCarplay*Bluetooth USB',
#  'Rocks S 1.4 Turbo,Navi,Infinity,PDC',
#  '1.2 XEL S/S Edition 75',
#  'E 1,4 Turbo 120 JAHRE 3-türig Bluetooth,',
#  '1.2T S/S GS Line 110',
#  '1.4 XEL S&S Glam',
#  'E 120 Jahre 1.4 Tempomat+Telefon+PDC-h.',
#  'F Edition 1.2 Turbo Multif.Lenkrad Knieairbag Klim',
#  'EU6d F 1.2 Edition/Klima/Lenkradheizung/Tempomat/S',
#  'F 1.2 EU6d Edition/Tempomat/Lichtsensor/Bluetooth/',
#  '1.4 66KW (90 CV) EXPRESSION PRO',
#  '1.4 66KW (90 CV) EXPRESSION PRO',
#  'GTC 1.6CDTi S/S Sportive',
#  '120 Jahre ecoFlex 1.4 Turbo EU6d-T/Sitzheizung/Tem',
#  'F 1.2 EU6d/Tempomat/Spurhalteassistent/Klimaanlage',
#  'E 120 Jahre 1.4 Allwetter+Kamera+Telefon',
#  'F GS Line 1.2 Turbo MATRIX LEDLICHT,NAVI-PRO,KEYLE',
#  'E AUTOMATIK-1.4i-EDITION-Paket ALU-LMF WinterPaket',
#  '1.4 XEL S&S Jam',
#  'F Elegance 1.2 Turbo AppleCarPlay AndroidAuto Klim',
#  'F Elegance 1.2 Turbo LED Rückfahrkam. Fernlichtass',
#  '1.2 Selection+KLIMA+14-ZOLL+5-GANG-SCHALTG',
#  'E 1.4 ACTIVE 5türig Sitz-u. Lenkradheizung',
#  '1.2 Enjoy',
#  '1.3CDTi C Mon ecoFlex',
#  'E 1.4 Turbo GSi RECARO Bi-Xenon Navi DAB',
#  '1.6T S/S GSi Line 200',
#  '1.4 Business 90 (4.75)',
#  '-e Elegance KLIMAAUTO KAMERA TEMPOMAT APPLE ANDROI',
#  'Edition 1.2 Turbo LED - Sitzheizung - USB - Tempom',
#  'F Edition 1.2 Sitzheizung - Bluetooth - Tempomat',
#  '1.4 XER S&S Rocks',
#  'E 1.4 Turbo Color Edition*PDC*SHZ*Winter-Paket*Kli',
#  '-e Elegance !!3-PHASEN KLIMAAUTO KAMERA TEMPOMAT A',
#  'F Edition 1.2 Turbo 100PS,LED-SCHEINWERFER,SITZHEI',
#  'F GS Line 1.2/TEILLEDER/LED/CAR-PLAY/ALU/PDC',
#  'F GS Line 1.2 Turbo Klima PDC BT DAB (32)',
#  '2.0DTi 16v Sport',
#  '-e Elegance !!LED NAVI WINTERPAKET TEMPOMAT!!',
#  'F Edition 1.2 Turbo 100 PS, Regensensor, Lenkradhe',
#  'e Edition !!3-PHASEN KLIMAAUTO TEMPOMAT BLUET. DAB',
#  'E ALLWETTER KLIMA MULTIFLENRKAD BLUETOOTH/FREISPRE',
#  '-e Elegance !!3-PHASEN KLIMAAUTO KAMERA TEMPOMAT A',
#  'F Elegance 1.2 Turbo Navi LED PDC Klima Rückfahrka',
#  'e Edition !!3-PHASEN KLIMAAUTO TEMPOMAT BLUET. DAB',
#  '-e Edition !!3-PHASEN Apple CarPlay Klimaautom SHZ',
#  '-e Elegance !!3-PHASEN KLIMAAUTO KAMERA TEMPOMAT A',
#  'F Elegance Matrix-LED*Kamera*SHZ*PDC*Klima*Navigat',
#  'F GS Line 1.2 Turbo PDC Kamera Navi DAB',
#  'F Elegance 1.2 75PS,Allwetterreifen, Klimaautomati',
#  '2.0DTi 16v Sport',
#  'E 120 Jahre 1.2 Parktronic + Winterpaket',
#  '-e Edition !!3-PHASEN KLIMAAUTO NAVI PDC TEMPOMAT',
#  "1.4T  'Color Edition' *Klima*Lkrd+SHz*PDC*",
#  '-e Elegance !!3-PHASEN LED NAVI WINTERPAKET TEMPOM',
#  '1.0T S/S Selective',
#  '-e Elegance !!3-PHASEN LED NAVI WINTERPAKET TEMPOM',
#  '1.0 Turbo Glam Winterpaket Temp LED-Himmel',
#  '1.2 Essentia (146CO2)',
#  'F Elegance 1.2 Turbo Multifunktionslenkrad - PDC',
#  '1.4 XEL Jam Aut.',
#  '-e Elegance !!3-PHASEN LED NAVI WINTERPAKET TEMPOM',
#  'F Edition LED SHZ LHZ BLUETOOTH PDC DAB ALU KLIMA',
#  '1.4T Selective',
#  '-e Edition !!3-PHASEN Apple CarPlay Klimaautom SHZ',
#  'e Edition !!3-PHASEN SPURASSIST KLIMAAUTO SITZHZG!',
#  'Jam 1.4 Klimaanlage/PDC/Sitzheizung/ Bluetooth/Tem',
#  'Corsa-e Elegance-e',
#  '1.5D DTH S/S Elegance 130',
#  'F Basis 1.2 EU6d/Bluetooth/Klimaanlage/Tempomat/Sp',
#  '1.2 Jam Dachhimmel Led,Klima, 17Zoll Alu,Intellili',
#  '1.2 Selection',
#  'E ALLWETTER NAV APPLE/ANDROID DAB KLIMA BLUETOOTH/',
#  '1.2T XHT S/S Elegance AT8 100',
#  '2.0CDTi S/S Selective 165',
#  '1.4 Twinport 87ch Unlimited Start/Stop',
#  '1.6 Turbo OPC topstaat dikste Corsa OPC dealer aut',
#  '2.0 T Cosmo',
#  '1.4 Turbo Sport 3e Eigenaar! Trekhaak Airco NAP AP',
#  '1.5D DT S/S Edition 100',
#  '1.4 Turbo Edition 50% deal 4.125,- ACTIE Automaat',
#  '1.3 CDTi EcoFlex Cosmo INRUILKOOPJE !!',
#  '1.5D DT S/S Edition 100',
#  '1.4 OPC LINE / COLOR EDITION / AIRCO / NAVI / CRUI',
#  '2.0 T Executive. Automaat Bovag-Garantie',
#  ...]

# %%
# Since the make and model of the car are related to the upholstery colour, 
# we can fill the missing values by considering the relationship between the make_model 
# and colour of the car with the upholstery_colour.

# After the groupby operation, how many NaN values do I have remaining?

df.groupby(['make_model','colour', 'upholstery'], group_keys = False)['upholstery_colour'].transform(lambda x: x.fillna(x.mode()[0] if len(x.mode()) > 0 else np.nan)).isnull().sum()
# Out:
# 1736

# %%
df["upholstery_colour"] = df.groupby(['make_model','colour', 'upholstery'], group_keys = False)['upholstery_colour'].transform(lambda x: x.fillna(x.mode()[0] if len(x.mode()) > 0 else np.nan))

# %%
handle_missing_values(df, "upholstery_colour" )
# Out:
# Missing Values in 'upholstery_colour':
# Count: 1736
# Percentage: 6.07%

# %%
# Since the body_type, paint and location_country of the car are related to the upholstery colour, 
# we can fill the missing values by considering the relationship between them  with the upholstery_colour.

# After the groupby operation, how many NaN values do I have remaining?

df.groupby(['body_type','paint', 'location_country'], group_keys = False)['upholstery_colour'].transform(lambda x: x.fillna(x.mode()[0] if len(x.mode()) > 0 else np.nan)).isnull().sum()
# Out:
# 1

# %%
df["upholstery_colour"] = df.groupby(['body_type','paint', 'location_country'], group_keys = False)['upholstery_colour'].transform(lambda x: x.fillna(x.mode()[0] if len(x.mode()) > 0 else np.nan))

# %%
handle_missing_values(df, "upholstery_colour")
# Out:
# Missing Values in 'upholstery_colour':
# Count: 1
# Percentage: 0.00%

# %%
# Since the make_model and country_version of the car are related to the upholstery colour, 
# we can fill the missing values by considering the relationship between the make_model 
# and country_version of the car with the upholstery_colour.

# After the groupby operation, how many NaN values do I have remaining?

df.groupby(['make_model', 'country_version'], group_keys = False)['upholstery_colour'].transform(lambda x: x.fillna(x.mode()[0] if len(x.mode()) > 0 else np.nan)).isnull().sum()
# Out:
# 0

# %%
df["upholstery_colour"] = df.groupby(['make_model', 'country_version'], group_keys = False)['upholstery_colour'].transform(lambda x: x.fillna(x.mode()[0] if len(x.mode()) > 0 else np.nan))

# %%
handle_missing_values(df, "upholstery_colour")
# Out:
# Missing Values in 'upholstery_colour':
# Count: 0
# Percentage: 0.00%

# %% [markdown]
# <a id="30"></a>
# <div class="alert alert-info" role="alert">
# <h1>Column name :<span style="color:red"> fuel_consumption </span></h1>
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Operation : </b> To fill in the missing values in the "fuel_consumption" column, we can use the "short_description" column . Since the "fuel_consumption" column is associated with <span style="color:red"><b>  " body_type " , " power " , " engine_size ", " gearbox " , " gears " , " make_model ", " model ", " country_version ", " first_registration "  and " drivetrain "</b></span> . let's fill in the <span style="color:red"><b> NaN values</b></span> in this column by grouping the data based on these columns and performing the necessary operations.
# </div>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
first_looking("fuel_consumption")
# Out:
# column name    :  fuel_consumption
# --------------------------------
# per_of_nulls   :  % 18.26
# num_of_nulls   :  5223
# num_of_uniques :  304
# NaN     5223
# 0.0      648
# 5.0      562
# 5.4      505
# 4.9      494
#         ...
# 56.0       1
# 0.5        1
# 31.4       1
# 22.7       1
# 15.2       1
# Name: fuel_consumption, Length: 305, dtype: int64

# %%
first_looking("fuel_type")
# Out:
# column name    :  fuel_type
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  6
# Benzine     17819
# Diesel       8952
# Hybrid        875
# Electric      358
# Others        354
# Lpg           244
# Name: fuel_type, dtype: int64

# %%
# "Benzine", "Diesel", "Other", "LPG" fuel types have been analyzed separately from Hybrid and Electic Models
df_fuel = df[df["fuel_type"].isin(["Benzine", "Diesel", "Other", "LPG"])]
df_fuel.groupby(["model", "fuel_type", "body_type"])["fuel_consumption"].transform(lambda x: x.mean())
# Out:
# 0        41.600000
# 2         7.540385
# 3         6.665000
# 4        53.700000
# 5         8.200000
#            ...
# 29472     6.201538
# 29475     9.100000
# 29476    50.766667
# 29477     5.519231
# 29478    10.525000
# Name: fuel_consumption, Length: 26771, dtype: float64

# %%
# After the groupby operation, how many NaN values do I have remaining?
# first NaN values have been filled according to ["model", "fuel_type", "body_type"]
df.fuel_consumption.fillna(df_fuel.groupby(["model", "fuel_type", "body_type"])["fuel_consumption"].transform(lambda x: x.mean())).isnull().sum()
# Out:
# 1342

# %%
df.fuel_consumption.fillna(df_fuel.groupby(["model", "fuel_type", "body_type"])["fuel_consumption"].transform(lambda x: x.mean()), inplace = True)

# %%
handle_missing_values(df, "fuel_consumption")
# Out:
# Missing Values in 'fuel_consumption':
# Count: 1342
# Percentage: 4.69%

# %%
# After the groupby operation, how many NaN values do I have remaining?
df.fuel_consumption.fillna(df_fuel.groupby(["model", "fuel_type", "engine_size"])["fuel_consumption"].transform(lambda x: x.mean())).isnull().sum()
# Out:
# 1265

# %%
#NaN values have been filled according to ["model", "fuel_type", "engine_size"]
df.fuel_consumption.fillna(df_fuel.groupby(["model", "fuel_type", "engine_size"])["fuel_consumption"].transform(lambda x: x.mean()), inplace = True)

# %%
handle_missing_values(df, "fuel_consumption")
# Out:
# Missing Values in 'fuel_consumption':
# Count: 1265
# Percentage: 4.42%

# %%
# After the groupby operation, how many NaN values do I have remaining?
df.fuel_consumption.fillna(df_fuel.groupby(["fuel_type", "engine_size"])["fuel_consumption"].transform(lambda x: x.mean())).isnull().sum()
# Out:
# 648

# %%
#NaN values have been filled according to ["fuel_type", "engine_size"]
df.fuel_consumption.fillna(df_fuel.groupby(["fuel_type", "engine_size"])["fuel_consumption"].transform(lambda x: x.mean()), inplace = True)

# %%
handle_missing_values(df, "fuel_consumption")
# Out:
# Missing Values in 'fuel_consumption':
# Count: 648
# Percentage: 2.27%

# %%
# After the groupby operation, how many NaN values do I have remaining?
df.fuel_consumption.fillna(df_fuel.groupby(["make_model", "gears"])["fuel_consumption"].transform(lambda x: x.mean())).isnull().sum()
# Out:
# 640

# %%
#NaN values have been filled according to ["make_model", "gears"]
df.fuel_consumption.fillna(df_fuel.groupby(["make_model", "gears"])["fuel_consumption"].transform(lambda x: x.mean()), inplace = True)

# %%
handle_missing_values(df, "fuel_consumption")
# Out:
# Missing Values in 'fuel_consumption':
# Count: 640
# Percentage: 2.24%

# %%
df.groupby("fuel_type")["fuel_consumption"].value_counts(dropna = False)
# Out:
# fuel_type  fuel_consumption
# Benzine    5.0                 556
#            5.4                 502
#            4.9                 482
#            5.1                 476
#            0.0                 467
#                               ...
# Others     17.1                  1
#            18.8                  1
#            21.9                  1
#            22.7                  1
#            23.8                  1
# Name: fuel_consumption, Length: 1041, dtype: int64

# %%
df_fuel = df_fuel.copy()

# %%
df.engine_size.dtype
# Out:
# dtype('float64')

# %%
df_fuel["engine_class"] = df_fuel.engine_size.transform(lambda x: "best" if x <= 1.4 else \
                    "medium" if x <= 1.8  else "high" if x <= 2.6 \
                    else "higher" if x <= 3.5 else "too much")

# %%
# After the groupby operation, how many NaN values do I have remaining?
df.fuel_consumption.fillna(df_fuel.groupby(["make", "engine_class"])["fuel_consumption"].transform(lambda x: x.mean())).isnull().sum()
# Out:
# 626

# %%
# remaining NaN values have been filled after engine size has been reclassified as seen above
df.fuel_consumption.fillna(df_fuel.groupby(["make", "engine_class"])["fuel_consumption"].transform(lambda x: x.mean()), inplace = True)

# %%
handle_missing_values(df, "fuel_consumption")
# Out:
# Missing Values in 'fuel_consumption':
# Count: 626
# Percentage: 2.19%

# %%
# Let's fill Electric and Hybrid fuel_type .
# Let's handle hybrid and electric vehicles separately because their fuel consumption is calculated differently.
df[df.fuel_consumption.isnull()]["fuel_type"].unique()
# Out:
# array(['Electric', 'Lpg', 'Hybrid', 'Others', 'Benzine'], dtype=object)

# %%
df[df["fuel_type"] == "Hybrid"].index
# Out:
# Int64Index([  732,  1263,  1291,  1400,  1622,  2003,  2019,  2026,  2028,
#              2037,
#             ...
#             29288, 29299, 29302, 29315, 29324, 29338, 29398, 29408, 29466,
#             29474],
#            dtype='int64', length=875)

# %%
# Even though the most common Fuel Type for hybrid automobiles is Benzine, Diesel also might be preferred.
# Hybrid/diesel fuel type has been searched in Short Description 
df.loc[df[df["fuel_type"] == "Hybrid"]["short_description"].str.extract("(diesel)", flags=re.IGNORECASE).dropna().index, "fuel_consumption"]
# Out:
# 1263     1.9
# 27829    5.6
# 27831    5.6
# 27890    5.5
# 28215    5.6
# 28217    5.6
# 28272    5.5
# 28324    NaN
# 28399    4.7
# 28724    NaN
# 28799    4.7
# Name: fuel_consumption, dtype: float64

# %%
# hybrid diesel fuel type has been reclassified as "Hybrid/Diesel"
df.loc[df[df["fuel_type"] == "Hybrid"]["short_description"].str.extract("(diesel)", flags=re.IGNORECASE).dropna().index, "fuel_type"] = "Hybrid/Diesel"

# %%
# hybrid diesel fuel type has been transformed from LT/100 km to KwH/100 km
df.loc[df["fuel_type"] == "Hybrid/Diesel", "fuel_consumption"] = (df.loc[df["fuel_type"] == "Hybrid/Diesel", "fuel_consumption"] * 10.96).round(1)

# %%
df[df["fuel_type"] == "Hybrid/Diesel"]["fuel_consumption"]
# Out:
# 1263     20.8
# 27829    61.4
# 27831    61.4
# 27890    60.3
# 28215    61.4
# 28217    61.4
# 28272    60.3
# 28324     NaN
# 28399    51.5
# 28724     NaN
# 28799    51.5
# Name: fuel_consumption, dtype: float64

# %%
# hybrid Benzine fuel type has been transformed from LT/100 km to KwH/100 km
df.loc[df[df["fuel_type"] == "Hybrid"].index, "fuel_consumption"] = (df.loc[df[df["fuel_type"] == "Hybrid"].index, "fuel_consumption"] * 9.61).round(1)

# %%
df[df["fuel_type"] == "Hybrid"]["fuel_consumption"]
# Out:
# 732      78.8
# 1291      NaN
# 1400      NaN
# 1622     83.6
# 2003     42.3
#          ...
# 29338    16.3
# 29398    57.7
# 29408    57.7
# 29466    18.3
# 29474    19.2
# Name: fuel_consumption, Length: 864, dtype: float64

# %%
handle_missing_values(df, "fuel_consumption")
# Out:
# Missing Values in 'fuel_consumption':
# Count: 626
# Percentage: 2.19%

# %%
# After the groupby operation, how many NaN values do I have remaining?
df.fuel_consumption.fillna(df.groupby(["model", "fuel_type", "engine_size"])["fuel_consumption"].transform(lambda x: x.mean())).isnull().sum()
# Out:
# 456

# %%
# Remainin NaN values have been filled according to ["model", "fuel_type", "engine_size"]
df.fuel_consumption.fillna(df.groupby(["model", "fuel_type", "engine_size"])["fuel_consumption"].transform(lambda x: x.mean()), inplace = True)

# %%
handle_missing_values(df, "fuel_consumption")
# Out:
# Missing Values in 'fuel_consumption':
# Count: 456
# Percentage: 1.59%

# %%
# After the groupby operation, how many NaN values do I have remaining?
df.fuel_consumption.fillna(df.groupby(["power", "country_version"])["fuel_consumption"].transform(lambda x: x.mean())).isnull().sum()
# Out:
# 39

# %%
# Remainin NaN values have been filled according to ["power", "country_version"]
df.fuel_consumption.fillna(df.groupby(["power", "country_version"])["fuel_consumption"].transform(lambda x: x.mean()), inplace = True)

# %%
handle_missing_values(df, "fuel_consumption")
# Out:
# Missing Values in 'fuel_consumption':
# Count: 39
# Percentage: 0.14%

# %%
# After the groupby operation, how many NaN values do I have remaining?
df.fuel_consumption.fillna(df.groupby(["fuel_type", "drivetrain"])["fuel_consumption"].transform(lambda x: x.mean())).isnull().sum()
# Out:
# 0

# %%
# Remainin NaN values have been filled according to ["fuel_type", "drivetrain"]
df.fuel_consumption.fillna(df.groupby(["fuel_type", "drivetrain"])["fuel_consumption"].transform(lambda x: x.mean()), inplace = True)

# %%
handle_missing_values(df, "fuel_consumption")
# Out:
# Missing Values in 'fuel_consumption':
# Count: 0
# Percentage: 0.00%

# %% [markdown]
# <a id="31"></a>
# <div class="alert alert-info" role="alert">
# <h1>Column name :<span style="color:red"> make_model and model </span></h1>
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Operation : </b> To fill in the missing values in the "fuel_consumption" column, we can use the "short_description" column . Since the "fuel_consumption" column is associated with <span style="color:red"><b> ' body_type ',' make ', ' drivetrain', ' country_version ' , ' engine_size ' and '  first_registration '</b></span> . let's fill in the <span style="color:red"><b> NaN values</b></span> in this column by grouping the data based on these columns and performing the necessary operations.
# </div>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
first_looking("model")
# Out:
# column name    :  model
# --------------------------------
# per_of_nulls   :  % 0.95
# num_of_nulls   :  272
# num_of_uniques :  585
# Megane        863
# Leon          787
# V40           740
# Sandero       730
# i30           706
#              ...
# CLK 240         1
# Ariya           1
# 280 ZX          1
# GLS 63 AMG      1
# 244             1
# Name: model, Length: 586, dtype: int64

# %%
df[df["model"].isnull()]["make_model"]
# Out:
# 162      Mercedes-Benz
# 184      Mercedes-Benz
# 186      Mercedes-Benz
# 211      Mercedes-Benz
# 213      Mercedes-Benz
#               ...
# 27638            Volvo
# 27681            Volvo
# 28020            Volvo
# 28036            Volvo
# 28079            Volvo
# Name: make_model, Length: 272, dtype: object

# %%
first_looking("make")
# Out:
# column name    :  make
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  13
# Volvo            3657
# Mercedes-Benz    2394
# Opel             2384
# Peugeot          2357
# Renault          2344
# Fiat             2336
# Ford             2321
# Nissan           2062
# Toyota           2037
# Hyundai          1866
# SEAT             1743
# Skoda            1565
# Dacia            1536
# Name: make, dtype: int64

# %%
first_looking("make_model")
# Out:
# column name    :  make_model
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  0
# num_of_uniques :  603
# Renault Megane            863
# SEAT Leon                 787
# Volvo V40                 740
# Dacia Sandero             730
# Hyundai i30               706
#                          ...
# Mercedes-Benz CLK 240       1
# Mercedes-Benz SL 450        1
# Nissan NV250                1
# Mercedes-Benz C 32 AMG      1
# Volvo 244                   1
# Name: make_model, Length: 603, dtype: int64

# %%
df[df["model"].isnull()][["model_code", "make_model", 'body_type']]
# Out:
#       model_code      make_model         body_type
# 162          NaN  Mercedes-Benz            Compact
# 184          NaN  Mercedes-Benz            Compact
# 186          NaN  Mercedes-Benz            Compact
# 211          NaN  Mercedes-Benz            Compact
# 213          NaN  Mercedes-Benz            Compact
# ...          ...             ...               ...
# 27638        NaN          Volvo   Off-Road/Pick-up
# 27681        NaN          Volvo   Off-Road/Pick-up
# 28020   9101/BTE          Volvo   Off-Road/Pick-up
# 28036        NaN          Volvo   Off-Road/Pick-up
# 28079        NaN          Volvo   Off-Road/Pick-up
#
# [272 rows x 3 columns]

# %%
# missing model names has been filtered and assigned to df_model_nan
df_model_nan = df[df["model"].isnull()]

# %%
df_model_nan.make.unique()
# Out:
# array(['Mercedes-Benz', 'Opel', 'Renault', 'Peugeot', 'Fiat', 'SEAT',
#        'Skoda', 'Dacia', 'Toyota', 'Nissan', 'Ford', 'Hyundai', 'Volvo'],
#       dtype=object)

# %%
count = 0  # To keep track of the number of matching values

for index, row in df.loc[df['model'].isna()].iterrows():
    short_desc = row['short_description']
    matched_models = []
    longest_model = ""
    for model in df['model']:
        if pd.notna(model) and not pd.isna(short_desc) and model.lower() in short_desc.lower() and not model.lower() == "ion":
            if len(model) > 1:  # Exclude single-letter names
                matched_models.append(model)
                if len(model) > len(longest_model):
                    longest_model = model
    if matched_models:
        df.at[index, 'model'] = longest_model  # Assign the longest matching value to the 'model' column
        count += 1  # Increment the counter for each match
        print(f"Index: {index}, Longest Matching Value: {longest_model}")

print("Number of Matching Values:", count)
# Out:
# Index: 162, Longest Matching Value: A 180
# Index: 184, Longest Matching Value: A 180
# Index: 186, Longest Matching Value: A 180
# Index: 211, Longest Matching Value: A 160
# Index: 213, Longest Matching Value: A 180
# Index: 226, Longest Matching Value: A 160
# Index: 319, Longest Matching Value: CL
# Index: 442, Longest Matching Value: CL
# Index: 642, Longest Matching Value: C 180
# Index: 643, Longest Matching Value: C 200
# Index: 651, Longest Matching Value: Antara
# Index: 856, Longest Matching Value: E 500
# Index: 861, Longest Matching Value: AMG GT
# Index: 1275, Longest Matching Value: GLA 250
# Index: 1820, Longest Matching Value: C 43 AMG
# Index: 1974, Longest Matching Value: C 300
# Index: 2035, Longest Matching Value: E 63 AMG
# Index: 2186, Longest Matching Value: S 580
# Index: 2337, Longest Matching Value: B 220
# Index: 2917, Longest Matching Value: Excel
# Index: 2921, Longest Matching Value: Excel
# Index: 2923, Longest Matching Value: Excel
# Index: 2924, Longest Matching Value: Excel
# Index: 2926, Longest Matching Value: Excel
# Index: 2927, Longest Matching Value: Excel
# Index: 2928, Longest Matching Value: Excel
# Index: 2931, Longest Matching Value: Excel
# Index: 2932, Longest Matching Value: Excel
# Index: 2933, Longest Matching Value: Excel
# Index: 2934, Longest Matching Value: Excel
# Index: 2936, Longest Matching Value: Excel
# Index: 2939, Longest Matching Value: Excel
# Index: 2942, Longest Matching Value: Excel
# Index: 2943, Longest Matching Value: Excel
# Index: 2944, Longest Matching Value: Excel
# Index: 2945, Longest Matching Value: Excel
# Index: 2948, Longest Matching Value: Excel
# Index: 2949, Longest Matching Value: Excel
# Index: 2950, Longest Matching Value: Excel
# Index: 2951, Longest Matching Value: Excel
# Index: 2952, Longest Matching Value: Excel
# Index: 2953, Longest Matching Value: Excel
# Index: 2954, Longest Matching Value: Excel
# Index: 2958, Longest Matching Value: Excel
# Index: 2959, Longest Matching Value: Excel
# Index: 2960, Longest Matching Value: Excel
# Index: 2961, Longest Matching Value: Excel
# Index: 2962, Longest Matching Value: Excel
# Index: 2964, Longest Matching Value: Excel
# Index: 2965, Longest Matching Value: Excel
# Index: 2966, Longest Matching Value: Excel
# Index: 2967, Longest Matching Value: Excel
# Index: 2968, Longest Matching Value: Excel
# Index: 2969, Longest Matching Value: Excel
# Index: 2970, Longest Matching Value: Excel
# Index: 2971, Longest Matching Value: Excel
# Index: 2972, Longest Matching Value: Excel
# Index: 2973, Longest Matching Value: Excel
# Index: 2974, Longest Matching Value: Excel
# Index: 2975, Longest Matching Value: Excel
# Index: 2976, Longest Matching Value: Excel
# Index: 2978, Longest Matching Value: Excel
# Index: 2979, Longest Matching Value: Excel
# Index: 2980, Longest Matching Value: Excel
# Index: 2981, Longest Matching Value: Excel
# Index: 2982, Longest Matching Value: Excel
# Index: 2983, Longest Matching Value: Excel
# Index: 2984, Longest Matching Value: Excel
# Index: 2985, Longest Matching Value: Excel
# Index: 2987, Longest Matching Value: Excel
# Index: 2989, Longest Matching Value: Excel
# Index: 2990, Longest Matching Value: Excel
# Index: 2991, Longest Matching Value: Excel
# Index: 2992, Longest Matching Value: Excel
# Index: 2993, Longest Matching Value: Excel
# Index: 2995, Longest Matching Value: Excel
# Index: 2996, Longest Matching Value: Excel
# Index: 2997, Longest Matching Value: Excel
# Index: 2998, Longest Matching Value: Excel
# Index: 2999, Longest Matching Value: Excel
# Index: 3000, Longest Matching Value: Excel
# Index: 3001, Longest Matching Value: Excel
# Index: 3002, Longest Matching Value: Excel
# Index: 3003, Longest Matching Value: Excel
# Index: 3004, Longest Matching Value: Excel
# Index: 3005, Longest Matching Value: Excel
# Index: 3006, Longest Matching Value: Excel
# Index: 3007, Longest Matching Value: Excel
# Index: 3009, Longest Matching Value: Excel
# Index: 3010, Longest Matching Value: Excel
# Index: 3011, Longest Matching Value: Excel
# Index: 3012, Longest Matching Value: Excel
# Index: 3013, Longest Matching Value: Excel
# Index: 3015, Longest Matching Value: Excel
# Index: 3016, Longest Matching Value: Excel
# Index: 3017, Longest Matching Value: Excel
# Index: 3018, Longest Matching Value: Excel
# Index: 3019, Longest Matching Value: Excel
# Index: 3020, Longest Matching Value: Excel
# Index: 3021, Longest Matching Value: Excel
# Index: 3022, Longest Matching Value: Excel
# Index: 3023, Longest Matching Value: Excel
# Index: 3024, Longest Matching Value: Excel
# Index: 3025, Longest Matching Value: Excel
# Index: 3026, Longest Matching Value: Excel
# Index: 3028, Longest Matching Value: Excel
# Index: 3029, Longest Matching Value: Excel
# Index: 3030, Longest Matching Value: Excel
# Index: 3031, Longest Matching Value: Excel
# Index: 3032, Longest Matching Value: Excel
# Index: 3033, Longest Matching Value: Excel
# Index: 3034, Longest Matching Value: Excel
# Index: 3035, Longest Matching Value: Excel
# Index: 3037, Longest Matching Value: Excel
# Index: 3039, Longest Matching Value: Excel
# Index: 3040, Longest Matching Value: Excel
# Index: 3041, Longest Matching Value: Excel
# Index: 3042, Longest Matching Value: Excel
# Index: 3043, Longest Matching Value: Excel
# Index: 3044, Longest Matching Value: Excel
# Index: 3387, Longest Matching Value: Astra
# Index: 5196, Longest Matching Value: Twizy
# Index: 5324, Longest Matching Value: Spider
# Index: 5408, Longest Matching Value: Spider
# Index: 5660, Longest Matching Value: Alpine A610
# Index: 6723, Longest Matching Value: 200
# Index: 6745, Longest Matching Value: 190
# Index: 9762, Longest Matching Value: 500
# Index: 10145, Longest Matching Value: 124 Spider
# Index: 10319, Longest Matching Value: 124 Spider
# Index: 10430, Longest Matching Value: Coupe
# Index: 10431, Longest Matching Value: Coupe
# Index: 10475, Longest Matching Value: Coupe
# Index: 10477, Longest Matching Value: Coupe
# Index: 10480, Longest Matching Value: 230
# Index: 10526, Longest Matching Value: 850
# Index: 10571, Longest Matching Value: 230
# Index: 10600, Longest Matching Value: Coupe
# Index: 10631, Longest Matching Value: 500
# Index: 10632, Longest Matching Value: Coupe
# Index: 10657, Longest Matching Value: Coupe
# Index: 10660, Longest Matching Value: R 5
# Index: 11228, Longest Matching Value: Qubo
# Index: 11252, Longest Matching Value: Qubo
# Index: 11346, Longest Matching Value: 500
# Index: 12072, Longest Matching Value: 600
# Index: 12395, Longest Matching Value: 850
# Index: 12410, Longest Matching Value: 128
# Index: 16846, Longest Matching Value: 130
# Index: 17560, Longest Matching Value: Supra
# Index: 17837, Longest Matching Value: Supra
# Index: 17839, Longest Matching Value: GT
# Index: 18512, Longest Matching Value: Auris
# Index: 18524, Longest Matching Value: Auris
# Index: 18577, Longest Matching Value: 130
# Index: 19904, Longest Matching Value: Skyline
# Index: 19940, Longest Matching Value: 240
# Index: 19991, Longest Matching Value: Skyline
# Index: 20004, Longest Matching Value: Datsun
# Index: 20008, Longest Matching Value: Datsun
# Index: 20031, Longest Matching Value: Datsun
# Index: 21920, Longest Matching Value: Coupe
# Index: 21960, Longest Matching Value: Mustang
# Index: 21979, Longest Matching Value: 500
# Index: 22268, Longest Matching Value: Coupe
# Index: 22531, Longest Matching Value: 200
# Index: 22556, Longest Matching Value: F 150
# Index: 25204, Longest Matching Value: i30
# Index: 25222, Longest Matching Value: BAYON
# Index: 25315, Longest Matching Value: i30
# Index: 25316, Longest Matching Value: i30
# Index: 26739, Longest Matching Value: GT
# Index: 27062, Longest Matching Value: GT
# Index: 27124, Longest Matching Value: Amazon
# Index: 27185, Longest Matching Value: PV544
# Index: 27235, Longest Matching Value: P1800
# Index: 27301, Longest Matching Value: P1800
# Index: 27318, Longest Matching Value: Amazon
# Index: 27379, Longest Matching Value: PV544
# Index: 27429, Longest Matching Value: P1800
# Index: 27495, Longest Matching Value: P1800
# Number of Matching Values: 181

# %%
handle_missing_values(df, "model")
# Out:
# Missing Values in 'model':
# Count: 91
# Percentage: 0.32%

# %%
# After the groupby operation, how many NaN values do I have remaining?

df.groupby(['drivetrain', 'body_type', 'make', 'first_registration'], group_keys = False)['model'].transform(lambda x: x.fillna(x.mode()[0] if len(x.mode()) > 0 else np.nan)).isnull().sum()
# Out:
# 22

# %%
df.model = df.groupby(['drivetrain', 'body_type', 'make', 'first_registration'], group_keys = False)['model'].transform(lambda x: x.fillna(x.mode()[0] if len(x.mode()) > 0 else np.nan))

# %%
handle_missing_values(df, "model")
# Out:
# Missing Values in 'model':
# Count: 22
# Percentage: 0.08%

# %%
# After the groupby operation, how many NaN values do I have remaining?

df.groupby(['country_version', 'body_type', 'make'], group_keys = False)['model'].transform(lambda x: x.fillna(x.mode()[0] if len(x.mode()) > 0 else np.nan)).isnull().sum()
# Out:
# 0

# %%
df.model = df.groupby(['country_version', 'body_type', 'make'], group_keys = False)['model'].transform(lambda x: x.fillna(x.mode()[0] if len(x.mode()) > 0 else np.nan))

# %%
handle_missing_values(df, "model")
# Out:
# Missing Values in 'model':
# Count: 0
# Percentage: 0.00%

# %%
handle_missing_values(df, "make")
# Out:
# Missing Values in 'make':
# Count: 0
# Percentage: 0.00%

# %%
handle_missing_values(df, "make_model")
# Out:
# Missing Values in 'make_model':
# Count: 0
# Percentage: 0.00%

# %%
# Since missing value handlind is completed for model column. Make_model column is also filled simultaneously.
df["make_model"] = df["make"].str.strip() + " " + df["model"].str.strip()
df["make_model"] = df["make_model"].str.title()

# %%
df.make_model
# Out:
# 0           Mercedes-Benz A 160
# 1         Mercedes-Benz Eqe 350
# 2        Mercedes-Benz A 45 Amg
# 3        Mercedes-Benz A 35 Amg
# 4        Mercedes-Benz A 45 Amg
#                   ...
# 29474                 Volvo S90
# 29475                 Volvo S40
# 29476                 Volvo C30
# 29477                 Volvo S90
# 29478                 Volvo S80
# Name: make_model, Length: 28602, dtype: object

# %%
selected_columns = ['price', 'make_model', 'model', 'first_registration', 'engine_size', 'model_code']
filters = {'make_model'}
select_rows(df, selected_columns, filters )
# Out:
# Dropdown(description='make_model:', options=('Mercedes-Benz A 160', 'Mercedes-Benz Eqe 350', 'Mercedes-Benz A …
# Button(description='Selection', style=ButtonStyle())

# %% [markdown]
# <a id="32"></a>
# <div class="alert alert-info" role="alert">
# <h1>Column name :<span style="color:red"> emission_class </span></h1>
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Operation : </b> To fill in the missing values in the "emission_class" column, we can use the "short_description" column . Let's classify the NaN values in the <span style="color:red"><b> "emission_class"</span> column based on the <span style="color:red"><b>"first_registration"</b></span> dates. Since this classification was not in place before 1992, let's create an <span style="color:red"><b> "Under Class" </b></span>category for models registered before 1992.
# </div>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
first_looking("emission_class")
# Out:
# column name    :  emission_class
# --------------------------------
# per_of_nulls   :  % 37.57
# num_of_nulls   :  10745
# num_of_uniques :  9
# NaN             10745
# Euro 6           6417
# Euro 6d-TEMP     3399
# Euro 6d          2858
# Euro 5           2388
# Euro 4           1743
# Euro 3            523
# Euro 2            217
# Euro 1            172
# Euro 6c           140
# Name: emission_class, dtype: int64

# %%
# Let's classify the NaN values in the "emission_class" column based on the "first_registration" dates.

# Since this classification was not in place before 1992,
# let's create an "Under Class" category for models registered before 1992.
df.emission_class = df.emission_class.fillna(df.loc[(df.emission_class.isnull() & (pd.to_datetime(df.first_registration).dt.date < pd.to_datetime('1992').date())), 'emission_class'].replace(np.NaN, 'Under Class'))

df.emission_class = df.emission_class.fillna(df.loc[(df.emission_class.isnull() & (pd.to_datetime(df.first_registration).dt.date < pd.to_datetime('1996').date())), 'emission_class'].replace(np.NaN, 'Euro 1'))

df.emission_class = df.emission_class.fillna(df.loc[(df.emission_class.isnull() & (pd.to_datetime(df.first_registration).dt.date < pd.to_datetime('2000').date())), 'emission_class'].replace(np.NaN, 'Euro 2'))

df.emission_class = df.emission_class.fillna(df.loc[(df.emission_class.isnull() & (pd.to_datetime(df.first_registration).dt.date < pd.to_datetime('2005').date())), 'emission_class'].replace(np.NaN, 'Euro 3'))

df.emission_class = df.emission_class.fillna(df.loc[(df.emission_class.isnull() & (pd.to_datetime(df.first_registration).dt.date < pd.to_datetime('2009').date())), 'emission_class'].replace(np.NaN, 'Euro 4'))

df.emission_class = df.emission_class.fillna(df.loc[(df.emission_class.isnull() & (pd.to_datetime(df.first_registration).dt.date < pd.to_datetime('2014').date())), 'emission_class'].replace(np.NaN, 'Euro 5'))

df.emission_class = df.emission_class.fillna(df.loc[(df.emission_class.isnull() & (pd.to_datetime(df.first_registration).dt.date >= pd.to_datetime('2014').date())), 'emission_class'].replace(np.NaN, 'Euro 6'))

df.emission_class = df.emission_class.fillna(df.loc[(df.emission_class.isnull() & (pd.to_datetime(df.first_registration).dt.date > pd.to_datetime('2014').date())), 'emission_class'].replace(np.NaN, 'Euro 6'))

df.emission_class = df.emission_class.str.replace('Euro 6d-TEMP','Euro 6')
df.emission_class = df.emission_class.str.replace('Euro 6d','Euro 6')
df.emission_class = df.emission_class.str.replace('Euro 6c','Euro 6')   

df.emission_class.isnull().sum()
# Out:
# 0

# %%
handle_missing_values(df, "emission_class")
# Out:
# Missing Values in 'emission_class':
# Count: 0
# Percentage: 0.00%

# %%
df.emission_class.value_counts()
# Out:
# Euro 6         12814
# Under Class    10745
# Euro 5          2388
# Euro 4          1743
# Euro 3           523
# Euro 2           217
# Euro 1           172
# Name: emission_class, dtype: int64

# %% [markdown]
# <a id="33"></a>
# <div class="alert alert-info" role="alert">
# <h1>Column name :<span style="color:red"> emissions_sticker </span></h1>
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Operation : </b> To fill in the missing values in the "emissions_sticker" column, we can use the "short_description" column . Since the "emissions_sticker" column is associated with <span style="color:red"><b>  " emission_class" , " make_model ", " fuel_type " and " first_registration "  </b></span> . let's fill in the <span style="color:red"><b> NaN values</b></span> in this column by grouping the data based on these columns and performing the necessary operations.
# </div>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
first_looking("emissions_sticker")
# Out:
# column name    :  emissions_sticker
# --------------------------------
# per_of_nulls   :  % 67.09
# num_of_nulls   :  19189
# num_of_uniques :  4
# NaN               19189
# green_sticker      9230
# no_sticker          175
# yellow_sticker        6
# red_sticker           2
# Name: emissions_sticker, dtype: int64

# %%
df.columns
# Out:
# Index(['make_model', 'short_description', 'make', 'model', 'location', 'price',
#        'body_type', 'type', 'doors', 'country_version', 'offer_number',
#        'warranty', 'mileage', 'first_registration', 'gearbox', 'fuel_type',
#        'colour', 'paint', 'desc', 'seller', 'seats', 'power', 'engine_size',
#        'gears', 'co_emissions', 'manufacturer_colour', 'drivetrain',
#        'cylinders', 'fuel_consumption', 'comfort_&_convenience',
#        'entertainment_&_media', 'safety_&_security', 'extras', 'empty_weight',
#        'model_code', 'general_inspection', 'full_service_history',
#        'non_smoker_vehicle', 'emission_class', 'emissions_sticker',
#        'upholstery_colour', 'upholstery', 'previous_owner',
#        'energy_efficiency_class', 'co_efficiency', 'location_country',
#        'location_city'],
#       dtype='object')

# %%
# Let's examine the short description of the emissions_sticker
list(df.loc[df[df["emissions_sticker"].isnull()].index, "short_description"])
# Out:
# ['CDi',
#  '350+',
#  'S 4Matic+ 8G-DCT',
#  '4Matic+ 7G-DCT',
#  '200CDI BE Line 4M 7G-DCT',
#  '7G-DCT',
#  '4MATIC',
#  '200CDI Autotronic',
#  'CDI 90PK NK77971',
#  '4Matic 7G-DCT',
#  'BE AMG Line 7G-DCT',
#  'd 116PK RZ47072',
#  '200CDI BE Line 4M 7G-DCT',
#  'e Limousine',
#  '4Matic+ 7G-DCT',
#  '180d 7G-DCT',
#  '4Matic 7G-DCT',
#  '180d 7G-DCT',
#  '180d Sedán 7G-DCT',
#  nan,
#  nan,
#  'd 4Matic (EURO 6d)',
#  '180d 7G-DCT',
#  'S 4Matic+ 8G-DCT',
#  'CDI',
#  '4Matic 7G-DCT',
#  'Limousine',
#  nan,
#  '250e 8G-DCT',
#  'CDI Elegance',
#  '7G-DCT (4.75)',
#  nan,
#  '180d 7G-DCT',
#  'd AMG Line (EURO 6d)',
#  'Berline - Garantie 48 mois - 316.41 €/mois*',
#  'CDI BlueEfficiency Standard 110PK MZ74192',
#  'd (177.003)',
#  'progressive mbux, dab, apple carplay',
#  '-Klasse Navi RDC Klima SHZ DVD CD-W CD MP3 ESP MAL',
#  '180d 7G-DCT',
#  '7G-DCT',
#  '180d 7G-DCT',
#  '180d 7G-DCT',
#  '180d 7G-DCT',
#  '180d 7G-DCT',
#  'AUTOMATIK NAV LED KAMERA PARK-ASSIST SHZ DIG-DISPL',
#  '200CDI BE Style',
#  '200CDI BE Urban 7G-DCT',
#  'd (177.003)',
#  '180d 7G-DCT',
#  '180d Sedán 7G-DCT',
#  nan,
#  '180d 7G-DCT',
#  '7G-DCT',
#  'Business Solution LED GPS PDC CAM Verw. Zetels',
#  '200d 4Matic 8G-DCT',
#  '180d 7G-DCT',
#  nan,
#  '200CDI BE AMG Line 7G-DCT',
#  '200CDI BE AMG Line 7G-DCT',
#  '200d 7G-DCT',
#  'A-CLASS A180 1.3 136 CV 7G-DCT 5P',
#  '200d Sedán 8G-DCT',
#  'S 4MATIC+',
#  'd Avantgarde Largo',
#  '180d Sedán 7G-DCT',
#  'AMG Line AUTOMATIK NAV LED KAMERA NIGHT PAKET SHZ',
#  '180d 7G-DCT',
#  'Avantgarde',
#  nan,
#  'Avantgarde',
#  'Sport 4Matic 7G-DCT',
#  'progressive mbux, camera, lane assist, pdc',
#  'progressive led high performance, mbux, lane assis',
#  '7G-DCT',
#  'CDI Blueefficiency Edition Style 110PK EF53658',
#  '4Matic+ 7G-DCT',
#  'C Coupe (BM 190)',
#  '300E',
#  '4-Door Coupe 43 4MATIC+ Premium AMG, NIEUWSTAAT!!',
#  '4-Door GT 63 S CARBON AERO 5-ZITS HUD',
#  '180CDI Avantgarde Aut.',
#  '4-Door Coupe 53 4MATIC+ Premium | AMG Trackpace |',
#  '580 4MATIC AMG Line Premium plus | Rij-assist + |',
#  '450+ AMG Line 108kWh',
#  'S 4Matic+ 8G-DCT',
#  'S AMG 4MATIC+',
#  'S 4Matic+ 8G-DCT',
#  '4-Door Coupe 43 4MATIC+ Premium Plus 63 AMG Uitgev',
#  'A35 AMG 4MATIC Premium+ 306PK | Pano | Sfeer | Bur',
#  'Business Solution AMG',
#  '4-Door Coupe 43 4MATIC+ Premium Plus PANO, BURMEST',
#  '4MATIC PERFORMANCE AERO PACK/SCHAAL/PANO/MEMORY VO',
#  '4MATIC l Top staat! l Panorama l Camera l Dealer O',
#  'AMG/ NIGHT PAKKET/ PANO/ AMG SPOILER',
#  'CDI Ambition 4U3 Navigatie',
#  'd Business Solution Automaat - Cruise - Navi - Hal',
#  '4MATIC STOELVERWARMING/AERO/381PK/BOMVOL',
#  '350 AMG Line 90kWh Premium Pack',
#  'd Lease Edition Ambition',
#  'CDI Ambition [ Xenon | Navi | Cruise ]',
#  'A35 AMG 4-MATIC *Pano*Burmester*4AMG Aero*Vol!*',
#  '4MATIC [ Panorama Xenon Leder ]',
#  'S Coupe Edition 1',
#  'Business Solution AMG',
#  'Business Solution AMG',
#  'AMG Sport Prestige Automaat (NAVIGATIE, TELEFOON,',
#  '4Matic 7G-DCT',
#  '4MATIC Edition 1 MEMORY/PANO/LEER/H&K/BOMVOL',
#  'CDI Air-Lift Schuifdak Harman/Kardon Night Leder U',
#  'AMG A 35 4MATIC',
#  '4MATIC | 381PK | Apple Carplay | Stoelverwarming |',
#  '4MATIC 280kW/381pk DCT7 NIGHT PAKKET + PANORAMADAK',
#  'Premium Night Aut. [ Burmester Widescreen Half-Led',
#  'Premium+ AMG Edition 1 225PK | Pano | Sfeer | Virt',
#  '4-Door 63 S 4MATIC+',
#  'Premium Plus | AMG Line | Lederen bekleding | LED',
#  '4MATIC | Pano | Navi | PDC | Cruise |',
#  'D AMG Pakket / Panoramadak / Navigatie / N.A.P.',
#  'e AMG Line Panodak',
#  'AMG Edition Sport Automaat (SCHUIFDAK, APPLE CARPL',
#  'Business Solution AMG',
#  '180CDI',
#  '180CDI Exclusive Edition',
#  'd (177.003)',
#  'Automaat | Leder Interieur | 1j Garantie',
#  'd Led Navigatie Stoelverw. Carplay Leer Zondag a.s',
#  'CDi',
#  'A35 AMG 4MATIC Advantage',
#  'd (177.003)',
#  'Ambition | Harman | ACC | Pano | CAM | AMG-Line',
#  '200 CDi 1.8 CDI Boîte auto',
#  'S 4Matic+ 8G-DCT',
#  'CLASSE  d Fascination 4Matic 7G-DCT',
#  'AMG Ambiante verlichting Panodak Camera Zondag a.s',
#  '200 d Fascination 7G-DCT',
#  '250e 8G-DCT',
#  '180d 7G-DCT',
#  '7G-DCT',
#  '-Edition BlueEfficiency',
#  'd AMG PANORAMADAK/WIDESCREEN/SFEER/MEMORY/BOMVOL',
#  "Ambition NAVI BT LEDER PDC LED STOELVERW '16",
#  'd AMG / Panorama dak / Leder / Navi / Pdc / Led /',
#  '250e Sedán 8G-DCT',
#  '180d 7G-DCT',
#  '220d 7G-DCT',
#  'AMG Stoelkoeling ACC Multibeam LED Burmester Panor',
#  '250e 8G-DCT',
#  'AMG PANORAMADAK/ WIDESCREEN/ SFEER/ AUTOMAAT/ BOMV',
#  'CDI Edition Navigatie 4U3',
#  nan,
#  '4Matic 7G-DCT',
#  'Classe A 1.9 116ch A 180 d',
#  '180d 7G-DCT',
#  'Ambition | Automaat | Stoelverwarming | Navigaties',
#  'Sport Ambition AMG-Exclusief Pakket',
#  'AMG 123PK | Pano | Sfeer | Grote Navi | Camera | G',
#  'AMG Sport Automaat (APPLE CARPLAY, GROOT NAVI, CLI',
#  'Solution AMG PANORAMADAK, NAVIGATIE, ECC AIRCO,',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  'AMG Line, Automaat, LED',
#  'Ambition',
#  '180d 7G-DCT',
#  '35 AMG 306ch 4Matic 7G-DCT Speedshift AMG',
#  'Business Solution AMG Upgrade | NAVIGATIE | CAMERA',
#  '250e 8G-DCT',
#  'Sport Ambition 211PK/AMG/Nieuwstaat/Alcantara/Lede',
#  'Business Solution AMG PANO/MEMORY/WIDESCREEN/LEER/',
#  'Automaat AMG Sportpakket-Leder-Navigatie-Full Led-',
#  '200d 7G-DCT',
#  'AMG-LINE',
#  'Prestige 122PK | FG02071 | Navi | Climate | Half L',
#  'Classe A 1.5 109ch A 180 CDI BlueEfficiency',
#  'Classe A 1.5 116ch A 180 d',
#  'd Business Solution Plus Upgrade, Automaat, LED, L',
#  'CLASSE  CDI Inspiration',
#  'A Class 180 1.5 115ch A 180 d',
#  'Edition Navigatie 4U3',
#  'AMG Night Panodak',
#  '7G-DCT',
#  'd ACC NAVIGATIE LM VELGEN SPORTSTOELEN LEDER',
#  'BlueEFFICIENCY Ambition',
#  '180d 7G-DCT',
#  'AMG LINE -PANO',
#  'd Lease Edition Ambition AUTOMAAT',
#  'd Style + Pneus Hiver',
#  'A160 My First Star - Navi',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  'Ambition Automaat Bi-Xenon, Airco, Cruise, PDC, AM',
#  'AMG Memory Multibeam LED Panorama Sfeerverlichting',
#  'Ambition Automaat AMG Pack',
#  '200 d 150ch Progressive Line 8G-DCT 8cv',
#  'Sport Automaat (SCHUIFDAK, GROOT NAVIGATIE, PARKEE',
#  'AMG Sport 7G Automaat BiXenon Becker Map Pilot Nav',
#  'AMG PANORAMADAK/WIDESCREEN/SFEER/AUTOMAAT/ BOMVOL',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '200 d Business 7G-DCT',
#  'Classe A 1.5 90ch A 160 CDI / d',
#  'Business Solution AMG, Automaat, LED, Navigatie',
#  'Classe A 1.5 116ch A 180 d',
#  '200  Sport',
#  '200d 7G-DCT',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  'd Business Solution, Automaat, Navigatie',
#  '100 PK Ambition | Cruise | PDC | Airco | NAV | LED',
#  '220d 7G-DCT',
#  'Business Solution Automaat, Navi, Bluetooth/Tel, M',
#  'BlueEfficiency 122PK | PK10244 | Navi | Bi-Xenon |',
#  '220 d Fascination 7G-DCT',
#  'AMG LEDER LED NAVI LMV CRUISE',
#  'AMG Aut. [ LED Navi Camera ]',
#  'Business Solution AMG I AVANTAGE I AUTOMAAT I MBUX',
#  'Classe A 1.3 109ch A 160',
#  'My First Star',
#  'AMG/ PANO/ NIGHT/ CAMERA/ VOL!',
#  '35 AMG 306ch 4Matic 7G-DCT Speedshift AMG 19cv',
#  '200 d Inspiration 7G-DCT Euro6c',
#  'Ambition 120 PK - Automaat | Schuif/kantel-dak | C',
#  'Classe  d (cdi) Premium auto FL E6',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  'd Progressive 7G-DCT',
#  '220 190ch Progressive Line 7G-DCT Siege chauf gran',
#  'CDI Ambition [ Xenon Climate Navi Cruise LM Velgen',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  'd 4Matic AMG Line (EURO 6d)',
#  '220 d 190ch AMG Line 8G-DCT 10cv GPS Camera Radar ',
#  '180 d 116ch Business Line 7G-DCT',
#  '200 d 150ch Business Line 8G-DCT GPS Camera',
#  'Premium Plus | VERWACHT! | BTW Auto | Apple Carpla',
#  '180 d 116ch AMG Line 7G-DCT',
#  '200 d Inspiration 7G-DCT',
#  'Hatch * Carplay | Parkeersenoren | Zetelverw.',
#  '200 163ch Style Line 7G-DCT',
#  '35 AMG 306ch 4Matic 7G-DCT Speedshift AMG TOuvrant',
#  '200 d 150ch AMG Line 8G-DCT 8cv',
#  'd Style + Pneus Hiver',
#  '200 d Fascination Tpano GPS Camera',
#  'CDI 100kW ( 136CV ) Urban',
#  '180 d 116ch AMG Line LED GPS Camera Radar AV/AR',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '180 136ch Progressive Line 7G-DCT 7cv',
#  'd',
#  '180 d Sensation 7G-DCT',
#  'e A 250e Progressive Sfeerverlichting / NIEUW GERE',
#  '200 d 150ch AMG Line 8G-DCT',
#  '220 190ch Progressive Line 7G-DCT',
#  '180 d Sensation 7G-DCT',
#  'e Advantage LED / Navi / Aut / Cam / Half leder /',
#  '180 136ch Business Line 7G-DCT',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  'Business Solution AMG | Navigatie | Dealer Onderho',
#  '7G-DCT Business Solution AMG (Koop nu online!)',
#  '180 AMBITION (All-in prijs)',
#  '220 190ch Progressive Line 7G-DCT Ecran 10 GPS Cam',
#  '180 d Intuition 7G-DCT',
#  '160 109ch Style Line',
#  '200 163ch AMG Line 7G-DCT',
#  '160 Inspiration 7G-DCT',
#  '200 163ch AMG Line 7G-DCT 9cv',
#  '180 d 116ch Progressive Line 7G-DCT',
#  'Coupé 3.0 CDI V6 DPF 7G-TRONIC BlueEFFICIENCY 265',
#  'AMG AUT/ PANO/ LEDER/ CLIMA/ CRUISE',
#  'S 4Matic+ 8G-DCT',
#  'BENZINA + GPL NUOVO + UNICO PROPRIEATARIO',
#  '136 CV "40.335 KM!!!" VETTURA UFFICIALE ITALIANA',
#  'A35 AMG 4MATIC Edition 1 |Pano | kuipstoelen | sfe',
#  'A 45 AMG 4Matic Automatic',
#  'd Progressive',
#  'E 280',
#  'S 4Matic+ 8G-DCT',
#  '4Matic 7G-DCT',
#  '220CDI BE AMG Sport 7G-DCT',
#  'd Premium',
#  '220CDI BE Line 4M 7G-DCT',
#  'S 4Matic+ 8G-DCT',
#  '4Matic 7G-DCT',
#  'Edition 1 4Matic 7G-DCT',
#  '4Matic 7G-DCT',
#  'S 4Matic+ 8G-DCT',
#  'A35 AMG 4-Matic |306PK|FULL OPTIES|',
#  'S 4Matic+ 8G-DCT',
#  '4Matic 7G-DCT',
#  'S 4Matic+ 8G-DCT',
#  '4Matic+ 7G-DCT',
#  '220d 7G-DCT',
#  '4Matic 7G-DCT',
#  '4Matic+ 7G-DCT',
#  '4Matic+ 7G-DCT',
#  'S 4Matic+ 8G-DCT',
#  '220CDI BE AMG Sport 7G-DCT',
#  '180CDI Elegance',
#  '7G-DCT',
#  '4Matic 7G-DCT',
#  '4Matic 7G-DCT',
#  '180CDI BE AMG Line 7G-DCT',
#  '4Matic 7G-DCT',
#  '4MATIC SCHAALSTOELEN/PANO/SPOILER',
#  'S 4Matic+ 8G-DCT',
#  '4Matic 7G-DCT',
#  '4Matic 7G-DCT',
#  '220d 8G-DCT',
#  '4Matic 7G-DCT',
#  '4Matic+ 7G-DCT',
#  'Sedán 4Matic+ 7G-DCT',
#  'MERCEDES-BENZ Clase GLK Pequeño  Automático de 5',
#  '4Matic+ 7G-DCT',
#  'S 4Matic+ 8G-DCT',
#  '200d 8G-DCT',
#  '200d 8G-DCT',
#  '180d 7G-DCT',
#  '200CDI Avantgarde',
#  '4Matic+ 7G-DCT',
#  '4Matic 7G-DCT',
#  '180d 7G-DCT',
#  '200CDI BE Urban',
#  '250e Sedán 8G-DCT',
#  '180d',
#  '180CDI Polar Star',
#  'Pequeño Automático de 5 Puertas',
#  '4Matic+ 7G-DCT',
#  '4Matic+ 7G-DCT',
#  '7G-DCT',
#  'S 4Matic+ 8G-DCT',
#  '4Matic Coupe 4Matic+ (EURO 6d-TEMP)',
#  '200d 7G-DCT',
#  '200d',
#  'Edition 1 4Matic 7G-DCT',
#  nan,
#  '4Matic 7G-DCT',
#  '220CDI BE AMG Line 7G-DCT',
#  '200CDI BE AMG Line 7G-DCT',
#  '7G-DCT (4.75)',
#  '200d',
#  '7G-DCT',
#  'S 4Matic+ 4Matic (EURO 6d)',
#  '4Matic 7G-DCT',
#  nan,
#  '180d 7G-DCT',
#  '200d',
#  '250e Sedán 8G-DCT',
#  '180CDI Autotronic',
#  '200d 8G-DCT',
#  '200d 8G-DCT',
#  'S 4Matic+ 8G-DCT',
#  '7G-DCT',
#  '200d 8G-DCT',
#  'Sport 4Matic 7G-DCT',
#  '180d 8G-DCT',
#  '4Matic+ 7G-DCT',
#  'de 4Matic AMG Line (EURO 6d)',
#  'Edition 1 4Matic 7G-DCT',
#  '220d 8G-DCT',
#  '180d 7G-DCT',
#  'CDI Premium',
#  '4Matic 7G-DCT',
#  '180d 7G-DCT',
#  'd (177.003)',
#  '180d 7G-DCT',
#  '7G-DCT',
#  '200CDI BE Urban 7G-DCT',
#  'BlueEFFICIENCY Urban',
#  'CDI',
#  '200d 8G-DCT',
#  '4Matic 7G-DCT',
#  '7G-DCT (4.75)',
#  '200d 8G-DCT',
#  '200d 8G-DCT',
#  '4Matic 7G-DCT',
#  '200d',
#  '7G-DCT',
#  '200CDI BE Urban 7G-DCT',
#  '200CDI BE Urban',
#  '180CDI BE AMG Line 7G-DCT',
#  '4Matic 7G-DCT',
#  'Edition 1 4Matic 7G-DCT',
#  'd (177.003)',
#  '200d 7G-DCT',
#  'S 4Matic+ 8G-DCT',
#  '4Matic+ 7G-DCT',
#  '180CDI BE AMG Line',
#  '180d',
#  'CDI Style',
#  '220CDI BE AMG Line 7G-DCT',
#  '180d 7G-DCT',
#  'C *** CERAMIC BRAKES / BURMESTER / BELGIAN CAR ***',
#  'AMG | 36.000KM | B&O | MAGIC SKY | AIRSCARF',
#  'Aut. Comand+Xen+Airsc+SHZ+PDC+Leder',
#  'Roadster COMAND/Burmester/Memory/Kamera Autom.',
#  'C Roadster',
#  'Biturbo V-Max',
#  'Cabrio CGI BE Aut.',
#  'GT S Roadster KAMERA+BURMESTER+MEMORY+AIRSCARF',
#  'SL 43 DIGITAL LIGHT+BURMESTER+DISTRO+HUD+MEMORY',
#  'CDI pack AMG  * Capteurs, Gps, Sg chauff, ...',
#  'Roadster*Magno*Night*SportAga*Distr+*RFK*',
#  'Leder Verw/gevent* Radio/CD* Navi* Dual Airco* PDC',
#  'abrio Mercedes-AMG 4MATIC',
#  'MERCEDES-BENZ Clase SL Descapotable  Automático d',
#  'AMG pack - leder - camera - navi command - Nieuw !',
#  'Cabrio 350BlueTec Aut.',
#  nan,
#  'C 43 4MATIC Cabrio ILS+BURMESTER+DISTRO+AIRSCARF',
#  'GT Roadster BURMESTER+SITZKLIMA+DISTRO+MEMORY',
#  nan,
#  'Cabrio 4M Sportabgas LED HUD Kamera 19"',
#  'MercedesAMG',
#  '*EURO6*NAVI*PDC*CUIR*LED*AIRSCARF*SIEGES CHAUFFANT',
#  'Cabrio 220d 9G-Tronic (4.75)',
#  'C 63 S Cabrio DRIVERP+DISTRO+KAMERA+AIRSCARF+LED',
#  'Cabrio Benzine Autom. - airco - Leder',
#  'Cabriolet AMG Line/COMAND/Distronic/360° Styling',
#  '-Klasse Cabrio Cabriolet AMG-Line',
#  'Roadster Automatik Radio/CD 18" ALU',
#  '435cv AMG ***SOLO 37.000KMS *** LIBRO OFICIAL',
#  'Roadster BI-XENON SHZ NAVI PDC VO+HI AUTOMATIK',
#  'AMG - BOITE AUTO ✅ GARANTIE ✅ LED - BLUETOOTH',
#  'BlueEFFICIENCY CGI LEDER NAVI',
#  'Cabrio CGI AMG ILS Airscraft Navi Leder PDC',
#  'SL Pagode',
#  'Cabriolet  4Matic+ ABSOLUTE VOLLAUSTATTUNG',
#  'Cabrio-AMG PAKKET- Nekverwarming - Windscherm',
#  'UNIEKE SL 560 EUROPESE LOOK IN NIEUWSTAAT.AUTOM.',
#  'd Cabriolet',
#  'Cabrio 7G Plus',
#  'Cabriolet AMG Line',
#  'r107 original belgian delivery! first owner car.',
#  'abrio Mercedes-AMG 4MATIC',
#  nan,
#  'Roadster Kompressor Original Brabus Umbau',
#  'd Cabriolet AVANTGARDE',
#  'AMG C 63 S Cabrio Night-P/Drivers P/360°/Comand',
#  'Cabrio 350CDI BE 7G Plus',
#  'E -Klasse Cabrio E 200 +AMG LINE+NAVI+CAM+',
#  'Cabrio CGI Automatik Nackenheizung',
#  'R107 Cabrio Hardtop + Softtop H-Kennzeichen',
#  'Roadster Leder LED Kurvenlicht Panorama Fernlichta',
#  '200K',
#  'Cabrio 220CDI BE 7G Plus',
#  'R107 Cabrio Hardtop + Softtop US Modell H-Kennzeic',
#  'Cabrio CGI BE Avantgarde',
#  'C 63 Cabrio BURMESTER+MULTIB+360°+AIRSCARF+DISTR',
#  'AMG C 43 4M Cabrio Night-Pak/Burm/360°/Abgasanl.',
#  'Cabrio d',
#  'SL Roadster',
#  'Cabrio Navi/7G-Tronic/Aircap/Airscarf/SHZ Autom.',
#  'Deutsches Fahrzeug  Sammlerzustand',
#  'Cabrio d',
#  'Cabrio AMG AHK+MULTIBEAM+360°+AIRSCARF+SHZ',
#  'Roadster Kompressor SCHWARZ AUTOMATIK KLIMA LEDER',
#  'Cabrio 220CDI 7G Plus',
#  nan,
#  'Klima Sitzheizung Navi',
#  'Cabriolet AMG Line 360°/Totw./Comand/LED Styling',
#  'Cabriolet AMG-Line/Navi/LED/Kamera/PDC uvm Autom.',
#  'Cabrio d',
#  'Cabrio AMG Line 9G/Kamera/Navi/LED/Ambient Autom.',
#  'Cabriolet AMGLine/LED/Airscarf/Navi/Kamera Autom.',
#  'Cabriolet AMG Line/9G/LED/KAMERA/Navi/SHZ Styling',
#  'Cabrio AMG Line Leder + Verdeck Rot/360°/ Autom.',
#  'Avantgarde Cabrio AHK+AIRSCARF+KAMERA+DAB',
#  'Cabriolet AMG Line/Kamera/LED/9G/Navi/SHZ Styling',
#  'Cabriolet AMG LED 19" Navi Kamera AMG Line',
#  'Cabrio 9G-Tronic',
#  'CDI Roadster COMAND LEDER',
#  'Roadster + hardtop',
#  'AUTOMATIQUE - GARANTIE 12 MOIS - GPS-XENON-DESIGNO',
#  'Cabriolet AMG Line',
#  '-CLASS 6.2 COUPE SPORT AUTO 457 2P',
#  'Cabriolet CDI Blueefficiency 164PK RG05871',
#  'Classe E AMG 53 4MATIC+',
#  'V12 - Origineel Nederlands -',
#  'CLASSE S CABRIOLET Speedshift MCT  4Matic+',
#  'Roadster 4.0 Facelift - Airscarf - Touchpad',
#  'H/K-L7 MEMORY AIRWAVE CAMERA NAVI LEDER STOELVERW',
#  'SL63 AMG Carbon Editie | 1ste Eig | 1j Garantie',
#  'Classe   9G-Tronic Executive',
#  'Cabriolet 4MATIC',
#  '43 AMG / Air Scarf / Harman Kardon / Comand',
#  'Carbon Editie - 1e eigenaar - Keuring + Garantie',
#  'CILINDRATA 2.000 Sport AUTOMATICA PELLE NAVI FULL',
#  '200 K.',
#  'Performance Package - Carbon',
#  'Roadster*Distronic*Bose*Sitzk.*2.Besitz*Ö-Auto*',
#  'C43 AMG Cabrio Schalensitze Burmester Head UP 360',
#  'V8 | Airscarf | Nappa | Harman-Kardon | Memory',
#  'C SW 200 d  auto',
#  'GE',
#  'cilindrata 2.000 Sport AUTOMATICA PELLE NAVI FULL',
#  'Mercedes- C Roadster',
#  'SL',
#  'Cabriolet AMG Line',
#  'cat Sport*AIR SCARF*SOSPENS ATTIVE*SEDILI RISC*HAR',
#  '(R129)',
#  nan,
#  '(R129) 2nd Owner/Collectable',
#  'Cabrio 1e eigenaar-Dealer onderhouden-Complete his',
#  'SL 600 V12 AUT. ORG. NL.',
#  'Automatik*Massagesitz*Airscarf*AMG-Paket*',
#  '(cgi be) Sport AUTO *90.000 KM*',
#  'auto',
#  'Cabriolet 4Matic',
#  'Kompressor  1PROPRIETARIO ! TAGLIANDI MERCEDESBENZ',
#  '(R171) 350 7GTRO',
#  '4Matic Mild hybrid Cabrio Premium Plus',
#  'Cabrio',
#  'V8 Cabrio Aut.',
#  'C Roadster',
#  'Cabriolet S 4MATIC',
#  'C Roadster',
#  'Cabrio',
#  'SL',
#  'Cabriolet Elegance lpg revisie moterblok',
#  'Cabrio Multibeam Perf.Sitz PAGA Sitzlü.',
#  'Cabrio',
#  'cabrio d  Premium Plus 4matic auto',
#  'CABRIOLET 2.1 CDI 204CV AUTO GARANTIE 6 MOIS',
#  '220 d executive a',
#  '4MATIC+ Cabriolet V-Max 360°*Sitzklima',
#  'Cabrio  eq-boost 4matic + auto my20',
#  'Cabrio 2.0i AMG - Burmester Aut. || FULL OPTION',
#  '| 48.000KM | Orig. NL | BOSE',
#  nan,
#  '200 AMG Sport 7G-Tronic BVA',
#  'Cabrio',
#  'CLK Cabrio 230 k evo Elegance',
#  '250 d Sport auto',
#  'Cabriolet Premium Plus 1e Eigenaar, AMG-pakket, Bu',
#  'E Cabrio 250 cdi be Executive',
#  'cilindrata 2.000 Sport AUTOMATICA PELLE NAVI FULL',
#  'Cabrio 9G-Tronic (9.75)',
#  'Cabriolet 4MATIC PERFORMANCE SEATS 36838KM!',
#  'Cabrio 9G-Tronic (9.75)',
#  'Cabrio 220CDI BE',
#  '220 A Cabriolet',
#  'ROADSTER',
#  'V6 231pk Automaat Prest. Plus NL-auto',
#  'SL 500 V8',
#  'Kompressor',
#  'AMG Line',
#  'S cabrio BURMESTER | LED | 360° | TRACK PACE',
#  '190SL',
#  "AUT NAVI BT AIRWAVE LEDER STOELVERW PDC CRUISE '11",
#  'AUT 245pk! 1eEIG YOUNGTIMER XENON LEDER NAVI CRUIS',
#  'K. Season Edition | Navi | Leder',
#  'auto * Harman/Kardon * Pack mémoires * ILS *PTS',
#  'S Cabriolet Ponton Typ A (W 180)',
#  'Cabrio Multibeam Perf.Sitz PAGA Sitzlü.',
#  'AMG | Airco | Cruise | Stoelverwarming',
#  'Cabrio  eq-boost 4matic + auto my20',
#  'K. Cabrio / Leder / Airco / Stoelverwarming',
#  'CDI BlueEfficiency E -Klasse Cabrio (BM 207)',
#  'Roadster Aut.',
#  'Roadster 4.0 | Performance-uitlaat | Night-Pakket',
#  'E Cabrio 220 d Premium auto',
#  nan,
#  'd Cabriolet',
#  'Leder AD Dyn. Kurvenlicht Klimasitze e-Sitze Nacht',
#  'V8 4Matic Autom. - Designo - Topstaat! 1Ste Eig!',
#  'D',
#  'Coupé R',
#  'COUPE 4-M *AMG-LINE*, NAVI, PANODAK, BT, LED, 360',
#  'Aut.',
#  '350CDI BE (9.75) Aut.',
#  'AMG GLC 43 4MATIC Coupé',
#  nan,
#  nan,
#  'COUPE | 4MATIC | SPORTEXHAUST | PANO |',
#  'Aut.',
#  '-CLASS 4MATIC',
#  'Coupe AMG Line',
#  'Coupé 462',
#  '4MATIC+ Coupé',
#  'Coupé 220d 9G-Tronic',
#  'S 4Matic+ 8G-DCT',
#  'oupé Mercedes-AMG 4MATIC',
#  'Burmester+PerformanceAGA+Pano+++',
#  '220d Urban 7G-DCT 177',
#  'CE Liebhaberstück',
#  'SEb (111)*DEUTSCHES-FAHRZEUG*H-KENNZEICHEN*TOP-ZUS',
#  nan,
#  'C oupe AMG Speedshift 7G-DCT LED RFK PDC',
#  'd 4MATIC',
#  'Coupe AMG Leder Navi Kamera Widescreen PDC',
#  'd 4MATIC Coupé AMG Line',
#  'BiTurbo 4MATIC* HEATED SEATS * CAMERA * FULL LED *',
#  '43 4-Matic+|CAMERA*XENON*PACK NIGHT*LED*BURMESTER*',
#  nan,
#  '4Matic+ 7G-DCT',
#  'd AMG Line /MULTIBEAM LED/ACC/360°CAMERA/...',
#  'Coupé 4Matic (14.75) Aut.',
#  '320CDI Aut.',
#  '4Matic Leder - 4xSitzheizung - Navi - Lenkradheizu',
#  '220CE',
#  'Coupe *Nachtsicht-Assistent*BI-XENON TV',
#  'Coupé 184PK AL88634',
#  'S Coupe',
#  'Mercedes-AMG S 4MATIC+',
#  'Burmaster Keramikbremsen Leder Alcantara Pano Navi',
#  '4Matic (EURO 6d-TEMP)',
#  'Aut.',
#  '-CLASS 3.0 4MATIC AUTO 333 2P',
#  'CGI BlueEfficiencyasse Coupe 1.8 Leder Panorama Ho',
#  '350CDI BE 4M Aut.',
#  'Coupé 4M Aut.',
#  'Coupe AMG-Line Panorama Burmester Night',
#  'Aut.',
#  'Aut.',
#  'Coupe 4Matic AMG Magic Sky Burmester Nacht',
#  'e AMG Line+Pano+',
#  '220CDI AMG Line 7G-DCT',
#  '53 4M+ Night-P/Panor/360°/Burm./Abgasan. Navi',
#  '200K',
#  '250d ECO Aut.',
#  'Coupe AMG LED+Navi+StandHZG+Keyless+e-Sitze+Parkle',
#  'd Coupé EXCLUSIVE',
#  'Aut.',
#  'C Coupe*DEUTSCHES-FAHRZEUG*AUTOMATIK*H-KENNZEICHEN',
#  'Coupé AMG Line 155PK MU20418',
#  'C 43 4MATIC Coupé ILS+PANO+STANDHZ+BURMESTE+360°',
#  '220CDI AMG Line 7G-DCT',
#  'GLC 63 4MATIC Coupé AHK+SH-DACH+360°+DISTRO+MEMO',
#  '43 4-Matic+ (EU6d-TEMP) MAT ORIGINEEL KLEUR',
#  'CLA 35 4MATIC KAMERA+DISTRO+AMBIENTE+KEYLESS+SHZ',
#  'GLC 63 S 4MATIC Coupé SH-DACH+DISTR+360°+DRIVERP',
#  'Coupé S 4Matic Aut.',
#  '200K',
#  'Coupé PROGRESSIVE',
#  'Coupé 9G-Tronic',
#  'Coupé',
#  'Coupe AMG + NIGHTPACK - LEDER - PANO DAK - 360° -',
#  'Coupé 220d 4Matic 9G-Tronic',
#  'AMG Line',
#  'Aut.',
#  'Coupé 350CDI BE Aut.',
#  'GLC-Coupe 400 d 4Matic 9G-TRONIC AMG Line',
#  'Aut.',
#  'CDI Coupé',
#  'SEC',
#  'Aut.',
#  'Coupé CDI',
#  'Coupé AMG Line 185PK FE41259',
#  'Compressor',
#  'Mercedes-AMG CLS 53 4MATIC+ Navi/SHD/Styling/LED',
#  '*** BRABUS 730 / CARBON CERAMIC / FULL OPTION ***',
#  '220d 4Matic 7G-DCT',
#  'Coupé 4M Aut.',
#  '220CDI AMG Line 7G-DCT',
#  '220d Aut.',
#  'Coupé',
#  '*AMG-LINE*LED*MBUX*NAVI*PDC*CAMERA*EURO6*',
#  '4MATIC AMG MULTIBEAM+DISTRO+SHDACH+AHK',
#  '4MATIC Coupé BURMESTER+DISTRO+SITZKLIMA',
#  'Coupé AMG -Garantie 48 mois - 412,47 €/mois*',
#  'ABC Fahrwerk*Xenon*1. Hand*GSD',
#  'Coupé',
#  'd 4MATIC',
#  'Matte wrapping',
#  '270CDI',
#  'S 4M+ Coupé V8 Drivers+Comand+DAB+AHK',
#  'd 4MATIC -',
#  '350CDI BE (9.75) Aut.',
#  '350d 4Matic Aut.',
#  '-Klasse Coupe EU6d-T LED Navi Keyless e-Sitze Park',
#  'Coupé S 4Matic Aut.',
#  'coupé 4.0 4MATIC 469 2P',
#  'SLC, 1 Hand, Scheunenfund, Oldtimer, Bastler',
#  'Coupé 7G-DCT AMG LINE - BURMESTER - SFEERVERLICHTI',
#  'd 4MATIC Coupé AMG MULTIB+BURME+PANO+AHK',
#  '320CDI Avantgarde 7G',
#  '53 4M+ Night-Pak./Panorama/Multibeam/360° Navi',
#  'd 4MATIC Coupé',
#  'AMG C 63 Coupé Burmes./360°/Pano/Abgasanl/Memory',
#  'Coupé d',
#  'C 63 Coupé Night-P/Panorama/Totw./360°/Multibeam',
#  '350d 4Matic Aut.',
#  '43 4M+ Night-P/360°/Panor/Burm./Abgasanl. Navi',
#  'Coupé e 4Matic',
#  'Coupé 4Matic Aut.',
#  nan,
#  'AMG C 63 S Coupé Night/Aero-Paket/360°/Drivers P',
#  'd 4MATIC',
#  'Coupé 250d 4Matic Aut.',
#  'Coupé 400d 4Matic Aut.',
#  'Coupé 400d 4Matic Aut.',
#  'CDI Chrome',
#  'Coupé 4Matic Aut.',
#  '220d 4Matic 7G-DCT',
#  'e Coupé',
#  'Coupé d AMG LINE',
#  'd (205.314)',
#  'd Coupé AMG MULTIBEAM+COMAND+360°+PANO+19"',
#  'Coupé d',
#  'Coupé 220d 4Matic Aut.',
#  'EQ Boost Aut. (9.75)',
#  'Mercedes-AMG C 63 Coupé COMAND/MultibeamLED/360°',
#  'd 4M Coupé AMG Line/Pano/360°/AHK/Totwin Navi',
#  'Coupé 9G-Tronic',
#  'AMG C 63 S Coupé Night-P/Drivers P/360°/Panorama',
#  'AMG C 43 4M Coupé Night-P/Panorama/360°/Abgasanl',
#  'Aut.',
#  'Coupé 220d 4Matic 9G-Tronic',
#  'd 4MATIC AMG MULTIBEAM+BURMESTER+SH-DACH',
#  'Coupé',
#  '200d Urban',
#  '350d 4Matic Aut.',
#  'Coupé 350d 4Matic Aut.',
#  'CDI (LA) Sport Edition (203.708)',
#  'Coupé 220d',
#  'd 4MATIC Coupé AMG AHK+SH-DACH+COMAND',
#  'Coupé 4Matic Aut.',
#  'AMG GLC 63 4M+ Coupé Night-P/SHD/Kamer/AHK/Abgas',
#  'd 4MATIC AMG MULTIB+SH-DACH+HUD+BURMESTE',
#  '220CDI',
#  'K',
#  'Aut.',
#  'd 4M Coupé AMG Panor./AHK/360°/Led beige Navi',
#  'Classe E 300d Coupé AMG Line Mercedes-Benz E Klas',
#  'd Edition*AMG LINE*NAVI*CAMERA*TOIT PANO*EURO6*',
#  '-Klasse Coupe CGI BlueEfficiency AMG Navi Dyn. Kur',
#  '-Klasse Coupe CGI BlueEfficiency AMG Navi Dyn. Kur',
#  'COUPE AMG -Line',
#  'Coupé 220d 4Matic Aut.',
#  'Coupé 220d 9G-Tronic',
#  'Coupe d 4Matic AMG-LINE',
#  'Coupé',
#  'Coupé 4Matic 9G-Tronic',
#  'Coupé 350CDI BE Aut.',
#  'Coupe 4Matic EU6d-T',
#  'Coupé d AMG LINE',
#  'Coupé d 4MATIC',
#  '350d 4Matic Aut.',
#  '4-Matic PANO- A.M.G- LUCHTVERING -MASSAGESTOELEN',
#  'CDI Inspiration 7G-DCT',
#  '4Matic 3.0i 333pk automaat AMG pack/Leder/Led/Navi',
#  '320CDI Aut.',
#  '4Matic 9G-Tronic',
#  'AMGpack + NIGHTPACK - CAMERA 48700€ + btw',
#  '4M Aut.',
#  'd Stronger Than Time Edition diesel 330pk 700Nm',
#  'CDI Voll Voll VOll TV Standheizung',
#  'Aut.',
#  'd 4MATIC*NAVI*T.O PANO*AMG LINE*EURO6*PDC*CAMERA*',
#  'AMG GLE 53 4M+ Night-P/360°/Panorama/AHK/Distron',
#  'd 4-Matic 9G-TRONIC PACK AMG TOE CUIR LED CAME 360',
#  '4MATIC',
#  '300d 4Matic Aut.',
#  '220d 4Matic Aut.',
#  '220d 4Matic Aut.',
#  '220d 4Matic 9G-Tronic',
#  '220d 4Matic 9G-Tronic',
#  'Aut.',
#  '220d 4Matic Aut.',
#  'BlueTec 4Matic CDI DPF Off-Road-Styling-Paket',
#  '220d 4Matic 8G-DCT',
#  '4M Aut.',
#  'Hybride Pack AMG 1°EIG. FULL OPTIES NEW STAAT!',
#  '4m panorama, trekhaak, lichte vracht mogelijk !!',
#  'Aut.',
#  'AMG Line+CAM+Schiebdach+',
#  'd 4MATIC AMG BURMESTER+PANO+AHK+DISTRO',
#  'Real Hybrid/Diesel/FULL AMG Pack/Night Pack/Trekha',
#  'd 4MATIC',
#  '4MATIC',
#  'd 4Matic AMG Line 163PK YW79474',
#  '4MATIC AMG Line',
#  'b*SPORT*NAVI*PDC*AUT AC*LIKE NEW*',
#  'CDI Autom. - AMG - GPS - Leder  -Topstaat! 1Ste...',
#  'Mercedes-AMG GLE 53 4MATIC+ Pano/360°/Night/AHK',
#  '400CDI',
#  '4MATIC',
#  '250BlueTec 4M 7G Plus',
#  '1.6 Essence Euro6b 8.951km réels Garantie 12M',
#  'EQ HEV HYBRID *4 MATIC*GPS*CAMERA*LED*ALU BI COLOR',
#  '300d 4Matic Aut.',
#  'CDI Autom. 4Matic - GPS - Pano - Topstaat!',
#  '300e 4Matic 9G-Tronic',
#  '4Matic 9G-Tronic',
#  '4MATIC',
#  '4Matic 9G-Tronic',
#  '420CDI Aut.',
#  'e 4Matic',
#  '320CDI 4M Aut.',
#  '4Matic 9G-Tronic',
#  '4MATIC AMG AHK STANDHZG DISTRONIC LED AMG Line',
#  '4Matic 9G-Tronic',
#  'de 4-Matic PHEV AMG CAMERA AUTOMAAT',
#  'd 4Matic All-Terrain Estate Avantdarde',
#  'G Klasse 350d Mercedes-Benz G Klasse 350d - Direct',
#  'd 4Matic 9G-Tronic',
#  '4M AMG Line',
#  '220d 4Matic Aut.',
#  'd*EUR 6!*AMG*NAV*DVD*FULL*LIKE NEW*',
#  'd 4MATIC',
#  '220d 4Matic Aut.',
#  'Sportpaket Navi Vollleder',
#  '4Matic 9G-Tronic',
#  '4M Hybride - AMG LINE - Caméra-Garantie 48 mois',
#  'd +DAB +Lane Assist +Sfeerverlichting +Camera +...',
#  'd + Camera + Sfeerverlichting + Zetelverw. + DAB',
#  '4MATIC AMG LINE',
#  'e 4-Matic PHEV - leder - open dak - AMG pack -',
#  '220d 4Matic Aut.',
#  '200CDI BE 7G Plus',
#  'D 4-MATIC, AUTOM, NAVI, APPLE/ANDROID, DRIVER ASS',
#  "7G-DCT AMG + NIGHTPACK - ALU 19' - SFEERVERLICHTIN",
#  'AMG **Designo Magno** AHK Multibeam',
#  'Coupé dA 4-Matic AMG Line Pro LEDER/CUIR LED GP',
#  'd 4 MATIC 245cv 9 vel. *IVA deducible* *2020* *Nac',
#  'd 4MATIC AMG Line',
#  'CDI',
#  '4x4² DESIGNO+STANDHZG+KAMERA+HARMAN+SHDACH',
#  'S Coupe Pano HUD Night 360Kamera Memory 466kW Burm',
#  '4Matic 8G-DCT',
#  'AMG LINE',
#  'GLC 43 4MATIC ILS+PANO+STANDHZ+DISTRO+KAMERA+SHZ',
#  '350e 4Matic',
#  'GLS 400d 4MATIC AMG Line Mercedes-Benz GLS 400d 4M',
#  'd 4MATIC',
#  nan,
#  'GLC 43 4MATIC AHK+PANO+ILS+BURMESTER+DISTRO+MEMO',
#  '4Matic 7-Sitzer AHK Comand ILS Kamera Assist',
#  'd 4MATIC AHK+PANO+BURMESTE+DISTRO+MULTIB',
#  '350BlueTec 4M 7G Plus',
#  'd AMG Line',
#  'd 4Matic (253.915)',
#  'night pack, panorama, burmester, memory seats, ful',
#  '350d 4Matic Aut.',
#  'GLC 43 4MATIC LED+PANO+HUD+DISTRO+KAMERA+AIRBODY',
#  'BlueTEC 4MATIC',
#  'de 4MATIC KAMERA+DISTRO+SITZHZ+KEYLESS',
#  '220d 4Matic Aut.',
#  '| AMG STYLING | OPENDAK | BURMESTER |',
#  '4M AMG Multibeam MBUX-AR',
#  '350d 4Matic Aut.',
#  '4MATIC - Garantie 48 mois - 661,69 €/mois*',
#  'd 4Matic Edition Power Aut. Navi AHK 360Cam',
#  'Pack AMG - Toit ouvrant - Possibilité leasing',
#  'AMG GLC 43 4MATIC',
#  'e 4Matic',
#  '220d 4Matic Aut.',
#  '300 4MATIC',
#  'GLC 63 S 4MATIC EDITION1 DRIVERP+DISTRO+360°+ILS',
#  '220d 4Matic Aut.',
#  '4MATIC',
#  '258PS 4Matic LED HIGH Luxury NAV CAM',
#  'd  AMG ABC Multibeam HighEnd-MBUX  AHK',
#  'D ADVANTAGE + PAQ NIGHT',
#  'LA -Klasse GLA 220 d 4Matic 170 PS',
#  nan,
#  'd 4M AMG Line AHK/Navi/Burmes/Night/Pano Styling',
#  '220d 4Matic Aut.',
#  'GE lang Cabrio Steyr-D-Puch AHK Automatik Rücksitz',
#  '1.6i - NAVI / LED / LEDER / PANO OPENDAK /TREKHAAK',
#  'e Coupe - 4-Matic PHEV',
#  '250d 4Matic Aut.',
#  'Coupé 350D 258 CV',
#  '250d 4Matic Aut.',
#  'GLC 43 4MATIC ILS+AHK+STANDHZ+DISTRO+360°+COMAND',
#  '320CDI Edition 10 Aut.',
#  'GLB 35 4MATIC AHK+MULTIBEAM+KAMERA+DISTRO+SHZ',
#  'Mercedes-AMG 4MATIC',
#  'd 4MATIC - AMG Line - Pano dak',
#  '320CDI Aut.',
#  'D',
#  'Mercedes-AMG 4MATIC',
#  '4Matic Aut.',
#  '4Matic+ Aut.',
#  'd PROGRESSIVE',
#  '300d 4Matic Aut.',
#  '200 d GPS PDC Pano Cruise Ctrl BT S&S',
#  'Mercedes-AMG 4MATIC+',
#  'd 4MATIC',
#  'Urban AHK  Rückfahrkamera Score',
#  '200d 7G-DCT',
#  'd 4Matic (253.915)',
#  '220d 4Matic 7G-DCT',
#  '280CDI Aut.',
#  'Diesel+Euro6+voll foliert+Teil-Leder+Navi+Alu+',
#  '350d 4Matic Aut.',
#  'D 2.2 170CV AUT 5P',
#  'GLC 63 4MATIC ILS+COMAND+DAB+PANO+AHK+EASY-PACK',
#  'd 4MATIC AMG Line 170PK AK19401',
#  'd 4MATIC',
#  'd 4Matic 9G-TRONIC+LED+Advanced Info',
#  '4Matic Aut.',
#  'UNIEK!AMG 63-PAKKET XENON,PANO,AUTOM,LEDER,EURO 6',
#  'AMG-Line LED Navi Leder StHZG Panorama',
#  'e 4MATIC',
#  '4MATIC AMG MULTIB+AHK+PANO+AMBIENTE+PTS',
#  '4Matic 9G-Tronic',
#  'd Pack AMG',
#  'd 9G-Tronic AMG 4 MATIC - LEDER - PANODAK - LED -',
#  '316 DOKA+PRITSCHE+KLIMA 7 SITZER 316 CDI',
#  'AMG G 63 COMAND/SHD/Night/360°/AHK/Standhzg LED',
#  'Urban',
#  '300d 4Matic Aut.',
#  'd 4MATIC Avantgarde AHK+MEMO+KAMERA+MBUX',
#  'd 4Matic',
#  'd',
#  'e Plug-In Hybrid 49g Co2',
#  '* 2016 * Navi * Xenon * Euro6b * Garantie',
#  'E Break dA Exclusive Ext./AVG Int. Business LEDER/',
#  'd break AMG Line',
#  'CDI Break - GPS - Airco - Leder - Goede Staat!',
#  'BREAK |\xa0PANO | DESIGNO | CARBON | CAMERA | LED',
#  'SHB 4-M AMG, NAVI, APPLE/ANDROID, BURMESTER, PANO',
#  'd - WIDESCREEN - KeylessGo - AdaptCruise - Camera',
#  'BREAK | NIGHT | BURMESTER | SPORTUITL. | L.VRACHT',
#  'd Toit Ouvrant , Clim , Navi , Bluethoot , Cruise',
#  'AMG-PACK SFEERVERLICHTING BTW AFTREKBAAR',
#  'T Avantgarde 4-Matic voll voll voll',
#  'CDI 4-Matic',
#  'Autom. 4Matic - GPS - Topstaat!',
#  'b*NAVI*LED*LEDER*PDC*AUTOMAAT*',
#  'T AHK LED Navi Night-P. Ambiente el.Klappe',
#  'Shooting Brake  BE 4Matic Bluetooth',
#  'D - BOITE AUTO - MBUX - LED ✅ GARANTIE 1 AN ✅',
#  'CGI Avantgarde Aut. +COMAND+Bi-Xenon+GSHD',
#  'Avantgarde',
#  'Estate 200CDI BE Edition',
#  'Break dA Business AVG Int. LEDER/CUIR LED GPS PDC',
#  'Shooting Brake 200d',
#  'Shooting Brake 200d 7G-DCT',
#  'S T Navi Sitzh. LED 360 Kamera Memory ACC Leder',
#  'AMG CLA 35 4MATIC Shooting Brake',
#  'Shooting Brake Sport 4MATIC Amg Line 210PK LK10691',
#  'Break Avantgarde * Camera * Navi * Automaat',
#  'Estate S 4Matic+ 9G-Tronic',
#  '-Klasse T-Modell Avantgarde Automatik LED RFK Busi',
#  'S T Pano HUD Camera Adaptive Cruise LED High Perf',
#  'T-Modell BlueTEC d T Avantgarde',
#  'SB AMG line*Led*Navi*',
#  'T d Avantgarde Automatik EU6d-T Navi LED',
#  'D T EXCLUSIVE 4MATIC AUTOMATIK (+EURO6+ALLRAD',
#  'AMG line-Leder+Alcantara-Elekt koffer-Automaat (9)',
#  'Estate 4Matic 7G Plus',
#  'Estate 200d 9G-Tronic',
#  'T d Avantgarde Automatik EU6d Navi LED PDC',
#  'C63 S AMG DESIGNO HUD BURMESTER PANO DRIVERSPACK',
#  'Shooting Brake  Automaat AMG Pack/Led/Navi/BT',
#  'CLASSE B B 180 d BE Edition',
#  'BI TURBO 4MATIC - LEDER/ALCANTARA - LED - NAVI - 1',
#  'e Break AMG Line - NP: € 72.565 !! STOCK !!',
#  'Estate 4Matic 7G Plus',
#  'd AMG Line + Carplay + 360Camera + Pano dak + ...',
#  'SB * RACE * Pano * Camera * Navi * 381pk',
#  'T d Avantgarde Automatik EU6d',
#  '(+)2.0 AVANTGARDE AUTO 211 5P STATE',
#  'T d Widescreen Kamera Totwinkel Navi Sitzh.',
#  'd  Facelift - Automaat/GPS/Camera',
#  'd T AMG AHK+STANDHZG+MULTIBEAM+DISTRO+360°',
#  '4m sb panorama, night pack, keyless-go, sound',
#  'E 63 S 4M T-Modell STANDHZG+PANO+360°+BURMESTER',
#  nan,
#  'CLA 35 4MATIC SB MULTIBEAM+PANO+DISTRO+AMBIENTE',
#  'Garantie bis 2025/Panorama/Burmester',
#  'Estate',
#  '4MATIC',
#  'd Shooting Brake',
#  'd Estate Avantgarde',
#  'd Estate',
#  'de Estate AMG LINE',
#  'AMG-line-LED-Leder-Pan.sunroof- 9GTRONIC AUT',
#  'CDI Blue Efficiency Estate',
#  'C220d AMG 194pk/ch',
#  'e T PLUGIN HYBRID KOMBI AUTOMATIK 7 GANG NAVI BURM',
#  'AMG E 53 4MATIC+ Estate',
#  'b*AMG*NAVI*PDC*LIKE NEW*',
#  'T d Automatik EU6d-T Navi LED Klima PDC',
#  'Mercedes-AMG 4MATIC Estate',
#  'Break*MBUX*AVANTGARD*LED*T.O PANO*CUIR*NAVI*EURO6*',
#  'd T LED+AHK+DISTRO+COMAND+KAMERA+PTS+SHZ',
#  'd T LED+AHK+DISTRO+COMAND+KAMERA+PTS+SHZ',
#  'd T 4MATIC All-Terrain Avantgarde AHK+PANO',
#  'Estate 220d',
#  'AMG Line',
#  'CLA 45 S 4MATIC Shooting Brake LEDER+PANO+360°',
#  'd 4-Matic',
#  'd Estate Business Line',
#  'Estate 220d 9G-Tronic',
#  'd T 4MATIC AMG AHK+PANO+HUD+360°+DISTRONIC',
#  'Estate Business Line',
#  'd T 4MATIC AMG DISTRO+360°+MEMO+WIDESCREEN',
#  'Kompressor*Tempomat*Klimaaut.*RCD*SHZ*MFL*ZV*Airba',
#  'd AMG/rijassist',
#  'Estate Estate',
#  'd Estate',
#  'd T 4MATIC AMG LED+DISTRO+COMAND+AMBIENTE',
#  'Estate 220d 9G-Tronic',
#  'Shooting Brake',
#  '-Klasse T-Modell CDI Avantgarde BlueTEC PANO+LED+L',
#  'T d Automatik Business Plus EU6d-T LED Navi PDC',
#  'Estate 7G Plus',
#  'T AMG LED+360°+STANDHZG+AIRMATIC+AMBIENTE',
#  'PACK AMG PACK SPORT 1ER PROPRIETAIRE',
#  'd + AMG +Burmester + Panodak + Memory + 360 + ...',
#  'Break AUTOMAAT 2022 DAB radio GPS CAMERA',
#  'CDI Urban Style Edition',
#  ...]

# %%
# Since the co_emissions, emission_class, energy_efficiency_class and make_model of the car are related to the emissions_sticker, 
# we can fill the missing values by considering the relationship between the make_model 
# and colour of the car with the upholstery_colour.

# After the groupby operation, how many NaN values do I have remaining?

df.groupby(['make_model','emission_class'], group_keys = False)['emissions_sticker'].transform(lambda x: x.fillna(x.mode()[0] if len(x.mode()) > 0 else np.nan)).isnull().sum()
# Out:
# 4615

# %%
df["emissions_sticker"] = df.groupby(['make_model','emission_class'], group_keys = False)['emissions_sticker'].transform(lambda x: x.fillna(x.mode()[0] if len(x.mode()) > 0 else np.nan))

# %%
handle_missing_values(df, "emissions_sticker")
# Out:
# Missing Values in 'emissions_sticker':
# Count: 4615
# Percentage: 16.14%

# %%
df[df["emissions_sticker"].isnull()]["fuel_type"].value_counts()
# Out:
# Benzine          2259
# Diesel           2097
# Hybrid            136
# Others             72
# Electric           28
# Lpg                21
# Hybrid/Diesel       2
# Name: fuel_type, dtype: int64

# %%
df.fuel_type.value_counts().index
# Out:
# Index(['Benzine', 'Diesel', 'Hybrid', 'Electric', 'Others', 'Lpg',
#        'Hybrid/Diesel'],
#       dtype='object')

# %%
# how many NaN values do I have remaining?
for i in df.fuel_type.value_counts().index:
    count = df[df['fuel_type'] == i].groupby(['first_registration', 'emission_class'], group_keys=False)['emissions_sticker'].transform(lambda x: x.fillna(x.mode()[0] if len(x.mode()) > 0 else np.nan)).isnull().sum()
    print("Category : " , i, " : how many NaN values do I have remaining? :", count)
# Out:
# Category :  Benzine  : how many NaN values do I have remaining? : 66
# Category :  Diesel  : how many NaN values do I have remaining? : 20
# Category :  Hybrid  : how many NaN values do I have remaining? : 8
# Category :  Electric  : how many NaN values do I have remaining? : 8
# Category :  Others  : how many NaN values do I have remaining? : 3
# Category :  Lpg  : how many NaN values do I have remaining? : 12
# Category :  Hybrid/Diesel  : how many NaN values do I have remaining? : 0

# %%
# df[df["emissions_sticker"].isnull()& (df["fuel_type"] == "Benzine")]["emissions_sticker"] = df[df['fuel_type'] == 'Benzine'].groupby(['first_registration', 'emission_class'], group_keys=False)['emissions_sticker'].transform(lambda x: x.fillna(x.mode()[0] if len(x.mode()) > 0 else np.nan))
# df[df["emissions_sticker"].isnull()& (df["fuel_type"] == "Diesel")]["emissions_sticker"] = df[df['fuel_type'] == 'Benzine'].groupby(['first_registration', 'emission_class'], group_keys=False)['emissions_sticker'].transform(lambda x: x.fillna(x.mode()[0] if len(x.mode()) > 0 else np.nan))

# %%
# Let's group the fuel_types by 'first_registration' and 'emission_class' and fill their missing values with the mode values:
for i in df.fuel_type.value_counts().index:
    df.loc[df["emissions_sticker"].isnull() & (df["fuel_type"] == i), "emissions_sticker"] = df[df['fuel_type'] == i].groupby(['first_registration', 'emission_class'], group_keys=False)['emissions_sticker'].transform(lambda x: x.fillna(x.mode()[0] if len(x.mode()) > 0 else np.nan))

# %%
handle_missing_values(df, "emissions_sticker")
# Out:
# Missing Values in 'emissions_sticker':
# Count: 117
# Percentage: 0.41%

# %%
df.groupby(['emission_class'], group_keys = False)['emissions_sticker'].transform(lambda x: x.fillna(x.mode()[0] if len(x.mode()) > 0 else np.nan)).isnull().sum()
# Out:
# 0

# %%
df["emissions_sticker"] = df.groupby(['emission_class'], group_keys = False)['emissions_sticker'].transform(lambda x: x.fillna(x.mode()[0] if len(x.mode()) > 0 else np.nan))

# %%
handle_missing_values(df, "emissions_sticker")
# Out:
# Missing Values in 'emissions_sticker':
# Count: 0
# Percentage: 0.00%

# %%
df.emissions_sticker.value_counts()
# Out:
# green_sticker     27959
# no_sticker          634
# yellow_sticker        7
# red_sticker           2
# Name: emissions_sticker, dtype: int64

# %%
df[df["emissions_sticker"] == "red_sticker"]
# Out:
#            make_model                        short_description    make  \
# 3395     Opel Calibra  2.0i 16V - Rostfrei - 1. Hand - TÜV NEU    Opel
# 17481  Toyota Corolla                              AE86 Cabrio  Toyota
#
#          model                            location    price    body_type  \
# 3395   Calibra  Schüttelsand 14,  49808 Lingen, DE   9999.0        Coupe
# 17481  Corolla                 27446 Selsingen, DE  22500.0  Convertible
#
#        type  doors country_version  ... non_smoker_vehicle emission_class  \
# 3395   Used    2.0         Germany  ...                NaN         Euro 2
# 17481  Used    2.0         Belgium  ...                Yes         Euro 1
#
#        emissions_sticker  upholstery_colour   upholstery previous_owner  \
# 3395         red_sticker            prim_up  fabric_hols            1.0
# 17481        red_sticker            prim_up  fabric_hols            2.0
#
#       energy_efficiency_class co_efficiency location_country location_city
# 3395                      NaN           NaN               DE        Lingen
# 17481                     NaN           NaN               DE     Selsingen
#
# [2 rows x 47 columns]

# %% [markdown]
# <a id="34"></a>
# <div class="alert alert-info" role="alert">
# <h1>Column name :<span style="color:red"> cylinders </span></h1>
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Operation : </b> To fill in the missing values in the "cylinders" column, we can use the "short_description" column . Since the "cylinders" column is associated with <span style="color:red"><b>  " gears" , " make_model ", " drivetrain " , " fuel_type " , " power " and " engine_size "  </b></span> . let's fill in the <span style="color:red"><b> NaN values</b></span> in this column by grouping the data based on these columns and performing the necessary operations.
# </div>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
first_looking("cylinders")
# Out:
# column name    :  cylinders
# --------------------------------
# per_of_nulls   :  % 34.11
# num_of_nulls   :  9756
# num_of_uniques :  12
# 4.0     13065
# NaN      9756
# 3.0      3256
# 6.0      1012
# 5.0       799
# 8.0       539
# 2.0       103
# 0.0        35
# 1.0        21
# 12.0        8
# 7.0         6
# 26.0        1
# 16.0        1
# Name: cylinders, dtype: int64

# %%
df.cylinders.fillna(df.groupby(['make_model', 'engine_size', 'fuel_type','power'])['cylinders'].transform(lambda x: round(x.mean(), 0))).isnull().sum()
# Out:
# 3054

# %%
df.cylinders = df.cylinders.fillna(df.groupby(['make_model', 'engine_size', 'fuel_type','power'])['cylinders'].transform(lambda x: round(x.mean(), 0)))

# %%
handle_missing_values(df, "cylinders")
# Out:
# Missing Values in 'cylinders':
# Count: 3054
# Percentage: 10.68%

# %%
df.cylinders.fillna(df.groupby(['gears', 'engine_size','power'])['cylinders'].transform(lambda x: round(x.mean(), 0))).isnull().sum()
# Out:
# 1531

# %%
df.cylinders = df.cylinders.fillna(df.groupby(['gears', 'engine_size','power'])['cylinders'].transform(lambda x: round(x.mean(), 0)))

# %%
handle_missing_values(df, "cylinders")
# Out:
# Missing Values in 'cylinders':
# Count: 1531
# Percentage: 5.35%

# %%
df.cylinders.fillna(df.groupby(['body_type' , 'power'])['cylinders'].transform(lambda x: round(x.mean(), 0))).isnull().sum()
# Out:
# 452

# %%
df.cylinders = df.cylinders.fillna(df.groupby(['body_type' , 'power'])['cylinders'].transform(lambda x: round(x.mean(), 0)))

# %%
handle_missing_values(df, "cylinders")
# Out:
# Missing Values in 'cylinders':
# Count: 452
# Percentage: 1.58%

# %%
df.cylinders.fillna(df.groupby(['make_model' , 'engine_size'])['cylinders'].transform(lambda x: round(x.mean(), 0))).isnull().sum()
# Out:
# 72

# %%
df.cylinders = df.cylinders.fillna(df.groupby(['make_model' , 'engine_size'])['cylinders'].transform(lambda x: round(x.mean(), 0)))

# %%
handle_missing_values(df, "cylinders")
# Out:
# Missing Values in 'cylinders':
# Count: 72
# Percentage: 0.25%

# %%
df.cylinders.fillna(df.groupby(["drivetrain", "gears", "gearbox"])['cylinders'].transform(lambda x: round(x.mean(), 0))).isnull().sum()
# Out:
# 0

# %%
df.cylinders = df.cylinders.fillna(df.groupby(["drivetrain", "gears", "gearbox"])['cylinders'].transform(lambda x: round(x.mean(), 0)))

# %%
handle_missing_values(df, "cylinders")
# Out:
# Missing Values in 'cylinders':
# Count: 0
# Percentage: 0.00%

# %% [markdown]
# <a id="52"></a>
#
# <div class="alert alert-info" role="alert">
# <h1><span style="color:red"> Drop </span></h1>
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Operation:</b> Let's drop the remaining columns as they will not be used in Part 3 and have not been filled: <span style="color:red"><b>" co_efficiency ", " energy_effienciency_class ", " model_code ", " non_smoker_vehicle ", " general_inspection ", " co_emissions ", " offer_number ", " desc ", " short_description "</b></span>
# </div>
#
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
missing_values(df)
# Out:
#                          Missing_Number  Missing_Percent
# co_efficiency                     20798        72.715195
# energy_efficiency_class           20798        72.715195
# model_code                        20236        70.750297
# non_smoker_vehicle                17008        59.464373
# general_inspection                16353        57.174323
# co_emissions                      10015        35.015034
# offer_number                       5528        19.327320
# desc                                672         2.349486
# short_description                   213         0.744703

# %%
df.drop(["co_efficiency", "energy_efficiency_class", "model_code", "non_smoker_vehicle", "general_inspection", "co_emissions", "offer_number", "desc", "short_description"], axis=1, inplace = True)

# %%
# Let's exclude the "location_city" column for now in case we may need it in future steps.
missing_values(df)
# Out:
# Empty DataFrame
# Columns: [Missing_Number, Missing_Percent]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28602 entries, 0 to 29478
# Data columns (total 38 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   make_model             28602 non-null  object
#  1   make                   28602 non-null  object
#  2   model                  28602 non-null  object
#  3   location               28602 non-null  object
#  4   price                  28602 non-null  float64
#  5   body_type              28602 non-null  object
#  6   type                   28602 non-null  object
#  7   doors                  28602 non-null  float64
#  8   country_version        28602 non-null  object
#  9   warranty               28602 non-null  object
#  10  mileage                28602 non-null  float64
#  11  first_registration     28602 non-null  float64
#  12  gearbox                28602 non-null  object
#  13  fuel_type              28602 non-null  object
#  14  colour                 28602 non-null  object
#  15  paint                  28602 non-null  object
#  16  seller                 28602 non-null  object
#  17  seats                  28602 non-null  float64
#  18  power                  28602 non-null  float64
#  19  engine_size            28602 non-null  float64
#  20  gears                  28602 non-null  float64
#  21  manufacturer_colour    28602 non-null  object
#  22  drivetrain             28602 non-null  object
#  23  cylinders              28602 non-null  float64
#  24  fuel_consumption       28602 non-null  float64
#  25  comfort_&_convenience  28602 non-null  object
#  26  entertainment_&_media  28602 non-null  object
#  27  safety_&_security      28602 non-null  object
#  28  extras                 28602 non-null  object
#  29  empty_weight           28602 non-null  float64
#  30  full_service_history   28602 non-null  object
#  31  emission_class         28602 non-null  object
#  32  emissions_sticker      28602 non-null  object
#  33  upholstery_colour      28602 non-null  object
#  34  upholstery             28602 non-null  object
#  35  previous_owner         28602 non-null  float64
#  36  location_country       28602 non-null  object
#  37  location_city          28602 non-null  object
# dtypes: float64(12), object(26)
# memory usage: 9.5+ MB

# %% [markdown]
# ![image-2.png](https://cdn.pixabay.com/photo/2013/11/20/18/51/autos-214033_1280.jpg)
# [Image Credit: ](https://pixabay.com/tr/photos/arabalar-teknoloji-vw-otopark-214033/)

# %% [markdown]
# <a id="48"></a>
# # <p style="background-color:#FF6961; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ End of Part - 2 ✨</p>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %% [markdown]
# <a id="51"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Let's save the final state of the DataFrame as a CSV file. ✨</p>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
df.to_csv("capstone_part_2_final.csv", index = False)

# %% [markdown]
# <h3 style="text-align:center;font-size:200%;">Progress Bars</h3>
# <div class="progress">
#   <div class="progress-bar bg-danger" role="progressbar" style="width: 66%;" aria-valuenow="66" aria-valuemin="66" aria-valuemax="100">66%</div>
# </div>

# %% [markdown]
# <h6><span class="label label-danger">Attention</span>This study consists of three parts. You can access the entire study through the following links. Good luck with your work. </h6>

# %% [markdown]
# <ul class="nav flex-column">
#   <h3 class="list-group-item list-group-item-action active" data-toggle="list" role="tab" aria-controls="home" style="background-color:#FF6961; color:white"><b>AutoScout Exploratory Data Analysis (EDA) Project</b></h3>
#   <li class="nav-item">
#     <a class="nav-link active" style="background-color:; color:Blue" href="https://github.com/huseyincenik/data_science/tree/main/Projects/Capstone%20Project" role="tab"><b>Part - 1 - Data Cleaning</b></a>
#   </li>
#   <li class="nav-item">
#     <a class="nav-link" style="background-color:; color:black" href="https://github.com/huseyincenik/data_science/tree/main/Projects/Capstone%20Project"><b>Part - 2 - Handling With Missing Values</b></a>
#   </li>
#   <li class="nav-item">
#     <a class="nav-link" style="background-color:; color:red" href="https://github.com/huseyincenik/data_science/tree/main/Projects/Capstone%20Project"><b>Part - 3 - Handling With Outliers</b></a>
#   </li>
#     <li class="nav-item">
#     <a class="nav-link" style="background-color:; color:blue" href="https://github.com/huseyincenik/data_science/tree/main/Projects/Capstone%20Project"><b>Analysis of the Dataset</b></a>
#   </li>
#   <li class="nav-item">
#     <a class="nav-link" style="background-color:; color:green" href="https://www.linkedin.com/in/huseyincenik/"><b>Linkedin Account</b></a>
#   </li>
# </ul>
