# %% [markdown]
# # <p style="background-color:#FF6961; font-family:newtimeroman;color:#FFF9ED;font-size:220%; text-align:center; border-radius: 15px 55px;">📈 Time Series Decomposition Example - 1 📉</p>

# %% [markdown]
# <img src="https://i.ibb.co/p3cqmmp/Analysis-Brainstorm-Presentation.png" alt="Melbourne" width="1000" height="1000">

# %% [markdown]
# <a id="part_1_decomposition"></a>
# <div style="border-radius: 10px; border: 1px solid black; background-color:#87CEFA ; font-size: 100%; text-align: left; box-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5); padding: 10px; margin-bottom: 20px;">
#     <h2 style="border: 0; border-radius: 15px; font-weight: bold; font-size: 220%; color: #FF5733; background-color: white; padding: 10px; text-align: center; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">⚡️ Additive and Multiplicative Decomposition in Time Series Analysis ⚡️</h2>
#     <p>
#         Time series analysis involves examining data that changes over time. To understand and model time series data, we often decompose it into its components. The main components are typically trend, seasonality, and randomness. Decomposition methods are used to analyze these components, and they come in two main types: <strong>additive</strong> and <strong>multiplicative</strong> decomposition.
#     </p>
#     <h3 style="border: 0; border-radius: 15px; font-weight: bold; font-size: 180%; color: #FF5733; background-color: white; padding: 10px; text-align: center; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">Additive Decomposition</h3>
#     <p>
#         Additive decomposition breaks the time series into the following components:
#     </p>
#     <pre><code>Y_t = T_t + S_t + E_t</code></pre>
#     <ul>
#         <li><strong>Y_t</strong>: Observed value (time series)</li>
#         <li><strong>T_t</strong>: Trend component</li>
#         <li><strong>S_t</strong>: Seasonal component</li>
#         <li><strong>E_t</strong>: Random component (error)</li>
#     </ul>
#     <p>
#         Additive decomposition assumes that the seasonal component is added to the other components of the time series. This method implies that each component is independent and combined through addition.
#     </p>
#     <h4 style="border: 0; border-radius: 15px; font-weight: bold; font-size: 160%; color: #FF5733; background-color: white; padding: 10px; text-align: center; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">Use Cases</h4>
#     <ul>
#         <li>Suitable when seasonal effects are pronounced in the data.</li>
#         <li>Useful when seasonal effects do not change over time or have a constant cycle.</li>
#     </ul>
#     <h3 style="border: 0; border-radius: 15px; font-weight: bold; font-size: 180%; color: #FF5733; background-color: white; padding: 10px; text-align: center; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">Multiplicative Decomposition</h3>
#     <p>
#         Multiplicative decomposition breaks the time series into the following components:
#     </p>
#     <pre><code>Y_t = T_t × S_t × E_t</code></pre>
#     <ul>
#         <li><strong>Y_t</strong>: Observed value (time series)</li>
#         <li><strong>T_t</strong>: Trend component</li>
#         <li><strong>S_t</strong>: Seasonal component</li>
#         <li><strong>E_t</strong>: Random component (error)</li>
#     </ul>
#     <p>
#         Multiplicative decomposition assumes that the seasonal component is multiplied with the other components of the time series. This method implies that seasonal effects vary with the magnitude of the time series and are combined through multiplication.
#     </p>
#     <h4 style="border: 0; border-radius: 15px; font-weight: bold; font-size: 160%; color: #FF5733; background-color: white; padding: 10px; text-align: center; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">Use Cases</h4>
#     <ul>
#         <li>Suitable when seasonal effects vary with the size of the data.</li>
#         <li>Useful when seasonal effects are related to the magnitude of the data and change over time.</li>
#     </ul>
#     <h3 style="border: 0; border-radius: 15px; font-weight: bold; font-size: 180%; color: #FF5733; background-color: white; padding: 10px; text-align: center; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">Comparison and Selection</h3>
#     <ul>
#         <li><strong>Additive Decomposition</strong>: Generally suitable for data with fixed and distinct seasonal effects.</li>
#         <li><strong>Multiplicative Decomposition</strong>: Suitable for data where seasonal effects change over time or are related to the size of the data.</li>
#     </ul>
#     <p>
#         Using both methods to analyze time series data can help determine the most appropriate model based on the nature of the data.
#     </p>
# </div>

# %% [markdown]
# <h3 style="text-align:center;font-size:200%;">Progress Bars</h3>
# <div class="progress">
#   <div class="progress-bar bg-danger" role="progressbar" style="width: 0%;" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100">0%</div>
# </div>

# %% [markdown]
# <ul class="nav flex-column">
#   <h3 class="list-group-item list-group-item-action active" data-toggle="list" role="tab" aria-controls="home" style="background-color:#FF6961; color:white"><b> Time Series Decomposition Example - 1
#  </b></h3>
#   <li class="nav-item">
#     <a class="nav-link" style="background-color:; color:red" href="https://github.com/huseyincenik/data_science/tree/main/time_series_analysis/time_series_decomposition_example_1"><b>Github Notebook Link</b></a>
#   </li>
#     <li class="nav-item">
#     <a class="nav-link" style="background-color:; color:blue" href="https://www.kaggle.com/code/huseyincenik/time-series-decomposition-example-1"><b>Kaggle Notebook Link</b></a>
#   </li>
#   <li class="nav-item">
#     <a class="nav-link" style="background-color:; color:green" href="https://www.linkedin.com/in/huseyincenik/"><b>My Linkedin Account</b></a>
#   </li>
# </ul>

# %% [markdown]
# <a id="toc"></a>
# <div style="border-radius: 10px;
#             border: black solid;
#             background-color: lightblue;
#             font-size: 100%;
#             text-align: left;
#             box-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
# <h2 style="border: 0; border-radius: 15px; font-weight: bold; font-size: 220%; color: white; background-color: red;"><center> ✍✍ Content ✍✍</center></h2>
# <div style="display: flex;">
#     <hr style="border: none;
#                height: 2px;
#                width: 100%;
#                background-color: linear-gradient(to right, blue, white);
#                box-shadow: 0px 2px 4px rgba(0, 0, 0, 0.5);
#                margin-left: 0;">
# </div>
# <div>
#   <ul style="background-color: white;">
#     <li><a href="#part_1">PART - 1 READING & UNDERSTANDING DATA</a></li>
#     <ul>
#         <li><a href="#bolum_1_1">Importing Libraries Needed in This Notebook</a></li>
#         <li><a href="#bolum_1_2">Importing Data</a></li>
#     </ul>
#     <li><a href="#part_2">PART - 2 TIME SERIES</a></li>
#     <ul>
#         <li><a href="#part_2_1">Date Structure Transformation</a></li>
#         <li><a href="#part_2_2">Additive Decomposition</a></li>
#         <li><a href="#part_2_3">Multiplicative Decomposition</a></li>
#         <li><a href="#part_2_4">Both Decomposition</a></li>
#         <li><a href="#part_2_5">Decomposition with Logarithm</a></li>
#     </ul>
#     </ul>
# </div>
# <div style="display: flex;">
#     <hr style="border: none;
#                height: 2px;
#                width: 100%;
#                background-color: linear-gradient(to right, blue, white);
#                box-shadow: 0px 2px 4px rgba(0, 0, 0, 0.5);
#                margin-left: 0;">
# </div>
# <div>
#   <ul style="background-color: white;">
#     <li><a href="#summary">SUMMARY</a></li>
#     <li><a href="#the_end">THE END </a></li>
#   </ul>
# </div>
# </div>

# %% [markdown]
# <a id="part_1"></a>
# # <p style="background-color:#FF6961; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ PART - 1 Reading & Understanding Data ✨</p>

# %% [markdown]
# <a id="part_1_dataset"></a>
# <div style="border-radius: 10px; border: 1px solid black; background-color:#87CEFA ; font-size: 100%; text-align: left; box-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5); padding: 10px; margin-bottom: 20px;">
#     <h2 style="border: 0; border-radius: 15px; font-weight: bold; font-size: 220%; color: #FF5733; background-color: white; padding: 10px; text-align: center; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">⚡️ Electric Production Dataset ⚡️</h2>
#     <p>
#         <strong style="color: white;">Dataset Source:</strong>
#         The Electric Production dataset is available on Kaggle. You can access it using the following link:
#     </p>
#     <ul>
#         <li><a href="https://www.kaggle.com/datasets/shenba/time-series-datasets" style="color: white; text-decoration: underline;">Electric Production Dataset on Kaggle</a></li>
#     </ul>
#     <p>
#         <strong style="color: white;">Columns:</strong>
#         The dataset includes the following columns:
#     </p>
#     <ul>
#         <li><strong>DATE</strong>: Date of the data entry</li>
#         <li><strong>IPG2211A2N</strong>: ‘Energy_Production’ - Energy production values</li>
#     </ul>
# </div>

# %% [markdown]
# <a href="#part_1" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 1</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %% [markdown]
# <a id="part_1_1"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Importing Libraries Needed in This Notebook ✨</p>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose as sm

# %%
# version control
import statsmodels
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

print("Statsmodels Version: ", statsmodels.__version__)
print("Pandas Version: ", pd.__version__)
print("Matplotlib Version: ", plt.matplotlib.__version__)
print("Numpy Version: ", np.__version__)
# Out:
# Statsmodels Version:  0.14.0
# Pandas Version:  2.2.2
# Matplotlib Version:  3.8.0
# Numpy Version:  1.26.4

# %% [markdown]
# <a id="part_1_2"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Importing Data ✨</p>

# %% [markdown]
# <a href="#part_1" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 1</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
df = pd.read_csv("Electric_Production.csv")
df
# Out:
#           DATE  IPG2211A2N
# 0     1/1/1985     72.5052
# 1     2/1/1985     70.6720
# 2     3/1/1985     62.4502
# 3     4/1/1985     57.4714
# 4     5/1/1985     55.3151
# ..         ...         ...
# 392   9/1/2017     98.6154
# 393  10/1/2017     93.6137
# 394  11/1/2017     97.3359
# 395  12/1/2017    114.7212
# 396   1/1/2018    129.4048
#
# [397 rows x 2 columns]

# %%
dates = pd.date_range("1985", periods=len(df["DATE"]), freq="MS")
dates
# Out:
# DatetimeIndex(['1985-01-01', '1985-02-01', '1985-03-01', '1985-04-01',
#                '1985-05-01', '1985-06-01', '1985-07-01', '1985-08-01',
#                '1985-09-01', '1985-10-01',
#                ...
#                '2017-04-01', '2017-05-01', '2017-06-01', '2017-07-01',
#                '2017-08-01', '2017-09-01', '2017-10-01', '2017-11-01',
#                '2017-12-01', '2018-01-01'],
#               dtype='datetime64[ns]', length=397, freq='MS')

# %%
df["DATE"]=dates

# %%
print(df.dtypes)
# Out:
# DATE          datetime64[ns]
# IPG2211A2N           float64
# dtype: object

# %% [markdown]
# <a id="part_2"></a>
# # <p style="background-color:#FF6961; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ PART - 2 Time Series ✨</p>

# %% [markdown]
# <a id="part_2_1"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Date Structure Transformation ✨</p>

# %% [markdown]
# <a href="#part_2" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 2</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %% [markdown]
# <div style="background-color:#3498DB; padding:10px; border-radius: 10px; box-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
#     <p style="font-weight: bold; color: white;">In time series analysis, the date structure is transformed into an index structure.</p>
# </div>

# %%
df.set_index("DATE", inplace = True)

# %%
df
# Out:
#             IPG2211A2N
# DATE
# 1985-01-01     72.5052
# 1985-02-01     70.6720
# 1985-03-01     62.4502
# 1985-04-01     57.4714
# 1985-05-01     55.3151
# ...                ...
# 2017-09-01     98.6154
# 2017-10-01     93.6137
# 2017-11-01     97.3359
# 2017-12-01    114.7212
# 2018-01-01    129.4048
#
# [397 rows x 1 columns]

# %%
df.plot();
# plt.xticks(veri.index, veri.index.astype("str"), rotation = 90)
# plt.show()

# %% [markdown]
# <a id="part_2_2"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Additive Decomposition ✨</p>

# %% [markdown]
# <a href="#part_2" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 2</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
decomposition = sm(df["IPG2211A2N"], model = "add", period = 12)
decomposition.plot()
plt.show()

# %% [markdown]
# <div style="background-color:#3498DB; padding:10px; border-radius: 10px; box-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
#     <p style="font-weight: bold; color: white;"># Trend -- Central Moving Average</p>
#     <p style="color: white;">The central moving average helps to identify the overall trend in the time series data by smoothing out short-term fluctuations.</p>
#     <p style="font-weight: bold; color: white;"># Residual -- Irregular Movements</p>
#     <p style="color: white;">Residuals represent the irregular or random variations in the time series data that cannot be explained by the trend component.</p>
# </div>

# %% [markdown]
# <a id="part_2_3"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Multiplicative Decomposition ✨</p>

# %% [markdown]
# <a href="#part_2" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 2</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
decomposition_2 = sm(df["IPG2211A2N"], model = "mul", period = 12)
decomposition_2.plot()
plt.show()

# %%
trend = decomposition_2.trend
seasonal = decomposition_2.seasonal
resid = decomposition_2.resid

# %%
trend.plot();

# %% [markdown]
# <a id="part_2_4"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Both Decomposition ✨</p>

# %% [markdown]
# <a href="#part_2" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 2</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
decomposition_1 = sm(df["IPG2211A2N"], model = "add", period = 12)
decomposition_2 = sm(df["IPG2211A2N"], model = "mul", period = 12)

# %%
decomposition_1.plot()
plt.title("Additive Decomposition")
decomposition_1.plot()
plt.title("Multiplicative Decomposition")
plt.show()

# %%
import matplotlib.pyplot as plt

# Create figure with specified size
plt.figure(figsize=(12, 12))  # Width and height can be adjusted

# First subplot (top)
plt.subplot(3, 2, 1)  # 3 rows, 2 columns, 1st subplot
plt.plot(decomposition_1.trend, label='Trend')
plt.title('Additive Model - Trend')
plt.legend()

plt.subplot(3, 2, 3)  # 3 rows, 2 columns, 3rd subplot
plt.plot(decomposition_1.seasonal, label='Seasonal')
plt.title('Additive Model - Seasonal')
plt.legend()

plt.subplot(3, 2, 5)  # 3 rows, 2 columns, 5th subplot
plt.plot(decomposition_1.resid, label='Residual')
plt.title('Additive Model - Residual')
plt.legend()

# Second subplot (bottom)
plt.subplot(3, 2, 2)  # 3 rows, 2 columns, 2nd subplot
plt.plot(decomposition_2.trend, label='Trend')
plt.title('Multiplicative Model - Trend')
plt.legend()

plt.subplot(3, 2, 4)  # 3 rows, 2 columns, 4th subplot
plt.plot(decomposition_2.seasonal, label='Seasonal')
plt.title('Multiplicative Model - Seasonal')
plt.legend()

plt.subplot(3, 2, 6)  # 3 rows, 2 columns, 6th subplot
plt.plot(decomposition_2.resid, label='Residual')
plt.title('Multiplicative Model - Residual')
plt.legend()

# Display the plots
plt.tight_layout()  # Automatically adjusts layout for better spacing
plt.show()

# %% [markdown]
# <a href="#info" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Info</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %% [markdown]
# <div style="background-color:#3498DB; padding:10px; border-radius: 10px; box-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
#     <p style="font-weight: bold; color: white;">Looking at the residuals, it can be observed that the standard deviation of the additive model is higher than that of the multiplicative model. Consequently, if the additive model is used, its forecasting power will be somewhat lower compared to the multiplicative model.</p>
# </div>

# %%
# Calculate the standard deviation of the residuals for the Additive Model
std_residuals_additive = np.std(decomposition_1.resid)

# Print the result with a descriptive message
print(f"Standard Deviation of Residuals for the Additive Model: {std_residuals_additive:.4f}")
# Out:
# Standard Deviation of Residuals for the Additive Model: 2.5907

# %%
# Calculate the standard deviation of the residuals for the Multiplicative Model
std_residuals_multiplicative = np.std(decomposition_2.resid)

# Print the result with a descriptive message
print(f"Standard Deviation of Residuals for the Multiplicative Model: {std_residuals_multiplicative:.4f}")
# Out:
# Standard Deviation of Residuals for the Multiplicative Model: 0.0238

# %% [markdown]
# <a id="part_2_5"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Decomposition with Logarithm ✨</p>

# %% [markdown]
# <a href="#part_2" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 2</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %%
decomposition_3 = sm(np.log(df["IPG2211A2N"]), model = "add", period = 12)
decomposition_4 = sm(np.log(df["IPG2211A2N"]), model = "mul", period = 12)

# %%
# Create figure with specified size
plt.figure(figsize=(15, 15))  # Adjusted for additional plots

# First subplot (top-left)
plt.subplot(4, 4, 1)  # 4 rows, 4 columns, 1st subplot
plt.plot(decomposition_1.trend, label='Trend')
plt.title('Additive Model - Trend')
plt.legend()

# Second subplot (top-right)
plt.subplot(4, 4, 2)  # 4 rows, 4 columns, 2nd subplot
plt.plot(decomposition_2.trend, label='Trend')
plt.title('Multiplicative Model - Trend')
plt.legend()

# Third subplot (top-left)
plt.subplot(4, 4, 3)  # 4 rows, 4 columns, 3rd subplot
plt.plot(decomposition_3.trend, label='Trend')
plt.title('Log Additive Model - Trend')
plt.legend()

# Fourth subplot (top-right)
plt.subplot(4, 4, 4)  # 4 rows, 4 columns, 4th subplot
plt.plot(decomposition_4.trend, label='Trend')
plt.title('Log Multiplicative Model - Trend')
plt.legend()

# Fifth subplot (middle-left)
plt.subplot(4, 4, 5)  # 4 rows, 4 columns, 5th subplot
plt.plot(decomposition_1.seasonal, label='Seasonal')
plt.title('Additive Model - Seasonal')
plt.legend()

# Sixth subplot (middle-right)
plt.subplot(4, 4, 6)  # 4 rows, 4 columns, 6th subplot
plt.plot(decomposition_2.seasonal, label='Seasonal')
plt.title('Multiplicative Model - Seasonal')
plt.legend()

# Seventh subplot (middle-left)
plt.subplot(4, 4, 7)  # 4 rows, 4 columns, 7th subplot
plt.plot(decomposition_3.seasonal, label='Seasonal')
plt.title('Log Additive Model - Seasonal')
plt.legend()

# Eighth subplot (middle-right)
plt.subplot(4, 4, 8)  # 4 rows, 4 columns, 8th subplot
plt.plot(decomposition_4.seasonal, label='Seasonal')
plt.title('Log Multiplicative Model - Seasonal')
plt.legend()

# Ninth subplot (bottom-left)
plt.subplot(4, 4, 9)  # 4 rows, 4 columns, 9th subplot
plt.plot(decomposition_1.resid, label='Residual')
plt.title('Additive Model - Residual')
plt.legend()

# Tenth subplot (bottom-right)
plt.subplot(4, 4, 10)  # 4 rows, 4 columns, 10th subplot
plt.plot(decomposition_2.resid, label='Residual')
plt.title('Multiplicative Model - Residual')
plt.legend()

# Eleventh subplot (bottom-left)
plt.subplot(4, 4, 11)  # 4 rows, 4 columns, 11th subplot
plt.plot(decomposition_3.resid, label='Residual')
plt.title('Log Additive Model - Residual')
plt.legend()

# Twelfth subplot (bottom-right)
plt.subplot(4, 4, 12)  # 4 rows, 4 columns, 12th subplot
plt.plot(decomposition_4.resid, label='Residual')
plt.title('Log Multiplicative Model - Residual')
plt.legend()

# Display the plots
plt.tight_layout()  # Automatically adjusts layout for better spacing
plt.show()

# %% [markdown]
# <a href="#info" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Info</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %% [markdown]
# <div style="background-color:#3498DB; padding:10px; border-radius: 10px; box-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
#     <p style="font-weight: bold; color: white;">Logarithmic transformation often yields better predictive models. The standard deviation of the log multiplicative model is lower, providing better results in forecasting.</p>
# </div>

# %%
std_residuals_log_additive = np.std(decomposition_3.resid)

print(f"Standard Deviation of Residuals for the Log Additive Model: {std_residuals_log_additive:.4f}")
# Out:
# Standard Deviation of Residuals for the Log Additive Model: 0.0238

# %%
std_residuals_log_multiplicative = np.std(decomposition_4.resid)

print(f"Standard Deviation of Residuals for the Log Multiplicative Model: {std_residuals_log_multiplicative:.4f}")
# Out:
# Standard Deviation of Residuals for the Log Multiplicative Model: 0.0052

# %% [markdown]
# <a id="summary"></a>
# # <p style="background-color:#3498DB; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ Summary ✨</p>

# %% [markdown]
# <a href="#part_2" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 2</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %% [markdown]
# <div style="background-color:#3498DB; padding:10px; border-radius: 10px; box-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
#     <p style="font-weight: bold; color: white;">This document contains two sections on fundamental Python concepts:</p>
# </div>
#
# #### [Part 1: Reading & Understanding Data](#part_1)
# This section covers the basics of importing libraries and data. Key topics include:
# - Importing Libraries Needed in This Notebook
# - Importing Data
#
# #### [Part 2: Time Series](#part_2)
# This section delves into time series analysis with a focus on decomposition methods. Key topics include:
# - Date Structure Transformation
# - Additive Decomposition
# - Multiplicative Decomposition
# - Both Decomposition
# - Decomposition with Logarithm
#
# <div style="background-color:#3498DB; padding:10px; border-radius: 10px; box-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);">
#     <p style="font-weight: bold; color: white;">Logarithmic transformation often yields better predictive models. The standard deviation of the log multiplicative model is lower, providing better results in forecasting.</p>
# </div>

# %% [markdown]
# <h3 style="text-align:center;font-size:200%;">Progress Bars</h3>
# <div class="progress">
#   <div class="progress-bar bg-danger" role="progressbar" style="width: 100%;" aria-valuenow="100" aria-valuemin="100" aria-valuemax="100">100%</div>
# </div>

# %% [markdown]
# <a id="the_end"></a>
# # <p style="background-color:#FF6961; font-family:newtimeroman;color:#FFF9ED; font-size:150%; text-align:center; border-radius: 15px 50px;"> ✨ THE END ✨</p>

# %% [markdown]
# <a href="#part_1" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 1</a>
# <a href="#part_2" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:white;">Part - 2</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;">Content</a>

# %% [markdown]
# <h6><span class="label label-danger">Attention</span>You can access the entire study through the following links. Good luck with your work. </h6>

# %% [markdown]
# <ul class="nav flex-column">
#   <h3 class="list-group-item list-group-item-action active" data-toggle="list" role="tab" aria-controls="home" style="background-color:#FF6961; color:white"><b> Time Series Decomposition Example - 1
#  </b></h3>
#   <li class="nav-item">
#     <a class="nav-link" style="background-color:; color:red" href="https://github.com/huseyincenik/data_science/tree/main/time_series_analysis/time_series_decomposition_example_1"><b>Github Notebook Link</b></a>
#   </li>
#     <li class="nav-item">
#     <a class="nav-link" style="background-color:; color:blue" href="https://www.kaggle.com/code/huseyincenik/time-series-decomposition-example-1"><b>Kaggle Notebook Link</b></a>
#   </li>
#   <li class="nav-item">
#     <a class="nav-link" style="background-color:; color:green" href="https://www.linkedin.com/in/huseyincenik/"><b>My Linkedin Account</b></a>
#   </li>
# </ul>
